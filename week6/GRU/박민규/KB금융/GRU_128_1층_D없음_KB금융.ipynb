# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=db3fa62f708a5f0a4ca292f80acc41ddd3bd573943f7a555bebfa01367e74d5b
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 1: val_loss improved from inf to 0.00304, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 4s 25ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 2/100
# 31/34 [==========================>...] - ETA: 0s - loss: 7.8575e-04
# Epoch 2: val_loss improved from 0.00304 to 0.00207, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 7.8673e-04 - val_loss: 0.0021
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 6.4391e-04
# Epoch 3: val_loss did not improve from 0.00207
# 34/34 [==============================] - 1s 18ms/step - loss: 6.4391e-04 - val_loss: 0.0023
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.1431e-04
# Epoch 4: val_loss did not improve from 0.00207
# 34/34 [==============================] - 1s 17ms/step - loss: 8.0359e-04 - val_loss: 0.0027
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.3756e-04
# Epoch 5: val_loss improved from 0.00207 to 0.00206, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 6.1792e-04 - val_loss: 0.0021
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.9316e-04
# Epoch 6: val_loss improved from 0.00206 to 0.00089, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 5.1478e-04 - val_loss: 8.8745e-04
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.8664e-04
# Epoch 7: val_loss did not improve from 0.00089
# 34/34 [==============================] - 1s 17ms/step - loss: 5.6144e-04 - val_loss: 0.0019
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.4872e-04
# Epoch 8: val_loss did not improve from 0.00089
# 34/34 [==============================] - 1s 17ms/step - loss: 4.5298e-04 - val_loss: 0.0011
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.2075e-04
# Epoch 9: val_loss did not improve from 0.00089
# 34/34 [==============================] - 1s 17ms/step - loss: 5.1829e-04 - val_loss: 0.0030
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.1794e-04
# Epoch 10: val_loss did not improve from 0.00089
# 34/34 [==============================] - 1s 18ms/step - loss: 6.0574e-04 - val_loss: 0.0016
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1735e-04
# Epoch 11: val_loss did not improve from 0.00089
# 34/34 [==============================] - 1s 18ms/step - loss: 4.1434e-04 - val_loss: 0.0013
# Epoch 12/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.8835e-04
# Epoch 12: val_loss improved from 0.00089 to 0.00084, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 4.3804e-04 - val_loss: 8.3545e-04
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3914e-04
# Epoch 13: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 16ms/step - loss: 5.3464e-04 - val_loss: 9.0490e-04
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.5333e-04
# Epoch 14: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 17ms/step - loss: 6.8826e-04 - val_loss: 0.0011
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 6.4229e-04
# Epoch 15: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 18ms/step - loss: 6.4229e-04 - val_loss: 0.0018
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.7810e-04
# Epoch 16: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 17ms/step - loss: 5.5810e-04 - val_loss: 0.0013
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 4.2517e-04
# Epoch 17: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 18ms/step - loss: 4.2517e-04 - val_loss: 0.0010
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.4492e-04
# Epoch 18: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 17ms/step - loss: 6.4433e-04 - val_loss: 0.0013
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.6559e-04
# Epoch 19: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 16ms/step - loss: 4.6321e-04 - val_loss: 0.0020
# Epoch 20/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.2130e-04
# Epoch 20: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 17ms/step - loss: 4.1426e-04 - val_loss: 0.0010
# Epoch 21/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.5103e-04
# Epoch 21: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 18ms/step - loss: 4.7916e-04 - val_loss: 0.0024
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6407e-04
# Epoch 22: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7291e-04 - val_loss: 0.0010
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:1617.8994326248117
# [1617.8994326248117]
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0130
# Epoch 1: val_loss improved from inf to 0.00104, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 19ms/step - loss: 0.0125 - val_loss: 0.0010
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 6.2381e-04
# Epoch 2: val_loss improved from 0.00104 to 0.00080, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 6.2057e-04 - val_loss: 8.0470e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0409e-04
# Epoch 3: val_loss improved from 0.00080 to 0.00055, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 5.0409e-04 - val_loss: 5.5026e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 4.8612e-04
# Epoch 4: val_loss did not improve from 0.00055
# 69/69 [==============================] - 1s 17ms/step - loss: 4.8612e-04 - val_loss: 6.4405e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3619e-04
# Epoch 5: val_loss did not improve from 0.00055
# 69/69 [==============================] - 1s 17ms/step - loss: 4.3619e-04 - val_loss: 6.8352e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2315e-04
# Epoch 6: val_loss improved from 0.00055 to 0.00041, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 4.2315e-04 - val_loss: 4.1304e-04
# Epoch 7/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9707e-04
# Epoch 7: val_loss did not improve from 0.00041
# 69/69 [==============================] - 1s 16ms/step - loss: 3.9969e-04 - val_loss: 4.4937e-04
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3628e-04
# Epoch 8: val_loss did not improve from 0.00041
# 69/69 [==============================] - 1s 17ms/step - loss: 4.3628e-04 - val_loss: 5.4711e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9756e-04
# Epoch 9: val_loss improved from 0.00041 to 0.00039, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 3.9756e-04 - val_loss: 3.9431e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5206e-04
# Epoch 10: val_loss did not improve from 0.00039
# 69/69 [==============================] - 1s 17ms/step - loss: 4.5206e-04 - val_loss: 4.7703e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0627e-04
# Epoch 11: val_loss did not improve from 0.00039
# 69/69 [==============================] - 1s 16ms/step - loss: 4.0365e-04 - val_loss: 4.7695e-04
# Epoch 12/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.2130e-04
# Epoch 12: val_loss improved from 0.00039 to 0.00038, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 4.3677e-04 - val_loss: 3.8064e-04
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.5799e-04
# Epoch 13: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 17ms/step - loss: 4.5695e-04 - val_loss: 4.3951e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.4473e-04
# Epoch 14: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 17ms/step - loss: 5.4891e-04 - val_loss: 0.0010
# Epoch 15/100
# 66/69 [===========================>..] - ETA: 0s - loss: 6.0497e-04
# Epoch 15: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 18ms/step - loss: 5.9528e-04 - val_loss: 6.9392e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.9069e-04
# Epoch 16: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 18ms/step - loss: 3.9237e-04 - val_loss: 3.9476e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7061e-04
# Epoch 17: val_loss improved from 0.00038 to 0.00038, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 3.6989e-04 - val_loss: 3.7679e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3369e-04
# Epoch 18: val_loss improved from 0.00038 to 0.00035, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 4.3369e-04 - val_loss: 3.5339e-04
# Epoch 19/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.9553e-04
# Epoch 19: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 18ms/step - loss: 3.9081e-04 - val_loss: 3.7146e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4558e-04
# Epoch 20: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 4.4558e-04 - val_loss: 9.6506e-04
# Epoch 21/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.0132e-04
# Epoch 21: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 5.0234e-04 - val_loss: 7.3718e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3267e-04
# Epoch 22: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 4.3267e-04 - val_loss: 7.6705e-04
# Epoch 23/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.8498e-04
# Epoch 23: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 3.8425e-04 - val_loss: 3.8485e-04
# Epoch 24/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.2324e-04
# Epoch 24: val_loss improved from 0.00035 to 0.00035, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 4.2089e-04 - val_loss: 3.5248e-04
# Epoch 25/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.0113e-04
# Epoch 25: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 18ms/step - loss: 3.9874e-04 - val_loss: 5.5238e-04
# Epoch 26/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.3961e-04
# Epoch 26: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 18ms/step - loss: 3.4345e-04 - val_loss: 3.6530e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9014e-04
# Epoch 27: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 3.9014e-04 - val_loss: 4.2207e-04
# Epoch 28/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.3307e-04
# Epoch 28: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 18ms/step - loss: 3.3188e-04 - val_loss: 3.7779e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4446e-04
# Epoch 29: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 4.4446e-04 - val_loss: 5.5618e-04
# Epoch 30/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.4782e-04
# Epoch 30: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 5.5011e-04 - val_loss: 4.9548e-04
# Epoch 31/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.2512e-04
# Epoch 31: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 4.2095e-04 - val_loss: 4.9643e-04
# Epoch 32/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7761e-04
# Epoch 32: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 3.7761e-04 - val_loss: 3.7241e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3673e-04
# Epoch 33: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 4.3673e-04 - val_loss: 4.9332e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 3.4910e-04
# Epoch 34: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 17ms/step - loss: 3.4910e-04 - val_loss: 4.7173e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1359.0573845059175
# [1617.8994326248117, 1359.0573845059175]
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 1: val_loss improved from inf to 0.00145, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 19ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.4819e-04
# Epoch 2: val_loss improved from 0.00145 to 0.00095, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 6.4967e-04 - val_loss: 9.4933e-04
# Epoch 3/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.4772e-04
# Epoch 3: val_loss did not improve from 0.00095
# 104/104 [==============================] - 2s 17ms/step - loss: 5.4745e-04 - val_loss: 0.0013
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.8041e-04
# Epoch 4: val_loss improved from 0.00095 to 0.00075, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 5.7709e-04 - val_loss: 7.5012e-04
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.8412e-04
# Epoch 5: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.8679e-04 - val_loss: 9.4374e-04
# Epoch 6/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.6829e-04
# Epoch 6: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 16ms/step - loss: 4.6333e-04 - val_loss: 0.0010
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.4467e-04
# Epoch 7: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.4378e-04 - val_loss: 9.3239e-04
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.2151e-04
# Epoch 8: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.1950e-04 - val_loss: 0.0013
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.2932e-04
# Epoch 9: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.2855e-04 - val_loss: 0.0011
# Epoch 10/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6994e-04
# Epoch 10: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 16ms/step - loss: 3.6745e-04 - val_loss: 0.0010
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 4.0401e-04
# Epoch 11: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 21ms/step - loss: 4.0401e-04 - val_loss: 9.3848e-04
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2662e-04
# Epoch 12: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.2662e-04 - val_loss: 8.2214e-04
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.5064e-04
# Epoch 13: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 16ms/step - loss: 4.6251e-04 - val_loss: 0.0018
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.4950e-04
# Epoch 14: val_loss did not improve from 0.00075
# 104/104 [==============================] - 2s 17ms/step - loss: 4.4930e-04 - val_loss: 7.7542e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1674.5861651296084
# [1617.8994326248117, 1359.0573845059175, 1674.5861651296084]
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 1: val_loss improved from inf to 0.00090, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 7s 50ms/step - loss: 0.0015 - val_loss: 8.9993e-04
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 7.0534e-04
# Epoch 2: val_loss did not improve from 0.00090
# 113/113 [==============================] - 5s 48ms/step - loss: 7.0534e-04 - val_loss: 0.0011
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 5.8994e-04
# Epoch 3: val_loss improved from 0.00090 to 0.00078, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 48ms/step - loss: 5.8994e-04 - val_loss: 7.7955e-04
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.9337e-04
# Epoch 4: val_loss did not improve from 0.00078
# 113/113 [==============================] - 5s 47ms/step - loss: 6.9329e-04 - val_loss: 8.2531e-04
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.5264e-04
# Epoch 5: val_loss did not improve from 0.00078
# 113/113 [==============================] - 6s 56ms/step - loss: 6.4937e-04 - val_loss: 8.5440e-04
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 6.4680e-04
# Epoch 6: val_loss did not improve from 0.00078
# 113/113 [==============================] - 5s 48ms/step - loss: 6.4680e-04 - val_loss: 0.0013
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 7.5818e-04
# Epoch 7: val_loss did not improve from 0.00078
# 113/113 [==============================] - 5s 48ms/step - loss: 7.5818e-04 - val_loss: 9.8312e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.5453e-04
# Epoch 8: val_loss did not improve from 0.00078
# 113/113 [==============================] - 5s 49ms/step - loss: 5.5453e-04 - val_loss: 0.0023
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.7757e-04
# Epoch 9: val_loss improved from 0.00078 to 0.00050, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 7s 65ms/step - loss: 5.7910e-04 - val_loss: 4.9629e-04
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8683e-04
# Epoch 10: val_loss did not improve from 0.00050
# 113/113 [==============================] - 5s 47ms/step - loss: 4.8683e-04 - val_loss: 0.0017
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.1935e-04
# Epoch 11: val_loss did not improve from 0.00050
# 113/113 [==============================] - 5s 48ms/step - loss: 5.2502e-04 - val_loss: 7.4179e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.6962e-04
# Epoch 12: val_loss did not improve from 0.00050
# 113/113 [==============================] - 5s 47ms/step - loss: 5.6962e-04 - val_loss: 6.8382e-04
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2860e-04
# Epoch 13: val_loss improved from 0.00050 to 0.00043, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 48ms/step - loss: 5.2716e-04 - val_loss: 4.2770e-04
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.8910e-04
# Epoch 14: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 4.8896e-04 - val_loss: 9.8321e-04
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 4.6216e-04
# Epoch 15: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 4.6216e-04 - val_loss: 0.0017
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2193e-04
# Epoch 16: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 47ms/step - loss: 5.2193e-04 - val_loss: 4.4123e-04
# Epoch 17/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.3952e-04
# Epoch 17: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 47ms/step - loss: 5.4410e-04 - val_loss: 0.0039
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9468e-04
# Epoch 18: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 47ms/step - loss: 4.9468e-04 - val_loss: 7.2203e-04
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 4.4421e-04
# Epoch 19: val_loss improved from 0.00043 to 0.00043, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 48ms/step - loss: 4.4421e-04 - val_loss: 4.2689e-04
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6439e-04
# Epoch 20: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 47ms/step - loss: 4.6711e-04 - val_loss: 4.4398e-04
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 4.7406e-04
# Epoch 21: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 4.7406e-04 - val_loss: 4.9655e-04
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 4.6135e-04
# Epoch 22: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 4.6135e-04 - val_loss: 0.0014
# Epoch 23/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0591e-04
# Epoch 23: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 5.0591e-04 - val_loss: 5.4271e-04
# Epoch 24/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5246e-04
# Epoch 24: val_loss did not improve from 0.00043
# 113/113 [==============================] - 6s 50ms/step - loss: 4.5045e-04 - val_loss: 9.1634e-04
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9491e-04
# Epoch 25: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 49ms/step - loss: 4.9495e-04 - val_loss: 9.2634e-04
# Epoch 26/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7571e-04
# Epoch 26: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 48ms/step - loss: 4.7462e-04 - val_loss: 0.0011
# Epoch 27/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1200e-04
# Epoch 27: val_loss did not improve from 0.00043
# 113/113 [==============================] - 7s 63ms/step - loss: 5.1200e-04 - val_loss: 9.1991e-04
# Epoch 28/100
# 113/113 [==============================] - ETA: 0s - loss: 4.3184e-04
# Epoch 28: val_loss did not improve from 0.00043
# 113/113 [==============================] - 5s 49ms/step - loss: 4.3184e-04 - val_loss: 5.0084e-04
# Epoch 29/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5111e-04
# Epoch 29: val_loss did not improve from 0.00043
# 113/113 [==============================] - 6s 49ms/step - loss: 4.5111e-04 - val_loss: 6.5129e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1178.9943277482816
# [1617.8994326248117, 1359.0573845059175, 1674.5861651296084, 1178.9943277482816]

# %%
predict
# Out:
# [array([[60358.76]], dtype=float32),
#  array([[60095.367]], dtype=float32),
#  array([[62967.035]], dtype=float32),
#  array([[59669.586]], dtype=float32)]

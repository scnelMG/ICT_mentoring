# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, dropout = 0.2,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, dropout = 0.2, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=246aa04be100e3b624c5edc0f51ff84bd044a7e78748690b78eb403d4316c0c4
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0183
# Epoch 1: val_loss improved from inf to 0.00698, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 4s 48ms/step - loss: 0.0179 - val_loss: 0.0070
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 2: val_loss did not improve from 0.00698
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0036 - val_loss: 0.0114
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 3: val_loss did not improve from 0.00698
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0023 - val_loss: 0.0108
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 4: val_loss did not improve from 0.00698
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0023 - val_loss: 0.0097
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 5: val_loss improved from 0.00698 to 0.00401, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0021 - val_loss: 0.0142
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 7: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 8: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 9: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 10: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0014 - val_loss: 0.0086
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0014 - val_loss: 0.0095
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 12: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0014 - val_loss: 0.0070
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 13: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0013 - val_loss: 0.0102
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 14: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0015 - val_loss: 0.0130
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.00401
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0012 - val_loss: 0.0098
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4873.8999969787665
# [4873.8999969787665]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 1: val_loss improved from inf to 0.00414, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 5s 37ms/step - loss: 0.0324 - val_loss: 0.0041
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 2: val_loss improved from 0.00414 to 0.00218, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 3: val_loss improved from 0.00218 to 0.00063, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0025 - val_loss: 6.2630e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 4: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 5: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0018 - val_loss: 9.4357e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 6: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0015 - val_loss: 8.9253e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 7: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 10: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 11: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00063
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0052
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:4054.069362991721
# [4873.8999969787665, 4054.069362991721]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 1: val_loss improved from inf to 0.00203, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 7s 47ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss did not improve from 0.00203
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.00203
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 5: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 7: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0013 - val_loss: 0.0040
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 8: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0015 - val_loss: 0.0125
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 9: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0011 - val_loss: 0.0053
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.8723e-04
# Epoch 11: val_loss did not improve from 0.00203
# 104/104 [==============================] - 3s 29ms/step - loss: 9.8349e-04 - val_loss: 0.0068
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:2896.0208731038856
# [4873.8999969787665, 4054.069362991721, 2896.0208731038856]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 1: val_loss improved from inf to 0.00113, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 8s 40ms/step - loss: 0.0119 - val_loss: 0.0011
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0020 - val_loss: 0.0065
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 3: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 4: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 5: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 6: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 7: val_loss did not improve from 0.00113
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0014 - val_loss: 0.0084
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss improved from 0.00113 to 0.00086, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0013 - val_loss: 8.5620e-04
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 9: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 36ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 11: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 12: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 13: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 14: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 36ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 17: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0013 - val_loss: 0.0101
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 18: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0011 - val_loss: 0.0056
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:2556.5990437904293
# [4873.8999969787665, 4054.069362991721, 2896.0208731038856, 2556.5990437904293]

# %%
predict
# Out:
# [array([[56860.906]], dtype=float32),
#  array([[60866.203]], dtype=float32),
#  array([[58608.375]], dtype=float32),
#  array([[59719.156]], dtype=float32)]

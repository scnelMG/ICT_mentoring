# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=28f109af08d9608cf37b7878d33cdb5de10f26814ea926375b78085d65019e77
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 1: val_loss improved from inf to 0.00675, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 4s 48ms/step - loss: 0.0153 - val_loss: 0.0067
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.9672e-04
# Epoch 2: val_loss improved from 0.00675 to 0.00188, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 8.9753e-04 - val_loss: 0.0019
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.7356e-04
# Epoch 3: val_loss improved from 0.00188 to 0.00109, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 6.7704e-04 - val_loss: 0.0011
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.4669e-04
# Epoch 4: val_loss improved from 0.00109 to 0.00081, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 5.4479e-04 - val_loss: 8.0656e-04
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3429e-04
# Epoch 5: val_loss did not improve from 0.00081
# 34/34 [==============================] - 1s 30ms/step - loss: 5.3446e-04 - val_loss: 0.0014
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.8449e-04
# Epoch 6: val_loss did not improve from 0.00081
# 34/34 [==============================] - 1s 29ms/step - loss: 4.8205e-04 - val_loss: 0.0014
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.8647e-04
# Epoch 7: val_loss did not improve from 0.00081
# 34/34 [==============================] - 1s 29ms/step - loss: 4.9718e-04 - val_loss: 0.0014
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4956e-04
# Epoch 8: val_loss did not improve from 0.00081
# 34/34 [==============================] - 1s 31ms/step - loss: 4.4583e-04 - val_loss: 8.4037e-04
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0590e-04
# Epoch 9: val_loss improved from 0.00081 to 0.00062, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 4.1105e-04 - val_loss: 6.1623e-04
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2316e-04
# Epoch 10: val_loss improved from 0.00062 to 0.00060, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 4.2777e-04 - val_loss: 5.9819e-04
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3656e-04
# Epoch 11: val_loss did not improve from 0.00060
# 34/34 [==============================] - 2s 49ms/step - loss: 4.3656e-04 - val_loss: 7.7891e-04
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8052e-04
# Epoch 12: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 3.7972e-04 - val_loss: 7.5151e-04
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.0579e-04
# Epoch 13: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 5.0836e-04 - val_loss: 9.3780e-04
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.8434e-04
# Epoch 14: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 4.8696e-04 - val_loss: 8.9822e-04
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0693e-04
# Epoch 15: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 4.2373e-04 - val_loss: 9.5498e-04
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9062e-04
# Epoch 16: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 3.8225e-04 - val_loss: 0.0011
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0513e-04
# Epoch 17: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 30ms/step - loss: 4.1578e-04 - val_loss: 9.0367e-04
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6416e-04
# Epoch 18: val_loss improved from 0.00060 to 0.00055, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 3.6236e-04 - val_loss: 5.4667e-04
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0012e-04
# Epoch 19: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 3.9454e-04 - val_loss: 9.9975e-04
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2120e-04
# Epoch 20: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 4.1918e-04 - val_loss: 5.5909e-04
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.5483e-04
# Epoch 21: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 4.5924e-04 - val_loss: 7.0743e-04
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2338e-04
# Epoch 22: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 4.4638e-04 - val_loss: 6.9545e-04
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8250e-04
# Epoch 23: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 31ms/step - loss: 3.8134e-04 - val_loss: 5.5596e-04
# Epoch 24/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.6441e-04
# Epoch 24: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 31ms/step - loss: 4.5900e-04 - val_loss: 9.4254e-04
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1699e-04
# Epoch 25: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 4.1434e-04 - val_loss: 0.0011
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.0885e-04
# Epoch 26: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 5.0385e-04 - val_loss: 7.4008e-04
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6149e-04
# Epoch 27: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 3.6054e-04 - val_loss: 7.2880e-04
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9311e-04
# Epoch 28: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 3.9591e-04 - val_loss: 7.8342e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:1491.1103618684278
# [1491.1103618684278]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 1: val_loss improved from inf to 0.00158, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 5s 38ms/step - loss: 0.0213 - val_loss: 0.0016
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 6.6544e-04
# Epoch 2: val_loss improved from 0.00158 to 0.00069, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 6.6544e-04 - val_loss: 6.9080e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 5.1916e-04
# Epoch 3: val_loss did not improve from 0.00069
# 69/69 [==============================] - 2s 30ms/step - loss: 5.1916e-04 - val_loss: 9.4870e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 4.8632e-04
# Epoch 4: val_loss improved from 0.00069 to 0.00063, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.8632e-04 - val_loss: 6.2703e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 5.1292e-04
# Epoch 5: val_loss improved from 0.00063 to 0.00056, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 5.1292e-04 - val_loss: 5.6392e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0457e-04
# Epoch 6: val_loss improved from 0.00056 to 0.00049, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 31ms/step - loss: 5.0457e-04 - val_loss: 4.8937e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4612e-04
# Epoch 7: val_loss improved from 0.00049 to 0.00045, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.4612e-04 - val_loss: 4.4868e-04
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3995e-04
# Epoch 8: val_loss did not improve from 0.00045
# 69/69 [==============================] - 2s 31ms/step - loss: 4.3995e-04 - val_loss: 8.0317e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1963e-04
# Epoch 9: val_loss did not improve from 0.00045
# 69/69 [==============================] - 2s 31ms/step - loss: 4.1963e-04 - val_loss: 8.4357e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 4.9437e-04
# Epoch 10: val_loss improved from 0.00045 to 0.00036, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.9437e-04 - val_loss: 3.6056e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4732e-04
# Epoch 11: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 30ms/step - loss: 4.4732e-04 - val_loss: 3.7050e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8638e-04
# Epoch 12: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 30ms/step - loss: 3.8638e-04 - val_loss: 0.0013
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 5.2408e-04
# Epoch 13: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 30ms/step - loss: 5.2408e-04 - val_loss: 4.0270e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0599e-04
# Epoch 14: val_loss improved from 0.00036 to 0.00036, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.0599e-04 - val_loss: 3.5787e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8419e-04
# Epoch 15: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 29ms/step - loss: 3.8419e-04 - val_loss: 7.5860e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9356e-04
# Epoch 16: val_loss improved from 0.00036 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 31ms/step - loss: 3.9356e-04 - val_loss: 3.2170e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2932e-04
# Epoch 17: val_loss did not improve from 0.00032
# 69/69 [==============================] - 2s 30ms/step - loss: 4.2932e-04 - val_loss: 5.3769e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4317e-04
# Epoch 18: val_loss improved from 0.00032 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.4317e-04 - val_loss: 3.1739e-04
# Epoch 19/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5449e-04
# Epoch 19: val_loss did not improve from 0.00032
# 69/69 [==============================] - 4s 54ms/step - loss: 4.5449e-04 - val_loss: 3.6956e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.4662e-04
# Epoch 20: val_loss did not improve from 0.00032
# 69/69 [==============================] - 3s 38ms/step - loss: 7.5602e-04 - val_loss: 3.2190e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5429e-04
# Epoch 21: val_loss did not improve from 0.00032
# 69/69 [==============================] - 2s 30ms/step - loss: 4.5429e-04 - val_loss: 3.5608e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5047e-04
# Epoch 22: val_loss did not improve from 0.00032
# 69/69 [==============================] - 2s 30ms/step - loss: 4.5047e-04 - val_loss: 3.4264e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0571e-04
# Epoch 23: val_loss did not improve from 0.00032
# 69/69 [==============================] - 2s 30ms/step - loss: 5.0571e-04 - val_loss: 7.2549e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 5.6676e-04
# Epoch 24: val_loss improved from 0.00032 to 0.00031, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 5.6676e-04 - val_loss: 3.1317e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8746e-04
# Epoch 25: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 30ms/step - loss: 3.8746e-04 - val_loss: 3.1586e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6905e-04
# Epoch 26: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 30ms/step - loss: 3.6905e-04 - val_loss: 3.6643e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9445e-04
# Epoch 27: val_loss improved from 0.00031 to 0.00029, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9445e-04 - val_loss: 2.9052e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0160e-04
# Epoch 28: val_loss did not improve from 0.00029
# 69/69 [==============================] - 2s 30ms/step - loss: 4.0160e-04 - val_loss: 2.9374e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 6.2366e-04
# Epoch 29: val_loss did not improve from 0.00029
# 69/69 [==============================] - 2s 30ms/step - loss: 6.2366e-04 - val_loss: 3.0465e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7354e-04
# Epoch 30: val_loss did not improve from 0.00029
# 69/69 [==============================] - 2s 30ms/step - loss: 3.7354e-04 - val_loss: 4.9454e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6044e-04
# Epoch 31: val_loss did not improve from 0.00029
# 69/69 [==============================] - 2s 30ms/step - loss: 3.6044e-04 - val_loss: 3.2157e-04
# Epoch 32/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6440e-04
# Epoch 32: val_loss improved from 0.00029 to 0.00028, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 31ms/step - loss: 3.6440e-04 - val_loss: 2.7615e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 3.3139e-04
# Epoch 33: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 3.3139e-04 - val_loss: 3.0509e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8055e-04
# Epoch 34: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 3.8055e-04 - val_loss: 4.2164e-04
# Epoch 35/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8371e-04
# Epoch 35: val_loss improved from 0.00028 to 0.00028, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 3.8371e-04 - val_loss: 2.7606e-04
# Epoch 36/100
# 69/69 [==============================] - ETA: 0s - loss: 3.4654e-04
# Epoch 36: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 3.4654e-04 - val_loss: 3.0649e-04
# Epoch 37/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9964e-04
# Epoch 37: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9964e-04 - val_loss: 3.3265e-04
# Epoch 38/100
# 69/69 [==============================] - ETA: 0s - loss: 5.1094e-04
# Epoch 38: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 5.1094e-04 - val_loss: 4.7020e-04
# Epoch 39/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1334e-04
# Epoch 39: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 30ms/step - loss: 4.1334e-04 - val_loss: 2.8673e-04
# Epoch 40/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5035e-04
# Epoch 40: val_loss improved from 0.00028 to 0.00027, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 4.5035e-04 - val_loss: 2.6910e-04
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7133e-04
# Epoch 41: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.7133e-04 - val_loss: 5.6377e-04
# Epoch 42/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9817e-04
# Epoch 42: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9817e-04 - val_loss: 2.7410e-04
# Epoch 43/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7453e-04
# Epoch 43: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.7453e-04 - val_loss: 3.3110e-04
# Epoch 44/100
# 69/69 [==============================] - ETA: 0s - loss: 5.3362e-04
# Epoch 44: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 5.3362e-04 - val_loss: 4.2621e-04
# Epoch 45/100
# 69/69 [==============================] - ETA: 0s - loss: 4.6526e-04
# Epoch 45: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 4.6526e-04 - val_loss: 2.7610e-04
# Epoch 46/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9594e-04
# Epoch 46: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9594e-04 - val_loss: 3.3107e-04
# Epoch 47/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9100e-04
# Epoch 47: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9100e-04 - val_loss: 6.7403e-04
# Epoch 48/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6145e-04
# Epoch 48: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.6145e-04 - val_loss: 3.1095e-04
# Epoch 49/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6743e-04
# Epoch 49: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.6743e-04 - val_loss: 6.6773e-04
# Epoch 50/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8476e-04
# Epoch 50: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 3.8476e-04 - val_loss: 3.0107e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1188.0503770065557
# [1491.1103618684278, 1188.0503770065557]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 1: val_loss improved from inf to 0.00150, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 8s 51ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.8592e-04
# Epoch 2: val_loss improved from 0.00150 to 0.00143, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 31ms/step - loss: 4.8357e-04 - val_loss: 0.0014
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1781e-04
# Epoch 3: val_loss did not improve from 0.00143
# 104/104 [==============================] - 3s 30ms/step - loss: 4.1780e-04 - val_loss: 0.0015
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.9845e-04
# Epoch 4: val_loss improved from 0.00143 to 0.00110, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 30ms/step - loss: 3.9895e-04 - val_loss: 0.0011
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3728e-04
# Epoch 5: val_loss did not improve from 0.00110
# 104/104 [==============================] - 3s 30ms/step - loss: 4.3651e-04 - val_loss: 0.0023
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.3188e-04
# Epoch 6: val_loss did not improve from 0.00110
# 104/104 [==============================] - 3s 30ms/step - loss: 5.3047e-04 - val_loss: 0.0013
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.5002e-04
# Epoch 7: val_loss did not improve from 0.00110
# 104/104 [==============================] - 3s 30ms/step - loss: 4.4831e-04 - val_loss: 0.0022
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8737e-04
# Epoch 8: val_loss did not improve from 0.00110
# 104/104 [==============================] - 3s 30ms/step - loss: 3.8547e-04 - val_loss: 0.0013
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.5295e-04
# Epoch 9: val_loss improved from 0.00110 to 0.00057, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 30ms/step - loss: 4.5193e-04 - val_loss: 5.6690e-04
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.6920e-04
# Epoch 10: val_loss did not improve from 0.00057
# 104/104 [==============================] - 3s 30ms/step - loss: 4.6639e-04 - val_loss: 6.6652e-04
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 3.4873e-04
# Epoch 11: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 40ms/step - loss: 3.4873e-04 - val_loss: 0.0016
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8391e-04
# Epoch 12: val_loss did not improve from 0.00057
# 104/104 [==============================] - 3s 30ms/step - loss: 3.8444e-04 - val_loss: 6.0736e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.4501e-04
# Epoch 13: val_loss did not improve from 0.00057
# 104/104 [==============================] - 3s 30ms/step - loss: 4.4276e-04 - val_loss: 0.0019
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3684e-04
# Epoch 14: val_loss improved from 0.00057 to 0.00051, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 31ms/step - loss: 4.3412e-04 - val_loss: 5.0708e-04
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8040e-04
# Epoch 15: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.7979e-04 - val_loss: 0.0022
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3168e-04
# Epoch 16: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 4.3064e-04 - val_loss: 0.0010
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.6839e-04
# Epoch 17: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.6933e-04 - val_loss: 5.2388e-04
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0277e-04
# Epoch 18: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 4.0211e-04 - val_loss: 8.3528e-04
# Epoch 19/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.9026e-04
# Epoch 19: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.8849e-04 - val_loss: 7.8931e-04
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.4035e-04
# Epoch 20: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 4.3923e-04 - val_loss: 0.0016
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8337e-04
# Epoch 21: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.8210e-04 - val_loss: 6.8725e-04
# Epoch 22/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.3926e-04
# Epoch 22: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.3874e-04 - val_loss: 5.1431e-04
# Epoch 23/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8597e-04
# Epoch 23: val_loss did not improve from 0.00051
# 104/104 [==============================] - 5s 46ms/step - loss: 3.8597e-04 - val_loss: 0.0022
# Epoch 24/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5034e-04
# Epoch 24: val_loss did not improve from 0.00051
# 104/104 [==============================] - 3s 30ms/step - loss: 3.5204e-04 - val_loss: 5.4801e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1053.1580015114928
# [1491.1103618684278, 1188.0503770065557, 1053.1580015114928]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 1: val_loss improved from inf to 0.00168, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 8s 41ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 7.9044e-04
# Epoch 2: val_loss improved from 0.00168 to 0.00141, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 7.9044e-04 - val_loss: 0.0014
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 6.0186e-04
# Epoch 3: val_loss did not improve from 0.00141
# 113/113 [==============================] - 4s 36ms/step - loss: 6.0186e-04 - val_loss: 0.0018
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 6.2502e-04
# Epoch 4: val_loss did not improve from 0.00141
# 113/113 [==============================] - 4s 36ms/step - loss: 6.2502e-04 - val_loss: 0.0032
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.6201e-04
# Epoch 5: val_loss did not improve from 0.00141
# 113/113 [==============================] - 4s 36ms/step - loss: 5.7039e-04 - val_loss: 0.0018
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 5.9862e-04
# Epoch 6: val_loss did not improve from 0.00141
# 113/113 [==============================] - 4s 36ms/step - loss: 5.9862e-04 - val_loss: 0.0025
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 5.9725e-04
# Epoch 7: val_loss improved from 0.00141 to 0.00086, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 5.9725e-04 - val_loss: 8.6247e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.4532e-04
# Epoch 8: val_loss improved from 0.00086 to 0.00068, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 4s 37ms/step - loss: 5.4532e-04 - val_loss: 6.8426e-04
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9422e-04
# Epoch 9: val_loss improved from 0.00068 to 0.00044, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 4.9422e-04 - val_loss: 4.3717e-04
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 5.7802e-04
# Epoch 10: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.7802e-04 - val_loss: 8.6847e-04
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 6.3909e-04
# Epoch 11: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 37ms/step - loss: 6.3909e-04 - val_loss: 5.7068e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.5081e-04
# Epoch 12: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.5081e-04 - val_loss: 0.0035
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 5.3986e-04
# Epoch 13: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.3986e-04 - val_loss: 5.2320e-04
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2266e-04
# Epoch 14: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.2813e-04 - val_loss: 0.0028
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 4.6061e-04
# Epoch 15: val_loss did not improve from 0.00044
# 113/113 [==============================] - 6s 53ms/step - loss: 4.6061e-04 - val_loss: 5.1910e-04
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9109e-04
# Epoch 16: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 4.9109e-04 - val_loss: 0.0022
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9574e-04
# Epoch 17: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 4.9574e-04 - val_loss: 6.1813e-04
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2945e-04
# Epoch 18: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.2900e-04 - val_loss: 0.0012
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1305e-04
# Epoch 19: val_loss did not improve from 0.00044
# 113/113 [==============================] - 4s 36ms/step - loss: 5.1305e-04 - val_loss: 0.0022
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1763.596578992981
# [1491.1103618684278, 1188.0503770065557, 1053.1580015114928, 1763.596578992981]

# %%
predict
# Out:
# [array([[59003.348]], dtype=float32),
#  array([[59522.734]], dtype=float32),
#  array([[60345.55]], dtype=float32),
#  array([[60409.297]], dtype=float32)]

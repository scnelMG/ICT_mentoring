# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, dropout = 0.2,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0514
# Epoch 1: val_loss improved from inf to 0.00891, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 6s 40ms/step - loss: 0.0492 - val_loss: 0.0089
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 2: val_loss improved from 0.00891 to 0.00843, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0065 - val_loss: 0.0084
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 3: val_loss improved from 0.00843 to 0.00363, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 4: val_loss did not improve from 0.00363
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0029 - val_loss: 0.0073
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 5: val_loss did not improve from 0.00363
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 6: val_loss did not improve from 0.00363
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 7: val_loss did not improve from 0.00363
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 8: val_loss improved from 0.00363 to 0.00291, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 9: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 10: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0020 - val_loss: 0.0065
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 11: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 12/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 12: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 13: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 14: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0061
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 15: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 0.0075
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 16: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0082
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 17: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0079
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 18: val_loss did not improve from 0.00291
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 0.0084
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:3854.5054852105627
# [3854.5054852105627]
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1594
# Epoch 1: val_loss improved from inf to 0.00956, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 20ms/step - loss: 0.1529 - val_loss: 0.0096
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 2: val_loss improved from 0.00956 to 0.00895, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 3: val_loss improved from 0.00895 to 0.00589, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0059
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 4: val_loss improved from 0.00589 to 0.00482, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 5: val_loss improved from 0.00482 to 0.00416, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 6/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 6: val_loss did not improve from 0.00416
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0028 - val_loss: 0.0055
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 7: val_loss improved from 0.00416 to 0.00130, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 8: val_loss did not improve from 0.00130
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.0047
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 9: val_loss did not improve from 0.00130
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 10: val_loss did not improve from 0.00130
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00130
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 12: val_loss did not improve from 0.00130
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 13: val_loss improved from 0.00130 to 0.00104, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 14/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 14: val_loss did not improve from 0.00104
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 15: val_loss improved from 0.00104 to 0.00074, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 7.3751e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 16: val_loss did not improve from 0.00074
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 8.3086e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 17: val_loss did not improve from 0.00074
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 7.8729e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00074
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 19/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 19: val_loss improved from 0.00074 to 0.00072, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 7.2173e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 20: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 21: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 22/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 7.7140e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 23: val_loss improved from 0.00072 to 0.00062, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 6.1827e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 24: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 6.6553e-04
# Epoch 25/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 25: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0010 - val_loss: 7.2879e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 26: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 6.4866e-04
# Epoch 27/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 27: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 6.8722e-04
# Epoch 28/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.8401e-04
# Epoch 28: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 17ms/step - loss: 9.7902e-04 - val_loss: 0.0016
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 29: val_loss improved from 0.00062 to 0.00057, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 5.7258e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 30: val_loss did not improve from 0.00057
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 9.5997e-04
# Epoch 31/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 31: val_loss did not improve from 0.00057
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 6.3266e-04
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.8214e-04
# Epoch 32: val_loss improved from 0.00057 to 0.00054, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 9.8091e-04 - val_loss: 5.3971e-04
# Epoch 33/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 33: val_loss did not improve from 0.00054
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0010 - val_loss: 5.6477e-04
# Epoch 34/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.3588e-04
# Epoch 34: val_loss did not improve from 0.00054
# 69/69 [==============================] - 1s 17ms/step - loss: 9.5653e-04 - val_loss: 7.4421e-04
# Epoch 35/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.9887e-04
# Epoch 35: val_loss did not improve from 0.00054
# 69/69 [==============================] - 1s 17ms/step - loss: 9.9801e-04 - val_loss: 5.6313e-04
# Epoch 36/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 36: val_loss did not improve from 0.00054
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 5.4211e-04
# Epoch 37/100
# 69/69 [==============================] - ETA: 0s - loss: 8.9177e-04
# Epoch 37: val_loss improved from 0.00054 to 0.00052, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 8.9177e-04 - val_loss: 5.1902e-04
# Epoch 38/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.0505e-04
# Epoch 38: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.9704e-04 - val_loss: 5.3078e-04
# Epoch 39/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.5203e-04
# Epoch 39: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 18ms/step - loss: 8.5100e-04 - val_loss: 6.1439e-04
# Epoch 40/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.3424e-04
# Epoch 40: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.3947e-04 - val_loss: 5.4833e-04
# Epoch 41/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.6793e-04
# Epoch 41: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.6693e-04 - val_loss: 7.8240e-04
# Epoch 42/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.3815e-04
# Epoch 42: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.4162e-04 - val_loss: 5.5133e-04
# Epoch 43/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.0790e-04
# Epoch 43: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.8828e-04 - val_loss: 5.3343e-04
# Epoch 44/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.6215e-04
# Epoch 44: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.6851e-04 - val_loss: 5.3923e-04
# Epoch 45/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.6948e-04
# Epoch 45: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.5252e-04 - val_loss: 7.7720e-04
# Epoch 46/100
# 69/69 [==============================] - ETA: 0s - loss: 8.8034e-04
# Epoch 46: val_loss did not improve from 0.00052
# 69/69 [==============================] - 1s 17ms/step - loss: 8.8034e-04 - val_loss: 6.5519e-04
# Epoch 47/100
# 69/69 [==============================] - ETA: 0s - loss: 8.7024e-04
# Epoch 47: val_loss improved from 0.00052 to 0.00050, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 8.7024e-04 - val_loss: 5.0491e-04
# Epoch 48/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.5380e-04
# Epoch 48: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 9.4806e-04 - val_loss: 5.1465e-04
# Epoch 49/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.2761e-04
# Epoch 49: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 8.2964e-04 - val_loss: 6.1409e-04
# Epoch 50/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.8679e-04
# Epoch 50: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 7.9936e-04 - val_loss: 6.5701e-04
# Epoch 51/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.3621e-04
# Epoch 51: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 17ms/step - loss: 8.3773e-04 - val_loss: 7.1961e-04
# Epoch 52/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.7283e-04
# Epoch 52: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 17ms/step - loss: 7.6474e-04 - val_loss: 5.2807e-04
# Epoch 53/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.5731e-04
# Epoch 53: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 7.5994e-04 - val_loss: 6.0730e-04
# Epoch 54/100
# 69/69 [==============================] - ETA: 0s - loss: 7.7647e-04
# Epoch 54: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 7.7647e-04 - val_loss: 6.0195e-04
# Epoch 55/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.1732e-04
# Epoch 55: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 17ms/step - loss: 8.2523e-04 - val_loss: 5.0562e-04
# Epoch 56/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.4504e-04
# Epoch 56: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 17ms/step - loss: 7.3363e-04 - val_loss: 5.4346e-04
# Epoch 57/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.8392e-04
# Epoch 57: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 18ms/step - loss: 6.8504e-04 - val_loss: 5.5765e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1690.6637119847996
# [3854.5054852105627, 1690.6637119847996]
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 1: val_loss improved from inf to 0.00766, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 20ms/step - loss: 0.0286 - val_loss: 0.0077
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 2: val_loss improved from 0.00766 to 0.00264, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0068 - val_loss: 0.0026
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 3: val_loss improved from 0.00264 to 0.00168, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 4: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 5: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 6: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 7: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 8: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 9: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 11: val_loss did not improve from 0.00168
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 12: val_loss improved from 0.00168 to 0.00143, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 13/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 13: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 14/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 14: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 15: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 17/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 17: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 18: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 19: val_loss did not improve from 0.00143
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 20: val_loss improved from 0.00143 to 0.00137, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.6486e-04
# Epoch 21: val_loss did not improve from 0.00137
# 104/104 [==============================] - 2s 17ms/step - loss: 9.7607e-04 - val_loss: 0.0062
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 22: val_loss did not improve from 0.00137
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 23/100
# 102/104 [============================>.] - ETA: 0s - loss: 9.3425e-04
# Epoch 23: val_loss did not improve from 0.00137
# 104/104 [==============================] - 2s 17ms/step - loss: 9.3659e-04 - val_loss: 0.0020
# Epoch 24/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 24: val_loss did not improve from 0.00137
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 25/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 25: val_loss did not improve from 0.00137
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 26/100
# 102/104 [============================>.] - ETA: 0s - loss: 9.5188e-04
# Epoch 26: val_loss improved from 0.00137 to 0.00135, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 9.4419e-04 - val_loss: 0.0014
# Epoch 27/100
# 104/104 [==============================] - ETA: 0s - loss: 8.5553e-04
# Epoch 27: val_loss did not improve from 0.00135
# 104/104 [==============================] - 2s 17ms/step - loss: 8.5553e-04 - val_loss: 0.0042
# Epoch 28/100
# 102/104 [============================>.] - ETA: 0s - loss: 9.4763e-04
# Epoch 28: val_loss improved from 0.00135 to 0.00126, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 9.4656e-04 - val_loss: 0.0013
# Epoch 29/100
# 102/104 [============================>.] - ETA: 0s - loss: 8.6021e-04
# Epoch 29: val_loss did not improve from 0.00126
# 104/104 [==============================] - 2s 17ms/step - loss: 8.6356e-04 - val_loss: 0.0018
# Epoch 30/100
# 101/104 [============================>.] - ETA: 0s - loss: 8.2730e-04
# Epoch 30: val_loss improved from 0.00126 to 0.00085, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 8.3242e-04 - val_loss: 8.5389e-04
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 8.6289e-04
# Epoch 31: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 8.6289e-04 - val_loss: 0.0020
# Epoch 32/100
# 102/104 [============================>.] - ETA: 0s - loss: 8.1105e-04
# Epoch 32: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 8.1488e-04 - val_loss: 0.0048
# Epoch 33/100
# 101/104 [============================>.] - ETA: 0s - loss: 9.1954e-04
# Epoch 33: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 9.0597e-04 - val_loss: 0.0013
# Epoch 34/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.9405e-04
# Epoch 34: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 18ms/step - loss: 7.8980e-04 - val_loss: 0.0017
# Epoch 35/100
# 104/104 [==============================] - ETA: 0s - loss: 7.8382e-04
# Epoch 35: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 7.8382e-04 - val_loss: 9.5331e-04
# Epoch 36/100
# 104/104 [==============================] - ETA: 0s - loss: 8.2095e-04
# Epoch 36: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 8.2095e-04 - val_loss: 0.0021
# Epoch 37/100
# 104/104 [==============================] - ETA: 0s - loss: 8.0705e-04
# Epoch 37: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 8.0705e-04 - val_loss: 0.0013
# Epoch 38/100
# 101/104 [============================>.] - ETA: 0s - loss: 7.2116e-04
# Epoch 38: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 7.4537e-04 - val_loss: 9.9817e-04
# Epoch 39/100
# 104/104 [==============================] - ETA: 0s - loss: 7.6730e-04
# Epoch 39: val_loss did not improve from 0.00085
# 104/104 [==============================] - 2s 17ms/step - loss: 7.6730e-04 - val_loss: 8.9264e-04
# Epoch 40/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.2812e-04
# Epoch 40: val_loss improved from 0.00085 to 0.00068, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 7.3185e-04 - val_loss: 6.8340e-04
# Epoch 41/100
# 104/104 [==============================] - ETA: 0s - loss: 7.0634e-04
# Epoch 41: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 7.0634e-04 - val_loss: 0.0012
# Epoch 42/100
# 104/104 [==============================] - ETA: 0s - loss: 7.9854e-04
# Epoch 42: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 7.9854e-04 - val_loss: 0.0020
# Epoch 43/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.7011e-04
# Epoch 43: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 18ms/step - loss: 7.6620e-04 - val_loss: 0.0013
# Epoch 44/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.5058e-04
# Epoch 44: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 7.4889e-04 - val_loss: 0.0010
# Epoch 45/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.7445e-04
# Epoch 45: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 18ms/step - loss: 7.7856e-04 - val_loss: 0.0015
# Epoch 46/100
# 104/104 [==============================] - ETA: 0s - loss: 7.5099e-04
# Epoch 46: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 7.5099e-04 - val_loss: 8.5676e-04
# Epoch 47/100
# 102/104 [============================>.] - ETA: 0s - loss: 8.0773e-04
# Epoch 47: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 8.0711e-04 - val_loss: 0.0013
# Epoch 48/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.4060e-04
# Epoch 48: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 21ms/step - loss: 7.4006e-04 - val_loss: 0.0014
# Epoch 49/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.9392e-04
# Epoch 49: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 19ms/step - loss: 6.9290e-04 - val_loss: 0.0013
# Epoch 50/100
# 101/104 [============================>.] - ETA: 0s - loss: 7.9801e-04
# Epoch 50: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 7.9672e-04 - val_loss: 0.0027
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:2179.8603571687668
# [3854.5054852105627, 1690.6637119847996, 2179.8603571687668]
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0304
# Epoch 1: val_loss improved from inf to 0.03147, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 6s 46ms/step - loss: 0.0302 - val_loss: 0.0315
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 2: val_loss improved from 0.03147 to 0.00683, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 3: val_loss improved from 0.00683 to 0.00224, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 4: val_loss did not improve from 0.00224
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 5: val_loss did not improve from 0.00224
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss did not improve from 0.00224
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 7: val_loss did not improve from 0.00224
# 113/113 [==============================] - 6s 53ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 8: val_loss did not improve from 0.00224
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 9: val_loss did not improve from 0.00224
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 10: val_loss improved from 0.00224 to 0.00116, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 12: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 15/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 16: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 17/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 17: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 18: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 19: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 20/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 20: val_loss did not improve from 0.00116
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0010 - val_loss: 0.0023
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1747.9721752201267
# [3854.5054852105627, 1690.6637119847996, 2179.8603571687668, 1747.9721752201267]

# %%
predict
# Out:
# [array([[59742.734]], dtype=float32),
#  array([[59032.8]], dtype=float32),
#  array([[59560.5]], dtype=float32),
#  array([[60084.95]], dtype=float32)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=6566a84f5e80a6ca3a0ff63f8dc36d5ffdf2f9b50e701d6f5051ef6a37928e5d
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 1: val_loss improved from inf to 0.00773, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 3s 31ms/step - loss: 0.0087 - val_loss: 0.0077
# Epoch 2/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 2: val_loss did not improve from 0.00773
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 0.0108
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 3: val_loss did not improve from 0.00773
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0077
# Epoch 4/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 4: val_loss improved from 0.00773 to 0.00568, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 5/100
# 30/34 [=========================>....] - ETA: 0s - loss: 8.9009e-04
# Epoch 5: val_loss did not improve from 0.00568
# 34/34 [==============================] - 0s 13ms/step - loss: 8.6167e-04 - val_loss: 0.0075
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 9.4235e-04
# Epoch 6: val_loss did not improve from 0.00568
# 34/34 [==============================] - 0s 12ms/step - loss: 9.2130e-04 - val_loss: 0.0067
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 7.2215e-04
# Epoch 7: val_loss improved from 0.00568 to 0.00394, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 7.1410e-04 - val_loss: 0.0039
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.9420e-04
# Epoch 8: val_loss improved from 0.00394 to 0.00373, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 7.2863e-04 - val_loss: 0.0037
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.9272e-04
# Epoch 9: val_loss improved from 0.00373 to 0.00339, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 7.1038e-04 - val_loss: 0.0034
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 6.1140e-04
# Epoch 10: val_loss improved from 0.00339 to 0.00257, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 6.3187e-04 - val_loss: 0.0026
# Epoch 11/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.4011e-04
# Epoch 11: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 12ms/step - loss: 6.2650e-04 - val_loss: 0.0045
# Epoch 12/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.9574e-04
# Epoch 12: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 13ms/step - loss: 5.9326e-04 - val_loss: 0.0031
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 7.4128e-04
# Epoch 13: val_loss improved from 0.00257 to 0.00199, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 7.3852e-04 - val_loss: 0.0020
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.3139e-04
# Epoch 14: val_loss improved from 0.00199 to 0.00186, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 6.4486e-04 - val_loss: 0.0019
# Epoch 15/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.8880e-04
# Epoch 15: val_loss did not improve from 0.00186
# 34/34 [==============================] - 0s 13ms/step - loss: 6.6337e-04 - val_loss: 0.0023
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.0533e-04
# Epoch 16: val_loss did not improve from 0.00186
# 34/34 [==============================] - 0s 13ms/step - loss: 7.8739e-04 - val_loss: 0.0029
# Epoch 17/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.8620e-04
# Epoch 17: val_loss improved from 0.00186 to 0.00151, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 6.1483e-04 - val_loss: 0.0015
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.8401e-04
# Epoch 18: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 12ms/step - loss: 5.5850e-04 - val_loss: 0.0029
# Epoch 19/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.7607e-04
# Epoch 19: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 6.0014e-04 - val_loss: 0.0016
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.7605e-04
# Epoch 20: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 12ms/step - loss: 5.5957e-04 - val_loss: 0.0018
# Epoch 21/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.7430e-04
# Epoch 21: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 5.7492e-04 - val_loss: 0.0033
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.7747e-04
# Epoch 22: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 12ms/step - loss: 5.8491e-04 - val_loss: 0.0030
# Epoch 23/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.8203e-04
# Epoch 23: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 12ms/step - loss: 6.7764e-04 - val_loss: 0.0021
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 4.9125e-04
# Epoch 24: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 4.9125e-04 - val_loss: 0.0020
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.6146e-04
# Epoch 25: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 5.7186e-04 - val_loss: 0.0016
# Epoch 26/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.4100e-04
# Epoch 26: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 5.2094e-04 - val_loss: 0.0027
# Epoch 27/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.9558e-04
# Epoch 27: val_loss did not improve from 0.00151
# 34/34 [==============================] - 0s 13ms/step - loss: 5.9063e-04 - val_loss: 0.0040
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4151.0766900632125
# [4151.0766900632125]
# Epoch 1/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0407
# Epoch 1: val_loss improved from inf to 0.00381, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 4s 20ms/step - loss: 0.0391 - val_loss: 0.0038
# Epoch 2/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 2: val_loss improved from 0.00381 to 0.00205, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 3/100
# 65/69 [===========================>..] - ETA: 0s - loss: 9.2446e-04
# Epoch 3: val_loss improved from 0.00205 to 0.00138, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 9.3246e-04 - val_loss: 0.0014
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.0142e-04
# Epoch 4: val_loss improved from 0.00138 to 0.00072, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 7.9960e-04 - val_loss: 7.1817e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 7.8676e-04
# Epoch 5: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 12ms/step - loss: 7.8676e-04 - val_loss: 7.3124e-04
# Epoch 6/100
# 65/69 [===========================>..] - ETA: 0s - loss: 6.7406e-04
# Epoch 6: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 12ms/step - loss: 6.6977e-04 - val_loss: 0.0011
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 6.4936e-04
# Epoch 7: val_loss did not improve from 0.00072
# 69/69 [==============================] - 1s 12ms/step - loss: 6.3845e-04 - val_loss: 9.3950e-04
# Epoch 8/100
# 65/69 [===========================>..] - ETA: 0s - loss: 5.5025e-04
# Epoch 8: val_loss improved from 0.00072 to 0.00048, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 5.5325e-04 - val_loss: 4.7557e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 5.4694e-04
# Epoch 9: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 12ms/step - loss: 5.4694e-04 - val_loss: 8.2066e-04
# Epoch 10/100
# 65/69 [===========================>..] - ETA: 0s - loss: 5.1847e-04
# Epoch 10: val_loss improved from 0.00048 to 0.00042, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 5.1374e-04 - val_loss: 4.2242e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.9974e-04
# Epoch 11: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 13ms/step - loss: 4.9914e-04 - val_loss: 4.6266e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 5.6315e-04
# Epoch 12: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 19ms/step - loss: 5.6315e-04 - val_loss: 4.8818e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6100e-04
# Epoch 13: val_loss improved from 0.00042 to 0.00042, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 4.5693e-04 - val_loss: 4.1631e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4862e-04
# Epoch 14: val_loss improved from 0.00042 to 0.00039, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 4.4862e-04 - val_loss: 3.9363e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4334e-04
# Epoch 15: val_loss did not improve from 0.00039
# 69/69 [==============================] - 1s 13ms/step - loss: 4.4334e-04 - val_loss: 4.0786e-04
# Epoch 16/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.6684e-04
# Epoch 16: val_loss did not improve from 0.00039
# 69/69 [==============================] - 1s 12ms/step - loss: 4.6876e-04 - val_loss: 4.0903e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.4190e-04
# Epoch 17: val_loss improved from 0.00039 to 0.00037, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 4.4561e-04 - val_loss: 3.7160e-04
# Epoch 18/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.4969e-04
# Epoch 18: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 12ms/step - loss: 4.5584e-04 - val_loss: 0.0011
# Epoch 19/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.4595e-04
# Epoch 19: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 12ms/step - loss: 4.4791e-04 - val_loss: 4.5763e-04
# Epoch 20/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.5166e-04
# Epoch 20: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 12ms/step - loss: 4.6662e-04 - val_loss: 5.6644e-04
# Epoch 21/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.6455e-04
# Epoch 21: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 12ms/step - loss: 4.6522e-04 - val_loss: 4.9151e-04
# Epoch 22/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.0946e-04
# Epoch 22: val_loss improved from 0.00037 to 0.00033, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 4.0976e-04 - val_loss: 3.3168e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.4023e-04
# Epoch 23: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 13ms/step - loss: 4.4626e-04 - val_loss: 4.2732e-04
# Epoch 24/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.3072e-04
# Epoch 24: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 12ms/step - loss: 4.2693e-04 - val_loss: 3.9715e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3299e-04
# Epoch 25: val_loss improved from 0.00033 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 4.3299e-04 - val_loss: 3.1752e-04
# Epoch 26/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.1532e-04
# Epoch 26: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 4.1542e-04 - val_loss: 4.0725e-04
# Epoch 27/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.2113e-04
# Epoch 27: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 4.2286e-04 - val_loss: 7.3012e-04
# Epoch 28/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3667e-04
# Epoch 28: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 4.3895e-04 - val_loss: 3.2095e-04
# Epoch 29/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.2330e-04
# Epoch 29: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 4.2798e-04 - val_loss: 3.3032e-04
# Epoch 30/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.1138e-04
# Epoch 30: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 4.1170e-04 - val_loss: 3.8404e-04
# Epoch 31/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0977e-04
# Epoch 31: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 13ms/step - loss: 4.0943e-04 - val_loss: 4.7467e-04
# Epoch 32/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.9277e-04
# Epoch 32: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 3.9325e-04 - val_loss: 4.3403e-04
# Epoch 33/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.7635e-04
# Epoch 33: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 3.7481e-04 - val_loss: 4.0604e-04
# Epoch 34/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.7245e-04
# Epoch 34: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 3.9146e-04 - val_loss: 3.2351e-04
# Epoch 35/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.8220e-04
# Epoch 35: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 12ms/step - loss: 3.8418e-04 - val_loss: 3.3885e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1558.0694802541072
# [4151.0766900632125, 1558.0694802541072]
# Epoch 1/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0097
# Epoch 1: val_loss improved from inf to 0.00224, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 4s 20ms/step - loss: 0.0094 - val_loss: 0.0022
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 2: val_loss improved from 0.00224 to 0.00177, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 9.8670e-04
# Epoch 3: val_loss improved from 0.00177 to 0.00162, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 9.7979e-04 - val_loss: 0.0016
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.8915e-04
# Epoch 4: val_loss improved from 0.00162 to 0.00142, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 7.8639e-04 - val_loss: 0.0014
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 6.7270e-04
# Epoch 5: val_loss improved from 0.00142 to 0.00131, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 6.7270e-04 - val_loss: 0.0013
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.8437e-04
# Epoch 6: val_loss did not improve from 0.00131
# 104/104 [==============================] - 1s 12ms/step - loss: 5.8097e-04 - val_loss: 0.0017
# Epoch 7/100
# 100/104 [===========================>..] - ETA: 0s - loss: 6.1199e-04
# Epoch 7: val_loss improved from 0.00131 to 0.00112, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 6.0234e-04 - val_loss: 0.0011
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.4758e-04
# Epoch 8: val_loss did not improve from 0.00112
# 104/104 [==============================] - 2s 15ms/step - loss: 5.5251e-04 - val_loss: 0.0013
# Epoch 9/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.2072e-04
# Epoch 9: val_loss did not improve from 0.00112
# 104/104 [==============================] - 2s 15ms/step - loss: 5.1934e-04 - val_loss: 0.0018
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 4.7237e-04
# Epoch 10: val_loss did not improve from 0.00112
# 104/104 [==============================] - 1s 12ms/step - loss: 4.7237e-04 - val_loss: 0.0014
# Epoch 11/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.7804e-04
# Epoch 11: val_loss did not improve from 0.00112
# 104/104 [==============================] - 1s 12ms/step - loss: 4.7426e-04 - val_loss: 0.0016
# Epoch 12/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.8343e-04
# Epoch 12: val_loss did not improve from 0.00112
# 104/104 [==============================] - 1s 12ms/step - loss: 4.7739e-04 - val_loss: 0.0015
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4821e-04
# Epoch 13: val_loss did not improve from 0.00112
# 104/104 [==============================] - 1s 12ms/step - loss: 4.4821e-04 - val_loss: 0.0013
# Epoch 14/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.2398e-04
# Epoch 14: val_loss improved from 0.00112 to 0.00108, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 4.2066e-04 - val_loss: 0.0011
# Epoch 15/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.2351e-04
# Epoch 15: val_loss improved from 0.00108 to 0.00089, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 4.1737e-04 - val_loss: 8.9105e-04
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 4.5596e-04
# Epoch 16: val_loss did not improve from 0.00089
# 104/104 [==============================] - 1s 12ms/step - loss: 4.5596e-04 - val_loss: 0.0012
# Epoch 17/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.8557e-04
# Epoch 17: val_loss did not improve from 0.00089
# 104/104 [==============================] - 1s 12ms/step - loss: 3.8779e-04 - val_loss: 0.0033
# Epoch 18/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.1178e-04
# Epoch 18: val_loss did not improve from 0.00089
# 104/104 [==============================] - 1s 12ms/step - loss: 4.0741e-04 - val_loss: 9.3383e-04
# Epoch 19/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.7701e-04
# Epoch 19: val_loss did not improve from 0.00089
# 104/104 [==============================] - 1s 12ms/step - loss: 3.8530e-04 - val_loss: 0.0010
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.2668e-04
# Epoch 20: val_loss improved from 0.00089 to 0.00072, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 4.3041e-04 - val_loss: 7.1723e-04
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0222e-04
# Epoch 21: val_loss did not improve from 0.00072
# 104/104 [==============================] - 1s 13ms/step - loss: 4.0322e-04 - val_loss: 0.0011
# Epoch 22/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.8157e-04
# Epoch 22: val_loss did not improve from 0.00072
# 104/104 [==============================] - 1s 12ms/step - loss: 3.8691e-04 - val_loss: 9.0174e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0572e-04
# Epoch 23: val_loss did not improve from 0.00072
# 104/104 [==============================] - 1s 13ms/step - loss: 4.0636e-04 - val_loss: 0.0019
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9442e-04
# Epoch 24: val_loss improved from 0.00072 to 0.00068, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 3.9442e-04 - val_loss: 6.7633e-04
# Epoch 25/100
# 104/104 [==============================] - ETA: 0s - loss: 4.0068e-04
# Epoch 25: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 12ms/step - loss: 4.0068e-04 - val_loss: 0.0012
# Epoch 26/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.5664e-04
# Epoch 26: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 12ms/step - loss: 4.5396e-04 - val_loss: 0.0014
# Epoch 27/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5638e-04
# Epoch 27: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 13ms/step - loss: 3.5530e-04 - val_loss: 0.0014
# Epoch 28/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7541e-04
# Epoch 28: val_loss improved from 0.00068 to 0.00064, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 3.7541e-04 - val_loss: 6.3965e-04
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8952e-04
# Epoch 29: val_loss did not improve from 0.00064
# 104/104 [==============================] - 2s 19ms/step - loss: 3.8952e-04 - val_loss: 6.8925e-04
# Epoch 30/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.1190e-04
# Epoch 30: val_loss did not improve from 0.00064
# 104/104 [==============================] - 2s 17ms/step - loss: 4.1335e-04 - val_loss: 9.0623e-04
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9675e-04
# Epoch 31: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 12ms/step - loss: 3.9675e-04 - val_loss: 0.0012
# Epoch 32/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8673e-04
# Epoch 32: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 12ms/step - loss: 3.8673e-04 - val_loss: 7.8938e-04
# Epoch 33/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4380e-04
# Epoch 33: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 12ms/step - loss: 4.4380e-04 - val_loss: 0.0012
# Epoch 34/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4695e-04
# Epoch 34: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 12ms/step - loss: 3.4536e-04 - val_loss: 7.1520e-04
# Epoch 35/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.0808e-04
# Epoch 35: val_loss improved from 0.00064 to 0.00060, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 4.0529e-04 - val_loss: 5.9745e-04
# Epoch 36/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.8796e-04
# Epoch 36: val_loss improved from 0.00060 to 0.00060, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 3.9448e-04 - val_loss: 5.9613e-04
# Epoch 37/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0906e-04
# Epoch 37: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 4.0816e-04 - val_loss: 0.0011
# Epoch 38/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7612e-04
# Epoch 38: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.7605e-04 - val_loss: 0.0028
# Epoch 39/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.5489e-04
# Epoch 39: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.5958e-04 - val_loss: 7.2086e-04
# Epoch 40/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.7218e-04
# Epoch 40: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.6893e-04 - val_loss: 8.2930e-04
# Epoch 41/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5327e-04
# Epoch 41: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.5165e-04 - val_loss: 0.0013
# Epoch 42/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.4880e-04
# Epoch 42: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.4981e-04 - val_loss: 0.0014
# Epoch 43/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1634e-04
# Epoch 43: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 4.1659e-04 - val_loss: 7.9858e-04
# Epoch 44/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5507e-04
# Epoch 44: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.5700e-04 - val_loss: 0.0010
# Epoch 45/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.3102e-04
# Epoch 45: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 3.3259e-04 - val_loss: 0.0014
# Epoch 46/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.4723e-04
# Epoch 46: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 13ms/step - loss: 3.5038e-04 - val_loss: 0.0014
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1301.1049645783116
# [4151.0766900632125, 1558.0694802541072, 1301.1049645783116]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0226
# Epoch 1: val_loss improved from inf to 0.00764, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 6s 25ms/step - loss: 0.0225 - val_loss: 0.0076
# Epoch 2/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss improved from 0.00764 to 0.00534, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 20ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 3/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss improved from 0.00534 to 0.00259, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 21ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.00259
# 113/113 [==============================] - 2s 20ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 9.8910e-04
# Epoch 5: val_loss improved from 0.00259 to 0.00210, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 21ms/step - loss: 9.8910e-04 - val_loss: 0.0021
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 8.2553e-04
# Epoch 6: val_loss did not improve from 0.00210
# 113/113 [==============================] - 2s 20ms/step - loss: 8.2432e-04 - val_loss: 0.0044
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 7.9509e-04
# Epoch 7: val_loss improved from 0.00210 to 0.00188, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 20ms/step - loss: 7.9509e-04 - val_loss: 0.0019
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.8457e-04
# Epoch 8: val_loss did not improve from 0.00188
# 113/113 [==============================] - 2s 20ms/step - loss: 6.8248e-04 - val_loss: 0.0032
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.5592e-04
# Epoch 9: val_loss did not improve from 0.00188
# 113/113 [==============================] - 2s 20ms/step - loss: 6.5910e-04 - val_loss: 0.0025
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.1366e-04
# Epoch 10: val_loss did not improve from 0.00188
# 113/113 [==============================] - 3s 29ms/step - loss: 6.1268e-04 - val_loss: 0.0034
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.9322e-04
# Epoch 11: val_loss did not improve from 0.00188
# 113/113 [==============================] - 3s 24ms/step - loss: 5.9384e-04 - val_loss: 0.0021
# Epoch 12/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.9319e-04
# Epoch 12: val_loss did not improve from 0.00188
# 113/113 [==============================] - 2s 20ms/step - loss: 5.9595e-04 - val_loss: 0.0021
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.6124e-04
# Epoch 13: val_loss improved from 0.00188 to 0.00165, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 25ms/step - loss: 5.5912e-04 - val_loss: 0.0016
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.7115e-04
# Epoch 14: val_loss did not improve from 0.00165
# 113/113 [==============================] - 2s 20ms/step - loss: 5.7102e-04 - val_loss: 0.0027
# Epoch 15/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.2289e-04
# Epoch 15: val_loss improved from 0.00165 to 0.00129, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 21ms/step - loss: 5.2820e-04 - val_loss: 0.0013
# Epoch 16/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.9431e-04
# Epoch 16: val_loss improved from 0.00129 to 0.00115, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 21ms/step - loss: 5.9348e-04 - val_loss: 0.0012
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2650e-04
# Epoch 17: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 5.2650e-04 - val_loss: 0.0013
# Epoch 18/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.9325e-04
# Epoch 18: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 21ms/step - loss: 4.9445e-04 - val_loss: 0.0026
# Epoch 19/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.6414e-04
# Epoch 19: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 5.6240e-04 - val_loss: 0.0013
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9975e-04
# Epoch 20: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 4.9781e-04 - val_loss: 0.0027
# Epoch 21/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.1443e-04
# Epoch 21: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 5.1368e-04 - val_loss: 0.0024
# Epoch 22/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.8511e-04
# Epoch 22: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 4.8463e-04 - val_loss: 0.0030
# Epoch 23/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.2752e-04
# Epoch 23: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 5.2518e-04 - val_loss: 0.0020
# Epoch 24/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.6656e-04
# Epoch 24: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 4.6578e-04 - val_loss: 0.0015
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6249e-04
# Epoch 25: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 4.6820e-04 - val_loss: 0.0020
# Epoch 26/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.8028e-04
# Epoch 26: val_loss did not improve from 0.00115
# 113/113 [==============================] - 2s 20ms/step - loss: 4.8245e-04 - val_loss: 0.0019
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1632.739093165141
# [4151.0766900632125, 1558.0694802541072, 1301.1049645783116, 1632.739093165141]

# %%
predict
# Out:
# [array([[58259.855]], dtype=float32),
#  array([[58963.676]], dtype=float32),
#  array([[59853.06]], dtype=float32),
#  array([[57350.13]], dtype=float32)]

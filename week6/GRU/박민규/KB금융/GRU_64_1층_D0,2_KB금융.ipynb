# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, dropout = 0.2,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0949
# Epoch 1: val_loss improved from inf to 0.00783, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 12ms/step - loss: 0.0852 - val_loss: 0.0078
# Epoch 2/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0081
# Epoch 2: val_loss improved from 0.00783 to 0.00392, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0039
# Epoch 3/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0053
# Epoch 3: val_loss did not improve from 0.00392
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 4/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0050
# Epoch 4: val_loss improved from 0.00392 to 0.00346, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 5/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0037
# Epoch 5: val_loss did not improve from 0.00346
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 6/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0036
# Epoch 6: val_loss improved from 0.00346 to 0.00340, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 7/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0029
# Epoch 7: val_loss improved from 0.00340 to 0.00279, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 8/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0028
# Epoch 8: val_loss improved from 0.00279 to 0.00200, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 9/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0021
# Epoch 9: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 11/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 12/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0019
# Epoch 12: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 13/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0017
# Epoch 13: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 14: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 15/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 16/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0016
# Epoch 16: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 17/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 18/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0033
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4125.561857434731
# [4125.561857434731]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0741
# Epoch 1: val_loss improved from inf to 0.00319, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0741 - val_loss: 0.0032
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 2: val_loss improved from 0.00319 to 0.00254, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0025
# Epoch 3/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 3: val_loss did not improve from 0.00254
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 4/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 4: val_loss improved from 0.00254 to 0.00233, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 5: val_loss did not improve from 0.00233
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 6/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0017
# Epoch 6: val_loss did not improve from 0.00233
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 7/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 7: val_loss improved from 0.00233 to 0.00097, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 9.7342e-04
# Epoch 8/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0016
# Epoch 8: val_loss did not improve from 0.00097
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 9: val_loss improved from 0.00097 to 0.00061, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 6.0575e-04
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 10: val_loss improved from 0.00061 to 0.00053, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 5.2746e-04
# Epoch 11/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 11: val_loss did not improve from 0.00053
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.8569e-04
# Epoch 12/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00053
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 6.9574e-04
# Epoch 13/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 13: val_loss did not improve from 0.00053
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 8.2650e-04
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 14: val_loss did not improve from 0.00053
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 6.6532e-04
# Epoch 15/100
# 60/69 [=========================>....] - ETA: 0s - loss: 9.5167e-04
# Epoch 15: val_loss improved from 0.00053 to 0.00045, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 6ms/step - loss: 9.3263e-04 - val_loss: 4.4949e-04
# Epoch 16/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0010
# Epoch 16: val_loss improved from 0.00045 to 0.00045, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 4.4674e-04
# Epoch 17/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.0650e-04
# Epoch 17: val_loss improved from 0.00045 to 0.00044, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 9.1399e-04 - val_loss: 4.3847e-04
# Epoch 18/100
# 64/69 [==========================>...] - ETA: 0s - loss: 9.7954e-04
# Epoch 18: val_loss did not improve from 0.00044
# 69/69 [==============================] - 0s 7ms/step - loss: 9.9336e-04 - val_loss: 4.4530e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.7557e-04
# Epoch 19: val_loss did not improve from 0.00044
# 69/69 [==============================] - 1s 9ms/step - loss: 9.7194e-04 - val_loss: 4.6493e-04
# Epoch 20/100
# 61/69 [=========================>....] - ETA: 0s - loss: 9.8621e-04
# Epoch 20: val_loss did not improve from 0.00044
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0010 - val_loss: 5.0851e-04
# Epoch 21/100
# 61/69 [=========================>....] - ETA: 0s - loss: 9.0511e-04
# Epoch 21: val_loss did not improve from 0.00044
# 69/69 [==============================] - 1s 10ms/step - loss: 9.2860e-04 - val_loss: 5.5259e-04
# Epoch 22/100
# 60/69 [=========================>....] - ETA: 0s - loss: 9.8583e-04
# Epoch 22: val_loss did not improve from 0.00044
# 69/69 [==============================] - 0s 6ms/step - loss: 9.6242e-04 - val_loss: 4.5119e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.1389e-04
# Epoch 23: val_loss did not improve from 0.00044
# 69/69 [==============================] - 1s 10ms/step - loss: 9.1537e-04 - val_loss: 6.3575e-04
# Epoch 24/100
# 63/69 [==========================>...] - ETA: 0s - loss: 9.1725e-04
# Epoch 24: val_loss did not improve from 0.00044
# 69/69 [==============================] - 0s 7ms/step - loss: 9.0602e-04 - val_loss: 6.3504e-04
# Epoch 25/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.9447e-04
# Epoch 25: val_loss did not improve from 0.00044
# 69/69 [==============================] - 0s 7ms/step - loss: 7.9849e-04 - val_loss: 5.2219e-04
# Epoch 26/100
# 61/69 [=========================>....] - ETA: 0s - loss: 8.9112e-04
# Epoch 26: val_loss improved from 0.00044 to 0.00042, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7354e-04 - val_loss: 4.2117e-04
# Epoch 27/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.2582e-04
# Epoch 27: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 7ms/step - loss: 8.2850e-04 - val_loss: 6.5678e-04
# Epoch 28/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.0028e-04
# Epoch 28: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0119e-04 - val_loss: 5.6460e-04
# Epoch 29/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.1361e-04
# Epoch 29: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0471e-04 - val_loss: 6.2865e-04
# Epoch 30/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.4813e-04
# Epoch 30: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4853e-04 - val_loss: 4.9095e-04
# Epoch 31/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.7560e-04
# Epoch 31: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8558e-04 - val_loss: 6.2661e-04
# Epoch 32/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.0687e-04
# Epoch 32: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1467e-04 - val_loss: 5.9395e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 8.5891e-04
# Epoch 33: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5891e-04 - val_loss: 9.6749e-04
# Epoch 34/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.6643e-04
# Epoch 34: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 7ms/step - loss: 7.7514e-04 - val_loss: 5.1421e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.9883e-04
# Epoch 35: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 6ms/step - loss: 9.1507e-04 - val_loss: 4.3722e-04
# Epoch 36/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.4062e-04
# Epoch 36: val_loss did not improve from 0.00042
# 69/69 [==============================] - 0s 7ms/step - loss: 8.4663e-04 - val_loss: 4.4879e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1764.5311376133252
# [4125.561857434731, 1764.5311376133252]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 1: val_loss improved from inf to 0.00083, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 9ms/step - loss: 0.0049 - val_loss: 8.2795e-04
# Epoch 2/100
#  96/104 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss did not improve from 0.00083
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 3/100
#  96/104 [==========================>...] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss improved from 0.00083 to 0.00081, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 8.0635e-04
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 4: val_loss improved from 0.00081 to 0.00078, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 7.7695e-04
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 9.8607e-04
# Epoch 5: val_loss did not improve from 0.00078
# 104/104 [==============================] - 1s 6ms/step - loss: 9.8607e-04 - val_loss: 0.0010
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 6: val_loss improved from 0.00078 to 0.00070, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0010 - val_loss: 7.0040e-04
# Epoch 7/100
#  95/104 [==========================>...] - ETA: 0s - loss: 8.6695e-04
# Epoch 7: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 6ms/step - loss: 8.6281e-04 - val_loss: 0.0011
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 9.1864e-04
# Epoch 8: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 6ms/step - loss: 9.1864e-04 - val_loss: 0.0014
# Epoch 9/100
# 100/104 [===========================>..] - ETA: 0s - loss: 8.6774e-04
# Epoch 9: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 6ms/step - loss: 8.5824e-04 - val_loss: 0.0017
# Epoch 10/100
#  99/104 [===========================>..] - ETA: 0s - loss: 8.3249e-04
# Epoch 10: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 6ms/step - loss: 8.2391e-04 - val_loss: 0.0016
# Epoch 11/100
#  99/104 [===========================>..] - ETA: 0s - loss: 8.9808e-04
# Epoch 11: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 6ms/step - loss: 8.9373e-04 - val_loss: 0.0011
# Epoch 12/100
#  95/104 [==========================>...] - ETA: 0s - loss: 7.6964e-04
# Epoch 12: val_loss improved from 0.00070 to 0.00068, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 6ms/step - loss: 7.8930e-04 - val_loss: 6.8352e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.6735e-04
# Epoch 13: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.7147e-04 - val_loss: 9.0564e-04
# Epoch 14/100
#  98/104 [===========================>..] - ETA: 0s - loss: 7.7305e-04
# Epoch 14: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.6426e-04 - val_loss: 0.0018
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 7.2472e-04
# Epoch 15: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.3190e-04 - val_loss: 0.0037
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.6758e-04
# Epoch 16: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.6772e-04 - val_loss: 0.0013
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 6.8274e-04
# Epoch 17: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 6.8274e-04 - val_loss: 9.7154e-04
# Epoch 18/100
#  96/104 [==========================>...] - ETA: 0s - loss: 6.9439e-04
# Epoch 18: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.0134e-04 - val_loss: 0.0014
# Epoch 19/100
# 100/104 [===========================>..] - ETA: 0s - loss: 6.8089e-04
# Epoch 19: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 6.7873e-04 - val_loss: 0.0029
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.0701e-04
# Epoch 20: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.0530e-04 - val_loss: 7.3935e-04
# Epoch 21/100
#  96/104 [==========================>...] - ETA: 0s - loss: 7.0412e-04
# Epoch 21: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 7.0796e-04 - val_loss: 0.0038
# Epoch 22/100
# 103/104 [============================>.] - ETA: 0s - loss: 6.6424e-04
# Epoch 22: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 6ms/step - loss: 6.6134e-04 - val_loss: 0.0014
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1472.0906150561927
# [4125.561857434731, 1764.5311376133252, 1472.0906150561927]
# Epoch 1/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 1: val_loss improved from inf to 0.00307, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0031
# Epoch 2/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 2: val_loss improved from 0.00307 to 0.00133, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 3/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 3: val_loss did not improve from 0.00133
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 4/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 4: val_loss did not improve from 0.00133
# 113/113 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 5/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00133
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 6/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss did not improve from 0.00133
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 7/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 7: val_loss did not improve from 0.00133
# 113/113 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 8: val_loss improved from 0.00133 to 0.00086, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 8.6200e-04
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 9: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 10/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 10: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 8ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 11/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 11: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 12/100
# 110/113 [============================>.] - ETA: 0s - loss: 9.6471e-04
# Epoch 12: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 9.6143e-04 - val_loss: 0.0023
# Epoch 13/100
# 107/113 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 13: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 14/100
# 109/113 [===========================>..] - ETA: 0s - loss: 9.4344e-04
# Epoch 14: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 9.4635e-04 - val_loss: 0.0040
# Epoch 15/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0082
# Epoch 16/100
# 107/113 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 16: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 9.9954e-04 - val_loss: 0.0025
# Epoch 17/100
# 110/113 [============================>.] - ETA: 0s - loss: 9.8399e-04
# Epoch 17: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 8ms/step - loss: 9.9060e-04 - val_loss: 0.0024
# Epoch 18/100
# 111/113 [============================>.] - ETA: 0s - loss: 9.8453e-04
# Epoch 18: val_loss did not improve from 0.00086
# 113/113 [==============================] - 1s 9ms/step - loss: 9.8277e-04 - val_loss: 0.0036
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:2060.87157161521
# [4125.561857434731, 1764.5311376133252, 1472.0906150561927, 2060.87157161521]

# %%
predict
# Out:
# [array([[58037.203]], dtype=float32),
#  array([[58170.844]], dtype=float32),
#  array([[61909.242]], dtype=float32),
#  array([[60427.445]], dtype=float32)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, dropout = 0.3,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0263
# Epoch 1: val_loss improved from inf to 0.01391, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0239 - val_loss: 0.0139
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 2: val_loss improved from 0.01391 to 0.00918, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0092
# Epoch 3/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0040
# Epoch 3: val_loss did not improve from 0.00918
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0040 - val_loss: 0.0100
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 4: val_loss did not improve from 0.00918
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0136
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 5: val_loss did not improve from 0.00918
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0114
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 6: val_loss did not improve from 0.00918
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 7: val_loss improved from 0.00918 to 0.00694, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0069
# Epoch 8/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0021
# Epoch 8: val_loss did not improve from 0.00694
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0109
# Epoch 9/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0019
# Epoch 9: val_loss did not improve from 0.00694
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0085
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 10: val_loss did not improve from 0.00694
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0071
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 11: val_loss did not improve from 0.00694
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0086
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss improved from 0.00694 to 0.00580, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 13: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0085
# Epoch 14/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0014
# Epoch 14: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0068
# Epoch 15/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0015
# Epoch 15: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0103
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 16: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 17/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0011
# Epoch 17: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 18/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0076
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 19: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0077
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 20: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0098
# Epoch 21/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0014
# Epoch 21: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0102
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00580
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0078
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:7178.792455928638
# [7178.792455928638]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0689
# Epoch 1: val_loss improved from inf to 0.00722, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 13ms/step - loss: 0.0689 - val_loss: 0.0072
# Epoch 2/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 2: val_loss improved from 0.00722 to 0.00344, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0034
# Epoch 3/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 3: val_loss improved from 0.00344 to 0.00300, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 4/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 4: val_loss improved from 0.00300 to 0.00120, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 5: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 6/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 6: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 7/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 7: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 8: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 9: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00120
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss improved from 0.00120 to 0.00108, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 12/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 12: val_loss did not improve from 0.00108
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 13/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00108
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00108
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 15/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 15: val_loss improved from 0.00108 to 0.00103, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 16/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 16: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 17: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 18/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 18: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 19/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 19: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 20: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 21/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 21: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 22: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 23: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 24/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 24: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 25: val_loss did not improve from 0.00103
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0014
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:3374.09548462215
# [7178.792455928638, 3374.09548462215]
# Epoch 1/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0097
# Epoch 1: val_loss improved from inf to 0.00675, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 11ms/step - loss: 0.0094 - val_loss: 0.0067
# Epoch 2/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 2: val_loss improved from 0.00675 to 0.00219, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 3/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 3: val_loss improved from 0.00219 to 0.00103, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 4/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 4: val_loss did not improve from 0.00103
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 5/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 5: val_loss did not improve from 0.00103
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 6/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss improved from 0.00103 to 0.00100, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 9.9799e-04
# Epoch 7/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 7: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0071
# Epoch 8/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 9: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0010 - val_loss: 0.0091
# Epoch 10/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 10: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 11/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 11: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 12: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 13/100
#  99/104 [===========================>..] - ETA: 0s - loss: 9.4170e-04
# Epoch 13: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 10ms/step - loss: 9.4619e-04 - val_loss: 0.0075
# Epoch 14/100
#  99/104 [===========================>..] - ETA: 0s - loss: 9.6971e-04
# Epoch 14: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0010 - val_loss: 0.0079
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 16/100
#  98/104 [===========================>..] - ETA: 0s - loss: 9.4967e-04
# Epoch 16: val_loss did not improve from 0.00100
# 104/104 [==============================] - 1s 9ms/step - loss: 9.4843e-04 - val_loss: 0.0022
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1811.9407300638773
# [7178.792455928638, 3374.09548462215, 1811.9407300638773]
# Epoch 1/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0096
# Epoch 1: val_loss improved from inf to 0.00178, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 15ms/step - loss: 0.0095 - val_loss: 0.0018
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 2: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 3/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 3: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 4/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 4: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 5/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 5: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 6: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 7/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 7: val_loss did not improve from 0.00178
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 8/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 8: val_loss improved from 0.00178 to 0.00111, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 9: val_loss did not improve from 0.00111
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 10/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 10: val_loss did not improve from 0.00111
# 113/113 [==============================] - 2s 19ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 11: val_loss did not improve from 0.00111
# 113/113 [==============================] - 2s 21ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 12/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 12: val_loss did not improve from 0.00111
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 13/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 13: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 0.0060
# Epoch 14/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 0.0074
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 16/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 16: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 17/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 17: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 18: val_loss did not improve from 0.00111
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 0.0038
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:2029.8813877484627
# [7178.792455928638, 3374.09548462215, 1811.9407300638773, 2029.8813877484627]

# %%
predict
# Out:
# [array([[54834.574]], dtype=float32),
#  array([[58053.406]], dtype=float32),
#  array([[61078.555]], dtype=float32),
#  array([[60052.457]], dtype=float32)]

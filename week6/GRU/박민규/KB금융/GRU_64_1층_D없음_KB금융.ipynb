# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0298
# Epoch 1: val_loss improved from inf to 0.00411, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 2s 19ms/step - loss: 0.0267 - val_loss: 0.0041
# Epoch 2/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss improved from 0.00411 to 0.00290, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 9.2428e-04
# Epoch 3: val_loss did not improve from 0.00290
# 34/34 [==============================] - 0s 11ms/step - loss: 8.9816e-04 - val_loss: 0.0033
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 8.0636e-04
# Epoch 4: val_loss improved from 0.00290 to 0.00219, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 8.0636e-04 - val_loss: 0.0022
# Epoch 5/100
# 29/34 [========================>.....] - ETA: 0s - loss: 8.4031e-04
# Epoch 5: val_loss did not improve from 0.00219
# 34/34 [==============================] - 0s 11ms/step - loss: 7.9793e-04 - val_loss: 0.0028
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.4228e-04
# Epoch 6: val_loss did not improve from 0.00219
# 34/34 [==============================] - 0s 11ms/step - loss: 6.4027e-04 - val_loss: 0.0029
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.7051e-04
# Epoch 7: val_loss did not improve from 0.00219
# 34/34 [==============================] - 0s 11ms/step - loss: 5.7114e-04 - val_loss: 0.0026
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3495e-04
# Epoch 8: val_loss improved from 0.00219 to 0.00212, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 5.4120e-04 - val_loss: 0.0021
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.9425e-04
# Epoch 9: val_loss did not improve from 0.00212
# 34/34 [==============================] - 0s 11ms/step - loss: 6.0406e-04 - val_loss: 0.0024
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.6230e-04
# Epoch 10: val_loss did not improve from 0.00212
# 34/34 [==============================] - 0s 11ms/step - loss: 5.3402e-04 - val_loss: 0.0025
# Epoch 11/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.5853e-04
# Epoch 11: val_loss did not improve from 0.00212
# 34/34 [==============================] - 0s 11ms/step - loss: 4.5507e-04 - val_loss: 0.0026
# Epoch 12/100
# 29/34 [========================>.....] - ETA: 0s - loss: 5.6622e-04
# Epoch 12: val_loss did not improve from 0.00212
# 34/34 [==============================] - 0s 12ms/step - loss: 5.4672e-04 - val_loss: 0.0022
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 5.0827e-04
# Epoch 13: val_loss improved from 0.00212 to 0.00138, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 5.0827e-04 - val_loss: 0.0014
# Epoch 14/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.2829e-04
# Epoch 14: val_loss did not improve from 0.00138
# 34/34 [==============================] - 0s 11ms/step - loss: 5.1400e-04 - val_loss: 0.0016
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3632e-04
# Epoch 15: val_loss improved from 0.00138 to 0.00124, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3632e-04 - val_loss: 0.0012
# Epoch 16/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.1352e-04
# Epoch 16: val_loss did not improve from 0.00124
# 34/34 [==============================] - 0s 11ms/step - loss: 4.1961e-04 - val_loss: 0.0014
# Epoch 17/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.9953e-04
# Epoch 17: val_loss did not improve from 0.00124
# 34/34 [==============================] - 0s 11ms/step - loss: 4.0766e-04 - val_loss: 0.0013
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.2849e-04
# Epoch 18: val_loss did not improve from 0.00124
# 34/34 [==============================] - 0s 12ms/step - loss: 4.1169e-04 - val_loss: 0.0014
# Epoch 19/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7557e-04
# Epoch 19: val_loss did not improve from 0.00124
# 34/34 [==============================] - 0s 11ms/step - loss: 3.7642e-04 - val_loss: 0.0014
# Epoch 20/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.4990e-04
# Epoch 20: val_loss did not improve from 0.00124
# 34/34 [==============================] - 0s 12ms/step - loss: 3.7284e-04 - val_loss: 0.0013
# Epoch 21/100
# 29/34 [========================>.....] - ETA: 0s - loss: 4.0724e-04
# Epoch 21: val_loss improved from 0.00124 to 0.00116, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 4.0578e-04 - val_loss: 0.0012
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.9011e-04
# Epoch 22: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 11ms/step - loss: 3.9785e-04 - val_loss: 0.0017
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 4.5813e-04
# Epoch 23: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 13ms/step - loss: 4.5813e-04 - val_loss: 0.0013
# Epoch 24/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.5641e-04
# Epoch 24: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 11ms/step - loss: 3.9431e-04 - val_loss: 0.0017
# Epoch 25/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.0170e-04
# Epoch 25: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 11ms/step - loss: 4.1002e-04 - val_loss: 0.0013
# Epoch 26/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.9071e-04
# Epoch 26: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 11ms/step - loss: 3.8354e-04 - val_loss: 0.0015
# Epoch 27/100
# 29/34 [========================>.....] - ETA: 0s - loss: 4.4772e-04
# Epoch 27: val_loss improved from 0.00116 to 0.00100, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 4.4427e-04 - val_loss: 9.9657e-04
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 4.5566e-04
# Epoch 28: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 12ms/step - loss: 4.5566e-04 - val_loss: 0.0012
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 3.4783e-04
# Epoch 29: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 12ms/step - loss: 3.4783e-04 - val_loss: 0.0014
# Epoch 30/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.4637e-04
# Epoch 30: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 12ms/step - loss: 3.5578e-04 - val_loss: 0.0012
# Epoch 31/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.0518e-04
# Epoch 31: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.2224e-04 - val_loss: 0.0011
# Epoch 32/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7975e-04
# Epoch 32: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.8895e-04 - val_loss: 0.0016
# Epoch 33/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.5901e-04
# Epoch 33: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.5048e-04 - val_loss: 0.0013
# Epoch 34/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.3315e-04
# Epoch 34: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.2771e-04 - val_loss: 0.0013
# Epoch 35/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.3742e-04
# Epoch 35: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.6164e-04 - val_loss: 0.0012
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 3.6875e-04
# Epoch 36: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 12ms/step - loss: 3.6875e-04 - val_loss: 0.0012
# Epoch 37/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.6065e-04
# Epoch 37: val_loss did not improve from 0.00100
# 34/34 [==============================] - 0s 11ms/step - loss: 3.6373e-04 - val_loss: 0.0014
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:2435.0001660470407
# [2435.0001660470407]
# Epoch 1/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 1: val_loss improved from inf to 0.00154, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 15ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 2/100
# 65/69 [===========================>..] - ETA: 0s - loss: 6.7487e-04
# Epoch 2: val_loss improved from 0.00154 to 0.00056, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 6.6187e-04 - val_loss: 5.5524e-04
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 5.6326e-04
# Epoch 3: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 5.6157e-04 - val_loss: 8.6768e-04
# Epoch 4/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.9795e-04
# Epoch 4: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 5.0175e-04 - val_loss: 8.8949e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 7.0782e-04
# Epoch 5: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 12ms/step - loss: 7.0782e-04 - val_loss: 5.6654e-04
# Epoch 6/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.5989e-04
# Epoch 6: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 5.5734e-04 - val_loss: 9.7336e-04
# Epoch 7/100
# 64/69 [==========================>...] - ETA: 0s - loss: 4.7993e-04
# Epoch 7: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 4.7107e-04 - val_loss: 5.5978e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3238e-04
# Epoch 8: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 4.2974e-04 - val_loss: 6.1934e-04
# Epoch 9/100
# 64/69 [==========================>...] - ETA: 0s - loss: 5.0314e-04
# Epoch 9: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 5.0924e-04 - val_loss: 0.0012
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9364e-04
# Epoch 10: val_loss did not improve from 0.00056
# 69/69 [==============================] - 1s 11ms/step - loss: 3.9572e-04 - val_loss: 6.3535e-04
# Epoch 11/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.7133e-04
# Epoch 11: val_loss improved from 0.00056 to 0.00040, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 4.6900e-04 - val_loss: 3.9970e-04
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.9881e-04
# Epoch 12: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 5.0174e-04 - val_loss: 6.4227e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9961e-04
# Epoch 13: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 3.9961e-04 - val_loss: 7.1549e-04
# Epoch 14/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.4976e-04
# Epoch 14: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 4.5035e-04 - val_loss: 6.2569e-04
# Epoch 15/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.7725e-04
# Epoch 15: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 10ms/step - loss: 3.7450e-04 - val_loss: 8.1274e-04
# Epoch 16/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7815e-04
# Epoch 16: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 3.8453e-04 - val_loss: 4.5908e-04
# Epoch 17/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.0150e-04
# Epoch 17: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 4.0502e-04 - val_loss: 8.2899e-04
# Epoch 18/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.0400e-04
# Epoch 18: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 4.0032e-04 - val_loss: 4.3872e-04
# Epoch 19/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.4349e-04
# Epoch 19: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 4.5371e-04 - val_loss: 6.1121e-04
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7564e-04
# Epoch 20: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 10ms/step - loss: 3.7936e-04 - val_loss: 6.7664e-04
# Epoch 21/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.5805e-04
# Epoch 21: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 11ms/step - loss: 4.5362e-04 - val_loss: 4.4171e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1590.0327878075273
# [2435.0001660470407, 1590.0327878075273]
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 1: val_loss improved from inf to 0.00131, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 14ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 2/100
# 100/104 [===========================>..] - ETA: 0s - loss: 8.0827e-04
# Epoch 2: val_loss improved from 0.00131 to 0.00088, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 8.0012e-04 - val_loss: 8.7859e-04
# Epoch 3/100
#  99/104 [===========================>..] - ETA: 0s - loss: 6.0150e-04
# Epoch 3: val_loss improved from 0.00088 to 0.00075, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 5.9635e-04 - val_loss: 7.4905e-04
# Epoch 4/100
# 101/104 [============================>.] - ETA: 0s - loss: 6.4287e-04
# Epoch 4: val_loss improved from 0.00075 to 0.00063, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 6.3303e-04 - val_loss: 6.3334e-04
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.3009e-04
# Epoch 5: val_loss did not improve from 0.00063
# 104/104 [==============================] - 1s 11ms/step - loss: 5.2727e-04 - val_loss: 7.4166e-04
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3806e-04
# Epoch 6: val_loss did not improve from 0.00063
# 104/104 [==============================] - 1s 11ms/step - loss: 4.3607e-04 - val_loss: 9.3773e-04
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.7243e-04
# Epoch 7: val_loss improved from 0.00063 to 0.00058, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 4.6851e-04 - val_loss: 5.8412e-04
# Epoch 8/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.3112e-04
# Epoch 8: val_loss improved from 0.00058 to 0.00058, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 4.2696e-04 - val_loss: 5.7515e-04
# Epoch 9/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.3459e-04
# Epoch 9: val_loss did not improve from 0.00058
# 104/104 [==============================] - 1s 11ms/step - loss: 4.3092e-04 - val_loss: 5.8635e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7537e-04
# Epoch 10: val_loss did not improve from 0.00058
# 104/104 [==============================] - 1s 11ms/step - loss: 3.7537e-04 - val_loss: 6.1511e-04
# Epoch 11/100
# 100/104 [===========================>..] - ETA: 0s - loss: 5.5011e-04
# Epoch 11: val_loss improved from 0.00058 to 0.00053, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 5.5031e-04 - val_loss: 5.2745e-04
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 4.7010e-04
# Epoch 12: val_loss did not improve from 0.00053
# 104/104 [==============================] - 2s 16ms/step - loss: 4.7010e-04 - val_loss: 6.3483e-04
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.1318e-04
# Epoch 13: val_loss did not improve from 0.00053
# 104/104 [==============================] - 2s 19ms/step - loss: 5.1050e-04 - val_loss: 5.4827e-04
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 3.5925e-04
# Epoch 14: val_loss did not improve from 0.00053
# 104/104 [==============================] - 2s 18ms/step - loss: 3.5925e-04 - val_loss: 7.3475e-04
# Epoch 15/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.0912e-04
# Epoch 15: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 4.0631e-04 - val_loss: 6.0294e-04
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8115e-04
# Epoch 16: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 3.8115e-04 - val_loss: 5.4266e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 5.4665e-04
# Epoch 17: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 5.4665e-04 - val_loss: 5.5517e-04
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.7407e-04
# Epoch 18: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 3.7412e-04 - val_loss: 6.1821e-04
# Epoch 19/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.4010e-04
# Epoch 19: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 10ms/step - loss: 3.4316e-04 - val_loss: 7.6855e-04
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6318e-04
# Epoch 20: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 3.6523e-04 - val_loss: 8.2286e-04
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1295e-04
# Epoch 21: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 11ms/step - loss: 4.1076e-04 - val_loss: 6.1006e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1008.0170737369149
# [2435.0001660470407, 1590.0327878075273, 1008.0170737369149]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 1: val_loss improved from inf to 0.00760, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 16ms/step - loss: 0.0153 - val_loss: 0.0076
# Epoch 2/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 2: val_loss improved from 0.00760 to 0.00466, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0010 - val_loss: 0.0047
# Epoch 3/100
# 111/113 [============================>.] - ETA: 0s - loss: 7.7668e-04
# Epoch 3: val_loss improved from 0.00466 to 0.00338, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 15ms/step - loss: 7.7646e-04 - val_loss: 0.0034
# Epoch 4/100
# 111/113 [============================>.] - ETA: 0s - loss: 6.7790e-04
# Epoch 4: val_loss did not improve from 0.00338
# 113/113 [==============================] - 2s 15ms/step - loss: 6.7219e-04 - val_loss: 0.0042
# Epoch 5/100
# 110/113 [============================>.] - ETA: 0s - loss: 6.2460e-04
# Epoch 5: val_loss improved from 0.00338 to 0.00241, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 15ms/step - loss: 6.2578e-04 - val_loss: 0.0024
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 5.8875e-04
# Epoch 6: val_loss did not improve from 0.00241
# 113/113 [==============================] - 2s 15ms/step - loss: 5.8875e-04 - val_loss: 0.0033
# Epoch 7/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.3546e-04
# Epoch 7: val_loss improved from 0.00241 to 0.00177, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 15ms/step - loss: 5.3232e-04 - val_loss: 0.0018
# Epoch 8/100
# 110/113 [============================>.] - ETA: 0s - loss: 5.2413e-04
# Epoch 8: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 15ms/step - loss: 5.2534e-04 - val_loss: 0.0019
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9091e-04
# Epoch 9: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 15ms/step - loss: 4.8972e-04 - val_loss: 0.0022
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9528e-04
# Epoch 10: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 4.9347e-04 - val_loss: 0.0026
# Epoch 11/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.4603e-04
# Epoch 11: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 5.4216e-04 - val_loss: 0.0025
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1279e-04
# Epoch 12: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 5.1279e-04 - val_loss: 0.0033
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.8499e-04
# Epoch 13: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 4.8462e-04 - val_loss: 0.0022
# Epoch 14/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.9732e-04
# Epoch 14: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 15ms/step - loss: 4.9546e-04 - val_loss: 0.0019
# Epoch 15/100
# 109/113 [===========================>..] - ETA: 0s - loss: 5.5167e-04
# Epoch 15: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 5.6216e-04 - val_loss: 0.0024
# Epoch 16/100
# 110/113 [============================>.] - ETA: 0s - loss: 4.8677e-04
# Epoch 16: val_loss did not improve from 0.00177
# 113/113 [==============================] - 2s 14ms/step - loss: 4.8988e-04 - val_loss: 0.0023
# Epoch 17/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.5058e-04
# Epoch 17: val_loss improved from 0.00177 to 0.00095, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 4.4869e-04 - val_loss: 9.5036e-04
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6257e-04
# Epoch 18: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 14ms/step - loss: 4.6375e-04 - val_loss: 0.0013
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 4.7156e-04
# Epoch 19: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 14ms/step - loss: 4.7156e-04 - val_loss: 0.0024
# Epoch 20/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.6835e-04
# Epoch 20: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 4.6654e-04 - val_loss: 0.0011
# Epoch 21/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.4355e-04
# Epoch 21: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 4.4014e-04 - val_loss: 0.0023
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5084e-04
# Epoch 22: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 4.5084e-04 - val_loss: 0.0016
# Epoch 23/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.4922e-04
# Epoch 23: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 16ms/step - loss: 4.4879e-04 - val_loss: 0.0019
# Epoch 24/100
# 110/113 [============================>.] - ETA: 0s - loss: 4.6168e-04
# Epoch 24: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 4.6880e-04 - val_loss: 0.0029
# Epoch 25/100
# 113/113 [==============================] - ETA: 0s - loss: 5.7932e-04
# Epoch 25: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 5.7932e-04 - val_loss: 0.0017
# Epoch 26/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5275e-04
# Epoch 26: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 15ms/step - loss: 4.5249e-04 - val_loss: 0.0015
# Epoch 27/100
# 110/113 [============================>.] - ETA: 0s - loss: 4.5162e-04
# Epoch 27: val_loss did not improve from 0.00095
# 113/113 [==============================] - 2s 14ms/step - loss: 4.5145e-04 - val_loss: 0.0013
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1406.7240920160837
# [2435.0001660470407, 1590.0327878075273, 1008.0170737369149, 1406.7240920160837]

# %%
predict
# Out:
# [array([[58615.28]], dtype=float32),
#  array([[59675.453]], dtype=float32),
#  array([[60466.105]], dtype=float32),
#  array([[59229.55]], dtype=float32)]

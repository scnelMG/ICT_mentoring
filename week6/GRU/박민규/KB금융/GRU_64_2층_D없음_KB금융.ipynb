# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_금융_KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=877338fc7d3961bf732f76306992ab3ccb2a576ca4586717e702c5528ec3cc9f
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0374
# Epoch 1: val_loss improved from inf to 0.01001, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 3s 36ms/step - loss: 0.0355 - val_loss: 0.0100
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 2: val_loss improved from 0.01001 to 0.00206, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.6546e-04
# Epoch 3: val_loss improved from 0.00206 to 0.00184, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 8.4664e-04 - val_loss: 0.0018
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.2795e-04
# Epoch 4: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 15ms/step - loss: 7.3891e-04 - val_loss: 0.0027
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.2085e-04
# Epoch 5: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 16ms/step - loss: 6.1014e-04 - val_loss: 0.0023
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.5870e-04
# Epoch 6: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 16ms/step - loss: 5.5695e-04 - val_loss: 0.0032
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.7361e-04
# Epoch 7: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 16ms/step - loss: 5.6391e-04 - val_loss: 0.0029
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3463e-04
# Epoch 8: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 16ms/step - loss: 5.2824e-04 - val_loss: 0.0022
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9668e-04
# Epoch 9: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 16ms/step - loss: 5.0290e-04 - val_loss: 0.0026
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4993e-04
# Epoch 10: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 15ms/step - loss: 4.5797e-04 - val_loss: 0.0027
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.2583e-04
# Epoch 11: val_loss did not improve from 0.00184
# 34/34 [==============================] - 1s 15ms/step - loss: 5.3110e-04 - val_loss: 0.0040
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.4750e-04
# Epoch 12: val_loss improved from 0.00184 to 0.00149, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 6.4554e-04 - val_loss: 0.0015
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9963e-04
# Epoch 13: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 16ms/step - loss: 4.9403e-04 - val_loss: 0.0021
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1416e-04
# Epoch 14: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 16ms/step - loss: 4.1973e-04 - val_loss: 0.0017
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.6248e-04
# Epoch 15: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 15ms/step - loss: 4.6351e-04 - val_loss: 0.0032
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.6678e-04
# Epoch 16: val_loss improved from 0.00149 to 0.00145, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 4.7395e-04 - val_loss: 0.0015
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.9101e-04
# Epoch 17: val_loss did not improve from 0.00145
# 34/34 [==============================] - 1s 15ms/step - loss: 4.8933e-04 - val_loss: 0.0018
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.9181e-04
# Epoch 18: val_loss did not improve from 0.00145
# 34/34 [==============================] - 1s 16ms/step - loss: 3.9964e-04 - val_loss: 0.0016
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2335e-04
# Epoch 19: val_loss improved from 0.00145 to 0.00142, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 4.2117e-04 - val_loss: 0.0014
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7213e-04
# Epoch 20: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 3.8555e-04 - val_loss: 0.0024
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9066e-04
# Epoch 21: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 3.9011e-04 - val_loss: 0.0022
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.9324e-04
# Epoch 22: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 3.9218e-04 - val_loss: 0.0020
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3106e-04
# Epoch 23: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 4.3650e-04 - val_loss: 0.0028
# Epoch 24/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.8873e-04
# Epoch 24: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 5.8695e-04 - val_loss: 0.0027
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0641e-04
# Epoch 25: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 15ms/step - loss: 4.0755e-04 - val_loss: 0.0028
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.4565e-04
# Epoch 26: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 16ms/step - loss: 4.4616e-04 - val_loss: 0.0023
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7077e-04
# Epoch 27: val_loss improved from 0.00142 to 0.00123, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 3.6546e-04 - val_loss: 0.0012
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.5930e-04
# Epoch 28: val_loss improved from 0.00123 to 0.00085, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 5.5391e-04 - val_loss: 8.4656e-04
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4522e-04
# Epoch 29: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 4.3959e-04 - val_loss: 0.0013
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9888e-04
# Epoch 30: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 4.1149e-04 - val_loss: 9.4828e-04
# Epoch 31/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6216e-04
# Epoch 31: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 3.7194e-04 - val_loss: 0.0015
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0824e-04
# Epoch 32: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 4.1121e-04 - val_loss: 0.0015
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6102e-04
# Epoch 33: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 3.5607e-04 - val_loss: 0.0012
# Epoch 34/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4750e-04
# Epoch 34: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 3.4370e-04 - val_loss: 0.0012
# Epoch 35/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.9907e-04
# Epoch 35: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 4.0839e-04 - val_loss: 0.0011
# Epoch 36/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.6896e-04
# Epoch 36: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 5.7217e-04 - val_loss: 0.0039
# Epoch 37/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.0658e-04
# Epoch 37: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 5.9694e-04 - val_loss: 9.8276e-04
# Epoch 38/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4961e-04
# Epoch 38: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 15ms/step - loss: 4.4076e-04 - val_loss: 0.0017
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:2178.0043426382426
# [2178.0043426382426]
# Epoch 1/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 1: val_loss improved from inf to 0.00094, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 4s 23ms/step - loss: 0.0057 - val_loss: 9.4298e-04
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.2039e-04
# Epoch 2: val_loss improved from 0.00094 to 0.00056, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 6.2432e-04 - val_loss: 5.5570e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 5.4255e-04
# Epoch 3: val_loss improved from 0.00056 to 0.00050, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4255e-04 - val_loss: 4.9747e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0889e-04
# Epoch 4: val_loss improved from 0.00050 to 0.00048, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 5.0889e-04 - val_loss: 4.8167e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 4.7397e-04
# Epoch 5: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 15ms/step - loss: 4.7397e-04 - val_loss: 9.3369e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.3890e-04
# Epoch 6: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 15ms/step - loss: 7.3115e-04 - val_loss: 5.4941e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1688e-04
# Epoch 7: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 15ms/step - loss: 4.1688e-04 - val_loss: 5.2082e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.2560e-04
# Epoch 8: val_loss improved from 0.00048 to 0.00042, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 4.2938e-04 - val_loss: 4.1887e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3365e-04
# Epoch 9: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 4.3365e-04 - val_loss: 4.6763e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 4.9186e-04
# Epoch 10: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 4.9186e-04 - val_loss: 4.8490e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.9345e-04
# Epoch 11: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 4.9356e-04 - val_loss: 7.2602e-04
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.7518e-04
# Epoch 12: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 16ms/step - loss: 4.7618e-04 - val_loss: 7.0276e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 5.6073e-04
# Epoch 13: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 5.6073e-04 - val_loss: 0.0016
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 6.8313e-04
# Epoch 14: val_loss improved from 0.00042 to 0.00042, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 6.8313e-04 - val_loss: 4.1577e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.2232e-04
# Epoch 15: val_loss improved from 0.00042 to 0.00040, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 4.2026e-04 - val_loss: 4.0449e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7674e-04
# Epoch 16: val_loss improved from 0.00040 to 0.00038, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 3.7674e-04 - val_loss: 3.7750e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.1050e-04
# Epoch 17: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 15ms/step - loss: 5.1150e-04 - val_loss: 4.0849e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.5026e-04
# Epoch 18: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 16ms/step - loss: 6.4907e-04 - val_loss: 7.0526e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6694e-04
# Epoch 19: val_loss improved from 0.00038 to 0.00036, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 4.6801e-04 - val_loss: 3.6276e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3822e-04
# Epoch 20: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 4.4204e-04 - val_loss: 8.0384e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9065e-04
# Epoch 21: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 16ms/step - loss: 3.9065e-04 - val_loss: 5.9538e-04
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.2676e-04
# Epoch 22: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 4.2612e-04 - val_loss: 3.6758e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8475e-04
# Epoch 23: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 3.8475e-04 - val_loss: 3.7977e-04
# Epoch 24/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7673e-04
# Epoch 24: val_loss improved from 0.00036 to 0.00034, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 3.7819e-04 - val_loss: 3.4346e-04
# Epoch 25/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.9508e-04
# Epoch 25: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 16ms/step - loss: 3.9166e-04 - val_loss: 3.7582e-04
# Epoch 26/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1200e-04
# Epoch 26: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 17ms/step - loss: 4.1321e-04 - val_loss: 6.9412e-04
# Epoch 27/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7411e-04
# Epoch 27: val_loss improved from 0.00034 to 0.00034, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 3.7980e-04 - val_loss: 3.4067e-04
# Epoch 28/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.4063e-04
# Epoch 28: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 16ms/step - loss: 3.3905e-04 - val_loss: 3.5924e-04
# Epoch 29/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7583e-04
# Epoch 29: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 16ms/step - loss: 3.8165e-04 - val_loss: 3.4544e-04
# Epoch 30/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.5536e-04
# Epoch 30: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 16ms/step - loss: 3.5487e-04 - val_loss: 3.5393e-04
# Epoch 31/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7247e-04
# Epoch 31: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 22ms/step - loss: 3.7380e-04 - val_loss: 3.6324e-04
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.7282e-04
# Epoch 32: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 23ms/step - loss: 4.7405e-04 - val_loss: 8.1620e-04
# Epoch 33/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.2027e-04
# Epoch 33: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 22ms/step - loss: 4.1775e-04 - val_loss: 6.1241e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7003e-04
# Epoch 34: val_loss improved from 0.00034 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 3.7003e-04 - val_loss: 3.2295e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.5184e-04
# Epoch 35: val_loss improved from 0.00032 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 4.5180e-04 - val_loss: 3.1739e-04
# Epoch 36/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.4601e-04
# Epoch 36: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 15ms/step - loss: 3.4359e-04 - val_loss: 4.0642e-04
# Epoch 37/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.4511e-04
# Epoch 37: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 15ms/step - loss: 4.4102e-04 - val_loss: 3.2435e-04
# Epoch 38/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.2915e-04
# Epoch 38: val_loss did not improve from 0.00032
# 69/69 [==============================] - 1s 16ms/step - loss: 4.3811e-04 - val_loss: 4.9095e-04
# Epoch 39/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1785e-04
# Epoch 39: val_loss improved from 0.00032 to 0.00031, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 4.1785e-04 - val_loss: 3.1241e-04
# Epoch 40/100
# 69/69 [==============================] - ETA: 0s - loss: 5.5564e-04
# Epoch 40: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 16ms/step - loss: 5.5564e-04 - val_loss: 4.8182e-04
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8211e-04
# Epoch 41: val_loss improved from 0.00031 to 0.00031, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 3.8211e-04 - val_loss: 3.0793e-04
# Epoch 42/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.0769e-04
# Epoch 42: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 16ms/step - loss: 3.1419e-04 - val_loss: 3.9467e-04
# Epoch 43/100
# 69/69 [==============================] - ETA: 0s - loss: 3.3672e-04
# Epoch 43: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 16ms/step - loss: 3.3672e-04 - val_loss: 3.6773e-04
# Epoch 44/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.3541e-04
# Epoch 44: val_loss improved from 0.00031 to 0.00031, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 3.3536e-04 - val_loss: 3.0566e-04
# Epoch 45/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7679e-04
# Epoch 45: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 16ms/step - loss: 3.7528e-04 - val_loss: 3.2352e-04
# Epoch 46/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.4111e-04
# Epoch 46: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 16ms/step - loss: 3.4102e-04 - val_loss: 3.2193e-04
# Epoch 47/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.7354e-04
# Epoch 47: val_loss improved from 0.00031 to 0.00030, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 3.7324e-04 - val_loss: 2.9769e-04
# Epoch 48/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.2228e-04
# Epoch 48: val_loss did not improve from 0.00030
# 69/69 [==============================] - 2s 25ms/step - loss: 3.2350e-04 - val_loss: 3.0896e-04
# Epoch 49/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.8249e-04
# Epoch 49: val_loss did not improve from 0.00030
# 69/69 [==============================] - 2s 23ms/step - loss: 3.8177e-04 - val_loss: 3.2534e-04
# Epoch 50/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.1215e-04
# Epoch 50: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 4.0769e-04 - val_loss: 4.2325e-04
# Epoch 51/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.6270e-04
# Epoch 51: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 15ms/step - loss: 3.6810e-04 - val_loss: 4.2880e-04
# Epoch 52/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.9721e-04
# Epoch 52: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 15ms/step - loss: 3.9428e-04 - val_loss: 3.1762e-04
# Epoch 53/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.4024e-04
# Epoch 53: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 3.3796e-04 - val_loss: 3.2545e-04
# Epoch 54/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.0673e-04
# Epoch 54: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 3.0764e-04 - val_loss: 3.0051e-04
# Epoch 55/100
# 69/69 [==============================] - ETA: 0s - loss: 3.4312e-04
# Epoch 55: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 3.4312e-04 - val_loss: 3.2241e-04
# Epoch 56/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.9940e-04
# Epoch 56: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 5.0912e-04 - val_loss: 3.6132e-04
# Epoch 57/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.4647e-04
# Epoch 57: val_loss did not improve from 0.00030
# 69/69 [==============================] - 1s 16ms/step - loss: 4.4982e-04 - val_loss: 3.2071e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1408.3217404752197
# [2178.0043426382426, 1408.3217404752197]
# Epoch 1/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 1: val_loss improved from inf to 0.00306, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 4s 21ms/step - loss: 0.0089 - val_loss: 0.0031
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.1758e-04
# Epoch 2: val_loss improved from 0.00306 to 0.00099, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 6.2166e-04 - val_loss: 9.9054e-04
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.6954e-04
# Epoch 3: val_loss did not improve from 0.00099
# 104/104 [==============================] - 2s 16ms/step - loss: 5.6613e-04 - val_loss: 0.0024
# Epoch 4/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.4770e-04
# Epoch 4: val_loss improved from 0.00099 to 0.00093, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 5.5351e-04 - val_loss: 9.2781e-04
# Epoch 5/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.0960e-04
# Epoch 5: val_loss did not improve from 0.00093
# 104/104 [==============================] - 2s 15ms/step - loss: 5.0538e-04 - val_loss: 0.0011
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1445e-04
# Epoch 6: val_loss did not improve from 0.00093
# 104/104 [==============================] - 2s 16ms/step - loss: 4.1445e-04 - val_loss: 9.5971e-04
# Epoch 7/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.1527e-04
# Epoch 7: val_loss did not improve from 0.00093
# 104/104 [==============================] - 2s 16ms/step - loss: 4.1300e-04 - val_loss: 0.0019
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.8408e-04
# Epoch 8: val_loss did not improve from 0.00093
# 104/104 [==============================] - 2s 16ms/step - loss: 4.8360e-04 - val_loss: 0.0014
# Epoch 9/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.0582e-04
# Epoch 9: val_loss improved from 0.00093 to 0.00072, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 4.0476e-04 - val_loss: 7.2323e-04
# Epoch 10/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.9549e-04
# Epoch 10: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 4.9127e-04 - val_loss: 0.0022
# Epoch 11/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.6736e-04
# Epoch 11: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 5.6064e-04 - val_loss: 0.0025
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1635e-04
# Epoch 12: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 4.2074e-04 - val_loss: 7.2351e-04
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9870e-04
# Epoch 13: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 3.9870e-04 - val_loss: 8.9286e-04
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8278e-04
# Epoch 14: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 3.8395e-04 - val_loss: 9.1282e-04
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.9633e-04
# Epoch 15: val_loss did not improve from 0.00072
# 104/104 [==============================] - 2s 16ms/step - loss: 3.9814e-04 - val_loss: 0.0014
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.4938e-04
# Epoch 16: val_loss improved from 0.00072 to 0.00068, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 3.5101e-04 - val_loss: 6.8249e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 3.3555e-04
# Epoch 17: val_loss improved from 0.00068 to 0.00066, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 3.3555e-04 - val_loss: 6.6004e-04
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 3.3123e-04
# Epoch 18: val_loss did not improve from 0.00066
# 104/104 [==============================] - 2s 16ms/step - loss: 3.3123e-04 - val_loss: 0.0018
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 3.4876e-04
# Epoch 19: val_loss did not improve from 0.00066
# 104/104 [==============================] - 2s 15ms/step - loss: 3.4876e-04 - val_loss: 7.0541e-04
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.8168e-04
# Epoch 20: val_loss improved from 0.00066 to 0.00066, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 4.8085e-04 - val_loss: 6.5550e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 4.3272e-04
# Epoch 21: val_loss did not improve from 0.00066
# 104/104 [==============================] - 2s 19ms/step - loss: 4.3272e-04 - val_loss: 0.0030
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1946e-04
# Epoch 22: val_loss did not improve from 0.00066
# 104/104 [==============================] - 2s 24ms/step - loss: 4.1946e-04 - val_loss: 6.6778e-04
# Epoch 23/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.6520e-04
# Epoch 23: val_loss did not improve from 0.00066
# 104/104 [==============================] - 2s 18ms/step - loss: 3.7009e-04 - val_loss: 0.0015
# Epoch 24/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4991e-04
# Epoch 24: val_loss improved from 0.00066 to 0.00061, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 3.5101e-04 - val_loss: 6.0872e-04
# Epoch 25/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.3830e-04
# Epoch 25: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.3720e-04 - val_loss: 0.0020
# Epoch 26/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.5707e-04
# Epoch 26: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.5583e-04 - val_loss: 8.6934e-04
# Epoch 27/100
# 104/104 [==============================] - ETA: 0s - loss: 3.5898e-04
# Epoch 27: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.5898e-04 - val_loss: 6.4559e-04
# Epoch 28/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5431e-04
# Epoch 28: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.5572e-04 - val_loss: 0.0015
# Epoch 29/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6822e-04
# Epoch 29: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.6602e-04 - val_loss: 8.3440e-04
# Epoch 30/100
# 104/104 [==============================] - ETA: 0s - loss: 3.4401e-04
# Epoch 30: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.4401e-04 - val_loss: 0.0017
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7973e-04
# Epoch 31: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.7973e-04 - val_loss: 6.6753e-04
# Epoch 32/100
# 104/104 [==============================] - ETA: 0s - loss: 3.4700e-04
# Epoch 32: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.4700e-04 - val_loss: 7.9544e-04
# Epoch 33/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5937e-04
# Epoch 33: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 3.6341e-04 - val_loss: 0.0012
# Epoch 34/100
# 103/104 [============================>.] - ETA: 0s - loss: 2.9902e-04
# Epoch 34: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 16ms/step - loss: 2.9824e-04 - val_loss: 6.9214e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1307.9835350288922
# [2178.0043426382426, 1408.3217404752197, 1307.9835350288922]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 1: val_loss improved from inf to 0.00109, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 6s 27ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 7.6840e-04
# Epoch 2: val_loss improved from 0.00109 to 0.00062, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 22ms/step - loss: 7.6840e-04 - val_loss: 6.1690e-04
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 7.0851e-04
# Epoch 3: val_loss did not improve from 0.00062
# 113/113 [==============================] - 2s 22ms/step - loss: 7.0851e-04 - val_loss: 6.6602e-04
# Epoch 4/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.8870e-04
# Epoch 4: val_loss did not improve from 0.00062
# 113/113 [==============================] - 2s 21ms/step - loss: 5.8669e-04 - val_loss: 8.5066e-04
# Epoch 5/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.6691e-04
# Epoch 5: val_loss improved from 0.00062 to 0.00056, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 22ms/step - loss: 5.6563e-04 - val_loss: 5.6018e-04
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.4072e-04
# Epoch 6: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 22ms/step - loss: 5.3997e-04 - val_loss: 6.6554e-04
# Epoch 7/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.8216e-04
# Epoch 7: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 22ms/step - loss: 5.8060e-04 - val_loss: 7.0954e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0726e-04
# Epoch 8: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 22ms/step - loss: 5.0726e-04 - val_loss: 9.7481e-04
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.7942e-04
# Epoch 9: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 22ms/step - loss: 5.7698e-04 - val_loss: 6.0870e-04
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 4.7815e-04
# Epoch 10: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 22ms/step - loss: 4.7815e-04 - val_loss: 8.0422e-04
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6082e-04
# Epoch 11: val_loss did not improve from 0.00056
# 113/113 [==============================] - 3s 22ms/step - loss: 4.6148e-04 - val_loss: 7.8209e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.7698e-04
# Epoch 12: val_loss did not improve from 0.00056
# 113/113 [==============================] - 2s 21ms/step - loss: 5.7698e-04 - val_loss: 0.0022
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 5.5662e-04
# Epoch 13: val_loss improved from 0.00056 to 0.00053, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 22ms/step - loss: 5.5662e-04 - val_loss: 5.3181e-04
# Epoch 14/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.0399e-04
# Epoch 14: val_loss did not improve from 0.00053
# 113/113 [==============================] - 2s 21ms/step - loss: 5.0630e-04 - val_loss: 0.0020
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0456e-04
# Epoch 15: val_loss did not improve from 0.00053
# 113/113 [==============================] - 2s 22ms/step - loss: 5.0456e-04 - val_loss: 5.8953e-04
# Epoch 16/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.1427e-04
# Epoch 16: val_loss did not improve from 0.00053
# 113/113 [==============================] - 2s 22ms/step - loss: 5.1666e-04 - val_loss: 0.0017
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2230e-04
# Epoch 17: val_loss did not improve from 0.00053
# 113/113 [==============================] - 3s 25ms/step - loss: 5.2230e-04 - val_loss: 5.3510e-04
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.3235e-04
# Epoch 18: val_loss did not improve from 0.00053
# 113/113 [==============================] - 4s 32ms/step - loss: 4.3383e-04 - val_loss: 0.0014
# Epoch 19/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6237e-04
# Epoch 19: val_loss did not improve from 0.00053
# 113/113 [==============================] - 2s 22ms/step - loss: 4.6228e-04 - val_loss: 9.6303e-04
# Epoch 20/100
# 113/113 [==============================] - ETA: 0s - loss: 4.2918e-04
# Epoch 20: val_loss improved from 0.00053 to 0.00048, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 3s 22ms/step - loss: 4.2918e-04 - val_loss: 4.8464e-04
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1562e-04
# Epoch 21: val_loss did not improve from 0.00048
# 113/113 [==============================] - 2s 22ms/step - loss: 5.1562e-04 - val_loss: 7.8624e-04
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 5.4932e-04
# Epoch 22: val_loss did not improve from 0.00048
# 113/113 [==============================] - 2s 22ms/step - loss: 5.4932e-04 - val_loss: 9.0642e-04
# Epoch 23/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9807e-04
# Epoch 23: val_loss did not improve from 0.00048
# 113/113 [==============================] - 2s 22ms/step - loss: 4.9846e-04 - val_loss: 5.8598e-04
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 4.6647e-04
# Epoch 24: val_loss improved from 0.00048 to 0.00045, saving model to model/tmp_checkpoint.h5
# 113/113 [==============================] - 2s 22ms/step - loss: 4.6647e-04 - val_loss: 4.5078e-04
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7300e-04
# Epoch 25: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 22ms/step - loss: 4.7730e-04 - val_loss: 0.0010
# Epoch 26/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.5367e-04
# Epoch 26: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 22ms/step - loss: 4.5259e-04 - val_loss: 8.4869e-04
# Epoch 27/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.5653e-04
# Epoch 27: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 22ms/step - loss: 4.5857e-04 - val_loss: 0.0020
# Epoch 28/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.1934e-04
# Epoch 28: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 22ms/step - loss: 4.2137e-04 - val_loss: 8.0411e-04
# Epoch 29/100
# 113/113 [==============================] - ETA: 0s - loss: 4.4572e-04
# Epoch 29: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 22ms/step - loss: 4.4572e-04 - val_loss: 0.0011
# Epoch 30/100
# 113/113 [==============================] - ETA: 0s - loss: 5.4916e-04
# Epoch 30: val_loss did not improve from 0.00045
# 113/113 [==============================] - 3s 23ms/step - loss: 5.4916e-04 - val_loss: 4.9002e-04
# Epoch 31/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.5999e-04
# Epoch 31: val_loss did not improve from 0.00045
# 113/113 [==============================] - 3s 23ms/step - loss: 4.6055e-04 - val_loss: 5.0887e-04
# Epoch 32/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.1233e-04
# Epoch 32: val_loss did not improve from 0.00045
# 113/113 [==============================] - 3s 22ms/step - loss: 5.1089e-04 - val_loss: 0.0024
# Epoch 33/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.3339e-04
# Epoch 33: val_loss did not improve from 0.00045
# 113/113 [==============================] - 2s 21ms/step - loss: 4.3295e-04 - val_loss: 4.7061e-04
# Epoch 34/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.3823e-04
# Epoch 34: val_loss did not improve from 0.00045
# 113/113 [==============================] - 3s 22ms/step - loss: 4.3934e-04 - val_loss: 0.0013
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1297.2161236575635
# [2178.0043426382426, 1408.3217404752197, 1307.9835350288922, 1297.2161236575635]

# %%
predict
# Out:
# [array([[59504.293]], dtype=float32),
#  array([[60203.645]], dtype=float32),
#  array([[60968.05]], dtype=float32),
#  array([[60173.62]], dtype=float32)]

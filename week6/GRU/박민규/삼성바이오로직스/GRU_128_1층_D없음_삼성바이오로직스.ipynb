# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0156
# Epoch 1: val_loss improved from inf to 0.00096, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0149 - val_loss: 9.6439e-04
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 2: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0079
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.7575e-04
# Epoch 3: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 16ms/step - loss: 8.8175e-04 - val_loss: 0.0011
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.9045e-04
# Epoch 4: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 16ms/step - loss: 5.8395e-04 - val_loss: 0.0013
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.7590e-04
# Epoch 5: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 17ms/step - loss: 4.7326e-04 - val_loss: 0.0013
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.8687e-04
# Epoch 6: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 17ms/step - loss: 4.1354e-04 - val_loss: 0.0010
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.5542e-04
# Epoch 7: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 16ms/step - loss: 4.4649e-04 - val_loss: 0.0011
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.8681e-04
# Epoch 8: val_loss improved from 0.00096 to 0.00095, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 3.8099e-04 - val_loss: 9.4669e-04
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 3.6469e-04
# Epoch 9: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 16ms/step - loss: 3.6469e-04 - val_loss: 0.0010
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5557e-04
# Epoch 10: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 16ms/step - loss: 3.4775e-04 - val_loss: 0.0011
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.0904e-04
# Epoch 11: val_loss improved from 0.00095 to 0.00083, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 3.0872e-04 - val_loss: 8.3015e-04
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.0806e-04
# Epoch 12: val_loss did not improve from 0.00083
# 34/34 [==============================] - 1s 17ms/step - loss: 3.0198e-04 - val_loss: 9.9286e-04
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2319e-04
# Epoch 13: val_loss did not improve from 0.00083
# 34/34 [==============================] - 1s 17ms/step - loss: 3.2319e-04 - val_loss: 0.0010
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8172e-04
# Epoch 14: val_loss did not improve from 0.00083
# 34/34 [==============================] - 1s 16ms/step - loss: 2.8625e-04 - val_loss: 9.1096e-04
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8715e-04
# Epoch 15: val_loss improved from 0.00083 to 0.00081, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 2.8677e-04 - val_loss: 8.1207e-04
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1653e-04
# Epoch 16: val_loss did not improve from 0.00081
# 34/34 [==============================] - 1s 16ms/step - loss: 4.1603e-04 - val_loss: 0.0031
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3575e-04
# Epoch 17: val_loss improved from 0.00081 to 0.00079, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 3.3214e-04 - val_loss: 7.8855e-04
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.3941e-04
# Epoch 18: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5983e-04 - val_loss: 8.3761e-04
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.5078e-04
# Epoch 19: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 4.4642e-04 - val_loss: 0.0012
# Epoch 20/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.5096e-04
# Epoch 20: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5919e-04 - val_loss: 0.0011
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0208e-04
# Epoch 21: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 3.0208e-04 - val_loss: 9.1407e-04
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.9943e-04
# Epoch 22: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 3.9904e-04 - val_loss: 9.3122e-04
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.5597e-04
# Epoch 23: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 16ms/step - loss: 2.5542e-04 - val_loss: 0.0015
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8294e-04
# Epoch 24: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 16ms/step - loss: 3.8010e-04 - val_loss: 0.0014
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9619e-04
# Epoch 25: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 16ms/step - loss: 2.9612e-04 - val_loss: 8.3258e-04
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.6909e-04
# Epoch 26: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 16ms/step - loss: 2.6088e-04 - val_loss: 8.5736e-04
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.7875e-04
# Epoch 27: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7737e-04 - val_loss: 8.6160e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:23591.256880296387
# [23591.256880296387]
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0119
# Epoch 1: val_loss improved from inf to 0.01367, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 3s 49ms/step - loss: 0.0117 - val_loss: 0.0137
# Epoch 2/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.1997e-04
# Epoch 2: val_loss improved from 0.01367 to 0.01176, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 9.1358e-04 - val_loss: 0.0118
# Epoch 3/100
# 43/43 [==============================] - ETA: 0s - loss: 5.8534e-04
# Epoch 3: val_loss improved from 0.01176 to 0.01060, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 5.8534e-04 - val_loss: 0.0106
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 4.9252e-04
# Epoch 4: val_loss improved from 0.01060 to 0.00879, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 44ms/step - loss: 4.9252e-04 - val_loss: 0.0088
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 3.8470e-04
# Epoch 5: val_loss improved from 0.00879 to 0.00851, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 44ms/step - loss: 3.8470e-04 - val_loss: 0.0085
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 3.9813e-04
# Epoch 6: val_loss improved from 0.00851 to 0.00561, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 3.9813e-04 - val_loss: 0.0056
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 3.0474e-04
# Epoch 7: val_loss improved from 0.00561 to 0.00547, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 3.0474e-04 - val_loss: 0.0055
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8703e-04
# Epoch 8: val_loss did not improve from 0.00547
# 43/43 [==============================] - 2s 47ms/step - loss: 2.8703e-04 - val_loss: 0.0056
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 2.7441e-04
# Epoch 9: val_loss did not improve from 0.00547
# 43/43 [==============================] - 2s 46ms/step - loss: 2.7441e-04 - val_loss: 0.0057
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 3.2131e-04
# Epoch 10: val_loss did not improve from 0.00547
# 43/43 [==============================] - 2s 47ms/step - loss: 3.2131e-04 - val_loss: 0.0091
# Epoch 11/100
# 43/43 [==============================] - ETA: 0s - loss: 4.1206e-04
# Epoch 11: val_loss did not improve from 0.00547
# 43/43 [==============================] - 3s 72ms/step - loss: 4.1206e-04 - val_loss: 0.0060
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 2.5372e-04
# Epoch 12: val_loss improved from 0.00547 to 0.00448, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 3s 60ms/step - loss: 2.5372e-04 - val_loss: 0.0045
# Epoch 13/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4757e-04
# Epoch 13: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 44ms/step - loss: 2.4633e-04 - val_loss: 0.0046
# Epoch 14/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5307e-04
# Epoch 14: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 45ms/step - loss: 2.5428e-04 - val_loss: 0.0062
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3893e-04
# Epoch 15: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 43ms/step - loss: 2.3893e-04 - val_loss: 0.0052
# Epoch 16/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5354e-04
# Epoch 16: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 45ms/step - loss: 2.5173e-04 - val_loss: 0.0047
# Epoch 17/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5286e-04
# Epoch 17: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 44ms/step - loss: 2.5674e-04 - val_loss: 0.0077
# Epoch 18/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8839e-04
# Epoch 18: val_loss did not improve from 0.00448
# 43/43 [==============================] - 2s 46ms/step - loss: 2.8839e-04 - val_loss: 0.0048
# Epoch 19/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0706e-04
# Epoch 19: val_loss improved from 0.00448 to 0.00417, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 2.0706e-04 - val_loss: 0.0042
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1524e-04
# Epoch 20: val_loss improved from 0.00417 to 0.00296, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 2.1317e-04 - val_loss: 0.0030
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.0198e-04
# Epoch 21: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 45ms/step - loss: 2.0065e-04 - val_loss: 0.0050
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.9787e-04
# Epoch 22: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 44ms/step - loss: 2.0582e-04 - val_loss: 0.0050
# Epoch 23/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3673e-04
# Epoch 23: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 46ms/step - loss: 2.3742e-04 - val_loss: 0.0070
# Epoch 24/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.8329e-04
# Epoch 24: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 44ms/step - loss: 2.8112e-04 - val_loss: 0.0062
# Epoch 25/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8410e-04
# Epoch 25: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 44ms/step - loss: 2.8410e-04 - val_loss: 0.0079
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3850e-04
# Epoch 26: val_loss did not improve from 0.00296
# 43/43 [==============================] - 2s 45ms/step - loss: 2.3850e-04 - val_loss: 0.0038
# Epoch 27/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5097e-04
# Epoch 27: val_loss improved from 0.00296 to 0.00261, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 2.4878e-04 - val_loss: 0.0026
# Epoch 28/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8107e-04
# Epoch 28: val_loss did not improve from 0.00261
# 43/43 [==============================] - 2s 44ms/step - loss: 2.8107e-04 - val_loss: 0.0067
# Epoch 29/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3189e-04
# Epoch 29: val_loss did not improve from 0.00261
# 43/43 [==============================] - 2s 45ms/step - loss: 2.3189e-04 - val_loss: 0.0038
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1959e-04
# Epoch 30: val_loss did not improve from 0.00261
# 43/43 [==============================] - 2s 46ms/step - loss: 2.1825e-04 - val_loss: 0.0062
# Epoch 31/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.7593e-04
# Epoch 31: val_loss did not improve from 0.00261
# 43/43 [==============================] - 2s 46ms/step - loss: 2.7589e-04 - val_loss: 0.0047
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 4.1466e-04
# Epoch 32: val_loss did not improve from 0.00261
# 43/43 [==============================] - 2s 49ms/step - loss: 4.1466e-04 - val_loss: 0.0050
# Epoch 33/100
# 43/43 [==============================] - ETA: 0s - loss: 2.4083e-04
# Epoch 33: val_loss improved from 0.00261 to 0.00216, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 2.4083e-04 - val_loss: 0.0022
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1574e-04
# Epoch 34: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 46ms/step - loss: 2.1574e-04 - val_loss: 0.0060
# Epoch 35/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.8298e-04
# Epoch 35: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 46ms/step - loss: 1.8584e-04 - val_loss: 0.0029
# Epoch 36/100
# 43/43 [==============================] - ETA: 0s - loss: 2.5720e-04
# Epoch 36: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 47ms/step - loss: 2.5720e-04 - val_loss: 0.0048
# Epoch 37/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5992e-04
# Epoch 37: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 45ms/step - loss: 2.5926e-04 - val_loss: 0.0073
# Epoch 38/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3385e-04
# Epoch 38: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 46ms/step - loss: 2.3385e-04 - val_loss: 0.0065
# Epoch 39/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.9544e-04
# Epoch 39: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 56ms/step - loss: 1.9434e-04 - val_loss: 0.0051
# Epoch 40/100
# 43/43 [==============================] - ETA: 0s - loss: 1.8738e-04
# Epoch 40: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 44ms/step - loss: 1.8738e-04 - val_loss: 0.0044
# Epoch 41/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0220e-04
# Epoch 41: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 45ms/step - loss: 2.0220e-04 - val_loss: 0.0050
# Epoch 42/100
# 43/43 [==============================] - ETA: 0s - loss: 1.9258e-04
# Epoch 42: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 45ms/step - loss: 1.9258e-04 - val_loss: 0.0044
# Epoch 43/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3402e-04
# Epoch 43: val_loss did not improve from 0.00216
# 43/43 [==============================] - 2s 46ms/step - loss: 2.3292e-04 - val_loss: 0.0059
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:83065.99063209872
# [23591.256880296387, 83065.99063209872]

# %%
predict
# Out:
# [array([[833128.4]], dtype=float32), array([[801728.3]], dtype=float32)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, dropout = 0.3,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=fde01e352231739a032f32e4ef1d68cd915571e6920a0b7587981030fdc3785d
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 1: val_loss improved from inf to 0.04077, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 5s 33ms/step - loss: 0.0571 - val_loss: 0.0408
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 2: val_loss improved from 0.04077 to 0.02645, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0227 - val_loss: 0.0264
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 3: val_loss improved from 0.02645 to 0.02194, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0162 - val_loss: 0.0219
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0125
# Epoch 4: val_loss improved from 0.02194 to 0.01352, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 5: val_loss improved from 0.01352 to 0.00790, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0097 - val_loss: 0.0079
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0081
# Epoch 6: val_loss did not improve from 0.00790
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0079 - val_loss: 0.0137
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0063
# Epoch 7: val_loss did not improve from 0.00790
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0062 - val_loss: 0.0092
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 8: val_loss improved from 0.00790 to 0.00646, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 9: val_loss did not improve from 0.00646
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0051 - val_loss: 0.0068
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 10: val_loss improved from 0.00646 to 0.00557, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 11: val_loss improved from 0.00557 to 0.00489, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss did not improve from 0.00489
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 13: val_loss improved from 0.00489 to 0.00447, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 14: val_loss improved from 0.00447 to 0.00399, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 15: val_loss improved from 0.00399 to 0.00324, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 16/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 16: val_loss did not improve from 0.00324
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 17: val_loss did not improve from 0.00324
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 18: val_loss did not improve from 0.00324
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 19: val_loss improved from 0.00324 to 0.00293, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 20: val_loss improved from 0.00293 to 0.00249, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 21/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 21: val_loss did not improve from 0.00249
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00249
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 23: val_loss improved from 0.00249 to 0.00221, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 24: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 25/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 25: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 26: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 27: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 28: val_loss improved from 0.00221 to 0.00221, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 30: val_loss did not improve from 0.00221
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 31/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 31: val_loss improved from 0.00221 to 0.00194, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 32/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 32: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 33: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 34: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 35/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 35: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 36/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 36: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 37/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 37: val_loss did not improve from 0.00194
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 38: val_loss improved from 0.00194 to 0.00191, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 39/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 39: val_loss did not improve from 0.00191
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 40: val_loss improved from 0.00191 to 0.00183, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 41/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 41: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 42/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 42: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 43/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 43: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 44/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 44: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 45/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 45: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 46/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 46: val_loss did not improve from 0.00183
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 47/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 47: val_loss improved from 0.00183 to 0.00181, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 48/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 48: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 49/100
# 31/34 [==========================>...] - ETA: 0s - loss: 9.8899e-04
# Epoch 49: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 18ms/step - loss: 9.8843e-04 - val_loss: 0.0021
# Epoch 50/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 50: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 51/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.9943e-04
# Epoch 51: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 9.9003e-04 - val_loss: 0.0020
# Epoch 52/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 52: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 53/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 53: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 54/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 54: val_loss did not improve from 0.00181
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 55: val_loss improved from 0.00181 to 0.00179, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 56/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 56: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 57/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 57: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 58/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 58: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 59/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 59: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 60/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.6624e-04
# Epoch 60: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 19ms/step - loss: 9.6654e-04 - val_loss: 0.0026
# Epoch 61/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.2299e-04
# Epoch 61: val_loss improved from 0.00179 to 0.00156, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 9.1914e-04 - val_loss: 0.0016
# Epoch 62/100
# 34/34 [==============================] - ETA: 0s - loss: 8.7431e-04
# Epoch 62: val_loss did not improve from 0.00156
# 34/34 [==============================] - 1s 27ms/step - loss: 8.7431e-04 - val_loss: 0.0016
# Epoch 63/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.3969e-04
# Epoch 63: val_loss did not improve from 0.00156
# 34/34 [==============================] - 1s 28ms/step - loss: 9.3770e-04 - val_loss: 0.0016
# Epoch 64/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.3276e-04
# Epoch 64: val_loss did not improve from 0.00156
# 34/34 [==============================] - 1s 29ms/step - loss: 8.2892e-04 - val_loss: 0.0018
# Epoch 65/100
# 31/34 [==========================>...] - ETA: 0s - loss: 9.3143e-04
# Epoch 65: val_loss did not improve from 0.00156
# 34/34 [==============================] - 1s 19ms/step - loss: 9.8403e-04 - val_loss: 0.0018
# Epoch 66/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.8094e-04
# Epoch 66: val_loss improved from 0.00156 to 0.00149, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 9.7934e-04 - val_loss: 0.0015
# Epoch 67/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 67: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 68/100
# 34/34 [==============================] - ETA: 0s - loss: 9.7206e-04
# Epoch 68: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 9.7206e-04 - val_loss: 0.0018
# Epoch 69/100
# 34/34 [==============================] - ETA: 0s - loss: 9.7022e-04
# Epoch 69: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 9.7022e-04 - val_loss: 0.0022
# Epoch 70/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.1794e-04
# Epoch 70: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 9.3037e-04 - val_loss: 0.0015
# Epoch 71/100
# 34/34 [==============================] - ETA: 0s - loss: 9.4683e-04
# Epoch 71: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 9.4683e-04 - val_loss: 0.0025
# Epoch 72/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.8099e-04
# Epoch 72: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 8.8181e-04 - val_loss: 0.0018
# Epoch 73/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.9273e-04
# Epoch 73: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 18ms/step - loss: 8.9147e-04 - val_loss: 0.0030
# Epoch 74/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.2421e-04
# Epoch 74: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 8.1932e-04 - val_loss: 0.0023
# Epoch 75/100
# 34/34 [==============================] - ETA: 0s - loss: 9.5031e-04
# Epoch 75: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 9.5031e-04 - val_loss: 0.0017
# Epoch 76/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.3088e-04
# Epoch 76: val_loss did not improve from 0.00149
# 34/34 [==============================] - 1s 19ms/step - loss: 8.2562e-04 - val_loss: 0.0028
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:58108.264578442984
# [58108.264578442984]
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0243
# Epoch 1: val_loss improved from inf to 0.11189, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 4s 52ms/step - loss: 0.0243 - val_loss: 0.1119
# Epoch 2/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 2: val_loss improved from 0.11189 to 0.05615, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0084 - val_loss: 0.0561
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 3: val_loss improved from 0.05615 to 0.03677, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0048 - val_loss: 0.0368
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 4: val_loss improved from 0.03677 to 0.03101, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0034 - val_loss: 0.0310
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 5: val_loss did not improve from 0.03101
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0028 - val_loss: 0.0317
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss improved from 0.03101 to 0.02623, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0020 - val_loss: 0.0262
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 7: val_loss improved from 0.02623 to 0.02414, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0018 - val_loss: 0.0241
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 8: val_loss improved from 0.02414 to 0.02237, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 50ms/step - loss: 0.0016 - val_loss: 0.0224
# Epoch 9/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 9: val_loss did not improve from 0.02237
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0016 - val_loss: 0.0252
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 10: val_loss improved from 0.02237 to 0.01737, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 3s 67ms/step - loss: 0.0013 - val_loss: 0.0174
# Epoch 11/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 11: val_loss improved from 0.01737 to 0.01670, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 3s 68ms/step - loss: 0.0012 - val_loss: 0.0167
# Epoch 12/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.01670
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0012 - val_loss: 0.0206
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 13: val_loss did not improve from 0.01670
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0011 - val_loss: 0.0212
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss improved from 0.01670 to 0.01664, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 0.0012 - val_loss: 0.0166
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.01664
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 9.3293e-04
# Epoch 16: val_loss did not improve from 0.01664
# 43/43 [==============================] - 2s 49ms/step - loss: 9.3293e-04 - val_loss: 0.0173
# Epoch 17/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 17: val_loss did not improve from 0.01664
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0011 - val_loss: 0.0181
# Epoch 18/100
# 43/43 [==============================] - ETA: 0s - loss: 9.3466e-04
# Epoch 18: val_loss improved from 0.01664 to 0.01423, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 9.3466e-04 - val_loss: 0.0142
# Epoch 19/100
# 43/43 [==============================] - ETA: 0s - loss: 9.2289e-04
# Epoch 19: val_loss did not improve from 0.01423
# 43/43 [==============================] - 2s 47ms/step - loss: 9.2289e-04 - val_loss: 0.0166
# Epoch 20/100
# 43/43 [==============================] - ETA: 0s - loss: 9.0066e-04
# Epoch 20: val_loss did not improve from 0.01423
# 43/43 [==============================] - 2s 47ms/step - loss: 9.0066e-04 - val_loss: 0.0184
# Epoch 21/100
# 43/43 [==============================] - ETA: 0s - loss: 9.3025e-04
# Epoch 21: val_loss did not improve from 0.01423
# 43/43 [==============================] - 2s 48ms/step - loss: 9.3025e-04 - val_loss: 0.0187
# Epoch 22/100
# 43/43 [==============================] - ETA: 0s - loss: 8.1382e-04
# Epoch 22: val_loss did not improve from 0.01423
# 43/43 [==============================] - 2s 49ms/step - loss: 8.1382e-04 - val_loss: 0.0151
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 8.8286e-04
# Epoch 23: val_loss did not improve from 0.01423
# 43/43 [==============================] - 2s 47ms/step - loss: 8.8286e-04 - val_loss: 0.0165
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 8.5044e-04
# Epoch 24: val_loss improved from 0.01423 to 0.01254, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 49ms/step - loss: 8.5044e-04 - val_loss: 0.0125
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.4208e-04
# Epoch 25: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 49ms/step - loss: 8.3981e-04 - val_loss: 0.0127
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 8.4363e-04
# Epoch 26: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 49ms/step - loss: 8.4363e-04 - val_loss: 0.0143
# Epoch 27/100
# 43/43 [==============================] - ETA: 0s - loss: 7.6194e-04
# Epoch 27: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 48ms/step - loss: 7.6194e-04 - val_loss: 0.0164
# Epoch 28/100
# 43/43 [==============================] - ETA: 0s - loss: 7.4852e-04
# Epoch 28: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 48ms/step - loss: 7.4852e-04 - val_loss: 0.0155
# Epoch 29/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.7583e-04
# Epoch 29: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 50ms/step - loss: 8.7847e-04 - val_loss: 0.0127
# Epoch 30/100
# 43/43 [==============================] - ETA: 0s - loss: 7.6969e-04
# Epoch 30: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 47ms/step - loss: 7.6969e-04 - val_loss: 0.0169
# Epoch 31/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.1917e-04
# Epoch 31: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 46ms/step - loss: 7.2327e-04 - val_loss: 0.0142
# Epoch 32/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.3567e-04
# Epoch 32: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 47ms/step - loss: 6.3506e-04 - val_loss: 0.0151
# Epoch 33/100
# 43/43 [==============================] - ETA: 0s - loss: 7.0087e-04
# Epoch 33: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 50ms/step - loss: 7.0087e-04 - val_loss: 0.0167
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 6.5201e-04
# Epoch 34: val_loss did not improve from 0.01254
# 43/43 [==============================] - 2s 49ms/step - loss: 6.5201e-04 - val_loss: 0.0159
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:171569.39303043176
# [58108.264578442984, 171569.39303043176]

# %%
predict
# Out:
# [array([[863312.7]], dtype=float32), array([[682905.6]], dtype=float32)]

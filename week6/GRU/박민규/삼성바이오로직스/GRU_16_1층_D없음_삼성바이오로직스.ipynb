# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv") 
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=1ecd73129f6db4f4ce553a3f6bf3a99871b5c29241b10a8f886dd78d644876eb
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0487
# Epoch 1: val_loss improved from inf to 0.09543, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 2s 17ms/step - loss: 0.0429 - val_loss: 0.0954
# Epoch 2/100
# 23/34 [===================>..........] - ETA: 0s - loss: 0.0143
# Epoch 2: val_loss improved from 0.09543 to 0.01822, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0182
# Epoch 3/100
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0070
# Epoch 3: val_loss improved from 0.01822 to 0.00550, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 4/100
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0043
# Epoch 4: val_loss improved from 0.00550 to 0.00203, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 5/100
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0036
# Epoch 5: val_loss did not improve from 0.00203
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 6/100
# 25/34 [=====================>........] - ETA: 0s - loss: 0.0021
# Epoch 6: val_loss did not improve from 0.00203
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 7/100
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0018
# Epoch 7: val_loss improved from 0.00203 to 0.00195, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 8/100
# 24/34 [====================>.........] - ETA: 0s - loss: 0.0017
# Epoch 8: val_loss improved from 0.00195 to 0.00179, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 9: val_loss did not improve from 0.00179
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 10: val_loss improved from 0.00179 to 0.00175, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 8.7326e-04
# Epoch 11: val_loss did not improve from 0.00175
# 34/34 [==============================] - 0s 6ms/step - loss: 8.7326e-04 - val_loss: 0.0019
# Epoch 12/100
# 24/34 [====================>.........] - ETA: 0s - loss: 7.9582e-04
# Epoch 12: val_loss improved from 0.00175 to 0.00173, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 7.6574e-04 - val_loss: 0.0017
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 7.2982e-04
# Epoch 13: val_loss did not improve from 0.00173
# 34/34 [==============================] - 0s 6ms/step - loss: 7.2982e-04 - val_loss: 0.0021
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 7.1422e-04
# Epoch 14: val_loss improved from 0.00173 to 0.00165, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 7.1422e-04 - val_loss: 0.0017
# Epoch 15/100
# 23/34 [===================>..........] - ETA: 0s - loss: 5.9466e-04
# Epoch 15: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 6.2683e-04 - val_loss: 0.0019
# Epoch 16/100
# 23/34 [===================>..........] - ETA: 0s - loss: 6.8157e-04
# Epoch 16: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 7ms/step - loss: 6.8630e-04 - val_loss: 0.0026
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 6.5629e-04
# Epoch 17: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 6.5629e-04 - val_loss: 0.0019
# Epoch 18/100
# 24/34 [====================>.........] - ETA: 0s - loss: 5.6119e-04
# Epoch 18: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 5.8726e-04 - val_loss: 0.0018
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 5.3327e-04
# Epoch 19: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 5.3327e-04 - val_loss: 0.0017
# Epoch 20/100
# 23/34 [===================>..........] - ETA: 0s - loss: 6.4447e-04
# Epoch 20: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 6.0830e-04 - val_loss: 0.0017
# Epoch 21/100
# 25/34 [=====================>........] - ETA: 0s - loss: 5.5502e-04
# Epoch 21: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 5.6497e-04 - val_loss: 0.0029
# Epoch 22/100
# 23/34 [===================>..........] - ETA: 0s - loss: 6.1313e-04
# Epoch 22: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 6ms/step - loss: 5.6819e-04 - val_loss: 0.0020
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 5.8453e-04
# Epoch 23: val_loss improved from 0.00165 to 0.00155, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 5.8453e-04 - val_loss: 0.0015
# Epoch 24/100
# 24/34 [====================>.........] - ETA: 0s - loss: 4.7636e-04
# Epoch 24: val_loss improved from 0.00155 to 0.00141, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 5.1139e-04 - val_loss: 0.0014
# Epoch 25/100
# 25/34 [=====================>........] - ETA: 0s - loss: 5.0584e-04
# Epoch 25: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 5.0131e-04 - val_loss: 0.0019
# Epoch 26/100
# 25/34 [=====================>........] - ETA: 0s - loss: 4.6114e-04
# Epoch 26: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.5947e-04 - val_loss: 0.0017
# Epoch 27/100
# 24/34 [====================>.........] - ETA: 0s - loss: 4.7071e-04
# Epoch 27: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.6301e-04 - val_loss: 0.0015
# Epoch 28/100
# 24/34 [====================>.........] - ETA: 0s - loss: 5.0721e-04
# Epoch 28: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.9398e-04 - val_loss: 0.0015
# Epoch 29/100
# 25/34 [=====================>........] - ETA: 0s - loss: 5.3628e-04
# Epoch 29: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 5.1638e-04 - val_loss: 0.0015
# Epoch 30/100
# 23/34 [===================>..........] - ETA: 0s - loss: 4.6056e-04
# Epoch 30: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.6153e-04 - val_loss: 0.0022
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6980e-04
# Epoch 31: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.6980e-04 - val_loss: 0.0014
# Epoch 32/100
# 25/34 [=====================>........] - ETA: 0s - loss: 4.4780e-04
# Epoch 32: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.3498e-04 - val_loss: 0.0014
# Epoch 33/100
# 25/34 [=====================>........] - ETA: 0s - loss: 4.2830e-04
# Epoch 33: val_loss did not improve from 0.00141
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1493e-04 - val_loss: 0.0018
# Epoch 34/100
# 24/34 [====================>.........] - ETA: 0s - loss: 4.9162e-04
# Epoch 34: val_loss improved from 0.00141 to 0.00137, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 4.4423e-04 - val_loss: 0.0014
# Epoch 35/100
# 24/34 [====================>.........] - ETA: 0s - loss: 4.2725e-04
# Epoch 35: val_loss did not improve from 0.00137
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1727e-04 - val_loss: 0.0018
# Epoch 36/100
# 23/34 [===================>..........] - ETA: 0s - loss: 3.8274e-04
# Epoch 36: val_loss did not improve from 0.00137
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1488e-04 - val_loss: 0.0018
# Epoch 37/100
# 25/34 [=====================>........] - ETA: 0s - loss: 4.3927e-04
# Epoch 37: val_loss improved from 0.00137 to 0.00131, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 4.4944e-04 - val_loss: 0.0013
# Epoch 38/100
# 24/34 [====================>.........] - ETA: 0s - loss: 3.3720e-04
# Epoch 38: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8769e-04 - val_loss: 0.0018
# Epoch 39/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.1769e-04
# Epoch 39: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1734e-04 - val_loss: 0.0018
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8257e-04
# Epoch 40: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8035e-04 - val_loss: 0.0020
# Epoch 41/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1505e-04
# Epoch 41: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1505e-04 - val_loss: 0.0018
# Epoch 42/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9543e-04
# Epoch 42: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 4.0046e-04 - val_loss: 0.0014
# Epoch 43/100
# 25/34 [=====================>........] - ETA: 0s - loss: 4.1373e-04
# Epoch 43: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.7219e-04 - val_loss: 0.0017
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 3.6652e-04
# Epoch 44: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.6652e-04 - val_loss: 0.0016
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 4.5429e-04
# Epoch 45: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 4.5429e-04 - val_loss: 0.0019
# Epoch 46/100
# 24/34 [====================>.........] - ETA: 0s - loss: 3.7765e-04
# Epoch 46: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.5295e-04 - val_loss: 0.0015
# Epoch 47/100
# 23/34 [===================>..........] - ETA: 0s - loss: 3.4360e-04
# Epoch 47: val_loss did not improve from 0.00131
# 34/34 [==============================] - 0s 6ms/step - loss: 3.3997e-04 - val_loss: 0.0022
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:55243.346498622996
# [55243.346498622996]
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 1: val_loss improved from inf to 0.19151, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 14ms/step - loss: 0.0126 - val_loss: 0.1915
# Epoch 2/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 2: val_loss improved from 0.19151 to 0.08291, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0829
# Epoch 3/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 3: val_loss improved from 0.08291 to 0.07349, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0735
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 4: val_loss improved from 0.07349 to 0.06662, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0666
# Epoch 5/100
# 38/43 [=========================>....] - ETA: 0s - loss: 0.0010
# Epoch 5: val_loss improved from 0.06662 to 0.05560, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0556
# Epoch 6/100
# 37/43 [========================>.....] - ETA: 0s - loss: 8.4243e-04
# Epoch 6: val_loss improved from 0.05560 to 0.04168, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 8.4042e-04 - val_loss: 0.0417
# Epoch 7/100
# 36/43 [========================>.....] - ETA: 0s - loss: 7.2706e-04
# Epoch 7: val_loss improved from 0.04168 to 0.03706, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 7.3571e-04 - val_loss: 0.0371
# Epoch 8/100
# 37/43 [========================>.....] - ETA: 0s - loss: 7.2932e-04
# Epoch 8: val_loss improved from 0.03706 to 0.02782, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 7.1830e-04 - val_loss: 0.0278
# Epoch 9/100
# 37/43 [========================>.....] - ETA: 0s - loss: 6.0361e-04
# Epoch 9: val_loss did not improve from 0.02782
# 43/43 [==============================] - 0s 8ms/step - loss: 6.1016e-04 - val_loss: 0.0347
# Epoch 10/100
# 36/43 [========================>.....] - ETA: 0s - loss: 6.7032e-04
# Epoch 10: val_loss did not improve from 0.02782
# 43/43 [==============================] - 0s 8ms/step - loss: 6.6028e-04 - val_loss: 0.0289
# Epoch 11/100
# 38/43 [=========================>....] - ETA: 0s - loss: 5.1063e-04
# Epoch 11: val_loss did not improve from 0.02782
# 43/43 [==============================] - 0s 8ms/step - loss: 5.2841e-04 - val_loss: 0.0293
# Epoch 12/100
# 37/43 [========================>.....] - ETA: 0s - loss: 4.4314e-04
# Epoch 12: val_loss improved from 0.02782 to 0.02455, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 4.5277e-04 - val_loss: 0.0246
# Epoch 13/100
# 39/43 [==========================>...] - ETA: 0s - loss: 4.2935e-04
# Epoch 13: val_loss improved from 0.02455 to 0.02349, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 4.2676e-04 - val_loss: 0.0235
# Epoch 14/100
# 38/43 [=========================>....] - ETA: 0s - loss: 4.3552e-04
# Epoch 14: val_loss did not improve from 0.02349
# 43/43 [==============================] - 0s 8ms/step - loss: 4.2785e-04 - val_loss: 0.0273
# Epoch 15/100
# 37/43 [========================>.....] - ETA: 0s - loss: 3.9244e-04
# Epoch 15: val_loss did not improve from 0.02349
# 43/43 [==============================] - 0s 8ms/step - loss: 4.0757e-04 - val_loss: 0.0266
# Epoch 16/100
# 38/43 [=========================>....] - ETA: 0s - loss: 4.0580e-04
# Epoch 16: val_loss did not improve from 0.02349
# 43/43 [==============================] - 0s 8ms/step - loss: 4.0342e-04 - val_loss: 0.0240
# Epoch 17/100
# 39/43 [==========================>...] - ETA: 0s - loss: 3.5524e-04
# Epoch 17: val_loss improved from 0.02349 to 0.02206, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 3.4925e-04 - val_loss: 0.0221
# Epoch 18/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.3360e-04
# Epoch 18: val_loss did not improve from 0.02206
# 43/43 [==============================] - 0s 10ms/step - loss: 3.4367e-04 - val_loss: 0.0249
# Epoch 19/100
# 43/43 [==============================] - ETA: 0s - loss: 3.6192e-04
# Epoch 19: val_loss did not improve from 0.02206
# 43/43 [==============================] - 0s 8ms/step - loss: 3.6192e-04 - val_loss: 0.0223
# Epoch 20/100
# 39/43 [==========================>...] - ETA: 0s - loss: 3.8178e-04
# Epoch 20: val_loss did not improve from 0.02206
# 43/43 [==============================] - 0s 8ms/step - loss: 3.7408e-04 - val_loss: 0.0238
# Epoch 21/100
# 38/43 [=========================>....] - ETA: 0s - loss: 3.6325e-04
# Epoch 21: val_loss improved from 0.02206 to 0.02120, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 3.5444e-04 - val_loss: 0.0212
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.1052e-04
# Epoch 22: val_loss did not improve from 0.02120
# 43/43 [==============================] - 0s 9ms/step - loss: 3.1124e-04 - val_loss: 0.0231
# Epoch 23/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.8583e-04
# Epoch 23: val_loss improved from 0.02120 to 0.01744, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 2.9080e-04 - val_loss: 0.0174
# Epoch 24/100
# 39/43 [==========================>...] - ETA: 0s - loss: 3.1972e-04
# Epoch 24: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 3.0889e-04 - val_loss: 0.0198
# Epoch 25/100
# 36/43 [========================>.....] - ETA: 0s - loss: 2.6745e-04
# Epoch 25: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 2.7423e-04 - val_loss: 0.0226
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 2.7291e-04
# Epoch 26: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 9ms/step - loss: 2.7291e-04 - val_loss: 0.0182
# Epoch 27/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.9924e-04
# Epoch 27: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 3.0219e-04 - val_loss: 0.0230
# Epoch 28/100
# 37/43 [========================>.....] - ETA: 0s - loss: 4.3574e-04
# Epoch 28: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 4.3512e-04 - val_loss: 0.0199
# Epoch 29/100
# 41/43 [===========================>..] - ETA: 0s - loss: 3.3095e-04
# Epoch 29: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 9ms/step - loss: 3.2908e-04 - val_loss: 0.0179
# Epoch 30/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.9309e-04
# Epoch 30: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 2.8119e-04 - val_loss: 0.0207
# Epoch 31/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.8833e-04
# Epoch 31: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 2.9124e-04 - val_loss: 0.0183
# Epoch 32/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.4481e-04
# Epoch 32: val_loss did not improve from 0.01744
# 43/43 [==============================] - 0s 8ms/step - loss: 2.7095e-04 - val_loss: 0.0176
# Epoch 33/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.6015e-04
# Epoch 33: val_loss improved from 0.01744 to 0.01739, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.5625e-04 - val_loss: 0.0174
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 2.7155e-04
# Epoch 34: val_loss did not improve from 0.01739
# 43/43 [==============================] - 0s 9ms/step - loss: 2.7155e-04 - val_loss: 0.0224
# Epoch 35/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.6193e-04
# Epoch 35: val_loss did not improve from 0.01739
# 43/43 [==============================] - 0s 8ms/step - loss: 2.4939e-04 - val_loss: 0.0187
# Epoch 36/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.5507e-04
# Epoch 36: val_loss did not improve from 0.01739
# 43/43 [==============================] - 0s 8ms/step - loss: 2.5384e-04 - val_loss: 0.0214
# Epoch 37/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.5068e-04
# Epoch 37: val_loss did not improve from 0.01739
# 43/43 [==============================] - 0s 9ms/step - loss: 2.5739e-04 - val_loss: 0.0189
# Epoch 38/100
# 36/43 [========================>.....] - ETA: 0s - loss: 2.2446e-04
# Epoch 38: val_loss improved from 0.01739 to 0.01591, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 10ms/step - loss: 2.3272e-04 - val_loss: 0.0159
# Epoch 39/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3022e-04
# Epoch 39: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 9ms/step - loss: 2.3022e-04 - val_loss: 0.0201
# Epoch 40/100
# 43/43 [==============================] - ETA: 0s - loss: 2.2097e-04
# Epoch 40: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2097e-04 - val_loss: 0.0179
# Epoch 41/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.2447e-04
# Epoch 41: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 9ms/step - loss: 2.2205e-04 - val_loss: 0.0174
# Epoch 42/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4898e-04
# Epoch 42: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 9ms/step - loss: 2.4872e-04 - val_loss: 0.0175
# Epoch 43/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1145e-04
# Epoch 43: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 9ms/step - loss: 2.1726e-04 - val_loss: 0.0166
# Epoch 44/100
# 43/43 [==============================] - ETA: 0s - loss: 2.2194e-04
# Epoch 44: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 9ms/step - loss: 2.2194e-04 - val_loss: 0.0182
# Epoch 45/100
# 37/43 [========================>.....] - ETA: 0s - loss: 1.9929e-04
# Epoch 45: val_loss did not improve from 0.01591
# 43/43 [==============================] - 0s 8ms/step - loss: 2.0711e-04 - val_loss: 0.0160
# Epoch 46/100
# 43/43 [==============================] - ETA: 0s - loss: 2.4513e-04
# Epoch 46: val_loss improved from 0.01591 to 0.01495, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 2.4513e-04 - val_loss: 0.0149
# Epoch 47/100
# 36/43 [========================>.....] - ETA: 0s - loss: 2.7217e-04
# Epoch 47: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 9ms/step - loss: 2.6079e-04 - val_loss: 0.0163
# Epoch 48/100
# 36/43 [========================>.....] - ETA: 0s - loss: 2.2227e-04
# Epoch 48: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3121e-04 - val_loss: 0.0154
# Epoch 49/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.4664e-04
# Epoch 49: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3585e-04 - val_loss: 0.0168
# Epoch 50/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.1884e-04
# Epoch 50: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 9ms/step - loss: 2.1741e-04 - val_loss: 0.0201
# Epoch 51/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.2346e-04
# Epoch 51: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2004e-04 - val_loss: 0.0193
# Epoch 52/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.3604e-04
# Epoch 52: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 9ms/step - loss: 2.3415e-04 - val_loss: 0.0178
# Epoch 53/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.2601e-04
# Epoch 53: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.1795e-04 - val_loss: 0.0175
# Epoch 54/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.4248e-04
# Epoch 54: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3607e-04 - val_loss: 0.0168
# Epoch 55/100
# 38/43 [=========================>....] - ETA: 0s - loss: 1.8564e-04
# Epoch 55: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 2.1110e-04 - val_loss: 0.0250
# Epoch 56/100
# 39/43 [==========================>...] - ETA: 0s - loss: 3.2072e-04
# Epoch 56: val_loss did not improve from 0.01495
# 43/43 [==============================] - 0s 8ms/step - loss: 3.2029e-04 - val_loss: 0.0154
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:263999.77359946806
# [55243.346498622996, 263999.77359946806]

# %%
predict
# Out:
# [array([[891327.8]], dtype=float32), array([[583469.44]], dtype=float32)]

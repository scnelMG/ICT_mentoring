# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0196
# Epoch 1: val_loss improved from inf to 0.01349, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 4s 29ms/step - loss: 0.0182 - val_loss: 0.0135
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss improved from 0.01349 to 0.00489, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.6708e-04
# Epoch 3: val_loss improved from 0.00489 to 0.00165, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 9.5974e-04 - val_loss: 0.0016
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 7.3796e-04
# Epoch 4: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 13ms/step - loss: 7.3796e-04 - val_loss: 0.0019
# Epoch 5/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.7141e-04
# Epoch 5: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 13ms/step - loss: 6.2890e-04 - val_loss: 0.0017
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 5.8079e-04
# Epoch 6: val_loss did not improve from 0.00165
# 34/34 [==============================] - 0s 14ms/step - loss: 5.8079e-04 - val_loss: 0.0017
# Epoch 7/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.6039e-04
# Epoch 7: val_loss improved from 0.00165 to 0.00155, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 5.3610e-04 - val_loss: 0.0015
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 5.2513e-04
# Epoch 8: val_loss did not improve from 0.00155
# 34/34 [==============================] - 0s 14ms/step - loss: 5.2513e-04 - val_loss: 0.0019
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.7434e-04
# Epoch 9: val_loss did not improve from 0.00155
# 34/34 [==============================] - 0s 14ms/step - loss: 4.7383e-04 - val_loss: 0.0019
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.6745e-04
# Epoch 10: val_loss did not improve from 0.00155
# 34/34 [==============================] - 0s 13ms/step - loss: 4.5548e-04 - val_loss: 0.0017
# Epoch 11/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.6220e-04
# Epoch 11: val_loss did not improve from 0.00155
# 34/34 [==============================] - 0s 12ms/step - loss: 4.5048e-04 - val_loss: 0.0019
# Epoch 12/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.4577e-04
# Epoch 12: val_loss improved from 0.00155 to 0.00143, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3617e-04 - val_loss: 0.0014
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3291e-04
# Epoch 13: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3291e-04 - val_loss: 0.0016
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.0611e-04
# Epoch 14: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3596e-04 - val_loss: 0.0019
# Epoch 15/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.0682e-04
# Epoch 15: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 4.0325e-04 - val_loss: 0.0021
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.1752e-04
# Epoch 16: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 4.0617e-04 - val_loss: 0.0019
# Epoch 17/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.8405e-04
# Epoch 17: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 3.7691e-04 - val_loss: 0.0018
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7088e-04
# Epoch 18: val_loss did not improve from 0.00143
# 34/34 [==============================] - 0s 13ms/step - loss: 3.7949e-04 - val_loss: 0.0017
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.2343e-04
# Epoch 19: val_loss did not improve from 0.00143
# 34/34 [==============================] - 1s 15ms/step - loss: 4.0747e-04 - val_loss: 0.0024
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.9122e-04
# Epoch 20: val_loss improved from 0.00143 to 0.00138, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 3.8554e-04 - val_loss: 0.0014
# Epoch 21/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8224e-04
# Epoch 21: val_loss did not improve from 0.00138
# 34/34 [==============================] - 1s 15ms/step - loss: 3.8323e-04 - val_loss: 0.0016
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3960e-04
# Epoch 22: val_loss did not improve from 0.00138
# 34/34 [==============================] - 1s 15ms/step - loss: 3.6059e-04 - val_loss: 0.0035
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 3.9840e-04
# Epoch 23: val_loss did not improve from 0.00138
# 34/34 [==============================] - 0s 14ms/step - loss: 3.9840e-04 - val_loss: 0.0024
# Epoch 24/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.0592e-04
# Epoch 24: val_loss did not improve from 0.00138
# 34/34 [==============================] - 0s 13ms/step - loss: 3.5078e-04 - val_loss: 0.0022
# Epoch 25/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.1506e-04
# Epoch 25: val_loss did not improve from 0.00138
# 34/34 [==============================] - 0s 13ms/step - loss: 3.4599e-04 - val_loss: 0.0020
# Epoch 26/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.5982e-04
# Epoch 26: val_loss did not improve from 0.00138
# 34/34 [==============================] - 0s 13ms/step - loss: 3.5331e-04 - val_loss: 0.0026
# Epoch 27/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2402e-04
# Epoch 27: val_loss improved from 0.00138 to 0.00133, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 3.2057e-04 - val_loss: 0.0013
# Epoch 28/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6542e-04
# Epoch 28: val_loss did not improve from 0.00133
# 34/34 [==============================] - 0s 12ms/step - loss: 3.5635e-04 - val_loss: 0.0016
# Epoch 29/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5423e-04
# Epoch 29: val_loss improved from 0.00133 to 0.00127, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 3.6233e-04 - val_loss: 0.0013
# Epoch 30/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.0686e-04
# Epoch 30: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 4.0479e-04 - val_loss: 0.0021
# Epoch 31/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2266e-04
# Epoch 31: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 12ms/step - loss: 3.3453e-04 - val_loss: 0.0021
# Epoch 32/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.1988e-04
# Epoch 32: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 3.1485e-04 - val_loss: 0.0019
# Epoch 33/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.0719e-04
# Epoch 33: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0299e-04 - val_loss: 0.0017
# Epoch 34/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0447e-04
# Epoch 34: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 3.0562e-04 - val_loss: 0.0016
# Epoch 35/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.1321e-04
# Epoch 35: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 3.1661e-04 - val_loss: 0.0015
# Epoch 36/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2285e-04
# Epoch 36: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 3.1535e-04 - val_loss: 0.0020
# Epoch 37/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.7618e-04
# Epoch 37: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 13ms/step - loss: 2.9571e-04 - val_loss: 0.0020
# Epoch 38/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0847e-04
# Epoch 38: val_loss did not improve from 0.00127
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0805e-04 - val_loss: 0.0019
# Epoch 39/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.0560e-04
# Epoch 39: val_loss improved from 0.00127 to 0.00121, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 3.0239e-04 - val_loss: 0.0012
# Epoch 40/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.7753e-04
# Epoch 40: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 12ms/step - loss: 2.8453e-04 - val_loss: 0.0020
# Epoch 41/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.0577e-04
# Epoch 41: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 13ms/step - loss: 3.1076e-04 - val_loss: 0.0019
# Epoch 42/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9071e-04
# Epoch 42: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 12ms/step - loss: 2.9457e-04 - val_loss: 0.0015
# Epoch 43/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.8782e-04
# Epoch 43: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 13ms/step - loss: 2.8222e-04 - val_loss: 0.0021
# Epoch 44/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.1336e-04
# Epoch 44: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0721e-04 - val_loss: 0.0014
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 2.9655e-04
# Epoch 45: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 12ms/step - loss: 2.9655e-04 - val_loss: 0.0014
# Epoch 46/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2412e-04
# Epoch 46: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 12ms/step - loss: 3.3797e-04 - val_loss: 0.0017
# Epoch 47/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.8281e-04
# Epoch 47: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 13ms/step - loss: 3.0320e-04 - val_loss: 0.0012
# Epoch 48/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.7553e-04
# Epoch 48: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 13ms/step - loss: 2.7067e-04 - val_loss: 0.0018
# Epoch 49/100
# 34/34 [==============================] - ETA: 0s - loss: 2.6842e-04
# Epoch 49: val_loss did not improve from 0.00121
# 34/34 [==============================] - 0s 13ms/step - loss: 2.6842e-04 - val_loss: 0.0024
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:71167.40867988007
# [71167.40867988007]
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 1: val_loss improved from inf to 0.03113, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 4s 35ms/step - loss: 0.0217 - val_loss: 0.0311
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss improved from 0.03113 to 0.01905, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0020 - val_loss: 0.0191
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 3: val_loss improved from 0.01905 to 0.01034, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0012 - val_loss: 0.0103
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 7.7104e-04
# Epoch 4: val_loss improved from 0.01034 to 0.00696, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 22ms/step - loss: 7.7104e-04 - val_loss: 0.0070
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 5.8663e-04
# Epoch 5: val_loss improved from 0.00696 to 0.00498, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 5.8663e-04 - val_loss: 0.0050
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.0870e-04
# Epoch 6: val_loss improved from 0.00498 to 0.00384, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 22ms/step - loss: 5.0623e-04 - val_loss: 0.0038
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 5.0988e-04
# Epoch 7: val_loss did not improve from 0.00384
# 43/43 [==============================] - 1s 21ms/step - loss: 5.0988e-04 - val_loss: 0.0043
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 4.7175e-04
# Epoch 8: val_loss did not improve from 0.00384
# 43/43 [==============================] - 1s 21ms/step - loss: 4.7175e-04 - val_loss: 0.0052
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 4.0400e-04
# Epoch 9: val_loss did not improve from 0.00384
# 43/43 [==============================] - 1s 20ms/step - loss: 4.0400e-04 - val_loss: 0.0050
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 3.9439e-04
# Epoch 10: val_loss did not improve from 0.00384
# 43/43 [==============================] - 1s 20ms/step - loss: 3.9439e-04 - val_loss: 0.0051
# Epoch 11/100
# 43/43 [==============================] - ETA: 0s - loss: 3.7050e-04
# Epoch 11: val_loss improved from 0.00384 to 0.00333, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 3.7050e-04 - val_loss: 0.0033
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 3.7700e-04
# Epoch 12: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 21ms/step - loss: 3.7700e-04 - val_loss: 0.0051
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 3.4505e-04
# Epoch 13: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 19ms/step - loss: 3.4505e-04 - val_loss: 0.0036
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 3.4253e-04
# Epoch 14: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 3.4253e-04 - val_loss: 0.0041
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 3.4770e-04
# Epoch 15: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 3.4770e-04 - val_loss: 0.0045
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 3.1446e-04
# Epoch 16: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 3.1446e-04 - val_loss: 0.0064
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 2.9784e-04
# Epoch 17: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 2.9784e-04 - val_loss: 0.0060
# Epoch 18/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.9902e-04
# Epoch 18: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 21ms/step - loss: 2.9629e-04 - val_loss: 0.0055
# Epoch 19/100
# 43/43 [==============================] - ETA: 0s - loss: 2.6688e-04
# Epoch 19: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 2.6688e-04 - val_loss: 0.0061
# Epoch 20/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8237e-04
# Epoch 20: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 20ms/step - loss: 2.8237e-04 - val_loss: 0.0046
# Epoch 21/100
# 43/43 [==============================] - ETA: 0s - loss: 2.7735e-04
# Epoch 21: val_loss did not improve from 0.00333
# 43/43 [==============================] - 1s 19ms/step - loss: 2.7735e-04 - val_loss: 0.0067
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:103536.00250585222
# [71167.40867988007, 103536.00250585222]

# %%
predict
# Out:
# [array([[768344.44]], dtype=float32), array([[802507.2]], dtype=float32)]

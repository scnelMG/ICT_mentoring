# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False, 
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0862
# Epoch 1: val_loss improved from inf to 0.02572, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0727 - val_loss: 0.0257
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 2: val_loss improved from 0.02572 to 0.00216, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 3: val_loss improved from 0.00216 to 0.00138, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 4/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0014
# Epoch 4: val_loss improved from 0.00138 to 0.00100, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 9.9833e-04
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 5: val_loss improved from 0.00100 to 0.00096, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 9.6094e-04
# Epoch 6/100
# 30/34 [=========================>....] - ETA: 0s - loss: 9.9757e-04
# Epoch 6: val_loss improved from 0.00096 to 0.00084, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 8.3725e-04
# Epoch 7/100
# 29/34 [========================>.....] - ETA: 0s - loss: 8.4834e-04
# Epoch 7: val_loss did not improve from 0.00084
# 34/34 [==============================] - 0s 10ms/step - loss: 8.9357e-04 - val_loss: 0.0010
# Epoch 8/100
# 25/34 [=====================>........] - ETA: 0s - loss: 8.6908e-04
# Epoch 8: val_loss improved from 0.00084 to 0.00083, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 8ms/step - loss: 8.5428e-04 - val_loss: 8.2850e-04
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 6.8875e-04
# Epoch 9: val_loss improved from 0.00083 to 0.00068, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 7.2935e-04 - val_loss: 6.7849e-04
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1233e-04
# Epoch 10: val_loss improved from 0.00068 to 0.00066, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 7ms/step - loss: 7.0155e-04 - val_loss: 6.5562e-04
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.1948e-04
# Epoch 11: val_loss improved from 0.00066 to 0.00063, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 6.1446e-04 - val_loss: 6.2795e-04
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 5.6756e-04
# Epoch 12: val_loss improved from 0.00063 to 0.00061, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 5.6756e-04 - val_loss: 6.0927e-04
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 5.2313e-04
# Epoch 13: val_loss did not improve from 0.00061
# 34/34 [==============================] - 0s 6ms/step - loss: 5.2313e-04 - val_loss: 6.3030e-04
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.9461e-04
# Epoch 14: val_loss did not improve from 0.00061
# 34/34 [==============================] - 0s 6ms/step - loss: 4.9302e-04 - val_loss: 7.4584e-04
# Epoch 15/100
# 24/34 [====================>.........] - ETA: 0s - loss: 5.1797e-04
# Epoch 15: val_loss did not improve from 0.00061
# 34/34 [==============================] - 0s 6ms/step - loss: 4.9024e-04 - val_loss: 6.5430e-04
# Epoch 16/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.7084e-04
# Epoch 16: val_loss did not improve from 0.00061
# 34/34 [==============================] - 0s 6ms/step - loss: 4.6567e-04 - val_loss: 7.8017e-04
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4274e-04
# Epoch 17: val_loss did not improve from 0.00061
# 34/34 [==============================] - 0s 6ms/step - loss: 4.4199e-04 - val_loss: 6.2473e-04
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1999e-04
# Epoch 18: val_loss improved from 0.00061 to 0.00057, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1999e-04 - val_loss: 5.7336e-04
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2394e-04
# Epoch 19: val_loss did not improve from 0.00057
# 34/34 [==============================] - 0s 6ms/step - loss: 4.1970e-04 - val_loss: 5.7851e-04
# Epoch 20/100
# 25/34 [=====================>........] - ETA: 0s - loss: 3.9140e-04
# Epoch 20: val_loss did not improve from 0.00057
# 34/34 [==============================] - 0s 6ms/step - loss: 3.7993e-04 - val_loss: 5.8715e-04
# Epoch 21/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7680e-04
# Epoch 21: val_loss did not improve from 0.00057
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8438e-04 - val_loss: 7.6448e-04
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 3.7171e-04
# Epoch 22: val_loss did not improve from 0.00057
# 34/34 [==============================] - 0s 6ms/step - loss: 3.7171e-04 - val_loss: 6.3320e-04
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 3.5990e-04
# Epoch 23: val_loss improved from 0.00057 to 0.00056, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 6ms/step - loss: 3.5990e-04 - val_loss: 5.5673e-04
# Epoch 24/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5132e-04
# Epoch 24: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.4925e-04 - val_loss: 7.4825e-04
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5222e-04
# Epoch 25: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.4929e-04 - val_loss: 5.7489e-04
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 3.4974e-04
# Epoch 26: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.4974e-04 - val_loss: 7.4879e-04
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 3.3925e-04
# Epoch 27: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.3925e-04 - val_loss: 6.2566e-04
# Epoch 28/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8059e-04
# Epoch 28: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8465e-04 - val_loss: 0.0011
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9045e-04
# Epoch 29: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.9360e-04 - val_loss: 0.0011
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5276e-04
# Epoch 30: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.4335e-04 - val_loss: 9.7026e-04
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2240e-04
# Epoch 31: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.2240e-04 - val_loss: 6.4436e-04
# Epoch 32/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.6939e-04
# Epoch 32: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.6910e-04 - val_loss: 6.1297e-04
# Epoch 33/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7513e-04
# Epoch 33: val_loss did not improve from 0.00056
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8171e-04 - val_loss: 6.4461e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:27658.583852533928
# [27658.583852533928]
# Epoch 1/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0188
# Epoch 1: val_loss improved from inf to 0.10302, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 12ms/step - loss: 0.0174 - val_loss: 0.1030
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 2: val_loss improved from 0.10302 to 0.04516, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0452
# Epoch 3/100
# 41/43 [===========================>..] - ETA: 0s - loss: 6.3199e-04
# Epoch 3: val_loss improved from 0.04516 to 0.03125, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 6.3355e-04 - val_loss: 0.0313
# Epoch 4/100
# 40/43 [==========================>...] - ETA: 0s - loss: 5.1402e-04
# Epoch 4: val_loss improved from 0.03125 to 0.02815, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 5.1487e-04 - val_loss: 0.0282
# Epoch 5/100
# 39/43 [==========================>...] - ETA: 0s - loss: 4.6468e-04
# Epoch 5: val_loss improved from 0.02815 to 0.02287, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 4.4916e-04 - val_loss: 0.0229
# Epoch 6/100
# 38/43 [=========================>....] - ETA: 0s - loss: 3.8045e-04
# Epoch 6: val_loss improved from 0.02287 to 0.01957, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 9ms/step - loss: 3.9199e-04 - val_loss: 0.0196
# Epoch 7/100
# 40/43 [==========================>...] - ETA: 0s - loss: 3.8474e-04
# Epoch 7: val_loss improved from 0.01957 to 0.01422, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 3.7660e-04 - val_loss: 0.0142
# Epoch 8/100
# 40/43 [==========================>...] - ETA: 0s - loss: 3.3965e-04
# Epoch 8: val_loss improved from 0.01422 to 0.00968, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 3.4464e-04 - val_loss: 0.0097
# Epoch 9/100
# 38/43 [=========================>....] - ETA: 0s - loss: 3.2025e-04
# Epoch 9: val_loss improved from 0.00968 to 0.00727, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 3.1896e-04 - val_loss: 0.0073
# Epoch 10/100
# 40/43 [==========================>...] - ETA: 0s - loss: 3.0930e-04
# Epoch 10: val_loss did not improve from 0.00727
# 43/43 [==============================] - 0s 8ms/step - loss: 3.0076e-04 - val_loss: 0.0080
# Epoch 11/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.8482e-04
# Epoch 11: val_loss improved from 0.00727 to 0.00574, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.8205e-04 - val_loss: 0.0057
# Epoch 12/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.7562e-04
# Epoch 12: val_loss did not improve from 0.00574
# 43/43 [==============================] - 0s 8ms/step - loss: 2.6726e-04 - val_loss: 0.0066
# Epoch 13/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.7495e-04
# Epoch 13: val_loss improved from 0.00574 to 0.00440, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.7344e-04 - val_loss: 0.0044
# Epoch 14/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.5101e-04
# Epoch 14: val_loss did not improve from 0.00440
# 43/43 [==============================] - 0s 8ms/step - loss: 2.4644e-04 - val_loss: 0.0055
# Epoch 15/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.4065e-04
# Epoch 15: val_loss improved from 0.00440 to 0.00391, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.5230e-04 - val_loss: 0.0039
# Epoch 16/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.4971e-04
# Epoch 16: val_loss did not improve from 0.00391
# 43/43 [==============================] - 0s 8ms/step - loss: 2.4996e-04 - val_loss: 0.0051
# Epoch 17/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.4718e-04
# Epoch 17: val_loss did not improve from 0.00391
# 43/43 [==============================] - 0s 8ms/step - loss: 2.4078e-04 - val_loss: 0.0049
# Epoch 18/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.4877e-04
# Epoch 18: val_loss improved from 0.00391 to 0.00379, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3937e-04 - val_loss: 0.0038
# Epoch 19/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.9967e-04
# Epoch 19: val_loss improved from 0.00379 to 0.00357, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.9880e-04 - val_loss: 0.0036
# Epoch 20/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.8771e-04
# Epoch 20: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.9029e-04 - val_loss: 0.0048
# Epoch 21/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.3893e-04
# Epoch 21: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2804e-04 - val_loss: 0.0045
# Epoch 22/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.2007e-04
# Epoch 22: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2497e-04 - val_loss: 0.0059
# Epoch 23/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.3387e-04
# Epoch 23: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3436e-04 - val_loss: 0.0042
# Epoch 24/100
# 37/43 [========================>.....] - ETA: 0s - loss: 2.1847e-04
# Epoch 24: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.1393e-04 - val_loss: 0.0044
# Epoch 25/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.6685e-04
# Epoch 25: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 8ms/step - loss: 2.8003e-04 - val_loss: 0.0049
# Epoch 26/100
# 37/43 [========================>.....] - ETA: 0s - loss: 3.0781e-04
# Epoch 26: val_loss did not improve from 0.00357
# 43/43 [==============================] - 0s 9ms/step - loss: 2.8916e-04 - val_loss: 0.0038
# Epoch 27/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.4827e-04
# Epoch 27: val_loss improved from 0.00357 to 0.00198, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.4571e-04 - val_loss: 0.0020
# Epoch 28/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.1970e-04
# Epoch 28: val_loss did not improve from 0.00198
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3364e-04 - val_loss: 0.0023
# Epoch 29/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.5540e-04
# Epoch 29: val_loss did not improve from 0.00198
# 43/43 [==============================] - 0s 8ms/step - loss: 2.5462e-04 - val_loss: 0.0034
# Epoch 30/100
# 37/43 [========================>.....] - ETA: 0s - loss: 1.8971e-04
# Epoch 30: val_loss did not improve from 0.00198
# 43/43 [==============================] - 0s 8ms/step - loss: 1.9040e-04 - val_loss: 0.0043
# Epoch 31/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.4047e-04
# Epoch 31: val_loss improved from 0.00198 to 0.00139, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3699e-04 - val_loss: 0.0014
# Epoch 32/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.4512e-04
# Epoch 32: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3669e-04 - val_loss: 0.0030
# Epoch 33/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.3777e-04
# Epoch 33: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3280e-04 - val_loss: 0.0042
# Epoch 34/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.0055e-04
# Epoch 34: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 1.9949e-04 - val_loss: 0.0032
# Epoch 35/100
# 39/43 [==========================>...] - ETA: 0s - loss: 1.9020e-04
# Epoch 35: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 1.8251e-04 - val_loss: 0.0028
# Epoch 36/100
# 40/43 [==========================>...] - ETA: 0s - loss: 1.8196e-04
# Epoch 36: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 1.9309e-04 - val_loss: 0.0034
# Epoch 37/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9005e-04
# Epoch 37: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 1.8906e-04 - val_loss: 0.0025
# Epoch 38/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.3693e-04
# Epoch 38: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.3797e-04 - val_loss: 0.0030
# Epoch 39/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.1394e-04
# Epoch 39: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.1758e-04 - val_loss: 0.0017
# Epoch 40/100
# 39/43 [==========================>...] - ETA: 0s - loss: 2.1868e-04
# Epoch 40: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2419e-04 - val_loss: 0.0056
# Epoch 41/100
# 38/43 [=========================>....] - ETA: 0s - loss: 2.3438e-04
# Epoch 41: val_loss did not improve from 0.00139
# 43/43 [==============================] - 0s 8ms/step - loss: 2.2630e-04 - val_loss: 0.0029
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:61427.2355232957
# [27658.583852533928, 61427.2355232957]

# %%
predict
# Out:
# [array([[856247.4]], dtype=float32), array([[781825.44]], dtype=float32)]

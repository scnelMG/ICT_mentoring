# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/drive/MyDrive/HEM/data/_건강관리_삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64,
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.1.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.1-py3-none-any.whl size=28985 sha256=a5b1d9a87226a338f73984f3b58ce9b10965dc32d33300f7f9490f8a7cdccb6d
#   Stored in directory: /root/.cache/pip/wheels/bc/2a/c2/a56e77d07edc16a1fa7fb012667e55cb0643cfa65996bddecc
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.1
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0408
# Epoch 1: val_loss improved from inf to 0.02040, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 4s 37ms/step - loss: 0.0375 - val_loss: 0.0204
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss improved from 0.02040 to 0.00182, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 7.3490e-04
# Epoch 3: val_loss improved from 0.00182 to 0.00100, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 7.3490e-04 - val_loss: 0.0010
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9775e-04
# Epoch 4: val_loss improved from 0.00100 to 0.00084, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 4.9429e-04 - val_loss: 8.4146e-04
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3365e-04
# Epoch 5: val_loss did not improve from 0.00084
# 34/34 [==============================] - 1s 21ms/step - loss: 4.3365e-04 - val_loss: 0.0015
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.1225e-04
# Epoch 6: val_loss improved from 0.00084 to 0.00079, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 4.1260e-04 - val_loss: 7.9238e-04
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9308e-04
# Epoch 7: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 21ms/step - loss: 3.9401e-04 - val_loss: 8.6309e-04
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7520e-04
# Epoch 8: val_loss did not improve from 0.00079
# 34/34 [==============================] - 1s 18ms/step - loss: 3.9273e-04 - val_loss: 9.8221e-04
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8972e-04
# Epoch 9: val_loss improved from 0.00079 to 0.00074, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 3.9337e-04 - val_loss: 7.4123e-04
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7165e-04
# Epoch 10: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 17ms/step - loss: 3.6673e-04 - val_loss: 0.0010
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7526e-04
# Epoch 11: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7259e-04 - val_loss: 9.9658e-04
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3662e-04
# Epoch 12: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 16ms/step - loss: 3.3828e-04 - val_loss: 0.0010
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7511e-04
# Epoch 13: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7996e-04 - val_loss: 9.7713e-04
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5809e-04
# Epoch 14: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 16ms/step - loss: 3.6819e-04 - val_loss: 0.0017
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7800e-04
# Epoch 15: val_loss did not improve from 0.00074
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7084e-04 - val_loss: 0.0010
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3387e-04
# Epoch 16: val_loss improved from 0.00074 to 0.00073, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 3.3777e-04 - val_loss: 7.3001e-04
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6612e-04
# Epoch 17: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 17ms/step - loss: 3.5709e-04 - val_loss: 9.7703e-04
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.2815e-04
# Epoch 18: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 17ms/step - loss: 4.3745e-04 - val_loss: 8.0725e-04
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.1255e-04
# Epoch 19: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1651e-04 - val_loss: 8.5716e-04
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0301e-04
# Epoch 20: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9848e-04 - val_loss: 0.0011
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8766e-04
# Epoch 21: val_loss improved from 0.00073 to 0.00066, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 2.8535e-04 - val_loss: 6.6211e-04
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0840e-04
# Epoch 22: val_loss did not improve from 0.00066
# 34/34 [==============================] - 1s 17ms/step - loss: 3.0478e-04 - val_loss: 7.2264e-04
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9653e-04
# Epoch 23: val_loss did not improve from 0.00066
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9360e-04 - val_loss: 7.5705e-04
# Epoch 24/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8700e-04
# Epoch 24: val_loss did not improve from 0.00066
# 34/34 [==============================] - 1s 17ms/step - loss: 2.8200e-04 - val_loss: 6.8522e-04
# Epoch 25/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.1535e-04
# Epoch 25: val_loss did not improve from 0.00066
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1074e-04 - val_loss: 7.3203e-04
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5055e-04
# Epoch 26: val_loss did not improve from 0.00066
# 34/34 [==============================] - 1s 17ms/step - loss: 3.4899e-04 - val_loss: 8.4184e-04
# Epoch 27/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7868e-04
# Epoch 27: val_loss improved from 0.00066 to 0.00063, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 2.7788e-04 - val_loss: 6.2709e-04
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9742e-04
# Epoch 28: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9882e-04 - val_loss: 8.6100e-04
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 3.3465e-04
# Epoch 29: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 18ms/step - loss: 3.3465e-04 - val_loss: 8.0770e-04
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.4571e-04
# Epoch 30: val_loss improved from 0.00063 to 0.00062, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 3.4918e-04 - val_loss: 6.1600e-04
# Epoch 31/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2443e-04
# Epoch 31: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 3.3269e-04 - val_loss: 9.4343e-04
# Epoch 32/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7168e-04
# Epoch 32: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7953e-04 - val_loss: 6.3180e-04
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7592e-04
# Epoch 33: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 3.7721e-04 - val_loss: 0.0010
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.7635e-04
# Epoch 34: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 2.6536e-04 - val_loss: 0.0013
# Epoch 35/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.3363e-04
# Epoch 35: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 18ms/step - loss: 3.1970e-04 - val_loss: 6.7085e-04
# Epoch 36/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.5152e-04
# Epoch 36: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5002e-04 - val_loss: 6.7700e-04
# Epoch 37/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7492e-04
# Epoch 37: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 18ms/step - loss: 2.7404e-04 - val_loss: 8.2628e-04
# Epoch 38/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.4611e-04
# Epoch 38: val_loss improved from 0.00062 to 0.00060, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 4.8743e-04 - val_loss: 5.9779e-04
# Epoch 39/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.0395e-04
# Epoch 39: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 4.0118e-04 - val_loss: 7.1853e-04
# Epoch 40/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.3725e-04
# Epoch 40: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.3586e-04 - val_loss: 6.8805e-04
# Epoch 41/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.8125e-04
# Epoch 41: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7572e-04 - val_loss: 7.4947e-04
# Epoch 42/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.8182e-04
# Epoch 42: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.8052e-04 - val_loss: 7.9252e-04
# Epoch 43/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.3764e-04
# Epoch 43: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.4565e-04 - val_loss: 6.0061e-04
# Epoch 44/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.5860e-04
# Epoch 44: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.6975e-04 - val_loss: 7.9414e-04
# Epoch 45/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.6115e-04
# Epoch 45: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 16ms/step - loss: 2.6545e-04 - val_loss: 6.8410e-04
# Epoch 46/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.6823e-04
# Epoch 46: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7123e-04 - val_loss: 6.3493e-04
# Epoch 47/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.6723e-04
# Epoch 47: val_loss did not improve from 0.00060
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7441e-04 - val_loss: 6.3031e-04
# Epoch 48/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4361e-04
# Epoch 48: val_loss improved from 0.00060 to 0.00059, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4462e-04 - val_loss: 5.9125e-04
# Epoch 49/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.3611e-04
# Epoch 49: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 17ms/step - loss: 2.3424e-04 - val_loss: 6.1374e-04
# Epoch 50/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4475e-04
# Epoch 50: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5008e-04 - val_loss: 6.0796e-04
# Epoch 51/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.3238e-04
# Epoch 51: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 17ms/step - loss: 2.3721e-04 - val_loss: 6.2663e-04
# Epoch 52/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.2304e-04
# Epoch 52: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 17ms/step - loss: 3.4631e-04 - val_loss: 8.5478e-04
# Epoch 53/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.8493e-04
# Epoch 53: val_loss improved from 0.00059 to 0.00059, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 2.8181e-04 - val_loss: 5.8661e-04
# Epoch 54/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.3705e-04
# Epoch 54: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 17ms/step - loss: 2.4732e-04 - val_loss: 6.1776e-04
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.3912e-04
# Epoch 55: val_loss improved from 0.00059 to 0.00057, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 2.3910e-04 - val_loss: 5.7078e-04
# Epoch 56/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2683e-04
# Epoch 56: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1283e-04 - val_loss: 6.1991e-04
# Epoch 57/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.9515e-04
# Epoch 57: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9136e-04 - val_loss: 6.3496e-04
# Epoch 58/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4763e-04
# Epoch 58: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 2.4776e-04 - val_loss: 5.9226e-04
# Epoch 59/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8727e-04
# Epoch 59: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9131e-04 - val_loss: 6.4739e-04
# Epoch 60/100
# 34/34 [==============================] - ETA: 0s - loss: 4.2419e-04
# Epoch 60: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 4.2419e-04 - val_loss: 8.7649e-04
# Epoch 61/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3235e-04
# Epoch 61: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 4.4992e-04 - val_loss: 7.2959e-04
# Epoch 62/100
# 34/34 [==============================] - ETA: 0s - loss: 2.7801e-04
# Epoch 62: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 18ms/step - loss: 2.7801e-04 - val_loss: 7.2857e-04
# Epoch 63/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.7420e-04
# Epoch 63: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9492e-04 - val_loss: 9.2803e-04
# Epoch 64/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6331e-04
# Epoch 64: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 3.5703e-04 - val_loss: 8.6151e-04
# Epoch 65/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.5796e-04
# Epoch 65: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5783e-04 - val_loss: 9.1064e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:32976.98383332874
# [32976.98383332874]
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0187
# Epoch 1: val_loss improved from inf to 0.04133, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 5s 36ms/step - loss: 0.0184 - val_loss: 0.0413
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 2: val_loss improved from 0.04133 to 0.03377, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0012 - val_loss: 0.0338
# Epoch 3/100
# 41/43 [===========================>..] - ETA: 0s - loss: 6.3752e-04
# Epoch 3: val_loss improved from 0.03377 to 0.02689, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 6.6780e-04 - val_loss: 0.0269
# Epoch 4/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.3217e-04
# Epoch 4: val_loss improved from 0.02689 to 0.02115, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 5.2837e-04 - val_loss: 0.0212
# Epoch 5/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.9070e-04
# Epoch 5: val_loss did not improve from 0.02115
# 43/43 [==============================] - 1s 23ms/step - loss: 4.8933e-04 - val_loss: 0.0233
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.3960e-04
# Epoch 6: val_loss improved from 0.02115 to 0.01891, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 4.4018e-04 - val_loss: 0.0189
# Epoch 7/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.6945e-04
# Epoch 7: val_loss did not improve from 0.01891
# 43/43 [==============================] - 1s 23ms/step - loss: 3.6785e-04 - val_loss: 0.0201
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 3.3227e-04
# Epoch 8: val_loss improved from 0.01891 to 0.01802, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 3.3227e-04 - val_loss: 0.0180
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 3.5475e-04
# Epoch 9: val_loss improved from 0.01802 to 0.01399, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 3.5475e-04 - val_loss: 0.0140
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 3.1346e-04
# Epoch 10: val_loss did not improve from 0.01399
# 43/43 [==============================] - 1s 24ms/step - loss: 3.1346e-04 - val_loss: 0.0159
# Epoch 11/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.7573e-04
# Epoch 11: val_loss improved from 0.01399 to 0.01364, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 2.7717e-04 - val_loss: 0.0136
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 3.3614e-04
# Epoch 12: val_loss did not improve from 0.01364
# 43/43 [==============================] - 1s 24ms/step - loss: 3.3614e-04 - val_loss: 0.0175
# Epoch 13/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.8754e-04
# Epoch 13: val_loss did not improve from 0.01364
# 43/43 [==============================] - 1s 24ms/step - loss: 2.9174e-04 - val_loss: 0.0157
# Epoch 14/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.7845e-04
# Epoch 14: val_loss did not improve from 0.01364
# 43/43 [==============================] - 1s 23ms/step - loss: 2.8269e-04 - val_loss: 0.0151
# Epoch 15/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.0389e-04
# Epoch 15: val_loss improved from 0.01364 to 0.01323, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 3.0730e-04 - val_loss: 0.0132
# Epoch 16/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.6686e-04
# Epoch 16: val_loss improved from 0.01323 to 0.01299, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 2.6998e-04 - val_loss: 0.0130
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3859e-04
# Epoch 17: val_loss did not improve from 0.01299
# 43/43 [==============================] - 1s 23ms/step - loss: 2.3859e-04 - val_loss: 0.0137
# Epoch 18/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.4864e-04
# Epoch 18: val_loss did not improve from 0.01299
# 43/43 [==============================] - 1s 24ms/step - loss: 2.5294e-04 - val_loss: 0.0204
# Epoch 19/100
# 43/43 [==============================] - ETA: 0s - loss: 4.4608e-04
# Epoch 19: val_loss did not improve from 0.01299
# 43/43 [==============================] - 1s 24ms/step - loss: 4.4608e-04 - val_loss: 0.0138
# Epoch 20/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.1605e-04
# Epoch 20: val_loss improved from 0.01299 to 0.01228, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 2.2221e-04 - val_loss: 0.0123
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.2811e-04
# Epoch 21: val_loss did not improve from 0.01228
# 43/43 [==============================] - 1s 24ms/step - loss: 2.2665e-04 - val_loss: 0.0151
# Epoch 22/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1485e-04
# Epoch 22: val_loss did not improve from 0.01228
# 43/43 [==============================] - 1s 24ms/step - loss: 2.1485e-04 - val_loss: 0.0133
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3937e-04
# Epoch 23: val_loss did not improve from 0.01228
# 43/43 [==============================] - 1s 24ms/step - loss: 2.3937e-04 - val_loss: 0.0153
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1143e-04
# Epoch 24: val_loss did not improve from 0.01228
# 43/43 [==============================] - 1s 32ms/step - loss: 2.1143e-04 - val_loss: 0.0163
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4482e-04
# Epoch 25: val_loss improved from 0.01228 to 0.01201, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 38ms/step - loss: 2.4608e-04 - val_loss: 0.0120
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 2.2849e-04
# Epoch 26: val_loss improved from 0.01201 to 0.00972, saving model to model/tmp_checkpoint.h5
# 43/43 [==============================] - 2s 37ms/step - loss: 2.2849e-04 - val_loss: 0.0097
# Epoch 27/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.3122e-04
# Epoch 27: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 25ms/step - loss: 2.3399e-04 - val_loss: 0.0130
# Epoch 28/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5509e-04
# Epoch 28: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 2.5643e-04 - val_loss: 0.0149
# Epoch 29/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0083e-04
# Epoch 29: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 2.0083e-04 - val_loss: 0.0103
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.0465e-04
# Epoch 30: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 24ms/step - loss: 2.0286e-04 - val_loss: 0.0134
# Epoch 31/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.8343e-04
# Epoch 31: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 1.8360e-04 - val_loss: 0.0115
# Epoch 32/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1468e-04
# Epoch 32: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 2.1365e-04 - val_loss: 0.0118
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1955e-04
# Epoch 33: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 2.2058e-04 - val_loss: 0.0109
# Epoch 34/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.2404e-04
# Epoch 34: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 2.2294e-04 - val_loss: 0.0131
# Epoch 35/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9963e-04
# Epoch 35: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 23ms/step - loss: 1.9924e-04 - val_loss: 0.0115
# Epoch 36/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3813e-04
# Epoch 36: val_loss did not improve from 0.00972
# 43/43 [==============================] - 1s 24ms/step - loss: 2.3813e-04 - val_loss: 0.0120
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:153689.44140239464
# [32976.98383332874, 153689.44140239464]

# %%
predict
# Out:
# [array([[824378.75]], dtype=float32), array([[703437.4]], dtype=float32)]

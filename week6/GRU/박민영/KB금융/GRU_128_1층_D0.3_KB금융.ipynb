# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0330
# Epoch 1: val_loss improved from inf to 0.00784, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 13s 206ms/step - loss: 0.0319 - val_loss: 0.0078
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 2: val_loss improved from 0.00784 to 0.00323, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 89ms/step - loss: 0.0110 - val_loss: 0.0032
# Epoch 3/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0059
# Epoch 3: val_loss did not improve from 0.00323
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 4: val_loss improved from 0.00323 to 0.00305, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 87ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 5: val_loss improved from 0.00305 to 0.00267, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0048 - val_loss: 0.0027
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 6: val_loss improved from 0.00267 to 0.00259, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 106ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 7: val_loss improved from 0.00259 to 0.00227, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 8: val_loss did not improve from 0.00227
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 9: val_loss did not improve from 0.00227
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 10: val_loss improved from 0.00227 to 0.00198, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 11: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 12: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 13: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0036 - val_loss: 0.0049
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 14: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 15: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 16: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 17: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 18: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 19: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss did not improve from 0.00198
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0028 - val_loss: 0.0064
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4273.074933914509
# [4273.074933914509]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 1: val_loss improved from inf to 0.00373, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 12s 65ms/step - loss: 0.0168 - val_loss: 0.0037
# Epoch 2/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0063
# Epoch 2: val_loss improved from 0.00373 to 0.00066, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0062 - val_loss: 6.6322e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 3: val_loss improved from 0.00066 to 0.00053, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0051 - val_loss: 5.3051e-04
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 4: val_loss did not improve from 0.00053
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0049 - val_loss: 6.2141e-04
# Epoch 5/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 5: val_loss improved from 0.00053 to 0.00046, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0039 - val_loss: 4.6092e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 6: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0039 - val_loss: 4.8932e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 7: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0039 - val_loss: 5.9263e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 8: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 9: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 10: val_loss improved from 0.00046 to 0.00042, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0029 - val_loss: 4.2430e-04
# Epoch 11/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 11: val_loss improved from 0.00042 to 0.00039, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0034 - val_loss: 3.9480e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 12: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0033 - val_loss: 4.8529e-04
# Epoch 13/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 13: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 14: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0031 - val_loss: 4.4560e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 15: val_loss improved from 0.00039 to 0.00039, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0023 - val_loss: 3.9373e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 16: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 17: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0029 - val_loss: 4.6375e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 18: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0029 - val_loss: 4.7301e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 19: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0025 - val_loss: 4.0324e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0020 - val_loss: 6.6884e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 21: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0021 - val_loss: 4.2790e-04
# Epoch 22/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 22: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0022 - val_loss: 5.4280e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 23: val_loss improved from 0.00039 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0020 - val_loss: 3.5186e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 24: val_loss did not improve from 0.00035
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0019 - val_loss: 5.5507e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 25: val_loss did not improve from 0.00035
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0022 - val_loss: 3.5416e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 26: val_loss improved from 0.00035 to 0.00034, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0020 - val_loss: 3.3986e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 27: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0019 - val_loss: 7.6280e-04
# Epoch 28/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 28: val_loss improved from 0.00034 to 0.00031, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0017 - val_loss: 3.1497e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 29: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0019 - val_loss: 5.9808e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 30: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0019 - val_loss: 3.5707e-04
# Epoch 31/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 31: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0018 - val_loss: 4.4599e-04
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 32: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0022 - val_loss: 4.1687e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 33: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0016 - val_loss: 5.1841e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0017 - val_loss: 4.2118e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 35: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0017 - val_loss: 5.8833e-04
# Epoch 36/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 36: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0014 - val_loss: 3.6226e-04
# Epoch 37/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 37: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 38/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 38: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0019 - val_loss: 0.0014
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:3463.443024050634
# [4273.074933914509, 3463.443024050634]
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 1: val_loss improved from inf to 0.00368, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 9s 35ms/step - loss: 0.0216 - val_loss: 0.0037
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 2: val_loss did not improve from 0.00368
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0040 - val_loss: 0.0080
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 3: val_loss improved from 0.00368 to 0.00115, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 4: val_loss did not improve from 0.00115
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 5: val_loss did not improve from 0.00115
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 6: val_loss did not improve from 0.00115
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 7: val_loss did not improve from 0.00115
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 8: val_loss did not improve from 0.00115
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 9: val_loss improved from 0.00115 to 0.00084, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0020 - val_loss: 8.4067e-04
# Epoch 10/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 10: val_loss did not improve from 0.00084
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00084
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 12/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 12: val_loss did not improve from 0.00084
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 13: val_loss improved from 0.00084 to 0.00061, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0020 - val_loss: 6.1379e-04
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 14: val_loss did not improve from 0.00061
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 15: val_loss did not improve from 0.00061
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.00061
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 18/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 18: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 19: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 20: val_loss did not improve from 0.00061
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0012 - val_loss: 8.3739e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 21: val_loss did not improve from 0.00061
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00061
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0012 - val_loss: 6.5970e-04
# Epoch 23/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 23: val_loss did not improve from 0.00061
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0011 - val_loss: 6.2933e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1129.984730197172
# [4273.074933914509, 3463.443024050634, 1129.984730197172]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 1: val_loss improved from inf to 0.00437, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 17s 57ms/step - loss: 0.0227 - val_loss: 0.0044
# Epoch 2/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 2: val_loss did not improve from 0.00437
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 3: val_loss improved from 0.00437 to 0.00170, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 4: val_loss did not improve from 0.00170
# 113/113 [==============================] - 8s 73ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 5: val_loss improved from 0.00170 to 0.00057, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0033 - val_loss: 5.7411e-04
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 6: val_loss did not improve from 0.00057
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0031 - val_loss: 6.3743e-04
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 7: val_loss improved from 0.00057 to 0.00051, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0029 - val_loss: 5.1184e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 8: val_loss did not improve from 0.00051
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0027 - val_loss: 5.9096e-04
# Epoch 9/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 9: val_loss did not improve from 0.00051
# 113/113 [==============================] - 3s 28ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 10/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 10: val_loss did not improve from 0.00051
# 113/113 [==============================] - 2s 21ms/step - loss: 0.0026 - val_loss: 7.8505e-04
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 11: val_loss improved from 0.00051 to 0.00049, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 21ms/step - loss: 0.0021 - val_loss: 4.8655e-04
# Epoch 12/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 12: val_loss did not improve from 0.00049
# 113/113 [==============================] - 2s 21ms/step - loss: 0.0022 - val_loss: 7.5062e-04
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 13: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0021 - val_loss: 8.5244e-04
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 14: val_loss did not improve from 0.00049
# 113/113 [==============================] - 2s 22ms/step - loss: 0.0018 - val_loss: 5.9705e-04
# Epoch 15/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 15: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 22ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 16/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 16: val_loss did not improve from 0.00049
# 113/113 [==============================] - 2s 20ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 17/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 17: val_loss did not improve from 0.00049
# 113/113 [==============================] - 4s 32ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 18: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0017 - val_loss: 9.2201e-04
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 19: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 20: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 29ms/step - loss: 0.0016 - val_loss: 9.2599e-04
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 21: val_loss did not improve from 0.00049
# 113/113 [==============================] - 3s 29ms/step - loss: 0.0016 - val_loss: 0.0015
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1619.2660732451707
# [4273.074933914509, 3463.443024050634, 1129.984730197172, 1619.2660732451707]

# %%
print(predict)
# Out:
# [array([[56822.77]], dtype=float32), array([[56452.746]], dtype=float32), array([[59729.066]], dtype=float32), array([[58536.32]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

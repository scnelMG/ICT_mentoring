# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0448
# Epoch 1: val_loss improved from inf to 0.01831, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 30s 526ms/step - loss: 0.0448 - val_loss: 0.0183
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 2: val_loss improved from 0.01831 to 0.00895, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 57s 2s/step - loss: 0.0016 - val_loss: 0.0090
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.4456e-04
# Epoch 3: val_loss improved from 0.00895 to 0.00614, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 19s 561ms/step - loss: 8.1405e-04 - val_loss: 0.0061
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.2360e-04
# Epoch 4: val_loss improved from 0.00614 to 0.00520, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 60s 2s/step - loss: 6.1807e-04 - val_loss: 0.0052
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 5.5383e-04
# Epoch 5: val_loss did not improve from 0.00520
# 34/34 [==============================] - 2s 60ms/step - loss: 5.5383e-04 - val_loss: 0.0056
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.4102e-04
# Epoch 6: val_loss improved from 0.00520 to 0.00430, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 126ms/step - loss: 5.3307e-04 - val_loss: 0.0043
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.3547e-04
# Epoch 7: val_loss improved from 0.00430 to 0.00341, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 64ms/step - loss: 5.2081e-04 - val_loss: 0.0034
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.8758e-04
# Epoch 8: val_loss did not improve from 0.00341
# 34/34 [==============================] - 4s 122ms/step - loss: 4.8269e-04 - val_loss: 0.0043
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.3846e-04
# Epoch 9: val_loss did not improve from 0.00341
# 34/34 [==============================] - 2s 68ms/step - loss: 4.3839e-04 - val_loss: 0.0049
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 4.4505e-04
# Epoch 10: val_loss did not improve from 0.00341
# 34/34 [==============================] - 2s 53ms/step - loss: 4.4505e-04 - val_loss: 0.0037
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2872e-04
# Epoch 11: val_loss improved from 0.00341 to 0.00272, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 64ms/step - loss: 4.2800e-04 - val_loss: 0.0027
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 4.4027e-04
# Epoch 12: val_loss did not improve from 0.00272
# 34/34 [==============================] - 2s 57ms/step - loss: 4.4027e-04 - val_loss: 0.0033
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.2249e-04
# Epoch 13: val_loss did not improve from 0.00272
# 34/34 [==============================] - 2s 63ms/step - loss: 4.2654e-04 - val_loss: 0.0030
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 4.2912e-04
# Epoch 14: val_loss did not improve from 0.00272
# 34/34 [==============================] - 2s 47ms/step - loss: 4.2912e-04 - val_loss: 0.0041
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3369e-04
# Epoch 15: val_loss did not improve from 0.00272
# 34/34 [==============================] - 1s 44ms/step - loss: 4.3369e-04 - val_loss: 0.0039
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0336e-04
# Epoch 16: val_loss did not improve from 0.00272
# 34/34 [==============================] - 2s 57ms/step - loss: 4.0338e-04 - val_loss: 0.0040
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.1920e-04
# Epoch 17: val_loss did not improve from 0.00272
# 34/34 [==============================] - 1s 42ms/step - loss: 4.1553e-04 - val_loss: 0.0041
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7612e-04
# Epoch 18: val_loss did not improve from 0.00272
# 34/34 [==============================] - 2s 66ms/step - loss: 3.9284e-04 - val_loss: 0.0034
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8329e-04
# Epoch 19: val_loss improved from 0.00272 to 0.00271, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 54ms/step - loss: 3.8471e-04 - val_loss: 0.0027
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2568e-04
# Epoch 20: val_loss did not improve from 0.00271
# 34/34 [==============================] - 3s 83ms/step - loss: 4.2913e-04 - val_loss: 0.0040
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8194e-04
# Epoch 21: val_loss improved from 0.00271 to 0.00269, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 75ms/step - loss: 3.7686e-04 - val_loss: 0.0027
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5727e-04
# Epoch 22: val_loss improved from 0.00269 to 0.00263, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 54ms/step - loss: 3.6228e-04 - val_loss: 0.0026
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0499e-04
# Epoch 23: val_loss did not improve from 0.00263
# 34/34 [==============================] - 2s 58ms/step - loss: 4.0499e-04 - val_loss: 0.0033
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.1254e-04
# Epoch 24: val_loss improved from 0.00263 to 0.00208, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 46ms/step - loss: 4.1202e-04 - val_loss: 0.0021
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9182e-04
# Epoch 25: val_loss did not improve from 0.00208
# 34/34 [==============================] - 2s 51ms/step - loss: 3.9428e-04 - val_loss: 0.0039
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0786e-04
# Epoch 26: val_loss did not improve from 0.00208
# 34/34 [==============================] - 2s 48ms/step - loss: 4.0786e-04 - val_loss: 0.0021
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4758e-04
# Epoch 27: val_loss improved from 0.00208 to 0.00203, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 5s 151ms/step - loss: 3.6158e-04 - val_loss: 0.0020
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 3.5250e-04
# Epoch 28: val_loss did not improve from 0.00203
# 34/34 [==============================] - 11s 336ms/step - loss: 3.5250e-04 - val_loss: 0.0025
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4346e-04
# Epoch 29: val_loss did not improve from 0.00203
# 34/34 [==============================] - 1s 31ms/step - loss: 4.3641e-04 - val_loss: 0.0020
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7350e-04
# Epoch 30: val_loss did not improve from 0.00203
# 34/34 [==============================] - 1s 30ms/step - loss: 3.7030e-04 - val_loss: 0.0032
# Epoch 31/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.4768e-04
# Epoch 31: val_loss improved from 0.00203 to 0.00158, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 3.4409e-04 - val_loss: 0.0016
# Epoch 32/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.2072e-04
# Epoch 32: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 17ms/step - loss: 4.0900e-04 - val_loss: 0.0019
# Epoch 33/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2691e-04
# Epoch 33: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 23ms/step - loss: 4.3536e-04 - val_loss: 0.0033
# Epoch 34/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7790e-04
# Epoch 34: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 20ms/step - loss: 3.8595e-04 - val_loss: 0.0019
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6841e-04
# Epoch 35: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 31ms/step - loss: 4.6841e-04 - val_loss: 0.0032
# Epoch 36/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1696e-04
# Epoch 36: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 26ms/step - loss: 4.1485e-04 - val_loss: 0.0033
# Epoch 37/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4954e-04
# Epoch 37: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 26ms/step - loss: 3.4368e-04 - val_loss: 0.0020
# Epoch 38/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6902e-04
# Epoch 38: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 20ms/step - loss: 3.7766e-04 - val_loss: 0.0021
# Epoch 39/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.4526e-04
# Epoch 39: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 37ms/step - loss: 3.4389e-04 - val_loss: 0.0022
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3801e-04
# Epoch 40: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 24ms/step - loss: 5.3265e-04 - val_loss: 0.0019
# Epoch 41/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8449e-04
# Epoch 41: val_loss did not improve from 0.00158
# 34/34 [==============================] - 1s 30ms/step - loss: 3.9822e-04 - val_loss: 0.0026
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:2506.483559022621
# [2506.483559022621]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 1: val_loss improved from inf to 0.00054, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 16s 87ms/step - loss: 0.0036 - val_loss: 5.4227e-04
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 6.3239e-04
# Epoch 2: val_loss did not improve from 0.00054
# 69/69 [==============================] - 4s 55ms/step - loss: 6.3033e-04 - val_loss: 7.9031e-04
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 6.3578e-04
# Epoch 3: val_loss did not improve from 0.00054
# 69/69 [==============================] - 2s 22ms/step - loss: 6.2655e-04 - val_loss: 6.3083e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 6.9291e-04
# Epoch 4: val_loss improved from 0.00054 to 0.00049, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 6.9291e-04 - val_loss: 4.8862e-04
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.4069e-04
# Epoch 5: val_loss improved from 0.00049 to 0.00039, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 5.3867e-04 - val_loss: 3.8996e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 5.8983e-04
# Epoch 6: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 23ms/step - loss: 5.8983e-04 - val_loss: 6.8330e-04
# Epoch 7/100
# 67/69 [============================>.] - ETA: 0s - loss: 6.9796e-04
# Epoch 7: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 24ms/step - loss: 6.9599e-04 - val_loss: 4.9393e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6925e-04
# Epoch 8: val_loss did not improve from 0.00039
# 69/69 [==============================] - 2s 33ms/step - loss: 4.6817e-04 - val_loss: 7.1342e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6198e-04
# Epoch 9: val_loss improved from 0.00039 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 4.6717e-04 - val_loss: 3.6319e-04
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.3322e-04
# Epoch 10: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 23ms/step - loss: 4.3716e-04 - val_loss: 5.1805e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0778e-04
# Epoch 11: val_loss did not improve from 0.00036
# 69/69 [==============================] - 4s 56ms/step - loss: 5.0778e-04 - val_loss: 5.4323e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2192e-04
# Epoch 12: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 27ms/step - loss: 4.2192e-04 - val_loss: 4.8018e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.0404e-04
# Epoch 13: val_loss improved from 0.00036 to 0.00034, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 5.0360e-04 - val_loss: 3.4423e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1743e-04
# Epoch 14: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 30ms/step - loss: 4.1403e-04 - val_loss: 3.9479e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.8825e-04
# Epoch 15: val_loss improved from 0.00034 to 0.00031, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 3.8645e-04 - val_loss: 3.1247e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.0236e-04
# Epoch 16: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 25ms/step - loss: 5.0090e-04 - val_loss: 9.4860e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.2088e-04
# Epoch 17: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 26ms/step - loss: 4.3000e-04 - val_loss: 5.4227e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0870e-04
# Epoch 18: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 4.0744e-04 - val_loss: 5.1659e-04
# Epoch 19/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.9612e-04
# Epoch 19: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 5.0056e-04 - val_loss: 4.1350e-04
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 5.5166e-04
# Epoch 20: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 24ms/step - loss: 5.4652e-04 - val_loss: 3.1689e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3731e-04
# Epoch 21: val_loss did not improve from 0.00031
# 69/69 [==============================] - 2s 22ms/step - loss: 4.3731e-04 - val_loss: 5.1745e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1074e-04
# Epoch 22: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 21ms/step - loss: 4.1074e-04 - val_loss: 3.6831e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0592e-04
# Epoch 23: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 20ms/step - loss: 4.0592e-04 - val_loss: 3.6169e-04
# Epoch 24/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.6553e-04
# Epoch 24: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 21ms/step - loss: 4.6711e-04 - val_loss: 3.2229e-04
# Epoch 25/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.6852e-04
# Epoch 25: val_loss did not improve from 0.00031
# 69/69 [==============================] - 1s 20ms/step - loss: 3.6800e-04 - val_loss: 4.3194e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1307.2114359317789
# [2506.483559022621, 1307.2114359317789]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 1: val_loss improved from inf to 0.00349, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 8s 32ms/step - loss: 0.0191 - val_loss: 0.0035
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 6.6780e-04
# Epoch 2: val_loss improved from 0.00349 to 0.00278, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 21ms/step - loss: 6.6614e-04 - val_loss: 0.0028
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.5379e-04
# Epoch 3: val_loss improved from 0.00278 to 0.00150, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 20ms/step - loss: 5.5233e-04 - val_loss: 0.0015
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.9074e-04
# Epoch 4: val_loss improved from 0.00150 to 0.00103, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 21ms/step - loss: 4.8634e-04 - val_loss: 0.0010
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 4.7562e-04
# Epoch 5: val_loss did not improve from 0.00103
# 104/104 [==============================] - 3s 24ms/step - loss: 4.7562e-04 - val_loss: 0.0012
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2570e-04
# Epoch 6: val_loss did not improve from 0.00103
# 104/104 [==============================] - 3s 27ms/step - loss: 4.2570e-04 - val_loss: 0.0026
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2250e-04
# Epoch 7: val_loss did not improve from 0.00103
# 104/104 [==============================] - 2s 21ms/step - loss: 4.2250e-04 - val_loss: 0.0020
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1687e-04
# Epoch 8: val_loss did not improve from 0.00103
# 104/104 [==============================] - 2s 21ms/step - loss: 4.1687e-04 - val_loss: 0.0013
# Epoch 9/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.9348e-04
# Epoch 9: val_loss did not improve from 0.00103
# 104/104 [==============================] - 3s 31ms/step - loss: 3.9469e-04 - val_loss: 0.0021
# Epoch 10/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.2260e-04
# Epoch 10: val_loss did not improve from 0.00103
# 104/104 [==============================] - 2s 23ms/step - loss: 4.1975e-04 - val_loss: 0.0012
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.9860e-04
# Epoch 11: val_loss did not improve from 0.00103
# 104/104 [==============================] - 2s 23ms/step - loss: 3.9754e-04 - val_loss: 0.0013
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9795e-04
# Epoch 12: val_loss improved from 0.00103 to 0.00099, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 25ms/step - loss: 3.9795e-04 - val_loss: 9.9445e-04
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8455e-04
# Epoch 13: val_loss improved from 0.00099 to 0.00092, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 25ms/step - loss: 3.8455e-04 - val_loss: 9.2066e-04
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7240e-04
# Epoch 14: val_loss improved from 0.00092 to 0.00068, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 25ms/step - loss: 3.7240e-04 - val_loss: 6.8140e-04
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7949e-04
# Epoch 15: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 22ms/step - loss: 3.8547e-04 - val_loss: 0.0025
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6752e-04
# Epoch 16: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 20ms/step - loss: 3.6459e-04 - val_loss: 0.0013
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0859e-04
# Epoch 17: val_loss did not improve from 0.00068
# 104/104 [==============================] - 3s 29ms/step - loss: 4.0673e-04 - val_loss: 0.0013
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6530e-04
# Epoch 18: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 21ms/step - loss: 3.7241e-04 - val_loss: 0.0013
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.1762e-04
# Epoch 19: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 22ms/step - loss: 4.1619e-04 - val_loss: 0.0018
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0349e-04
# Epoch 20: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 21ms/step - loss: 4.0740e-04 - val_loss: 7.3876e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6948e-04
# Epoch 21: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 19ms/step - loss: 3.6948e-04 - val_loss: 8.1543e-04
# Epoch 22/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.3565e-04
# Epoch 22: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 4.3223e-04 - val_loss: 0.0011
# Epoch 23/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5055e-04
# Epoch 23: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 17ms/step - loss: 3.5171e-04 - val_loss: 0.0012
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6726e-04
# Epoch 24: val_loss did not improve from 0.00068
# 104/104 [==============================] - 2s 18ms/step - loss: 3.6726e-04 - val_loss: 0.0048
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1479.8611910043662
# [2506.483559022621, 1307.2114359317789, 1479.8611910043662]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 1: val_loss improved from inf to 0.00074, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 10s 35ms/step - loss: 0.0171 - val_loss: 7.4230e-04
# Epoch 2/100
# 111/113 [============================>.] - ETA: 0s - loss: 8.3713e-04
# Epoch 2: val_loss improved from 0.00074 to 0.00060, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 24ms/step - loss: 8.3363e-04 - val_loss: 6.0358e-04
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.9049e-04
# Epoch 3: val_loss did not improve from 0.00060
# 113/113 [==============================] - 3s 26ms/step - loss: 6.9447e-04 - val_loss: 6.9613e-04
# Epoch 4/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.6565e-04
# Epoch 4: val_loss did not improve from 0.00060
# 113/113 [==============================] - 3s 25ms/step - loss: 5.6917e-04 - val_loss: 7.7268e-04
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 5.4265e-04
# Epoch 5: val_loss improved from 0.00060 to 0.00056, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 25ms/step - loss: 5.4265e-04 - val_loss: 5.6459e-04
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9204e-04
# Epoch 6: val_loss did not improve from 0.00056
# 113/113 [==============================] - 3s 22ms/step - loss: 4.9204e-04 - val_loss: 7.7771e-04
# Epoch 7/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.0535e-04
# Epoch 7: val_loss improved from 0.00056 to 0.00047, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 24ms/step - loss: 5.0384e-04 - val_loss: 4.7053e-04
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7927e-04
# Epoch 8: val_loss did not improve from 0.00047
# 113/113 [==============================] - 3s 25ms/step - loss: 4.8720e-04 - val_loss: 7.3232e-04
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1361e-04
# Epoch 9: val_loss did not improve from 0.00047
# 113/113 [==============================] - 3s 24ms/step - loss: 5.1361e-04 - val_loss: 5.2707e-04
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2243e-04
# Epoch 10: val_loss did not improve from 0.00047
# 113/113 [==============================] - 3s 26ms/step - loss: 5.2243e-04 - val_loss: 6.6744e-04
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.1361e-04
# Epoch 11: val_loss did not improve from 0.00047
# 113/113 [==============================] - 5s 41ms/step - loss: 5.1226e-04 - val_loss: 0.0018
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2319e-04
# Epoch 12: val_loss did not improve from 0.00047
# 113/113 [==============================] - 7s 62ms/step - loss: 5.2319e-04 - val_loss: 8.1942e-04
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.9547e-04
# Epoch 13: val_loss did not improve from 0.00047
# 113/113 [==============================] - 6s 54ms/step - loss: 5.9466e-04 - val_loss: 8.7180e-04
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9073e-04
# Epoch 14: val_loss did not improve from 0.00047
# 113/113 [==============================] - 6s 50ms/step - loss: 4.9073e-04 - val_loss: 7.1295e-04
# Epoch 15/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.8915e-04
# Epoch 15: val_loss did not improve from 0.00047
# 113/113 [==============================] - 6s 50ms/step - loss: 4.8948e-04 - val_loss: 8.8476e-04
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5588e-04
# Epoch 16: val_loss did not improve from 0.00047
# 113/113 [==============================] - 4s 36ms/step - loss: 4.5588e-04 - val_loss: 0.0017
# Epoch 17/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2169e-04
# Epoch 17: val_loss did not improve from 0.00047
# 113/113 [==============================] - 3s 31ms/step - loss: 5.2178e-04 - val_loss: 4.7323e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1295.5317547670356
# [2506.483559022621, 1307.2114359317789, 1479.8611910043662, 1295.5317547670356]

# %%
print(predict)
# Out:
# [array([[58492.18]], dtype=float32), array([[60348.168]], dtype=float32), array([[58414.695]], dtype=float32), array([[60380.08]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

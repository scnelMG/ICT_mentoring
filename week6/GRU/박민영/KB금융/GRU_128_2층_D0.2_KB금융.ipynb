# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, return_sequences=False, stateful=False))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
    

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0605
# Epoch 1: val_loss improved from inf to 0.02049, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 9s 83ms/step - loss: 0.0590 - val_loss: 0.0205
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 2: val_loss improved from 0.02049 to 0.00751, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0039 - val_loss: 0.0075
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 3: val_loss improved from 0.00751 to 0.00448, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 4: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 5: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 6: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0021 - val_loss: 0.0070
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 7: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 8: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 9: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00448
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 11: val_loss improved from 0.00448 to 0.00335, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 12: val_loss did not improve from 0.00335
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 13: val_loss did not improve from 0.00335
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 14: val_loss improved from 0.00335 to 0.00317, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 15: val_loss improved from 0.00317 to 0.00187, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 16/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.00187
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 17: val_loss improved from 0.00187 to 0.00139, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 18: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 19: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 20: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 21: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 22: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 23: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 24: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 25: val_loss did not improve from 0.00139
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 26: val_loss did not improve from 0.00139
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 27: val_loss did not improve from 0.00139
# 34/34 [==============================] - 3s 89ms/step - loss: 0.0011 - val_loss: 0.0058
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4454.930388992094
# [4454.930388992094]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 1: val_loss improved from inf to 0.00079, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 11s 60ms/step - loss: 0.0109 - val_loss: 7.8856e-04
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 2: val_loss improved from 0.00079 to 0.00075, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0023 - val_loss: 7.5048e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 3: val_loss did not improve from 0.00075
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0020 - val_loss: 9.7609e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 4: val_loss improved from 0.00075 to 0.00039, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 40ms/step - loss: 0.0017 - val_loss: 3.8559e-04
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 5: val_loss did not improve from 0.00039
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0016 - val_loss: 5.3934e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 6: val_loss did not improve from 0.00039
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0014 - val_loss: 7.2377e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 7: val_loss did not improve from 0.00039
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0012 - val_loss: 4.3679e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 8: val_loss improved from 0.00039 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0014 - val_loss: 3.8453e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 10/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 10: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 48ms/step - loss: 0.0013 - val_loss: 6.8363e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 11: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 49ms/step - loss: 0.0011 - val_loss: 8.9051e-04
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 12: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 48ms/step - loss: 0.0018 - val_loss: 9.9206e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 49ms/step - loss: 0.0012 - val_loss: 4.8846e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 14: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 46ms/step - loss: 0.0011 - val_loss: 5.8674e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 9.9518e-04
# Epoch 15: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 45ms/step - loss: 9.9518e-04 - val_loss: 4.1251e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0011 - val_loss: 4.2497e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0015 - val_loss: 4.7228e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 18: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0014 - val_loss: 4.7141e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1323.1243120331094
# [4454.930388992094, 1323.1243120331094]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 1: val_loss improved from inf to 0.00189, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 12s 47ms/step - loss: 0.0136 - val_loss: 0.0019
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 2: val_loss did not improve from 0.00189
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 3: val_loss improved from 0.00189 to 0.00090, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0016 - val_loss: 8.9572e-04
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 4: val_loss did not improve from 0.00090
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0015 - val_loss: 9.7268e-04
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 5: val_loss improved from 0.00090 to 0.00066, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0013 - val_loss: 6.5562e-04
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss did not improve from 0.00066
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0012 - val_loss: 9.1248e-04
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 9.8425e-04
# Epoch 7: val_loss did not improve from 0.00066
# 104/104 [==============================] - 5s 44ms/step - loss: 9.8425e-04 - val_loss: 0.0011
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.9522e-04
# Epoch 8: val_loss did not improve from 0.00066
# 104/104 [==============================] - 4s 35ms/step - loss: 9.9362e-04 - val_loss: 7.6999e-04
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.3160e-04
# Epoch 9: val_loss improved from 0.00066 to 0.00058, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 34ms/step - loss: 9.3362e-04 - val_loss: 5.8394e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 8.7210e-04
# Epoch 10: val_loss did not improve from 0.00058
# 104/104 [==============================] - 3s 32ms/step - loss: 8.7210e-04 - val_loss: 6.1887e-04
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.8464e-04
# Epoch 11: val_loss did not improve from 0.00058
# 104/104 [==============================] - 3s 33ms/step - loss: 9.8435e-04 - val_loss: 7.5919e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 8.9872e-04
# Epoch 12: val_loss improved from 0.00058 to 0.00057, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 36ms/step - loss: 8.9434e-04 - val_loss: 5.7401e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 13: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.9381e-04
# Epoch 14: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 35ms/step - loss: 9.8752e-04 - val_loss: 6.5014e-04
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 9.8915e-04
# Epoch 16: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 40ms/step - loss: 9.8915e-04 - val_loss: 7.3767e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 9.0013e-04
# Epoch 17: val_loss did not improve from 0.00057
# 104/104 [==============================] - 4s 41ms/step - loss: 9.0013e-04 - val_loss: 8.6069e-04
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.4499e-04
# Epoch 18: val_loss improved from 0.00057 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 42ms/step - loss: 7.4564e-04 - val_loss: 5.2885e-04
# Epoch 19/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.1089e-04
# Epoch 19: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 45ms/step - loss: 7.1320e-04 - val_loss: 5.3210e-04
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 8.1118e-04
# Epoch 20: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 46ms/step - loss: 8.1118e-04 - val_loss: 6.9723e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 8.1514e-04
# Epoch 21: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 46ms/step - loss: 8.1514e-04 - val_loss: 6.6483e-04
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 7.2643e-04
# Epoch 22: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 42ms/step - loss: 7.2643e-04 - val_loss: 0.0013
# Epoch 23/100
# 104/104 [==============================] - ETA: 0s - loss: 7.5684e-04
# Epoch 23: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 41ms/step - loss: 7.5684e-04 - val_loss: 0.0014
# Epoch 24/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.5494e-04
# Epoch 24: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 46ms/step - loss: 7.5583e-04 - val_loss: 5.6428e-04
# Epoch 25/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.5787e-04
# Epoch 25: val_loss improved from 0.00053 to 0.00052, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 34ms/step - loss: 7.6174e-04 - val_loss: 5.1972e-04
# Epoch 26/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.0725e-04
# Epoch 26: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 33ms/step - loss: 7.1167e-04 - val_loss: 5.4519e-04
# Epoch 27/100
# 104/104 [==============================] - ETA: 0s - loss: 6.3449e-04
# Epoch 27: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 31ms/step - loss: 6.3449e-04 - val_loss: 0.0011
# Epoch 28/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.3904e-04
# Epoch 28: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 32ms/step - loss: 7.4472e-04 - val_loss: 0.0039
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 6.9192e-04
# Epoch 29: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 30ms/step - loss: 6.9192e-04 - val_loss: 0.0010
# Epoch 30/100
# 104/104 [==============================] - ETA: 0s - loss: 7.2415e-04
# Epoch 30: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 29ms/step - loss: 7.2415e-04 - val_loss: 9.5205e-04
# Epoch 31/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.5193e-04
# Epoch 31: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 30ms/step - loss: 6.6064e-04 - val_loss: 7.1660e-04
# Epoch 32/100
# 104/104 [==============================] - ETA: 0s - loss: 6.2788e-04
# Epoch 32: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 31ms/step - loss: 6.2788e-04 - val_loss: 0.0010
# Epoch 33/100
# 104/104 [==============================] - ETA: 0s - loss: 5.9717e-04
# Epoch 33: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 32ms/step - loss: 5.9717e-04 - val_loss: 6.7536e-04
# Epoch 34/100
# 104/104 [==============================] - ETA: 0s - loss: 7.1047e-04
# Epoch 34: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 31ms/step - loss: 7.1047e-04 - val_loss: 5.3300e-04
# Epoch 35/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.4317e-04
# Epoch 35: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 33ms/step - loss: 5.4327e-04 - val_loss: 0.0012
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1308.8040835733104
# [4454.930388992094, 1323.1243120331094, 1308.8040835733104]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 1: val_loss improved from inf to 0.00293, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 16s 61ms/step - loss: 0.0067 - val_loss: 0.0029
# Epoch 2/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss improved from 0.00293 to 0.00076, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0019 - val_loss: 7.5650e-04
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 3: val_loss did not improve from 0.00076
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 4: val_loss did not improve from 0.00076
# 113/113 [==============================] - 7s 60ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 5: val_loss did not improve from 0.00076
# 113/113 [==============================] - 6s 57ms/step - loss: 0.0013 - val_loss: 9.7411e-04
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss did not improve from 0.00076
# 113/113 [==============================] - 6s 50ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 7: val_loss did not improve from 0.00076
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00076
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 9: val_loss improved from 0.00076 to 0.00056, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0011 - val_loss: 5.6140e-04
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss did not improve from 0.00056
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 11: val_loss did not improve from 0.00056
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0013 - val_loss: 8.3019e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 12: val_loss did not improve from 0.00056
# 113/113 [==============================] - 6s 55ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.1072e-04
# Epoch 13: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 41ms/step - loss: 9.0570e-04 - val_loss: 0.0019
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 9.1088e-04
# Epoch 14: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 41ms/step - loss: 9.1088e-04 - val_loss: 0.0033
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 9.6833e-04
# Epoch 15: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 40ms/step - loss: 9.6833e-04 - val_loss: 0.0017
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 9.2887e-04
# Epoch 16: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 44ms/step - loss: 9.2887e-04 - val_loss: 0.0027
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 8.4171e-04
# Epoch 17: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 44ms/step - loss: 8.4171e-04 - val_loss: 0.0018
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.1695e-04
# Epoch 18: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 44ms/step - loss: 9.1815e-04 - val_loss: 0.0033
# Epoch 19/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.6380e-04
# Epoch 19: val_loss did not improve from 0.00056
# 113/113 [==============================] - 5s 48ms/step - loss: 9.7373e-04 - val_loss: 6.5820e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1204.676635895118
# [4454.930388992094, 1323.1243120331094, 1308.8040835733104, 1204.676635895118]

# %%
print(predict)
# Out:
# [array([[54940.465]], dtype=float32), array([[60510.98]], dtype=float32), array([[59032.914]], dtype=float32), array([[60942.074]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

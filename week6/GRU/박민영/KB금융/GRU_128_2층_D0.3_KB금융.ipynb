# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, return_sequences=False, stateful=False))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0219
# Epoch 1: val_loss improved from inf to 0.01001, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 21s 154ms/step - loss: 0.0219 - val_loss: 0.0100
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 2: val_loss improved from 0.01001 to 0.00252, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 81ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 3: val_loss improved from 0.00252 to 0.00236, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 95ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 4: val_loss improved from 0.00236 to 0.00232, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 106ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 5: val_loss improved from 0.00232 to 0.00188, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 6: val_loss did not improve from 0.00188
# 34/34 [==============================] - 5s 147ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 7: val_loss did not improve from 0.00188
# 34/34 [==============================] - 4s 129ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 8: val_loss did not improve from 0.00188
# 34/34 [==============================] - 4s 108ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 9: val_loss improved from 0.00188 to 0.00160, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 102ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 10: val_loss did not improve from 0.00160
# 34/34 [==============================] - 3s 90ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 11: val_loss did not improve from 0.00160
# 34/34 [==============================] - 3s 87ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 12: val_loss improved from 0.00160 to 0.00132, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 80ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 13: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 14: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 15: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 16: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00132
# 34/34 [==============================] - 4s 112ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 18: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 19: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 20: val_loss did not improve from 0.00132
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 21: val_loss did not improve from 0.00132
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 22: val_loss did not improve from 0.00132
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0016 - val_loss: 0.0034
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:3664.920984405527
# [3664.920984405527]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 1: val_loss improved from inf to 0.00067, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 40s 136ms/step - loss: 0.0181 - val_loss: 6.7405e-04
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 2: val_loss did not improve from 0.00067
# 69/69 [==============================] - 4s 56ms/step - loss: 0.0035 - val_loss: 7.9809e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 3: val_loss did not improve from 0.00067
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 4: val_loss improved from 0.00067 to 0.00065, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0023 - val_loss: 6.5305e-04
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 5: val_loss improved from 0.00065 to 0.00048, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0025 - val_loss: 4.8067e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss did not improve from 0.00048
# 69/69 [==============================] - 3s 49ms/step - loss: 0.0020 - val_loss: 7.5155e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 7: val_loss did not improve from 0.00048
# 69/69 [==============================] - 3s 43ms/step - loss: 0.0022 - val_loss: 8.3750e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 8: val_loss improved from 0.00048 to 0.00042, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0020 - val_loss: 4.2247e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 9: val_loss did not improve from 0.00042
# 69/69 [==============================] - 3s 51ms/step - loss: 0.0018 - val_loss: 8.6137e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 10: val_loss did not improve from 0.00042
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0026 - val_loss: 4.3566e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 11: val_loss did not improve from 0.00042
# 69/69 [==============================] - 3s 51ms/step - loss: 0.0018 - val_loss: 6.5787e-04
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 12: val_loss did not improve from 0.00042
# 69/69 [==============================] - 3s 48ms/step - loss: 0.0017 - val_loss: 8.8985e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 13: val_loss did not improve from 0.00042
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0017 - val_loss: 4.6942e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 14: val_loss did not improve from 0.00042
# 69/69 [==============================] - 5s 75ms/step - loss: 0.0017 - val_loss: 6.3784e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 15: val_loss improved from 0.00042 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0015 - val_loss: 3.8383e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 16: val_loss did not improve from 0.00038
# 69/69 [==============================] - 5s 71ms/step - loss: 0.0015 - val_loss: 4.0156e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00038
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0015 - val_loss: 6.8159e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 18: val_loss did not improve from 0.00038
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0015 - val_loss: 5.3139e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 19: val_loss did not improve from 0.00038
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0017 - val_loss: 4.7136e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 20: val_loss improved from 0.00038 to 0.00037, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0017 - val_loss: 3.7034e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 21: val_loss did not improve from 0.00037
# 69/69 [==============================] - 4s 53ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 22: val_loss improved from 0.00037 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 45ms/step - loss: 0.0014 - val_loss: 3.5450e-04
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 23: val_loss improved from 0.00035 to 0.00033, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0017 - val_loss: 3.3411e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 24: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 50ms/step - loss: 0.0012 - val_loss: 4.1802e-04
# Epoch 25/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 25: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 40ms/step - loss: 0.0013 - val_loss: 4.2614e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 26: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 45ms/step - loss: 0.0012 - val_loss: 3.4815e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 27: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0013 - val_loss: 6.2175e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 28: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0012 - val_loss: 6.6447e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 29: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0013 - val_loss: 4.7843e-04
# Epoch 30/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 30: val_loss did not improve from 0.00033
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0015 - val_loss: 4.4943e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 31: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 41ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 32: val_loss did not improve from 0.00033
# 69/69 [==============================] - 3s 46ms/step - loss: 0.0013 - val_loss: 4.6340e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 33: val_loss did not improve from 0.00033
# 69/69 [==============================] - 5s 65ms/step - loss: 0.0011 - val_loss: 7.6412e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1943.3610398615508
# [3664.920984405527, 1943.3610398615508]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 1: val_loss improved from inf to 0.00250, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 22s 84ms/step - loss: 0.0119 - val_loss: 0.0025
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 2: val_loss improved from 0.00250 to 0.00086, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0020 - val_loss: 8.5524e-04
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 3: val_loss improved from 0.00086 to 0.00080, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 51ms/step - loss: 0.0018 - val_loss: 8.0095e-04
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 4: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 45ms/step - loss: 0.0014 - val_loss: 8.2760e-04
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 50ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 7: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 45ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 50ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 9: val_loss did not improve from 0.00080
# 104/104 [==============================] - 5s 46ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss did not improve from 0.00080
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 11: val_loss did not improve from 0.00080
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 12: val_loss did not improve from 0.00080
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00080
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0012 - val_loss: 0.0011
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1496.0089006630328
# [3664.920984405527, 1943.3610398615508, 1496.0089006630328]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 1: val_loss improved from inf to 0.00442, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 19s 76ms/step - loss: 0.0099 - val_loss: 0.0044
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 2: val_loss improved from 0.00442 to 0.00308, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 3: val_loss improved from 0.00308 to 0.00290, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 4: val_loss improved from 0.00290 to 0.00188, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 5: val_loss did not improve from 0.00188
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 6: val_loss did not improve from 0.00188
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 7/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 7: val_loss did not improve from 0.00188
# 113/113 [==============================] - 6s 51ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 8: val_loss improved from 0.00188 to 0.00165, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00165
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 10: val_loss improved from 0.00165 to 0.00095, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 56ms/step - loss: 0.0015 - val_loss: 9.5067e-04
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 11: val_loss did not improve from 0.00095
# 113/113 [==============================] - 7s 66ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 12/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00095
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00095
# 113/113 [==============================] - 7s 58ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 14: val_loss did not improve from 0.00095
# 113/113 [==============================] - 6s 56ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 15/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 15: val_loss did not improve from 0.00095
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 16/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss improved from 0.00095 to 0.00080, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 51ms/step - loss: 0.0011 - val_loss: 8.0500e-04
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 17: val_loss did not improve from 0.00080
# 113/113 [==============================] - 8s 67ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 18: val_loss improved from 0.00080 to 0.00063, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 7s 58ms/step - loss: 0.0010 - val_loss: 6.3012e-04
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 19: val_loss did not improve from 0.00063
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 20/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 20: val_loss did not improve from 0.00063
# 113/113 [==============================] - 6s 54ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 21: val_loss did not improve from 0.00063
# 113/113 [==============================] - 6s 56ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 8.9208e-04
# Epoch 22: val_loss did not improve from 0.00063
# 113/113 [==============================] - 7s 59ms/step - loss: 8.9208e-04 - val_loss: 0.0013
# Epoch 23/100
# 113/113 [==============================] - ETA: 0s - loss: 9.8032e-04
# Epoch 23: val_loss improved from 0.00063 to 0.00051, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 7s 61ms/step - loss: 9.8032e-04 - val_loss: 5.1137e-04
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 24: val_loss did not improve from 0.00051
# 113/113 [==============================] - 6s 52ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 25/100
# 113/113 [==============================] - ETA: 0s - loss: 9.4145e-04
# Epoch 25: val_loss did not improve from 0.00051
# 113/113 [==============================] - 5s 45ms/step - loss: 9.4145e-04 - val_loss: 9.4263e-04
# Epoch 26/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 26: val_loss did not improve from 0.00051
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0010 - val_loss: 0.0030
# Epoch 27/100
# 112/113 [============================>.] - ETA: 0s - loss: 8.9511e-04
# Epoch 27: val_loss did not improve from 0.00051
# 113/113 [==============================] - 5s 42ms/step - loss: 8.9274e-04 - val_loss: 0.0054
# Epoch 28/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.0485e-04
# Epoch 28: val_loss did not improve from 0.00051
# 113/113 [==============================] - 5s 46ms/step - loss: 9.0638e-04 - val_loss: 0.0040
# Epoch 29/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.1594e-04
# Epoch 29: val_loss did not improve from 0.00051
# 113/113 [==============================] - 5s 48ms/step - loss: 9.1382e-04 - val_loss: 0.0022
# Epoch 30/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.0358e-04
# Epoch 30: val_loss did not improve from 0.00051
# 113/113 [==============================] - 6s 56ms/step - loss: 9.0556e-04 - val_loss: 6.2331e-04
# Epoch 31/100
# 113/113 [==============================] - ETA: 0s - loss: 8.6703e-04
# Epoch 31: val_loss did not improve from 0.00051
# 113/113 [==============================] - 7s 61ms/step - loss: 8.6703e-04 - val_loss: 5.3140e-04
# Epoch 32/100
# 113/113 [==============================] - ETA: 0s - loss: 9.4191e-04
# Epoch 32: val_loss did not improve from 0.00051
# 113/113 [==============================] - 9s 78ms/step - loss: 9.4191e-04 - val_loss: 0.0016
# Epoch 33/100
# 113/113 [==============================] - ETA: 0s - loss: 8.8961e-04
# Epoch 33: val_loss did not improve from 0.00051
# 113/113 [==============================] - 10s 87ms/step - loss: 8.8961e-04 - val_loss: 0.0023
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1852.8336380945577
# [3664.920984405527, 1943.3610398615508, 1496.0089006630328, 1852.8336380945577]

# %%
print(predict)
# Out:
# [array([[57911.85]], dtype=float32), array([[59872.363]], dtype=float32), array([[59294.473]], dtype=float32), array([[59310.71]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

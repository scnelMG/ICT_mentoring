# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
    

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0375
# Epoch 1: val_loss improved from inf to 0.00341, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 34s 345ms/step - loss: 0.0365 - val_loss: 0.0034
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 2: val_loss improved from 0.00341 to 0.00324, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 78ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.7212e-04
# Epoch 3: val_loss did not improve from 0.00324
# 34/34 [==============================] - 2s 69ms/step - loss: 9.6973e-04 - val_loss: 0.0067
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 7.0162e-04
# Epoch 4: val_loss did not improve from 0.00324
# 34/34 [==============================] - 2s 71ms/step - loss: 7.0162e-04 - val_loss: 0.0045
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 6.1927e-04
# Epoch 5: val_loss did not improve from 0.00324
# 34/34 [==============================] - 2s 70ms/step - loss: 6.1927e-04 - val_loss: 0.0048
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 5.2399e-04
# Epoch 6: val_loss did not improve from 0.00324
# 34/34 [==============================] - 2s 65ms/step - loss: 5.2399e-04 - val_loss: 0.0040
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 6.2134e-04
# Epoch 7: val_loss did not improve from 0.00324
# 34/34 [==============================] - 2s 58ms/step - loss: 6.2134e-04 - val_loss: 0.0047
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 5.3809e-04
# Epoch 8: val_loss improved from 0.00324 to 0.00237, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 45ms/step - loss: 5.3809e-04 - val_loss: 0.0024
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3090e-04
# Epoch 9: val_loss did not improve from 0.00237
# 34/34 [==============================] - 1s 44ms/step - loss: 5.2028e-04 - val_loss: 0.0029
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6883e-04
# Epoch 10: val_loss did not improve from 0.00237
# 34/34 [==============================] - 1s 41ms/step - loss: 4.6883e-04 - val_loss: 0.0032
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3700e-04
# Epoch 11: val_loss improved from 0.00237 to 0.00227, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 45ms/step - loss: 4.5311e-04 - val_loss: 0.0023
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 5.6270e-04
# Epoch 12: val_loss did not improve from 0.00227
# 34/34 [==============================] - 1s 38ms/step - loss: 5.6270e-04 - val_loss: 0.0029
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.2515e-04
# Epoch 13: val_loss did not improve from 0.00227
# 34/34 [==============================] - 1s 42ms/step - loss: 6.1711e-04 - val_loss: 0.0027
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2271e-04
# Epoch 14: val_loss improved from 0.00227 to 0.00165, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 42ms/step - loss: 4.2388e-04 - val_loss: 0.0017
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1451e-04
# Epoch 15: val_loss did not improve from 0.00165
# 34/34 [==============================] - 1s 43ms/step - loss: 4.1202e-04 - val_loss: 0.0018
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1188e-04
# Epoch 16: val_loss did not improve from 0.00165
# 34/34 [==============================] - 2s 53ms/step - loss: 4.1428e-04 - val_loss: 0.0021
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 4.2463e-04
# Epoch 17: val_loss improved from 0.00165 to 0.00150, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 64ms/step - loss: 4.2463e-04 - val_loss: 0.0015
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0505e-04
# Epoch 18: val_loss did not improve from 0.00150
# 34/34 [==============================] - 2s 48ms/step - loss: 4.0823e-04 - val_loss: 0.0016
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0063e-04
# Epoch 19: val_loss did not improve from 0.00150
# 34/34 [==============================] - 2s 61ms/step - loss: 4.0063e-04 - val_loss: 0.0020
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0269e-04
# Epoch 20: val_loss improved from 0.00150 to 0.00135, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 83ms/step - loss: 4.1010e-04 - val_loss: 0.0013
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3679e-04
# Epoch 21: val_loss did not improve from 0.00135
# 34/34 [==============================] - 3s 96ms/step - loss: 4.3656e-04 - val_loss: 0.0017
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.9101e-04
# Epoch 22: val_loss did not improve from 0.00135
# 34/34 [==============================] - 3s 90ms/step - loss: 4.8345e-04 - val_loss: 0.0017
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1818e-04
# Epoch 23: val_loss did not improve from 0.00135
# 34/34 [==============================] - 2s 54ms/step - loss: 4.3158e-04 - val_loss: 0.0022
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 3.8868e-04
# Epoch 24: val_loss did not improve from 0.00135
# 34/34 [==============================] - 3s 79ms/step - loss: 3.8868e-04 - val_loss: 0.0024
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5942e-04
# Epoch 25: val_loss did not improve from 0.00135
# 34/34 [==============================] - 2s 62ms/step - loss: 3.5618e-04 - val_loss: 0.0023
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2071e-04
# Epoch 26: val_loss improved from 0.00135 to 0.00091, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 71ms/step - loss: 4.1744e-04 - val_loss: 9.0571e-04
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0672e-04
# Epoch 27: val_loss did not improve from 0.00091
# 34/34 [==============================] - 2s 51ms/step - loss: 4.0672e-04 - val_loss: 0.0012
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 4.2844e-04
# Epoch 28: val_loss did not improve from 0.00091
# 34/34 [==============================] - 2s 60ms/step - loss: 4.2844e-04 - val_loss: 0.0015
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3925e-04
# Epoch 29: val_loss improved from 0.00091 to 0.00079, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 60ms/step - loss: 5.2994e-04 - val_loss: 7.9138e-04
# Epoch 30/100
# 34/34 [==============================] - ETA: 0s - loss: 5.2104e-04
# Epoch 30: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 53ms/step - loss: 5.2104e-04 - val_loss: 0.0022
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 5.0290e-04
# Epoch 31: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 52ms/step - loss: 5.0290e-04 - val_loss: 0.0014
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.4587e-04
# Epoch 32: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 69ms/step - loss: 5.5884e-04 - val_loss: 9.8331e-04
# Epoch 33/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.2490e-04
# Epoch 33: val_loss did not improve from 0.00079
# 34/34 [==============================] - 3s 96ms/step - loss: 5.2803e-04 - val_loss: 0.0019
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1845e-04
# Epoch 34: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 70ms/step - loss: 4.1845e-04 - val_loss: 0.0013
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 5.0667e-04
# Epoch 35: val_loss did not improve from 0.00079
# 34/34 [==============================] - 3s 88ms/step - loss: 5.0667e-04 - val_loss: 0.0025
# Epoch 36/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6273e-04
# Epoch 36: val_loss did not improve from 0.00079
# 34/34 [==============================] - 3s 76ms/step - loss: 3.6388e-04 - val_loss: 0.0022
# Epoch 37/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0243e-04
# Epoch 37: val_loss did not improve from 0.00079
# 34/34 [==============================] - 3s 76ms/step - loss: 4.0243e-04 - val_loss: 0.0017
# Epoch 38/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3057e-04
# Epoch 38: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 68ms/step - loss: 3.3607e-04 - val_loss: 0.0014
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 3.9293e-04
# Epoch 39: val_loss did not improve from 0.00079
# 34/34 [==============================] - 2s 60ms/step - loss: 3.9293e-04 - val_loss: 0.0014
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:1630.3001825631893
# [1630.3001825631893]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 1: val_loss improved from inf to 0.00059, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 19s 78ms/step - loss: 0.0180 - val_loss: 5.9382e-04
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 5.9434e-04
# Epoch 2: val_loss improved from 0.00059 to 0.00040, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 42ms/step - loss: 5.9434e-04 - val_loss: 4.0227e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 4.9548e-04
# Epoch 3: val_loss did not improve from 0.00040
# 69/69 [==============================] - 3s 40ms/step - loss: 4.9548e-04 - val_loss: 8.8454e-04
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6733e-04
# Epoch 4: val_loss improved from 0.00040 to 0.00034, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 36ms/step - loss: 4.6603e-04 - val_loss: 3.3863e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3570e-04
# Epoch 5: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 42ms/step - loss: 4.3570e-04 - val_loss: 5.7352e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 4.8394e-04
# Epoch 6: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 37ms/step - loss: 4.8394e-04 - val_loss: 4.3375e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 4.8777e-04
# Epoch 7: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 40ms/step - loss: 4.8777e-04 - val_loss: 7.7151e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1151e-04
# Epoch 8: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 34ms/step - loss: 4.1480e-04 - val_loss: 3.7728e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6163e-04
# Epoch 9: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 38ms/step - loss: 4.6528e-04 - val_loss: 3.4238e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7264e-04
# Epoch 10: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 39ms/step - loss: 3.7264e-04 - val_loss: 3.5836e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1033e-04
# Epoch 11: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 39ms/step - loss: 4.1033e-04 - val_loss: 4.8518e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6664e-04
# Epoch 12: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 41ms/step - loss: 3.6664e-04 - val_loss: 4.4229e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8020e-04
# Epoch 13: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 41ms/step - loss: 3.8020e-04 - val_loss: 7.6180e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3080e-04
# Epoch 14: val_loss improved from 0.00034 to 0.00028, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 40ms/step - loss: 4.2898e-04 - val_loss: 2.8309e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 4.7202e-04
# Epoch 15: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 42ms/step - loss: 4.7202e-04 - val_loss: 3.0430e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5249e-04
# Epoch 16: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 46ms/step - loss: 4.5249e-04 - val_loss: 0.0011
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9889e-04
# Epoch 17: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 46ms/step - loss: 3.9889e-04 - val_loss: 3.0691e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2480e-04
# Epoch 18: val_loss improved from 0.00028 to 0.00028, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 45ms/step - loss: 4.2480e-04 - val_loss: 2.8106e-04
# Epoch 19/100
# 69/69 [==============================] - ETA: 0s - loss: 4.6114e-04
# Epoch 19: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 38ms/step - loss: 4.6114e-04 - val_loss: 6.9632e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1504e-04
# Epoch 20: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 39ms/step - loss: 4.1504e-04 - val_loss: 3.1345e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.8234e-04
# Epoch 21: val_loss did not improve from 0.00028
# 69/69 [==============================] - 3s 39ms/step - loss: 4.8916e-04 - val_loss: 4.1469e-04
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1285e-04
# Epoch 22: val_loss improved from 0.00028 to 0.00027, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 38ms/step - loss: 4.0956e-04 - val_loss: 2.6540e-04
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.8362e-04
# Epoch 23: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 32ms/step - loss: 3.8445e-04 - val_loss: 4.2614e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1681e-04
# Epoch 24: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 29ms/step - loss: 4.1681e-04 - val_loss: 0.0019
# Epoch 25/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.8257e-04
# Epoch 25: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 30ms/step - loss: 5.8148e-04 - val_loss: 3.0178e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4115e-04
# Epoch 26: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 27ms/step - loss: 4.4115e-04 - val_loss: 4.0823e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.9485e-04
# Epoch 27: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 28ms/step - loss: 3.9626e-04 - val_loss: 2.8347e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8332e-04
# Epoch 28: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 33ms/step - loss: 3.8332e-04 - val_loss: 3.4085e-04
# Epoch 29/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.5449e-04
# Epoch 29: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 31ms/step - loss: 3.5154e-04 - val_loss: 3.8565e-04
# Epoch 30/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9949e-04
# Epoch 30: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 35ms/step - loss: 3.9508e-04 - val_loss: 4.5100e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2987e-04
# Epoch 31: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 34ms/step - loss: 4.2987e-04 - val_loss: 3.1015e-04
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0377e-04
# Epoch 32: val_loss improved from 0.00027 to 0.00026, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 35ms/step - loss: 4.0963e-04 - val_loss: 2.5874e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 4.6073e-04
# Epoch 33: val_loss did not improve from 0.00026
# 69/69 [==============================] - 2s 35ms/step - loss: 4.6073e-04 - val_loss: 5.6469e-04
# Epoch 34/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.2385e-04
# Epoch 34: val_loss did not improve from 0.00026
# 69/69 [==============================] - 2s 34ms/step - loss: 4.2244e-04 - val_loss: 2.7497e-04
# Epoch 35/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4887e-04
# Epoch 35: val_loss did not improve from 0.00026
# 69/69 [==============================] - 2s 35ms/step - loss: 4.4887e-04 - val_loss: 3.2849e-04
# Epoch 36/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5752e-04
# Epoch 36: val_loss did not improve from 0.00026
# 69/69 [==============================] - 2s 36ms/step - loss: 4.5752e-04 - val_loss: 3.1856e-04
# Epoch 37/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2330e-04
# Epoch 37: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 37ms/step - loss: 4.2330e-04 - val_loss: 5.0983e-04
# Epoch 38/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0128e-04
# Epoch 38: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 39ms/step - loss: 5.0128e-04 - val_loss: 2.9481e-04
# Epoch 39/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2268e-04
# Epoch 39: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 38ms/step - loss: 4.2268e-04 - val_loss: 3.2547e-04
# Epoch 40/100
# 69/69 [==============================] - ETA: 0s - loss: 3.1930e-04
# Epoch 40: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 41ms/step - loss: 3.1930e-04 - val_loss: 4.3846e-04
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0832e-04
# Epoch 41: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 42ms/step - loss: 4.0832e-04 - val_loss: 2.5944e-04
# Epoch 42/100
# 69/69 [==============================] - ETA: 0s - loss: 4.7392e-04
# Epoch 42: val_loss did not improve from 0.00026
# 69/69 [==============================] - 3s 42ms/step - loss: 4.7392e-04 - val_loss: 3.5992e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1909.0805922505388
# [1630.3001825631893, 1909.0805922505388]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 1: val_loss improved from inf to 0.00325, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 16s 47ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 4.6065e-04
# Epoch 2: val_loss improved from 0.00325 to 0.00183, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 4.6065e-04 - val_loss: 0.0018
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.9778e-04
# Epoch 3: val_loss improved from 0.00183 to 0.00151, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 4.9421e-04 - val_loss: 0.0015
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3532e-04
# Epoch 4: val_loss improved from 0.00151 to 0.00054, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 31ms/step - loss: 4.3578e-04 - val_loss: 5.4499e-04
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.3822e-04
# Epoch 5: val_loss did not improve from 0.00054
# 104/104 [==============================] - 3s 32ms/step - loss: 4.3866e-04 - val_loss: 0.0011
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 3.8044e-04
# Epoch 6: val_loss did not improve from 0.00054
# 104/104 [==============================] - 4s 35ms/step - loss: 3.8044e-04 - val_loss: 0.0012
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 4.9391e-04
# Epoch 7: val_loss did not improve from 0.00054
# 104/104 [==============================] - 4s 34ms/step - loss: 4.9391e-04 - val_loss: 0.0054
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.9017e-04
# Epoch 8: val_loss did not improve from 0.00054
# 104/104 [==============================] - 4s 34ms/step - loss: 4.8967e-04 - val_loss: 6.8364e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1120e-04
# Epoch 9: val_loss did not improve from 0.00054
# 104/104 [==============================] - 4s 34ms/step - loss: 4.1120e-04 - val_loss: 0.0011
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.4026e-04
# Epoch 10: val_loss did not improve from 0.00054
# 104/104 [==============================] - 4s 35ms/step - loss: 4.4131e-04 - val_loss: 0.0021
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7106e-04
# Epoch 11: val_loss improved from 0.00054 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 36ms/step - loss: 3.7165e-04 - val_loss: 5.3173e-04
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 4.3618e-04
# Epoch 12: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 38ms/step - loss: 4.3618e-04 - val_loss: 0.0016
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5123e-04
# Epoch 13: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 36ms/step - loss: 3.5665e-04 - val_loss: 8.3169e-04
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.4743e-04
# Epoch 14: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 35ms/step - loss: 5.4395e-04 - val_loss: 0.0011
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 4.0624e-04
# Epoch 15: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 43ms/step - loss: 4.0624e-04 - val_loss: 0.0011
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 3.5527e-04
# Epoch 16: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 45ms/step - loss: 3.5527e-04 - val_loss: 9.4473e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 4.5819e-04
# Epoch 17: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 45ms/step - loss: 4.5819e-04 - val_loss: 9.6412e-04
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8069e-04
# Epoch 18: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 50ms/step - loss: 3.7948e-04 - val_loss: 0.0013
# Epoch 19/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5031e-04
# Epoch 19: val_loss did not improve from 0.00053
# 104/104 [==============================] - 5s 48ms/step - loss: 3.4946e-04 - val_loss: 0.0012
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8462e-04
# Epoch 20: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 37ms/step - loss: 3.8269e-04 - val_loss: 0.0015
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8273e-04
# Epoch 21: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 38ms/step - loss: 3.8200e-04 - val_loss: 7.7540e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1042.1672363159112
# [1630.3001825631893, 1909.0805922505388, 1042.1672363159112]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 1: val_loss improved from inf to 0.00225, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 14s 50ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 7.5712e-04
# Epoch 2: val_loss improved from 0.00225 to 0.00085, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 34ms/step - loss: 7.5712e-04 - val_loss: 8.5152e-04
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 5.9605e-04
# Epoch 3: val_loss did not improve from 0.00085
# 113/113 [==============================] - 4s 34ms/step - loss: 5.9605e-04 - val_loss: 0.0013
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0853e-04
# Epoch 4: val_loss did not improve from 0.00085
# 113/113 [==============================] - 4s 36ms/step - loss: 5.0853e-04 - val_loss: 0.0015
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 6.2138e-04
# Epoch 5: val_loss did not improve from 0.00085
# 113/113 [==============================] - 4s 36ms/step - loss: 6.2138e-04 - val_loss: 0.0018
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.1463e-04
# Epoch 6: val_loss did not improve from 0.00085
# 113/113 [==============================] - 5s 40ms/step - loss: 5.1503e-04 - val_loss: 0.0012
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 5.5875e-04
# Epoch 7: val_loss improved from 0.00085 to 0.00081, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 41ms/step - loss: 5.5875e-04 - val_loss: 8.0887e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.7635e-04
# Epoch 8: val_loss improved from 0.00081 to 0.00063, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 39ms/step - loss: 5.7635e-04 - val_loss: 6.2727e-04
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 4.9285e-04
# Epoch 9: val_loss did not improve from 0.00063
# 113/113 [==============================] - 5s 43ms/step - loss: 4.9285e-04 - val_loss: 6.5992e-04
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.9736e-04
# Epoch 10: val_loss improved from 0.00063 to 0.00057, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 42ms/step - loss: 5.0066e-04 - val_loss: 5.6578e-04
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 6.3047e-04
# Epoch 11: val_loss did not improve from 0.00057
# 113/113 [==============================] - 5s 47ms/step - loss: 6.3047e-04 - val_loss: 7.0707e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0771e-04
# Epoch 12: val_loss improved from 0.00057 to 0.00049, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 56ms/step - loss: 5.0771e-04 - val_loss: 4.9215e-04
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2471e-04
# Epoch 13: val_loss improved from 0.00049 to 0.00048, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 53ms/step - loss: 5.2667e-04 - val_loss: 4.7655e-04
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 5.9478e-04
# Epoch 14: val_loss improved from 0.00048 to 0.00046, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 51ms/step - loss: 5.9478e-04 - val_loss: 4.6163e-04
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0362e-04
# Epoch 15: val_loss did not improve from 0.00046
# 113/113 [==============================] - 6s 55ms/step - loss: 5.0362e-04 - val_loss: 4.7329e-04
# Epoch 16/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.6433e-04
# Epoch 16: val_loss did not improve from 0.00046
# 113/113 [==============================] - 7s 59ms/step - loss: 4.6221e-04 - val_loss: 5.6869e-04
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 5.1491e-04
# Epoch 17: val_loss did not improve from 0.00046
# 113/113 [==============================] - 6s 56ms/step - loss: 5.1491e-04 - val_loss: 0.0019
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.0721e-04
# Epoch 18: val_loss did not improve from 0.00046
# 113/113 [==============================] - 6s 49ms/step - loss: 5.0732e-04 - val_loss: 6.0061e-04
# Epoch 19/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5277e-04
# Epoch 19: val_loss did not improve from 0.00046
# 113/113 [==============================] - 5s 43ms/step - loss: 4.5409e-04 - val_loss: 4.7071e-04
# Epoch 20/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5140e-04
# Epoch 20: val_loss did not improve from 0.00046
# 113/113 [==============================] - 5s 42ms/step - loss: 4.5140e-04 - val_loss: 0.0011
# Epoch 21/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.3833e-04
# Epoch 21: val_loss did not improve from 0.00046
# 113/113 [==============================] - 4s 39ms/step - loss: 4.3644e-04 - val_loss: 7.5538e-04
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0761e-04
# Epoch 22: val_loss did not improve from 0.00046
# 113/113 [==============================] - 4s 39ms/step - loss: 5.0761e-04 - val_loss: 4.7042e-04
# Epoch 23/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.4501e-04
# Epoch 23: val_loss did not improve from 0.00046
# 113/113 [==============================] - 4s 36ms/step - loss: 5.4522e-04 - val_loss: 6.4692e-04
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2660e-04
# Epoch 24: val_loss did not improve from 0.00046
# 113/113 [==============================] - 5s 41ms/step - loss: 5.2660e-04 - val_loss: 7.3103e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1121.3126470306684
# [1630.3001825631893, 1909.0805922505388, 1042.1672363159112, 1121.3126470306684]

# %%
print(predict)
# Out:
# [array([[59815.695]], dtype=float32), array([[59305.29]], dtype=float32), array([[60378.414]], dtype=float32), array([[59132.98]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

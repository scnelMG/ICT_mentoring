# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.1037
# Epoch 1: val_loss improved from inf to 0.02095, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 22ms/step - loss: 0.1019 - val_loss: 0.0210
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0329
# Epoch 2: val_loss improved from 0.02095 to 0.00759, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0325 - val_loss: 0.0076
# Epoch 3/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0215
# Epoch 3: val_loss improved from 0.00759 to 0.00583, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0215 - val_loss: 0.0058
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 4: val_loss improved from 0.00583 to 0.00527, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0164 - val_loss: 0.0053
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0167
# Epoch 5: val_loss improved from 0.00527 to 0.00490, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0164 - val_loss: 0.0049
# Epoch 6/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0151
# Epoch 6: val_loss improved from 0.00490 to 0.00228, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0147 - val_loss: 0.0023
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0145
# Epoch 7: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0142 - val_loss: 0.0026
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0131
# Epoch 8: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0130 - val_loss: 0.0046
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0116
# Epoch 9: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0037
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 10: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0109 - val_loss: 0.0024
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0104
# Epoch 11: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0025
# Epoch 12/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0096
# Epoch 12: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 13: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0044
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 14: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0050
# Epoch 15/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0088
# Epoch 15: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0037
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0079
# Epoch 16: val_loss did not improve from 0.00228
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0025
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:2809.7956979579276
# [2809.7956979579276]
# Epoch 1/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0525
# Epoch 1: val_loss improved from inf to 0.00922, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 13ms/step - loss: 0.0498 - val_loss: 0.0092
# Epoch 2/100
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0238
# Epoch 2: val_loss improved from 0.00922 to 0.00231, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0236 - val_loss: 0.0023
# Epoch 3/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0204
# Epoch 3: val_loss did not improve from 0.00231
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0196 - val_loss: 0.0060
# Epoch 4/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 4: val_loss did not improve from 0.00231
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0046
# Epoch 5/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0150
# Epoch 5: val_loss improved from 0.00231 to 0.00170, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0149 - val_loss: 0.0017
# Epoch 6/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0105
# Epoch 6: val_loss did not improve from 0.00170
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0062
# Epoch 7/100
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0106
# Epoch 7: val_loss did not improve from 0.00170
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0038
# Epoch 8/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0116
# Epoch 8: val_loss did not improve from 0.00170
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0017
# Epoch 9/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 9: val_loss did not improve from 0.00170
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0030
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 10: val_loss did not improve from 0.00170
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0028
# Epoch 11/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0081
# Epoch 11: val_loss improved from 0.00170 to 0.00149, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0080 - val_loss: 0.0015
# Epoch 12/100
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0071
# Epoch 12: val_loss did not improve from 0.00149
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 13/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0070
# Epoch 13: val_loss improved from 0.00149 to 0.00114, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 14: val_loss did not improve from 0.00114
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 15: val_loss improved from 0.00114 to 0.00114, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 16: val_loss did not improve from 0.00114
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0017
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 17: val_loss did not improve from 0.00114
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0013
# Epoch 18/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0070
# Epoch 18: val_loss improved from 0.00114 to 0.00113, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0068 - val_loss: 0.0011
# Epoch 19/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0065
# Epoch 19: val_loss did not improve from 0.00113
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 20/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0061
# Epoch 20: val_loss did not improve from 0.00113
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 21: val_loss did not improve from 0.00113
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0033
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 22: val_loss did not improve from 0.00113
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 23/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0065
# Epoch 23: val_loss improved from 0.00113 to 0.00098, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0064 - val_loss: 9.8148e-04
# Epoch 24/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0054
# Epoch 24: val_loss did not improve from 0.00098
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 25/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0070
# Epoch 25: val_loss did not improve from 0.00098
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0069 - val_loss: 0.0014
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 26: val_loss improved from 0.00098 to 0.00075, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0063 - val_loss: 7.5218e-04
# Epoch 27/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 27: val_loss did not improve from 0.00075
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 28/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 28: val_loss did not improve from 0.00075
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0058 - val_loss: 0.0016
# Epoch 29/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0064
# Epoch 29: val_loss did not improve from 0.00075
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 30/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0061
# Epoch 30: val_loss did not improve from 0.00075
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 8.8493e-04
# Epoch 31/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 31: val_loss improved from 0.00075 to 0.00067, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0058 - val_loss: 6.6611e-04
# Epoch 32/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0055
# Epoch 32: val_loss did not improve from 0.00067
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 8.5928e-04
# Epoch 33/100
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0062
# Epoch 33: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 9.0490e-04
# Epoch 34/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 34: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0061 - val_loss: 7.8434e-04
# Epoch 35/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 35: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0056 - val_loss: 7.6155e-04
# Epoch 36/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0054
# Epoch 36: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0053 - val_loss: 7.3472e-04
# Epoch 37/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0056
# Epoch 37: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0056 - val_loss: 6.8541e-04
# Epoch 38/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 38: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 39/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 39: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0059 - val_loss: 7.5479e-04
# Epoch 40/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 40: val_loss did not improve from 0.00067
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 9.9117e-04
# Epoch 41/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0066
# Epoch 41: val_loss did not improve from 0.00067
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0065 - val_loss: 0.0014
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:4473.423190395294
# [2809.7956979579276, 4473.423190395294]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.1187
# Epoch 1: val_loss improved from inf to 0.06714, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 10ms/step - loss: 0.1168 - val_loss: 0.0671
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 2: val_loss improved from 0.06714 to 0.02343, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0170 - val_loss: 0.0234
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0120
# Epoch 3: val_loss did not improve from 0.02343
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0120 - val_loss: 0.0243
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 4: val_loss improved from 0.02343 to 0.01990, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0096 - val_loss: 0.0199
# Epoch 5/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0083
# Epoch 5: val_loss did not improve from 0.01990
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 0.0234
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 6: val_loss improved from 0.01990 to 0.00936, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0077 - val_loss: 0.0094
# Epoch 7/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 7: val_loss did not improve from 0.00936
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0062 - val_loss: 0.0172
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 8: val_loss improved from 0.00936 to 0.00794, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0058 - val_loss: 0.0079
# Epoch 9/100
#  96/104 [==========================>...] - ETA: 0s - loss: 0.0055
# Epoch 9: val_loss did not improve from 0.00794
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0126
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 10: val_loss did not improve from 0.00794
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0047 - val_loss: 0.0090
# Epoch 11/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 11: val_loss did not improve from 0.00794
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0039 - val_loss: 0.0133
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 12: val_loss improved from 0.00794 to 0.00680, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 13: val_loss improved from 0.00680 to 0.00428, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 14/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 14: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0053
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 16: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0078
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0059
# Epoch 18/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 18: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0065
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 19: val_loss did not improve from 0.00428
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 20/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss improved from 0.00428 to 0.00346, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 21: val_loss improved from 0.00346 to 0.00290, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 22/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 22: val_loss improved from 0.00290 to 0.00255, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 23/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 23: val_loss did not improve from 0.00255
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 24/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 24: val_loss did not improve from 0.00255
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0064
# Epoch 25/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 25: val_loss did not improve from 0.00255
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 26/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 26: val_loss did not improve from 0.00255
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 27/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 27: val_loss improved from 0.00255 to 0.00111, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 28/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 28: val_loss did not improve from 0.00111
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 29/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 29: val_loss did not improve from 0.00111
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 30/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 30: val_loss did not improve from 0.00111
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 31/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 31: val_loss did not improve from 0.00111
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 32/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 32: val_loss did not improve from 0.00111
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 33/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 33: val_loss improved from 0.00111 to 0.00059, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 5.9496e-04
# Epoch 34/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 34: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 6.0568e-04
# Epoch 35/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 35: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 36/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 36: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 37/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 37: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 38/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 38: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 39/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 39: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 40/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 40: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 41/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 41: val_loss did not improve from 0.00059
# 104/104 [==============================] - 2s 14ms/step - loss: 0.0022 - val_loss: 0.0049
# Epoch 42/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 42: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 43/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 43: val_loss did not improve from 0.00059
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0096
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:3112.065319651248
# [2809.7956979579276, 4473.423190395294, 3112.065319651248]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 1: val_loss improved from inf to 0.02397, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 19ms/step - loss: 0.0550 - val_loss: 0.0240
# Epoch 2/100
# 107/113 [===========================>..] - ETA: 0s - loss: 0.0211
# Epoch 2: val_loss improved from 0.02397 to 0.01941, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0208 - val_loss: 0.0194
# Epoch 3/100
# 107/113 [===========================>..] - ETA: 0s - loss: 0.0163
# Epoch 3: val_loss improved from 0.01941 to 0.01457, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0163 - val_loss: 0.0146
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0127
# Epoch 4: val_loss improved from 0.01457 to 0.01097, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0126 - val_loss: 0.0110
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 5: val_loss did not improve from 0.01097
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 6: val_loss improved from 0.01097 to 0.00800, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 1s 11ms/step - loss: 0.0104 - val_loss: 0.0080
# Epoch 7/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 7: val_loss improved from 0.00800 to 0.00639, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 8/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 8: val_loss improved from 0.00639 to 0.00383, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 9: val_loss improved from 0.00383 to 0.00364, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0063 - val_loss: 0.0036
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 10: val_loss did not improve from 0.00364
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 11: val_loss did not improve from 0.00364
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 12/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 12: val_loss improved from 0.00364 to 0.00132, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 13/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 13: val_loss did not improve from 0.00132
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0046 - val_loss: 0.0072
# Epoch 14/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 14: val_loss did not improve from 0.00132
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 15: val_loss did not improve from 0.00132
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0044 - val_loss: 0.0060
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 16: val_loss did not improve from 0.00132
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 17/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 17: val_loss improved from 0.00132 to 0.00087, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0045 - val_loss: 8.6571e-04
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 18: val_loss did not improve from 0.00087
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 19: val_loss did not improve from 0.00087
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 20: val_loss did not improve from 0.00087
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 21: val_loss did not improve from 0.00087
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 22/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 22: val_loss improved from 0.00087 to 0.00073, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0040 - val_loss: 7.3034e-04
# Epoch 23/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 23: val_loss did not improve from 0.00073
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 24: val_loss did not improve from 0.00073
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 25/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 25: val_loss did not improve from 0.00073
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 26/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 26: val_loss did not improve from 0.00073
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0046 - val_loss: 0.0012
# Epoch 27/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 27: val_loss did not improve from 0.00073
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 28/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 28: val_loss improved from 0.00073 to 0.00072, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0038 - val_loss: 7.2420e-04
# Epoch 29/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 29: val_loss did not improve from 0.00072
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 30/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 30: val_loss did not improve from 0.00072
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 31/100
# 108/113 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 31: val_loss did not improve from 0.00072
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 32/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 32: val_loss did not improve from 0.00072
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 33/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 33: val_loss did not improve from 0.00072
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 34/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 34: val_loss did not improve from 0.00072
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 35/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 35: val_loss did not improve from 0.00072
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 36/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 36: val_loss did not improve from 0.00072
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 37/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 37: val_loss did not improve from 0.00072
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 38/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 38: val_loss did not improve from 0.00072
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0040 - val_loss: 0.0056
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:2637.012695754916
# [2809.7956979579276, 4473.423190395294, 3112.065319651248, 2637.012695754916]

# %%
print(predict)
# Out:
# [array([[57053.27]], dtype=float32), array([[55906.51]], dtype=float32), array([[55331.285]], dtype=float32), array([[56509.625]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

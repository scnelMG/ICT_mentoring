# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
    

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0714
# Epoch 1: val_loss improved from inf to 0.01435, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 6s 61ms/step - loss: 0.0680 - val_loss: 0.0143
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0133
# Epoch 2: val_loss improved from 0.01435 to 0.00389, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0131 - val_loss: 0.0039
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 3: val_loss did not improve from 0.00389
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 4: val_loss improved from 0.00389 to 0.00320, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0081 - val_loss: 0.0032
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 5: val_loss did not improve from 0.00320
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0072 - val_loss: 0.0047
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 6: val_loss improved from 0.00320 to 0.00309, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0070 - val_loss: 0.0031
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 7: val_loss did not improve from 0.00309
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 8: val_loss did not improve from 0.00309
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0057 - val_loss: 0.0032
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 9: val_loss did not improve from 0.00309
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0074
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 10: val_loss improved from 0.00309 to 0.00300, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 11: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 12: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0045 - val_loss: 0.0078
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 13: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0045 - val_loss: 0.0085
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 14: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 15: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 16: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 0.0048
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 18: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 19: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0050
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 20: val_loss did not improve from 0.00300
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0036 - val_loss: 0.0054
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:6147.744364667073
# [6147.744364667073]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 1: val_loss improved from inf to 0.00359, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 7s 33ms/step - loss: 0.0215 - val_loss: 0.0036
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 2: val_loss improved from 0.00359 to 0.00189, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0087 - val_loss: 0.0019
# Epoch 3/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0069
# Epoch 3: val_loss did not improve from 0.00189
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0069 - val_loss: 0.0024
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 4: val_loss improved from 0.00189 to 0.00131, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 5: val_loss improved from 0.00131 to 0.00121, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0049 - val_loss: 0.0012
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 6: val_loss did not improve from 0.00121
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 7: val_loss improved from 0.00121 to 0.00096, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0052 - val_loss: 9.6347e-04
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 8: val_loss did not improve from 0.00096
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 9: val_loss improved from 0.00096 to 0.00076, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0040 - val_loss: 7.6475e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 10: val_loss did not improve from 0.00076
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 11: val_loss did not improve from 0.00076
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0039 - val_loss: 9.1912e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 12: val_loss improved from 0.00076 to 0.00075, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0033 - val_loss: 7.5060e-04
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 13: val_loss did not improve from 0.00075
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0032 - val_loss: 9.6940e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 14: val_loss improved from 0.00075 to 0.00070, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0029 - val_loss: 6.9572e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss improved from 0.00070 to 0.00059, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 22ms/step - loss: 0.0032 - val_loss: 5.8777e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 16: val_loss improved from 0.00059 to 0.00053, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0031 - val_loss: 5.2745e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 17: val_loss improved from 0.00053 to 0.00052, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0027 - val_loss: 5.1987e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 18: val_loss did not improve from 0.00052
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0024 - val_loss: 7.1800e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 19: val_loss did not improve from 0.00052
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0024 - val_loss: 5.3713e-04
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 20: val_loss improved from 0.00052 to 0.00050, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0025 - val_loss: 5.0060e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 21: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0024 - val_loss: 6.3262e-04
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 22: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0022 - val_loss: 5.2192e-04
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 23: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0021 - val_loss: 5.4624e-04
# Epoch 24/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 24: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 7.7196e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 25: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0021 - val_loss: 6.8376e-04
# Epoch 26/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 26: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0020 - val_loss: 6.9462e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 27: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0019 - val_loss: 5.9605e-04
# Epoch 28/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 28: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0019 - val_loss: 6.3590e-04
# Epoch 29/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 29: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0022 - val_loss: 5.1949e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 30: val_loss did not improve from 0.00050
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0019 - val_loss: 5.3178e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1412.7992244631405
# [6147.744364667073, 1412.7992244631405]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0161
# Epoch 1: val_loss improved from inf to 0.02790, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 10s 33ms/step - loss: 0.0159 - val_loss: 0.0279
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 2: val_loss improved from 0.02790 to 0.00967, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 3: val_loss did not improve from 0.00967
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0041 - val_loss: 0.0137
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 4: val_loss improved from 0.00967 to 0.00619, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 5: val_loss did not improve from 0.00619
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 6/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 6: val_loss improved from 0.00619 to 0.00519, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 7: val_loss improved from 0.00519 to 0.00397, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 8: val_loss improved from 0.00397 to 0.00298, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 9: val_loss improved from 0.00298 to 0.00290, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 10/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 10: val_loss did not improve from 0.00290
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 11/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 11: val_loss improved from 0.00290 to 0.00149, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 12: val_loss did not improve from 0.00149
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 13/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 13: val_loss did not improve from 0.00149
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 14: val_loss did not improve from 0.00149
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 15: val_loss did not improve from 0.00149
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 16: val_loss did not improve from 0.00149
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 17: val_loss did not improve from 0.00149
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 18: val_loss improved from 0.00149 to 0.00090, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0012 - val_loss: 9.0304e-04
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 19: val_loss did not improve from 0.00090
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 9.5714e-04
# Epoch 20: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 24ms/step - loss: 9.5714e-04 - val_loss: 0.0024
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 21: val_loss did not improve from 0.00090
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 23ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 23/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 23: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 24: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 25/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 25: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 26/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 26: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 27/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 27: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0011 - val_loss: 9.7339e-04
# Epoch 28/100
# 103/104 [============================>.] - ETA: 0s - loss: 9.4502e-04
# Epoch 28: val_loss did not improve from 0.00090
# 104/104 [==============================] - 2s 18ms/step - loss: 9.4483e-04 - val_loss: 0.0011
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1278.5020559964075
# [6147.744364667073, 1412.7992244631405, 1278.5020559964075]
# Epoch 1/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0133
# Epoch 1: val_loss improved from inf to 0.00261, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 8s 33ms/step - loss: 0.0132 - val_loss: 0.0026
# Epoch 2/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 2: val_loss improved from 0.00261 to 0.00144, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 29ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 3: val_loss did not improve from 0.00144
# 113/113 [==============================] - 3s 29ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 4: val_loss improved from 0.00144 to 0.00088, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 31ms/step - loss: 0.0042 - val_loss: 8.7678e-04
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 5: val_loss improved from 0.00088 to 0.00086, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 33ms/step - loss: 0.0036 - val_loss: 8.6039e-04
# Epoch 6/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 6: val_loss did not improve from 0.00086
# 113/113 [==============================] - 3s 30ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 7: val_loss did not improve from 0.00086
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 8: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0029 - val_loss: 9.7870e-04
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 9: val_loss did not improve from 0.00086
# 113/113 [==============================] - 3s 28ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 10: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 33ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 11: val_loss did not improve from 0.00086
# 113/113 [==============================] - 4s 31ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 12/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 12: val_loss did not improve from 0.00086
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 13: val_loss did not improve from 0.00086
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 14: val_loss did not improve from 0.00086
# 113/113 [==============================] - 5s 44ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 15/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 15: val_loss did not improve from 0.00086
# 113/113 [==============================] - 5s 42ms/step - loss: 0.0018 - val_loss: 0.0050
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:3159.5341003974613
# [6147.744364667073, 1412.7992244631405, 1278.5020559964075, 3159.5341003974613]

# %%
print(predict)
# Out:
# [array([[51590.875]], dtype=float32), array([[61272.945]], dtype=float32), array([[59610.957]], dtype=float32), array([[55514.145]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

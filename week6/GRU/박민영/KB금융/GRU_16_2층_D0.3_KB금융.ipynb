# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0204
# Epoch 1: val_loss improved from inf to 0.01260, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 13s 129ms/step - loss: 0.0201 - val_loss: 0.0126
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0105
# Epoch 2: val_loss improved from 0.01260 to 0.00275, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0104 - val_loss: 0.0028
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 3: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0096 - val_loss: 0.0082
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 4: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0072 - val_loss: 0.0124
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 5: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 6: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0059 - val_loss: 0.0143
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 7: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0059 - val_loss: 0.0123
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 8: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0052 - val_loss: 0.0092
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 9: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0043 - val_loss: 0.0106
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 10: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 11: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0042 - val_loss: 0.0086
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 12: val_loss did not improve from 0.00275
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0042 - val_loss: 0.0061
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:3806.6908014319056
# [3806.6908014319056]
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0689
# Epoch 1: val_loss improved from inf to 0.00722, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 12s 39ms/step - loss: 0.0683 - val_loss: 0.0072
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 2: val_loss improved from 0.00722 to 0.00152, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0194 - val_loss: 0.0015
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0131
# Epoch 3: val_loss improved from 0.00152 to 0.00139, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0130 - val_loss: 0.0014
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 4: val_loss improved from 0.00139 to 0.00126, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0092 - val_loss: 0.0013
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 5: val_loss improved from 0.00126 to 0.00106, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0087 - val_loss: 0.0011
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 6: val_loss improved from 0.00106 to 0.00094, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0081 - val_loss: 9.4032e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 7: val_loss did not improve from 0.00094
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0073 - val_loss: 0.0012
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 8: val_loss improved from 0.00094 to 0.00091, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0067 - val_loss: 9.1379e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 9: val_loss did not improve from 0.00091
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 10/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 10: val_loss did not improve from 0.00091
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 11: val_loss improved from 0.00091 to 0.00064, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0055 - val_loss: 6.3837e-04
# Epoch 12/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 12: val_loss did not improve from 0.00064
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0059 - val_loss: 0.0015
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 13: val_loss did not improve from 0.00064
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0053 - val_loss: 8.0222e-04
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 14: val_loss did not improve from 0.00064
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0051 - val_loss: 6.4457e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 15: val_loss improved from 0.00064 to 0.00055, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0049 - val_loss: 5.4501e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 16: val_loss did not improve from 0.00055
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0043 - val_loss: 6.0845e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 17: val_loss did not improve from 0.00055
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 18: val_loss did not improve from 0.00055
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0035 - val_loss: 6.9144e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 19: val_loss improved from 0.00055 to 0.00048, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0038 - val_loss: 4.8031e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 20: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 5.8611e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 21: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 22: val_loss improved from 0.00048 to 0.00040, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0033 - val_loss: 4.0147e-04
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 23: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0030 - val_loss: 4.3234e-04
# Epoch 24/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 24: val_loss improved from 0.00040 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0028 - val_loss: 3.8221e-04
# Epoch 25/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 25: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 3.8544e-04
# Epoch 26/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 26: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0027 - val_loss: 4.0606e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 27: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 28: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0027 - val_loss: 4.0147e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 29: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 22ms/step - loss: 0.0027 - val_loss: 5.5963e-04
# Epoch 30/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 30: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0030 - val_loss: 6.4575e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 31: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0029 - val_loss: 4.1381e-04
# Epoch 32/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 32: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0025 - val_loss: 4.3440e-04
# Epoch 33/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 33: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0025 - val_loss: 8.6353e-04
# Epoch 34/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 34: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0026 - val_loss: 3.8963e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:3094.6448934582913
# [3806.6908014319056, 3094.6448934582913]
# Epoch 1/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.1916
# Epoch 1: val_loss improved from inf to 0.04802, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 21s 59ms/step - loss: 0.1868 - val_loss: 0.0480
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 2: val_loss improved from 0.04802 to 0.03177, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0175 - val_loss: 0.0318
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 3: val_loss improved from 0.03177 to 0.02091, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0132 - val_loss: 0.0209
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 4: val_loss improved from 0.02091 to 0.00775, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 5: val_loss did not improve from 0.00775
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0081 - val_loss: 0.0094
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 6: val_loss did not improve from 0.00775
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0074 - val_loss: 0.0090
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 7: val_loss improved from 0.00775 to 0.00609, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 8: val_loss improved from 0.00609 to 0.00210, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 9/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 9: val_loss did not improve from 0.00210
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0057 - val_loss: 0.0029
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 10: val_loss did not improve from 0.00210
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 11: val_loss did not improve from 0.00210
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 12: val_loss did not improve from 0.00210
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 13: val_loss did not improve from 0.00210
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 14/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 14: val_loss improved from 0.00210 to 0.00127, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 15: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 16: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 17: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 18/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 18: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 19: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 20: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 21: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 22: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 23: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 24: val_loss did not improve from 0.00127
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0024 - val_loss: 0.0020
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1934.0898855710684
# [3806.6908014319056, 3094.6448934582913, 1934.0898855710684]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0338
# Epoch 1: val_loss improved from inf to 0.00251, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 14s 50ms/step - loss: 0.0338 - val_loss: 0.0025
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 2: val_loss did not improve from 0.00251
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 3: val_loss improved from 0.00251 to 0.00246, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 0.0071 - val_loss: 0.0025
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 4: val_loss did not improve from 0.00246
# 113/113 [==============================] - 3s 31ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 5: val_loss improved from 0.00246 to 0.00204, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 6: val_loss did not improve from 0.00204
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 7/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 7: val_loss improved from 0.00204 to 0.00092, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0044 - val_loss: 9.1754e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 8: val_loss did not improve from 0.00092
# 113/113 [==============================] - 3s 29ms/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 9/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 9: val_loss did not improve from 0.00092
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 10: val_loss did not improve from 0.00092
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 11: val_loss did not improve from 0.00092
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 12: val_loss improved from 0.00092 to 0.00082, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 0.0031 - val_loss: 8.1848e-04
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 13: val_loss did not improve from 0.00082
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0028 - val_loss: 8.4296e-04
# Epoch 14/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 14: val_loss did not improve from 0.00082
# 113/113 [==============================] - 4s 36ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 15: val_loss improved from 0.00082 to 0.00064, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0024 - val_loss: 6.4177e-04
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 16: val_loss did not improve from 0.00064
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 17/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 17: val_loss did not improve from 0.00064
# 113/113 [==============================] - 3s 30ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 18: val_loss did not improve from 0.00064
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0022 - val_loss: 6.7853e-04
# Epoch 19/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 19: val_loss did not improve from 0.00064
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 20: val_loss did not improve from 0.00064
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 21/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 21: val_loss did not improve from 0.00064
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 22: val_loss improved from 0.00064 to 0.00055, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 30ms/step - loss: 0.0019 - val_loss: 5.5262e-04
# Epoch 23/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 23: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0019 - val_loss: 9.0187e-04
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 24: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0017 - val_loss: 6.6671e-04
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 25: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0019 - val_loss: 7.4435e-04
# Epoch 26/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 26: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0018 - val_loss: 6.2433e-04
# Epoch 27/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 27: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0016 - val_loss: 7.5109e-04
# Epoch 28/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 28: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 29/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 29: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0017 - val_loss: 5.7196e-04
# Epoch 30/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 30: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 31/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 31: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 32/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 32: val_loss did not improve from 0.00055
# 113/113 [==============================] - 3s 25ms/step - loss: 0.0017 - val_loss: 0.0013
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1283.7292480018816
# [3806.6908014319056, 3094.6448934582913, 1934.0898855710684, 1283.7292480018816]

# %%
print(predict)
# Out:
# [array([[56205.]], dtype=float32), array([[56890.66]], dtype=float32), array([[57725.156]], dtype=float32), array([[58850.24]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

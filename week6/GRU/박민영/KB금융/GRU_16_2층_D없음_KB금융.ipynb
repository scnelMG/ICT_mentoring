# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 1: val_loss improved from inf to 0.00809, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 23s 206ms/step - loss: 0.0096 - val_loss: 0.0081
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 2: val_loss improved from 0.00809 to 0.00754, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0022 - val_loss: 0.0075
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 3: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0011 - val_loss: 0.0116
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.4629e-04
# Epoch 4: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 23ms/step - loss: 8.3922e-04 - val_loss: 0.0108
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.8667e-04
# Epoch 5: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 27ms/step - loss: 8.6613e-04 - val_loss: 0.0113
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 8.2629e-04
# Epoch 6: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 39ms/step - loss: 8.2629e-04 - val_loss: 0.0107
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.1194e-04
# Epoch 7: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 23ms/step - loss: 8.0755e-04 - val_loss: 0.0105
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 6.8703e-04
# Epoch 8: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 26ms/step - loss: 6.8703e-04 - val_loss: 0.0103
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.8966e-04
# Epoch 9: val_loss did not improve from 0.00754
# 34/34 [==============================] - 1s 24ms/step - loss: 6.8657e-04 - val_loss: 0.0089
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.3808e-04
# Epoch 10: val_loss improved from 0.00754 to 0.00740, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 6.2463e-04 - val_loss: 0.0074
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.0805e-04
# Epoch 11: val_loss improved from 0.00740 to 0.00633, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 6.1454e-04 - val_loss: 0.0063
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 5.6025e-04
# Epoch 12: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 21ms/step - loss: 5.6025e-04 - val_loss: 0.0083
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 5.4362e-04
# Epoch 13: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 23ms/step - loss: 5.4362e-04 - val_loss: 0.0094
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 5.4712e-04
# Epoch 14: val_loss improved from 0.00633 to 0.00614, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 5.4712e-04 - val_loss: 0.0061
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.6838e-04
# Epoch 15: val_loss did not improve from 0.00614
# 34/34 [==============================] - 1s 22ms/step - loss: 4.7311e-04 - val_loss: 0.0080
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3431e-04
# Epoch 16: val_loss improved from 0.00614 to 0.00572, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 5.5259e-04 - val_loss: 0.0057
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.3547e-04
# Epoch 17: val_loss did not improve from 0.00572
# 34/34 [==============================] - 1s 21ms/step - loss: 7.4211e-04 - val_loss: 0.0058
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.4536e-04
# Epoch 18: val_loss did not improve from 0.00572
# 34/34 [==============================] - 1s 21ms/step - loss: 5.7296e-04 - val_loss: 0.0075
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.4197e-04
# Epoch 19: val_loss improved from 0.00572 to 0.00495, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 4.5482e-04 - val_loss: 0.0050
# Epoch 20/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9099e-04
# Epoch 20: val_loss improved from 0.00495 to 0.00470, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 5.0066e-04 - val_loss: 0.0047
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3321e-04
# Epoch 21: val_loss did not improve from 0.00470
# 34/34 [==============================] - 1s 21ms/step - loss: 4.3296e-04 - val_loss: 0.0063
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.3612e-04
# Epoch 22: val_loss did not improve from 0.00470
# 34/34 [==============================] - 1s 20ms/step - loss: 4.3303e-04 - val_loss: 0.0066
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 4.4436e-04
# Epoch 23: val_loss improved from 0.00470 to 0.00467, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 4.4436e-04 - val_loss: 0.0047
# Epoch 24/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.5163e-04
# Epoch 24: val_loss improved from 0.00467 to 0.00413, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 5.5783e-04 - val_loss: 0.0041
# Epoch 25/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.0456e-04
# Epoch 25: val_loss improved from 0.00413 to 0.00341, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 5.0937e-04 - val_loss: 0.0034
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1940e-04
# Epoch 26: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 4.1940e-04 - val_loss: 0.0057
# Epoch 27/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.1078e-04
# Epoch 27: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 4.2970e-04 - val_loss: 0.0058
# Epoch 28/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.8816e-04
# Epoch 28: val_loss did not improve from 0.00341
# 34/34 [==============================] - 1s 15ms/step - loss: 5.6668e-04 - val_loss: 0.0041
# Epoch 29/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.2348e-04
# Epoch 29: val_loss did not improve from 0.00341
# 34/34 [==============================] - 1s 16ms/step - loss: 4.1234e-04 - val_loss: 0.0048
# Epoch 30/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3371e-04
# Epoch 30: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 4.3371e-04 - val_loss: 0.0060
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 5.5808e-04
# Epoch 31: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 5.5808e-04 - val_loss: 0.0082
# Epoch 32/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.6327e-04
# Epoch 32: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 4.4494e-04 - val_loss: 0.0058
# Epoch 33/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.2191e-04
# Epoch 33: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 14ms/step - loss: 4.1582e-04 - val_loss: 0.0064
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.7286e-04
# Epoch 34: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 13ms/step - loss: 4.7940e-04 - val_loss: 0.0084
# Epoch 35/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.5247e-04
# Epoch 35: val_loss did not improve from 0.00341
# 34/34 [==============================] - 0s 13ms/step - loss: 5.4263e-04 - val_loss: 0.0048
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:3715.708402042744
# [3715.708402042744]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0484
# Epoch 1: val_loss improved from inf to 0.00227, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 6s 41ms/step - loss: 0.0470 - val_loss: 0.0023
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 2: val_loss improved from 0.00227 to 0.00171, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 9.6588e-04
# Epoch 3: val_loss did not improve from 0.00171
# 69/69 [==============================] - 2s 23ms/step - loss: 9.6588e-04 - val_loss: 0.0018
# Epoch 4/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.4058e-04
# Epoch 4: val_loss improved from 0.00171 to 0.00156, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 19ms/step - loss: 8.3892e-04 - val_loss: 0.0016
# Epoch 5/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.9021e-04
# Epoch 5: val_loss improved from 0.00156 to 0.00129, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 7.9842e-04 - val_loss: 0.0013
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.0503e-04
# Epoch 6: val_loss did not improve from 0.00129
# 69/69 [==============================] - 1s 19ms/step - loss: 7.0204e-04 - val_loss: 0.0014
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.8522e-04
# Epoch 7: val_loss did not improve from 0.00129
# 69/69 [==============================] - 1s 21ms/step - loss: 6.8345e-04 - val_loss: 0.0020
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 6.1578e-04
# Epoch 8: val_loss did not improve from 0.00129
# 69/69 [==============================] - 1s 21ms/step - loss: 6.1578e-04 - val_loss: 0.0017
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.8192e-04
# Epoch 9: val_loss improved from 0.00129 to 0.00129, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 22ms/step - loss: 5.8344e-04 - val_loss: 0.0013
# Epoch 10/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.5864e-04
# Epoch 10: val_loss improved from 0.00129 to 0.00104, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 5.5711e-04 - val_loss: 0.0010
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.3483e-04
# Epoch 11: val_loss did not improve from 0.00104
# 69/69 [==============================] - 1s 19ms/step - loss: 5.3123e-04 - val_loss: 0.0014
# Epoch 12/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.4820e-04
# Epoch 12: val_loss improved from 0.00104 to 0.00087, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 5.4022e-04 - val_loss: 8.6717e-04
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 5.1828e-04
# Epoch 13: val_loss did not improve from 0.00087
# 69/69 [==============================] - 1s 18ms/step - loss: 5.1507e-04 - val_loss: 9.2276e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.7325e-04
# Epoch 14: val_loss did not improve from 0.00087
# 69/69 [==============================] - 1s 16ms/step - loss: 4.7442e-04 - val_loss: 9.7038e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.7950e-04
# Epoch 15: val_loss did not improve from 0.00087
# 69/69 [==============================] - 1s 19ms/step - loss: 4.7593e-04 - val_loss: 0.0013
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.8958e-04
# Epoch 16: val_loss did not improve from 0.00087
# 69/69 [==============================] - 2s 22ms/step - loss: 4.9048e-04 - val_loss: 0.0011
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 5.1591e-04
# Epoch 17: val_loss did not improve from 0.00087
# 69/69 [==============================] - 1s 20ms/step - loss: 5.1591e-04 - val_loss: 0.0010
# Epoch 18/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.4368e-04
# Epoch 18: val_loss improved from 0.00087 to 0.00073, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 4.4079e-04 - val_loss: 7.3256e-04
# Epoch 19/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.4999e-04
# Epoch 19: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 18ms/step - loss: 4.3970e-04 - val_loss: 8.8632e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.5119e-04
# Epoch 20: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 18ms/step - loss: 4.4672e-04 - val_loss: 0.0012
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.5082e-04
# Epoch 21: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 21ms/step - loss: 4.4829e-04 - val_loss: 0.0012
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3153e-04
# Epoch 22: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 20ms/step - loss: 4.3153e-04 - val_loss: 0.0011
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6707e-04
# Epoch 23: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 19ms/step - loss: 4.7613e-04 - val_loss: 8.4266e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 4.4949e-04
# Epoch 24: val_loss did not improve from 0.00073
# 69/69 [==============================] - 1s 19ms/step - loss: 4.4949e-04 - val_loss: 0.0010
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 4.7424e-04
# Epoch 25: val_loss did not improve from 0.00073
# 69/69 [==============================] - 2s 23ms/step - loss: 4.7424e-04 - val_loss: 0.0019
# Epoch 26/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.4799e-04
# Epoch 26: val_loss did not improve from 0.00073
# 69/69 [==============================] - 2s 27ms/step - loss: 4.4713e-04 - val_loss: 9.3280e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.2394e-04
# Epoch 27: val_loss did not improve from 0.00073
# 69/69 [==============================] - 2s 26ms/step - loss: 4.2134e-04 - val_loss: 0.0013
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 5.0065e-04
# Epoch 28: val_loss improved from 0.00073 to 0.00047, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 5.0065e-04 - val_loss: 4.6800e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0306e-04
# Epoch 29: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 29ms/step - loss: 4.0306e-04 - val_loss: 0.0014
# Epoch 30/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.6429e-04
# Epoch 30: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 32ms/step - loss: 4.6118e-04 - val_loss: 5.1808e-04
# Epoch 31/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3804e-04
# Epoch 31: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 28ms/step - loss: 4.3595e-04 - val_loss: 0.0011
# Epoch 32/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9193e-04
# Epoch 32: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 30ms/step - loss: 3.9193e-04 - val_loss: 0.0012
# Epoch 33/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7737e-04
# Epoch 33: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 24ms/step - loss: 3.8098e-04 - val_loss: 9.4273e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7395e-04
# Epoch 34: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 27ms/step - loss: 3.7395e-04 - val_loss: 9.9539e-04
# Epoch 35/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2430e-04
# Epoch 35: val_loss did not improve from 0.00047
# 69/69 [==============================] - 2s 25ms/step - loss: 4.2430e-04 - val_loss: 7.3564e-04
# Epoch 36/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1667e-04
# Epoch 36: val_loss did not improve from 0.00047
# 69/69 [==============================] - 1s 21ms/step - loss: 4.1689e-04 - val_loss: 0.0016
# Epoch 37/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.8832e-04
# Epoch 37: val_loss did not improve from 0.00047
# 69/69 [==============================] - 1s 19ms/step - loss: 3.8574e-04 - val_loss: 0.0011
# Epoch 38/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.8590e-04
# Epoch 38: val_loss did not improve from 0.00047
# 69/69 [==============================] - 1s 19ms/step - loss: 3.8432e-04 - val_loss: 9.2412e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:2763.641573042212
# [3715.708402042744, 2763.641573042212]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 1: val_loss improved from inf to 0.00931, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 11s 36ms/step - loss: 0.0159 - val_loss: 0.0093
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 2: val_loss improved from 0.00931 to 0.00430, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 8.8398e-04
# Epoch 3: val_loss did not improve from 0.00430
# 104/104 [==============================] - 2s 22ms/step - loss: 8.8398e-04 - val_loss: 0.0073
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.9486e-04
# Epoch 4: val_loss improved from 0.00430 to 0.00359, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 22ms/step - loss: 7.8950e-04 - val_loss: 0.0036
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 6.6052e-04
# Epoch 5: val_loss improved from 0.00359 to 0.00176, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 21ms/step - loss: 6.5855e-04 - val_loss: 0.0018
# Epoch 6/100
# 101/104 [============================>.] - ETA: 0s - loss: 6.0933e-04
# Epoch 6: val_loss improved from 0.00176 to 0.00157, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 20ms/step - loss: 6.0581e-04 - val_loss: 0.0016
# Epoch 7/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.6257e-04
# Epoch 7: val_loss did not improve from 0.00157
# 104/104 [==============================] - 2s 15ms/step - loss: 5.7407e-04 - val_loss: 0.0048
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.3841e-04
# Epoch 8: val_loss did not improve from 0.00157
# 104/104 [==============================] - 2s 16ms/step - loss: 5.3858e-04 - val_loss: 0.0026
# Epoch 9/100
# 100/104 [===========================>..] - ETA: 0s - loss: 5.4062e-04
# Epoch 9: val_loss did not improve from 0.00157
# 104/104 [==============================] - 1s 13ms/step - loss: 5.3554e-04 - val_loss: 0.0017
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 4.6603e-04
# Epoch 10: val_loss did not improve from 0.00157
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6603e-04 - val_loss: 0.0025
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.1270e-04
# Epoch 11: val_loss did not improve from 0.00157
# 104/104 [==============================] - 2s 16ms/step - loss: 5.1039e-04 - val_loss: 0.0016
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4841e-04
# Epoch 12: val_loss improved from 0.00157 to 0.00123, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 4.4841e-04 - val_loss: 0.0012
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.8706e-04
# Epoch 13: val_loss did not improve from 0.00123
# 104/104 [==============================] - 2s 17ms/step - loss: 4.8396e-04 - val_loss: 0.0017
# Epoch 14/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.3178e-04
# Epoch 14: val_loss did not improve from 0.00123
# 104/104 [==============================] - 2s 15ms/step - loss: 4.3334e-04 - val_loss: 0.0018
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3014e-04
# Epoch 15: val_loss improved from 0.00123 to 0.00119, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 18ms/step - loss: 4.2836e-04 - val_loss: 0.0012
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.2272e-04
# Epoch 16: val_loss improved from 0.00119 to 0.00086, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 21ms/step - loss: 4.2069e-04 - val_loss: 8.5645e-04
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8066e-04
# Epoch 17: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 18ms/step - loss: 3.8496e-04 - val_loss: 0.0018
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1747e-04
# Epoch 18: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 19ms/step - loss: 4.1811e-04 - val_loss: 9.5032e-04
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.9647e-04
# Epoch 19: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 21ms/step - loss: 3.9623e-04 - val_loss: 0.0012
# Epoch 20/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3386e-04
# Epoch 20: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 22ms/step - loss: 4.3237e-04 - val_loss: 0.0018
# Epoch 21/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.9992e-04
# Epoch 21: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 20ms/step - loss: 3.9819e-04 - val_loss: 0.0019
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1846e-04
# Epoch 22: val_loss did not improve from 0.00086
# 104/104 [==============================] - 2s 18ms/step - loss: 4.1846e-04 - val_loss: 0.0028
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1690e-04
# Epoch 23: val_loss improved from 0.00086 to 0.00073, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 20ms/step - loss: 4.1972e-04 - val_loss: 7.2582e-04
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 4.0026e-04
# Epoch 24: val_loss did not improve from 0.00073
# 104/104 [==============================] - 2s 23ms/step - loss: 4.0026e-04 - val_loss: 0.0019
# Epoch 25/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.0371e-04
# Epoch 25: val_loss did not improve from 0.00073
# 104/104 [==============================] - 2s 19ms/step - loss: 4.0562e-04 - val_loss: 0.0027
# Epoch 26/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.8893e-04
# Epoch 26: val_loss improved from 0.00073 to 0.00063, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 22ms/step - loss: 3.9048e-04 - val_loss: 6.3389e-04
# Epoch 27/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7306e-04
# Epoch 27: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 26ms/step - loss: 3.7410e-04 - val_loss: 8.2045e-04
# Epoch 28/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.7474e-04
# Epoch 28: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 19ms/step - loss: 3.7456e-04 - val_loss: 0.0018
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6602e-04
# Epoch 29: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 17ms/step - loss: 3.6602e-04 - val_loss: 0.0014
# Epoch 30/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1137e-04
# Epoch 30: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 23ms/step - loss: 4.1119e-04 - val_loss: 0.0013
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6411e-04
# Epoch 31: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 19ms/step - loss: 3.6411e-04 - val_loss: 6.5364e-04
# Epoch 32/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7729e-04
# Epoch 32: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 3.7820e-04 - val_loss: 0.0018
# Epoch 33/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6482e-04
# Epoch 33: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 21ms/step - loss: 3.6482e-04 - val_loss: 0.0014
# Epoch 34/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.4353e-04
# Epoch 34: val_loss improved from 0.00063 to 0.00063, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 3.4452e-04 - val_loss: 6.2846e-04
# Epoch 35/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.0772e-04
# Epoch 35: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 18ms/step - loss: 4.0229e-04 - val_loss: 7.5341e-04
# Epoch 36/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7126e-04
# Epoch 36: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 20ms/step - loss: 3.7126e-04 - val_loss: 6.8240e-04
# Epoch 37/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.7804e-04
# Epoch 37: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 23ms/step - loss: 3.7861e-04 - val_loss: 6.2915e-04
# Epoch 38/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5031e-04
# Epoch 38: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 3.4943e-04 - val_loss: 8.6897e-04
# Epoch 39/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9097e-04
# Epoch 39: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 21ms/step - loss: 3.9097e-04 - val_loss: 7.5889e-04
# Epoch 40/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.3823e-04
# Epoch 40: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 23ms/step - loss: 3.3864e-04 - val_loss: 6.7999e-04
# Epoch 41/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7585e-04
# Epoch 41: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 21ms/step - loss: 3.7585e-04 - val_loss: 8.2590e-04
# Epoch 42/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.4989e-04
# Epoch 42: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 20ms/step - loss: 3.4673e-04 - val_loss: 7.6883e-04
# Epoch 43/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.2700e-04
# Epoch 43: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 24ms/step - loss: 3.2694e-04 - val_loss: 6.7576e-04
# Epoch 44/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5351e-04
# Epoch 44: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 26ms/step - loss: 3.5220e-04 - val_loss: 7.9666e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1310.7562399943033
# [3715.708402042744, 2763.641573042212, 1310.7562399943033]
# Epoch 1/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 1: val_loss improved from inf to 0.00559, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 13s 40ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 2/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 2: val_loss improved from 0.00559 to 0.00374, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 28ms/step - loss: 0.0011 - val_loss: 0.0037
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 8.9290e-04
# Epoch 3: val_loss improved from 0.00374 to 0.00234, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 26ms/step - loss: 8.9008e-04 - val_loss: 0.0023
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 7.3333e-04
# Epoch 4: val_loss did not improve from 0.00234
# 113/113 [==============================] - 3s 24ms/step - loss: 7.3333e-04 - val_loss: 0.0027
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 6.8123e-04
# Epoch 5: val_loss improved from 0.00234 to 0.00134, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 25ms/step - loss: 6.8123e-04 - val_loss: 0.0013
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 7.2304e-04
# Epoch 6: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 25ms/step - loss: 7.2304e-04 - val_loss: 0.0014
# Epoch 7/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.2628e-04
# Epoch 7: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 25ms/step - loss: 6.2407e-04 - val_loss: 0.0019
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.0740e-04
# Epoch 8: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 23ms/step - loss: 6.0603e-04 - val_loss: 0.0038
# Epoch 9/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.8140e-04
# Epoch 9: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 24ms/step - loss: 5.7882e-04 - val_loss: 0.0017
# Epoch 10/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.3815e-04
# Epoch 10: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 24ms/step - loss: 5.4050e-04 - val_loss: 0.0039
# Epoch 11/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.3729e-04
# Epoch 11: val_loss did not improve from 0.00134
# 113/113 [==============================] - 3s 22ms/step - loss: 5.3576e-04 - val_loss: 0.0019
# Epoch 12/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2387e-04
# Epoch 12: val_loss did not improve from 0.00134
# 113/113 [==============================] - 2s 18ms/step - loss: 5.2474e-04 - val_loss: 0.0021
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 5.4255e-04
# Epoch 13: val_loss did not improve from 0.00134
# 113/113 [==============================] - 2s 18ms/step - loss: 5.4255e-04 - val_loss: 0.0017
# Epoch 14/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.1540e-04
# Epoch 14: val_loss did not improve from 0.00134
# 113/113 [==============================] - 2s 18ms/step - loss: 5.1542e-04 - val_loss: 0.0018
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8945e-04
# Epoch 15: val_loss did not improve from 0.00134
# 113/113 [==============================] - 2s 17ms/step - loss: 4.8945e-04 - val_loss: 0.0019
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1424.6270569632427
# [3715.708402042744, 2763.641573042212, 1310.7562399943033, 1424.6270569632427]

# %%
print(predict)
# Out:
# [array([[57436.164]], dtype=float32), array([[58429.156]], dtype=float32), array([[59473.055]], dtype=float32), array([[57809.39]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

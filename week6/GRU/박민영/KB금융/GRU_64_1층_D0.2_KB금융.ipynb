# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0386
# Epoch 1: val_loss improved from inf to 0.00330, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 28ms/step - loss: 0.0366 - val_loss: 0.0033
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0133
# Epoch 2: val_loss improved from 0.00330 to 0.00200, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0134 - val_loss: 0.0020
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0081
# Epoch 3: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0052
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 4: val_loss did not improve from 0.00200
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 5: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0045
# Epoch 6: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0085
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 7: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0070
# Epoch 8/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0046
# Epoch 8: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0045
# Epoch 9: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0044
# Epoch 10: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 11/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0042
# Epoch 11: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss did not improve from 0.00200
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0053
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4270.873658986808
# [4270.873658986808]
# Epoch 1/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0724
# Epoch 1: val_loss improved from inf to 0.00328, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 4s 22ms/step - loss: 0.0706 - val_loss: 0.0033
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0123
# Epoch 2: val_loss improved from 0.00328 to 0.00162, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0123 - val_loss: 0.0016
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 3: val_loss improved from 0.00162 to 0.00101, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 4/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 4: val_loss did not improve from 0.00101
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0052 - val_loss: 0.0012
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 5: val_loss improved from 0.00101 to 0.00084, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 8.4200e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 6: val_loss did not improve from 0.00084
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 7: val_loss did not improve from 0.00084
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0045 - val_loss: 0.0010
# Epoch 8/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 8: val_loss improved from 0.00084 to 0.00050, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 4.9539e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 9: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 10/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 10: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 9.3997e-04
# Epoch 11/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 11: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 5.0106e-04
# Epoch 12/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 12: val_loss did not improve from 0.00050
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 6.4240e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 13: val_loss improved from 0.00050 to 0.00042, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 4.1641e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 14: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 9.0246e-04
# Epoch 15/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 15: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 16/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 16: val_loss did not improve from 0.00042
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0034 - val_loss: 6.0193e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss improved from 0.00042 to 0.00037, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0033 - val_loss: 3.7456e-04
# Epoch 18/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 18: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 5.3044e-04
# Epoch 19/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 19: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0034 - val_loss: 4.0529e-04
# Epoch 20/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 20: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0030 - val_loss: 4.3242e-04
# Epoch 21/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 21: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 22/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 22: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0028 - val_loss: 9.7589e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 23: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0025 - val_loss: 4.0009e-04
# Epoch 24/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 24: val_loss improved from 0.00037 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0025 - val_loss: 3.6460e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 25: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0026 - val_loss: 3.6923e-04
# Epoch 26/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 26: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0028 - val_loss: 4.8687e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 27: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 28/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 28: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0024 - val_loss: 5.5109e-04
# Epoch 29/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 29: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 4.0259e-04
# Epoch 30/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 30: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0021 - val_loss: 3.6778e-04
# Epoch 31/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 31: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 5.4706e-04
# Epoch 32/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 32: val_loss improved from 0.00036 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0019 - val_loss: 3.4551e-04
# Epoch 33/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 33: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 4.0211e-04
# Epoch 34/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 34: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0022 - val_loss: 4.0361e-04
# Epoch 35/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 35: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0019 - val_loss: 6.4143e-04
# Epoch 36/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 36: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 37/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 37: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 5.7750e-04
# Epoch 38/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 38: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0020 - val_loss: 4.4246e-04
# Epoch 39/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 39: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 8.5433e-04
# Epoch 40/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 40: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 3.8571e-04
# Epoch 41/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 41: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 5.2113e-04
# Epoch 42/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 42: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 5.2921e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1900.9205299388352
# [4270.873658986808, 1900.9205299388352]
# Epoch 1/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 1: val_loss improved from inf to 0.00213, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 16ms/step - loss: 0.0084 - val_loss: 0.0021
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 2: val_loss did not improve from 0.00213
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0069
# Epoch 3/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 3: val_loss did not improve from 0.00213
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 4: val_loss did not improve from 0.00213
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 5/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 5: val_loss improved from 0.00213 to 0.00099, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 9.8602e-04
# Epoch 6/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 6: val_loss did not improve from 0.00099
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 9.9087e-04
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 7: val_loss improved from 0.00099 to 0.00092, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 9.2030e-04
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 8: val_loss did not improve from 0.00092
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 9/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00092
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 10: val_loss improved from 0.00092 to 0.00060, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 5.9712e-04
# Epoch 11/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 12/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 13: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 6.0866e-04
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 7.4777e-04
# Epoch 17/100
# 100/104 [===========================>..] - ETA: 0s - loss: 9.9454e-04
# Epoch 17: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 18: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 9.5937e-04
# Epoch 19: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 14ms/step - loss: 9.4770e-04 - val_loss: 8.1888e-04
# Epoch 20/100
#  99/104 [===========================>..] - ETA: 0s - loss: 9.6291e-04
# Epoch 20: val_loss did not improve from 0.00060
# 104/104 [==============================] - 1s 12ms/step - loss: 9.5164e-04 - val_loss: 8.5942e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1177.8290120899528
# [4270.873658986808, 1900.9205299388352, 1177.8290120899528]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 1: val_loss improved from inf to 0.00240, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 10s 29ms/step - loss: 0.0129 - val_loss: 0.0024
# Epoch 2/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 2: val_loss improved from 0.00240 to 0.00069, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0045 - val_loss: 6.8623e-04
# Epoch 3/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 3: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 4/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 4: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0034 - val_loss: 9.6260e-04
# Epoch 5/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 5: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 6/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 6: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 7/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 7: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0026 - val_loss: 9.3717e-04
# Epoch 8/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 8: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 9: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 10/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 12: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0018 - val_loss: 7.4952e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1141.3945341149013
# [4270.873658986808, 1900.9205299388352, 1177.8290120899528, 1141.3945341149013]

# %%
print(predict)
# Out:
# [array([[54214.395]], dtype=float32), array([[61845.25]], dtype=float32), array([[60463.54]], dtype=float32), array([[59651.625]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

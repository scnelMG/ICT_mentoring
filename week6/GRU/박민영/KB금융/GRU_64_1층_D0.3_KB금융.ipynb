# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
    

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0954
# Epoch 1: val_loss improved from inf to 0.00372, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 6s 44ms/step - loss: 0.0898 - val_loss: 0.0037
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 2: val_loss did not improve from 0.00372
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0258 - val_loss: 0.0144
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 3: val_loss did not improve from 0.00372
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0143 - val_loss: 0.0043
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 4: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0114 - val_loss: 0.0072
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0089
# Epoch 5: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0087 - val_loss: 0.0058
# Epoch 6/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0080
# Epoch 6: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 7: val_loss did not improve from 0.00372
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 8/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0073
# Epoch 8: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0064
# Epoch 9: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0063 - val_loss: 0.0123
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 10: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 11: val_loss did not improve from 0.00372
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0069
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4670.038074841836
# [4670.038074841836]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0382
# Epoch 1: val_loss improved from inf to 0.00205, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 7s 35ms/step - loss: 0.0382 - val_loss: 0.0020
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 2: val_loss improved from 0.00205 to 0.00121, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0095 - val_loss: 0.0012
# Epoch 3/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0079
# Epoch 3: val_loss improved from 0.00121 to 0.00101, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0077 - val_loss: 0.0010
# Epoch 4/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0065
# Epoch 4: val_loss improved from 0.00101 to 0.00070, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 6.9557e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 5: val_loss did not improve from 0.00070
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 6/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 6: val_loss did not improve from 0.00070
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0059 - val_loss: 8.7110e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 7: val_loss improved from 0.00070 to 0.00061, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0056 - val_loss: 6.1283e-04
# Epoch 8/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 8: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 9: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 10: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 7.5414e-04
# Epoch 11/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0050
# Epoch 11: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 12/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss improved from 0.00061 to 0.00053, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 5.2658e-04
# Epoch 13/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 13: val_loss did not improve from 0.00053
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 7.6490e-04
# Epoch 14/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 14: val_loss improved from 0.00053 to 0.00048, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 4.7684e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 15: val_loss improved from 0.00048 to 0.00041, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 4.1315e-04
# Epoch 16/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 16: val_loss did not improve from 0.00041
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 6.0311e-04
# Epoch 17/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 17: val_loss improved from 0.00041 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 3.7877e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 18: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 4.8295e-04
# Epoch 19/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 19: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 20/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 7.7298e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 21: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 3.8699e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 22: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 8.0541e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 23: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 24: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0031 - val_loss: 6.3974e-04
# Epoch 25/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 25: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 4.3389e-04
# Epoch 26/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 26: val_loss improved from 0.00038 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 3.6493e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 27: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 4.1148e-04
# Epoch 28/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 28: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 5.2252e-04
# Epoch 29/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 29: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 30/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 30: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 31/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 31: val_loss improved from 0.00036 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0026 - val_loss: 3.5128e-04
# Epoch 32/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 32: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 3.7346e-04
# Epoch 33/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 33: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 9.6029e-04
# Epoch 34/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 34: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0021 - val_loss: 3.8679e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 35: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0021 - val_loss: 4.7667e-04
# Epoch 36/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 36: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 5.0901e-04
# Epoch 37/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 37: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0020 - val_loss: 6.5894e-04
# Epoch 38/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 38: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 7.5992e-04
# Epoch 39/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 39: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0025 - val_loss: 3.6237e-04
# Epoch 40/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 40: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0021 - val_loss: 4.6496e-04
# Epoch 41/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 41: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0025 - val_loss: 6.3389e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:2523.9001782604987
# [4670.038074841836, 2523.9001782604987]
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0309
# Epoch 1: val_loss improved from inf to 0.00516, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 18ms/step - loss: 0.0307 - val_loss: 0.0052
# Epoch 2/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 2: val_loss improved from 0.00516 to 0.00105, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 3: val_loss improved from 0.00105 to 0.00099, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 9.9465e-04
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 4: val_loss improved from 0.00099 to 0.00091, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 9.0512e-04
# Epoch 5/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 5: val_loss did not improve from 0.00091
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 6: val_loss did not improve from 0.00091
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0038 - val_loss: 9.6041e-04
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 7: val_loss improved from 0.00091 to 0.00079, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0034 - val_loss: 7.8974e-04
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 8: val_loss did not improve from 0.00079
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 9/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 9: val_loss did not improve from 0.00079
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 10/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 10: val_loss did not improve from 0.00079
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 11: val_loss did not improve from 0.00079
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 12/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 12: val_loss improved from 0.00079 to 0.00068, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0024 - val_loss: 6.7590e-04
# Epoch 13/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 13: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 7.2639e-04
# Epoch 14/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 14: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 7.0807e-04
# Epoch 16/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 16: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 7.2669e-04
# Epoch 17/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 17: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 18/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 18: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 6.9118e-04
# Epoch 19/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 19: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 8.0557e-04
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 20: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 21: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 22: val_loss did not improve from 0.00068
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 9.0903e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1285.3060380528218
# [4670.038074841836, 2523.9001782604987, 1285.3060380528218]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0121
# Epoch 1: val_loss improved from inf to 0.00564, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 19ms/step - loss: 0.0120 - val_loss: 0.0056
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 2: val_loss did not improve from 0.00564
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 3/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 3: val_loss did not improve from 0.00564
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0044 - val_loss: 0.0082
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 4: val_loss improved from 0.00564 to 0.00284, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 5/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 5: val_loss improved from 0.00284 to 0.00221, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 6/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 6: val_loss did not improve from 0.00221
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0034 - val_loss: 0.0046
# Epoch 7/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 7: val_loss did not improve from 0.00221
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 8: val_loss improved from 0.00221 to 0.00143, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 9: val_loss improved from 0.00143 to 0.00141, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss did not improve from 0.00141
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 11: val_loss did not improve from 0.00141
# 113/113 [==============================] - 2s 20ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 12/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 12: val_loss did not improve from 0.00141
# 113/113 [==============================] - 2s 18ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 13/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 13: val_loss did not improve from 0.00141
# 113/113 [==============================] - 2s 17ms/step - loss: 0.0022 - val_loss: 0.0060
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 14: val_loss improved from 0.00141 to 0.00098, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 9.8463e-04
# Epoch 15/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 15: val_loss did not improve from 0.00098
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 16/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 16: val_loss did not improve from 0.00098
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0049
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 17: val_loss did not improve from 0.00098
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0018 - val_loss: 0.0056
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 18: val_loss did not improve from 0.00098
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 19: val_loss did not improve from 0.00098
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 20/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 20: val_loss improved from 0.00098 to 0.00057, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0018 - val_loss: 5.6668e-04
# Epoch 21/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 21: val_loss did not improve from 0.00057
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 22/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 22: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 23/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 23: val_loss did not improve from 0.00057
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 24/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 24: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 25: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 26/100
# 108/113 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 26: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 27/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 27: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 0.0047
# Epoch 28/100
# 109/113 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 28: val_loss did not improve from 0.00057
# 113/113 [==============================] - 1s 13ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 29/100
# 110/113 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss did not improve from 0.00057
# 113/113 [==============================] - 2s 13ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 30/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 30: val_loss did not improve from 0.00057
# 113/113 [==============================] - 2s 14ms/step - loss: 0.0015 - val_loss: 0.0028
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1856.6672343815667
# [4670.038074841836, 2523.9001782604987, 1285.3060380528218, 1856.6672343815667]

# %%
print(predict)
# Out:
# [array([[56402.43]], dtype=float32), array([[57674.957]], dtype=float32), array([[60486.797]], dtype=float32), array([[57575.477]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

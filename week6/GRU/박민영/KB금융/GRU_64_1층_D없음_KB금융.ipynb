# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 1: val_loss improved from inf to 0.02348, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 9s 46ms/step - loss: 0.0144 - val_loss: 0.0235
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 2: val_loss improved from 0.02348 to 0.01547, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - val_loss: 0.0155
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 3: val_loss did not improve from 0.01547
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0160
# Epoch 4/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0010
# Epoch 4: val_loss improved from 0.01547 to 0.01027, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0103
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.7264e-04
# Epoch 5: val_loss did not improve from 0.01027
# 34/34 [==============================] - 1s 15ms/step - loss: 8.5729e-04 - val_loss: 0.0104
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1957e-04
# Epoch 6: val_loss improved from 0.01027 to 0.00839, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 7.1704e-04 - val_loss: 0.0084
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.6672e-04
# Epoch 7: val_loss improved from 0.00839 to 0.00758, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 6.5769e-04 - val_loss: 0.0076
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.2467e-04
# Epoch 8: val_loss did not improve from 0.00758
# 34/34 [==============================] - 0s 14ms/step - loss: 6.5743e-04 - val_loss: 0.0084
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 6.0672e-04
# Epoch 9: val_loss improved from 0.00758 to 0.00621, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 6.0672e-04 - val_loss: 0.0062
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.7764e-04
# Epoch 10: val_loss did not improve from 0.00621
# 34/34 [==============================] - 0s 13ms/step - loss: 5.8483e-04 - val_loss: 0.0069
# Epoch 11/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.3897e-04
# Epoch 11: val_loss did not improve from 0.00621
# 34/34 [==============================] - 0s 12ms/step - loss: 5.4961e-04 - val_loss: 0.0073
# Epoch 12/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.2637e-04
# Epoch 12: val_loss improved from 0.00621 to 0.00394, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 5.3256e-04 - val_loss: 0.0039
# Epoch 13/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.8182e-04
# Epoch 13: val_loss did not improve from 0.00394
# 34/34 [==============================] - 0s 12ms/step - loss: 5.5456e-04 - val_loss: 0.0051
# Epoch 14/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.7788e-04
# Epoch 14: val_loss did not improve from 0.00394
# 34/34 [==============================] - 0s 12ms/step - loss: 4.7648e-04 - val_loss: 0.0055
# Epoch 15/100
# 28/34 [=======================>......] - ETA: 0s - loss: 4.6943e-04
# Epoch 15: val_loss improved from 0.00394 to 0.00374, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 5.1615e-04 - val_loss: 0.0037
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6183e-04
# Epoch 16: val_loss did not improve from 0.00374
# 34/34 [==============================] - 0s 11ms/step - loss: 4.6183e-04 - val_loss: 0.0047
# Epoch 17/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.4631e-04
# Epoch 17: val_loss improved from 0.00374 to 0.00272, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 15ms/step - loss: 4.6681e-04 - val_loss: 0.0027
# Epoch 18/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.8276e-04
# Epoch 18: val_loss did not improve from 0.00272
# 34/34 [==============================] - 0s 14ms/step - loss: 5.9511e-04 - val_loss: 0.0042
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.2584e-04
# Epoch 19: val_loss did not improve from 0.00272
# 34/34 [==============================] - 0s 11ms/step - loss: 4.3813e-04 - val_loss: 0.0033
# Epoch 20/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.9357e-04
# Epoch 20: val_loss did not improve from 0.00272
# 34/34 [==============================] - 0s 11ms/step - loss: 6.8911e-04 - val_loss: 0.0063
# Epoch 21/100
# 30/34 [=========================>....] - ETA: 0s - loss: 5.3421e-04
# Epoch 21: val_loss improved from 0.00272 to 0.00257, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 5.2621e-04 - val_loss: 0.0026
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.3221e-04
# Epoch 22: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3307e-04 - val_loss: 0.0030
# Epoch 23/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.0667e-04
# Epoch 23: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 11ms/step - loss: 4.0362e-04 - val_loss: 0.0032
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1226e-04
# Epoch 24: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 13ms/step - loss: 4.1226e-04 - val_loss: 0.0028
# Epoch 25/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.1935e-04
# Epoch 25: val_loss did not improve from 0.00257
# 34/34 [==============================] - 0s 13ms/step - loss: 4.4558e-04 - val_loss: 0.0043
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3400e-04
# Epoch 26: val_loss improved from 0.00257 to 0.00206, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 5.3274e-04 - val_loss: 0.0021
# Epoch 27/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.1141e-04
# Epoch 27: val_loss did not improve from 0.00206
# 34/34 [==============================] - 0s 12ms/step - loss: 4.8994e-04 - val_loss: 0.0043
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8462e-04
# Epoch 28: val_loss improved from 0.00206 to 0.00195, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 3.8886e-04 - val_loss: 0.0019
# Epoch 29/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.6473e-04
# Epoch 29: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 12ms/step - loss: 3.8093e-04 - val_loss: 0.0028
# Epoch 30/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.7596e-04
# Epoch 30: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 13ms/step - loss: 3.8574e-04 - val_loss: 0.0032
# Epoch 31/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7635e-04
# Epoch 31: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 11ms/step - loss: 3.8006e-04 - val_loss: 0.0029
# Epoch 32/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.3318e-04
# Epoch 32: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 12ms/step - loss: 3.4159e-04 - val_loss: 0.0035
# Epoch 33/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.8698e-04
# Epoch 33: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 14ms/step - loss: 3.8265e-04 - val_loss: 0.0028
# Epoch 34/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1513e-04
# Epoch 34: val_loss did not improve from 0.00195
# 34/34 [==============================] - 0s 11ms/step - loss: 4.1668e-04 - val_loss: 0.0021
# Epoch 35/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.6677e-04
# Epoch 35: val_loss improved from 0.00195 to 0.00172, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 4.6901e-04 - val_loss: 0.0017
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6167e-04
# Epoch 36: val_loss did not improve from 0.00172
# 34/34 [==============================] - 1s 17ms/step - loss: 4.6167e-04 - val_loss: 0.0019
# Epoch 37/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6293e-04
# Epoch 37: val_loss did not improve from 0.00172
# 34/34 [==============================] - 1s 15ms/step - loss: 3.6773e-04 - val_loss: 0.0025
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0840e-04
# Epoch 38: val_loss did not improve from 0.00172
# 34/34 [==============================] - 1s 15ms/step - loss: 4.0840e-04 - val_loss: 0.0027
# Epoch 39/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.5091e-04
# Epoch 39: val_loss did not improve from 0.00172
# 34/34 [==============================] - 0s 13ms/step - loss: 4.3805e-04 - val_loss: 0.0024
# Epoch 40/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.4872e-04
# Epoch 40: val_loss did not improve from 0.00172
# 34/34 [==============================] - 0s 11ms/step - loss: 4.4247e-04 - val_loss: 0.0023
# Epoch 41/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.5217e-04
# Epoch 41: val_loss did not improve from 0.00172
# 34/34 [==============================] - 0s 12ms/step - loss: 3.6701e-04 - val_loss: 0.0028
# Epoch 42/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.5191e-04
# Epoch 42: val_loss did not improve from 0.00172
# 34/34 [==============================] - 0s 13ms/step - loss: 5.5482e-04 - val_loss: 0.0023
# Epoch 43/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1439e-04
# Epoch 43: val_loss did not improve from 0.00172
# 34/34 [==============================] - 1s 17ms/step - loss: 4.1439e-04 - val_loss: 0.0026
# Epoch 44/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6003e-04
# Epoch 44: val_loss improved from 0.00172 to 0.00166, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 3.5389e-04 - val_loss: 0.0017
# Epoch 45/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3099e-04
# Epoch 45: val_loss did not improve from 0.00166
# 34/34 [==============================] - 1s 16ms/step - loss: 3.5346e-04 - val_loss: 0.0028
# Epoch 46/100
# 34/34 [==============================] - ETA: 0s - loss: 3.6530e-04
# Epoch 46: val_loss did not improve from 0.00166
# 34/34 [==============================] - 0s 13ms/step - loss: 3.6530e-04 - val_loss: 0.0025
# Epoch 47/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.2048e-04
# Epoch 47: val_loss did not improve from 0.00166
# 34/34 [==============================] - 0s 13ms/step - loss: 4.1543e-04 - val_loss: 0.0018
# Epoch 48/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.3956e-04
# Epoch 48: val_loss improved from 0.00166 to 0.00085, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 4.8282e-04 - val_loss: 8.4588e-04
# Epoch 49/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.7515e-04
# Epoch 49: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 16ms/step - loss: 4.6036e-04 - val_loss: 0.0016
# Epoch 50/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.2623e-04
# Epoch 50: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 15ms/step - loss: 4.0832e-04 - val_loss: 0.0034
# Epoch 51/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6042e-04
# Epoch 51: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 17ms/step - loss: 3.6707e-04 - val_loss: 0.0033
# Epoch 52/100
# 34/34 [==============================] - ETA: 0s - loss: 4.8120e-04
# Epoch 52: val_loss did not improve from 0.00085
# 34/34 [==============================] - 0s 14ms/step - loss: 4.8120e-04 - val_loss: 0.0049
# Epoch 53/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.9898e-04
# Epoch 53: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 15ms/step - loss: 5.8965e-04 - val_loss: 0.0039
# Epoch 54/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0008e-04
# Epoch 54: val_loss did not improve from 0.00085
# 34/34 [==============================] - 0s 15ms/step - loss: 4.0235e-04 - val_loss: 0.0025
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.9037e-04
# Epoch 55: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 17ms/step - loss: 3.9549e-04 - val_loss: 0.0030
# Epoch 56/100
# 34/34 [==============================] - ETA: 0s - loss: 3.8548e-04
# Epoch 56: val_loss did not improve from 0.00085
# 34/34 [==============================] - 1s 17ms/step - loss: 3.8548e-04 - val_loss: 0.0021
# Epoch 57/100
# 34/34 [==============================] - ETA: 0s - loss: 3.7104e-04
# Epoch 57: val_loss did not improve from 0.00085
# 34/34 [==============================] - 0s 13ms/step - loss: 3.7104e-04 - val_loss: 0.0029
# Epoch 58/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8048e-04
# Epoch 58: val_loss did not improve from 0.00085
# 34/34 [==============================] - 0s 15ms/step - loss: 3.7505e-04 - val_loss: 0.0011
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:1456.6576277089034
# [1456.6576277089034]
# Epoch 1/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0214
# Epoch 1: val_loss improved from inf to 0.00099, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 6s 21ms/step - loss: 0.0200 - val_loss: 9.9373e-04
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.5392e-04
# Epoch 2: val_loss improved from 0.00099 to 0.00097, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 8.5356e-04 - val_loss: 9.7455e-04
# Epoch 3/100
# 64/69 [==========================>...] - ETA: 0s - loss: 6.7174e-04
# Epoch 3: val_loss improved from 0.00097 to 0.00081, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 6.5132e-04 - val_loss: 8.0767e-04
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.4696e-04
# Epoch 4: val_loss improved from 0.00081 to 0.00059, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 5.4673e-04 - val_loss: 5.8881e-04
# Epoch 5/100
# 62/69 [=========================>....] - ETA: 0s - loss: 5.1477e-04
# Epoch 5: val_loss did not improve from 0.00059
# 69/69 [==============================] - 1s 8ms/step - loss: 5.0842e-04 - val_loss: 7.8894e-04
# Epoch 6/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.6379e-04
# Epoch 6: val_loss did not improve from 0.00059
# 69/69 [==============================] - 1s 9ms/step - loss: 4.6445e-04 - val_loss: 7.9452e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5558e-04
# Epoch 7: val_loss improved from 0.00059 to 0.00048, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 4.5558e-04 - val_loss: 4.8466e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.3427e-04
# Epoch 8: val_loss did not improve from 0.00048
# 69/69 [==============================] - 1s 12ms/step - loss: 4.2925e-04 - val_loss: 5.5621e-04
# Epoch 9/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.2422e-04
# Epoch 9: val_loss improved from 0.00048 to 0.00043, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 4.2063e-04 - val_loss: 4.2975e-04
# Epoch 10/100
# 65/69 [===========================>..] - ETA: 0s - loss: 4.0070e-04
# Epoch 10: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 4.0074e-04 - val_loss: 5.0432e-04
# Epoch 11/100
# 64/69 [==========================>...] - ETA: 0s - loss: 4.1717e-04
# Epoch 11: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 4.2421e-04 - val_loss: 4.4687e-04
# Epoch 12/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.8635e-04
# Epoch 12: val_loss improved from 0.00043 to 0.00041, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 3.8319e-04 - val_loss: 4.1398e-04
# Epoch 13/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.1608e-04
# Epoch 13: val_loss did not improve from 0.00041
# 69/69 [==============================] - 1s 13ms/step - loss: 4.1030e-04 - val_loss: 4.7089e-04
# Epoch 14/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.9213e-04
# Epoch 14: val_loss improved from 0.00041 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 3.8788e-04 - val_loss: 3.8302e-04
# Epoch 15/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.9644e-04
# Epoch 15: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 3.9929e-04 - val_loss: 4.9300e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 4.0631e-04
# Epoch 16: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 14ms/step - loss: 4.0631e-04 - val_loss: 4.9948e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 3.7374e-04
# Epoch 17: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 3.7374e-04 - val_loss: 4.0076e-04
# Epoch 18/100
# 64/69 [==========================>...] - ETA: 0s - loss: 3.6758e-04
# Epoch 18: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 12ms/step - loss: 3.6426e-04 - val_loss: 8.3067e-04
# Epoch 19/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.9680e-04
# Epoch 19: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 3.9276e-04 - val_loss: 4.7438e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9036e-04
# Epoch 20: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 3.9036e-04 - val_loss: 4.6724e-04
# Epoch 21/100
# 64/69 [==========================>...] - ETA: 0s - loss: 3.4661e-04
# Epoch 21: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 12ms/step - loss: 3.5208e-04 - val_loss: 5.3074e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3091e-04
# Epoch 22: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 4.3091e-04 - val_loss: 3.8770e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1800e-04
# Epoch 23: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 13ms/step - loss: 4.1800e-04 - val_loss: 4.3043e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 4.6655e-04
# Epoch 24: val_loss improved from 0.00038 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 4.6655e-04 - val_loss: 3.5998e-04
# Epoch 25/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.4821e-04
# Epoch 25: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 12ms/step - loss: 3.5634e-04 - val_loss: 5.3180e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6336e-04
# Epoch 26: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 14ms/step - loss: 3.6336e-04 - val_loss: 4.1232e-04
# Epoch 27/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.1409e-04
# Epoch 27: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 14ms/step - loss: 4.1819e-04 - val_loss: 3.9382e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6258e-04
# Epoch 28: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 3.6258e-04 - val_loss: 5.7444e-04
# Epoch 29/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.7033e-04
# Epoch 29: val_loss improved from 0.00036 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 3.6299e-04 - val_loss: 3.5621e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 4.5109e-04
# Epoch 30: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 16ms/step - loss: 4.5109e-04 - val_loss: 4.7773e-04
# Epoch 31/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.1544e-04
# Epoch 31: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 15ms/step - loss: 4.1457e-04 - val_loss: 4.3658e-04
# Epoch 32/100
# 66/69 [===========================>..] - ETA: 0s - loss: 4.1324e-04
# Epoch 32: val_loss did not improve from 0.00036
# 69/69 [==============================] - 1s 14ms/step - loss: 4.1498e-04 - val_loss: 5.2886e-04
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 3.9073e-04
# Epoch 33: val_loss improved from 0.00036 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 3.9073e-04 - val_loss: 3.4606e-04
# Epoch 34/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.6071e-04
# Epoch 34: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 14ms/step - loss: 3.6171e-04 - val_loss: 3.7100e-04
# Epoch 35/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.6305e-04
# Epoch 35: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 3.6113e-04 - val_loss: 4.4308e-04
# Epoch 36/100
# 69/69 [==============================] - ETA: 0s - loss: 3.6593e-04
# Epoch 36: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 3.6593e-04 - val_loss: 5.0406e-04
# Epoch 37/100
# 67/69 [============================>.] - ETA: 0s - loss: 4.0535e-04
# Epoch 37: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 4.0212e-04 - val_loss: 3.7129e-04
# Epoch 38/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.8072e-04
# Epoch 38: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 3.8812e-04 - val_loss: 3.6923e-04
# Epoch 39/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.3828e-04
# Epoch 39: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 3.3880e-04 - val_loss: 5.0344e-04
# Epoch 40/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.6132e-04
# Epoch 40: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 3.6274e-04 - val_loss: 3.6679e-04
# Epoch 41/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.7314e-04
# Epoch 41: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 3.7358e-04 - val_loss: 5.5423e-04
# Epoch 42/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9005e-04
# Epoch 42: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 3.9139e-04 - val_loss: 3.8702e-04
# Epoch 43/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0360e-04
# Epoch 43: val_loss improved from 0.00035 to 0.00034, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 4.0291e-04 - val_loss: 3.3792e-04
# Epoch 44/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.5096e-04
# Epoch 44: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 10ms/step - loss: 3.5139e-04 - val_loss: 3.4404e-04
# Epoch 45/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.5495e-04
# Epoch 45: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 12ms/step - loss: 3.5476e-04 - val_loss: 4.9998e-04
# Epoch 46/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.8958e-04
# Epoch 46: val_loss did not improve from 0.00034
# 69/69 [==============================] - 1s 12ms/step - loss: 3.8236e-04 - val_loss: 3.7331e-04
# Epoch 47/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.3793e-04
# Epoch 47: val_loss improved from 0.00034 to 0.00033, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 3.3659e-04 - val_loss: 3.3038e-04
# Epoch 48/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.2551e-04
# Epoch 48: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.2296e-04 - val_loss: 3.5952e-04
# Epoch 49/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9626e-04
# Epoch 49: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 11ms/step - loss: 4.0739e-04 - val_loss: 4.0264e-04
# Epoch 50/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.3356e-04
# Epoch 50: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 4.2986e-04 - val_loss: 6.5724e-04
# Epoch 51/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.6419e-04
# Epoch 51: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 11ms/step - loss: 3.6421e-04 - val_loss: 3.5672e-04
# Epoch 52/100
# 64/69 [==========================>...] - ETA: 0s - loss: 3.5120e-04
# Epoch 52: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.5366e-04 - val_loss: 3.7868e-04
# Epoch 53/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.1257e-04
# Epoch 53: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.1955e-04 - val_loss: 4.7873e-04
# Epoch 54/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.5468e-04
# Epoch 54: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.5171e-04 - val_loss: 6.4221e-04
# Epoch 55/100
# 63/69 [==========================>...] - ETA: 0s - loss: 4.3576e-04
# Epoch 55: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 11ms/step - loss: 4.2197e-04 - val_loss: 3.5389e-04
# Epoch 56/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.6936e-04
# Epoch 56: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.7190e-04 - val_loss: 4.7668e-04
# Epoch 57/100
# 65/69 [===========================>..] - ETA: 0s - loss: 3.8347e-04
# Epoch 57: val_loss did not improve from 0.00033
# 69/69 [==============================] - 1s 10ms/step - loss: 3.8276e-04 - val_loss: 3.3639e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1425.303896223415
# [1456.6576277089034, 1425.303896223415]
# Epoch 1/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 1: val_loss improved from inf to 0.00400, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 14ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.0661e-04
# Epoch 2: val_loss improved from 0.00400 to 0.00162, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 7.0959e-04 - val_loss: 0.0016
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.4167e-04
# Epoch 3: val_loss did not improve from 0.00162
# 104/104 [==============================] - 1s 10ms/step - loss: 5.3914e-04 - val_loss: 0.0023
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 4.6215e-04
# Epoch 4: val_loss improved from 0.00162 to 0.00092, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 4.6215e-04 - val_loss: 9.1672e-04
# Epoch 5/100
#  98/104 [===========================>..] - ETA: 0s - loss: 4.3865e-04
# Epoch 5: val_loss did not improve from 0.00092
# 104/104 [==============================] - 1s 10ms/step - loss: 4.4349e-04 - val_loss: 0.0023
# Epoch 6/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.1278e-04
# Epoch 6: val_loss improved from 0.00092 to 0.00074, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 4.1596e-04 - val_loss: 7.3778e-04
# Epoch 7/100
#  99/104 [===========================>..] - ETA: 0s - loss: 4.5313e-04
# Epoch 7: val_loss did not improve from 0.00074
# 104/104 [==============================] - 1s 7ms/step - loss: 4.5026e-04 - val_loss: 7.7320e-04
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2431e-04
# Epoch 8: val_loss improved from 0.00074 to 0.00066, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 7ms/step - loss: 4.2431e-04 - val_loss: 6.5809e-04
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0408e-04
# Epoch 9: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 8ms/step - loss: 4.0132e-04 - val_loss: 6.8829e-04
# Epoch 10/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.8617e-04
# Epoch 10: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 8ms/step - loss: 3.8339e-04 - val_loss: 8.1531e-04
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.4565e-04
# Epoch 11: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 8ms/step - loss: 4.4473e-04 - val_loss: 7.0320e-04
# Epoch 12/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.7339e-04
# Epoch 12: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 8ms/step - loss: 3.7268e-04 - val_loss: 7.4565e-04
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6625e-04
# Epoch 13: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 10ms/step - loss: 3.6625e-04 - val_loss: 9.4614e-04
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.6455e-04
# Epoch 14: val_loss did not improve from 0.00066
# 104/104 [==============================] - 1s 9ms/step - loss: 4.6389e-04 - val_loss: 6.7833e-04
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.4753e-04
# Epoch 15: val_loss improved from 0.00066 to 0.00064, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 4.4494e-04 - val_loss: 6.4097e-04
# Epoch 16/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.8127e-04
# Epoch 16: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 12ms/step - loss: 3.8645e-04 - val_loss: 7.1251e-04
# Epoch 17/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.6724e-04
# Epoch 17: val_loss improved from 0.00064 to 0.00061, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 3.6604e-04 - val_loss: 6.0733e-04
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.8068e-04
# Epoch 18: val_loss improved from 0.00061 to 0.00057, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 3.8319e-04 - val_loss: 5.7194e-04
# Epoch 19/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.7520e-04
# Epoch 19: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 10ms/step - loss: 3.7385e-04 - val_loss: 0.0019
# Epoch 20/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.1503e-04
# Epoch 20: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 9ms/step - loss: 4.1170e-04 - val_loss: 7.4661e-04
# Epoch 21/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.5881e-04
# Epoch 21: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 9ms/step - loss: 3.5796e-04 - val_loss: 9.5320e-04
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6803e-04
# Epoch 22: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 9ms/step - loss: 3.6803e-04 - val_loss: 7.1711e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4215e-04
# Epoch 23: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 9ms/step - loss: 3.4100e-04 - val_loss: 8.6774e-04
# Epoch 24/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.3026e-04
# Epoch 24: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 11ms/step - loss: 3.3072e-04 - val_loss: 5.8068e-04
# Epoch 25/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.1960e-04
# Epoch 25: val_loss improved from 0.00057 to 0.00057, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 4.1667e-04 - val_loss: 5.7058e-04
# Epoch 26/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.6154e-04
# Epoch 26: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 14ms/step - loss: 3.6036e-04 - val_loss: 7.9692e-04
# Epoch 27/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.5710e-04
# Epoch 27: val_loss did not improve from 0.00057
# 104/104 [==============================] - 1s 14ms/step - loss: 3.5634e-04 - val_loss: 0.0010
# Epoch 28/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6423e-04
# Epoch 28: val_loss improved from 0.00057 to 0.00056, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 3.6410e-04 - val_loss: 5.5502e-04
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7523e-04
# Epoch 29: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 3.7523e-04 - val_loss: 0.0022
# Epoch 30/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6377e-04
# Epoch 30: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 13ms/step - loss: 3.6437e-04 - val_loss: 8.7252e-04
# Epoch 31/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.4298e-04
# Epoch 31: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 3.4662e-04 - val_loss: 0.0011
# Epoch 32/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.7538e-04
# Epoch 32: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 3.7602e-04 - val_loss: 8.6832e-04
# Epoch 33/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7072e-04
# Epoch 33: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 12ms/step - loss: 3.7124e-04 - val_loss: 0.0010
# Epoch 34/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.4038e-04
# Epoch 34: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 3.4733e-04 - val_loss: 8.5515e-04
# Epoch 35/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4260e-04
# Epoch 35: val_loss did not improve from 0.00056
# 104/104 [==============================] - 2s 15ms/step - loss: 3.4034e-04 - val_loss: 7.0470e-04
# Epoch 36/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5383e-04
# Epoch 36: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 3.5380e-04 - val_loss: 0.0013
# Epoch 37/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.3968e-04
# Epoch 37: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 8ms/step - loss: 3.4315e-04 - val_loss: 8.9370e-04
# Epoch 38/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.4447e-04
# Epoch 38: val_loss improved from 0.00056 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 3.4187e-04 - val_loss: 5.2730e-04
# Epoch 39/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.7803e-04
# Epoch 39: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 8ms/step - loss: 3.7912e-04 - val_loss: 6.6638e-04
# Epoch 40/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.3222e-04
# Epoch 40: val_loss did not improve from 0.00053
# 104/104 [==============================] - 1s 7ms/step - loss: 3.3102e-04 - val_loss: 7.8869e-04
# Epoch 41/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.1293e-04
# Epoch 41: val_loss improved from 0.00053 to 0.00052, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 8ms/step - loss: 4.1294e-04 - val_loss: 5.2267e-04
# Epoch 42/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6580e-04
# Epoch 42: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 7ms/step - loss: 3.6580e-04 - val_loss: 5.2979e-04
# Epoch 43/100
# 104/104 [==============================] - ETA: 0s - loss: 3.2797e-04
# Epoch 43: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 7ms/step - loss: 3.2797e-04 - val_loss: 0.0019
# Epoch 44/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1116e-04
# Epoch 44: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 10ms/step - loss: 4.0967e-04 - val_loss: 0.0015
# Epoch 45/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7055e-04
# Epoch 45: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 12ms/step - loss: 3.6991e-04 - val_loss: 6.4535e-04
# Epoch 46/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.8333e-04
# Epoch 46: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 9ms/step - loss: 3.8002e-04 - val_loss: 8.5837e-04
# Epoch 47/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.1176e-04
# Epoch 47: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 12ms/step - loss: 3.1167e-04 - val_loss: 7.6665e-04
# Epoch 48/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.3324e-04
# Epoch 48: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 12ms/step - loss: 3.3417e-04 - val_loss: 5.7492e-04
# Epoch 49/100
# 104/104 [==============================] - ETA: 0s - loss: 3.1431e-04
# Epoch 49: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 14ms/step - loss: 3.1431e-04 - val_loss: 5.5585e-04
# Epoch 50/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.2217e-04
# Epoch 50: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 10ms/step - loss: 3.2032e-04 - val_loss: 7.6435e-04
# Epoch 51/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.3180e-04
# Epoch 51: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 10ms/step - loss: 3.3457e-04 - val_loss: 0.0010
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1137.3182882630833
# [1456.6576277089034, 1425.303896223415, 1137.3182882630833]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 1: val_loss improved from inf to 0.00323, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 24ms/step - loss: 0.0377 - val_loss: 0.0032
# Epoch 2/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 2: val_loss improved from 0.00323 to 0.00103, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 22ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 3/100
# 113/113 [==============================] - ETA: 0s - loss: 9.3867e-04
# Epoch 3: val_loss improved from 0.00103 to 0.00099, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 3s 25ms/step - loss: 9.3867e-04 - val_loss: 9.9061e-04
# Epoch 4/100
# 112/113 [============================>.] - ETA: 0s - loss: 7.7257e-04
# Epoch 4: val_loss did not improve from 0.00099
# 113/113 [==============================] - 2s 16ms/step - loss: 7.7481e-04 - val_loss: 0.0013
# Epoch 5/100
# 110/113 [============================>.] - ETA: 0s - loss: 6.5166e-04
# Epoch 5: val_loss did not improve from 0.00099
# 113/113 [==============================] - 2s 14ms/step - loss: 6.5095e-04 - val_loss: 0.0012
# Epoch 6/100
# 110/113 [============================>.] - ETA: 0s - loss: 6.8517e-04
# Epoch 6: val_loss improved from 0.00099 to 0.00069, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 14ms/step - loss: 6.8110e-04 - val_loss: 6.9037e-04
# Epoch 7/100
# 110/113 [============================>.] - ETA: 0s - loss: 5.5323e-04
# Epoch 7: val_loss did not improve from 0.00069
# 113/113 [==============================] - 2s 20ms/step - loss: 5.5373e-04 - val_loss: 7.3867e-04
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.3402e-04
# Epoch 8: val_loss improved from 0.00069 to 0.00064, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 5.3402e-04 - val_loss: 6.3707e-04
# Epoch 9/100
# 110/113 [============================>.] - ETA: 0s - loss: 5.4661e-04
# Epoch 9: val_loss improved from 0.00064 to 0.00054, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 2s 16ms/step - loss: 5.5928e-04 - val_loss: 5.4357e-04
# Epoch 10/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.3301e-04
# Epoch 10: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 16ms/step - loss: 5.3208e-04 - val_loss: 7.6237e-04
# Epoch 11/100
# 110/113 [============================>.] - ETA: 0s - loss: 4.8610e-04
# Epoch 11: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 16ms/step - loss: 4.8656e-04 - val_loss: 0.0011
# Epoch 12/100
# 110/113 [============================>.] - ETA: 0s - loss: 5.0499e-04
# Epoch 12: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 17ms/step - loss: 5.0158e-04 - val_loss: 0.0010
# Epoch 13/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.9873e-04
# Epoch 13: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 18ms/step - loss: 4.9470e-04 - val_loss: 0.0014
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8469e-04
# Epoch 14: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 20ms/step - loss: 4.8469e-04 - val_loss: 5.7801e-04
# Epoch 15/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.4340e-04
# Epoch 15: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 16ms/step - loss: 5.4077e-04 - val_loss: 9.9873e-04
# Epoch 16/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.9535e-04
# Epoch 16: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 17ms/step - loss: 4.9539e-04 - val_loss: 8.9407e-04
# Epoch 17/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.9897e-04
# Epoch 17: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 17ms/step - loss: 5.0152e-04 - val_loss: 0.0012
# Epoch 18/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.3408e-04
# Epoch 18: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 18ms/step - loss: 5.3438e-04 - val_loss: 9.2560e-04
# Epoch 19/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.2157e-04
# Epoch 19: val_loss did not improve from 0.00054
# 113/113 [==============================] - 2s 20ms/step - loss: 5.2206e-04 - val_loss: 0.0011
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1386.3870484799688
# [1456.6576277089034, 1425.303896223415, 1137.3182882630833, 1386.3870484799688]

# %%
print(predict)
# Out:
# [array([[58848.938]], dtype=float32), array([[60900.68]], dtype=float32), array([[59554.195]], dtype=float32), array([[58752.17]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

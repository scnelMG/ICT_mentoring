# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")

df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0711
# Epoch 1: val_loss improved from inf to 0.00261, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 10s 88ms/step - loss: 0.0711 - val_loss: 0.0026
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0099
# Epoch 2: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0097 - val_loss: 0.0029
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 3: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0055 - val_loss: 0.0027
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 4: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0047 - val_loss: 0.0029
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 5: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 6: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 7: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 8: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 9: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0029 - val_loss: 0.0068
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 10: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 11: val_loss did not improve from 0.00261
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0026 - val_loss: 0.0038
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:3663.8140612073066
# [3663.8140612073066]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0290
# Epoch 1: val_loss improved from inf to 0.00085, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 16s 51ms/step - loss: 0.0283 - val_loss: 8.5452e-04
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 2: val_loss did not improve from 0.00085
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 3: val_loss improved from 0.00085 to 0.00068, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0044 - val_loss: 6.7541e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 4: val_loss improved from 0.00068 to 0.00065, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 6.5176e-04
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 5: val_loss did not improve from 0.00065
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0028 - val_loss: 6.8656e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 6: val_loss did not improve from 0.00065
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 7/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 7: val_loss did not improve from 0.00065
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0031 - val_loss: 7.3457e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 8: val_loss did not improve from 0.00065
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0027 - val_loss: 8.7838e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 9: val_loss improved from 0.00065 to 0.00060, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0025 - val_loss: 5.9741e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 10: val_loss did not improve from 0.00060
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0026 - val_loss: 7.2040e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 11: val_loss did not improve from 0.00060
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0027 - val_loss: 6.9597e-04
# Epoch 12/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 12: val_loss did not improve from 0.00060
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 13: val_loss did not improve from 0.00060
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 14: val_loss did not improve from 0.00060
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0022 - val_loss: 6.3825e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 15: val_loss did not improve from 0.00060
# 69/69 [==============================] - 1s 21ms/step - loss: 0.0026 - val_loss: 6.4748e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 16: val_loss did not improve from 0.00060
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0023 - val_loss: 8.2052e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 17: val_loss improved from 0.00060 to 0.00057, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0022 - val_loss: 5.6680e-04
# Epoch 18/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 18: val_loss did not improve from 0.00057
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 19: val_loss improved from 0.00057 to 0.00049, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0019 - val_loss: 4.9329e-04
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 20: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 21: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0020 - val_loss: 9.7494e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 22: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0018 - val_loss: 9.5112e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 23: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0020 - val_loss: 8.3956e-04
# Epoch 24/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 24: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 25: val_loss did not improve from 0.00049
# 69/69 [==============================] - 2s 26ms/step - loss: 0.0020 - val_loss: 5.5282e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 26: val_loss improved from 0.00049 to 0.00043, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0017 - val_loss: 4.2910e-04
# Epoch 27/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 27: val_loss improved from 0.00043 to 0.00041, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 40ms/step - loss: 0.0018 - val_loss: 4.1014e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 28: val_loss improved from 0.00041 to 0.00040, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 50ms/step - loss: 0.0017 - val_loss: 4.0295e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss did not improve from 0.00040
# 69/69 [==============================] - 4s 54ms/step - loss: 0.0015 - val_loss: 5.9710e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 30: val_loss did not improve from 0.00040
# 69/69 [==============================] - 3s 50ms/step - loss: 0.0015 - val_loss: 5.3190e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 31: val_loss did not improve from 0.00040
# 69/69 [==============================] - 3s 48ms/step - loss: 0.0016 - val_loss: 4.2953e-04
# Epoch 32/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 32: val_loss improved from 0.00040 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0014 - val_loss: 3.8036e-04
# Epoch 33/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 33: val_loss did not improve from 0.00038
# 69/69 [==============================] - 3s 36ms/step - loss: 0.0015 - val_loss: 5.0113e-04
# Epoch 34/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 34: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0013 - val_loss: 4.2350e-04
# Epoch 35/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 35: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0014 - val_loss: 5.4059e-04
# Epoch 36/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 36: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0014 - val_loss: 5.0519e-04
# Epoch 37/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 37: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0016 - val_loss: 5.8021e-04
# Epoch 38/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 38: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 3.9379e-04
# Epoch 39/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 39: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0012 - val_loss: 4.7935e-04
# Epoch 40/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 40: val_loss did not improve from 0.00038
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.9425e-04
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 41: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0014 - val_loss: 6.5731e-04
# Epoch 42/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 42: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 22ms/step - loss: 0.0014 - val_loss: 8.0596e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1609.3871481586339
# [3663.8140612073066, 1609.3871481586339]
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 1: val_loss improved from inf to 0.00778, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 30s 106ms/step - loss: 0.0119 - val_loss: 0.0078
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 2: val_loss did not improve from 0.00778
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0036 - val_loss: 0.0116
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 3: val_loss improved from 0.00778 to 0.00509, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 47ms/step - loss: 0.0024 - val_loss: 0.0051
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 4: val_loss did not improve from 0.00509
# 104/104 [==============================] - 5s 47ms/step - loss: 0.0024 - val_loss: 0.0088
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 5: val_loss improved from 0.00509 to 0.00378, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 6: val_loss improved from 0.00378 to 0.00200, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 7: val_loss improved from 0.00200 to 0.00119, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 8: val_loss improved from 0.00119 to 0.00097, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0016 - val_loss: 9.6781e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 9: val_loss improved from 0.00097 to 0.00063, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0016 - val_loss: 6.3059e-04
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 10: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0017 - val_loss: 8.6428e-04
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 11: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00063
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0013 - val_loss: 9.9615e-04
# Epoch 13/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00063
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 14: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 15: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0013 - val_loss: 6.6451e-04
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 16: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 17: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 20ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 18: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 21ms/step - loss: 0.0011 - val_loss: 8.4593e-04
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 19: val_loss did not improve from 0.00063
# 104/104 [==============================] - 2s 22ms/step - loss: 0.0011 - val_loss: 0.0014
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1422.285253174443
# [3663.8140612073066, 1609.3871481586339, 1422.285253174443]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 1: val_loss improved from inf to 0.00157, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 28s 74ms/step - loss: 0.0090 - val_loss: 0.0016
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 2: val_loss improved from 0.00157 to 0.00080, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0035 - val_loss: 8.0444e-04
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 3: val_loss did not improve from 0.00080
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 4: val_loss did not improve from 0.00080
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 5/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 5: val_loss improved from 0.00080 to 0.00070, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0025 - val_loss: 6.9613e-04
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 6: val_loss did not improve from 0.00070
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 7/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 7: val_loss did not improve from 0.00070
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0021 - val_loss: 9.8188e-04
# Epoch 8/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 8: val_loss did not improve from 0.00070
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 9/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 9: val_loss did not improve from 0.00070
# 113/113 [==============================] - 4s 38ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 10/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 10: val_loss improved from 0.00070 to 0.00065, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0020 - val_loss: 6.5377e-04
# Epoch 11/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 11: val_loss did not improve from 0.00065
# 113/113 [==============================] - 6s 53ms/step - loss: 0.0017 - val_loss: 7.3932e-04
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 12: val_loss did not improve from 0.00065
# 113/113 [==============================] - 8s 67ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 13/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 13: val_loss improved from 0.00065 to 0.00062, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 7s 58ms/step - loss: 0.0016 - val_loss: 6.2327e-04
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 14: val_loss improved from 0.00062 to 0.00054, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 8s 74ms/step - loss: 0.0014 - val_loss: 5.3519e-04
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 15: val_loss did not improve from 0.00054
# 113/113 [==============================] - 6s 53ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 16/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.00054
# 113/113 [==============================] - 5s 48ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 17/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 17: val_loss improved from 0.00054 to 0.00051, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0014 - val_loss: 5.1302e-04
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss improved from 0.00051 to 0.00050, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.0013 - val_loss: 5.0307e-04
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 19: val_loss did not improve from 0.00050
# 113/113 [==============================] - 4s 37ms/step - loss: 0.0012 - val_loss: 9.9736e-04
# Epoch 20/100
# 111/113 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 20: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 30ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 21/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 21: val_loss improved from 0.00050 to 0.00048, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 33ms/step - loss: 0.0014 - val_loss: 4.8482e-04
# Epoch 22/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00048
# 113/113 [==============================] - 3s 30ms/step - loss: 0.0012 - val_loss: 9.5639e-04
# Epoch 23/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 23: val_loss did not improve from 0.00048
# 113/113 [==============================] - 4s 32ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 24/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 24: val_loss did not improve from 0.00048
# 113/113 [==============================] - 4s 32ms/step - loss: 0.0011 - val_loss: 4.9792e-04
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 25: val_loss did not improve from 0.00048
# 113/113 [==============================] - 4s 32ms/step - loss: 0.0011 - val_loss: 5.8259e-04
# Epoch 26/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 26: val_loss did not improve from 0.00048
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0011 - val_loss: 5.3235e-04
# Epoch 27/100
# 113/113 [==============================] - ETA: 0s - loss: 9.6440e-04
# Epoch 27: val_loss did not improve from 0.00048
# 113/113 [==============================] - 5s 41ms/step - loss: 9.6440e-04 - val_loss: 4.8646e-04
# Epoch 28/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 28: val_loss did not improve from 0.00048
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0010 - val_loss: 0.0026
# Epoch 29/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 29: val_loss did not improve from 0.00048
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0010 - val_loss: 7.5400e-04
# Epoch 30/100
# 112/113 [============================>.] - ETA: 0s - loss: 9.8863e-04
# Epoch 30: val_loss did not improve from 0.00048
# 113/113 [==============================] - 5s 44ms/step - loss: 9.8817e-04 - val_loss: 0.0015
# Epoch 31/100
# 113/113 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 31: val_loss did not improve from 0.00048
# 113/113 [==============================] - 7s 64ms/step - loss: 0.0010 - val_loss: 0.0028
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:2004.1819073477757
# [3663.8140612073066, 1609.3871481586339, 1422.285253174443, 2004.1819073477757]

# %%
print(predict)
# Out:
# [array([[56608.156]], dtype=float32), array([[59956.65]], dtype=float32), array([[58320.137]], dtype=float32), array([[57635.06]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

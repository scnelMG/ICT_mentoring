# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[금융]KB금융.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 1: val_loss improved from inf to 0.00150, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 17s 84ms/step - loss: 0.0249 - val_loss: 0.0015
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 2: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 7.4078e-04
# Epoch 3: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 32ms/step - loss: 7.4078e-04 - val_loss: 0.0033
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.9196e-04
# Epoch 4: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 30ms/step - loss: 6.8154e-04 - val_loss: 0.0026
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.3804e-04
# Epoch 5: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 32ms/step - loss: 6.2702e-04 - val_loss: 0.0031
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.4117e-04
# Epoch 6: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 31ms/step - loss: 5.2948e-04 - val_loss: 0.0040
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.9787e-04
# Epoch 7: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 28ms/step - loss: 4.9627e-04 - val_loss: 0.0039
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.0533e-04
# Epoch 8: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 36ms/step - loss: 5.0599e-04 - val_loss: 0.0028
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.0258e-04
# Epoch 9: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 24ms/step - loss: 5.1901e-04 - val_loss: 0.0040
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9803e-04
# Epoch 10: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 31ms/step - loss: 4.9110e-04 - val_loss: 0.0033
# Epoch 11/100
# 33/34 [============================>.] - ETA: 0s - loss: 5.3438e-04
# Epoch 11: val_loss did not improve from 0.00150
# 34/34 [==============================] - 1s 25ms/step - loss: 5.2889e-04 - val_loss: 0.0029
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:4136.523994271309
# [4136.523994271309]
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 1: val_loss improved from inf to 0.00062, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 21s 94ms/step - loss: 0.0022 - val_loss: 6.2201e-04
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 5.4431e-04
# Epoch 2: val_loss improved from 0.00062 to 0.00051, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 5.5266e-04 - val_loss: 5.1243e-04
# Epoch 3/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.2159e-04
# Epoch 3: val_loss did not improve from 0.00051
# 69/69 [==============================] - 2s 27ms/step - loss: 5.2340e-04 - val_loss: 5.9787e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 4.2374e-04
# Epoch 4: val_loss improved from 0.00051 to 0.00046, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 4.2374e-04 - val_loss: 4.6468e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 4.7289e-04
# Epoch 5: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 24ms/step - loss: 4.7289e-04 - val_loss: 6.3288e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.0378e-04
# Epoch 6: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 22ms/step - loss: 5.0368e-04 - val_loss: 9.2233e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.5497e-04
# Epoch 7: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 23ms/step - loss: 4.5260e-04 - val_loss: 5.3807e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 5.0353e-04
# Epoch 8: val_loss did not improve from 0.00046
# 69/69 [==============================] - 2s 24ms/step - loss: 5.0822e-04 - val_loss: 4.8280e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 5.0343e-04
# Epoch 9: val_loss improved from 0.00046 to 0.00038, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 5.0332e-04 - val_loss: 3.8374e-04
# Epoch 10/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.9151e-04
# Epoch 10: val_loss did not improve from 0.00038
# 69/69 [==============================] - 2s 26ms/step - loss: 3.8700e-04 - val_loss: 9.8885e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.0204e-04
# Epoch 11: val_loss improved from 0.00038 to 0.00034, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 3.9884e-04 - val_loss: 3.4335e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 4.6199e-04
# Epoch 12: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 27ms/step - loss: 4.6199e-04 - val_loss: 5.5704e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7462e-04
# Epoch 13: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 40ms/step - loss: 3.7539e-04 - val_loss: 4.5225e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 4.3265e-04
# Epoch 14: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 46ms/step - loss: 4.3265e-04 - val_loss: 4.0711e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 4.1785e-04
# Epoch 15: val_loss did not improve from 0.00034
# 69/69 [==============================] - 4s 58ms/step - loss: 4.1785e-04 - val_loss: 4.6206e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7896e-04
# Epoch 16: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 50ms/step - loss: 3.7921e-04 - val_loss: 3.8149e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 3.8311e-04
# Epoch 17: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 47ms/step - loss: 3.8619e-04 - val_loss: 3.9959e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.5585e-04
# Epoch 18: val_loss did not improve from 0.00034
# 69/69 [==============================] - 3s 43ms/step - loss: 3.5236e-04 - val_loss: 4.9377e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 4.7721e-04
# Epoch 19: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 35ms/step - loss: 4.7230e-04 - val_loss: 4.4765e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.7248e-04
# Epoch 20: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 25ms/step - loss: 3.7073e-04 - val_loss: 5.6386e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 3.8252e-04
# Epoch 21: val_loss did not improve from 0.00034
# 69/69 [==============================] - 2s 29ms/step - loss: 3.8252e-04 - val_loss: 4.3233e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1307.9528710932339
# [4136.523994271309, 1307.9528710932339]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 1: val_loss improved from inf to 0.00179, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 15s 43ms/step - loss: 0.0087 - val_loss: 0.0018
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 8.1175e-04
# Epoch 2: val_loss did not improve from 0.00179
# 104/104 [==============================] - 2s 22ms/step - loss: 8.0416e-04 - val_loss: 0.0037
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.8305e-04
# Epoch 3: val_loss did not improve from 0.00179
# 104/104 [==============================] - 2s 22ms/step - loss: 5.8113e-04 - val_loss: 0.0022
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.7280e-04
# Epoch 4: val_loss improved from 0.00179 to 0.00098, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 24ms/step - loss: 5.7125e-04 - val_loss: 9.7528e-04
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.2327e-04
# Epoch 5: val_loss did not improve from 0.00098
# 104/104 [==============================] - 2s 23ms/step - loss: 5.1954e-04 - val_loss: 0.0013
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.6682e-04
# Epoch 6: val_loss improved from 0.00098 to 0.00086, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 4.6517e-04 - val_loss: 8.6009e-04
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 4.3240e-04
# Epoch 7: val_loss did not improve from 0.00086
# 104/104 [==============================] - 3s 31ms/step - loss: 4.3240e-04 - val_loss: 0.0042
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.9663e-04
# Epoch 8: val_loss improved from 0.00086 to 0.00081, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 31ms/step - loss: 5.1098e-04 - val_loss: 8.0793e-04
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.4910e-04
# Epoch 9: val_loss improved from 0.00081 to 0.00056, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 5.4720e-04 - val_loss: 5.6244e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1981e-04
# Epoch 10: val_loss did not improve from 0.00056
# 104/104 [==============================] - 4s 35ms/step - loss: 4.1981e-04 - val_loss: 0.0028
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2797e-04
# Epoch 11: val_loss did not improve from 0.00056
# 104/104 [==============================] - 4s 38ms/step - loss: 4.2797e-04 - val_loss: 0.0029
# Epoch 12/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.3500e-04
# Epoch 12: val_loss improved from 0.00056 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 47ms/step - loss: 4.3101e-04 - val_loss: 5.3365e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.9717e-04
# Epoch 13: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 42ms/step - loss: 4.0120e-04 - val_loss: 0.0017
# Epoch 14/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.8215e-04
# Epoch 14: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 41ms/step - loss: 3.8069e-04 - val_loss: 0.0027
# Epoch 15/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.7992e-04
# Epoch 15: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 35ms/step - loss: 3.7770e-04 - val_loss: 0.0011
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 3.7397e-04
# Epoch 16: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 34ms/step - loss: 3.7397e-04 - val_loss: 8.8078e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 3.6434e-04
# Epoch 17: val_loss did not improve from 0.00053
# 104/104 [==============================] - 3s 33ms/step - loss: 3.6434e-04 - val_loss: 0.0019
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1719e-04
# Epoch 18: val_loss did not improve from 0.00053
# 104/104 [==============================] - 3s 33ms/step - loss: 4.1719e-04 - val_loss: 7.3670e-04
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 4.0180e-04
# Epoch 19: val_loss did not improve from 0.00053
# 104/104 [==============================] - 3s 32ms/step - loss: 4.0180e-04 - val_loss: 5.9279e-04
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.0580e-04
# Epoch 20: val_loss did not improve from 0.00053
# 104/104 [==============================] - 3s 32ms/step - loss: 4.0775e-04 - val_loss: 7.9830e-04
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1940e-04
# Epoch 21: val_loss did not improve from 0.00053
# 104/104 [==============================] - 4s 34ms/step - loss: 4.1940e-04 - val_loss: 6.2739e-04
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2940e-04
# Epoch 22: val_loss did not improve from 0.00053
# 104/104 [==============================] - 3s 33ms/step - loss: 4.2940e-04 - val_loss: 9.3597e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:1247.4618712087504
# [4136.523994271309, 1307.9528710932339, 1247.4618712087504]
# Epoch 1/100
# 112/113 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 1: val_loss improved from inf to 0.00523, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 16s 56ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 2/100
# 113/113 [==============================] - ETA: 0s - loss: 6.6310e-04
# Epoch 2: val_loss improved from 0.00523 to 0.00326, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 39ms/step - loss: 6.6310e-04 - val_loss: 0.0033
# Epoch 3/100
# 112/113 [============================>.] - ETA: 0s - loss: 7.7317e-04
# Epoch 3: val_loss improved from 0.00326 to 0.00309, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 39ms/step - loss: 7.6942e-04 - val_loss: 0.0031
# Epoch 4/100
# 113/113 [==============================] - ETA: 0s - loss: 6.2218e-04
# Epoch 4: val_loss improved from 0.00309 to 0.00273, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 46ms/step - loss: 6.2218e-04 - val_loss: 0.0027
# Epoch 5/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.4699e-04
# Epoch 5: val_loss improved from 0.00273 to 0.00176, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 44ms/step - loss: 5.4715e-04 - val_loss: 0.0018
# Epoch 6/100
# 113/113 [==============================] - ETA: 0s - loss: 6.3321e-04
# Epoch 6: val_loss did not improve from 0.00176
# 113/113 [==============================] - 4s 35ms/step - loss: 6.3321e-04 - val_loss: 0.0046
# Epoch 7/100
# 113/113 [==============================] - ETA: 0s - loss: 5.8852e-04
# Epoch 7: val_loss did not improve from 0.00176
# 113/113 [==============================] - 4s 37ms/step - loss: 5.8852e-04 - val_loss: 0.0064
# Epoch 8/100
# 113/113 [==============================] - ETA: 0s - loss: 5.5075e-04
# Epoch 8: val_loss improved from 0.00176 to 0.00150, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 44ms/step - loss: 5.5075e-04 - val_loss: 0.0015
# Epoch 9/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8812e-04
# Epoch 9: val_loss improved from 0.00150 to 0.00122, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 35ms/step - loss: 4.8812e-04 - val_loss: 0.0012
# Epoch 10/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.3241e-04
# Epoch 10: val_loss did not improve from 0.00122
# 113/113 [==============================] - 4s 35ms/step - loss: 5.2919e-04 - val_loss: 0.0023
# Epoch 11/100
# 112/113 [============================>.] - ETA: 0s - loss: 6.1264e-04
# Epoch 11: val_loss did not improve from 0.00122
# 113/113 [==============================] - 4s 35ms/step - loss: 6.1510e-04 - val_loss: 0.0026
# Epoch 12/100
# 113/113 [==============================] - ETA: 0s - loss: 5.7330e-04
# Epoch 12: val_loss did not improve from 0.00122
# 113/113 [==============================] - 4s 34ms/step - loss: 5.7330e-04 - val_loss: 0.0020
# Epoch 13/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.4526e-04
# Epoch 13: val_loss did not improve from 0.00122
# 113/113 [==============================] - 4s 37ms/step - loss: 4.4534e-04 - val_loss: 0.0018
# Epoch 14/100
# 113/113 [==============================] - ETA: 0s - loss: 5.8943e-04
# Epoch 14: val_loss did not improve from 0.00122
# 113/113 [==============================] - 4s 35ms/step - loss: 5.8943e-04 - val_loss: 0.0025
# Epoch 15/100
# 113/113 [==============================] - ETA: 0s - loss: 5.0629e-04
# Epoch 15: val_loss did not improve from 0.00122
# 113/113 [==============================] - 5s 49ms/step - loss: 5.0629e-04 - val_loss: 0.0036
# Epoch 16/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.3396e-04
# Epoch 16: val_loss improved from 0.00122 to 0.00113, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 57ms/step - loss: 5.3279e-04 - val_loss: 0.0011
# Epoch 17/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7429e-04
# Epoch 17: val_loss did not improve from 0.00113
# 113/113 [==============================] - 7s 64ms/step - loss: 4.7690e-04 - val_loss: 0.0018
# Epoch 18/100
# 113/113 [==============================] - ETA: 0s - loss: 5.3359e-04
# Epoch 18: val_loss did not improve from 0.00113
# 113/113 [==============================] - 7s 61ms/step - loss: 5.3359e-04 - val_loss: 0.0021
# Epoch 19/100
# 113/113 [==============================] - ETA: 0s - loss: 6.0438e-04
# Epoch 19: val_loss improved from 0.00113 to 0.00094, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 8s 69ms/step - loss: 6.0438e-04 - val_loss: 9.4417e-04
# Epoch 20/100
# 113/113 [==============================] - ETA: 0s - loss: 4.2446e-04
# Epoch 20: val_loss improved from 0.00094 to 0.00093, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 6s 55ms/step - loss: 4.2446e-04 - val_loss: 9.2587e-04
# Epoch 21/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5234e-04
# Epoch 21: val_loss did not improve from 0.00093
# 113/113 [==============================] - 5s 47ms/step - loss: 4.5234e-04 - val_loss: 0.0027
# Epoch 22/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5552e-04
# Epoch 22: val_loss did not improve from 0.00093
# 113/113 [==============================] - 5s 42ms/step - loss: 4.5658e-04 - val_loss: 0.0026
# Epoch 23/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.8538e-04
# Epoch 23: val_loss did not improve from 0.00093
# 113/113 [==============================] - 5s 40ms/step - loss: 4.8712e-04 - val_loss: 0.0023
# Epoch 24/100
# 111/113 [============================>.] - ETA: 0s - loss: 5.0289e-04
# Epoch 24: val_loss did not improve from 0.00093
# 113/113 [==============================] - 4s 38ms/step - loss: 4.9844e-04 - val_loss: 0.0015
# Epoch 25/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.3814e-04
# Epoch 25: val_loss did not improve from 0.00093
# 113/113 [==============================] - 3s 30ms/step - loss: 4.3769e-04 - val_loss: 0.0019
# Epoch 26/100
# 112/113 [============================>.] - ETA: 0s - loss: 5.3694e-04
# Epoch 26: val_loss did not improve from 0.00093
# 113/113 [==============================] - 3s 31ms/step - loss: 5.3817e-04 - val_loss: 0.0015
# Epoch 27/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8502e-04
# Epoch 27: val_loss did not improve from 0.00093
# 113/113 [==============================] - 3s 30ms/step - loss: 4.8502e-04 - val_loss: 0.0012
# Epoch 28/100
# 111/113 [============================>.] - ETA: 0s - loss: 4.8573e-04
# Epoch 28: val_loss did not improve from 0.00093
# 113/113 [==============================] - 4s 31ms/step - loss: 4.8798e-04 - val_loss: 0.0030
# Epoch 29/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7963e-04
# Epoch 29: val_loss did not improve from 0.00093
# 113/113 [==============================] - 4s 32ms/step - loss: 4.7817e-04 - val_loss: 0.0014
# Epoch 30/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5488e-04
# Epoch 30: val_loss improved from 0.00093 to 0.00078, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 32ms/step - loss: 4.5466e-04 - val_loss: 7.8013e-04
# Epoch 31/100
# 113/113 [==============================] - ETA: 0s - loss: 5.3299e-04
# Epoch 31: val_loss improved from 0.00078 to 0.00060, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 5s 41ms/step - loss: 5.3299e-04 - val_loss: 6.0485e-04
# Epoch 32/100
# 113/113 [==============================] - ETA: 0s - loss: 4.8759e-04
# Epoch 32: val_loss did not improve from 0.00060
# 113/113 [==============================] - 5s 41ms/step - loss: 4.8759e-04 - val_loss: 0.0029
# Epoch 33/100
# 113/113 [==============================] - ETA: 0s - loss: 5.2009e-04
# Epoch 33: val_loss did not improve from 0.00060
# 113/113 [==============================] - 4s 38ms/step - loss: 5.2009e-04 - val_loss: 8.4242e-04
# Epoch 34/100
# 113/113 [==============================] - ETA: 0s - loss: 4.4682e-04
# Epoch 34: val_loss did not improve from 0.00060
# 113/113 [==============================] - 4s 39ms/step - loss: 4.4682e-04 - val_loss: 0.0010
# Epoch 35/100
# 113/113 [==============================] - ETA: 0s - loss: 4.0045e-04
# Epoch 35: val_loss did not improve from 0.00060
# 113/113 [==============================] - 5s 44ms/step - loss: 4.0045e-04 - val_loss: 0.0016
# Epoch 36/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.1688e-04
# Epoch 36: val_loss did not improve from 0.00060
# 113/113 [==============================] - 8s 66ms/step - loss: 4.1495e-04 - val_loss: 9.0092e-04
# Epoch 37/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5084e-04
# Epoch 37: val_loss did not improve from 0.00060
# 113/113 [==============================] - 6s 54ms/step - loss: 4.5084e-04 - val_loss: 0.0017
# Epoch 38/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.2759e-04
# Epoch 38: val_loss did not improve from 0.00060
# 113/113 [==============================] - 5s 43ms/step - loss: 4.2642e-04 - val_loss: 9.9790e-04
# Epoch 39/100
# 113/113 [==============================] - ETA: 0s - loss: 4.1777e-04
# Epoch 39: val_loss did not improve from 0.00060
# 113/113 [==============================] - 4s 39ms/step - loss: 4.1777e-04 - val_loss: 0.0019
# Epoch 40/100
# 113/113 [==============================] - ETA: 0s - loss: 4.7833e-04
# Epoch 40: val_loss improved from 0.00060 to 0.00050, saving model to model\tmp_checkpoint.h5
# 113/113 [==============================] - 4s 36ms/step - loss: 4.7833e-04 - val_loss: 5.0225e-04
# Epoch 41/100
# 113/113 [==============================] - ETA: 0s - loss: 4.6932e-04
# Epoch 41: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 30ms/step - loss: 4.6932e-04 - val_loss: 6.7873e-04
# Epoch 42/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.5220e-04
# Epoch 42: val_loss did not improve from 0.00050
# 113/113 [==============================] - 4s 34ms/step - loss: 4.5258e-04 - val_loss: 0.0015
# Epoch 43/100
# 113/113 [==============================] - ETA: 0s - loss: 4.5645e-04
# Epoch 43: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 29ms/step - loss: 4.5645e-04 - val_loss: 0.0011
# Epoch 44/100
# 113/113 [==============================] - ETA: 0s - loss: 4.0942e-04
# Epoch 44: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 31ms/step - loss: 4.0942e-04 - val_loss: 0.0011
# Epoch 45/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.7130e-04
# Epoch 45: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 30ms/step - loss: 4.6922e-04 - val_loss: 0.0011
# Epoch 46/100
# 112/113 [============================>.] - ETA: 0s - loss: 4.1633e-04
# Epoch 46: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 28ms/step - loss: 4.1638e-04 - val_loss: 6.1941e-04
# Epoch 47/100
# 113/113 [==============================] - ETA: 0s - loss: 4.2148e-04
# Epoch 47: val_loss did not improve from 0.00050
# 113/113 [==============================] - 4s 32ms/step - loss: 4.2148e-04 - val_loss: 0.0013
# Epoch 48/100
# 113/113 [==============================] - ETA: 0s - loss: 4.2718e-04
# Epoch 48: val_loss did not improve from 0.00050
# 113/113 [==============================] - 3s 30ms/step - loss: 4.2718e-04 - val_loss: 0.0011
# Epoch 49/100
# 113/113 [==============================] - ETA: 0s - loss: 4.1928e-04
# Epoch 49: val_loss did not improve from 0.00050
# 113/113 [==============================] - 4s 33ms/step - loss: 4.1928e-04 - val_loss: 0.0012
# Epoch 50/100
# 113/113 [==============================] - ETA: 0s - loss: 3.8645e-04
# Epoch 50: val_loss did not improve from 0.00050
# 113/113 [==============================] - 4s 33ms/step - loss: 3.8645e-04 - val_loss: 9.1782e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:1212.390719397787
# [4136.523994271309, 1307.9528710932339, 1247.4618712087504, 1212.390719397787]

# %%
print(predict)
# Out:
# [array([[55570.05]], dtype=float32), array([[60636.39]], dtype=float32), array([[60228.633]], dtype=float32), array([[58995.805]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

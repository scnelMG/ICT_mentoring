# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 1: val_loss improved from inf to 0.00160, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 7s 41ms/step - loss: 0.0186 - val_loss: 0.0016
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 2: val_loss improved from 0.00160 to 0.00144, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.2403e-04
# Epoch 3: val_loss improved from 0.00144 to 0.00119, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 7.1272e-04 - val_loss: 0.0012
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.9961e-04
# Epoch 4: val_loss improved from 0.00119 to 0.00102, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 6.8348e-04 - val_loss: 0.0010
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.8333e-04
# Epoch 5: val_loss improved from 0.00102 to 0.00098, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 4.7289e-04 - val_loss: 9.8242e-04
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.3185e-04
# Epoch 6: val_loss did not improve from 0.00098
# 34/34 [==============================] - 1s 22ms/step - loss: 5.1430e-04 - val_loss: 9.8726e-04
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0035e-04
# Epoch 7: val_loss improved from 0.00098 to 0.00087, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 3.9817e-04 - val_loss: 8.6807e-04
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.0394e-04
# Epoch 8: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 17ms/step - loss: 3.9238e-04 - val_loss: 0.0012
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4826e-04
# Epoch 9: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 21ms/step - loss: 3.6435e-04 - val_loss: 9.9754e-04
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.1990e-04
# Epoch 10: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 23ms/step - loss: 6.0755e-04 - val_loss: 0.0016
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8085e-04
# Epoch 11: val_loss improved from 0.00087 to 0.00080, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 3.8093e-04 - val_loss: 8.0378e-04
# Epoch 12/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.5971e-04
# Epoch 12: val_loss improved from 0.00080 to 0.00075, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 4.5499e-04 - val_loss: 7.5377e-04
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.4249e-04
# Epoch 13: val_loss did not improve from 0.00075
# 34/34 [==============================] - 1s 22ms/step - loss: 3.3405e-04 - val_loss: 8.9074e-04
# Epoch 14/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0430e-04
# Epoch 14: val_loss did not improve from 0.00075
# 34/34 [==============================] - 1s 30ms/step - loss: 2.9663e-04 - val_loss: 9.8456e-04
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0498e-04
# Epoch 15: val_loss did not improve from 0.00075
# 34/34 [==============================] - 1s 21ms/step - loss: 3.0498e-04 - val_loss: 0.0015
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 3.3328e-04
# Epoch 16: val_loss did not improve from 0.00075
# 34/34 [==============================] - 1s 21ms/step - loss: 3.3328e-04 - val_loss: 0.0011
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.1728e-04
# Epoch 17: val_loss improved from 0.00075 to 0.00069, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 3.0486e-04 - val_loss: 6.9479e-04
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.8398e-04
# Epoch 18: val_loss improved from 0.00069 to 0.00068, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 2.8648e-04 - val_loss: 6.8218e-04
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7242e-04
# Epoch 19: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 20ms/step - loss: 2.7930e-04 - val_loss: 6.9015e-04
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1840e-04
# Epoch 20: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 17ms/step - loss: 4.2428e-04 - val_loss: 8.8500e-04
# Epoch 21/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.8491e-04
# Epoch 21: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 18ms/step - loss: 2.7801e-04 - val_loss: 7.5437e-04
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.2117e-04
# Epoch 22: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 19ms/step - loss: 3.1956e-04 - val_loss: 7.3739e-04
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 4.4429e-04
# Epoch 23: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 21ms/step - loss: 4.4429e-04 - val_loss: 8.3216e-04
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2274e-04
# Epoch 24: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 25ms/step - loss: 3.2274e-04 - val_loss: 8.0718e-04
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3089e-04
# Epoch 25: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 19ms/step - loss: 3.2810e-04 - val_loss: 7.7311e-04
# Epoch 26/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.8857e-04
# Epoch 26: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9199e-04 - val_loss: 6.8392e-04
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.7706e-04
# Epoch 27: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 19ms/step - loss: 2.7958e-04 - val_loss: 0.0014
# Epoch 28/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.3054e-04
# Epoch 28: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 18ms/step - loss: 3.3498e-04 - val_loss: 0.0020
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:30868.877973050472
# [30868.877973050472]
# Epoch 1/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0338
# Epoch 1: val_loss improved from inf to 0.08314, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 4s 46ms/step - loss: 0.0327 - val_loss: 0.0831
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 2: val_loss improved from 0.08314 to 0.03213, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0014 - val_loss: 0.0321
# Epoch 3/100
# 43/43 [==============================] - ETA: 0s - loss: 8.1734e-04
# Epoch 3: val_loss improved from 0.03213 to 0.02282, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 8.1734e-04 - val_loss: 0.0228
# Epoch 4/100
# 41/43 [===========================>..] - ETA: 0s - loss: 5.6657e-04
# Epoch 4: val_loss did not improve from 0.02282
# 43/43 [==============================] - 1s 20ms/step - loss: 5.6506e-04 - val_loss: 0.0240
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 4.3773e-04
# Epoch 5: val_loss did not improve from 0.02282
# 43/43 [==============================] - 1s 23ms/step - loss: 4.3773e-04 - val_loss: 0.0243
# Epoch 6/100
# 41/43 [===========================>..] - ETA: 0s - loss: 3.6009e-04
# Epoch 6: val_loss improved from 0.02282 to 0.01934, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 3.5523e-04 - val_loss: 0.0193
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 3.5182e-04
# Epoch 7: val_loss did not improve from 0.01934
# 43/43 [==============================] - 1s 24ms/step - loss: 3.5182e-04 - val_loss: 0.0222
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 2.9763e-04
# Epoch 8: val_loss improved from 0.01934 to 0.01542, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 29ms/step - loss: 2.9763e-04 - val_loss: 0.0154
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 3.4627e-04
# Epoch 9: val_loss did not improve from 0.01542
# 43/43 [==============================] - 1s 26ms/step - loss: 3.4627e-04 - val_loss: 0.0201
# Epoch 10/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.8368e-04
# Epoch 10: val_loss did not improve from 0.01542
# 43/43 [==============================] - 1s 22ms/step - loss: 2.8292e-04 - val_loss: 0.0165
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5923e-04
# Epoch 11: val_loss improved from 0.01542 to 0.01392, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 24ms/step - loss: 2.5819e-04 - val_loss: 0.0139
# Epoch 12/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4801e-04
# Epoch 12: val_loss did not improve from 0.01392
# 43/43 [==============================] - 1s 22ms/step - loss: 2.4738e-04 - val_loss: 0.0146
# Epoch 13/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.6132e-04
# Epoch 13: val_loss did not improve from 0.01392
# 43/43 [==============================] - 1s 22ms/step - loss: 2.5836e-04 - val_loss: 0.0144
# Epoch 14/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.4341e-04
# Epoch 14: val_loss improved from 0.01392 to 0.01368, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 26ms/step - loss: 2.4193e-04 - val_loss: 0.0137
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1943e-04
# Epoch 15: val_loss improved from 0.01368 to 0.01169, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 2.1943e-04 - val_loss: 0.0117
# Epoch 16/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.4658e-04
# Epoch 16: val_loss did not improve from 0.01169
# 43/43 [==============================] - 1s 21ms/step - loss: 2.4392e-04 - val_loss: 0.0155
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 2.5077e-04
# Epoch 17: val_loss improved from 0.01169 to 0.00980, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 23ms/step - loss: 2.5077e-04 - val_loss: 0.0098
# Epoch 18/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3665e-04
# Epoch 18: val_loss did not improve from 0.00980
# 43/43 [==============================] - 1s 24ms/step - loss: 2.3567e-04 - val_loss: 0.0124
# Epoch 19/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9934e-04
# Epoch 19: val_loss did not improve from 0.00980
# 43/43 [==============================] - 1s 21ms/step - loss: 1.9731e-04 - val_loss: 0.0135
# Epoch 20/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0383e-04
# Epoch 20: val_loss did not improve from 0.00980
# 43/43 [==============================] - 1s 19ms/step - loss: 2.0383e-04 - val_loss: 0.0174
# Epoch 21/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.0947e-04
# Epoch 21: val_loss did not improve from 0.00980
# 43/43 [==============================] - 1s 21ms/step - loss: 2.1917e-04 - val_loss: 0.0110
# Epoch 22/100
# 43/43 [==============================] - ETA: 0s - loss: 1.8745e-04
# Epoch 22: val_loss improved from 0.00980 to 0.00942, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 22ms/step - loss: 1.8745e-04 - val_loss: 0.0094
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0337e-04
# Epoch 23: val_loss improved from 0.00942 to 0.00831, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 18ms/step - loss: 2.0337e-04 - val_loss: 0.0083
# Epoch 24/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4122e-04
# Epoch 24: val_loss did not improve from 0.00831
# 43/43 [==============================] - 1s 21ms/step - loss: 2.3889e-04 - val_loss: 0.0104
# Epoch 25/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9961e-04
# Epoch 25: val_loss did not improve from 0.00831
# 43/43 [==============================] - 1s 21ms/step - loss: 2.0494e-04 - val_loss: 0.0119
# Epoch 26/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.8568e-04
# Epoch 26: val_loss improved from 0.00831 to 0.00825, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 20ms/step - loss: 1.8819e-04 - val_loss: 0.0083
# Epoch 27/100
# 40/43 [==========================>...] - ETA: 0s - loss: 2.1433e-04
# Epoch 27: val_loss did not improve from 0.00825
# 43/43 [==============================] - 1s 17ms/step - loss: 2.0955e-04 - val_loss: 0.0095
# Epoch 28/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.2510e-04
# Epoch 28: val_loss did not improve from 0.00825
# 43/43 [==============================] - 1s 17ms/step - loss: 2.2366e-04 - val_loss: 0.0128
# Epoch 29/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.8496e-04
# Epoch 29: val_loss did not improve from 0.00825
# 43/43 [==============================] - 1s 18ms/step - loss: 1.8368e-04 - val_loss: 0.0106
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.8622e-04
# Epoch 30: val_loss did not improve from 0.00825
# 43/43 [==============================] - 1s 22ms/step - loss: 1.8699e-04 - val_loss: 0.0095
# Epoch 31/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.7511e-04
# Epoch 31: val_loss improved from 0.00825 to 0.00744, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 1.7739e-04 - val_loss: 0.0074
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1258e-04
# Epoch 32: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 18ms/step - loss: 2.1258e-04 - val_loss: 0.0098
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.7979e-04
# Epoch 33: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 24ms/step - loss: 1.8065e-04 - val_loss: 0.0117
# Epoch 34/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.0163e-04
# Epoch 34: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 27ms/step - loss: 2.0075e-04 - val_loss: 0.0097
# Epoch 35/100
# 40/43 [==========================>...] - ETA: 0s - loss: 1.7738e-04
# Epoch 35: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 19ms/step - loss: 1.7727e-04 - val_loss: 0.0118
# Epoch 36/100
# 43/43 [==============================] - ETA: 0s - loss: 2.0057e-04
# Epoch 36: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 21ms/step - loss: 2.0057e-04 - val_loss: 0.0111
# Epoch 37/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.7963e-04
# Epoch 37: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 21ms/step - loss: 1.8425e-04 - val_loss: 0.0128
# Epoch 38/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.6732e-04
# Epoch 38: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 30ms/step - loss: 1.7060e-04 - val_loss: 0.0089
# Epoch 39/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.1663e-04
# Epoch 39: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 27ms/step - loss: 2.1201e-04 - val_loss: 0.0095
# Epoch 40/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9530e-04
# Epoch 40: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 32ms/step - loss: 1.9459e-04 - val_loss: 0.0106
# Epoch 41/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3162e-04
# Epoch 41: val_loss did not improve from 0.00744
# 43/43 [==============================] - 1s 30ms/step - loss: 2.3162e-04 - val_loss: 0.0125
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:119321.26232322406
# [30868.877973050472, 119321.26232322406]

# %%
print(predict)
# Out:
# [array([[843860.3]], dtype=float32), array([[766693.06]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

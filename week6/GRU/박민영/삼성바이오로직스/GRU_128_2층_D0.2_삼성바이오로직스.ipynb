# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(128, return_sequences=False, stateful=False))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0253
# Epoch 1: val_loss improved from inf to 0.00344, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 9s 107ms/step - loss: 0.0247 - val_loss: 0.0034
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 2: val_loss did not improve from 0.00344
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 3: val_loss did not improve from 0.00344
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 4: val_loss improved from 0.00344 to 0.00112, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00112
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss improved from 0.00112 to 0.00095, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 9.5482e-04
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 7: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0013 - val_loss: 0.0040
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 9: val_loss did not improve from 0.00095
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss did not improve from 0.00095
# 34/34 [==============================] - 2s 59ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 9.3526e-04
# Epoch 11: val_loss did not improve from 0.00095
# 34/34 [==============================] - 3s 77ms/step - loss: 9.3526e-04 - val_loss: 0.0022
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 12: val_loss did not improve from 0.00095
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 9.0099e-04
# Epoch 13: val_loss improved from 0.00095 to 0.00086, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 45ms/step - loss: 9.0099e-04 - val_loss: 8.5998e-04
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 9.4153e-04
# Epoch 14: val_loss did not improve from 0.00086
# 34/34 [==============================] - 2s 45ms/step - loss: 9.4153e-04 - val_loss: 0.0018
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 8.5130e-04
# Epoch 15: val_loss did not improve from 0.00086
# 34/34 [==============================] - 2s 54ms/step - loss: 8.5130e-04 - val_loss: 0.0031
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 16: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0013 - val_loss: 8.9349e-04
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 9.7123e-04
# Epoch 17: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 43ms/step - loss: 9.7123e-04 - val_loss: 0.0040
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.8965e-04
# Epoch 18: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.3311e-04
# Epoch 19: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 40ms/step - loss: 9.5113e-04 - val_loss: 0.0011
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.5370e-04
# Epoch 20: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 39ms/step - loss: 7.8617e-04 - val_loss: 0.0015
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 6.9240e-04
# Epoch 21: val_loss did not improve from 0.00086
# 34/34 [==============================] - 1s 41ms/step - loss: 6.9240e-04 - val_loss: 0.0021
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.8219e-04
# Epoch 22: val_loss improved from 0.00086 to 0.00073, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 45ms/step - loss: 9.8394e-04 - val_loss: 7.2741e-04
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 8.3762e-04
# Epoch 23: val_loss did not improve from 0.00073
# 34/34 [==============================] - 2s 46ms/step - loss: 8.3762e-04 - val_loss: 0.0031
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 9.2512e-04
# Epoch 24: val_loss did not improve from 0.00073
# 34/34 [==============================] - 2s 46ms/step - loss: 9.2512e-04 - val_loss: 7.8570e-04
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 8.1767e-04
# Epoch 25: val_loss did not improve from 0.00073
# 34/34 [==============================] - 2s 53ms/step - loss: 8.1767e-04 - val_loss: 8.2825e-04
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 8.7468e-04
# Epoch 26: val_loss did not improve from 0.00073
# 34/34 [==============================] - 2s 46ms/step - loss: 8.7468e-04 - val_loss: 0.0024
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 7.3978e-04
# Epoch 27: val_loss improved from 0.00073 to 0.00067, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 51ms/step - loss: 7.3978e-04 - val_loss: 6.7111e-04
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.4676e-04
# Epoch 28: val_loss did not improve from 0.00067
# 34/34 [==============================] - 2s 47ms/step - loss: 6.7570e-04 - val_loss: 0.0018
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.0676e-04
# Epoch 29: val_loss did not improve from 0.00067
# 34/34 [==============================] - 1s 38ms/step - loss: 7.9361e-04 - val_loss: 9.4621e-04
# Epoch 30/100
# 34/34 [==============================] - ETA: 0s - loss: 6.7413e-04
# Epoch 30: val_loss did not improve from 0.00067
# 34/34 [==============================] - 1s 41ms/step - loss: 6.7413e-04 - val_loss: 8.5575e-04
# Epoch 31/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.9447e-04
# Epoch 31: val_loss did not improve from 0.00067
# 34/34 [==============================] - 1s 33ms/step - loss: 7.1800e-04 - val_loss: 0.0020
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.6406e-04
# Epoch 32: val_loss did not improve from 0.00067
# 34/34 [==============================] - 1s 44ms/step - loss: 6.5673e-04 - val_loss: 0.0019
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 7.1176e-04
# Epoch 33: val_loss improved from 0.00067 to 0.00057, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 43ms/step - loss: 7.1176e-04 - val_loss: 5.6849e-04
# Epoch 34/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.0630e-04
# Epoch 34: val_loss did not improve from 0.00057
# 34/34 [==============================] - 1s 36ms/step - loss: 7.9138e-04 - val_loss: 8.6170e-04
# Epoch 35/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.9625e-04
# Epoch 35: val_loss improved from 0.00057 to 0.00055, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 38ms/step - loss: 8.7926e-04 - val_loss: 5.4566e-04
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 6.1999e-04
# Epoch 36: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 30ms/step - loss: 6.1999e-04 - val_loss: 0.0022
# Epoch 37/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1108e-04
# Epoch 37: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 28ms/step - loss: 6.8558e-04 - val_loss: 7.9348e-04
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 6.3184e-04
# Epoch 38: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 31ms/step - loss: 6.3184e-04 - val_loss: 8.0771e-04
# Epoch 39/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1366e-04
# Epoch 39: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 39ms/step - loss: 7.2367e-04 - val_loss: 0.0017
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.3735e-04
# Epoch 40: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 34ms/step - loss: 7.3635e-04 - val_loss: 5.9309e-04
# Epoch 41/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.6722e-04
# Epoch 41: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 28ms/step - loss: 6.6039e-04 - val_loss: 5.5511e-04
# Epoch 42/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.0280e-04
# Epoch 42: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 29ms/step - loss: 6.7991e-04 - val_loss: 7.6282e-04
# Epoch 43/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.5481e-04
# Epoch 43: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 27ms/step - loss: 7.4268e-04 - val_loss: 0.0021
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 7.1512e-04
# Epoch 44: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 28ms/step - loss: 7.1512e-04 - val_loss: 0.0016
# Epoch 45/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.8538e-04
# Epoch 45: val_loss did not improve from 0.00055
# 34/34 [==============================] - 1s 31ms/step - loss: 7.8091e-04 - val_loss: 8.1935e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:31778.578037699528
# [31778.578037699528]
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 1: val_loss improved from inf to 0.04157, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 8s 62ms/step - loss: 0.0113 - val_loss: 0.0416
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss improved from 0.04157 to 0.02789, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0019 - val_loss: 0.0279
# Epoch 3/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 3: val_loss did not improve from 0.02789
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0013 - val_loss: 0.0293
# Epoch 4/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.02789
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0012 - val_loss: 0.0302
# Epoch 5/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.7022e-04
# Epoch 5: val_loss improved from 0.02789 to 0.02184, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 48ms/step - loss: 9.6000e-04 - val_loss: 0.0218
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 7.9992e-04
# Epoch 6: val_loss improved from 0.02184 to 0.01686, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 55ms/step - loss: 7.9992e-04 - val_loss: 0.0169
# Epoch 7/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.1688e-04
# Epoch 7: val_loss did not improve from 0.01686
# 43/43 [==============================] - 2s 50ms/step - loss: 9.1153e-04 - val_loss: 0.0219
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.0999e-04
# Epoch 8: val_loss improved from 0.01686 to 0.01195, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 66ms/step - loss: 9.1161e-04 - val_loss: 0.0119
# Epoch 9/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.9160e-04
# Epoch 9: val_loss did not improve from 0.01195
# 43/43 [==============================] - 3s 60ms/step - loss: 6.9325e-04 - val_loss: 0.0180
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 6.2064e-04
# Epoch 10: val_loss did not improve from 0.01195
# 43/43 [==============================] - 3s 78ms/step - loss: 6.2064e-04 - val_loss: 0.0135
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.1697e-04
# Epoch 11: val_loss improved from 0.01195 to 0.01176, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 69ms/step - loss: 8.1913e-04 - val_loss: 0.0118
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 6.2679e-04
# Epoch 12: val_loss improved from 0.01176 to 0.00822, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 60ms/step - loss: 6.2679e-04 - val_loss: 0.0082
# Epoch 13/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.5598e-04
# Epoch 13: val_loss did not improve from 0.00822
# 43/43 [==============================] - 2s 51ms/step - loss: 5.5198e-04 - val_loss: 0.0109
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 5.4441e-04
# Epoch 14: val_loss improved from 0.00822 to 0.00701, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 52ms/step - loss: 5.4441e-04 - val_loss: 0.0070
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 5.8846e-04
# Epoch 15: val_loss improved from 0.00701 to 0.00439, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 5.8846e-04 - val_loss: 0.0044
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 5.7238e-04
# Epoch 16: val_loss did not improve from 0.00439
# 43/43 [==============================] - 2s 54ms/step - loss: 5.7238e-04 - val_loss: 0.0128
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 4.8554e-04
# Epoch 17: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 62ms/step - loss: 4.8554e-04 - val_loss: 0.0070
# Epoch 18/100
# 43/43 [==============================] - ETA: 0s - loss: 5.2467e-04
# Epoch 18: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 67ms/step - loss: 5.2467e-04 - val_loss: 0.0102
# Epoch 19/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.6982e-04
# Epoch 19: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 61ms/step - loss: 4.6948e-04 - val_loss: 0.0086
# Epoch 20/100
# 43/43 [==============================] - ETA: 0s - loss: 4.5160e-04
# Epoch 20: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 74ms/step - loss: 4.5160e-04 - val_loss: 0.0113
# Epoch 21/100
# 43/43 [==============================] - ETA: 0s - loss: 5.8124e-04
# Epoch 21: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 76ms/step - loss: 5.8124e-04 - val_loss: 0.0047
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.6381e-04
# Epoch 22: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 70ms/step - loss: 4.6123e-04 - val_loss: 0.0098
# Epoch 23/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.3575e-04
# Epoch 23: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 73ms/step - loss: 4.3512e-04 - val_loss: 0.0090
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 4.5421e-04
# Epoch 24: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 68ms/step - loss: 4.5421e-04 - val_loss: 0.0089
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.4376e-04
# Epoch 25: val_loss did not improve from 0.00439
# 43/43 [==============================] - 3s 67ms/step - loss: 4.4145e-04 - val_loss: 0.0086
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:78454.88816464272
# [31778.578037699528, 78454.88816464272]

# %%
print(predict)
# Out:
# [array([[841519.06]], dtype=float32), array([[799866.5]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0708
# Epoch 1: val_loss improved from inf to 0.08517, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 32ms/step - loss: 0.0677 - val_loss: 0.0852
# Epoch 2/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0287
# Epoch 2: val_loss improved from 0.08517 to 0.05542, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.0554
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0206
# Epoch 3: val_loss improved from 0.05542 to 0.05539, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0204 - val_loss: 0.0554
# Epoch 4/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0168
# Epoch 4: val_loss improved from 0.05539 to 0.04038, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0163 - val_loss: 0.0404
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 5: val_loss improved from 0.04038 to 0.03718, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0372
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 6: val_loss improved from 0.03718 to 0.01878, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0100 - val_loss: 0.0188
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 7: val_loss did not improve from 0.01878
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0083 - val_loss: 0.0262
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0074
# Epoch 8: val_loss did not improve from 0.01878
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0074 - val_loss: 0.0255
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0080
# Epoch 9: val_loss improved from 0.01878 to 0.01563, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0077 - val_loss: 0.0156
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0075
# Epoch 10: val_loss did not improve from 0.01563
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0214
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0082
# Epoch 11: val_loss improved from 0.01563 to 0.01080, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0108
# Epoch 12/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0056
# Epoch 12: val_loss did not improve from 0.01080
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0201
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 13: val_loss did not improve from 0.01080
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0167
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0067
# Epoch 14: val_loss did not improve from 0.01080
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0132
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 15: val_loss did not improve from 0.01080
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0052 - val_loss: 0.0158
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0063
# Epoch 16: val_loss did not improve from 0.01080
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0121
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 17: val_loss improved from 0.01080 to 0.00739, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0074
# Epoch 18/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0056
# Epoch 18: val_loss improved from 0.00739 to 0.00627, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0063
# Epoch 19/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0048
# Epoch 19: val_loss improved from 0.00627 to 0.00387, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 20/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0053
# Epoch 20: val_loss did not improve from 0.00387
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 21/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 21: val_loss improved from 0.00387 to 0.00369, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 22/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0043
# Epoch 22: val_loss did not improve from 0.00369
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0095
# Epoch 23/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0047
# Epoch 23: val_loss did not improve from 0.00369
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 24/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 24: val_loss did not improve from 0.00369
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0113
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 25: val_loss did not improve from 0.00369
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 26: val_loss did not improve from 0.00369
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 27/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 27: val_loss improved from 0.00369 to 0.00358, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 28/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0034
# Epoch 28: val_loss did not improve from 0.00358
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0061
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 29: val_loss improved from 0.00358 to 0.00265, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 30/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0039
# Epoch 30: val_loss did not improve from 0.00265
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 31/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0040
# Epoch 31: val_loss did not improve from 0.00265
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 32: val_loss did not improve from 0.00265
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0072
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 33: val_loss did not improve from 0.00265
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 34: val_loss did not improve from 0.00265
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0036 - val_loss: 0.0081
# Epoch 35/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 35: val_loss improved from 0.00265 to 0.00133, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 36: val_loss did not improve from 0.00133
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 37/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 37: val_loss did not improve from 0.00133
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 38: val_loss did not improve from 0.00133
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0031 - val_loss: 0.0073
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 39: val_loss did not improve from 0.00133
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 40: val_loss did not improve from 0.00133
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 41/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 41: val_loss did not improve from 0.00133
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 42/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0028
# Epoch 42: val_loss did not improve from 0.00133
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 43/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0024
# Epoch 43: val_loss did not improve from 0.00133
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 44: val_loss did not improve from 0.00133
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 45: val_loss improved from 0.00133 to 0.00099, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 9.8886e-04
# Epoch 46/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 46: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 47/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0029
# Epoch 47: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 48/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 48: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 49/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0033
# Epoch 49: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 50/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 50: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 51/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 51: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 52/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 52: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0036 - val_loss: 0.0062
# Epoch 53/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 53: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 54/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0024
# Epoch 54: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 55/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0026
# Epoch 55: val_loss did not improve from 0.00099
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0013
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:43657.665562606795
# [43657.665562606795]
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 1: val_loss improved from inf to 0.09290, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 6s 47ms/step - loss: 0.0361 - val_loss: 0.0929
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 2: val_loss improved from 0.09290 to 0.04598, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0090 - val_loss: 0.0460
# Epoch 3/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0063
# Epoch 3: val_loss improved from 0.04598 to 0.02012, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0064 - val_loss: 0.0201
# Epoch 4/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0051
# Epoch 4: val_loss improved from 0.02012 to 0.01718, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0051 - val_loss: 0.0172
# Epoch 5/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 5: val_loss did not improve from 0.01718
# 43/43 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0212
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 6: val_loss improved from 0.01718 to 0.01486, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0037 - val_loss: 0.0149
# Epoch 7/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 7: val_loss did not improve from 0.01486
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0035 - val_loss: 0.0172
# Epoch 8/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 8: val_loss did not improve from 0.01486
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0193
# Epoch 9/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 9: val_loss did not improve from 0.01486
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0028 - val_loss: 0.0190
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 10: val_loss improved from 0.01486 to 0.01455, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0029 - val_loss: 0.0146
# Epoch 11/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 11: val_loss did not improve from 0.01455
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0024 - val_loss: 0.0158
# Epoch 12/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 12: val_loss improved from 0.01455 to 0.01274, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0023 - val_loss: 0.0127
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 13: val_loss improved from 0.01274 to 0.00927, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 0.0093
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 14: val_loss improved from 0.00927 to 0.00533, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 15ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.00533
# 43/43 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0073
# Epoch 16/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 16: val_loss did not improve from 0.00533
# 43/43 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0075
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 12ms/step - loss: 0.0015 - val_loss: 0.0068
# Epoch 18/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 18: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 19/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 19: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0015 - val_loss: 0.0068
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 20: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0080
# Epoch 21/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 21: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 0.0069
# Epoch 22/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 22: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0012 - val_loss: 0.0065
# Epoch 23/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 23: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 0.0099
# Epoch 24/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 24: val_loss did not improve from 0.00533
# 43/43 [==============================] - 1s 15ms/step - loss: 0.0011 - val_loss: 0.0090
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:80151.18601582044
# [43657.665562606795, 80151.18601582044]

# %%
print(predict)
# Out:
# [array([[803745.3]], dtype=float32), array([[768645.4]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

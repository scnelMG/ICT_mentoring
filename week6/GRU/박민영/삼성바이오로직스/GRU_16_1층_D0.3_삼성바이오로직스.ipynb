# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0926
# Epoch 1: val_loss improved from inf to 0.10811, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 8s 75ms/step - loss: 0.0890 - val_loss: 0.1081
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0292
# Epoch 2: val_loss improved from 0.10811 to 0.04651, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0283 - val_loss: 0.0465
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0164
# Epoch 3: val_loss improved from 0.04651 to 0.02431, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0161 - val_loss: 0.0243
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 4: val_loss improved from 0.02431 to 0.01320, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0122 - val_loss: 0.0132
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 5: val_loss improved from 0.01320 to 0.00937, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0111 - val_loss: 0.0094
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 6: val_loss improved from 0.00937 to 0.00273, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0027
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 7: val_loss did not improve from 0.00273
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0101 - val_loss: 0.0062
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 8: val_loss did not improve from 0.00273
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0088 - val_loss: 0.0068
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 9: val_loss did not improve from 0.00273
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0083
# Epoch 10: val_loss did not improve from 0.00273
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 11: val_loss improved from 0.00273 to 0.00250, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0025
# Epoch 12/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 12: val_loss did not improve from 0.00250
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0062
# Epoch 13: val_loss did not improve from 0.00250
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 14: val_loss improved from 0.00250 to 0.00232, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 15: val_loss improved from 0.00232 to 0.00206, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 16/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0061
# Epoch 16: val_loss did not improve from 0.00206
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0063 - val_loss: 0.0051
# Epoch 17/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0061
# Epoch 17: val_loss did not improve from 0.00206
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 18: val_loss did not improve from 0.00206
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 19: val_loss did not improve from 0.00206
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0057 - val_loss: 0.0031
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 20: val_loss improved from 0.00206 to 0.00126, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 37ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 21/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0061
# Epoch 21: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 22: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 23: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 24: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 25/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0042
# Epoch 25: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 26: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 27/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 27: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 28: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 29/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 29: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 30: val_loss did not improve from 0.00126
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0057 - val_loss: 0.0049
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:76648.32252209805
# [76648.32252209805]
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.1358
# Epoch 1: val_loss improved from inf to 0.16838, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 16s 84ms/step - loss: 0.1348 - val_loss: 0.1684
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 2: val_loss improved from 0.16838 to 0.11193, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 38ms/step - loss: 0.0316 - val_loss: 0.1119
# Epoch 3/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 3: val_loss improved from 0.11193 to 0.08982, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 35ms/step - loss: 0.0155 - val_loss: 0.0898
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 4: val_loss improved from 0.08982 to 0.07612, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0121 - val_loss: 0.0761
# Epoch 5/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0106
# Epoch 5: val_loss improved from 0.07612 to 0.07398, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0105 - val_loss: 0.0740
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 6: val_loss did not improve from 0.07398
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0100 - val_loss: 0.0765
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 7: val_loss improved from 0.07398 to 0.05637, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 0.0091 - val_loss: 0.0564
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 8: val_loss improved from 0.05637 to 0.04906, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 52ms/step - loss: 0.0070 - val_loss: 0.0491
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 9: val_loss improved from 0.04906 to 0.04028, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 55ms/step - loss: 0.0063 - val_loss: 0.0403
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 10: val_loss improved from 0.04028 to 0.03258, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0057 - val_loss: 0.0326
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 11: val_loss did not improve from 0.03258
# 43/43 [==============================] - 1s 29ms/step - loss: 0.0051 - val_loss: 0.0332
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 12: val_loss improved from 0.03258 to 0.01925, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0045 - val_loss: 0.0192
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 13: val_loss did not improve from 0.01925
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0037 - val_loss: 0.0235
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 14: val_loss did not improve from 0.01925
# 43/43 [==============================] - 2s 38ms/step - loss: 0.0031 - val_loss: 0.0227
# Epoch 15/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 15: val_loss did not improve from 0.01925
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0030 - val_loss: 0.0204
# Epoch 16/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 16: val_loss improved from 0.01925 to 0.01311, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0032 - val_loss: 0.0131
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 17: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0028 - val_loss: 0.0173
# Epoch 18/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 18: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 34ms/step - loss: 0.0024 - val_loss: 0.0155
# Epoch 19/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 19: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 20/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 20: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 37ms/step - loss: 0.0024 - val_loss: 0.0144
# Epoch 21/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 21: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0024 - val_loss: 0.0175
# Epoch 22/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 22: val_loss did not improve from 0.01311
# 43/43 [==============================] - 2s 37ms/step - loss: 0.0022 - val_loss: 0.0139
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 23: val_loss improved from 0.01311 to 0.01225, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 0.0023 - val_loss: 0.0122
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 24: val_loss improved from 0.01225 to 0.01219, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 55ms/step - loss: 0.0022 - val_loss: 0.0122
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 25: val_loss improved from 0.01219 to 0.01186, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 0.0020 - val_loss: 0.0119
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 26: val_loss improved from 0.01186 to 0.01023, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 0.0022 - val_loss: 0.0102
# Epoch 27/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 27: val_loss did not improve from 0.01023
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0019 - val_loss: 0.0111
# Epoch 28/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 28: val_loss improved from 0.01023 to 0.00828, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0020 - val_loss: 0.0083
# Epoch 29/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 29: val_loss did not improve from 0.00828
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0021 - val_loss: 0.0130
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 30: val_loss did not improve from 0.00828
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0020 - val_loss: 0.0141
# Epoch 31/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 31: val_loss did not improve from 0.00828
# 43/43 [==============================] - 2s 39ms/step - loss: 0.0019 - val_loss: 0.0099
# Epoch 32/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 32: val_loss did not improve from 0.00828
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0019 - val_loss: 0.0108
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 33: val_loss did not improve from 0.00828
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 0.0100
# Epoch 34/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 34: val_loss improved from 0.00828 to 0.00680, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0068
# Epoch 35/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 35: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 0.0105
# Epoch 36/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 36: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0082
# Epoch 37/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 37: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0018 - val_loss: 0.0082
# Epoch 38/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 38: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0015 - val_loss: 0.0109
# Epoch 39/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 39: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 0.0076
# Epoch 40/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 40: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0106
# Epoch 41/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 41: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0072
# Epoch 42/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 42: val_loss did not improve from 0.00680
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0015 - val_loss: 0.0075
# Epoch 43/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 43: val_loss improved from 0.00680 to 0.00600, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 44/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 44: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0016 - val_loss: 0.0108
# Epoch 45/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 45: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 0.0076
# Epoch 46/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 46: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0017 - val_loss: 0.0116
# Epoch 47/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 47: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0014 - val_loss: 0.0081
# Epoch 48/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 48: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0015 - val_loss: 0.0084
# Epoch 49/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 49: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0015 - val_loss: 0.0086
# Epoch 50/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 50: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0014 - val_loss: 0.0073
# Epoch 51/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 51: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 0.0112
# Epoch 52/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 52: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0014 - val_loss: 0.0085
# Epoch 53/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 53: val_loss did not improve from 0.00600
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0014 - val_loss: 0.0083
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:75664.82426466285
# [76648.32252209805, 75664.82426466285]

# %%
print(predict)
# Out:
# [array([[684134.56]], dtype=float32), array([[818353.]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

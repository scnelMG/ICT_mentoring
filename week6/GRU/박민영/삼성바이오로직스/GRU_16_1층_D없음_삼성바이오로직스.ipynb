# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0633
# Epoch 1: val_loss improved from inf to 0.11641, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 10s 79ms/step - loss: 0.0595 - val_loss: 0.1164
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0096
# Epoch 2: val_loss improved from 0.11641 to 0.03641, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0364
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 3: val_loss improved from 0.03641 to 0.00998, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0031 - val_loss: 0.0100
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 4: val_loss improved from 0.00998 to 0.00440, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 5: val_loss did not improve from 0.00440
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 6: val_loss improved from 0.00440 to 0.00270, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 7: val_loss improved from 0.00270 to 0.00240, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 8/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0012
# Epoch 8: val_loss improved from 0.00240 to 0.00222, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 9: val_loss did not improve from 0.00222
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss did not improve from 0.00222
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.8288e-04
# Epoch 11: val_loss improved from 0.00222 to 0.00209, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 9.7716e-04 - val_loss: 0.0021
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 8.9573e-04
# Epoch 12: val_loss did not improve from 0.00209
# 34/34 [==============================] - 1s 21ms/step - loss: 8.9573e-04 - val_loss: 0.0033
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.3336e-04
# Epoch 13: val_loss did not improve from 0.00209
# 34/34 [==============================] - 1s 18ms/step - loss: 9.0560e-04 - val_loss: 0.0028
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 8.4849e-04
# Epoch 14: val_loss did not improve from 0.00209
# 34/34 [==============================] - 1s 22ms/step - loss: 8.4849e-04 - val_loss: 0.0036
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.0584e-04
# Epoch 15: val_loss did not improve from 0.00209
# 34/34 [==============================] - 1s 22ms/step - loss: 8.9914e-04 - val_loss: 0.0023
# Epoch 16/100
# 30/34 [=========================>....] - ETA: 0s - loss: 7.2990e-04
# Epoch 16: val_loss improved from 0.00209 to 0.00179, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 7.4438e-04 - val_loss: 0.0018
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.1264e-04
# Epoch 17: val_loss did not improve from 0.00179
# 34/34 [==============================] - 1s 21ms/step - loss: 7.1463e-04 - val_loss: 0.0024
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.4425e-04
# Epoch 18: val_loss improved from 0.00179 to 0.00162, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 7.4001e-04 - val_loss: 0.0016
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 6.8954e-04
# Epoch 19: val_loss did not improve from 0.00162
# 34/34 [==============================] - 1s 24ms/step - loss: 6.8954e-04 - val_loss: 0.0036
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.2943e-04
# Epoch 20: val_loss did not improve from 0.00162
# 34/34 [==============================] - 1s 30ms/step - loss: 7.3233e-04 - val_loss: 0.0017
# Epoch 21/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.1392e-04
# Epoch 21: val_loss improved from 0.00162 to 0.00142, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 6.3877e-04 - val_loss: 0.0014
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.7467e-04
# Epoch 22: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 31ms/step - loss: 6.6687e-04 - val_loss: 0.0022
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 6.5222e-04
# Epoch 23: val_loss did not improve from 0.00142
# 34/34 [==============================] - 2s 48ms/step - loss: 6.5222e-04 - val_loss: 0.0015
# Epoch 24/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.1450e-04
# Epoch 24: val_loss did not improve from 0.00142
# 34/34 [==============================] - 1s 38ms/step - loss: 6.2363e-04 - val_loss: 0.0017
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.3363e-04
# Epoch 25: val_loss did not improve from 0.00142
# 34/34 [==============================] - 2s 54ms/step - loss: 6.4050e-04 - val_loss: 0.0022
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.0308e-04
# Epoch 26: val_loss improved from 0.00142 to 0.00119, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 48ms/step - loss: 5.8998e-04 - val_loss: 0.0012
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 5.9278e-04
# Epoch 27: val_loss did not improve from 0.00119
# 34/34 [==============================] - 1s 37ms/step - loss: 5.9278e-04 - val_loss: 0.0019
# Epoch 28/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.5955e-04
# Epoch 28: val_loss did not improve from 0.00119
# 34/34 [==============================] - 1s 29ms/step - loss: 5.5737e-04 - val_loss: 0.0018
# Epoch 29/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.3383e-04
# Epoch 29: val_loss did not improve from 0.00119
# 34/34 [==============================] - 1s 41ms/step - loss: 5.2154e-04 - val_loss: 0.0021
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.7545e-04
# Epoch 30: val_loss did not improve from 0.00119
# 34/34 [==============================] - 1s 25ms/step - loss: 4.7000e-04 - val_loss: 0.0012
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 5.4693e-04
# Epoch 31: val_loss did not improve from 0.00119
# 34/34 [==============================] - 1s 27ms/step - loss: 5.4693e-04 - val_loss: 0.0017
# Epoch 32/100
# 34/34 [==============================] - ETA: 0s - loss: 4.9337e-04
# Epoch 32: val_loss improved from 0.00119 to 0.00096, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 36ms/step - loss: 4.9337e-04 - val_loss: 9.6357e-04
# Epoch 33/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.6911e-04
# Epoch 33: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 22ms/step - loss: 4.6247e-04 - val_loss: 0.0012
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.4399e-04
# Epoch 34: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 29ms/step - loss: 4.6554e-04 - val_loss: 0.0012
# Epoch 35/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.7786e-04
# Epoch 35: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 22ms/step - loss: 4.7357e-04 - val_loss: 0.0012
# Epoch 36/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.9268e-04
# Epoch 36: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 28ms/step - loss: 4.8833e-04 - val_loss: 0.0013
# Epoch 37/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4741e-04
# Epoch 37: val_loss did not improve from 0.00096
# 34/34 [==============================] - 1s 35ms/step - loss: 4.4554e-04 - val_loss: 0.0010
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3421e-04
# Epoch 38: val_loss improved from 0.00096 to 0.00089, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 4.3421e-04 - val_loss: 8.9470e-04
# Epoch 39/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.0966e-04
# Epoch 39: val_loss improved from 0.00089 to 0.00088, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 4.1037e-04 - val_loss: 8.7647e-04
# Epoch 40/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3306e-04
# Epoch 40: val_loss did not improve from 0.00088
# 34/34 [==============================] - 1s 35ms/step - loss: 4.3306e-04 - val_loss: 0.0010
# Epoch 41/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1289e-04
# Epoch 41: val_loss did not improve from 0.00088
# 34/34 [==============================] - 1s 27ms/step - loss: 4.1289e-04 - val_loss: 9.1696e-04
# Epoch 42/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.1315e-04
# Epoch 42: val_loss improved from 0.00088 to 0.00087, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 35ms/step - loss: 4.0838e-04 - val_loss: 8.6840e-04
# Epoch 43/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3149e-04
# Epoch 43: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 26ms/step - loss: 4.2983e-04 - val_loss: 0.0012
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1863e-04
# Epoch 44: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 26ms/step - loss: 4.1863e-04 - val_loss: 9.3791e-04
# Epoch 45/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.9592e-04
# Epoch 45: val_loss did not improve from 0.00087
# 34/34 [==============================] - 1s 29ms/step - loss: 4.1423e-04 - val_loss: 0.0012
# Epoch 46/100
# 34/34 [==============================] - ETA: 0s - loss: 4.1307e-04
# Epoch 46: val_loss improved from 0.00087 to 0.00082, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 4.1307e-04 - val_loss: 8.2027e-04
# Epoch 47/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8209e-04
# Epoch 47: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 31ms/step - loss: 3.8312e-04 - val_loss: 9.7516e-04
# Epoch 48/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.7151e-04
# Epoch 48: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 30ms/step - loss: 4.6808e-04 - val_loss: 9.9266e-04
# Epoch 49/100
# 34/34 [==============================] - ETA: 0s - loss: 4.3443e-04
# Epoch 49: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 29ms/step - loss: 4.3443e-04 - val_loss: 8.5504e-04
# Epoch 50/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7967e-04
# Epoch 50: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 28ms/step - loss: 3.7405e-04 - val_loss: 0.0011
# Epoch 51/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8491e-04
# Epoch 51: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 27ms/step - loss: 3.9039e-04 - val_loss: 0.0012
# Epoch 52/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.8529e-04
# Epoch 52: val_loss did not improve from 0.00082
# 34/34 [==============================] - 1s 28ms/step - loss: 3.8903e-04 - val_loss: 8.3911e-04
# Epoch 53/100
# 31/34 [==========================>...] - ETA: 0s - loss: 4.0019e-04
# Epoch 53: val_loss improved from 0.00082 to 0.00078, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 43ms/step - loss: 3.8903e-04 - val_loss: 7.7504e-04
# Epoch 54/100
# 34/34 [==============================] - ETA: 0s - loss: 3.5829e-04
# Epoch 54: val_loss did not improve from 0.00078
# 34/34 [==============================] - 1s 28ms/step - loss: 3.5829e-04 - val_loss: 8.1521e-04
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3959e-04
# Epoch 55: val_loss did not improve from 0.00078
# 34/34 [==============================] - 2s 43ms/step - loss: 3.4451e-04 - val_loss: 7.8200e-04
# Epoch 56/100
# 34/34 [==============================] - ETA: 0s - loss: 3.6153e-04
# Epoch 56: val_loss did not improve from 0.00078
# 34/34 [==============================] - 1s 31ms/step - loss: 3.6153e-04 - val_loss: 0.0013
# Epoch 57/100
# 34/34 [==============================] - ETA: 0s - loss: 4.6535e-04
# Epoch 57: val_loss did not improve from 0.00078
# 34/34 [==============================] - 1s 33ms/step - loss: 4.6535e-04 - val_loss: 8.1896e-04
# Epoch 58/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7131e-04
# Epoch 58: val_loss did not improve from 0.00078
# 34/34 [==============================] - 1s 25ms/step - loss: 3.6343e-04 - val_loss: 0.0013
# Epoch 59/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6872e-04
# Epoch 59: val_loss improved from 0.00078 to 0.00073, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 36ms/step - loss: 3.6526e-04 - val_loss: 7.2867e-04
# Epoch 60/100
# 34/34 [==============================] - ETA: 0s - loss: 3.3019e-04
# Epoch 60: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 35ms/step - loss: 3.3019e-04 - val_loss: 8.1108e-04
# Epoch 61/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8679e-04
# Epoch 61: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 29ms/step - loss: 3.8255e-04 - val_loss: 8.8808e-04
# Epoch 62/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8511e-04
# Epoch 62: val_loss did not improve from 0.00073
# 34/34 [==============================] - 1s 28ms/step - loss: 3.7688e-04 - val_loss: 8.0676e-04
# Epoch 63/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1556e-04
# Epoch 63: val_loss improved from 0.00073 to 0.00068, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 4.0614e-04 - val_loss: 6.8441e-04
# Epoch 64/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.4918e-04
# Epoch 64: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 36ms/step - loss: 3.5555e-04 - val_loss: 8.0470e-04
# Epoch 65/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.2297e-04
# Epoch 65: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 22ms/step - loss: 3.2526e-04 - val_loss: 7.2696e-04
# Epoch 66/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6291e-04
# Epoch 66: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 24ms/step - loss: 3.6357e-04 - val_loss: 9.9750e-04
# Epoch 67/100
# 34/34 [==============================] - ETA: 0s - loss: 3.4439e-04
# Epoch 67: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 21ms/step - loss: 3.4439e-04 - val_loss: 8.1591e-04
# Epoch 68/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.6380e-04
# Epoch 68: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 22ms/step - loss: 3.6721e-04 - val_loss: 0.0011
# Epoch 69/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4200e-04
# Epoch 69: val_loss improved from 0.00068 to 0.00068, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 36ms/step - loss: 3.6132e-04 - val_loss: 6.7682e-04
# Epoch 70/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2402e-04
# Epoch 70: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 34ms/step - loss: 3.2402e-04 - val_loss: 9.0090e-04
# Epoch 71/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6737e-04
# Epoch 71: val_loss did not improve from 0.00068
# 34/34 [==============================] - 1s 23ms/step - loss: 3.6351e-04 - val_loss: 0.0011
# Epoch 72/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.6447e-04
# Epoch 72: val_loss improved from 0.00068 to 0.00065, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 3.6096e-04 - val_loss: 6.5244e-04
# Epoch 73/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.9397e-04
# Epoch 73: val_loss did not improve from 0.00065
# 34/34 [==============================] - 1s 19ms/step - loss: 3.8621e-04 - val_loss: 7.1734e-04
# Epoch 74/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7816e-04
# Epoch 74: val_loss did not improve from 0.00065
# 34/34 [==============================] - 1s 21ms/step - loss: 3.7583e-04 - val_loss: 6.8925e-04
# Epoch 75/100
# 34/34 [==============================] - ETA: 0s - loss: 3.1476e-04
# Epoch 75: val_loss did not improve from 0.00065
# 34/34 [==============================] - 1s 23ms/step - loss: 3.1476e-04 - val_loss: 7.6816e-04
# Epoch 76/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.3016e-04
# Epoch 76: val_loss did not improve from 0.00065
# 34/34 [==============================] - 1s 19ms/step - loss: 3.2486e-04 - val_loss: 8.1928e-04
# Epoch 77/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0248e-04
# Epoch 77: val_loss improved from 0.00065 to 0.00064, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 3.0925e-04 - val_loss: 6.4431e-04
# Epoch 78/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.3335e-04
# Epoch 78: val_loss improved from 0.00064 to 0.00063, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 3.3216e-04 - val_loss: 6.3351e-04
# Epoch 79/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0789e-04
# Epoch 79: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1077e-04 - val_loss: 7.5142e-04
# Epoch 80/100
# 34/34 [==============================] - ETA: 0s - loss: 2.9321e-04
# Epoch 80: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 21ms/step - loss: 2.9321e-04 - val_loss: 6.8808e-04
# Epoch 81/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.6219e-04
# Epoch 81: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 16ms/step - loss: 3.6246e-04 - val_loss: 7.6081e-04
# Epoch 82/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.9156e-04
# Epoch 82: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 18ms/step - loss: 2.9856e-04 - val_loss: 6.9972e-04
# Epoch 83/100
# 34/34 [==============================] - ETA: 0s - loss: 2.9911e-04
# Epoch 83: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 22ms/step - loss: 2.9911e-04 - val_loss: 8.8737e-04
# Epoch 84/100
# 34/34 [==============================] - ETA: 0s - loss: 3.8857e-04
# Epoch 84: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 17ms/step - loss: 3.8857e-04 - val_loss: 9.0203e-04
# Epoch 85/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0844e-04
# Epoch 85: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 16ms/step - loss: 3.2588e-04 - val_loss: 7.2349e-04
# Epoch 86/100
# 34/34 [==============================] - ETA: 0s - loss: 2.9309e-04
# Epoch 86: val_loss improved from 0.00063 to 0.00062, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 2.9309e-04 - val_loss: 6.2156e-04
# Epoch 87/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0798e-04
# Epoch 87: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 19ms/step - loss: 3.0537e-04 - val_loss: 7.1877e-04
# Epoch 88/100
# 34/34 [==============================] - ETA: 0s - loss: 2.8196e-04
# Epoch 88: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 16ms/step - loss: 2.8196e-04 - val_loss: 6.4028e-04
# Epoch 89/100
# 28/34 [=======================>......] - ETA: 0s - loss: 2.9814e-04
# Epoch 89: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0166e-04 - val_loss: 7.3952e-04
# Epoch 90/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0006e-04
# Epoch 90: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 18ms/step - loss: 2.9687e-04 - val_loss: 6.3867e-04
# Epoch 91/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.9299e-04
# Epoch 91: val_loss did not improve from 0.00062
# 34/34 [==============================] - 0s 14ms/step - loss: 2.8054e-04 - val_loss: 6.9615e-04
# Epoch 92/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.8337e-04
# Epoch 92: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 16ms/step - loss: 2.8809e-04 - val_loss: 7.8590e-04
# Epoch 93/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0226e-04
# Epoch 93: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 3.0698e-04 - val_loss: 8.4214e-04
# Epoch 94/100
# 34/34 [==============================] - ETA: 0s - loss: 3.1755e-04
# Epoch 94: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 25ms/step - loss: 3.1755e-04 - val_loss: 6.2538e-04
# Epoch 95/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.9550e-04
# Epoch 95: val_loss did not improve from 0.00062
# 34/34 [==============================] - 1s 17ms/step - loss: 3.2930e-04 - val_loss: 7.5211e-04
# Epoch 96/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.9143e-04
# Epoch 96: val_loss improved from 0.00062 to 0.00059, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 2.9019e-04 - val_loss: 5.9344e-04
# Epoch 97/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7869e-04
# Epoch 97: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 21ms/step - loss: 2.7448e-04 - val_loss: 6.1163e-04
# Epoch 98/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.7888e-04
# Epoch 98: val_loss did not improve from 0.00059
# 34/34 [==============================] - 0s 14ms/step - loss: 2.8028e-04 - val_loss: 7.0996e-04
# Epoch 99/100
# 34/34 [==============================] - ETA: 0s - loss: 2.7907e-04
# Epoch 99: val_loss did not improve from 0.00059
# 34/34 [==============================] - 1s 22ms/step - loss: 2.7907e-04 - val_loss: 6.3441e-04
# Epoch 100/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0103e-04
# Epoch 100: val_loss improved from 0.00059 to 0.00059, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 2.9220e-04 - val_loss: 5.9101e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:21972.10354919502
# [21972.10354919502]
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 1: val_loss improved from inf to 0.04849, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 6s 37ms/step - loss: 0.0055 - val_loss: 0.0485
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 2: val_loss improved from 0.04849 to 0.02713, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0271
# Epoch 3/100
# 40/43 [==========================>...] - ETA: 0s - loss: 9.5945e-04
# Epoch 3: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 18ms/step - loss: 9.5670e-04 - val_loss: 0.0288
# Epoch 4/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.5653e-04
# Epoch 4: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 27ms/step - loss: 8.5082e-04 - val_loss: 0.0303
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 7.5886e-04
# Epoch 5: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 21ms/step - loss: 7.5886e-04 - val_loss: 0.0374
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 6.4042e-04
# Epoch 6: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 19ms/step - loss: 6.4042e-04 - val_loss: 0.0379
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 6.5266e-04
# Epoch 7: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 20ms/step - loss: 6.5266e-04 - val_loss: 0.0284
# Epoch 8/100
# 40/43 [==========================>...] - ETA: 0s - loss: 5.3054e-04
# Epoch 8: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 20ms/step - loss: 5.2783e-04 - val_loss: 0.0356
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 4.8423e-04
# Epoch 9: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 24ms/step - loss: 4.8423e-04 - val_loss: 0.0335
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 5.0637e-04
# Epoch 10: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 23ms/step - loss: 5.0637e-04 - val_loss: 0.0291
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.5700e-04
# Epoch 11: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 24ms/step - loss: 4.5760e-04 - val_loss: 0.0340
# Epoch 12/100
# 41/43 [===========================>..] - ETA: 0s - loss: 4.5627e-04
# Epoch 12: val_loss did not improve from 0.02713
# 43/43 [==============================] - 1s 21ms/step - loss: 4.4842e-04 - val_loss: 0.0343
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:213623.8137917662
# [21972.10354919502, 213623.8137917662]

# %%
print(predict)
# Out:
# [array([[818353.]], dtype=float32), array([[751994.06]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

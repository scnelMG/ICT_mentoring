# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 1: val_loss improved from inf to 0.00245, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 12s 74ms/step - loss: 0.0244 - val_loss: 0.0024
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0095
# Epoch 2: val_loss did not improve from 0.00245
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0036
# Epoch 3/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0083
# Epoch 3: val_loss did not improve from 0.00245
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 4: val_loss did not improve from 0.00245
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0067 - val_loss: 0.0027
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 5: val_loss improved from 0.00245 to 0.00214, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0056
# Epoch 6: val_loss did not improve from 0.00214
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 7: val_loss did not improve from 0.00214
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 8: val_loss did not improve from 0.00214
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0049 - val_loss: 0.0022
# Epoch 9/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 9: val_loss did not improve from 0.00214
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 10: val_loss improved from 0.00214 to 0.00206, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 11: val_loss improved from 0.00206 to 0.00152, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 12: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 13: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 14: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 15: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 16: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 17: val_loss did not improve from 0.00152
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 18/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 18: val_loss improved from 0.00152 to 0.00127, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 19/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 19: val_loss did not improve from 0.00127
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 20: val_loss did not improve from 0.00127
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 21: val_loss did not improve from 0.00127
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00127
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 23: val_loss did not improve from 0.00127
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 24: val_loss did not improve from 0.00127
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 25: val_loss improved from 0.00127 to 0.00124, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 26: val_loss did not improve from 0.00124
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 27: val_loss did not improve from 0.00124
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 28: val_loss did not improve from 0.00124
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 29: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 45ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 30: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 31: val_loss did not improve from 0.00124
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 32: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 33: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 34/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 34: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 35: val_loss did not improve from 0.00124
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0020 - val_loss: 0.0031
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:31935.91635392924
# [31935.91635392924]
# Epoch 1/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 1: val_loss improved from inf to 0.20935, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 15s 102ms/step - loss: 0.0351 - val_loss: 0.2094
# Epoch 2/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 2: val_loss improved from 0.20935 to 0.17050, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 42ms/step - loss: 0.0088 - val_loss: 0.1705
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 3: val_loss improved from 0.17050 to 0.15925, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0057 - val_loss: 0.1592
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 4: val_loss improved from 0.15925 to 0.11844, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 64ms/step - loss: 0.0044 - val_loss: 0.1184
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 5: val_loss improved from 0.11844 to 0.10241, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 53ms/step - loss: 0.0039 - val_loss: 0.1024
# Epoch 6/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 6: val_loss improved from 0.10241 to 0.08351, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 65ms/step - loss: 0.0034 - val_loss: 0.0835
# Epoch 7/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 7: val_loss improved from 0.08351 to 0.07605, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 53ms/step - loss: 0.0029 - val_loss: 0.0761
# Epoch 8/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 8: val_loss improved from 0.07605 to 0.06910, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 64ms/step - loss: 0.0022 - val_loss: 0.0691
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 9: val_loss did not improve from 0.06910
# 43/43 [==============================] - 2s 54ms/step - loss: 0.0023 - val_loss: 0.0694
# Epoch 10/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 10: val_loss improved from 0.06910 to 0.06637, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 70ms/step - loss: 0.0024 - val_loss: 0.0664
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 11: val_loss improved from 0.06637 to 0.05966, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 78ms/step - loss: 0.0021 - val_loss: 0.0597
# Epoch 12/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 12: val_loss did not improve from 0.05966
# 43/43 [==============================] - 2s 53ms/step - loss: 0.0020 - val_loss: 0.0680
# Epoch 13/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 13: val_loss improved from 0.05966 to 0.05575, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 3s 60ms/step - loss: 0.0019 - val_loss: 0.0557
# Epoch 14/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 14: val_loss did not improve from 0.05575
# 43/43 [==============================] - 2s 57ms/step - loss: 0.0019 - val_loss: 0.0580
# Epoch 15/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 15: val_loss improved from 0.05575 to 0.05389, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 55ms/step - loss: 0.0016 - val_loss: 0.0539
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 16: val_loss improved from 0.05389 to 0.05040, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0016 - val_loss: 0.0504
# Epoch 17/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 17: val_loss improved from 0.05040 to 0.04855, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0017 - val_loss: 0.0486
# Epoch 18/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 18: val_loss did not improve from 0.04855
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0017 - val_loss: 0.0544
# Epoch 19/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 19: val_loss did not improve from 0.04855
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0015 - val_loss: 0.0502
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 20: val_loss did not improve from 0.04855
# 43/43 [==============================] - 1s 35ms/step - loss: 0.0015 - val_loss: 0.0490
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 21: val_loss improved from 0.04855 to 0.04247, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0013 - val_loss: 0.0425
# Epoch 22/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 22: val_loss did not improve from 0.04247
# 43/43 [==============================] - 2s 55ms/step - loss: 0.0014 - val_loss: 0.0478
# Epoch 23/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 23: val_loss did not improve from 0.04247
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0014 - val_loss: 0.0507
# Epoch 24/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 24: val_loss improved from 0.04247 to 0.04245, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 51ms/step - loss: 0.0014 - val_loss: 0.0425
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 25: val_loss improved from 0.04245 to 0.03955, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0012 - val_loss: 0.0395
# Epoch 26/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 26: val_loss improved from 0.03955 to 0.03505, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 0.0012 - val_loss: 0.0350
# Epoch 27/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 27: val_loss did not improve from 0.03505
# 43/43 [==============================] - 2s 35ms/step - loss: 0.0011 - val_loss: 0.0391
# Epoch 28/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 28: val_loss did not improve from 0.03505
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0011 - val_loss: 0.0386
# Epoch 29/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 29: val_loss did not improve from 0.03505
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0010 - val_loss: 0.0387
# Epoch 30/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 30: val_loss did not improve from 0.03505
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0010 - val_loss: 0.0364
# Epoch 31/100
# 43/43 [==============================] - ETA: 0s - loss: 9.4881e-04
# Epoch 31: val_loss did not improve from 0.03505
# 43/43 [==============================] - 2s 51ms/step - loss: 9.4881e-04 - val_loss: 0.0374
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 9.5138e-04
# Epoch 32: val_loss improved from 0.03505 to 0.03283, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 53ms/step - loss: 9.5138e-04 - val_loss: 0.0328
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.6421e-04
# Epoch 33: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 44ms/step - loss: 9.6213e-04 - val_loss: 0.0400
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 34: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0010 - val_loss: 0.0376
# Epoch 35/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.0344e-04
# Epoch 35: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 46ms/step - loss: 9.0086e-04 - val_loss: 0.0361
# Epoch 36/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.8342e-04
# Epoch 36: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 47ms/step - loss: 8.8440e-04 - val_loss: 0.0357
# Epoch 37/100
# 43/43 [==============================] - ETA: 0s - loss: 9.2713e-04
# Epoch 37: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 49ms/step - loss: 9.2713e-04 - val_loss: 0.0362
# Epoch 38/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.4464e-04
# Epoch 38: val_loss did not improve from 0.03283
# 43/43 [==============================] - 2s 44ms/step - loss: 8.5619e-04 - val_loss: 0.0356
# Epoch 39/100
# 43/43 [==============================] - ETA: 0s - loss: 7.6285e-04
# Epoch 39: val_loss improved from 0.03283 to 0.03110, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 47ms/step - loss: 7.6285e-04 - val_loss: 0.0311
# Epoch 40/100
# 41/43 [===========================>..] - ETA: 0s - loss: 8.5017e-04
# Epoch 40: val_loss did not improve from 0.03110
# 43/43 [==============================] - 1s 33ms/step - loss: 8.3395e-04 - val_loss: 0.0314
# Epoch 41/100
# 43/43 [==============================] - ETA: 0s - loss: 8.7382e-04
# Epoch 41: val_loss improved from 0.03110 to 0.02880, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 32ms/step - loss: 8.7382e-04 - val_loss: 0.0288
# Epoch 42/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.6211e-04
# Epoch 42: val_loss improved from 0.02880 to 0.02817, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 45ms/step - loss: 8.7072e-04 - val_loss: 0.0282
# Epoch 43/100
# 43/43 [==============================] - ETA: 0s - loss: 7.0444e-04
# Epoch 43: val_loss did not improve from 0.02817
# 43/43 [==============================] - 2s 45ms/step - loss: 7.0444e-04 - val_loss: 0.0319
# Epoch 44/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.5682e-04
# Epoch 44: val_loss did not improve from 0.02817
# 43/43 [==============================] - 2s 45ms/step - loss: 6.5507e-04 - val_loss: 0.0341
# Epoch 45/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.6312e-04
# Epoch 45: val_loss improved from 0.02817 to 0.02601, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 54ms/step - loss: 6.7931e-04 - val_loss: 0.0260
# Epoch 46/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.3710e-04
# Epoch 46: val_loss did not improve from 0.02601
# 43/43 [==============================] - 2s 47ms/step - loss: 7.3422e-04 - val_loss: 0.0283
# Epoch 47/100
# 43/43 [==============================] - ETA: 0s - loss: 6.6232e-04
# Epoch 47: val_loss did not improve from 0.02601
# 43/43 [==============================] - 2s 54ms/step - loss: 6.6232e-04 - val_loss: 0.0275
# Epoch 48/100
# 43/43 [==============================] - ETA: 0s - loss: 7.2487e-04
# Epoch 48: val_loss did not improve from 0.02601
# 43/43 [==============================] - 2s 35ms/step - loss: 7.2487e-04 - val_loss: 0.0276
# Epoch 49/100
# 43/43 [==============================] - ETA: 0s - loss: 6.3846e-04
# Epoch 49: val_loss did not improve from 0.02601
# 43/43 [==============================] - 2s 41ms/step - loss: 6.3846e-04 - val_loss: 0.0293
# Epoch 50/100
# 43/43 [==============================] - ETA: 0s - loss: 6.5601e-04
# Epoch 50: val_loss improved from 0.02601 to 0.02547, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 36ms/step - loss: 6.5601e-04 - val_loss: 0.0255
# Epoch 51/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.8469e-04
# Epoch 51: val_loss improved from 0.02547 to 0.02434, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 38ms/step - loss: 5.7921e-04 - val_loss: 0.0243
# Epoch 52/100
# 43/43 [==============================] - ETA: 0s - loss: 6.0681e-04
# Epoch 52: val_loss did not improve from 0.02434
# 43/43 [==============================] - 1s 31ms/step - loss: 6.0681e-04 - val_loss: 0.0274
# Epoch 53/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.8075e-04
# Epoch 53: val_loss did not improve from 0.02434
# 43/43 [==============================] - 1s 35ms/step - loss: 5.8085e-04 - val_loss: 0.0252
# Epoch 54/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.5567e-04
# Epoch 54: val_loss did not improve from 0.02434
# 43/43 [==============================] - 2s 41ms/step - loss: 6.5797e-04 - val_loss: 0.0296
# Epoch 55/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.8538e-04
# Epoch 55: val_loss did not improve from 0.02434
# 43/43 [==============================] - 2s 35ms/step - loss: 5.8105e-04 - val_loss: 0.0250
# Epoch 56/100
# 43/43 [==============================] - ETA: 0s - loss: 5.1412e-04
# Epoch 56: val_loss did not improve from 0.02434
# 43/43 [==============================] - 2s 37ms/step - loss: 5.1412e-04 - val_loss: 0.0247
# Epoch 57/100
# 43/43 [==============================] - ETA: 0s - loss: 7.0479e-04
# Epoch 57: val_loss did not improve from 0.02434
# 43/43 [==============================] - 2s 39ms/step - loss: 7.0479e-04 - val_loss: 0.0244
# Epoch 58/100
# 43/43 [==============================] - ETA: 0s - loss: 5.3341e-04
# Epoch 58: val_loss improved from 0.02434 to 0.02414, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 41ms/step - loss: 5.3341e-04 - val_loss: 0.0241
# Epoch 59/100
# 43/43 [==============================] - ETA: 0s - loss: 6.6414e-04
# Epoch 59: val_loss did not improve from 0.02414
# 43/43 [==============================] - 2s 38ms/step - loss: 6.6414e-04 - val_loss: 0.0297
# Epoch 60/100
# 43/43 [==============================] - ETA: 0s - loss: 5.4764e-04
# Epoch 60: val_loss did not improve from 0.02414
# 43/43 [==============================] - 2s 44ms/step - loss: 5.4764e-04 - val_loss: 0.0267
# Epoch 61/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.2562e-04
# Epoch 61: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 29ms/step - loss: 5.2791e-04 - val_loss: 0.0268
# Epoch 62/100
# 43/43 [==============================] - ETA: 0s - loss: 5.2946e-04
# Epoch 62: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 21ms/step - loss: 5.2946e-04 - val_loss: 0.0255
# Epoch 63/100
# 40/43 [==========================>...] - ETA: 0s - loss: 5.1256e-04
# Epoch 63: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 20ms/step - loss: 5.1450e-04 - val_loss: 0.0258
# Epoch 64/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.2016e-04
# Epoch 64: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 19ms/step - loss: 5.1652e-04 - val_loss: 0.0247
# Epoch 65/100
# 43/43 [==============================] - ETA: 0s - loss: 4.8327e-04
# Epoch 65: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 19ms/step - loss: 4.8327e-04 - val_loss: 0.0253
# Epoch 66/100
# 43/43 [==============================] - ETA: 0s - loss: 5.0812e-04
# Epoch 66: val_loss did not improve from 0.02414
# 43/43 [==============================] - 1s 20ms/step - loss: 5.0812e-04 - val_loss: 0.0276
# Epoch 67/100
# 43/43 [==============================] - ETA: 0s - loss: 4.9738e-04
# Epoch 67: val_loss improved from 0.02414 to 0.02214, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 20ms/step - loss: 4.9738e-04 - val_loss: 0.0221
# Epoch 68/100
# 43/43 [==============================] - ETA: 0s - loss: 5.1415e-04
# Epoch 68: val_loss did not improve from 0.02214
# 43/43 [==============================] - 1s 21ms/step - loss: 5.1415e-04 - val_loss: 0.0234
# Epoch 69/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.0346e-04
# Epoch 69: val_loss did not improve from 0.02214
# 43/43 [==============================] - 1s 28ms/step - loss: 5.0034e-04 - val_loss: 0.0257
# Epoch 70/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.9942e-04
# Epoch 70: val_loss improved from 0.02214 to 0.01883, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 4.9779e-04 - val_loss: 0.0188
# Epoch 71/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.7378e-04
# Epoch 71: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 23ms/step - loss: 4.8725e-04 - val_loss: 0.0263
# Epoch 72/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.9314e-04
# Epoch 72: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 26ms/step - loss: 4.9328e-04 - val_loss: 0.0203
# Epoch 73/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.8233e-04
# Epoch 73: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 24ms/step - loss: 4.8622e-04 - val_loss: 0.0247
# Epoch 74/100
# 43/43 [==============================] - ETA: 0s - loss: 4.9439e-04
# Epoch 74: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 23ms/step - loss: 4.9439e-04 - val_loss: 0.0210
# Epoch 75/100
# 41/43 [===========================>..] - ETA: 0s - loss: 4.6928e-04
# Epoch 75: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 25ms/step - loss: 4.7435e-04 - val_loss: 0.0233
# Epoch 76/100
# 43/43 [==============================] - ETA: 0s - loss: 4.3570e-04
# Epoch 76: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 24ms/step - loss: 4.3570e-04 - val_loss: 0.0203
# Epoch 77/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.4787e-04
# Epoch 77: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 23ms/step - loss: 4.4870e-04 - val_loss: 0.0228
# Epoch 78/100
# 43/43 [==============================] - ETA: 0s - loss: 4.8766e-04
# Epoch 78: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 29ms/step - loss: 4.8766e-04 - val_loss: 0.0219
# Epoch 79/100
# 42/43 [============================>.] - ETA: 0s - loss: 4.9558e-04
# Epoch 79: val_loss did not improve from 0.01883
# 43/43 [==============================] - 1s 29ms/step - loss: 4.9143e-04 - val_loss: 0.0218
# Epoch 80/100
# 43/43 [==============================] - ETA: 0s - loss: 4.2884e-04
# Epoch 80: val_loss did not improve from 0.01883
# 43/43 [==============================] - 2s 37ms/step - loss: 4.2884e-04 - val_loss: 0.0236
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:179564.21920084738
# [31935.91635392924, 179564.21920084738]

# %%
print(predict)
# Out:
# [array([[885994.06]], dtype=float32), array([[709934.4]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

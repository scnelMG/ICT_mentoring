# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0549
# Epoch 1: val_loss improved from inf to 0.00986, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 27ms/step - loss: 0.0533 - val_loss: 0.0099
# Epoch 2/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0159
# Epoch 2: val_loss improved from 0.00986 to 0.00256, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.0026
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 3: val_loss did not improve from 0.00256
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0031
# Epoch 4/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0055
# Epoch 4: val_loss did not improve from 0.00256
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0056 - val_loss: 0.0073
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 5: val_loss did not improve from 0.00256
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 6: val_loss improved from 0.00256 to 0.00237, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0057 - val_loss: 0.0024
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0042
# Epoch 7: val_loss did not improve from 0.00237
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0053
# Epoch 8: val_loss did not improve from 0.00237
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0028
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0035
# Epoch 9: val_loss improved from 0.00237 to 0.00184, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 10: val_loss did not improve from 0.00184
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 11/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 11: val_loss did not improve from 0.00184
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 12: val_loss improved from 0.00184 to 0.00170, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 13/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0028
# Epoch 13: val_loss did not improve from 0.00170
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 14/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0035
# Epoch 14: val_loss did not improve from 0.00170
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 15/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 15: val_loss did not improve from 0.00170
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 16/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0033
# Epoch 16: val_loss improved from 0.00170 to 0.00116, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 18/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0030
# Epoch 18: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 19/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 19: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 20: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 0.0053
# Epoch 21/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0028
# Epoch 21: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 22/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0026
# Epoch 22: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 23/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0029
# Epoch 23: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 24/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 24: val_loss did not improve from 0.00116
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 25/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 25: val_loss did not improve from 0.00116
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 26: val_loss improved from 0.00116 to 0.00106, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 27/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0023
# Epoch 27: val_loss did not improve from 0.00106
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 28: val_loss did not improve from 0.00106
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 29: val_loss did not improve from 0.00106
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 30: val_loss did not improve from 0.00106
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 31/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 31: val_loss did not improve from 0.00106
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 32/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 32: val_loss did not improve from 0.00106
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 33: val_loss improved from 0.00106 to 0.00104, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 34: val_loss did not improve from 0.00104
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 35/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0018
# Epoch 35: val_loss did not improve from 0.00104
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 36: val_loss did not improve from 0.00104
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 37: val_loss did not improve from 0.00104
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 38/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 38: val_loss improved from 0.00104 to 0.00099, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0019 - val_loss: 9.8833e-04
# Epoch 39/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 39: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 40/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 40: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 41/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0014
# Epoch 41: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 42/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 42: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 43/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 43: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 44: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 45/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 45: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 46/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 46: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 47/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 47: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 48/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 48: val_loss did not improve from 0.00099
# 34/34 [==============================] - 1s 26ms/step - loss: 0.0020 - val_loss: 0.0022
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:33895.81822601622
# [33895.81822601622]
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0669
# Epoch 1: val_loss improved from inf to 0.11151, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 7s 44ms/step - loss: 0.0669 - val_loss: 0.1115
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0140
# Epoch 2: val_loss did not improve from 0.11151
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0138 - val_loss: 0.1132
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 3: val_loss did not improve from 0.11151
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0085 - val_loss: 0.1163
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 4: val_loss improved from 0.11151 to 0.09624, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0069 - val_loss: 0.0962
# Epoch 5/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 5: val_loss improved from 0.09624 to 0.09230, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 18ms/step - loss: 0.0053 - val_loss: 0.0923
# Epoch 6/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 6: val_loss improved from 0.09230 to 0.06303, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0048 - val_loss: 0.0630
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 7: val_loss did not improve from 0.06303
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0042 - val_loss: 0.0655
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 8: val_loss improved from 0.06303 to 0.06098, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0037 - val_loss: 0.0610
# Epoch 9/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 9: val_loss improved from 0.06098 to 0.05783, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0038 - val_loss: 0.0578
# Epoch 10/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 10: val_loss did not improve from 0.05783
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0037 - val_loss: 0.0581
# Epoch 11/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 11: val_loss improved from 0.05783 to 0.04302, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0034 - val_loss: 0.0430
# Epoch 12/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 12: val_loss did not improve from 0.04302
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0033 - val_loss: 0.0448
# Epoch 13/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 13: val_loss did not improve from 0.04302
# 43/43 [==============================] - 1s 15ms/step - loss: 0.0028 - val_loss: 0.0482
# Epoch 14/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 14: val_loss improved from 0.04302 to 0.03936, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0028 - val_loss: 0.0394
# Epoch 15/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 15: val_loss improved from 0.03936 to 0.03159, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0025 - val_loss: 0.0316
# Epoch 16/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 16: val_loss improved from 0.03159 to 0.02797, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0026 - val_loss: 0.0280
# Epoch 17/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 17: val_loss did not improve from 0.02797
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0020 - val_loss: 0.0320
# Epoch 18/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 18: val_loss improved from 0.02797 to 0.01962, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0024 - val_loss: 0.0196
# Epoch 19/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 19: val_loss did not improve from 0.01962
# 43/43 [==============================] - 1s 13ms/step - loss: 0.0019 - val_loss: 0.0233
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 20: val_loss improved from 0.01962 to 0.01907, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 15ms/step - loss: 0.0021 - val_loss: 0.0191
# Epoch 21/100
# 38/43 [=========================>....] - ETA: 0s - loss: 0.0020
# Epoch 21: val_loss improved from 0.01907 to 0.01549, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 13ms/step - loss: 0.0019 - val_loss: 0.0155
# Epoch 22/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 22: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 12ms/step - loss: 0.0019 - val_loss: 0.0193
# Epoch 23/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 23: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 13ms/step - loss: 0.0016 - val_loss: 0.0168
# Epoch 24/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 24: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0017 - val_loss: 0.0155
# Epoch 25/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 25: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0016 - val_loss: 0.0175
# Epoch 26/100
# 39/43 [==========================>...] - ETA: 0s - loss: 0.0015
# Epoch 26: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 0.0164
# Epoch 27/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 27: val_loss did not improve from 0.01549
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 0.0166
# Epoch 28/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 28: val_loss improved from 0.01549 to 0.01263, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 0.0126
# Epoch 29/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 29: val_loss improved from 0.01263 to 0.00916, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 0.0092
# Epoch 30/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 30: val_loss did not improve from 0.00916
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0013 - val_loss: 0.0101
# Epoch 31/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 31: val_loss did not improve from 0.00916
# 43/43 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 0.0094
# Epoch 32/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 32: val_loss did not improve from 0.00916
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0012 - val_loss: 0.0119
# Epoch 33/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 33: val_loss improved from 0.00916 to 0.00784, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 0.0078
# Epoch 34/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 34: val_loss improved from 0.00784 to 0.00694, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0010 - val_loss: 0.0069
# Epoch 35/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 35: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 17ms/step - loss: 0.0010 - val_loss: 0.0093
# Epoch 36/100
# 40/43 [==========================>...] - ETA: 0s - loss: 9.9752e-04
# Epoch 36: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0074
# Epoch 37/100
# 40/43 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 37: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0094
# Epoch 38/100
# 42/43 [============================>.] - ETA: 0s - loss: 9.1455e-04
# Epoch 38: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 17ms/step - loss: 9.0986e-04 - val_loss: 0.0121
# Epoch 39/100
# 39/43 [==========================>...] - ETA: 0s - loss: 9.2712e-04
# Epoch 39: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 17ms/step - loss: 9.2084e-04 - val_loss: 0.0085
# Epoch 40/100
# 41/43 [===========================>..] - ETA: 0s - loss: 9.5292e-04
# Epoch 40: val_loss did not improve from 0.00694
# 43/43 [==============================] - 1s 14ms/step - loss: 9.5142e-04 - val_loss: 0.0087
# Epoch 41/100
# 40/43 [==========================>...] - ETA: 0s - loss: 8.5746e-04
# Epoch 41: val_loss improved from 0.00694 to 0.00684, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 17ms/step - loss: 8.6559e-04 - val_loss: 0.0068
# Epoch 42/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.1935e-04
# Epoch 42: val_loss improved from 0.00684 to 0.00521, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 16ms/step - loss: 7.2018e-04 - val_loss: 0.0052
# Epoch 43/100
# 40/43 [==========================>...] - ETA: 0s - loss: 8.3111e-04
# Epoch 43: val_loss improved from 0.00521 to 0.00507, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 8.4252e-04 - val_loss: 0.0051
# Epoch 44/100
# 40/43 [==========================>...] - ETA: 0s - loss: 8.3444e-04
# Epoch 44: val_loss improved from 0.00507 to 0.00463, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 23ms/step - loss: 8.4515e-04 - val_loss: 0.0046
# Epoch 45/100
# 43/43 [==============================] - ETA: 0s - loss: 8.3783e-04
# Epoch 45: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 18ms/step - loss: 8.3783e-04 - val_loss: 0.0081
# Epoch 46/100
# 41/43 [===========================>..] - ETA: 0s - loss: 8.8285e-04
# Epoch 46: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 17ms/step - loss: 8.7875e-04 - val_loss: 0.0053
# Epoch 47/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.1133e-04
# Epoch 47: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 17ms/step - loss: 8.0611e-04 - val_loss: 0.0065
# Epoch 48/100
# 40/43 [==========================>...] - ETA: 0s - loss: 9.3969e-04
# Epoch 48: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 16ms/step - loss: 9.2700e-04 - val_loss: 0.0052
# Epoch 49/100
# 43/43 [==============================] - ETA: 0s - loss: 8.0493e-04
# Epoch 49: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 17ms/step - loss: 8.0493e-04 - val_loss: 0.0049
# Epoch 50/100
# 42/43 [============================>.] - ETA: 0s - loss: 8.1454e-04
# Epoch 50: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 30ms/step - loss: 8.0988e-04 - val_loss: 0.0073
# Epoch 51/100
# 41/43 [===========================>..] - ETA: 0s - loss: 8.9364e-04
# Epoch 51: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 22ms/step - loss: 8.8810e-04 - val_loss: 0.0058
# Epoch 52/100
# 43/43 [==============================] - ETA: 0s - loss: 8.2437e-04
# Epoch 52: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 22ms/step - loss: 8.2437e-04 - val_loss: 0.0058
# Epoch 53/100
# 41/43 [===========================>..] - ETA: 0s - loss: 7.4817e-04
# Epoch 53: val_loss did not improve from 0.00463
# 43/43 [==============================] - 1s 21ms/step - loss: 7.4890e-04 - val_loss: 0.0056
# Epoch 54/100
# 41/43 [===========================>..] - ETA: 0s - loss: 7.6029e-04
# Epoch 54: val_loss improved from 0.00463 to 0.00435, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 19ms/step - loss: 7.6180e-04 - val_loss: 0.0044
# Epoch 55/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.3877e-04
# Epoch 55: val_loss did not improve from 0.00435
# 43/43 [==============================] - 1s 22ms/step - loss: 7.3916e-04 - val_loss: 0.0053
# Epoch 56/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.3118e-04
# Epoch 56: val_loss did not improve from 0.00435
# 43/43 [==============================] - 1s 22ms/step - loss: 7.2865e-04 - val_loss: 0.0046
# Epoch 57/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.7247e-04
# Epoch 57: val_loss improved from 0.00435 to 0.00399, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 7.7929e-04 - val_loss: 0.0040
# Epoch 58/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.7681e-04
# Epoch 58: val_loss improved from 0.00399 to 0.00314, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 30ms/step - loss: 7.7324e-04 - val_loss: 0.0031
# Epoch 59/100
# 41/43 [===========================>..] - ETA: 0s - loss: 7.5438e-04
# Epoch 59: val_loss improved from 0.00314 to 0.00290, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 18ms/step - loss: 7.4009e-04 - val_loss: 0.0029
# Epoch 60/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.0503e-04
# Epoch 60: val_loss did not improve from 0.00290
# 43/43 [==============================] - 1s 23ms/step - loss: 7.0278e-04 - val_loss: 0.0058
# Epoch 61/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.2470e-04
# Epoch 61: val_loss improved from 0.00290 to 0.00255, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 23ms/step - loss: 7.1975e-04 - val_loss: 0.0026
# Epoch 62/100
# 43/43 [==============================] - ETA: 0s - loss: 7.5315e-04
# Epoch 62: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 21ms/step - loss: 7.5315e-04 - val_loss: 0.0085
# Epoch 63/100
# 40/43 [==========================>...] - ETA: 0s - loss: 7.3381e-04
# Epoch 63: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 19ms/step - loss: 7.2555e-04 - val_loss: 0.0034
# Epoch 64/100
# 41/43 [===========================>..] - ETA: 0s - loss: 6.9162e-04
# Epoch 64: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 19ms/step - loss: 6.8118e-04 - val_loss: 0.0033
# Epoch 65/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.6673e-04
# Epoch 65: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 25ms/step - loss: 7.8169e-04 - val_loss: 0.0046
# Epoch 66/100
# 41/43 [===========================>..] - ETA: 0s - loss: 6.7474e-04
# Epoch 66: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 27ms/step - loss: 6.7500e-04 - val_loss: 0.0042
# Epoch 67/100
# 41/43 [===========================>..] - ETA: 0s - loss: 6.7836e-04
# Epoch 67: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 18ms/step - loss: 6.6886e-04 - val_loss: 0.0042
# Epoch 68/100
# 43/43 [==============================] - ETA: 0s - loss: 6.2126e-04
# Epoch 68: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 18ms/step - loss: 6.2126e-04 - val_loss: 0.0047
# Epoch 69/100
# 40/43 [==========================>...] - ETA: 0s - loss: 7.2313e-04
# Epoch 69: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 22ms/step - loss: 7.1797e-04 - val_loss: 0.0030
# Epoch 70/100
# 42/43 [============================>.] - ETA: 0s - loss: 5.7972e-04
# Epoch 70: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 19ms/step - loss: 5.7549e-04 - val_loss: 0.0043
# Epoch 71/100
# 42/43 [============================>.] - ETA: 0s - loss: 7.0205e-04
# Epoch 71: val_loss did not improve from 0.00255
# 43/43 [==============================] - 1s 22ms/step - loss: 7.1935e-04 - val_loss: 0.0057
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:38297.7197130541
# [33895.81822601622, 38297.7197130541]

# %%
print(predict)
# Out:
# [array([[843563.75]], dtype=float32), array([[843105.5]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

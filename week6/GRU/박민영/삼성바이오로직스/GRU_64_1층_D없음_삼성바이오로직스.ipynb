# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.1052
# Epoch 1: val_loss improved from inf to 0.09571, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 5s 43ms/step - loss: 0.1052 - val_loss: 0.0957
# Epoch 2/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0045
# Epoch 2: val_loss improved from 0.09571 to 0.02086, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0209
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 3: val_loss improved from 0.02086 to 0.00890, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0018 - val_loss: 0.0089
# Epoch 4/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0014
# Epoch 4: val_loss improved from 0.00890 to 0.00834, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0083
# Epoch 5/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0012
# Epoch 5: val_loss improved from 0.00834 to 0.00592, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 6: val_loss did not improve from 0.00592
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0063
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.0055e-04
# Epoch 7: val_loss improved from 0.00592 to 0.00398, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 8.9555e-04 - val_loss: 0.0040
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 8.1602e-04
# Epoch 8: val_loss did not improve from 0.00398
# 34/34 [==============================] - 1s 18ms/step - loss: 7.7843e-04 - val_loss: 0.0045
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 6.9110e-04
# Epoch 9: val_loss did not improve from 0.00398
# 34/34 [==============================] - 0s 13ms/step - loss: 6.9110e-04 - val_loss: 0.0044
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 6.5105e-04
# Epoch 10: val_loss improved from 0.00398 to 0.00392, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 6.3626e-04 - val_loss: 0.0039
# Epoch 11/100
# 29/34 [========================>.....] - ETA: 0s - loss: 6.5362e-04
# Epoch 11: val_loss improved from 0.00392 to 0.00325, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 20ms/step - loss: 6.3384e-04 - val_loss: 0.0032
# Epoch 12/100
# 31/34 [==========================>...] - ETA: 0s - loss: 5.0738e-04
# Epoch 12: val_loss did not improve from 0.00325
# 34/34 [==============================] - 1s 19ms/step - loss: 5.0606e-04 - val_loss: 0.0039
# Epoch 13/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.0129e-04
# Epoch 13: val_loss did not improve from 0.00325
# 34/34 [==============================] - 1s 15ms/step - loss: 4.8989e-04 - val_loss: 0.0042
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.6597e-04
# Epoch 14: val_loss improved from 0.00325 to 0.00310, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 4.5581e-04 - val_loss: 0.0031
# Epoch 15/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.7588e-04
# Epoch 15: val_loss improved from 0.00310 to 0.00280, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 4.6836e-04 - val_loss: 0.0028
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.1853e-04
# Epoch 16: val_loss did not improve from 0.00280
# 34/34 [==============================] - 0s 14ms/step - loss: 4.2447e-04 - val_loss: 0.0033
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 4.0622e-04
# Epoch 17: val_loss improved from 0.00280 to 0.00249, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 4.0622e-04 - val_loss: 0.0025
# Epoch 18/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.6000e-04
# Epoch 18: val_loss did not improve from 0.00249
# 34/34 [==============================] - 0s 13ms/step - loss: 3.9566e-04 - val_loss: 0.0029
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5691e-04
# Epoch 19: val_loss did not improve from 0.00249
# 34/34 [==============================] - 0s 12ms/step - loss: 3.7144e-04 - val_loss: 0.0028
# Epoch 20/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.4664e-04
# Epoch 20: val_loss improved from 0.00249 to 0.00192, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 3.5713e-04 - val_loss: 0.0019
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5242e-04
# Epoch 21: val_loss did not improve from 0.00192
# 34/34 [==============================] - 0s 13ms/step - loss: 3.5021e-04 - val_loss: 0.0021
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.6854e-04
# Epoch 22: val_loss did not improve from 0.00192
# 34/34 [==============================] - 0s 12ms/step - loss: 3.6312e-04 - val_loss: 0.0022
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4580e-04
# Epoch 23: val_loss did not improve from 0.00192
# 34/34 [==============================] - 1s 16ms/step - loss: 3.4120e-04 - val_loss: 0.0025
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 3.5114e-04
# Epoch 24: val_loss did not improve from 0.00192
# 34/34 [==============================] - 0s 15ms/step - loss: 3.5114e-04 - val_loss: 0.0033
# Epoch 25/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.2877e-04
# Epoch 25: val_loss improved from 0.00192 to 0.00186, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 3.4904e-04 - val_loss: 0.0019
# Epoch 26/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2870e-04
# Epoch 26: val_loss did not improve from 0.00186
# 34/34 [==============================] - 0s 12ms/step - loss: 3.1951e-04 - val_loss: 0.0020
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 3.1785e-04
# Epoch 27: val_loss improved from 0.00186 to 0.00154, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 3.1785e-04 - val_loss: 0.0015
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0939e-04
# Epoch 28: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 13ms/step - loss: 3.0939e-04 - val_loss: 0.0029
# Epoch 29/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0430e-04
# Epoch 29: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 11ms/step - loss: 3.0900e-04 - val_loss: 0.0017
# Epoch 30/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.0461e-04
# Epoch 30: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0634e-04 - val_loss: 0.0024
# Epoch 31/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.9839e-04
# Epoch 31: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 12ms/step - loss: 2.9162e-04 - val_loss: 0.0025
# Epoch 32/100
# 29/34 [========================>.....] - ETA: 0s - loss: 3.1521e-04
# Epoch 32: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 12ms/step - loss: 3.3556e-04 - val_loss: 0.0029
# Epoch 33/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.1888e-04
# Epoch 33: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 11ms/step - loss: 3.1593e-04 - val_loss: 0.0021
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2331e-04
# Epoch 34: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 11ms/step - loss: 3.3050e-04 - val_loss: 0.0023
# Epoch 35/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.8114e-04
# Epoch 35: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0380e-04 - val_loss: 0.0031
# Epoch 36/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.9967e-04
# Epoch 36: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 12ms/step - loss: 3.0637e-04 - val_loss: 0.0042
# Epoch 37/100
# 34/34 [==============================] - ETA: 0s - loss: 3.3651e-04
# Epoch 37: val_loss did not improve from 0.00154
# 34/34 [==============================] - 0s 11ms/step - loss: 3.3651e-04 - val_loss: 0.0032
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:71171.95990202979
# [71171.95990202979]
# Epoch 1/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0206
# Epoch 1: val_loss improved from inf to 0.01403, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 5s 28ms/step - loss: 0.0199 - val_loss: 0.0140
# Epoch 2/100
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 2: val_loss improved from 0.01403 to 0.00452, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 3/100
# 42/43 [============================>.] - ETA: 0s - loss: 6.7925e-04
# Epoch 3: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 22ms/step - loss: 6.7573e-04 - val_loss: 0.0054
# Epoch 4/100
# 40/43 [==========================>...] - ETA: 0s - loss: 5.2805e-04
# Epoch 4: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 17ms/step - loss: 5.2197e-04 - val_loss: 0.0059
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 4.5684e-04
# Epoch 5: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 16ms/step - loss: 4.5684e-04 - val_loss: 0.0072
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 4.2209e-04
# Epoch 6: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 16ms/step - loss: 4.2209e-04 - val_loss: 0.0072
# Epoch 7/100
# 41/43 [===========================>..] - ETA: 0s - loss: 3.8939e-04
# Epoch 7: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 21ms/step - loss: 3.8828e-04 - val_loss: 0.0063
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.6269e-04
# Epoch 8: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 17ms/step - loss: 3.6036e-04 - val_loss: 0.0068
# Epoch 9/100
# 40/43 [==========================>...] - ETA: 0s - loss: 3.2723e-04
# Epoch 9: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 17ms/step - loss: 3.3784e-04 - val_loss: 0.0072
# Epoch 10/100
# 40/43 [==========================>...] - ETA: 0s - loss: 3.0898e-04
# Epoch 10: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 18ms/step - loss: 3.1086e-04 - val_loss: 0.0098
# Epoch 11/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.9760e-04
# Epoch 11: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 17ms/step - loss: 2.9835e-04 - val_loss: 0.0097
# Epoch 12/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.1012e-04
# Epoch 12: val_loss did not improve from 0.00452
# 43/43 [==============================] - 1s 17ms/step - loss: 3.1158e-04 - val_loss: 0.0095
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:159126.06237384732
# [71171.95990202979, 159126.06237384732]

# %%
print(predict)
# Out:
# [array([[707256.8]], dtype=float32), array([[792163.25]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[건강관리]삼성바이오로직스.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0124
# Epoch 1: val_loss improved from inf to 0.00178, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 10s 126ms/step - loss: 0.0118 - val_loss: 0.0018
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.7220e-04
# Epoch 2: val_loss improved from 0.00178 to 0.00070, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 30ms/step - loss: 8.5364e-04 - val_loss: 7.0288e-04
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 6.3823e-04
# Epoch 3: val_loss did not improve from 0.00070
# 34/34 [==============================] - 1s 37ms/step - loss: 6.3130e-04 - val_loss: 7.5298e-04
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 5.9204e-04
# Epoch 4: val_loss did not improve from 0.00070
# 34/34 [==============================] - 1s 31ms/step - loss: 5.9204e-04 - val_loss: 7.1997e-04
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 4.7126e-04
# Epoch 5: val_loss improved from 0.00070 to 0.00063, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 34ms/step - loss: 4.7340e-04 - val_loss: 6.2794e-04
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.3330e-04
# Epoch 6: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 30ms/step - loss: 4.2817e-04 - val_loss: 0.0011
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 4.9513e-04
# Epoch 7: val_loss did not improve from 0.00063
# 34/34 [==============================] - 1s 34ms/step - loss: 4.9513e-04 - val_loss: 8.9676e-04
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.9460e-04
# Epoch 8: val_loss improved from 0.00063 to 0.00063, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 33ms/step - loss: 4.0185e-04 - val_loss: 6.2662e-04
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.2994e-04
# Epoch 9: val_loss improved from 0.00063 to 0.00056, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 51ms/step - loss: 4.2932e-04 - val_loss: 5.6266e-04
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.5393e-04
# Epoch 10: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 33ms/step - loss: 3.5403e-04 - val_loss: 6.3245e-04
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2113e-04
# Epoch 11: val_loss improved from 0.00056 to 0.00056, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 38ms/step - loss: 3.2113e-04 - val_loss: 5.6044e-04
# Epoch 12/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.2041e-04
# Epoch 12: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 29ms/step - loss: 3.3423e-04 - val_loss: 6.7298e-04
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.0751e-04
# Epoch 13: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 27ms/step - loss: 4.1455e-04 - val_loss: 5.7667e-04
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 3.4474e-04
# Epoch 14: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 25ms/step - loss: 3.4474e-04 - val_loss: 8.7071e-04
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.1866e-04
# Epoch 15: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 26ms/step - loss: 3.1562e-04 - val_loss: 6.8778e-04
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0886e-04
# Epoch 16: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 27ms/step - loss: 3.0886e-04 - val_loss: 0.0010
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8770e-04
# Epoch 17: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 25ms/step - loss: 3.8739e-04 - val_loss: 7.4702e-04
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.0854e-04
# Epoch 18: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 26ms/step - loss: 5.1128e-04 - val_loss: 7.3051e-04
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.7208e-04
# Epoch 19: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 22ms/step - loss: 3.6798e-04 - val_loss: 5.7385e-04
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.1840e-04
# Epoch 20: val_loss did not improve from 0.00056
# 34/34 [==============================] - 1s 25ms/step - loss: 3.2833e-04 - val_loss: 6.8762e-04
# Epoch 21/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.9460e-04
# Epoch 21: val_loss improved from 0.00056 to 0.00053, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 2.8812e-04 - val_loss: 5.3062e-04
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.4580e-04
# Epoch 22: val_loss did not improve from 0.00053
# 34/34 [==============================] - 1s 33ms/step - loss: 3.4812e-04 - val_loss: 5.9387e-04
# Epoch 23/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.5100e-04
# Epoch 23: val_loss did not improve from 0.00053
# 34/34 [==============================] - 1s 26ms/step - loss: 6.3094e-04 - val_loss: 0.0040
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.5904e-04
# Epoch 24: val_loss did not improve from 0.00053
# 34/34 [==============================] - 1s 27ms/step - loss: 5.5035e-04 - val_loss: 7.5841e-04
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0736e-04
# Epoch 25: val_loss did not improve from 0.00053
# 34/34 [==============================] - 1s 37ms/step - loss: 3.0736e-04 - val_loss: 0.0010
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7637e-04
# Epoch 26: val_loss improved from 0.00053 to 0.00049, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 2.8408e-04 - val_loss: 4.8622e-04
# Epoch 27/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4456e-04
# Epoch 27: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 24ms/step - loss: 2.4840e-04 - val_loss: 5.0761e-04
# Epoch 28/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.9384e-04
# Epoch 28: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 24ms/step - loss: 3.0573e-04 - val_loss: 6.8062e-04
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.7438e-04
# Epoch 29: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 25ms/step - loss: 3.6853e-04 - val_loss: 6.2782e-04
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5799e-04
# Epoch 30: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 24ms/step - loss: 3.5690e-04 - val_loss: 0.0010
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 2.6524e-04
# Epoch 31: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 24ms/step - loss: 2.6524e-04 - val_loss: 8.4113e-04
# Epoch 32/100
# 34/34 [==============================] - ETA: 0s - loss: 2.4104e-04
# Epoch 32: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 23ms/step - loss: 2.4104e-04 - val_loss: 4.9732e-04
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2590e-04
# Epoch 33: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 25ms/step - loss: 3.2590e-04 - val_loss: 9.8550e-04
# Epoch 34/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.6600e-04
# Epoch 34: val_loss did not improve from 0.00049
# 34/34 [==============================] - 1s 28ms/step - loss: 2.5997e-04 - val_loss: 5.2825e-04
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2111e-04
# Epoch 35: val_loss improved from 0.00049 to 0.00047, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 3.2111e-04 - val_loss: 4.6625e-04
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 2.8657e-04
# Epoch 36: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 25ms/step - loss: 2.8657e-04 - val_loss: 5.4122e-04
# Epoch 37/100
# 34/34 [==============================] - ETA: 0s - loss: 2.5095e-04
# Epoch 37: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 35ms/step - loss: 2.5095e-04 - val_loss: 6.1461e-04
# Epoch 38/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9134e-04
# Epoch 38: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 32ms/step - loss: 2.8912e-04 - val_loss: 9.5756e-04
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 2.3408e-04
# Epoch 39: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 27ms/step - loss: 2.3408e-04 - val_loss: 5.7180e-04
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.5063e-04
# Epoch 40: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 26ms/step - loss: 2.5160e-04 - val_loss: 4.9989e-04
# Epoch 41/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.5389e-04
# Epoch 41: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 28ms/step - loss: 2.4946e-04 - val_loss: 4.7284e-04
# Epoch 42/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.2840e-04
# Epoch 42: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 25ms/step - loss: 2.3409e-04 - val_loss: 4.9310e-04
# Epoch 43/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.9512e-04
# Epoch 43: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 33ms/step - loss: 2.9817e-04 - val_loss: 5.7239e-04
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0287e-04
# Epoch 44: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 27ms/step - loss: 3.0287e-04 - val_loss: 8.1622e-04
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 2.5314e-04
# Epoch 45: val_loss did not improve from 0.00047
# 34/34 [==============================] - 1s 30ms/step - loss: 2.5314e-04 - val_loss: 5.1923e-04
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:20903.915702108527
# [20903.915702108527]
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 1: val_loss improved from inf to 0.01969, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 15s 107ms/step - loss: 0.0074 - val_loss: 0.0197
# Epoch 2/100
# 43/43 [==============================] - ETA: 0s - loss: 5.7715e-04
# Epoch 2: val_loss improved from 0.01969 to 0.01941, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 38ms/step - loss: 5.7715e-04 - val_loss: 0.0194
# Epoch 3/100
# 43/43 [==============================] - ETA: 0s - loss: 4.1699e-04
# Epoch 3: val_loss improved from 0.01941 to 0.01507, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 4.1699e-04 - val_loss: 0.0151
# Epoch 4/100
# 43/43 [==============================] - ETA: 0s - loss: 3.9465e-04
# Epoch 4: val_loss improved from 0.01507 to 0.01353, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 3.9465e-04 - val_loss: 0.0135
# Epoch 5/100
# 43/43 [==============================] - ETA: 0s - loss: 3.4631e-04
# Epoch 5: val_loss did not improve from 0.01353
# 43/43 [==============================] - 2s 41ms/step - loss: 3.4631e-04 - val_loss: 0.0174
# Epoch 6/100
# 43/43 [==============================] - ETA: 0s - loss: 3.6694e-04
# Epoch 6: val_loss did not improve from 0.01353
# 43/43 [==============================] - 2s 43ms/step - loss: 3.6694e-04 - val_loss: 0.0158
# Epoch 7/100
# 43/43 [==============================] - ETA: 0s - loss: 2.6480e-04
# Epoch 7: val_loss improved from 0.01353 to 0.01082, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 38ms/step - loss: 2.6480e-04 - val_loss: 0.0108
# Epoch 8/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.6661e-04
# Epoch 8: val_loss did not improve from 0.01082
# 43/43 [==============================] - 2s 35ms/step - loss: 2.6653e-04 - val_loss: 0.0123
# Epoch 9/100
# 43/43 [==============================] - ETA: 0s - loss: 2.5773e-04
# Epoch 9: val_loss improved from 0.01082 to 0.01039, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 40ms/step - loss: 2.5773e-04 - val_loss: 0.0104
# Epoch 10/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.6023e-04
# Epoch 10: val_loss did not improve from 0.01039
# 43/43 [==============================] - 1s 28ms/step - loss: 2.5585e-04 - val_loss: 0.0116
# Epoch 11/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3930e-04
# Epoch 11: val_loss improved from 0.01039 to 0.01009, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 27ms/step - loss: 2.3848e-04 - val_loss: 0.0101
# Epoch 12/100
# 43/43 [==============================] - ETA: 0s - loss: 3.2226e-04
# Epoch 12: val_loss did not improve from 0.01009
# 43/43 [==============================] - 1s 19ms/step - loss: 3.2226e-04 - val_loss: 0.0108
# Epoch 13/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3456e-04
# Epoch 13: val_loss improved from 0.01009 to 0.00929, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 25ms/step - loss: 2.3259e-04 - val_loss: 0.0093
# Epoch 14/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.1938e-04
# Epoch 14: val_loss improved from 0.00929 to 0.00874, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 21ms/step - loss: 2.2040e-04 - val_loss: 0.0087
# Epoch 15/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3586e-04
# Epoch 15: val_loss did not improve from 0.00874
# 43/43 [==============================] - 1s 21ms/step - loss: 2.4167e-04 - val_loss: 0.0094
# Epoch 16/100
# 43/43 [==============================] - ETA: 0s - loss: 2.8140e-04
# Epoch 16: val_loss improved from 0.00874 to 0.00579, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 39ms/step - loss: 2.8140e-04 - val_loss: 0.0058
# Epoch 17/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1012e-04
# Epoch 17: val_loss improved from 0.00579 to 0.00550, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 2s 36ms/step - loss: 2.1012e-04 - val_loss: 0.0055
# Epoch 18/100
# 41/43 [===========================>..] - ETA: 0s - loss: 3.3780e-04
# Epoch 18: val_loss did not improve from 0.00550
# 43/43 [==============================] - 1s 28ms/step - loss: 3.3304e-04 - val_loss: 0.0118
# Epoch 19/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3162e-04
# Epoch 19: val_loss did not improve from 0.00550
# 43/43 [==============================] - 1s 26ms/step - loss: 2.2989e-04 - val_loss: 0.0064
# Epoch 20/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.4317e-04
# Epoch 20: val_loss did not improve from 0.00550
# 43/43 [==============================] - 2s 36ms/step - loss: 2.4229e-04 - val_loss: 0.0112
# Epoch 21/100
# 42/43 [============================>.] - ETA: 0s - loss: 3.1475e-04
# Epoch 21: val_loss did not improve from 0.00550
# 43/43 [==============================] - 2s 38ms/step - loss: 3.1988e-04 - val_loss: 0.0112
# Epoch 22/100
# 43/43 [==============================] - ETA: 0s - loss: 3.2777e-04
# Epoch 22: val_loss did not improve from 0.00550
# 43/43 [==============================] - 1s 30ms/step - loss: 3.2777e-04 - val_loss: 0.0108
# Epoch 23/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3744e-04
# Epoch 23: val_loss did not improve from 0.00550
# 43/43 [==============================] - 1s 30ms/step - loss: 2.3733e-04 - val_loss: 0.0065
# Epoch 24/100
# 41/43 [===========================>..] - ETA: 0s - loss: 1.9802e-04
# Epoch 24: val_loss improved from 0.00550 to 0.00538, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 31ms/step - loss: 2.0032e-04 - val_loss: 0.0054
# Epoch 25/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.5802e-04
# Epoch 25: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 33ms/step - loss: 2.5844e-04 - val_loss: 0.0091
# Epoch 26/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.0425e-04
# Epoch 26: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 31ms/step - loss: 2.0333e-04 - val_loss: 0.0079
# Epoch 27/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.0640e-04
# Epoch 27: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 31ms/step - loss: 2.0805e-04 - val_loss: 0.0073
# Epoch 28/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.9526e-04
# Epoch 28: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 31ms/step - loss: 1.9462e-04 - val_loss: 0.0063
# Epoch 29/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.6118e-04
# Epoch 29: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 29ms/step - loss: 2.5888e-04 - val_loss: 0.0080
# Epoch 30/100
# 41/43 [===========================>..] - ETA: 0s - loss: 2.0187e-04
# Epoch 30: val_loss did not improve from 0.00538
# 43/43 [==============================] - 1s 33ms/step - loss: 2.1443e-04 - val_loss: 0.0081
# Epoch 31/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.1696e-04
# Epoch 31: val_loss improved from 0.00538 to 0.00469, saving model to model\tmp_checkpoint.h5
# 43/43 [==============================] - 1s 34ms/step - loss: 2.1938e-04 - val_loss: 0.0047
# Epoch 32/100
# 43/43 [==============================] - ETA: 0s - loss: 1.9313e-04
# Epoch 32: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 28ms/step - loss: 1.9313e-04 - val_loss: 0.0067
# Epoch 33/100
# 42/43 [============================>.] - ETA: 0s - loss: 1.9287e-04
# Epoch 33: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 31ms/step - loss: 1.9444e-04 - val_loss: 0.0095
# Epoch 34/100
# 43/43 [==============================] - ETA: 0s - loss: 1.7575e-04
# Epoch 34: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 27ms/step - loss: 1.7575e-04 - val_loss: 0.0066
# Epoch 35/100
# 43/43 [==============================] - ETA: 0s - loss: 2.3925e-04
# Epoch 35: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 34ms/step - loss: 2.3925e-04 - val_loss: 0.0102
# Epoch 36/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.3590e-04
# Epoch 36: val_loss did not improve from 0.00469
# 43/43 [==============================] - 2s 38ms/step - loss: 2.3766e-04 - val_loss: 0.0048
# Epoch 37/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.8103e-04
# Epoch 37: val_loss did not improve from 0.00469
# 43/43 [==============================] - 2s 40ms/step - loss: 2.7818e-04 - val_loss: 0.0117
# Epoch 38/100
# 43/43 [==============================] - ETA: 0s - loss: 1.8980e-04
# Epoch 38: val_loss did not improve from 0.00469
# 43/43 [==============================] - 3s 59ms/step - loss: 1.8980e-04 - val_loss: 0.0085
# Epoch 39/100
# 43/43 [==============================] - ETA: 0s - loss: 2.1615e-04
# Epoch 39: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 30ms/step - loss: 2.1615e-04 - val_loss: 0.0057
# Epoch 40/100
# 42/43 [============================>.] - ETA: 0s - loss: 2.0423e-04
# Epoch 40: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 33ms/step - loss: 2.0656e-04 - val_loss: 0.0082
# Epoch 41/100
# 43/43 [==============================] - ETA: 0s - loss: 1.8355e-04
# Epoch 41: val_loss did not improve from 0.00469
# 43/43 [==============================] - 1s 28ms/step - loss: 1.8355e-04 - val_loss: 0.0064
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:58852.12008189456
# [20903.915702108527, 58852.12008189456]

# %%
print(predict)
# Out:
# [array([[807304.25]], dtype=float32), array([[811241.56]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0309
# Epoch 1: val_loss improved from inf to 0.05970, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 37ms/step - loss: 0.0283 - val_loss: 0.0597
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0072
# Epoch 2: val_loss did not improve from 0.05970
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0070 - val_loss: 0.0715
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0046
# Epoch 3: val_loss improved from 0.05970 to 0.05026, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0503
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 4: val_loss improved from 0.05026 to 0.02830, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0283
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 5: val_loss did not improve from 0.02830
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0345
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 6: val_loss improved from 0.02830 to 0.02730, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0029 - val_loss: 0.0273
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 7: val_loss did not improve from 0.02730
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0373
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 8: val_loss did not improve from 0.02730
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0366
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0024
# Epoch 9: val_loss improved from 0.02730 to 0.02619, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0024 - val_loss: 0.0262
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 10: val_loss did not improve from 0.02619
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0282
# Epoch 11/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 11: val_loss did not improve from 0.02619
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0358
# Epoch 12/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 12: val_loss improved from 0.02619 to 0.02449, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0245
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 13: val_loss did not improve from 0.02449
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0021 - val_loss: 0.0284
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 14: val_loss improved from 0.02449 to 0.02440, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 0.0244
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 15: val_loss improved from 0.02440 to 0.02011, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0019 - val_loss: 0.0201
# Epoch 16/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 16: val_loss did not improve from 0.02011
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0017 - val_loss: 0.0206
# Epoch 17/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 17: val_loss did not improve from 0.02011
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0264
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 18: val_loss improved from 0.02011 to 0.01678, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 0.0168
# Epoch 19/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 19: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0275
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0209
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 21: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0214
# Epoch 22/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 22: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0169
# Epoch 23/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0016
# Epoch 23: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0017 - val_loss: 0.0220
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 24: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0017 - val_loss: 0.0191
# Epoch 25/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 25: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0214
# Epoch 26/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0016
# Epoch 26: val_loss did not improve from 0.01678
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0205
# Epoch 27/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 27: val_loss improved from 0.01678 to 0.01463, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0146
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 28: val_loss improved from 0.01463 to 0.01345, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0134
# Epoch 29/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss improved from 0.01345 to 0.01093, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0109
# Epoch 30/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 30: val_loss improved from 0.01093 to 0.01019, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0102
# Epoch 31/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0015
# Epoch 31: val_loss did not improve from 0.01019
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0131
# Epoch 32/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 32: val_loss did not improve from 0.01019
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0160
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 33: val_loss improved from 0.01019 to 0.00998, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0100
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00998
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0017 - val_loss: 0.0169
# Epoch 35/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0011
# Epoch 35: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0136
# Epoch 36/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 36: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0150
# Epoch 37/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0010
# Epoch 37: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 38/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 38: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0131
# Epoch 39/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0014
# Epoch 39: val_loss did not improve from 0.00998
# 34/34 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0158
# Epoch 40/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 40: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0124
# Epoch 41/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 41: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0107
# Epoch 42/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 42: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 43/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 43: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0192
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:33766.64211093502
# [33766.64211093502]
# Epoch 1/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0328
# Epoch 1: val_loss improved from inf to 0.00088, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 18ms/step - loss: 0.0311 - val_loss: 8.7766e-04
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 2: val_loss did not improve from 0.00088
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0064 - val_loss: 9.7084e-04
# Epoch 3/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0048
# Epoch 3: val_loss improved from 0.00088 to 0.00052, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 5.2413e-04
# Epoch 4/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 4: val_loss improved from 0.00052 to 0.00015, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0038 - val_loss: 1.5288e-04
# Epoch 5/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 5: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 6.6975e-04
# Epoch 6/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 6: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 8.6625e-04
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 7: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 3.3312e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 8: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0032 - val_loss: 4.5801e-04
# Epoch 9/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 9: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 6.6760e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 10: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 6.0343e-04
# Epoch 11/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 11: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0027 - val_loss: 6.4217e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 12: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0027 - val_loss: 1.9550e-04
# Epoch 13/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 13: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0027 - val_loss: 2.4115e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 14: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 2.4821e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:17019.951464244736
# [33766.64211093502, 17019.951464244736]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0521
# Epoch 1: val_loss improved from inf to 0.00049, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 20ms/step - loss: 0.0515 - val_loss: 4.8894e-04
# Epoch 2/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 2: val_loss improved from 0.00049 to 0.00037, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0088 - val_loss: 3.7005e-04
# Epoch 3/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 3: val_loss improved from 0.00037 to 0.00031, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0062 - val_loss: 3.1035e-04
# Epoch 4/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 4: val_loss did not improve from 0.00031
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0058 - val_loss: 4.4342e-04
# Epoch 5/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 5: val_loss did not improve from 0.00031
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 7.3488e-04
# Epoch 6/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 6: val_loss improved from 0.00031 to 0.00030, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 2.9834e-04
# Epoch 7/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 7: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 5.1429e-04
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 8: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 6.3530e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 9: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 3.4081e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 10: val_loss improved from 0.00030 to 0.00025, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 2.4816e-04
# Epoch 11/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 11: val_loss improved from 0.00025 to 0.00024, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 2.3613e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 12: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0042 - val_loss: 3.3763e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 13: val_loss improved from 0.00024 to 0.00021, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0043 - val_loss: 2.1166e-04
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 14: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 6.3605e-04
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 15: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 2.4332e-04
# Epoch 16/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 16: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0037 - val_loss: 3.3359e-04
# Epoch 17/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 17: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 3.1074e-04
# Epoch 18/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 18: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 5.3159e-04
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 19: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 7.6536e-04
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 20: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 3.1564e-04
# Epoch 21/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 21: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 2.5108e-04
# Epoch 22/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 22: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 3.5250e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 23: val_loss improved from 0.00021 to 0.00019, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 1.8509e-04
# Epoch 24/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 24: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0025 - val_loss: 3.8336e-04
# Epoch 25/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 25: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 4.5758e-04
# Epoch 26/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 26: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0026 - val_loss: 2.8351e-04
# Epoch 27/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 27: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 5.5505e-04
# Epoch 28/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 28: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 2.3619e-04
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 29: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 2.5179e-04
# Epoch 30/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 30: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 2.4031e-04
# Epoch 31/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0018
# Epoch 31: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 3.0928e-04
# Epoch 32/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 32: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 6.5820e-04
# Epoch 33/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 33: val_loss did not improve from 0.00019
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0017 - val_loss: 2.6427e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:9448.316529799342
# [33766.64211093502, 17019.951464244736, 9448.316529799342]
# Epoch 1/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 1: val_loss improved from inf to 0.00071, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 13ms/step - loss: 0.0145 - val_loss: 7.1249e-04
# Epoch 2/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 2: val_loss improved from 0.00071 to 0.00051, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0044 - val_loss: 5.0826e-04
# Epoch 3/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 3: val_loss did not improve from 0.00051
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 4/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 4: val_loss improved from 0.00051 to 0.00026, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0040 - val_loss: 2.6412e-04
# Epoch 5/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 5: val_loss did not improve from 0.00026
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0035 - val_loss: 6.1117e-04
# Epoch 6/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 6: val_loss improved from 0.00026 to 0.00026, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 2.6187e-04
# Epoch 7/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 7: val_loss did not improve from 0.00026
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0031 - val_loss: 5.8161e-04
# Epoch 8/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 8: val_loss did not improve from 0.00026
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 3.5062e-04
# Epoch 9/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 9: val_loss improved from 0.00026 to 0.00025, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0025 - val_loss: 2.5266e-04
# Epoch 10/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 10: val_loss did not improve from 0.00025
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0026 - val_loss: 2.7777e-04
# Epoch 11/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 11: val_loss improved from 0.00025 to 0.00025, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 2.5053e-04
# Epoch 12/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 12: val_loss did not improve from 0.00025
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0024 - val_loss: 6.7744e-04
# Epoch 13/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 13: val_loss improved from 0.00025 to 0.00024, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 2.4176e-04
# Epoch 14/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 14: val_loss did not improve from 0.00024
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0023 - val_loss: 6.3752e-04
# Epoch 15/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 15: val_loss did not improve from 0.00024
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 16/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 16: val_loss did not improve from 0.00024
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 17/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 17: val_loss improved from 0.00024 to 0.00017, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 1.7117e-04
# Epoch 18/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 18: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0017 - val_loss: 4.4096e-04
# Epoch 19/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 19: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0016 - val_loss: 2.6686e-04
# Epoch 20/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 20: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0015 - val_loss: 3.0955e-04
# Epoch 21/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 21: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0015 - val_loss: 8.0418e-04
# Epoch 22/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 22: val_loss did not improve from 0.00017
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 1.9071e-04
# Epoch 23/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 23: val_loss did not improve from 0.00017
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 4.0287e-04
# Epoch 24/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 24: val_loss did not improve from 0.00017
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 6.5016e-04
# Epoch 25/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 25: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0013 - val_loss: 3.7927e-04
# Epoch 26/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 26: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0013 - val_loss: 4.0753e-04
# Epoch 27/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 27: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0013 - val_loss: 2.6007e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:6898.10043082078
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078]
# Epoch 1/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 1: val_loss improved from inf to 0.00124, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 14ms/step - loss: 0.0195 - val_loss: 0.0012
# Epoch 2/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 2: val_loss improved from 0.00124 to 0.00055, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0030 - val_loss: 5.4926e-04
# Epoch 3/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 3: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 4/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 4: val_loss improved from 0.00055 to 0.00037, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0022 - val_loss: 3.7472e-04
# Epoch 5/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 5: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0021 - val_loss: 5.9480e-04
# Epoch 6/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0020 - val_loss: 4.5112e-04
# Epoch 7/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 7: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0017 - val_loss: 4.2758e-04
# Epoch 8/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 8: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0017 - val_loss: 4.4245e-04
# Epoch 9/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0015 - val_loss: 4.9551e-04
# Epoch 10/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 10: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 11/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 11: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0013 - val_loss: 5.6379e-04
# Epoch 12/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 12: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 13/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 13: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 14/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 6.0528e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:7663.4149926221
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221]
# Epoch 1/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 1: val_loss improved from inf to 0.00054, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 4s 14ms/step - loss: 0.0052 - val_loss: 5.3967e-04
# Epoch 2/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 2: val_loss did not improve from 0.00054
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 3: val_loss improved from 0.00054 to 0.00042, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0013 - val_loss: 4.1799e-04
# Epoch 4/100
# 208/209 [============================>.] - ETA: 0s - loss: 9.0175e-04
# Epoch 4: val_loss did not improve from 0.00042
# 209/209 [==============================] - 3s 14ms/step - loss: 9.0329e-04 - val_loss: 8.2796e-04
# Epoch 5/100
# 207/209 [============================>.] - ETA: 0s - loss: 9.3930e-04
# Epoch 5: val_loss did not improve from 0.00042
# 209/209 [==============================] - 3s 12ms/step - loss: 9.3959e-04 - val_loss: 6.1374e-04
# Epoch 6/100
# 205/209 [============================>.] - ETA: 0s - loss: 8.4170e-04
# Epoch 6: val_loss did not improve from 0.00042
# 209/209 [==============================] - 2s 11ms/step - loss: 8.5915e-04 - val_loss: 7.1514e-04
# Epoch 7/100
# 209/209 [==============================] - ETA: 0s - loss: 7.7612e-04
# Epoch 7: val_loss did not improve from 0.00042
# 209/209 [==============================] - 2s 11ms/step - loss: 7.7612e-04 - val_loss: 6.4855e-04
# Epoch 8/100
# 209/209 [==============================] - ETA: 0s - loss: 7.1030e-04
# Epoch 8: val_loss did not improve from 0.00042
# 209/209 [==============================] - 2s 11ms/step - loss: 7.1030e-04 - val_loss: 0.0032
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 6.6880e-04
# Epoch 9: val_loss improved from 0.00042 to 0.00035, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 6.6880e-04 - val_loss: 3.4985e-04
# Epoch 10/100
# 204/209 [============================>.] - ETA: 0s - loss: 5.9076e-04
# Epoch 10: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 10ms/step - loss: 6.0723e-04 - val_loss: 3.5159e-04
# Epoch 11/100
# 209/209 [==============================] - ETA: 0s - loss: 6.6515e-04
# Epoch 11: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 10ms/step - loss: 6.6515e-04 - val_loss: 7.0792e-04
# Epoch 12/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.2294e-04
# Epoch 12: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 11ms/step - loss: 6.2185e-04 - val_loss: 3.5931e-04
# Epoch 13/100
# 206/209 [============================>.] - ETA: 0s - loss: 6.8292e-04
# Epoch 13: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 10ms/step - loss: 6.7892e-04 - val_loss: 0.0034
# Epoch 14/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.0236e-04
# Epoch 14: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 10ms/step - loss: 6.0010e-04 - val_loss: 7.2446e-04
# Epoch 15/100
# 205/209 [============================>.] - ETA: 0s - loss: 5.9614e-04
# Epoch 15: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 10ms/step - loss: 5.9147e-04 - val_loss: 7.5377e-04
# Epoch 16/100
# 206/209 [============================>.] - ETA: 0s - loss: 6.1098e-04
# Epoch 16: val_loss improved from 0.00035 to 0.00035, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 6.0548e-04 - val_loss: 3.4679e-04
# Epoch 17/100
# 209/209 [==============================] - ETA: 0s - loss: 5.6546e-04
# Epoch 17: val_loss did not improve from 0.00035
# 209/209 [==============================] - 2s 11ms/step - loss: 5.6546e-04 - val_loss: 3.5336e-04
# Epoch 18/100
# 205/209 [============================>.] - ETA: 0s - loss: 5.4595e-04
# Epoch 18: val_loss improved from 0.00035 to 0.00034, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 5.4516e-04 - val_loss: 3.3771e-04
# Epoch 19/100
# 205/209 [============================>.] - ETA: 0s - loss: 5.2115e-04
# Epoch 19: val_loss improved from 0.00034 to 0.00031, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 5.1643e-04 - val_loss: 3.1292e-04
# Epoch 20/100
# 208/209 [============================>.] - ETA: 0s - loss: 5.3554e-04
# Epoch 20: val_loss did not improve from 0.00031
# 209/209 [==============================] - 2s 11ms/step - loss: 5.3455e-04 - val_loss: 8.1188e-04
# Epoch 21/100
# 207/209 [============================>.] - ETA: 0s - loss: 5.5904e-04
# Epoch 21: val_loss did not improve from 0.00031
# 209/209 [==============================] - 3s 12ms/step - loss: 5.6086e-04 - val_loss: 3.2792e-04
# Epoch 22/100
# 209/209 [==============================] - ETA: 0s - loss: 4.9861e-04
# Epoch 22: val_loss did not improve from 0.00031
# 209/209 [==============================] - 3s 12ms/step - loss: 4.9861e-04 - val_loss: 0.0016
# Epoch 23/100
# 209/209 [==============================] - ETA: 0s - loss: 6.2690e-04
# Epoch 23: val_loss improved from 0.00031 to 0.00028, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 12ms/step - loss: 6.2690e-04 - val_loss: 2.8096e-04
# Epoch 24/100
# 206/209 [============================>.] - ETA: 0s - loss: 5.7481e-04
# Epoch 24: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.7042e-04 - val_loss: 2.8431e-04
# Epoch 25/100
# 206/209 [============================>.] - ETA: 0s - loss: 5.5454e-04
# Epoch 25: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.5369e-04 - val_loss: 3.6728e-04
# Epoch 26/100
# 205/209 [============================>.] - ETA: 0s - loss: 4.5841e-04
# Epoch 26: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 10ms/step - loss: 4.6223e-04 - val_loss: 5.6639e-04
# Epoch 27/100
# 204/209 [============================>.] - ETA: 0s - loss: 5.7722e-04
# Epoch 27: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 10ms/step - loss: 5.7826e-04 - val_loss: 2.9668e-04
# Epoch 28/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.3777e-04
# Epoch 28: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 6.4010e-04 - val_loss: 9.4584e-04
# Epoch 29/100
# 208/209 [============================>.] - ETA: 0s - loss: 5.3098e-04
# Epoch 29: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.4466e-04 - val_loss: 0.0018
# Epoch 30/100
# 209/209 [==============================] - ETA: 0s - loss: 4.6599e-04
# Epoch 30: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 10ms/step - loss: 4.6599e-04 - val_loss: 5.2201e-04
# Epoch 31/100
# 209/209 [==============================] - ETA: 0s - loss: 5.8371e-04
# Epoch 31: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.8371e-04 - val_loss: 2.9393e-04
# Epoch 32/100
# 205/209 [============================>.] - ETA: 0s - loss: 5.2303e-04
# Epoch 32: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.2350e-04 - val_loss: 0.0010
# Epoch 33/100
# 209/209 [==============================] - ETA: 0s - loss: 5.8948e-04
# Epoch 33: val_loss did not improve from 0.00028
# 209/209 [==============================] - 2s 11ms/step - loss: 5.8948e-04 - val_loss: 5.2177e-04
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:5102.789129319154
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221, 5102.789129319154]
# Epoch 1/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 1: val_loss improved from inf to 0.00191, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 4s 12ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 2/100
# 241/244 [============================>.] - ETA: 0s - loss: 4.7600e-04
# Epoch 2: val_loss did not improve from 0.00191
# 244/244 [==============================] - 3s 10ms/step - loss: 4.7387e-04 - val_loss: 0.0027
# Epoch 3/100
# 241/244 [============================>.] - ETA: 0s - loss: 3.8109e-04
# Epoch 3: val_loss did not improve from 0.00191
# 244/244 [==============================] - 3s 11ms/step - loss: 3.7915e-04 - val_loss: 0.0026
# Epoch 4/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.9912e-04
# Epoch 4: val_loss improved from 0.00191 to 0.00059, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 3s 11ms/step - loss: 2.9826e-04 - val_loss: 5.8521e-04
# Epoch 5/100
# 239/244 [============================>.] - ETA: 0s - loss: 2.8591e-04
# Epoch 5: val_loss did not improve from 0.00059
# 244/244 [==============================] - 2s 10ms/step - loss: 2.8486e-04 - val_loss: 9.9104e-04
# Epoch 6/100
# 241/244 [============================>.] - ETA: 0s - loss: 2.5714e-04
# Epoch 6: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 2.5588e-04 - val_loss: 0.0033
# Epoch 7/100
# 241/244 [============================>.] - ETA: 0s - loss: 2.3057e-04
# Epoch 7: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 2.2965e-04 - val_loss: 0.0038
# Epoch 8/100
# 240/244 [============================>.] - ETA: 0s - loss: 2.0672e-04
# Epoch 8: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 2.0694e-04 - val_loss: 0.0021
# Epoch 9/100
# 241/244 [============================>.] - ETA: 0s - loss: 1.9699e-04
# Epoch 9: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 1.9690e-04 - val_loss: 8.2233e-04
# Epoch 10/100
# 240/244 [============================>.] - ETA: 0s - loss: 1.8323e-04
# Epoch 10: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 10ms/step - loss: 1.8307e-04 - val_loss: 0.0011
# Epoch 11/100
# 244/244 [==============================] - ETA: 0s - loss: 1.9842e-04
# Epoch 11: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 1.9842e-04 - val_loss: 9.1292e-04
# Epoch 12/100
# 240/244 [============================>.] - ETA: 0s - loss: 1.8310e-04
# Epoch 12: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 1.8392e-04 - val_loss: 0.0011
# Epoch 13/100
# 244/244 [==============================] - ETA: 0s - loss: 1.7025e-04
# Epoch 13: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 10ms/step - loss: 1.7025e-04 - val_loss: 0.0017
# Epoch 14/100
# 244/244 [==============================] - ETA: 0s - loss: 1.6574e-04
# Epoch 14: val_loss did not improve from 0.00059
# 244/244 [==============================] - 3s 11ms/step - loss: 1.6574e-04 - val_loss: 0.0026
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:7971.535113623194
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221, 5102.789129319154, 7971.535113623194]
# Epoch 1/100
# 278/279 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 1: val_loss improved from inf to 0.00090, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 5s 13ms/step - loss: 0.0028 - val_loss: 8.9621e-04
# Epoch 2/100
# 276/279 [============================>.] - ETA: 0s - loss: 3.8159e-04
# Epoch 2: val_loss did not improve from 0.00090
# 279/279 [==============================] - 3s 11ms/step - loss: 3.8119e-04 - val_loss: 9.2078e-04
# Epoch 3/100
# 275/279 [============================>.] - ETA: 0s - loss: 2.7350e-04
# Epoch 3: val_loss did not improve from 0.00090
# 279/279 [==============================] - 3s 11ms/step - loss: 2.7270e-04 - val_loss: 0.0011
# Epoch 4/100
# 275/279 [============================>.] - ETA: 0s - loss: 2.1906e-04
# Epoch 4: val_loss improved from 0.00090 to 0.00050, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 11ms/step - loss: 2.1869e-04 - val_loss: 5.0427e-04
# Epoch 5/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.9592e-04
# Epoch 5: val_loss improved from 0.00050 to 0.00048, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 12ms/step - loss: 1.9587e-04 - val_loss: 4.8427e-04
# Epoch 6/100
# 274/279 [============================>.] - ETA: 0s - loss: 1.7859e-04
# Epoch 6: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 12ms/step - loss: 1.7825e-04 - val_loss: 5.7484e-04
# Epoch 7/100
# 279/279 [==============================] - ETA: 0s - loss: 1.6362e-04
# Epoch 7: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 11ms/step - loss: 1.6362e-04 - val_loss: 5.7019e-04
# Epoch 8/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.4771e-04
# Epoch 8: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 10ms/step - loss: 1.4860e-04 - val_loss: 5.7097e-04
# Epoch 9/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.5203e-04
# Epoch 9: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 12ms/step - loss: 1.5340e-04 - val_loss: 0.0038
# Epoch 10/100
# 274/279 [============================>.] - ETA: 0s - loss: 1.5720e-04
# Epoch 10: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 11ms/step - loss: 1.5639e-04 - val_loss: 9.9750e-04
# Epoch 11/100
# 275/279 [============================>.] - ETA: 0s - loss: 1.4169e-04
# Epoch 11: val_loss did not improve from 0.00048
# 279/279 [==============================] - 3s 12ms/step - loss: 1.4152e-04 - val_loss: 4.8925e-04
# Epoch 12/100
# 279/279 [==============================] - ETA: 0s - loss: 1.2798e-04
# Epoch 12: val_loss improved from 0.00048 to 0.00042, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 10ms/step - loss: 1.2798e-04 - val_loss: 4.2408e-04
# Epoch 13/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.2251e-04
# Epoch 13: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.2194e-04 - val_loss: 5.3362e-04
# Epoch 14/100
# 276/279 [============================>.] - ETA: 0s - loss: 1.3554e-04
# Epoch 14: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.3621e-04 - val_loss: 0.0019
# Epoch 15/100
# 274/279 [============================>.] - ETA: 0s - loss: 1.3256e-04
# Epoch 15: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.3201e-04 - val_loss: 5.0727e-04
# Epoch 16/100
# 276/279 [============================>.] - ETA: 0s - loss: 1.3480e-04
# Epoch 16: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 12ms/step - loss: 1.3411e-04 - val_loss: 0.0014
# Epoch 17/100
# 275/279 [============================>.] - ETA: 0s - loss: 1.2639e-04
# Epoch 17: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 10ms/step - loss: 1.2612e-04 - val_loss: 0.0017
# Epoch 18/100
# 279/279 [==============================] - ETA: 0s - loss: 1.2761e-04
# Epoch 18: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.2761e-04 - val_loss: 0.0027
# Epoch 19/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.1894e-04
# Epoch 19: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 10ms/step - loss: 1.1887e-04 - val_loss: 0.0018
# Epoch 20/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.1689e-04
# Epoch 20: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.1668e-04 - val_loss: 0.0038
# Epoch 21/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.1628e-04
# Epoch 21: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 10ms/step - loss: 1.1673e-04 - val_loss: 7.4543e-04
# Epoch 22/100
# 274/279 [============================>.] - ETA: 0s - loss: 1.1260e-04
# Epoch 22: val_loss did not improve from 0.00042
# 279/279 [==============================] - 3s 11ms/step - loss: 1.1278e-04 - val_loss: 0.0023
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:12655.984667503575
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221, 5102.789129319154, 7971.535113623194, 12655.984667503575]
# Epoch 1/100
# 314/314 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 1: val_loss improved from inf to 0.00170, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 5s 13ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 2/100
# 312/314 [============================>.] - ETA: 0s - loss: 2.2027e-04
# Epoch 2: val_loss improved from 0.00170 to 0.00063, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 4s 12ms/step - loss: 2.1962e-04 - val_loss: 6.2888e-04
# Epoch 3/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.7886e-04
# Epoch 3: val_loss improved from 0.00063 to 0.00038, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 4s 12ms/step - loss: 1.7831e-04 - val_loss: 3.8244e-04
# Epoch 4/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.3381e-04
# Epoch 4: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 11ms/step - loss: 1.3365e-04 - val_loss: 6.4050e-04
# Epoch 5/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.1446e-04
# Epoch 5: val_loss did not improve from 0.00038
# 314/314 [==============================] - 4s 12ms/step - loss: 1.1420e-04 - val_loss: 6.7828e-04
# Epoch 6/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0223e-04
# Epoch 6: val_loss did not improve from 0.00038
# 314/314 [==============================] - 4s 11ms/step - loss: 1.0223e-04 - val_loss: 5.5261e-04
# Epoch 7/100
# 312/314 [============================>.] - ETA: 0s - loss: 9.6796e-05
# Epoch 7: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 10ms/step - loss: 9.6646e-05 - val_loss: 0.0046
# Epoch 8/100
# 314/314 [==============================] - ETA: 0s - loss: 9.5527e-05
# Epoch 8: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 11ms/step - loss: 9.5527e-05 - val_loss: 0.0022
# Epoch 9/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0100e-04
# Epoch 9: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 11ms/step - loss: 1.0100e-04 - val_loss: 9.1626e-04
# Epoch 10/100
# 314/314 [==============================] - ETA: 0s - loss: 9.6295e-05
# Epoch 10: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 11ms/step - loss: 9.6295e-05 - val_loss: 4.7823e-04
# Epoch 11/100
# 314/314 [==============================] - ETA: 0s - loss: 8.8666e-05
# Epoch 11: val_loss did not improve from 0.00038
# 314/314 [==============================] - 4s 11ms/step - loss: 8.8666e-05 - val_loss: 8.3383e-04
# Epoch 12/100
# 314/314 [==============================] - ETA: 0s - loss: 8.1107e-05
# Epoch 12: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 10ms/step - loss: 8.1107e-05 - val_loss: 7.2352e-04
# Epoch 13/100
# 310/314 [============================>.] - ETA: 0s - loss: 7.8832e-05
# Epoch 13: val_loss did not improve from 0.00038
# 314/314 [==============================] - 3s 11ms/step - loss: 7.8128e-05 - val_loss: 6.1169e-04
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:9796.64938838029
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221, 5102.789129319154, 7971.535113623194, 12655.984667503575, 9796.64938838029]
# Epoch 1/100
# 337/341 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 1: val_loss improved from inf to 0.00075, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 6s 13ms/step - loss: 0.0020 - val_loss: 7.5268e-04
# Epoch 2/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.5541e-04
# Epoch 2: val_loss improved from 0.00075 to 0.00028, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 13ms/step - loss: 1.5535e-04 - val_loss: 2.7954e-04
# Epoch 3/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.0404e-04
# Epoch 3: val_loss improved from 0.00028 to 0.00018, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 13ms/step - loss: 1.0365e-04 - val_loss: 1.7566e-04
# Epoch 4/100
# 337/341 [============================>.] - ETA: 0s - loss: 7.6114e-05
# Epoch 4: val_loss improved from 0.00018 to 0.00013, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 13ms/step - loss: 7.6217e-05 - val_loss: 1.3305e-04
# Epoch 5/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.4193e-05
# Epoch 5: val_loss did not improve from 0.00013
# 341/341 [==============================] - 5s 14ms/step - loss: 6.4119e-05 - val_loss: 2.9119e-04
# Epoch 6/100
# 341/341 [==============================] - ETA: 0s - loss: 5.7147e-05
# Epoch 6: val_loss did not improve from 0.00013
# 341/341 [==============================] - 4s 13ms/step - loss: 5.7147e-05 - val_loss: 2.5591e-04
# Epoch 7/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.2552e-05
# Epoch 7: val_loss did not improve from 0.00013
# 341/341 [==============================] - 5s 13ms/step - loss: 5.2579e-05 - val_loss: 2.2248e-04
# Epoch 8/100
# 338/341 [============================>.] - ETA: 0s - loss: 5.1566e-05
# Epoch 8: val_loss did not improve from 0.00013
# 341/341 [==============================] - 5s 14ms/step - loss: 5.1456e-05 - val_loss: 1.3913e-04
# Epoch 9/100
# 338/341 [============================>.] - ETA: 0s - loss: 4.4519e-05
# Epoch 9: val_loss improved from 0.00013 to 0.00012, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 13ms/step - loss: 4.4431e-05 - val_loss: 1.2361e-04
# Epoch 10/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.0213e-05
# Epoch 10: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 13ms/step - loss: 4.0222e-05 - val_loss: 1.7341e-04
# Epoch 11/100
# 338/341 [============================>.] - ETA: 0s - loss: 4.9061e-05
# Epoch 11: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 13ms/step - loss: 4.8935e-05 - val_loss: 5.4228e-04
# Epoch 12/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.2814e-05
# Epoch 12: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 13ms/step - loss: 4.2672e-05 - val_loss: 3.6431e-04
# Epoch 13/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.1554e-05
# Epoch 13: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 14ms/step - loss: 4.1608e-05 - val_loss: 3.2544e-04
# Epoch 14/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.9918e-05
# Epoch 14: val_loss did not improve from 0.00012
# 341/341 [==============================] - 4s 13ms/step - loss: 3.9920e-05 - val_loss: 1.5792e-04
# Epoch 15/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.1602e-05
# Epoch 15: val_loss did not improve from 0.00012
# 341/341 [==============================] - 4s 13ms/step - loss: 4.2003e-05 - val_loss: 2.1449e-04
# Epoch 16/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.8667e-05
# Epoch 16: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 13ms/step - loss: 3.8612e-05 - val_loss: 0.0011
# Epoch 17/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.0358e-05
# Epoch 17: val_loss did not improve from 0.00012
# 341/341 [==============================] - 4s 13ms/step - loss: 4.0335e-05 - val_loss: 4.3735e-04
# Epoch 18/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.9588e-05
# Epoch 18: val_loss did not improve from 0.00012
# 341/341 [==============================] - 5s 13ms/step - loss: 3.9439e-05 - val_loss: 3.6754e-04
# Epoch 19/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.8113e-05
# Epoch 19: val_loss did not improve from 0.00012
# 341/341 [==============================] - 4s 13ms/step - loss: 3.8496e-05 - val_loss: 3.5075e-04
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:28122.280444056818
# [33766.64211093502, 17019.951464244736, 9448.316529799342, 6898.10043082078, 7663.4149926221, 5102.789129319154, 7971.535113623194, 12655.984667503575, 9796.64938838029, 28122.280444056818]

# %%
print(predict)
# Out:
# [array([[175249.42]], dtype=float32), array([[173630.4]], dtype=float32), array([[190714.39]], dtype=float32), array([[191914.25]], dtype=float32), array([[196749.73]], dtype=float32), array([[195550.17]], dtype=float32), array([[196914.]], dtype=float32), array([[197142.16]], dtype=float32), array([[188532.19]], dtype=float32), array([[170531.75]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

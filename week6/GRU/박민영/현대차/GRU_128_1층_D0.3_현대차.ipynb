# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(128, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0497
# Epoch 1: val_loss improved from inf to 0.03475, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 33ms/step - loss: 0.0469 - val_loss: 0.0348
# Epoch 2/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0137
# Epoch 2: val_loss improved from 0.03475 to 0.02788, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0132 - val_loss: 0.0279
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 3: val_loss improved from 0.02788 to 0.01621, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0069 - val_loss: 0.0162
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 4: val_loss did not improve from 0.01621
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0048 - val_loss: 0.0218
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0044
# Epoch 5: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0264
# Epoch 6/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 6: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0216
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 7: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0276
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 8: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0286
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 9: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0227
# Epoch 10/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 10: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0208
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 11: val_loss did not improve from 0.01621
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0032 - val_loss: 0.0216
# Epoch 12/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 12: val_loss did not improve from 0.01621
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0031 - val_loss: 0.0207
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 13: val_loss did not improve from 0.01621
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0199
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:33947.99402602303
# [33947.99402602303]
# Epoch 1/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0372
# Epoch 1: val_loss improved from inf to 0.00147, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 21ms/step - loss: 0.0355 - val_loss: 0.0015
# Epoch 2/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0088
# Epoch 2: val_loss improved from 0.00147 to 0.00063, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0086 - val_loss: 6.3292e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 3: val_loss improved from 0.00063 to 0.00040, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 3.9896e-04
# Epoch 4/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0061
# Epoch 4: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0060 - val_loss: 7.1498e-04
# Epoch 5/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 5: val_loss did not improve from 0.00040
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 5.0472e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 6: val_loss improved from 0.00040 to 0.00029, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 2.8680e-04
# Epoch 7/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0051
# Epoch 7: val_loss improved from 0.00029 to 0.00019, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0051 - val_loss: 1.8775e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 8: val_loss improved from 0.00019 to 0.00017, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 1.6778e-04
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 9: val_loss did not improve from 0.00017
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0049 - val_loss: 1.9445e-04
# Epoch 10/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 10: val_loss did not improve from 0.00017
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0045 - val_loss: 3.1033e-04
# Epoch 11/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 11: val_loss did not improve from 0.00017
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 2.7016e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 12: val_loss improved from 0.00017 to 0.00017, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0044 - val_loss: 1.6630e-04
# Epoch 13/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 13: val_loss improved from 0.00017 to 0.00014, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 1.3900e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 14: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 15/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 15: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0036 - val_loss: 1.4513e-04
# Epoch 16/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 16: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0033 - val_loss: 2.1250e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 17: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0038 - val_loss: 1.6367e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 18: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0032 - val_loss: 1.4784e-04
# Epoch 19/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 19: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 3.9750e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0028 - val_loss: 1.6152e-04
# Epoch 21/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 21: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 3.9013e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 22: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0021 - val_loss: 2.7046e-04
# Epoch 23/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 23: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 2.1477e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:13817.43637609732
# [33947.99402602303, 13817.43637609732]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0504
# Epoch 1: val_loss improved from inf to 0.00317, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 17ms/step - loss: 0.0498 - val_loss: 0.0032
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 2: val_loss improved from 0.00317 to 0.00032, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0102 - val_loss: 3.1585e-04
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0086
# Epoch 3: val_loss improved from 0.00032 to 0.00031, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0085 - val_loss: 3.0812e-04
# Epoch 4/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 4: val_loss improved from 0.00031 to 0.00029, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0078 - val_loss: 2.8546e-04
# Epoch 5/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0075
# Epoch 5: val_loss improved from 0.00029 to 0.00021, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0075 - val_loss: 2.1043e-04
# Epoch 6/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 6: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0076 - val_loss: 2.7668e-04
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0071 - val_loss: 5.1287e-04
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 8: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 9/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0070
# Epoch 9: val_loss did not improve from 0.00021
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0069 - val_loss: 5.6274e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 10: val_loss improved from 0.00021 to 0.00020, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0062 - val_loss: 1.9502e-04
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 11: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 4.3002e-04
# Epoch 12/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 12: val_loss improved from 0.00020 to 0.00017, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0053 - val_loss: 1.7423e-04
# Epoch 13/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 13: val_loss improved from 0.00017 to 0.00016, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0055 - val_loss: 1.5856e-04
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 14: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 2.9954e-04
# Epoch 15/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 15: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 2.9144e-04
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 16: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 17/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 17: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0042 - val_loss: 1.6440e-04
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 18: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0042 - val_loss: 2.5239e-04
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 19: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0037 - val_loss: 1.8777e-04
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 20: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0035 - val_loss: 4.2466e-04
# Epoch 21/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 21: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 7.2025e-04
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 22: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 3.1854e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 23: val_loss did not improve from 0.00016
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0029 - val_loss: 2.5330e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:16156.820914048252
# [33947.99402602303, 13817.43637609732, 16156.820914048252]
# Epoch 1/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0382
# Epoch 1: val_loss improved from inf to 0.00037, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 14ms/step - loss: 0.0382 - val_loss: 3.6973e-04
# Epoch 2/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 2: val_loss did not improve from 0.00037
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0077 - val_loss: 0.0010
# Epoch 3/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 3: val_loss improved from 0.00037 to 0.00026, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0069 - val_loss: 2.6462e-04
# Epoch 4/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 4: val_loss did not improve from 0.00026
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0060 - val_loss: 2.7473e-04
# Epoch 5/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 5: val_loss improved from 0.00026 to 0.00025, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0059 - val_loss: 2.5223e-04
# Epoch 6/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 6: val_loss did not improve from 0.00025
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 7/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 7: val_loss improved from 0.00025 to 0.00021, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0054 - val_loss: 2.0716e-04
# Epoch 8/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 8: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0051 - val_loss: 2.6953e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 9: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0047 - val_loss: 3.3891e-04
# Epoch 10/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0040
# Epoch 10: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0040 - val_loss: 2.2929e-04
# Epoch 11/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 11: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0042 - val_loss: 2.6470e-04
# Epoch 12/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0037 - val_loss: 2.3575e-04
# Epoch 13/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 13: val_loss did not improve from 0.00021
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0036 - val_loss: 3.4863e-04
# Epoch 14/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 14: val_loss improved from 0.00021 to 0.00017, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 1.6953e-04
# Epoch 15/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0032 - val_loss: 2.3800e-04
# Epoch 16/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 16: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0029 - val_loss: 4.7339e-04
# Epoch 17/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 17: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 18/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 18: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0026 - val_loss: 5.9755e-04
# Epoch 19/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 19: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0029 - val_loss: 1.7184e-04
# Epoch 20/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 20: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0026 - val_loss: 2.2339e-04
# Epoch 21/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 21: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0023 - val_loss: 5.7419e-04
# Epoch 22/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 23/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 23: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0023 - val_loss: 3.0830e-04
# Epoch 24/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 24: val_loss did not improve from 0.00017
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0021 - val_loss: 5.5631e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:11613.540974674681
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681]
# Epoch 1/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0136
# Epoch 1: val_loss improved from inf to 0.00238, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 14ms/step - loss: 0.0134 - val_loss: 0.0024
# Epoch 2/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 2: val_loss improved from 0.00238 to 0.00051, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0038 - val_loss: 5.1032e-04
# Epoch 3/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 3: val_loss improved from 0.00051 to 0.00037, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 3.6682e-04
# Epoch 4/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 4: val_loss improved from 0.00037 to 0.00030, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 3.0135e-04
# Epoch 5/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 5: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 6/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 6: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 7/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 7: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0024 - val_loss: 4.3742e-04
# Epoch 8/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 8: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 3.2564e-04
# Epoch 9/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 9: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 9.3228e-04
# Epoch 10/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 10: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0020 - val_loss: 5.2878e-04
# Epoch 11/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 11: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 12/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 12: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0019 - val_loss: 7.6721e-04
# Epoch 13/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 13: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 7.2077e-04
# Epoch 14/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 14: val_loss did not improve from 0.00030
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 8.9391e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:9297.123500310003
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003]
# Epoch 1/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 1: val_loss improved from inf to 0.00184, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 4s 14ms/step - loss: 0.0079 - val_loss: 0.0018
# Epoch 2/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 2: val_loss improved from 0.00184 to 0.00048, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 14ms/step - loss: 0.0022 - val_loss: 4.7520e-04
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 3: val_loss improved from 0.00048 to 0.00046, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 13ms/step - loss: 0.0016 - val_loss: 4.6161e-04
# Epoch 4/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 4: val_loss did not improve from 0.00046
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 5/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00046
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 6/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss improved from 0.00046 to 0.00038, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 3.8171e-04
# Epoch 7/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 7: val_loss did not improve from 0.00038
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 8/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 8: val_loss did not improve from 0.00038
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0010 - val_loss: 4.5859e-04
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 9.5809e-04
# Epoch 9: val_loss did not improve from 0.00038
# 209/209 [==============================] - 2s 12ms/step - loss: 9.5809e-04 - val_loss: 0.0010
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - loss: 9.6422e-04
# Epoch 10: val_loss did not improve from 0.00038
# 209/209 [==============================] - 3s 13ms/step - loss: 9.6422e-04 - val_loss: 4.0420e-04
# Epoch 11/100
# 207/209 [============================>.] - ETA: 0s - loss: 8.0379e-04
# Epoch 11: val_loss did not improve from 0.00038
# 209/209 [==============================] - 3s 12ms/step - loss: 7.9970e-04 - val_loss: 4.2802e-04
# Epoch 12/100
# 206/209 [============================>.] - ETA: 0s - loss: 9.0944e-04
# Epoch 12: val_loss did not improve from 0.00038
# 209/209 [==============================] - 2s 12ms/step - loss: 9.1090e-04 - val_loss: 7.5286e-04
# Epoch 13/100
# 208/209 [============================>.] - ETA: 0s - loss: 9.7693e-04
# Epoch 13: val_loss improved from 0.00038 to 0.00036, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 11ms/step - loss: 9.8180e-04 - val_loss: 3.5653e-04
# Epoch 14/100
# 208/209 [============================>.] - ETA: 0s - loss: 8.4587e-04
# Epoch 14: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 15ms/step - loss: 8.5092e-04 - val_loss: 0.0026
# Epoch 15/100
# 206/209 [============================>.] - ETA: 0s - loss: 8.9163e-04
# Epoch 15: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 13ms/step - loss: 8.8588e-04 - val_loss: 6.8538e-04
# Epoch 16/100
# 205/209 [============================>.] - ETA: 0s - loss: 7.2261e-04
# Epoch 16: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 13ms/step - loss: 7.2627e-04 - val_loss: 0.0034
# Epoch 17/100
# 207/209 [============================>.] - ETA: 0s - loss: 7.5757e-04
# Epoch 17: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 14ms/step - loss: 7.5883e-04 - val_loss: 7.7733e-04
# Epoch 18/100
# 206/209 [============================>.] - ETA: 0s - loss: 8.6013e-04
# Epoch 18: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 13ms/step - loss: 8.5391e-04 - val_loss: 6.6971e-04
# Epoch 19/100
# 205/209 [============================>.] - ETA: 0s - loss: 7.4107e-04
# Epoch 19: val_loss did not improve from 0.00036
# 209/209 [==============================] - 3s 13ms/step - loss: 7.4325e-04 - val_loss: 4.7914e-04
# Epoch 20/100
# 207/209 [============================>.] - ETA: 0s - loss: 7.7709e-04
# Epoch 20: val_loss did not improve from 0.00036
# 209/209 [==============================] - 2s 11ms/step - loss: 7.7382e-04 - val_loss: 5.0077e-04
# Epoch 21/100
# 209/209 [==============================] - ETA: 0s - loss: 8.0398e-04
# Epoch 21: val_loss did not improve from 0.00036
# 209/209 [==============================] - 2s 11ms/step - loss: 8.0398e-04 - val_loss: 0.0024
# Epoch 22/100
# 207/209 [============================>.] - ETA: 0s - loss: 8.6037e-04
# Epoch 22: val_loss did not improve from 0.00036
# 209/209 [==============================] - 2s 11ms/step - loss: 8.6055e-04 - val_loss: 4.7404e-04
# Epoch 23/100
# 205/209 [============================>.] - ETA: 0s - loss: 7.5309e-04
# Epoch 23: val_loss did not improve from 0.00036
# 209/209 [==============================] - 2s 11ms/step - loss: 7.5414e-04 - val_loss: 6.6159e-04
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:6894.583289892997
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003, 6894.583289892997]
# Epoch 1/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 1: val_loss improved from inf to 0.00323, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 4s 13ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 2/100
# 243/244 [============================>.] - ETA: 0s - loss: 6.0764e-04
# Epoch 2: val_loss improved from 0.00323 to 0.00116, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 3s 12ms/step - loss: 6.0626e-04 - val_loss: 0.0012
# Epoch 3/100
# 244/244 [==============================] - ETA: 0s - loss: 4.9071e-04
# Epoch 3: val_loss improved from 0.00116 to 0.00087, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 3s 12ms/step - loss: 4.9071e-04 - val_loss: 8.7123e-04
# Epoch 4/100
# 243/244 [============================>.] - ETA: 0s - loss: 3.7030e-04
# Epoch 4: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 12ms/step - loss: 3.7002e-04 - val_loss: 0.0020
# Epoch 5/100
# 243/244 [============================>.] - ETA: 0s - loss: 3.3413e-04
# Epoch 5: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 14ms/step - loss: 3.3334e-04 - val_loss: 0.0078
# Epoch 6/100
# 241/244 [============================>.] - ETA: 0s - loss: 3.1261e-04
# Epoch 6: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 14ms/step - loss: 3.1390e-04 - val_loss: 0.0010
# Epoch 7/100
# 244/244 [==============================] - ETA: 0s - loss: 3.0307e-04
# Epoch 7: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 13ms/step - loss: 3.0307e-04 - val_loss: 0.0047
# Epoch 8/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.7578e-04
# Epoch 8: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 13ms/step - loss: 2.7494e-04 - val_loss: 0.0023
# Epoch 9/100
# 242/244 [============================>.] - ETA: 0s - loss: 2.6127e-04
# Epoch 9: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 14ms/step - loss: 2.6161e-04 - val_loss: 0.0093
# Epoch 10/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.5877e-04
# Epoch 10: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 13ms/step - loss: 2.6118e-04 - val_loss: 0.0017
# Epoch 11/100
# 244/244 [==============================] - ETA: 0s - loss: 2.5861e-04
# Epoch 11: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 13ms/step - loss: 2.5861e-04 - val_loss: 0.0078
# Epoch 12/100
# 241/244 [============================>.] - ETA: 0s - loss: 2.3729e-04
# Epoch 12: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 13ms/step - loss: 2.3708e-04 - val_loss: 0.0041
# Epoch 13/100
# 240/244 [============================>.] - ETA: 0s - loss: 2.6159e-04
# Epoch 13: val_loss did not improve from 0.00087
# 244/244 [==============================] - 3s 12ms/step - loss: 2.6103e-04 - val_loss: 0.0083
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:15019.456452133621
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003, 6894.583289892997, 15019.456452133621]
# Epoch 1/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 1: val_loss improved from inf to 0.00112, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 5s 14ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 2/100
# 275/279 [============================>.] - ETA: 0s - loss: 5.3339e-04
# Epoch 2: val_loss did not improve from 0.00112
# 279/279 [==============================] - 4s 13ms/step - loss: 5.3243e-04 - val_loss: 0.0022
# Epoch 3/100
# 275/279 [============================>.] - ETA: 0s - loss: 3.9904e-04
# Epoch 3: val_loss did not improve from 0.00112
# 279/279 [==============================] - 4s 14ms/step - loss: 3.9943e-04 - val_loss: 0.0012
# Epoch 4/100
# 279/279 [==============================] - ETA: 0s - loss: 3.1695e-04
# Epoch 4: val_loss did not improve from 0.00112
# 279/279 [==============================] - 4s 13ms/step - loss: 3.1695e-04 - val_loss: 0.0012
# Epoch 5/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.8826e-04
# Epoch 5: val_loss improved from 0.00112 to 0.00084, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 4s 13ms/step - loss: 2.8743e-04 - val_loss: 8.3744e-04
# Epoch 6/100
# 279/279 [==============================] - ETA: 0s - loss: 2.3485e-04
# Epoch 6: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 14ms/step - loss: 2.3485e-04 - val_loss: 0.0041
# Epoch 7/100
# 276/279 [============================>.] - ETA: 0s - loss: 2.3120e-04
# Epoch 7: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 2.3250e-04 - val_loss: 0.0023
# Epoch 8/100
# 276/279 [============================>.] - ETA: 0s - loss: 2.0169e-04
# Epoch 8: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 2.0105e-04 - val_loss: 0.0055
# Epoch 9/100
# 275/279 [============================>.] - ETA: 0s - loss: 2.0192e-04
# Epoch 9: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 2.0199e-04 - val_loss: 0.0088
# Epoch 10/100
# 275/279 [============================>.] - ETA: 0s - loss: 1.9327e-04
# Epoch 10: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 1.9243e-04 - val_loss: 0.0081
# Epoch 11/100
# 275/279 [============================>.] - ETA: 0s - loss: 2.2825e-04
# Epoch 11: val_loss did not improve from 0.00084
# 279/279 [==============================] - 3s 12ms/step - loss: 2.2813e-04 - val_loss: 0.0099
# Epoch 12/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.7787e-04
# Epoch 12: val_loss did not improve from 0.00084
# 279/279 [==============================] - 3s 13ms/step - loss: 1.7790e-04 - val_loss: 0.0166
# Epoch 13/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.8600e-04
# Epoch 13: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 1.8534e-04 - val_loss: 0.0115
# Epoch 14/100
# 275/279 [============================>.] - ETA: 0s - loss: 1.6767e-04
# Epoch 14: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 13ms/step - loss: 1.6827e-04 - val_loss: 0.0148
# Epoch 15/100
# 278/279 [============================>.] - ETA: 0s - loss: 2.0406e-04
# Epoch 15: val_loss did not improve from 0.00084
# 279/279 [==============================] - 4s 14ms/step - loss: 2.0418e-04 - val_loss: 0.0076
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:22722.04766548054
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003, 6894.583289892997, 15019.456452133621, 22722.04766548054]
# Epoch 1/100
# 311/314 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 1: val_loss improved from inf to 0.00069, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 6s 13ms/step - loss: 0.0031 - val_loss: 6.8534e-04
# Epoch 2/100
# 310/314 [============================>.] - ETA: 0s - loss: 3.6055e-04
# Epoch 2: val_loss did not improve from 0.00069
# 314/314 [==============================] - 4s 12ms/step - loss: 3.5913e-04 - val_loss: 0.0013
# Epoch 3/100
# 312/314 [============================>.] - ETA: 0s - loss: 2.7050e-04
# Epoch 3: val_loss improved from 0.00069 to 0.00030, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 4s 12ms/step - loss: 2.7002e-04 - val_loss: 3.0200e-04
# Epoch 4/100
# 314/314 [==============================] - ETA: 0s - loss: 2.0512e-04
# Epoch 4: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 11ms/step - loss: 2.0512e-04 - val_loss: 4.0900e-04
# Epoch 5/100
# 314/314 [==============================] - ETA: 0s - loss: 1.8681e-04
# Epoch 5: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 11ms/step - loss: 1.8681e-04 - val_loss: 3.7522e-04
# Epoch 6/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.6857e-04
# Epoch 6: val_loss did not improve from 0.00030
# 314/314 [==============================] - 3s 11ms/step - loss: 1.6948e-04 - val_loss: 0.0030
# Epoch 7/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.5315e-04
# Epoch 7: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 11ms/step - loss: 1.5482e-04 - val_loss: 5.7385e-04
# Epoch 8/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.5246e-04
# Epoch 8: val_loss did not improve from 0.00030
# 314/314 [==============================] - 3s 10ms/step - loss: 1.5134e-04 - val_loss: 0.0013
# Epoch 9/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.3421e-04
# Epoch 9: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 12ms/step - loss: 1.3471e-04 - val_loss: 9.0021e-04
# Epoch 10/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.2601e-04
# Epoch 10: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 11ms/step - loss: 1.2610e-04 - val_loss: 0.0014
# Epoch 11/100
# 309/314 [============================>.] - ETA: 0s - loss: 1.2691e-04
# Epoch 11: val_loss did not improve from 0.00030
# 314/314 [==============================] - 3s 10ms/step - loss: 1.2704e-04 - val_loss: 7.5035e-04
# Epoch 12/100
# 314/314 [==============================] - ETA: 0s - loss: 1.2275e-04
# Epoch 12: val_loss did not improve from 0.00030
# 314/314 [==============================] - 3s 10ms/step - loss: 1.2275e-04 - val_loss: 0.0026
# Epoch 13/100
# 311/314 [============================>.] - ETA: 0s - loss: 1.1432e-04
# Epoch 13: val_loss did not improve from 0.00030
# 314/314 [==============================] - 4s 11ms/step - loss: 1.1397e-04 - val_loss: 0.0015
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:20468.889731507392
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003, 6894.583289892997, 15019.456452133621, 22722.04766548054, 20468.889731507392]
# Epoch 1/100
# 341/341 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 1: val_loss improved from inf to 0.00046, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 8s 17ms/step - loss: 0.0015 - val_loss: 4.5790e-04
# Epoch 2/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.6604e-04
# Epoch 2: val_loss did not improve from 0.00046
# 341/341 [==============================] - 5s 14ms/step - loss: 1.6545e-04 - val_loss: 5.2567e-04
# Epoch 3/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.1499e-04
# Epoch 3: val_loss did not improve from 0.00046
# 341/341 [==============================] - 5s 13ms/step - loss: 1.1471e-04 - val_loss: 5.9000e-04
# Epoch 4/100
# 338/341 [============================>.] - ETA: 0s - loss: 9.8629e-05
# Epoch 4: val_loss improved from 0.00046 to 0.00035, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 14ms/step - loss: 9.8618e-05 - val_loss: 3.5269e-04
# Epoch 5/100
# 339/341 [============================>.] - ETA: 0s - loss: 9.1160e-05
# Epoch 5: val_loss improved from 0.00035 to 0.00025, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 14ms/step - loss: 9.1315e-05 - val_loss: 2.4886e-04
# Epoch 6/100
# 341/341 [==============================] - ETA: 0s - loss: 7.8596e-05
# Epoch 6: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 15ms/step - loss: 7.8596e-05 - val_loss: 9.0594e-04
# Epoch 7/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.1071e-05
# Epoch 7: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 13ms/step - loss: 7.1272e-05 - val_loss: 4.3483e-04
# Epoch 8/100
# 341/341 [==============================] - ETA: 0s - loss: 7.2695e-05
# Epoch 8: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 14ms/step - loss: 7.2695e-05 - val_loss: 6.4767e-04
# Epoch 9/100
# 337/341 [============================>.] - ETA: 0s - loss: 6.4906e-05
# Epoch 9: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 14ms/step - loss: 6.4655e-05 - val_loss: 5.9431e-04
# Epoch 10/100
# 339/341 [============================>.] - ETA: 0s - loss: 6.0003e-05
# Epoch 10: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 14ms/step - loss: 5.9919e-05 - val_loss: 2.8333e-04
# Epoch 11/100
# 338/341 [============================>.] - ETA: 0s - loss: 6.4906e-05
# Epoch 11: val_loss improved from 0.00025 to 0.00017, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 15ms/step - loss: 6.4930e-05 - val_loss: 1.6958e-04
# Epoch 12/100
# 338/341 [============================>.] - ETA: 0s - loss: 5.8822e-05
# Epoch 12: val_loss did not improve from 0.00017
# 341/341 [==============================] - 5s 14ms/step - loss: 5.8537e-05 - val_loss: 2.1826e-04
# Epoch 13/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.1311e-05
# Epoch 13: val_loss did not improve from 0.00017
# 341/341 [==============================] - 5s 14ms/step - loss: 6.1249e-05 - val_loss: 5.7628e-04
# Epoch 14/100
# 337/341 [============================>.] - ETA: 0s - loss: 5.1693e-05
# Epoch 14: val_loss improved from 0.00017 to 0.00017, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 15ms/step - loss: 5.1643e-05 - val_loss: 1.6693e-04
# Epoch 15/100
# 338/341 [============================>.] - ETA: 0s - loss: 5.2878e-05
# Epoch 15: val_loss did not improve from 0.00017
# 341/341 [==============================] - 5s 13ms/step - loss: 5.3000e-05 - val_loss: 3.8539e-04
# Epoch 16/100
# 341/341 [==============================] - ETA: 0s - loss: 6.3083e-05
# Epoch 16: val_loss improved from 0.00017 to 0.00016, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 14ms/step - loss: 6.3083e-05 - val_loss: 1.5879e-04
# Epoch 17/100
# 341/341 [==============================] - ETA: 0s - loss: 6.0730e-05
# Epoch 17: val_loss did not improve from 0.00016
# 341/341 [==============================] - 5s 14ms/step - loss: 6.0730e-05 - val_loss: 2.7452e-04
# Epoch 18/100
# 341/341 [==============================] - ETA: 0s - loss: 5.8059e-05
# Epoch 18: val_loss did not improve from 0.00016
# 341/341 [==============================] - 5s 16ms/step - loss: 5.8059e-05 - val_loss: 1.9449e-04
# Epoch 19/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.6266e-05
# Epoch 19: val_loss did not improve from 0.00016
# 341/341 [==============================] - 5s 15ms/step - loss: 5.6222e-05 - val_loss: 0.0017
# Epoch 20/100
# 337/341 [============================>.] - ETA: 0s - loss: 5.8336e-05
# Epoch 20: val_loss improved from 0.00016 to 0.00011, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 15ms/step - loss: 5.8766e-05 - val_loss: 1.0939e-04
# Epoch 21/100
# 341/341 [==============================] - ETA: 0s - loss: 5.5580e-05
# Epoch 21: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 13ms/step - loss: 5.5580e-05 - val_loss: 6.2462e-04
# Epoch 22/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.3461e-05
# Epoch 22: val_loss did not improve from 0.00011
# 341/341 [==============================] - 5s 15ms/step - loss: 5.3329e-05 - val_loss: 1.2774e-04
# Epoch 23/100
# 337/341 [============================>.] - ETA: 0s - loss: 5.5198e-05
# Epoch 23: val_loss did not improve from 0.00011
# 341/341 [==============================] - 5s 14ms/step - loss: 5.5476e-05 - val_loss: 1.4191e-04
# Epoch 24/100
# 341/341 [==============================] - ETA: 0s - loss: 5.4750e-05
# Epoch 24: val_loss did not improve from 0.00011
# 341/341 [==============================] - 5s 13ms/step - loss: 5.4750e-05 - val_loss: 5.4684e-04
# Epoch 25/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.4284e-05
# Epoch 25: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 13ms/step - loss: 5.4162e-05 - val_loss: 6.0797e-04
# Epoch 26/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.2552e-05
# Epoch 26: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 12ms/step - loss: 5.2502e-05 - val_loss: 2.1932e-04
# Epoch 27/100
# 341/341 [==============================] - ETA: 0s - loss: 5.9129e-05
# Epoch 27: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 12ms/step - loss: 5.9129e-05 - val_loss: 6.6400e-04
# Epoch 28/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.5978e-05
# Epoch 28: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 13ms/step - loss: 5.5834e-05 - val_loss: 4.3891e-04
# Epoch 29/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.1740e-05
# Epoch 29: val_loss did not improve from 0.00011
# 341/341 [==============================] - 4s 12ms/step - loss: 6.1688e-05 - val_loss: 1.9293e-04
# Epoch 30/100
# 341/341 [==============================] - ETA: 0s - loss: 5.6551e-05
# Epoch 30: val_loss improved from 0.00011 to 0.00010, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 5.6551e-05 - val_loss: 9.6285e-05
# Epoch 31/100
# 337/341 [============================>.] - ETA: 0s - loss: 5.3377e-05
# Epoch 31: val_loss did not improve from 0.00010
# 341/341 [==============================] - 4s 12ms/step - loss: 5.3430e-05 - val_loss: 1.0841e-04
# Epoch 32/100
# 341/341 [==============================] - ETA: 0s - loss: 5.3961e-05
# Epoch 32: val_loss did not improve from 0.00010
# 341/341 [==============================] - 4s 12ms/step - loss: 5.3961e-05 - val_loss: 6.8582e-04
# Epoch 33/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.4026e-05
# Epoch 33: val_loss did not improve from 0.00010
# 341/341 [==============================] - 5s 14ms/step - loss: 5.3869e-05 - val_loss: 1.3016e-04
# Epoch 34/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.8885e-05
# Epoch 34: val_loss did not improve from 0.00010
# 341/341 [==============================] - 5s 14ms/step - loss: 5.8815e-05 - val_loss: 3.4062e-04
# Epoch 35/100
# 341/341 [==============================] - ETA: 0s - loss: 5.4516e-05
# Epoch 35: val_loss did not improve from 0.00010
# 341/341 [==============================] - 4s 13ms/step - loss: 5.4516e-05 - val_loss: 0.0010
# Epoch 36/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.3333e-05
# Epoch 36: val_loss did not improve from 0.00010
# 341/341 [==============================] - 4s 13ms/step - loss: 5.3407e-05 - val_loss: 4.9319e-04
# Epoch 37/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.4718e-05
# Epoch 37: val_loss did not improve from 0.00010
# 341/341 [==============================] - 4s 13ms/step - loss: 5.4726e-05 - val_loss: 6.7744e-04
# Epoch 38/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.0722e-05
# Epoch 38: val_loss did not improve from 0.00010
# 341/341 [==============================] - 5s 13ms/step - loss: 5.0701e-05 - val_loss: 2.7904e-04
# Epoch 39/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.4968e-05
# Epoch 39: val_loss did not improve from 0.00010
# 341/341 [==============================] - 5s 15ms/step - loss: 5.4789e-05 - val_loss: 2.0686e-04
# Epoch 40/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.8040e-05
# Epoch 40: val_loss did not improve from 0.00010
# 341/341 [==============================] - 5s 15ms/step - loss: 5.7990e-05 - val_loss: 2.2315e-04
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:6721.967273681988
# [33947.99402602303, 13817.43637609732, 16156.820914048252, 11613.540974674681, 9297.123500310003, 6894.583289892997, 15019.456452133621, 22722.04766548054, 20468.889731507392, 6721.967273681988]

# %%
print(predict)
# Out:
# [array([[167405.86]], dtype=float32), array([[190928.67]], dtype=float32), array([[177716.03]], dtype=float32), array([[194609.02]], dtype=float32), array([[191522.7]], dtype=float32), array([[204879.14]], dtype=float32), array([[176384.16]], dtype=float32), array([[168065.92]], dtype=float32), array([[177868.23]], dtype=float32), array([[184623.6]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

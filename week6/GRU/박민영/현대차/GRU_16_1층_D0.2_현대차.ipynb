# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0846
# Epoch 1: val_loss improved from inf to 0.11001, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 35ms/step - loss: 0.0800 - val_loss: 0.1100
# Epoch 2/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0287
# Epoch 2: val_loss improved from 0.11001 to 0.05871, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0281 - val_loss: 0.0587
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0156
# Epoch 3: val_loss did not improve from 0.05871
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0156 - val_loss: 0.0701
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0127
# Epoch 4: val_loss improved from 0.05871 to 0.05074, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0126 - val_loss: 0.0507
# Epoch 5/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0121
# Epoch 5: val_loss did not improve from 0.05074
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.0546
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0114
# Epoch 6: val_loss did not improve from 0.05074
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 0.0545
# Epoch 7/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0113
# Epoch 7: val_loss did not improve from 0.05074
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0110 - val_loss: 0.0645
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 8: val_loss improved from 0.05074 to 0.04556, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 0.0104 - val_loss: 0.0456
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0093
# Epoch 9: val_loss did not improve from 0.04556
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0092 - val_loss: 0.0507
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0082
# Epoch 10: val_loss did not improve from 0.04556
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0502
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 11: val_loss improved from 0.04556 to 0.03746, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0375
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 12: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0561
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 13: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0429
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 14: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0421
# Epoch 15/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 15: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0419
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 16: val_loss did not improve from 0.03746
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0056 - val_loss: 0.0479
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 17: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0461
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0042
# Epoch 18: val_loss did not improve from 0.03746
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0515
# Epoch 19/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0043
# Epoch 19: val_loss improved from 0.03746 to 0.03262, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0043 - val_loss: 0.0326
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 20: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0383
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 21: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0369
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 22: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0438
# Epoch 23/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0034
# Epoch 23: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 0.0387
# Epoch 24/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0031
# Epoch 24: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0326
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 25: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0447
# Epoch 26/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0032
# Epoch 26: val_loss did not improve from 0.03262
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0352
# Epoch 27/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 27: val_loss improved from 0.03262 to 0.03077, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0308
# Epoch 28/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 28: val_loss did not improve from 0.03077
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0372
# Epoch 29/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0026
# Epoch 29: val_loss did not improve from 0.03077
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0335
# Epoch 30/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0023
# Epoch 30: val_loss did not improve from 0.03077
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0311
# Epoch 31/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0025
# Epoch 31: val_loss did not improve from 0.03077
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0332
# Epoch 32/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0022
# Epoch 32: val_loss did not improve from 0.03077
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0320
# Epoch 33/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 33: val_loss improved from 0.03077 to 0.02416, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0021 - val_loss: 0.0242
# Epoch 34/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 34: val_loss did not improve from 0.02416
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0336
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 35: val_loss did not improve from 0.02416
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0332
# Epoch 36/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0019
# Epoch 36: val_loss did not improve from 0.02416
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0274
# Epoch 37/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 37: val_loss did not improve from 0.02416
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0268
# Epoch 38/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 38: val_loss did not improve from 0.02416
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0270
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 39: val_loss did not improve from 0.02416
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0017 - val_loss: 0.0268
# Epoch 40/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0014
# Epoch 40: val_loss improved from 0.02416 to 0.02300, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 0.0230
# Epoch 41/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0015
# Epoch 41: val_loss improved from 0.02300 to 0.02237, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0015 - val_loss: 0.0224
# Epoch 42/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 42: val_loss did not improve from 0.02237
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0275
# Epoch 43/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0013
# Epoch 43: val_loss improved from 0.02237 to 0.02035, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0203
# Epoch 44/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 44: val_loss did not improve from 0.02035
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0250
# Epoch 45/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0011
# Epoch 45: val_loss did not improve from 0.02035
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0217
# Epoch 46/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 46: val_loss did not improve from 0.02035
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0229
# Epoch 47/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.5351e-04
# Epoch 47: val_loss did not improve from 0.02035
# 34/34 [==============================] - 0s 15ms/step - loss: 9.8661e-04 - val_loss: 0.0207
# Epoch 48/100
# 32/34 [===========================>..] - ETA: 0s - loss: 9.0604e-04
# Epoch 48: val_loss did not improve from 0.02035
# 34/34 [==============================] - 0s 12ms/step - loss: 9.0173e-04 - val_loss: 0.0221
# Epoch 49/100
# 29/34 [========================>.....] - ETA: 0s - loss: 9.7999e-04
# Epoch 49: val_loss improved from 0.02035 to 0.01750, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 9.6434e-04 - val_loss: 0.0175
# Epoch 50/100
# 29/34 [========================>.....] - ETA: 0s - loss: 8.5388e-04
# Epoch 50: val_loss improved from 0.01750 to 0.01170, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 8.5202e-04 - val_loss: 0.0117
# Epoch 51/100
# 33/34 [============================>.] - ETA: 0s - loss: 8.8602e-04
# Epoch 51: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 11ms/step - loss: 8.9029e-04 - val_loss: 0.0160
# Epoch 52/100
# 34/34 [==============================] - ETA: 0s - loss: 9.1687e-04
# Epoch 52: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 11ms/step - loss: 9.1687e-04 - val_loss: 0.0181
# Epoch 53/100
# 31/34 [==========================>...] - ETA: 0s - loss: 9.2458e-04
# Epoch 53: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 12ms/step - loss: 9.0483e-04 - val_loss: 0.0135
# Epoch 54/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.1409e-04
# Epoch 54: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 12ms/step - loss: 9.1224e-04 - val_loss: 0.0129
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 7.7488e-04
# Epoch 55: val_loss did not improve from 0.01170
# 34/34 [==============================] - 1s 16ms/step - loss: 7.6980e-04 - val_loss: 0.0141
# Epoch 56/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1387e-04
# Epoch 56: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 13ms/step - loss: 7.8948e-04 - val_loss: 0.0180
# Epoch 57/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.4109e-04
# Epoch 57: val_loss did not improve from 0.01170
# 34/34 [==============================] - 0s 12ms/step - loss: 8.1556e-04 - val_loss: 0.0159
# Epoch 58/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.4098e-04
# Epoch 58: val_loss improved from 0.01170 to 0.01158, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 6.4486e-04 - val_loss: 0.0116
# Epoch 59/100
# 34/34 [==============================] - ETA: 0s - loss: 7.5565e-04
# Epoch 59: val_loss improved from 0.01158 to 0.00881, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 7.5565e-04 - val_loss: 0.0088
# Epoch 60/100
# 29/34 [========================>.....] - ETA: 0s - loss: 6.8934e-04
# Epoch 60: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 11ms/step - loss: 7.0602e-04 - val_loss: 0.0136
# Epoch 61/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.6162e-04
# Epoch 61: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 12ms/step - loss: 7.6061e-04 - val_loss: 0.0108
# Epoch 62/100
# 32/34 [===========================>..] - ETA: 0s - loss: 7.1985e-04
# Epoch 62: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 13ms/step - loss: 7.0312e-04 - val_loss: 0.0141
# Epoch 63/100
# 29/34 [========================>.....] - ETA: 0s - loss: 6.2535e-04
# Epoch 63: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 13ms/step - loss: 6.0880e-04 - val_loss: 0.0130
# Epoch 64/100
# 34/34 [==============================] - ETA: 0s - loss: 7.4240e-04
# Epoch 64: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 11ms/step - loss: 7.4240e-04 - val_loss: 0.0113
# Epoch 65/100
# 34/34 [==============================] - ETA: 0s - loss: 5.3392e-04
# Epoch 65: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 12ms/step - loss: 5.3392e-04 - val_loss: 0.0128
# Epoch 66/100
# 30/34 [=========================>....] - ETA: 0s - loss: 6.5867e-04
# Epoch 66: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 12ms/step - loss: 6.3816e-04 - val_loss: 0.0098
# Epoch 67/100
# 28/34 [=======================>......] - ETA: 0s - loss: 5.5160e-04
# Epoch 67: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 11ms/step - loss: 5.4885e-04 - val_loss: 0.0122
# Epoch 68/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.0226e-04
# Epoch 68: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 12ms/step - loss: 6.0852e-04 - val_loss: 0.0099
# Epoch 69/100
# 32/34 [===========================>..] - ETA: 0s - loss: 6.0399e-04
# Epoch 69: val_loss did not improve from 0.00881
# 34/34 [==============================] - 0s 12ms/step - loss: 5.8850e-04 - val_loss: 0.0106
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:27752.484726920502
# [27752.484726920502]
# Epoch 1/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0401
# Epoch 1: val_loss improved from inf to 0.00517, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 4s 20ms/step - loss: 0.0386 - val_loss: 0.0052
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0183
# Epoch 2: val_loss improved from 0.00517 to 0.00301, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0184 - val_loss: 0.0030
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 3: val_loss improved from 0.00301 to 0.00133, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0156 - val_loss: 0.0013
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 4: val_loss improved from 0.00133 to 0.00103, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0143 - val_loss: 0.0010
# Epoch 5/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0139
# Epoch 5: val_loss improved from 0.00103 to 0.00061, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0139 - val_loss: 6.1481e-04
# Epoch 6/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0127
# Epoch 6: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 7.1519e-04
# Epoch 7/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 7: val_loss did not improve from 0.00061
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0111 - val_loss: 7.9605e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 8: val_loss improved from 0.00061 to 0.00059, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0100 - val_loss: 5.8561e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 9: val_loss improved from 0.00059 to 0.00045, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0084 - val_loss: 4.4726e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 10: val_loss did not improve from 0.00045
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 4.5268e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 11: val_loss improved from 0.00045 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0071 - val_loss: 3.4902e-04
# Epoch 12/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0066
# Epoch 12: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 13: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 4.3394e-04
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 14: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0053 - val_loss: 5.2606e-04
# Epoch 15/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 15: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0048 - val_loss: 5.1205e-04
# Epoch 16/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 16: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 8.9558e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 17: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0040 - val_loss: 7.6367e-04
# Epoch 18/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0036
# Epoch 18: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 19/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 19: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0034 - val_loss: 7.7709e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 20: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 19ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 21/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 21: val_loss did not improve from 0.00035
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0029 - val_loss: 0.0011
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:25963.951920804426
# [27752.484726920502, 25963.951920804426]
# Epoch 1/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0695
# Epoch 1: val_loss improved from inf to 0.00211, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 17ms/step - loss: 0.0695 - val_loss: 0.0021
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0326
# Epoch 2: val_loss improved from 0.00211 to 0.00111, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0325 - val_loss: 0.0011
# Epoch 3/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0262
# Epoch 3: val_loss improved from 0.00111 to 0.00091, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0260 - val_loss: 9.1362e-04
# Epoch 4/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0214
# Epoch 4: val_loss improved from 0.00091 to 0.00076, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0211 - val_loss: 7.5794e-04
# Epoch 5/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 5: val_loss did not improve from 0.00076
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0172 - val_loss: 7.8411e-04
# Epoch 6/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0146
# Epoch 6: val_loss improved from 0.00076 to 0.00064, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0144 - val_loss: 6.4382e-04
# Epoch 7/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0121
# Epoch 7: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0120 - val_loss: 9.0956e-04
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0127
# Epoch 8: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0125 - val_loss: 9.5840e-04
# Epoch 9/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 9: val_loss improved from 0.00064 to 0.00056, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0091 - val_loss: 5.5768e-04
# Epoch 10/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 10: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 8.1343e-04
# Epoch 11/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 11: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0075 - val_loss: 6.2923e-04
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 12: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0060 - val_loss: 9.4171e-04
# Epoch 13/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 13: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0059 - val_loss: 7.7349e-04
# Epoch 14/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 14: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0052 - val_loss: 8.3062e-04
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 15: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0045 - val_loss: 9.7132e-04
# Epoch 16/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 16: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 17/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 17: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 18/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 18: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 19/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 19: val_loss did not improve from 0.00056
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 9.6078e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:19282.540110767626
# [27752.484726920502, 25963.951920804426, 19282.540110767626]
# Epoch 1/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0622
# Epoch 1: val_loss improved from inf to 0.00146, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 6s 21ms/step - loss: 0.0612 - val_loss: 0.0015
# Epoch 2/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 2: val_loss improved from 0.00146 to 0.00075, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0192 - val_loss: 7.4956e-04
# Epoch 3/100
# 132/139 [===========================>..] - ETA: 0s - loss: 0.0143
# Epoch 3: val_loss did not improve from 0.00075
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0142 - val_loss: 0.0016
# Epoch 4/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 4: val_loss did not improve from 0.00075
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0119 - val_loss: 0.0017
# Epoch 5/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 5: val_loss did not improve from 0.00075
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0115 - val_loss: 0.0013
# Epoch 6/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 6: val_loss did not improve from 0.00075
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0097 - val_loss: 9.0401e-04
# Epoch 7/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 7: val_loss improved from 0.00075 to 0.00051, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0091 - val_loss: 5.0738e-04
# Epoch 8/100
# 132/139 [===========================>..] - ETA: 0s - loss: 0.0080
# Epoch 8: val_loss improved from 0.00051 to 0.00048, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 4.7785e-04
# Epoch 9/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 9: val_loss did not improve from 0.00048
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0072 - val_loss: 8.0500e-04
# Epoch 10/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 10: val_loss improved from 0.00048 to 0.00044, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 4.4085e-04
# Epoch 11/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 11: val_loss did not improve from 0.00044
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 7.9037e-04
# Epoch 12/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 12: val_loss did not improve from 0.00044
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0061 - val_loss: 0.0013
# Epoch 13/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 13: val_loss did not improve from 0.00044
# 139/139 [==============================] - 1s 8ms/step - loss: 0.0056 - val_loss: 4.9782e-04
# Epoch 14/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 14: val_loss did not improve from 0.00044
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0056 - val_loss: 5.5388e-04
# Epoch 15/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 15: val_loss improved from 0.00044 to 0.00042, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0058 - val_loss: 4.1622e-04
# Epoch 16/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 16: val_loss did not improve from 0.00042
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0054 - val_loss: 4.9822e-04
# Epoch 17/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 17: val_loss did not improve from 0.00042
# 139/139 [==============================] - 1s 8ms/step - loss: 0.0055 - val_loss: 4.4255e-04
# Epoch 18/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 18: val_loss did not improve from 0.00042
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0052 - val_loss: 4.7194e-04
# Epoch 19/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 19: val_loss did not improve from 0.00042
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 8.2241e-04
# Epoch 20/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 20: val_loss improved from 0.00042 to 0.00040, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 4.0343e-04
# Epoch 21/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 21: val_loss did not improve from 0.00040
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0048 - val_loss: 8.1923e-04
# Epoch 22/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 22: val_loss did not improve from 0.00040
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 23/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 23: val_loss did not improve from 0.00040
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0053 - val_loss: 7.2940e-04
# Epoch 24/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 24: val_loss did not improve from 0.00040
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0049 - val_loss: 6.4765e-04
# Epoch 25/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0051
# Epoch 25: val_loss did not improve from 0.00040
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0052 - val_loss: 7.7063e-04
# Epoch 26/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 26: val_loss improved from 0.00040 to 0.00037, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0049 - val_loss: 3.7136e-04
# Epoch 27/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 27: val_loss did not improve from 0.00037
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 7.8651e-04
# Epoch 28/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 28: val_loss did not improve from 0.00037
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 29/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 29: val_loss did not improve from 0.00037
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0047 - val_loss: 4.2150e-04
# Epoch 30/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 30: val_loss improved from 0.00037 to 0.00033, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 3.3209e-04
# Epoch 31/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 31: val_loss improved from 0.00033 to 0.00031, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0048 - val_loss: 3.1249e-04
# Epoch 32/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0051
# Epoch 32: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0051 - val_loss: 4.8733e-04
# Epoch 33/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 33: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 15ms/step - loss: 0.0057 - val_loss: 5.9422e-04
# Epoch 34/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 34: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0055 - val_loss: 3.2325e-04
# Epoch 35/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 35: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0047 - val_loss: 4.6313e-04
# Epoch 36/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 36: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0052 - val_loss: 4.0008e-04
# Epoch 37/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0053
# Epoch 37: val_loss did not improve from 0.00031
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0052 - val_loss: 6.9432e-04
# Epoch 38/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 38: val_loss improved from 0.00031 to 0.00029, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0054 - val_loss: 2.8877e-04
# Epoch 39/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 39: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0048 - val_loss: 3.0578e-04
# Epoch 40/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 40: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0051 - val_loss: 3.6856e-04
# Epoch 41/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 41: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 42/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 42: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0047 - val_loss: 6.0075e-04
# Epoch 43/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 43: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0047 - val_loss: 3.9303e-04
# Epoch 44/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 44: val_loss improved from 0.00029 to 0.00028, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 15ms/step - loss: 0.0048 - val_loss: 2.7867e-04
# Epoch 45/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 45: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 14ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 46/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 46: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0049 - val_loss: 4.4795e-04
# Epoch 47/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 47: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 14ms/step - loss: 0.0051 - val_loss: 3.5873e-04
# Epoch 48/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 48: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 15ms/step - loss: 0.0051 - val_loss: 6.7831e-04
# Epoch 49/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 49: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 14ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 50/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 50: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0052 - val_loss: 2.9312e-04
# Epoch 51/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 51: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0048 - val_loss: 5.0741e-04
# Epoch 52/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 52: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 53/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 53: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0049 - val_loss: 2.9037e-04
# Epoch 54/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 54: val_loss did not improve from 0.00028
# 139/139 [==============================] - 2s 18ms/step - loss: 0.0050 - val_loss: 3.7473e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:11844.256959304084
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084]
# Epoch 1/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0597
# Epoch 1: val_loss improved from inf to 0.00688, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 9s 22ms/step - loss: 0.0594 - val_loss: 0.0069
# Epoch 2/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 2: val_loss improved from 0.00688 to 0.00115, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0118 - val_loss: 0.0012
# Epoch 3/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 3: val_loss improved from 0.00115 to 0.00076, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0097 - val_loss: 7.6033e-04
# Epoch 4/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 4: val_loss improved from 0.00076 to 0.00072, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0074 - val_loss: 7.1544e-04
# Epoch 5/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 5: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0069 - val_loss: 0.0012
# Epoch 6/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 6: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0060 - val_loss: 8.3979e-04
# Epoch 7/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 7: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0048 - val_loss: 9.0382e-04
# Epoch 8/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 8: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0049 - val_loss: 0.0010
# Epoch 9/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 9: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 10/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 10: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 11/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 11: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0041 - val_loss: 9.3074e-04
# Epoch 12/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 12: val_loss did not improve from 0.00072
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0039 - val_loss: 9.9569e-04
# Epoch 13/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 13: val_loss improved from 0.00072 to 0.00055, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0040 - val_loss: 5.4931e-04
# Epoch 14/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 14: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 15/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 15: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0040 - val_loss: 6.3474e-04
# Epoch 16/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 16: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 17/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 17: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0037 - val_loss: 8.8800e-04
# Epoch 18/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 18: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 19/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 19: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 20/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 20: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 8.7293e-04
# Epoch 21/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 21: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0031 - val_loss: 7.3300e-04
# Epoch 22/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 22: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 23/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 23: val_loss did not improve from 0.00055
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0032 - val_loss: 9.2720e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:13257.72510084315
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084, 13257.72510084315]
# Epoch 1/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 1: val_loss improved from inf to 0.00060, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 22ms/step - loss: 0.0111 - val_loss: 6.0158e-04
# Epoch 2/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 2: val_loss improved from 0.00060 to 0.00059, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 17ms/step - loss: 0.0044 - val_loss: 5.9117e-04
# Epoch 3/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 3: val_loss did not improve from 0.00059
# 209/209 [==============================] - 3s 16ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 4/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 4: val_loss did not improve from 0.00059
# 209/209 [==============================] - 4s 17ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 5/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 5: val_loss did not improve from 0.00059
# 209/209 [==============================] - 4s 18ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 6/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 6: val_loss did not improve from 0.00059
# 209/209 [==============================] - 5s 22ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 7/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 7: val_loss did not improve from 0.00059
# 209/209 [==============================] - 4s 19ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 8/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 8: val_loss did not improve from 0.00059
# 209/209 [==============================] - 4s 17ms/step - loss: 0.0025 - val_loss: 0.0061
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 9: val_loss did not improve from 0.00059
# 209/209 [==============================] - 4s 18ms/step - loss: 0.0028 - val_loss: 9.4737e-04
# Epoch 10/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 10: val_loss improved from 0.00059 to 0.00047, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 4s 17ms/step - loss: 0.0027 - val_loss: 4.6689e-04
# Epoch 11/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 11: val_loss did not improve from 0.00047
# 209/209 [==============================] - 4s 17ms/step - loss: 0.0025 - val_loss: 4.7260e-04
# Epoch 12/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 12: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 17ms/step - loss: 0.0024 - val_loss: 4.8632e-04
# Epoch 13/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 13: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 16ms/step - loss: 0.0024 - val_loss: 5.4503e-04
# Epoch 14/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 14: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 15ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 15/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 15: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 14ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 16/100
# 203/209 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 16: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 13ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 17/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 17: val_loss did not improve from 0.00047
# 209/209 [==============================] - 3s 14ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 18/100
# ...
# 244/244 [==============================] - 4s 17ms/step - loss: 9.4753e-04 - val_loss: 0.0072
# Epoch 6/100
# 240/244 [============================>.] - ETA: 0s - loss: 8.7748e-04
# Epoch 6: val_loss improved from 0.00720 to 0.00704, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 5s 18ms/step - loss: 8.7905e-04 - val_loss: 0.0070
# Epoch 7/100
# 240/244 [============================>.] - ETA: 0s - loss: 8.3299e-04
# Epoch 7: val_loss improved from 0.00704 to 0.00524, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 5s 19ms/step - loss: 8.2951e-04 - val_loss: 0.0052
# Epoch 8/100
# 244/244 [==============================] - ETA: 0s - loss: 7.9044e-04
# Epoch 8: val_loss improved from 0.00524 to 0.00338, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 5s 19ms/step - loss: 7.9044e-04 - val_loss: 0.0034
# Epoch 9/100
# 243/244 [============================>.] - ETA: 0s - loss: 8.1195e-04
# Epoch 9: val_loss improved from 0.00338 to 0.00233, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 5s 20ms/step - loss: 8.1052e-04 - val_loss: 0.0023
# Epoch 10/100
# 243/244 [============================>.] - ETA: 0s - loss: 8.5376e-04
# Epoch 10: val_loss improved from 0.00233 to 0.00126, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 4s 18ms/step - loss: 8.5329e-04 - val_loss: 0.0013
# Epoch 11/100
# 243/244 [============================>.] - ETA: 0s - loss: 8.0180e-04
# Epoch 11: val_loss improved from 0.00126 to 0.00122, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 6s 23ms/step - loss: 8.0129e-04 - val_loss: 0.0012
# Epoch 12/100
# 240/244 [============================>.] - ETA: 0s - loss: 8.2923e-04
# Epoch 12: val_loss did not improve from 0.00122
# 244/244 [==============================] - 6s 23ms/step - loss: 8.2396e-04 - val_loss: 0.0084
# Epoch 13/100
# 242/244 [============================>.] - ETA: 0s - loss: 8.2381e-04
# Epoch 13: val_loss did not improve from 0.00122
# 244/244 [==============================] - 7s 29ms/step - loss: 8.2161e-04 - val_loss: 0.0035
# Epoch 14/100
# 242/244 [============================>.] - ETA: 0s - loss: 6.9468e-04
# Epoch 14: val_loss did not improve from 0.00122
# 244/244 [==============================] - 6s 25ms/step - loss: 6.9464e-04 - val_loss: 0.0030
# Epoch 15/100
# 242/244 [============================>.] - ETA: 0s - loss: 7.7498e-04
# Epoch 15: val_loss did not improve from 0.00122
# 244/244 [==============================] - 5s 19ms/step - loss: 7.7236e-04 - val_loss: 0.0025
# Epoch 16/100
# 243/244 [============================>.] - ETA: 0s - loss: 6.9981e-04
# Epoch 16: val_loss did not improve from 0.00122
# 244/244 [==============================] - 3s 14ms/step - loss: 6.9860e-04 - val_loss: 0.0017
# Epoch 17/100
# 244/244 [==============================] - ETA: 0s - loss: 7.0655e-04
# Epoch 17: val_loss did not improve from 0.00122
# 244/244 [==============================] - 3s 13ms/step - loss: 7.0655e-04 - val_loss: 0.0059
# Epoch 18/100
# 239/244 [============================>.] - ETA: 0s - loss: 7.2730e-04
# Epoch 18: val_loss did not improve from 0.00122
# 244/244 [==============================] - 3s 11ms/step - loss: 7.3561e-04 - val_loss: 0.0030
# Epoch 19/100
# 243/244 [============================>.] - ETA: 0s - loss: 6.6278e-04
# Epoch 19: val_loss did not improve from 0.00122
# 244/244 [==============================] - 3s 11ms/step - loss: 6.6216e-04 - val_loss: 0.0055
# Epoch 20/100
# 240/244 [============================>.] - ETA: 0s - loss: 6.9923e-04
# Epoch 20: val_loss improved from 0.00122 to 0.00102, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 10ms/step - loss: 7.0265e-04 - val_loss: 0.0010
# Epoch 21/100
# 242/244 [============================>.] - ETA: 0s - loss: 6.5166e-04
# Epoch 21: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 10ms/step - loss: 6.6414e-04 - val_loss: 0.0081
# Epoch 22/100
# 241/244 [============================>.] - ETA: 0s - loss: 6.0909e-04
# Epoch 22: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 10ms/step - loss: 6.1046e-04 - val_loss: 0.0053
# Epoch 23/100
# 242/244 [============================>.] - ETA: 0s - loss: 6.3758e-04
# Epoch 23: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 9ms/step - loss: 6.3535e-04 - val_loss: 0.0107
# Epoch 24/100
# 241/244 [============================>.] - ETA: 0s - loss: 6.5966e-04
# Epoch 24: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 10ms/step - loss: 6.5805e-04 - val_loss: 0.0040
# Epoch 25/100
# 244/244 [==============================] - ETA: 0s - loss: 6.7927e-04
# Epoch 25: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 10ms/step - loss: 6.7927e-04 - val_loss: 0.0072
# Epoch 26/100
# 239/244 [============================>.] - ETA: 0s - loss: 6.5587e-04
# Epoch 26: val_loss did not improve from 0.00102
# 244/244 [==============================] - 2s 9ms/step - loss: 6.4970e-04 - val_loss: 0.0070
# Epoch 27/100
# 238/244 [============================>.] - ETA: 0s - loss: 6.5760e-04
# Epoch 27: val_loss did not improve from 0.00102
# 244/244 [==============================] - 3s 11ms/step - loss: 6.5226e-04 - val_loss: 0.0062
# Epoch 28/100
# 243/244 [============================>.] - ETA: 0s - loss: 6.8408e-04
# Epoch 28: val_loss did not improve from 0.00102
# 244/244 [==============================] - 3s 12ms/step - loss: 6.8890e-04 - val_loss: 0.0042
# Epoch 29/100
# 241/244 [============================>.] - ETA: 0s - loss: 5.9813e-04
# Epoch 29: val_loss did not improve from 0.00102
# 244/244 [==============================] - 3s 13ms/step - loss: 5.9599e-04 - val_loss: 0.0111
# Epoch 30/100
# 238/244 [============================>.] - ETA: 0s - loss: 6.0836e-04
# Epoch 30: val_loss did not improve from 0.00102
# 244/244 [==============================] - 3s 14ms/step - loss: 6.0445e-04 - val_loss: 0.0081
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:15131.996062095404
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084, 13257.72510084315, 12136.868433306772, 15131.996062095404]
# Epoch 1/100
# 279/279 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 1: val_loss improved from inf to 0.00398, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 31s 32ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 2/100
# 278/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 2: val_loss improved from 0.00398 to 0.00268, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 6s 20ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 3/100
# 278/279 [============================>.] - ETA: 0s - loss: 8.3234e-04
# Epoch 3: val_loss did not improve from 0.00268
# 279/279 [==============================] - 4s 16ms/step - loss: 8.3151e-04 - val_loss: 0.0127
# Epoch 4/100
# 278/279 [============================>.] - ETA: 0s - loss: 6.9731e-04
# Epoch 4: val_loss did not improve from 0.00268
# 279/279 [==============================] - 5s 18ms/step - loss: 6.9596e-04 - val_loss: 0.0192
# Epoch 5/100
# 279/279 [==============================] - ETA: 0s - loss: 6.2638e-04
# Epoch 5: val_loss did not improve from 0.00268
# 279/279 [==============================] - 5s 19ms/step - loss: 6.2638e-04 - val_loss: 0.0244
# Epoch 6/100
# 275/279 [============================>.] - ETA: 0s - loss: 5.7622e-04
# Epoch 6: val_loss did not improve from 0.00268
# 279/279 [==============================] - 5s 20ms/step - loss: 5.7318e-04 - val_loss: 0.0266
# Epoch 7/100
# 277/279 [============================>.] - ETA: 0s - loss: 5.6769e-04
# Epoch 7: val_loss did not improve from 0.00268
# 279/279 [==============================] - 7s 25ms/step - loss: 5.6599e-04 - val_loss: 0.0265
# Epoch 8/100
# 278/279 [============================>.] - ETA: 0s - loss: 5.5757e-04
# Epoch 8: val_loss did not improve from 0.00268
# 279/279 [==============================] - 7s 24ms/step - loss: 5.5815e-04 - val_loss: 0.0306
# Epoch 9/100
# 279/279 [==============================] - ETA: 0s - loss: 5.5324e-04
# Epoch 9: val_loss did not improve from 0.00268
# 279/279 [==============================] - 9s 31ms/step - loss: 5.5324e-04 - val_loss: 0.0350
# Epoch 10/100
# 279/279 [==============================] - ETA: 0s - loss: 5.1219e-04
# Epoch 10: val_loss did not improve from 0.00268
# 279/279 [==============================] - 7s 24ms/step - loss: 5.1219e-04 - val_loss: 0.0226
# Epoch 11/100
# 277/279 [============================>.] - ETA: 0s - loss: 5.1439e-04
# Epoch 11: val_loss did not improve from 0.00268
# 279/279 [==============================] - 6s 20ms/step - loss: 5.1399e-04 - val_loss: 0.0360
# Epoch 12/100
# 279/279 [==============================] - ETA: 0s - loss: 4.6764e-04
# Epoch 12: val_loss did not improve from 0.00268
# 279/279 [==============================] - 5s 19ms/step - loss: 4.6764e-04 - val_loss: 0.0316
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:52349.27976173678
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084, 13257.72510084315, 12136.868433306772, 15131.996062095404, 52349.27976173678]
# Epoch 1/100
# 314/314 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 1: val_loss improved from inf to 0.00316, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 13s 19ms/step - loss: 0.0076 - val_loss: 0.0032
# Epoch 2/100
# 310/314 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 2: val_loss did not improve from 0.00316
# 314/314 [==============================] - 5s 14ms/step - loss: 0.0011 - val_loss: 0.0126
# Epoch 3/100
# 313/314 [============================>.] - ETA: 0s - loss: 7.2111e-04
# Epoch 3: val_loss did not improve from 0.00316
# 314/314 [==============================] - 5s 17ms/step - loss: 7.2745e-04 - val_loss: 0.0160
# Epoch 4/100
# 312/314 [============================>.] - ETA: 0s - loss: 6.0623e-04
# Epoch 4: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 18ms/step - loss: 6.0410e-04 - val_loss: 0.0154
# Epoch 5/100
# 313/314 [============================>.] - ETA: 0s - loss: 5.7212e-04
# Epoch 5: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 19ms/step - loss: 5.7130e-04 - val_loss: 0.0168
# Epoch 6/100
# 311/314 [============================>.] - ETA: 0s - loss: 5.3491e-04
# Epoch 6: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 20ms/step - loss: 5.3798e-04 - val_loss: 0.0174
# Epoch 7/100
# 314/314 [==============================] - ETA: 0s - loss: 4.3942e-04
# Epoch 7: val_loss did not improve from 0.00316
# 314/314 [==============================] - 7s 23ms/step - loss: 4.3942e-04 - val_loss: 0.0185
# Epoch 8/100
# 311/314 [============================>.] - ETA: 0s - loss: 4.8198e-04
# Epoch 8: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 21ms/step - loss: 4.7882e-04 - val_loss: 0.0155
# Epoch 9/100
# 314/314 [==============================] - ETA: 0s - loss: 4.1044e-04
# Epoch 9: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 18ms/step - loss: 4.1044e-04 - val_loss: 0.0143
# Epoch 10/100
# 311/314 [============================>.] - ETA: 0s - loss: 4.3578e-04
# Epoch 10: val_loss did not improve from 0.00316
# 314/314 [==============================] - 6s 19ms/step - loss: 4.3557e-04 - val_loss: 0.0105
# Epoch 11/100
# 310/314 [============================>.] - ETA: 0s - loss: 3.9412e-04
# Epoch 11: val_loss did not improve from 0.00316
# 314/314 [==============================] - 5s 16ms/step - loss: 3.9596e-04 - val_loss: 0.0139
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:65492.38987259573
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084, 13257.72510084315, 12136.868433306772, 15131.996062095404, 52349.27976173678, 65492.38987259573]
# Epoch 1/100
# 339/341 [============================>.] - ETA: 0s - loss: 0.0141
# Epoch 1: val_loss improved from inf to 0.02240, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 33s 45ms/step - loss: 0.0141 - val_loss: 0.0224
# Epoch 2/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.9564e-04
# Epoch 2: val_loss improved from 0.02240 to 0.00789, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 9s 27ms/step - loss: 7.9355e-04 - val_loss: 0.0079
# Epoch 3/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.7665e-04
# Epoch 3: val_loss improved from 0.00789 to 0.00358, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 4.7815e-04 - val_loss: 0.0036
# Epoch 4/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.8141e-04
# Epoch 4: val_loss improved from 0.00358 to 0.00287, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 3.8160e-04 - val_loss: 0.0029
# Epoch 5/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5362e-04
# Epoch 5: val_loss did not improve from 0.00287
# 341/341 [==============================] - 8s 24ms/step - loss: 3.5418e-04 - val_loss: 0.0037
# Epoch 6/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4384e-04
# Epoch 6: val_loss improved from 0.00287 to 0.00238, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 3.4384e-04 - val_loss: 0.0024
# Epoch 7/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0019e-04
# Epoch 7: val_loss did not improve from 0.00238
# 341/341 [==============================] - 10s 30ms/step - loss: 3.0019e-04 - val_loss: 0.0049
# Epoch 8/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1620e-04
# Epoch 8: val_loss did not improve from 0.00238
# 341/341 [==============================] - 12s 35ms/step - loss: 3.1605e-04 - val_loss: 0.0028
# Epoch 9/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.4993e-04
# Epoch 9: val_loss did not improve from 0.00238
# 341/341 [==============================] - 10s 30ms/step - loss: 2.5042e-04 - val_loss: 0.0031
# Epoch 10/100
# 341/341 [==============================] - ETA: 0s - loss: 2.1389e-04
# Epoch 10: val_loss did not improve from 0.00238
# 341/341 [==============================] - 9s 26ms/step - loss: 2.1389e-04 - val_loss: 0.0032
# Epoch 11/100
# 341/341 [==============================] - ETA: 0s - loss: 1.8643e-04
# Epoch 11: val_loss did not improve from 0.00238
# 341/341 [==============================] - 9s 27ms/step - loss: 1.8643e-04 - val_loss: 0.0027
# Epoch 12/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.8726e-04
# Epoch 12: val_loss did not improve from 0.00238
# 341/341 [==============================] - 9s 27ms/step - loss: 1.8727e-04 - val_loss: 0.0029
# Epoch 13/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.8123e-04
# Epoch 13: val_loss did not improve from 0.00238
# 341/341 [==============================] - 9s 27ms/step - loss: 1.8110e-04 - val_loss: 0.0029
# Epoch 14/100
# 341/341 [==============================] - ETA: 0s - loss: 1.7109e-04
# Epoch 14: val_loss did not improve from 0.00238
# 341/341 [==============================] - 10s 29ms/step - loss: 1.7109e-04 - val_loss: 0.0039
# Epoch 15/100
# 341/341 [==============================] - ETA: 0s - loss: 1.7122e-04
# Epoch 15: val_loss did not improve from 0.00238
# 341/341 [==============================] - 13s 38ms/step - loss: 1.7122e-04 - val_loss: 0.0029
# Epoch 16/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.7619e-04
# Epoch 16: val_loss did not improve from 0.00238
# 341/341 [==============================] - 10s 28ms/step - loss: 1.7703e-04 - val_loss: 0.0046
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:83480.65862106507
# [27752.484726920502, 25963.951920804426, 19282.540110767626, 11844.256959304084, 13257.72510084315, 12136.868433306772, 15131.996062095404, 52349.27976173678, 65492.38987259573, 83480.65862106507]

# %%
print(predict)
# Out:
# [array([[179195.97]], dtype=float32), array([[185413.94]], dtype=float32), array([[177895.44]], dtype=float32), array([[193938.]], dtype=float32), array([[199012.94]], dtype=float32), array([[182673.53]], dtype=float32), array([[175477.12]], dtype=float32), array([[114090.336]], dtype=float32), array([[124298.07]], dtype=float32), array([[114063.766]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

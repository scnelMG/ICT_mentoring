# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.2769
# Epoch 1: val_loss improved from inf to 0.10156, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 4s 37ms/step - loss: 0.2769 - val_loss: 0.1016
# Epoch 2/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0670
# Epoch 2: val_loss improved from 0.10156 to 0.07985, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0619 - val_loss: 0.0798
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0272
# Epoch 3: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0262 - val_loss: 0.1173
# Epoch 4/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0196
# Epoch 4: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0191 - val_loss: 0.1229
# Epoch 5/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0188
# Epoch 5: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0188 - val_loss: 0.1287
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0147
# Epoch 6: val_loss did not improve from 0.07985
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0146 - val_loss: 0.1385
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0155
# Epoch 7: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0152 - val_loss: 0.1392
# Epoch 8/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0143
# Epoch 8: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0147 - val_loss: 0.1485
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0132
# Epoch 9: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.1514
# Epoch 10/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0114
# Epoch 10: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0115 - val_loss: 0.1439
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 11: val_loss did not improve from 0.07985
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0113 - val_loss: 0.1446
# Epoch 12/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0118
# Epoch 12: val_loss did not improve from 0.07985
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.1473
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:80555.82660429335
# [80555.82660429335]
# Epoch 1/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0789
# Epoch 1: val_loss improved from inf to 0.00156, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 7s 31ms/step - loss: 0.0789 - val_loss: 0.0016
# Epoch 2/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0272
# Epoch 2: val_loss improved from 0.00156 to 0.00107, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0269 - val_loss: 0.0011
# Epoch 3/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 3: val_loss did not improve from 0.00107
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0216 - val_loss: 0.0012
# Epoch 4/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0214
# Epoch 4: val_loss improved from 0.00107 to 0.00096, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0214 - val_loss: 9.6131e-04
# Epoch 5/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0173
# Epoch 5: val_loss improved from 0.00096 to 0.00077, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0172 - val_loss: 7.6505e-04
# Epoch 6/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0172
# Epoch 6: val_loss improved from 0.00077 to 0.00062, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0168 - val_loss: 6.1660e-04
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0140
# Epoch 7: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0142 - val_loss: 6.1696e-04
# Epoch 8/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0144
# Epoch 8: val_loss did not improve from 0.00062
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0143 - val_loss: 9.4226e-04
# Epoch 9/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0136
# Epoch 9: val_loss improved from 0.00062 to 0.00058, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0135 - val_loss: 5.8223e-04
# Epoch 10/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0116
# Epoch 10: val_loss improved from 0.00058 to 0.00054, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0115 - val_loss: 5.4496e-04
# Epoch 11/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0096
# Epoch 11: val_loss improved from 0.00054 to 0.00043, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0098 - val_loss: 4.3345e-04
# Epoch 12/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0094
# Epoch 12: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0092 - val_loss: 6.1541e-04
# Epoch 13/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 13: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0079 - val_loss: 8.5701e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 14: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 5.6079e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 15: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 4.4765e-04
# Epoch 16/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 16: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0056 - val_loss: 4.4242e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 17: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 18/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 18: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 6.4831e-04
# Epoch 19/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 19: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 20/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 20: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 9.2811e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 21: val_loss did not improve from 0.00043
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0017
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:29041.483458948976
# [80555.82660429335, 29041.483458948976]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.1317
# Epoch 1: val_loss improved from inf to 0.00234, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 18ms/step - loss: 0.1317 - val_loss: 0.0023
# Epoch 2/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0584
# Epoch 2: val_loss improved from 0.00234 to 0.00143, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0579 - val_loss: 0.0014
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0511
# Epoch 3: val_loss did not improve from 0.00143
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0511 - val_loss: 0.0029
# Epoch 4/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0494
# Epoch 4: val_loss improved from 0.00143 to 0.00119, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0486 - val_loss: 0.0012
# Epoch 5/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0389
# Epoch 5: val_loss did not improve from 0.00119
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0389 - val_loss: 0.0015
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0286
# Epoch 6: val_loss did not improve from 0.00119
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0285 - val_loss: 0.0023
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 7: val_loss improved from 0.00119 to 0.00098, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0211 - val_loss: 9.8017e-04
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 8: val_loss improved from 0.00098 to 0.00070, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0184 - val_loss: 7.0480e-04
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 9: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0164 - val_loss: 7.7716e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 10: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 14ms/step - loss: 0.0129 - val_loss: 7.7464e-04
# Epoch 11/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0105
# Epoch 11: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0105 - val_loss: 8.5894e-04
# Epoch 12/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 12: val_loss did not improve from 0.00070
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0095 - val_loss: 0.0014
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 13: val_loss did not improve from 0.00070
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0086 - val_loss: 0.0011
# Epoch 14/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0072
# Epoch 14: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 15/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 15: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 16/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 16: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0016
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 17: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 18: val_loss did not improve from 0.00070
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0056 - val_loss: 0.0012
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:26546.318825062706
# [80555.82660429335, 29041.483458948976, 26546.318825062706]
# Epoch 1/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0801
# Epoch 1: val_loss improved from inf to 0.00435, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 16ms/step - loss: 0.0791 - val_loss: 0.0044
# Epoch 2/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 2: val_loss improved from 0.00435 to 0.00252, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0360 - val_loss: 0.0025
# Epoch 3/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0286
# Epoch 3: val_loss did not improve from 0.00252
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0286 - val_loss: 0.0030
# Epoch 4/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0218
# Epoch 4: val_loss did not improve from 0.00252
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0216 - val_loss: 0.0035
# Epoch 5/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0200
# Epoch 5: val_loss improved from 0.00252 to 0.00075, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0200 - val_loss: 7.5334e-04
# Epoch 6/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 6: val_loss did not improve from 0.00075
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0167 - val_loss: 0.0012
# Epoch 7/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 7: val_loss improved from 0.00075 to 0.00043, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0151 - val_loss: 4.3324e-04
# Epoch 8/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 8: val_loss did not improve from 0.00043
# 139/139 [==============================] - 2s 11ms/step - loss: 0.0124 - val_loss: 5.5790e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 9: val_loss improved from 0.00043 to 0.00041, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0104 - val_loss: 4.0602e-04
# Epoch 10/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 10: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0105 - val_loss: 9.1561e-04
# Epoch 11/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 11: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0097 - val_loss: 7.9116e-04
# Epoch 12/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 12: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0084 - val_loss: 4.4994e-04
# Epoch 13/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 13: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 8ms/step - loss: 0.0088 - val_loss: 6.5198e-04
# Epoch 14/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 14: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0072 - val_loss: 8.7215e-04
# Epoch 15/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0079
# Epoch 15: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0079 - val_loss: 7.5243e-04
# Epoch 16/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 16: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 5.7343e-04
# Epoch 17/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 17: val_loss did not improve from 0.00041
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0076 - val_loss: 5.8670e-04
# Epoch 18/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 18: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 5.5692e-04
# Epoch 19/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 19: val_loss did not improve from 0.00041
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0070 - val_loss: 5.0859e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:14542.854578481649
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649]
# Epoch 1/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 1: val_loss improved from inf to 0.00291, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 7s 16ms/step - loss: 0.0348 - val_loss: 0.0029
# Epoch 2/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 2: val_loss improved from 0.00291 to 0.00280, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0141 - val_loss: 0.0028
# Epoch 3/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0113
# Epoch 3: val_loss improved from 0.00280 to 0.00240, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0111 - val_loss: 0.0024
# Epoch 4/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 4: val_loss did not improve from 0.00240
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0093 - val_loss: 0.0028
# Epoch 5/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 5: val_loss did not improve from 0.00240
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0089 - val_loss: 0.0032
# Epoch 6/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0071
# Epoch 6: val_loss did not improve from 0.00240
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0073 - val_loss: 0.0025
# Epoch 7/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 7: val_loss improved from 0.00240 to 0.00224, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0069 - val_loss: 0.0022
# Epoch 8/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 8: val_loss did not improve from 0.00224
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0023
# Epoch 9/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 9: val_loss improved from 0.00224 to 0.00215, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 10/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 10: val_loss improved from 0.00215 to 0.00196, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0064 - val_loss: 0.0020
# Epoch 11/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 11: val_loss did not improve from 0.00196
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 12/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 12: val_loss improved from 0.00196 to 0.00187, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0019
# Epoch 13/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 13: val_loss improved from 0.00187 to 0.00180, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 14/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 14: val_loss did not improve from 0.00180
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 15/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 15: val_loss did not improve from 0.00180
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 16/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 16: val_loss did not improve from 0.00180
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 17/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 17: val_loss improved from 0.00180 to 0.00165, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 18/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 18: val_loss did not improve from 0.00165
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0061 - val_loss: 0.0028
# Epoch 19/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 19: val_loss improved from 0.00165 to 0.00118, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 20/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 20: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 21/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 21: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 22/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 22: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 23/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 23: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 24/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 24: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 25/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 25: val_loss did not improve from 0.00118
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 26/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 26: val_loss improved from 0.00118 to 0.00110, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 27/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 27: val_loss improved from 0.00110 to 0.00092, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0056 - val_loss: 9.1717e-04
# Epoch 28/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 28: val_loss did not improve from 0.00092
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 29/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 29: val_loss did not improve from 0.00092
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0059 - val_loss: 0.0032
# Epoch 30/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 30: val_loss improved from 0.00092 to 0.00076, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0060 - val_loss: 7.5617e-04
# Epoch 31/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 31: val_loss improved from 0.00076 to 0.00073, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0059 - val_loss: 7.3124e-04
# Epoch 32/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 32: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 15ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 33/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 33: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 15ms/step - loss: 0.0059 - val_loss: 8.6043e-04
# Epoch 34/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 34: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0060 - val_loss: 8.9070e-04
# Epoch 35/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 35: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 36/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 36: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 37/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 37: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 17ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 38/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 38: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0058 - val_loss: 0.0010
# Epoch 39/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 39: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 15ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 40/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 40: val_loss did not improve from 0.00073
# 174/174 [==============================] - 2s 14ms/step - loss: 0.0054 - val_loss: 7.4080e-04
# Epoch 41/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 41: val_loss did not improve from 0.00073
# 174/174 [==============================] - 3s 16ms/step - loss: 0.0058 - val_loss: 7.8197e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:8250.286687794835
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835]
# Epoch 1/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0467
# Epoch 1: val_loss improved from inf to 0.02377, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 11s 20ms/step - loss: 0.0465 - val_loss: 0.0238
# Epoch 2/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 2: val_loss improved from 0.02377 to 0.00322, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 13ms/step - loss: 0.0074 - val_loss: 0.0032
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 3: val_loss improved from 0.00322 to 0.00311, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0057 - val_loss: 0.0031
# Epoch 4/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 4: val_loss improved from 0.00311 to 0.00109, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 5/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 5: val_loss did not improve from 0.00109
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 6/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 6: val_loss did not improve from 0.00109
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0038 - val_loss: 0.0096
# Epoch 7/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 7: val_loss did not improve from 0.00109
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0034 - val_loss: 0.0085
# Epoch 8/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 8: val_loss improved from 0.00109 to 0.00062, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0035 - val_loss: 6.2390e-04
# Epoch 9/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 9: val_loss improved from 0.00062 to 0.00061, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0032 - val_loss: 6.0735e-04
# Epoch 10/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 10: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0031 - val_loss: 0.0104
# Epoch 11/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 11: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0033 - val_loss: 0.0062
# Epoch 12/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 12: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 13/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 13: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0035 - val_loss: 8.3599e-04
# Epoch 14/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 14: val_loss did not improve from 0.00061
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 15/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 15: val_loss did not improve from 0.00061
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 16/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 16: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0032 - val_loss: 7.4971e-04
# Epoch 17/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 17: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 18/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 18: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 19/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 19: val_loss did not improve from 0.00061
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0030 - val_loss: 0.0042
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:9970.07855285542
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835, 9970.07855285542]
# Epoch 1/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 1: val_loss improved from inf to 0.01420, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 20s 29ms/step - loss: 0.0094 - val_loss: 0.0142
# Epoch 2/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 2: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 17ms/step - loss: 0.0022 - val_loss: 0.0238
# Epoch 3/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 3: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 17ms/step - loss: 0.0017 - val_loss: 0.0176
# Epoch 4/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 4: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 17ms/step - loss: 0.0016 - val_loss: 0.0162
# Epoch 5/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 15ms/step - loss: 0.0014 - val_loss: 0.0192
# Epoch 6/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 6: val_loss did not improve from 0.01420
# 244/244 [==============================] - 3s 14ms/step - loss: 0.0013 - val_loss: 0.0269
# Epoch 7/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 7: val_loss did not improve from 0.01420
# 244/244 [==============================] - 3s 13ms/step - loss: 0.0013 - val_loss: 0.0208
# Epoch 8/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 8: val_loss did not improve from 0.01420
# 244/244 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0288
# Epoch 9/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 9: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 16ms/step - loss: 0.0012 - val_loss: 0.0274
# Epoch 10/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 10: val_loss did not improve from 0.01420
# 244/244 [==============================] - 4s 16ms/step - loss: 0.0012 - val_loss: 0.0475
# Epoch 11/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 11: val_loss did not improve from 0.01420
# 244/244 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0274
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:27117.54799623059
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835, 9970.07855285542, 27117.54799623059]
# Epoch 1/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 1: val_loss improved from inf to 0.05160, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 23s 34ms/step - loss: 0.0110 - val_loss: 0.0516
# Epoch 2/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 2: val_loss did not improve from 0.05160
# 279/279 [==============================] - 5s 18ms/step - loss: 0.0017 - val_loss: 0.0605
# Epoch 3/100
# 274/279 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss did not improve from 0.05160
# 279/279 [==============================] - 4s 16ms/step - loss: 0.0014 - val_loss: 0.0558
# Epoch 4/100
# 278/279 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.05160
# 279/279 [==============================] - 5s 17ms/step - loss: 0.0012 - val_loss: 0.0716
# Epoch 5/100
# 276/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 5: val_loss did not improve from 0.05160
# 279/279 [==============================] - 5s 17ms/step - loss: 0.0010 - val_loss: 0.0538
# Epoch 6/100
# 276/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 6: val_loss did not improve from 0.05160
# 279/279 [==============================] - 5s 18ms/step - loss: 0.0010 - val_loss: 0.0791
# Epoch 7/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 7: val_loss did not improve from 0.05160
# 279/279 [==============================] - 5s 19ms/step - loss: 9.9806e-04 - val_loss: 0.0635
# Epoch 8/100
# 279/279 [==============================] - ETA: 0s - loss: 9.5469e-04
# Epoch 8: val_loss did not improve from 0.05160
# 279/279 [==============================] - 6s 20ms/step - loss: 9.5469e-04 - val_loss: 0.0635
# Epoch 9/100
# 278/279 [============================>.] - ETA: 0s - loss: 9.4632e-04
# Epoch 9: val_loss did not improve from 0.05160
# 279/279 [==============================] - 7s 24ms/step - loss: 9.4487e-04 - val_loss: 0.0607
# Epoch 10/100
# 278/279 [============================>.] - ETA: 0s - loss: 9.0758e-04
# Epoch 10: val_loss did not improve from 0.05160
# 279/279 [==============================] - 8s 28ms/step - loss: 9.1216e-04 - val_loss: 0.0747
# Epoch 11/100
# 276/279 [============================>.] - ETA: 0s - loss: 9.2116e-04
# Epoch 11: val_loss did not improve from 0.05160
# 279/279 [==============================] - 7s 24ms/step - loss: 9.2029e-04 - val_loss: 0.0552
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:66665.37355545488
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835, 9970.07855285542, 27117.54799623059, 66665.37355545488]
# Epoch 1/100
# 310/314 [============================>.] - ETA: 0s - loss: 0.0342
# Epoch 1: val_loss improved from inf to 0.01959, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 12s 20ms/step - loss: 0.0338 - val_loss: 0.0196
# Epoch 2/100
# 313/314 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 2: val_loss improved from 0.01959 to 0.00269, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 5s 14ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 3/100
# 310/314 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss improved from 0.00269 to 0.00181, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 4s 13ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 4/100
# 312/314 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.00181
# 314/314 [==============================] - 5s 17ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 5/100
# 314/314 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 5: val_loss did not improve from 0.00181
# 314/314 [==============================] - 5s 17ms/step - loss: 0.0012 - val_loss: 0.0127
# Epoch 6/100
# 310/314 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 6: val_loss did not improve from 0.00181
# 314/314 [==============================] - 6s 19ms/step - loss: 0.0011 - val_loss: 0.0208
# Epoch 7/100
# 314/314 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 7: val_loss did not improve from 0.00181
# 314/314 [==============================] - 7s 24ms/step - loss: 0.0011 - val_loss: 0.0283
# Epoch 8/100
# 312/314 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 8: val_loss did not improve from 0.00181
# 314/314 [==============================] - 7s 24ms/step - loss: 0.0010 - val_loss: 0.0276
# Epoch 9/100
# 312/314 [============================>.] - ETA: 0s - loss: 8.7838e-04
# Epoch 9: val_loss did not improve from 0.00181
# 314/314 [==============================] - 7s 23ms/step - loss: 8.8437e-04 - val_loss: 0.0331
# Epoch 10/100
# 314/314 [==============================] - ETA: 0s - loss: 9.3222e-04
# Epoch 10: val_loss did not improve from 0.00181
# 314/314 [==============================] - 6s 18ms/step - loss: 9.3222e-04 - val_loss: 0.0293
# Epoch 11/100
# 313/314 [============================>.] - ETA: 0s - loss: 8.8531e-04
# Epoch 11: val_loss did not improve from 0.00181
# 314/314 [==============================] - 6s 18ms/step - loss: 8.8380e-04 - val_loss: 0.0312
# Epoch 12/100
# 310/314 [============================>.] - ETA: 0s - loss: 9.0617e-04
# Epoch 12: val_loss did not improve from 0.00181
# 314/314 [==============================] - 6s 18ms/step - loss: 8.9943e-04 - val_loss: 0.0340
# Epoch 13/100
# 310/314 [============================>.] - ETA: 0s - loss: 8.6015e-04
# Epoch 13: val_loss did not improve from 0.00181
# 314/314 [==============================] - 6s 18ms/step - loss: 8.5407e-04 - val_loss: 0.0311
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:100753.01469172441
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835, 9970.07855285542, 27117.54799623059, 66665.37355545488, 100753.01469172441]
# Epoch 1/100
# 341/341 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 1: val_loss improved from inf to 0.02793, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 36s 36ms/step - loss: 0.0055 - val_loss: 0.0279
# Epoch 2/100
# 341/341 [==============================] - ETA: 0s - loss: 7.9396e-04
# Epoch 2: val_loss improved from 0.02793 to 0.01564, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 7s 20ms/step - loss: 7.9396e-04 - val_loss: 0.0156
# Epoch 3/100
# 341/341 [==============================] - ETA: 0s - loss: 5.2715e-04
# Epoch 3: val_loss improved from 0.01564 to 0.01144, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 7s 21ms/step - loss: 5.2715e-04 - val_loss: 0.0114
# Epoch 4/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.4255e-04
# Epoch 4: val_loss improved from 0.01144 to 0.00832, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 4.4108e-04 - val_loss: 0.0083
# Epoch 5/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.9575e-04
# Epoch 5: val_loss improved from 0.00832 to 0.00674, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 9s 27ms/step - loss: 3.9476e-04 - val_loss: 0.0067
# Epoch 6/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5745e-04
# Epoch 19: val_loss did not improve from 0.00425
# 341/341 [==============================] - 7s 22ms/step - loss: 3.5724e-04 - val_loss: 0.0050
# Epoch 20/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.4998e-04
# Epoch 20: val_loss did not improve from 0.00425
# 341/341 [==============================] - 8s 24ms/step - loss: 3.4902e-04 - val_loss: 0.0043
# Epoch 21/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.3984e-04
# Epoch 21: val_loss improved from 0.00425 to 0.00396, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 7s 21ms/step - loss: 3.3955e-04 - val_loss: 0.0040
# Epoch 22/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4700e-04
# Epoch 22: val_loss did not improve from 0.00396
# 341/341 [==============================] - 9s 27ms/step - loss: 3.4700e-04 - val_loss: 0.0044
# Epoch 23/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.4289e-04
# Epoch 23: val_loss did not improve from 0.00396
# 341/341 [==============================] - 10s 30ms/step - loss: 3.4408e-04 - val_loss: 0.0046
# Epoch 24/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.4322e-04
# Epoch 24: val_loss did not improve from 0.00396
# 341/341 [==============================] - 11s 33ms/step - loss: 3.4223e-04 - val_loss: 0.0044
# Epoch 25/100
# 341/341 [==============================] - ETA: 0s - loss: 3.3565e-04
# Epoch 25: val_loss did not improve from 0.00396
# 341/341 [==============================] - 9s 27ms/step - loss: 3.3565e-04 - val_loss: 0.0047
# Epoch 26/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.2771e-04
# Epoch 26: val_loss did not improve from 0.00396
# 341/341 [==============================] - 9s 25ms/step - loss: 3.2649e-04 - val_loss: 0.0045
# Epoch 27/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.1254e-04
# Epoch 27: val_loss did not improve from 0.00396
# 341/341 [==============================] - 9s 26ms/step - loss: 3.1102e-04 - val_loss: 0.0053
# Epoch 28/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1860e-04
# Epoch 28: val_loss did not improve from 0.00396
# 341/341 [==============================] - 9s 28ms/step - loss: 3.1809e-04 - val_loss: 0.0044
# Epoch 29/100
# 341/341 [==============================] - ETA: 0s - loss: 3.1102e-04
# Epoch 29: val_loss improved from 0.00396 to 0.00380, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 9s 27ms/step - loss: 3.1102e-04 - val_loss: 0.0038
# Epoch 30/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2940e-04
# Epoch 30: val_loss did not improve from 0.00380
# 341/341 [==============================] - 11s 32ms/step - loss: 3.2940e-04 - val_loss: 0.0042
# Epoch 31/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.2934e-04
# Epoch 31: val_loss did not improve from 0.00380
# 341/341 [==============================] - 12s 35ms/step - loss: 3.3279e-04 - val_loss: 0.0051
# Epoch 32/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1770e-04
# Epoch 32: val_loss did not improve from 0.00380
# 341/341 [==============================] - 8s 25ms/step - loss: 3.1745e-04 - val_loss: 0.0047
# Epoch 33/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.2142e-04
# Epoch 33: val_loss did not improve from 0.00380
# 341/341 [==============================] - 6s 19ms/step - loss: 3.2118e-04 - val_loss: 0.0042
# Epoch 34/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.0590e-04
# Epoch 34: val_loss did not improve from 0.00380
# 341/341 [==============================] - 6s 18ms/step - loss: 3.0522e-04 - val_loss: 0.0043
# Epoch 35/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0804e-04
# Epoch 35: val_loss did not improve from 0.00380
# 341/341 [==============================] - 6s 18ms/step - loss: 3.0804e-04 - val_loss: 0.0057
# Epoch 36/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.2351e-04
# Epoch 36: val_loss improved from 0.00380 to 0.00326, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 7s 21ms/step - loss: 3.2426e-04 - val_loss: 0.0033
# Epoch 37/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.9826e-04
# Epoch 37: val_loss did not improve from 0.00326
# 341/341 [==============================] - 8s 24ms/step - loss: 2.9990e-04 - val_loss: 0.0033
# Epoch 38/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0231e-04
# Epoch 38: val_loss did not improve from 0.00326
# 341/341 [==============================] - 9s 27ms/step - loss: 3.0231e-04 - val_loss: 0.0043
# Epoch 39/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1270e-04
# Epoch 39: val_loss did not improve from 0.00326
# 341/341 [==============================] - 10s 30ms/step - loss: 3.1237e-04 - val_loss: 0.0039
# Epoch 40/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0821e-04
# Epoch 40: val_loss did not improve from 0.00326
# 341/341 [==============================] - 12s 35ms/step - loss: 3.0821e-04 - val_loss: 0.0041
# Epoch 41/100
# 341/341 [==============================] - ETA: 0s - loss: 3.3345e-04
# Epoch 41: val_loss did not improve from 0.00326
# 341/341 [==============================] - 10s 31ms/step - loss: 3.3345e-04 - val_loss: 0.0041
# Epoch 42/100
# 341/341 [==============================] - ETA: 0s - loss: 3.1286e-04
# Epoch 42: val_loss did not improve from 0.00326
# 341/341 [==============================] - 8s 25ms/step - loss: 3.1286e-04 - val_loss: 0.0039
# Epoch 43/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0682e-04
# Epoch 43: val_loss did not improve from 0.00326
# 341/341 [==============================] - 7s 20ms/step - loss: 3.0682e-04 - val_loss: 0.0041
# Epoch 44/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.2840e-04
# Epoch 44: val_loss did not improve from 0.00326
# 341/341 [==============================] - 7s 22ms/step - loss: 3.2781e-04 - val_loss: 0.0039
# Epoch 45/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.8777e-04
# Epoch 45: val_loss did not improve from 0.00326
# 341/341 [==============================] - 8s 23ms/step - loss: 2.8764e-04 - val_loss: 0.0048
# Epoch 46/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1763e-04
# Epoch 46: val_loss did not improve from 0.00326
# 341/341 [==============================] - 9s 27ms/step - loss: 3.1715e-04 - val_loss: 0.0038
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:44613.334225750885
# [80555.82660429335, 29041.483458948976, 26546.318825062706, 14542.854578481649, 8250.286687794835, 9970.07855285542, 27117.54799623059, 66665.37355545488, 100753.01469172441, 44613.334225750885]

# %%
print(predict)
# Out:
# [array([[146260.06]], dtype=float32), array([[190451.58]], dtype=float32), array([[181543.84]], dtype=float32), array([[189639.55]], dtype=float32), array([[196709.77]], dtype=float32), array([[194743.25]], dtype=float32), array([[166733.16]], dtype=float32), array([[117031.25]], dtype=float32), array([[101105.23]], dtype=float32), array([[145209.22]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0323
# Epoch 1: val_loss improved from inf to 0.01323, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 36s 303ms/step - loss: 0.0318 - val_loss: 0.0132
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 2: val_loss improved from 0.01323 to 0.01240, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0101 - val_loss: 0.0124
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 3: val_loss improved from 0.01240 to 0.00980, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0083 - val_loss: 0.0098
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0071
# Epoch 4: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0071 - val_loss: 0.0138
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 5: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0069 - val_loss: 0.0150
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 6: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0064 - val_loss: 0.0161
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 7: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0057 - val_loss: 0.0175
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 8: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 37ms/step - loss: 0.0059 - val_loss: 0.0125
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 9: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0063 - val_loss: 0.0148
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 10: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0050 - val_loss: 0.0242
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 11: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 36ms/step - loss: 0.0043 - val_loss: 0.0217
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 12: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0050 - val_loss: 0.0225
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 13: val_loss did not improve from 0.00980
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0045 - val_loss: 0.0187
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:57673.13121569629
# [57673.13121569629]
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.1033
# Epoch 1: val_loss improved from inf to 0.00158, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 29s 142ms/step - loss: 0.1020 - val_loss: 0.0016
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 2: val_loss improved from 0.00158 to 0.00069, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0168 - val_loss: 6.8732e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 3: val_loss did not improve from 0.00069
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0142 - val_loss: 9.2619e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 4: val_loss did not improve from 0.00069
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0111 - val_loss: 0.0012
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 5: val_loss did not improve from 0.00069
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0099 - val_loss: 8.3956e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 6: val_loss improved from 0.00069 to 0.00055, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0091 - val_loss: 5.5045e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 7: val_loss did not improve from 0.00055
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0084 - val_loss: 8.3899e-04
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 8: val_loss improved from 0.00055 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0076 - val_loss: 3.6452e-04
# Epoch 9/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 9: val_loss did not improve from 0.00036
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0076 - val_loss: 3.7291e-04
# Epoch 10/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0076
# Epoch 10: val_loss improved from 0.00036 to 0.00028, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0075 - val_loss: 2.8492e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 11: val_loss did not improve from 0.00028
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0064 - val_loss: 2.9037e-04
# Epoch 12/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 12: val_loss improved from 0.00028 to 0.00027, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0063 - val_loss: 2.6922e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 13: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0063 - val_loss: 6.4007e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 14: val_loss did not improve from 0.00027
# 69/69 [==============================] - 2s 34ms/step - loss: 0.0060 - val_loss: 5.6633e-04
# Epoch 15/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 15: val_loss improved from 0.00027 to 0.00023, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 39ms/step - loss: 0.0057 - val_loss: 2.3035e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 16: val_loss did not improve from 0.00023
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0057 - val_loss: 3.4646e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 17: val_loss did not improve from 0.00023
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0049 - val_loss: 3.3171e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 18: val_loss improved from 0.00023 to 0.00020, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0046 - val_loss: 1.9836e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 19: val_loss did not improve from 0.00020
# 69/69 [==============================] - 2s 36ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 20: val_loss did not improve from 0.00020
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0044 - val_loss: 3.1604e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 21: val_loss did not improve from 0.00020
# 69/69 [==============================] - 3s 44ms/step - loss: 0.0043 - val_loss: 2.4688e-04
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 22: val_loss did not improve from 0.00020
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0035 - val_loss: 2.0937e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 23: val_loss improved from 0.00020 to 0.00019, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 50ms/step - loss: 0.0039 - val_loss: 1.9061e-04
# Epoch 24/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 24: val_loss did not improve from 0.00019
# 69/69 [==============================] - 4s 60ms/step - loss: 0.0035 - val_loss: 2.7850e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 25: val_loss did not improve from 0.00019
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0036 - val_loss: 2.0098e-04
# Epoch 26/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 26: val_loss did not improve from 0.00019
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0031 - val_loss: 5.6940e-04
# Epoch 27/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 27: val_loss did not improve from 0.00019
# 69/69 [==============================] - 3s 40ms/step - loss: 0.0029 - val_loss: 3.8486e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 28: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0024 - val_loss: 1.9098e-04
# Epoch 29/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 29: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0022 - val_loss: 2.4179e-04
# Epoch 30/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 30: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 25ms/step - loss: 0.0022 - val_loss: 3.1943e-04
# Epoch 31/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 31: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 24ms/step - loss: 0.0022 - val_loss: 2.4145e-04
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 32: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0020 - val_loss: 2.1612e-04
# Epoch 33/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 33: val_loss did not improve from 0.00019
# 69/69 [==============================] - 2s 23ms/step - loss: 0.0018 - val_loss: 2.2370e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:22278.956213459827
# [57673.13121569629, 22278.956213459827]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 1: val_loss improved from inf to 0.00331, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 23s 84ms/step - loss: 0.0821 - val_loss: 0.0033
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 2: val_loss improved from 0.00331 to 0.00110, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0253 - val_loss: 0.0011
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 3: val_loss improved from 0.00110 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0161 - val_loss: 5.3207e-04
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 4: val_loss improved from 0.00053 to 0.00052, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0150 - val_loss: 5.2151e-04
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0135
# Epoch 5: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0134 - val_loss: 5.9829e-04
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 6: val_loss did not improve from 0.00052
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0127 - val_loss: 0.0013
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 7: val_loss improved from 0.00052 to 0.00042, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 38ms/step - loss: 0.0112 - val_loss: 4.2428e-04
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 8: val_loss improved from 0.00042 to 0.00038, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 44ms/step - loss: 0.0109 - val_loss: 3.8077e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 9: val_loss did not improve from 0.00038
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0101 - val_loss: 6.3695e-04
# Epoch 10/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 10: val_loss did not improve from 0.00038
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0096 - val_loss: 4.0981e-04
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 11: val_loss did not improve from 0.00038
# 104/104 [==============================] - 5s 52ms/step - loss: 0.0082 - val_loss: 3.9674e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 12: val_loss improved from 0.00038 to 0.00029, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 46ms/step - loss: 0.0079 - val_loss: 2.9058e-04
# Epoch 13/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 13: val_loss did not improve from 0.00029
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0068 - val_loss: 7.2462e-04
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 14: val_loss did not improve from 0.00029
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0068 - val_loss: 9.6485e-04
# Epoch 15/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 15: val_loss improved from 0.00029 to 0.00027, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0060 - val_loss: 2.6884e-04
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 16: val_loss did not improve from 0.00027
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0055 - val_loss: 3.1435e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 17: val_loss did not improve from 0.00027
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0047 - val_loss: 2.8942e-04
# Epoch 18/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 18: val_loss did not improve from 0.00027
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0048 - val_loss: 2.7528e-04
# Epoch 19/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 19: val_loss improved from 0.00027 to 0.00024, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0045 - val_loss: 2.4467e-04
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 20: val_loss did not improve from 0.00024
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0041 - val_loss: 3.5188e-04
# Epoch 21/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 21: val_loss did not improve from 0.00024
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0037 - val_loss: 2.6779e-04
# Epoch 22/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 22: val_loss did not improve from 0.00024
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0030 - val_loss: 2.6755e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 23: val_loss did not improve from 0.00024
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0027 - val_loss: 2.6303e-04
# Epoch 24/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 24: val_loss did not improve from 0.00024
# 104/104 [==============================] - 3s 33ms/step - loss: 0.0027 - val_loss: 2.9588e-04
# Epoch 25/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 25: val_loss did not improve from 0.00024
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0025 - val_loss: 2.4877e-04
# Epoch 26/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 26: val_loss did not improve from 0.00024
# 104/104 [==============================] - 4s 39ms/step - loss: 0.0024 - val_loss: 3.9280e-04
# Epoch 27/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 27: val_loss improved from 0.00024 to 0.00024, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 51ms/step - loss: 0.0023 - val_loss: 2.3847e-04
# Epoch 28/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 28: val_loss did not improve from 0.00024
# 104/104 [==============================] - 5s 47ms/step - loss: 0.0019 - val_loss: 3.4425e-04
# Epoch 29/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 29: val_loss improved from 0.00024 to 0.00023, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0018 - val_loss: 2.3272e-04
# Epoch 30/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 30: val_loss did not improve from 0.00023
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0017 - val_loss: 2.4867e-04
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 31: val_loss did not improve from 0.00023
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0015 - val_loss: 4.2183e-04
# Epoch 32/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 6: val_loss improved from 0.00070 to 0.00059, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 39ms/step - loss: 0.0074 - val_loss: 5.8898e-04
# Epoch 7/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 7: val_loss improved from 0.00059 to 0.00035, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0069 - val_loss: 3.4559e-04
# Epoch 8/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 8: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0063 - val_loss: 7.1902e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 9: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0056 - val_loss: 5.5890e-04
# Epoch 10/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 10: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 28ms/step - loss: 0.0048 - val_loss: 5.8454e-04
# Epoch 11/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 11: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 28ms/step - loss: 0.0044 - val_loss: 7.4187e-04
# Epoch 12/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 12: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0041 - val_loss: 8.7861e-04
# Epoch 13/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 13: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 14/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 14: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0037 - val_loss: 4.9058e-04
# Epoch 15/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 15: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0034 - val_loss: 4.2142e-04
# Epoch 16/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 16: val_loss did not improve from 0.00035
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 17/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 17: val_loss improved from 0.00035 to 0.00028, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0030 - val_loss: 2.7741e-04
# Epoch 18/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 18: val_loss improved from 0.00028 to 0.00021, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 33ms/step - loss: 0.0026 - val_loss: 2.0696e-04
# Epoch 19/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 19: val_loss did not improve from 0.00021
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0028 - val_loss: 6.3515e-04
# Epoch 20/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 20: val_loss improved from 0.00021 to 0.00020, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0030 - val_loss: 2.0401e-04
# Epoch 21/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 21: val_loss did not improve from 0.00020
# 139/139 [==============================] - 7s 48ms/step - loss: 0.0028 - val_loss: 4.4726e-04
# Epoch 22/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 22: val_loss did not improve from 0.00020
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 23/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 23: val_loss did not improve from 0.00020
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0025 - val_loss: 4.0787e-04
# Epoch 24/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 24: val_loss did not improve from 0.00020
# 139/139 [==============================] - 4s 28ms/step - loss: 0.0026 - val_loss: 2.1862e-04
# Epoch 25/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 25: val_loss did not improve from 0.00020
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0023 - val_loss: 2.9111e-04
# Epoch 26/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 26: val_loss did not improve from 0.00020
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0024 - val_loss: 2.8394e-04
# Epoch 27/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 27: val_loss did not improve from 0.00020
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0026 - val_loss: 2.5769e-04
# Epoch 28/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 28: val_loss did not improve from 0.00020
# 139/139 [==============================] - 3s 21ms/step - loss: 0.0026 - val_loss: 2.3673e-04
# Epoch 29/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 29: val_loss did not improve from 0.00020
# 139/139 [==============================] - 3s 21ms/step - loss: 0.0025 - val_loss: 3.0163e-04
# Epoch 30/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 30: val_loss improved from 0.00020 to 0.00019, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 21ms/step - loss: 0.0025 - val_loss: 1.9345e-04
# Epoch 31/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 31: val_loss did not improve from 0.00019
# 139/139 [==============================] - 3s 20ms/step - loss: 0.0024 - val_loss: 3.5707e-04
# Epoch 32/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 32: val_loss did not improve from 0.00019
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0024 - val_loss: 4.4291e-04
# Epoch 33/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 33: val_loss did not improve from 0.00019
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0024 - val_loss: 3.4713e-04
# Epoch 34/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 34: val_loss did not improve from 0.00019
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0024 - val_loss: 3.1631e-04
# Epoch 35/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 35: val_loss did not improve from 0.00019
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0024 - val_loss: 2.2832e-04
# Epoch 36/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 36: val_loss improved from 0.00019 to 0.00019, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0025 - val_loss: 1.8879e-04
# Epoch 37/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 37: val_loss did not improve from 0.00019
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0024 - val_loss: 6.3931e-04
# Epoch 38/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 38: val_loss did not improve from 0.00019
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0024 - val_loss: 5.4944e-04
# Epoch 39/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 39: val_loss did not improve from 0.00019
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0024 - val_loss: 2.1808e-04
# Epoch 40/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 40: val_loss improved from 0.00019 to 0.00015, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0024 - val_loss: 1.4532e-04
# Epoch 41/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 41: val_loss did not improve from 0.00015
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0023 - val_loss: 4.6802e-04
# Epoch 42/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 42: val_loss did not improve from 0.00015
# 139/139 [==============================] - 5s 38ms/step - loss: 0.0023 - val_loss: 1.4677e-04
# Epoch 43/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 43: val_loss improved from 0.00015 to 0.00014, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 6s 40ms/step - loss: 0.0024 - val_loss: 1.4227e-04
# Epoch 44/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 44: val_loss did not improve from 0.00014
# 139/139 [==============================] - 5s 33ms/step - loss: 0.0023 - val_loss: 2.5692e-04
# Epoch 45/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 45: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 27ms/step - loss: 0.0022 - val_loss: 2.0886e-04
# Epoch 46/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 46: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0024 - val_loss: 3.6457e-04
# Epoch 47/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 47: val_loss did not improve from 0.00014
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0022 - val_loss: 3.0221e-04
# Epoch 48/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 48: val_loss did not improve from 0.00014
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0023 - val_loss: 2.8318e-04
# Epoch 49/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 49: val_loss did not improve from 0.00014
# 139/139 [==============================] - 3s 24ms/step - loss: 0.0022 - val_loss: 2.3902e-04
# Epoch 50/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 50: val_loss improved from 0.00014 to 0.00014, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0024 - val_loss: 1.3614e-04
# Epoch 51/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 51: val_loss did not improve from 0.00014
# 139/139 [==============================] - 3s 24ms/step - loss: 0.0022 - val_loss: 1.7014e-04
# Epoch 52/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 52: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 25ms/step - loss: 0.0023 - val_loss: 1.5005e-04
# Epoch 53/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 53: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 26ms/step - loss: 0.0022 - val_loss: 5.7565e-04
# Epoch 54/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 54: val_loss did not improve from 0.00014
# 139/139 [==============================] - 5s 33ms/step - loss: 0.0022 - val_loss: 7.9019e-04
# Epoch 55/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 55: val_loss improved from 0.00014 to 0.00014, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 33ms/step - loss: 0.0024 - val_loss: 1.3549e-04
# Epoch 56/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 56: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 28ms/step - loss: 0.0023 - val_loss: 3.6258e-04
# Epoch 57/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 57: val_loss did not improve from 0.00014
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0022 - val_loss: 1.4518e-04
# Epoch 58/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 58: val_loss improved from 0.00014 to 0.00013, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0023 - val_loss: 1.3083e-04
# Epoch 59/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 59: val_loss did not improve from 0.00013
# 139/139 [==============================] - 5s 33ms/step - loss: 0.0024 - val_loss: 1.7301e-04
# Epoch 60/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 60: val_loss improved from 0.00013 to 0.00013, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 31ms/step - loss: 0.0023 - val_loss: 1.3058e-04
# Epoch 61/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 61: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 32ms/step - loss: 0.0025 - val_loss: 2.4116e-04
# Epoch 62/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 62: val_loss did not improve from 0.00013
# 139/139 [==============================] - 5s 34ms/step - loss: 0.0023 - val_loss: 1.4596e-04
# Epoch 63/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 63: val_loss did not improve from 0.00013
# 139/139 [==============================] - 5s 34ms/step - loss: 0.0023 - val_loss: 1.4202e-04
# Epoch 64/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 64: val_loss did not improve from 0.00013
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0022 - val_loss: 1.3959e-04
# Epoch 65/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 65: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 27ms/step - loss: 0.0023 - val_loss: 2.7152e-04
# Epoch 66/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 66: val_loss did not improve from 0.00013
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0025 - val_loss: 1.6943e-04
# Epoch 67/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 67: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 26ms/step - loss: 0.0023 - val_loss: 1.3707e-04
# Epoch 68/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 68: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0024 - val_loss: 2.3608e-04
# Epoch 69/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 69: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0023 - val_loss: 6.3092e-04
# Epoch 70/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 70: val_loss did not improve from 0.00013
# 139/139 [==============================] - 4s 30ms/step - loss: 0.0023 - val_loss: 1.3847e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:8046.02520315784
# [57673.13121569629, 22278.956213459827, 13736.211599729133, 8046.02520315784]
# Epoch 1/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0604
# Epoch 1: val_loss improved from inf to 0.00368, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 24s 54ms/step - loss: 0.0604 - val_loss: 0.0037
# Epoch 2/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 2: val_loss did not improve from 0.00368
# 174/174 [==============================] - 5s 28ms/step - loss: 0.0113 - val_loss: 0.0047
# Epoch 3/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 3: val_loss improved from 0.00368 to 0.00180, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 5s 31ms/step - loss: 0.0087 - val_loss: 0.0018
# Epoch 4/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 4: val_loss did not improve from 0.00180
# 174/174 [==============================] - 5s 30ms/step - loss: 0.0072 - val_loss: 0.0019
# Epoch 5/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 5: val_loss did not improve from 0.00180
# 174/174 [==============================] - 5s 31ms/step - loss: 0.0063 - val_loss: 0.0074
# Epoch 6/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 6: val_loss improved from 0.00180 to 0.00095, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 6s 32ms/step - loss: 0.0056 - val_loss: 9.4829e-04
# Epoch 7/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 7: val_loss did not improve from 0.00095
# 174/174 [==============================] - 5s 29ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 8/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 8: val_loss did not improve from 0.00095
# 174/174 [==============================] - 5s 26ms/step - loss: 0.0045 - val_loss: 9.5999e-04
# Epoch 9/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 9: val_loss improved from 0.00095 to 0.00089, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0043 - val_loss: 8.8714e-04
# Epoch 10/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 10: val_loss did not improve from 0.00089
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0039 - val_loss: 8.9429e-04
# Epoch 11/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 11: val_loss did not improve from 0.00089
# 174/174 [==============================] - 4s 23ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 12/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 12: val_loss improved from 0.00089 to 0.00080, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 25ms/step - loss: 0.0034 - val_loss: 8.0031e-04
# Epoch 13/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 13: val_loss did not improve from 0.00080
# 174/174 [==============================] - 4s 25ms/step - loss: 0.0030 - val_loss: 8.3398e-04
# Epoch 14/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 14: val_loss improved from 0.00080 to 0.00061, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 24ms/step - loss: 0.0029 - val_loss: 6.1445e-04
# Epoch 15/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 15: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0027 - val_loss: 9.8751e-04
# Epoch 16/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 16: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 23ms/step - loss: 0.0026 - val_loss: 7.9500e-04
# Epoch 17/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 17: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 23ms/step - loss: 0.0026 - val_loss: 7.9319e-04
# Epoch 18/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 18: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0024 - val_loss: 8.0274e-04
# Epoch 19/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 19: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 20/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 20: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 22ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 21/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 21: val_loss did not improve from 0.00061
# 174/174 [==============================] - 4s 26ms/step - loss: 0.0023 - val_loss: 6.9205e-04
# Epoch 22/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 22: val_loss improved from 0.00061 to 0.00055, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 5s 31ms/step - loss: 0.0022 - val_loss: 5.5084e-04
# Epoch 23/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 23: val_loss improved from 0.00055 to 0.00052, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 6s 34ms/step - loss: 0.0024 - val_loss: 5.2182e-04
# Epoch 24/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 24: val_loss did not improve from 0.00052
# 174/174 [==============================] - 8s 45ms/step - loss: 0.0024 - val_loss: 5.6153e-04
# Epoch 25/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 25: val_loss did not improve from 0.00052
# 174/174 [==============================] - 7s 43ms/step - loss: 0.0025 - val_loss: 5.2798e-04
# Epoch 26/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 26: val_loss did not improve from 0.00052
# 174/174 [==============================] - 7s 40ms/step - loss: 0.0023 - val_loss: 6.6463e-04
# Epoch 27/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 27: val_loss did not improve from 0.00052
# 174/174 [==============================] - 5s 26ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 28/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 28: val_loss did not improve from 0.00052
# 174/174 [==============================] - 5s 29ms/step - loss: 0.0023 - val_loss: 6.5728e-04
# Epoch 29/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 29: val_loss improved from 0.00052 to 0.00045, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 24ms/step - loss: 0.0022 - val_loss: 4.4705e-04
# Epoch 30/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 30: val_loss did not improve from 0.00045
# 174/174 [==============================] - 4s 21ms/step - loss: 0.0024 - val_loss: 5.2578e-04
# Epoch 31/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 31: val_loss did not improve from 0.00045
# 174/174 [==============================] - 3s 19ms/step - loss: 0.0023 - val_loss: 7.5160e-04
# Epoch 32/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 32: val_loss did not improve from 0.00045
# 174/174 [==============================] - 3s 20ms/step - loss: 0.0024 - val_loss: 8.3578e-04
# Epoch 33/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 33: val_loss did not improve from 0.00045
# 174/174 [==============================] - 4s 25ms/step - loss: 0.0021 - val_loss: 5.2732e-04
# Epoch 34/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 7: val_loss improved from 0.00083 to 0.00075, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 43ms/step - loss: 0.0017 - val_loss: 7.5213e-04
# Epoch 8/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 8: val_loss did not improve from 0.00075
# 209/209 [==============================] - 9s 41ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss did not improve from 0.00075
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 10/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 10: val_loss did not improve from 0.00075
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 11/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss improved from 0.00075 to 0.00054, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0014 - val_loss: 5.4304e-04
# Epoch 12/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 12: val_loss did not improve from 0.00054
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 13/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 13: val_loss did not improve from 0.00054
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0013 - val_loss: 7.1448e-04
# Epoch 14/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 14: val_loss did not improve from 0.00054
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 15/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.00054
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 16/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 16: val_loss improved from 0.00054 to 0.00043, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 43ms/step - loss: 0.0013 - val_loss: 4.2668e-04
# Epoch 17/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 17: val_loss did not improve from 0.00043
# 209/209 [==============================] - 10s 46ms/step - loss: 0.0012 - val_loss: 7.8967e-04
# Epoch 18/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00043
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 19/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 19: val_loss did not improve from 0.00043
# 209/209 [==============================] - 11s 54ms/step - loss: 0.0013 - val_loss: 8.3025e-04
# Epoch 20/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 30: val_loss did not improve from 0.00039
# 209/209 [==============================] - 18s 85ms/step - loss: 0.0012 - val_loss: 9.8916e-04
# Epoch 31/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 31: val_loss improved from 0.00039 to 0.00029, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 45ms/step - loss: 0.0012 - val_loss: 2.9194e-04
# Epoch 32/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 32: val_loss did not improve from 0.00029
# 209/209 [==============================] - 10s 46ms/step - loss: 0.0012 - val_loss: 5.7521e-04
# Epoch 33/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 33: val_loss did not improve from 0.00029
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0012 - val_loss: 3.1984e-04
# Epoch 34/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 34: val_loss did not improve from 0.00029
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0012 - val_loss: 6.9793e-04
# Epoch 35/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 35: val_loss did not improve from 0.00029
# 209/209 [==============================] - 10s 48ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 36/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 36: val_loss did not improve from 0.00029
# 209/209 [==============================] - 9s 44ms/step - loss: 0.0012 - val_loss: 2.9601e-04
# Epoch 37/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 37: val_loss did not improve from 0.00029
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0012 - val_loss: 0.0050
# Epoch 38/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 38: val_loss did not improve from 0.00029
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0011 - val_loss: 7.3719e-04
# Epoch 39/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 39: val_loss did not improve from 0.00029
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 40/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 40: val_loss did not improve from 0.00029
# 209/209 [==============================] - 9s 42ms/step - loss: 0.0010 - val_loss: 3.2499e-04
# Epoch 41/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 41: val_loss did not improve from 0.00029
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0011 - val_loss: 5.3963e-04
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:4491.539992162776
# [57673.13121569629, 22278.956213459827, 13736.211599729133, 8046.02520315784, 9796.046605030719, 4491.539992162776]
# Epoch 1/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.6970e-04
# Epoch 13: val_loss improved from 0.00083 to 0.00066, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 14s 49ms/step - loss: 2.6969e-04 - val_loss: 6.5947e-04
# Epoch 14/100
# 278/279 [============================>.] - ETA: 0s - loss: 2.4406e-04
# Epoch 14: val_loss did not improve from 0.00066
# 279/279 [==============================] - 13s 45ms/step - loss: 2.4442e-04 - val_loss: 0.0017
# Epoch 15/100
# 279/279 [==============================] - ETA: 0s - loss: 2.4519e-04
# Epoch 15: val_loss did not improve from 0.00066
# 279/279 [==============================] - 12s 42ms/step - loss: 2.4519e-04 - val_loss: 0.0013
# Epoch 16/100
# 279/279 [==============================] - ETA: 0s - loss: 2.3398e-04
# Epoch 16: val_loss did not improve from 0.00066
# 279/279 [==============================] - 15s 53ms/step - loss: 2.3398e-04 - val_loss: 0.0021
# Epoch 17/100
# 278/279 [============================>.] - ETA: 0s - loss: 2.5136e-04
# Epoch 17: val_loss did not improve from 0.00066
# 279/279 [==============================] - 16s 58ms/step - loss: 2.5088e-04 - val_loss: 0.0027
# Epoch 18/100
# 278/279 [============================>.] - ETA: 0s - loss: 2.4528e-04
# Epoch 18: val_loss did not improve from 0.00066
# 279/279 [==============================] - 15s 54ms/step - loss: 2.4644e-04 - val_loss: 0.0038
# Epoch 19/100
# 279/279 [==============================] - ETA: 0s - loss: 2.6082e-04
# Epoch 19: val_loss did not improve from 0.00066
# 279/279 [==============================] - 15s 53ms/step - loss: 2.6082e-04 - val_loss: 0.0028
# Epoch 20/100
# 279/279 [==============================] - ETA: 0s - loss: 2.2250e-04
# Epoch 20: val_loss did not improve from 0.00066
# 279/279 [==============================] - 15s 54ms/step - loss: 2.2250e-04 - val_loss: 0.0035
# Epoch 21/100
# 278/279 [============================>.] - ETA: 0s - loss: 2.4120e-04
# Epoch 21: val_loss did not improve from 0.00066
# 279/279 [==============================] - 15s 55ms/step - loss: 2.4104e-04 - val_loss: 0.0014
# Epoch 22/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.3608e-04
# Epoch 22: val_loss did not improve from 0.00066
# 279/279 [==============================] - 16s 56ms/step - loss: 2.3677e-04 - val_loss: 7.4227e-04
# Epoch 23/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.3223e-04
# Epoch 23: val_loss did not improve from 0.00066
# 279/279 [==============================] - 14s 51ms/step - loss: 2.3209e-04 - val_loss: 0.0026
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:13947.913415625992
# [57673.13121569629, 22278.956213459827, 13736.211599729133, 8046.02520315784, 9796.046605030719, 4491.539992162776, 41542.8353361776, 13947.913415625992]
# Epoch 1/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.4396e-04
# Epoch 29: val_loss did not improve from 0.00026
# 314/314 [==============================] - 15s 49ms/step - loss: 1.4369e-04 - val_loss: 4.9964e-04
# Epoch 30/100
# 314/314 [==============================] - ETA: 0s - loss: 1.6447e-04
# Epoch 30: val_loss improved from 0.00026 to 0.00024, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 17s 55ms/step - loss: 1.6447e-04 - val_loss: 2.3554e-04
# Epoch 31/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.3488e-04
# Epoch 31: val_loss improved from 0.00024 to 0.00018, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 19s 60ms/step - loss: 1.3486e-04 - val_loss: 1.8394e-04
# Epoch 32/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.5207e-04
# Epoch 32: val_loss did not improve from 0.00018
# 314/314 [==============================] - 17s 53ms/step - loss: 1.5312e-04 - val_loss: 7.0250e-04
# Epoch 33/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.5545e-04
# Epoch 33: val_loss did not improve from 0.00018
# 314/314 [==============================] - 13s 40ms/step - loss: 1.5529e-04 - val_loss: 2.0835e-04
# Epoch 34/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.4517e-04
# Epoch 34: val_loss did not improve from 0.00018
# 314/314 [==============================] - 12s 37ms/step - loss: 1.4483e-04 - val_loss: 2.9786e-04
# Epoch 35/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.4446e-04
# Epoch 35: val_loss did not improve from 0.00018
# 314/314 [==============================] - 11s 36ms/step - loss: 1.4418e-04 - val_loss: 9.5211e-04
# Epoch 36/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.3802e-04
# Epoch 36: val_loss did not improve from 0.00018
# 314/314 [==============================] - 13s 43ms/step - loss: 1.3850e-04 - val_loss: 0.0012
# Epoch 37/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.4307e-04
# Epoch 37: val_loss did not improve from 0.00018
# 314/314 [==============================] - 19s 60ms/step - loss: 1.4334e-04 - val_loss: 9.1945e-04
# Epoch 38/100
# 314/314 [==============================] - ETA: 0s - loss: 1.5071e-04
# Epoch 38: val_loss did not improve from 0.00018
# 314/314 [==============================] - 21s 65ms/step - loss: 1.5071e-04 - val_loss: 1.9994e-04
# Epoch 39/100
# 314/314 [==============================] - ETA: 0s - loss: 1.3890e-04
# Epoch 40: val_loss did not improve from 0.00018
# 314/314 [==============================] - 13s 40ms/step - loss: 1.3890e-04 - val_loss: 5.3327e-04
# Epoch 41/100
# 314/314 [==============================] - ETA: 0s - loss: 1.2650e-04
# Epoch 41: val_loss did not improve from 0.00018
# 314/314 [==============================] - 13s 42ms/step - loss: 1.2650e-04 - val_loss: 3.2547e-04
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:7491.583716987908
# [57673.13121569629, 22278.956213459827, 13736.211599729133, 8046.02520315784, 9796.046605030719, 4491.539992162776, 41542.8353361776, 13947.913415625992, 7491.583716987908]
# Epoch 1/100
# 341/341 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 1: val_loss improved from inf to 0.00449, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 112s 133ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 2/100
# 341/341 [==============================] - ETA: 0s - loss: 6.5452e-04
# Epoch 2: val_loss improved from 0.00449 to 0.00311, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 22s 63ms/step - loss: 6.5452e-04 - val_loss: 0.0031
# Epoch 3/100
# 341/341 [==============================] - ETA: 0s - loss: 3.9714e-04
# Epoch 3: val_loss improved from 0.00311 to 0.00277, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 31s 90ms/step - loss: 3.9714e-04 - val_loss: 0.0028
# Epoch 4/100
# 341/341 [==============================] - ETA: 0s - loss: 2.9834e-04
# Epoch 4: val_loss did not improve from 0.00277
# 341/341 [==============================] - 31s 90ms/step - loss: 2.9834e-04 - val_loss: 0.0046
# Epoch 5/100
# 341/341 [==============================] - ETA: 0s - loss: 2.2897e-04
# Epoch 5: val_loss improved from 0.00277 to 0.00198, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 28s 83ms/step - loss: 2.2897e-04 - val_loss: 0.0020
# Epoch 6/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.8761e-04
# Epoch 6: val_loss did not improve from 0.00198
# 341/341 [==============================] - 35s 104ms/step - loss: 1.8737e-04 - val_loss: 0.0021
# Epoch 7/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.5389e-04
# Epoch 7: val_loss improved from 0.00198 to 0.00163, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 24s 69ms/step - loss: 1.5365e-04 - val_loss: 0.0016
# Epoch 8/100
# 341/341 [==============================] - ETA: 0s - loss: 1.1529e-04
# Epoch 8: val_loss did not improve from 0.00163
# 341/341 [==============================] - 23s 69ms/step - loss: 1.1529e-04 - val_loss: 0.0022
# Epoch 9/100
# 341/341 [==============================] - ETA: 0s - loss: 1.0828e-04
# Epoch 9: val_loss improved from 0.00163 to 0.00074, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 31s 92ms/step - loss: 1.0828e-04 - val_loss: 7.3908e-04
# Epoch 10/100
# 341/341 [==============================] - ETA: 0s - loss: 9.4123e-05
# Epoch 10: val_loss did not improve from 0.00074
# 341/341 [==============================] - 20s 58ms/step - loss: 9.4123e-05 - val_loss: 7.4430e-04
# Epoch 11/100
# 341/341 [==============================] - ETA: 0s - loss: 9.2978e-05
# Epoch 11: val_loss did not improve from 0.00074
# 341/341 [==============================] - 20s 59ms/step - loss: 9.2978e-05 - val_loss: 0.0010
# Epoch 12/100
# 341/341 [==============================] - ETA: 0s - loss: 8.8006e-05
# Epoch 12: val_loss improved from 0.00074 to 0.00053, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 27s 80ms/step - loss: 8.8006e-05 - val_loss: 5.2877e-04
# Epoch 13/100
# 340/341 [============================>.] - ETA: 0s - loss: 7.9598e-05
# Epoch 13: val_loss improved from 0.00053 to 0.00035, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 24s 71ms/step - loss: 7.9565e-05 - val_loss: 3.4964e-04
# Epoch 14/100
# 340/341 [============================>.] - ETA: 0s - loss: 8.5702e-05
# Epoch 14: val_loss did not improve from 0.00035
# 341/341 [==============================] - 20s 58ms/step - loss: 8.5658e-05 - val_loss: 7.9962e-04
# Epoch 15/100
# 341/341 [==============================] - ETA: 0s - loss: 7.3479e-05
# Epoch 15: val_loss did not improve from 0.00035
# 341/341 [==============================] - 27s 79ms/step - loss: 7.3479e-05 - val_loss: 0.0015
# Epoch 16/100
# 340/341 [============================>.] - ETA: 0s - loss: 7.3317e-05
# Epoch 16: val_loss did not improve from 0.00035
# 341/341 [==============================] - 29s 84ms/step - loss: 7.3272e-05 - val_loss: 9.8777e-04
# Epoch 17/100
# 340/341 [============================>.] - ETA: 0s - loss: 7.0482e-05
# Epoch 17: val_loss did not improve from 0.00035
# 341/341 [==============================] - 21s 62ms/step - loss: 7.0388e-05 - val_loss: 5.9663e-04
# Epoch 18/100
# 341/341 [==============================] - ETA: 0s - loss: 6.9817e-05
# Epoch 18: val_loss did not improve from 0.00035
# 341/341 [==============================] - 28s 82ms/step - loss: 6.9817e-05 - val_loss: 0.0012
# Epoch 19/100
# 341/341 [==============================] - ETA: 0s - loss: 6.9090e-05
# Epoch 19: val_loss did not improve from 0.00035
# 341/341 [==============================] - 25s 73ms/step - loss: 6.9090e-05 - val_loss: 7.1616e-04
# Epoch 20/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.5073e-05
# Epoch 20: val_loss did not improve from 0.00035
# 341/341 [==============================] - 14s 41ms/step - loss: 6.4972e-05 - val_loss: 4.8553e-04
# Epoch 21/100
# 341/341 [==============================] - ETA: 0s - loss: 6.3534e-05
# Epoch 21: val_loss did not improve from 0.00035
# 341/341 [==============================] - 16s 48ms/step - loss: 6.3534e-05 - val_loss: 0.0011
# Epoch 22/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.3655e-05
# Epoch 22: val_loss did not improve from 0.00035
# 341/341 [==============================] - 29s 84ms/step - loss: 6.3584e-05 - val_loss: 0.0012
# Epoch 23/100
# 341/341 [==============================] - ETA: 0s - loss: 6.4990e-05
# Epoch 23: val_loss did not improve from 0.00035
# 341/341 [==============================] - 24s 71ms/step - loss: 6.4990e-05 - val_loss: 7.8616e-04
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:27303.55470193377
# [57673.13121569629, 22278.956213459827, 13736.211599729133, 8046.02520315784, 9796.046605030719, 4491.539992162776, 41542.8353361776, 13947.913415625992, 7491.583716987908, 27303.55470193377]

# %%
print(predict)
# Out:
# [array([[140209.12]], dtype=float32), array([[182027.75]], dtype=float32), array([[182428.66]], dtype=float32), array([[186031.28]], dtype=float32), array([[183953.84]], dtype=float32), array([[188967.83]], dtype=float32), array([[143707.14]], dtype=float32), array([[176175.39]], dtype=float32), array([[185188.52]], dtype=float32), array([[163041.72]], dtype=float32)]

# %% [markdown]
# ![image.png](attachment:image.png)

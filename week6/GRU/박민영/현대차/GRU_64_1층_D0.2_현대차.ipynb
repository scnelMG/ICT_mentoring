# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 1: val_loss improved from inf to 0.00837, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 12s 100ms/step - loss: 0.0625 - val_loss: 0.0084
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 2: val_loss did not improve from 0.00837
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0130 - val_loss: 0.0239
# Epoch 3/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0091
# Epoch 3: val_loss improved from 0.00837 to 0.00633, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0090 - val_loss: 0.0063
# Epoch 4/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0074
# Epoch 4: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 24ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 5: val_loss did not improve from 0.00633
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0059 - val_loss: 0.0110
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 6: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 30ms/step - loss: 0.0064 - val_loss: 0.0135
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 7: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 34ms/step - loss: 0.0058 - val_loss: 0.0137
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 8: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 31ms/step - loss: 0.0056 - val_loss: 0.0236
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 9: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 38ms/step - loss: 0.0049 - val_loss: 0.0214
# Epoch 10/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 10: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0047 - val_loss: 0.0117
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 11: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 33ms/step - loss: 0.0048 - val_loss: 0.0230
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 12: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0046 - val_loss: 0.0131
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 13: val_loss did not improve from 0.00633
# 34/34 [==============================] - 1s 35ms/step - loss: 0.0056 - val_loss: 0.0160
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:15392.070237995433
# [15392.070237995433]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0789
# Epoch 1: val_loss improved from inf to 0.00389, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 25s 95ms/step - loss: 0.0771 - val_loss: 0.0039
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0135
# Epoch 2: val_loss improved from 0.00389 to 0.00056, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 28ms/step - loss: 0.0135 - val_loss: 5.5563e-04
# Epoch 3/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 3: val_loss did not improve from 0.00056
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0076 - val_loss: 7.5473e-04
# Epoch 4/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 4: val_loss improved from 0.00056 to 0.00037, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0066 - val_loss: 3.6686e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 5: val_loss improved from 0.00037 to 0.00026, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0058 - val_loss: 2.6358e-04
# Epoch 6/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 6: val_loss did not improve from 0.00026
# 69/69 [==============================] - 2s 29ms/step - loss: 0.0061 - val_loss: 2.7203e-04
# Epoch 7/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 7: val_loss improved from 0.00026 to 0.00025, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0059 - val_loss: 2.5026e-04
# Epoch 8/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 8: val_loss did not improve from 0.00025
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0049 - val_loss: 3.5545e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 9: val_loss did not improve from 0.00025
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0046 - val_loss: 3.7462e-04
# Epoch 10/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 10: val_loss did not improve from 0.00025
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0056 - val_loss: 3.6690e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 11: val_loss improved from 0.00025 to 0.00021, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 37ms/step - loss: 0.0051 - val_loss: 2.1482e-04
# Epoch 12/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 12: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 34ms/step - loss: 0.0051 - val_loss: 4.6412e-04
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 13: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0045 - val_loss: 2.3269e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 14: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 34ms/step - loss: 0.0045 - val_loss: 3.4784e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 15: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 31ms/step - loss: 0.0041 - val_loss: 3.5855e-04
# Epoch 16/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 16: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0042 - val_loss: 7.2563e-04
# Epoch 17/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 17: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 35ms/step - loss: 0.0038 - val_loss: 3.1220e-04
# Epoch 18/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 18: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 27ms/step - loss: 0.0035 - val_loss: 3.7890e-04
# Epoch 19/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 19: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0039 - val_loss: 2.7713e-04
# Epoch 20/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 20: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 30ms/step - loss: 0.0037 - val_loss: 3.1516e-04
# Epoch 21/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 21: val_loss did not improve from 0.00021
# 69/69 [==============================] - 2s 33ms/step - loss: 0.0032 - val_loss: 2.9020e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:21493.814406738158
# [15392.070237995433, 21493.814406738158]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 1: val_loss improved from inf to 0.00078, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 23s 58ms/step - loss: 0.0158 - val_loss: 7.8089e-04
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 2: val_loss did not improve from 0.00078
# 104/104 [==============================] - 3s 30ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0069
# Epoch 3: val_loss improved from 0.00078 to 0.00067, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0069 - val_loss: 6.7357e-04
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 4: val_loss did not improve from 0.00067
# 104/104 [==============================] - 3s 25ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 5/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 5: val_loss did not improve from 0.00067
# 104/104 [==============================] - 3s 24ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 6: val_loss improved from 0.00067 to 0.00046, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0067 - val_loss: 4.6034e-04
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 7: val_loss improved from 0.00046 to 0.00025, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0054 - val_loss: 2.5141e-04
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 8: val_loss did not improve from 0.00025
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0050 - val_loss: 2.6296e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 9: val_loss did not improve from 0.00025
# 104/104 [==============================] - 3s 26ms/step - loss: 0.0051 - val_loss: 2.9668e-04
# Epoch 10/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 10: val_loss improved from 0.00025 to 0.00020, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0044 - val_loss: 2.0254e-04
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 11: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 35ms/step - loss: 0.0043 - val_loss: 9.0526e-04
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 12: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 28ms/step - loss: 0.0045 - val_loss: 2.2885e-04
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 13: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 27ms/step - loss: 0.0039 - val_loss: 2.3113e-04
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 14: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 31ms/step - loss: 0.0035 - val_loss: 2.3757e-04
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 15: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 36ms/step - loss: 0.0037 - val_loss: 2.8768e-04
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 16: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0033 - val_loss: 4.9530e-04
# Epoch 17/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 17: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 29ms/step - loss: 0.0029 - val_loss: 2.5056e-04
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 18: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 37ms/step - loss: 0.0029 - val_loss: 2.3059e-04
# Epoch 19/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 19: val_loss did not improve from 0.00020
# 104/104 [==============================] - 3s 32ms/step - loss: 0.0028 - val_loss: 6.2915e-04
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 20: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 34ms/step - loss: 0.0026 - val_loss: 7.7930e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:11596.089260645462
# [15392.070237995433, 21493.814406738158, 11596.089260645462]
# Epoch 1/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0265
# Epoch 1: val_loss improved from inf to 0.00109, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 15s 38ms/step - loss: 0.0263 - val_loss: 0.0011
# Epoch 2/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 2: val_loss improved from 0.00109 to 0.00094, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 26ms/step - loss: 0.0093 - val_loss: 9.3501e-04
# Epoch 3/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 3: val_loss improved from 0.00094 to 0.00071, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 23ms/step - loss: 0.0081 - val_loss: 7.1120e-04
# Epoch 4/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 4: val_loss improved from 0.00071 to 0.00034, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 29ms/step - loss: 0.0070 - val_loss: 3.3503e-04
# Epoch 5/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 5: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 26ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 6/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 6: val_loss did not improve from 0.00034
# 139/139 [==============================] - 3s 24ms/step - loss: 0.0056 - val_loss: 5.0162e-04
# Epoch 7/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 7: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 25ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 8/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 8: val_loss did not improve from 0.00034
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0045 - val_loss: 9.4130e-04
# Epoch 9/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 9: val_loss did not improve from 0.00034
# 139/139 [==============================] - 3s 25ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 10/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 10: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 26ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 11/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 11: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 28ms/step - loss: 0.0038 - val_loss: 8.4971e-04
# Epoch 12/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 12: val_loss did not improve from 0.00034
# 139/139 [==============================] - 3s 22ms/step - loss: 0.0036 - val_loss: 5.2117e-04
# Epoch 13/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 13: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 27ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 14/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 14: val_loss did not improve from 0.00034
# 139/139 [==============================] - 4s 32ms/step - loss: 0.0030 - val_loss: 3.8531e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:12449.254758831548
# [15392.070237995433, 21493.814406738158, 11596.089260645462, 12449.254758831548]
# Epoch 1/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 1: val_loss improved from inf to 0.00339, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 20s 43ms/step - loss: 0.0307 - val_loss: 0.0034
# Epoch 2/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 2: val_loss improved from 0.00339 to 0.00158, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 5s 27ms/step - loss: 0.0068 - val_loss: 0.0016
# Epoch 3/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 3: val_loss did not improve from 0.00158
# 174/174 [==============================] - 5s 30ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 4/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 4: val_loss improved from 0.00158 to 0.00108, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 6s 34ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 5/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 5: val_loss improved from 0.00108 to 0.00041, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 6s 36ms/step - loss: 0.0039 - val_loss: 4.1292e-04
# Epoch 6/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 6: val_loss did not improve from 0.00041
# 174/174 [==============================] - 7s 40ms/step - loss: 0.0033 - val_loss: 8.8098e-04
# Epoch 7/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 7: val_loss did not improve from 0.00041
# 174/174 [==============================] - 7s 38ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 8/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 8: val_loss did not improve from 0.00041
# 174/174 [==============================] - 8s 47ms/step - loss: 0.0027 - val_loss: 6.0053e-04
# Epoch 9/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 9: val_loss did not improve from 0.00041
# 174/174 [==============================] - 6s 36ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 10/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss improved from 0.00041 to 0.00041, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 5s 31ms/step - loss: 0.0023 - val_loss: 4.1007e-04
# Epoch 11/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 11: val_loss improved from 0.00041 to 0.00040, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 25ms/step - loss: 0.0021 - val_loss: 4.0156e-04
# Epoch 12/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 12: val_loss improved from 0.00040 to 0.00038, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 5s 27ms/step - loss: 0.0020 - val_loss: 3.8141e-04
# Epoch 13/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 13: val_loss did not improve from 0.00038
# 174/174 [==============================] - 4s 24ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 14/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 14: val_loss improved from 0.00038 to 0.00033, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 4s 23ms/step - loss: 0.0020 - val_loss: 3.2682e-04
# Epoch 15/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 15: val_loss did not improve from 0.00033
# 174/174 [==============================] - 4s 24ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 16/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 16: val_loss did not improve from 0.00033
# 174/174 [==============================] - 5s 26ms/step - loss: 0.0019 - val_loss: 6.5122e-04
# Epoch 17/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 17: val_loss did not improve from 0.00033
# 174/174 [==============================] - 4s 24ms/step - loss: 0.0019 - val_loss: 4.5985e-04
# Epoch 18/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 18: val_loss did not improve from 0.00033
# 174/174 [==============================] - 4s 25ms/step - loss: 0.0018 - val_loss: 6.0876e-04
# Epoch 19/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 19: val_loss improved from 0.00033 to 0.00029, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 6s 33ms/step - loss: 0.0017 - val_loss: 2.9026e-04
# Epoch 20/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 20: val_loss did not improve from 0.00029
# 174/174 [==============================] - 5s 29ms/step - loss: 0.0017 - val_loss: 4.4085e-04
# Epoch 21/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 21: val_loss did not improve from 0.00029
# 174/174 [==============================] - 5s 31ms/step - loss: 0.0017 - val_loss: 4.5758e-04
# Epoch 22/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 22: val_loss did not improve from 0.00029
# 174/174 [==============================] - 6s 33ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 23/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 23: val_loss did not improve from 0.00029
# 174/174 [==============================] - 7s 40ms/step - loss: 0.0015 - val_loss: 4.2628e-04
# Epoch 24/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 24: val_loss did not improve from 0.00029
# 174/174 [==============================] - 7s 40ms/step - loss: 0.0016 - val_loss: 3.0432e-04
# Epoch 25/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 25: val_loss did not improve from 0.00029
# 174/174 [==============================] - 6s 33ms/step - loss: 0.0015 - val_loss: 4.2400e-04
# Epoch 26/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 26: val_loss did not improve from 0.00029
# 174/174 [==============================] - 6s 33ms/step - loss: 0.0016 - val_loss: 4.5737e-04
# Epoch 27/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 27: val_loss did not improve from 0.00029
# 174/174 [==============================] - 5s 30ms/step - loss: 0.0016 - val_loss: 3.6615e-04
# Epoch 28/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 28: val_loss did not improve from 0.00029
# 174/174 [==============================] - 5s 29ms/step - loss: 0.0015 - val_loss: 9.6686e-04
# Epoch 29/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 29: val_loss did not improve from 0.00029
# 174/174 [==============================] - 5s 26ms/step - loss: 0.0016 - val_loss: 0.0028
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:14123.663847750779
# [15392.070237995433, 21493.814406738158, 11596.089260645462, 12449.254758831548, 14123.663847750779]
# Epoch 1/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 1: val_loss improved from inf to 0.00068, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 16s 37ms/step - loss: 0.0076 - val_loss: 6.7887e-04
# Epoch 2/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss did not improve from 0.00068
# 209/209 [==============================] - 6s 27ms/step - loss: 0.0019 - val_loss: 8.8747e-04
# Epoch 3/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 3: val_loss improved from 0.00068 to 0.00042, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 6s 27ms/step - loss: 0.0016 - val_loss: 4.2427e-04
# Epoch 4/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 4: val_loss did not improve from 0.00042
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 5/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 5: val_loss did not improve from 0.00042
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 6/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss did not improve from 0.00042
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 7/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 7: val_loss improved from 0.00042 to 0.00036, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 42ms/step - loss: 0.0011 - val_loss: 3.6121e-04
# Epoch 8/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 8: val_loss did not improve from 0.00036
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0010 - val_loss: 6.4258e-04
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 9.6317e-04
# Epoch 9: val_loss did not improve from 0.00036
# 209/209 [==============================] - 8s 36ms/step - loss: 9.6317e-04 - val_loss: 4.8088e-04
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - loss: 9.8958e-04
# Epoch 10: val_loss did not improve from 0.00036
# 209/209 [==============================] - 5s 26ms/step - loss: 9.8958e-04 - val_loss: 4.6492e-04
# Epoch 11/100
# 209/209 [==============================] - ETA: 0s - loss: 8.5404e-04
# Epoch 11: val_loss did not improve from 0.00036
# 209/209 [==============================] - 5s 24ms/step - loss: 8.5404e-04 - val_loss: 0.0013
# Epoch 12/100
# 208/209 [============================>.] - ETA: 0s - loss: 8.8444e-04
# Epoch 12: val_loss improved from 0.00036 to 0.00032, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 5s 26ms/step - loss: 8.8183e-04 - val_loss: 3.2005e-04
# Epoch 13/100
# 205/209 [============================>.] - ETA: 0s - loss: 8.6917e-04
# Epoch 13: val_loss did not improve from 0.00032
# 209/209 [==============================] - 5s 25ms/step - loss: 8.5919e-04 - val_loss: 3.6132e-04
# Epoch 14/100
# 208/209 [============================>.] - ETA: 0s - loss: 7.3841e-04
# Epoch 14: val_loss did not improve from 0.00032
# 209/209 [==============================] - 5s 23ms/step - loss: 7.4378e-04 - val_loss: 4.5095e-04
# Epoch 15/100
# 206/209 [============================>.] - ETA: 0s - loss: 8.5874e-04
# Epoch 15: val_loss did not improve from 0.00032
# 209/209 [==============================] - 5s 26ms/step - loss: 8.5486e-04 - val_loss: 5.3017e-04
# Epoch 16/100
# 209/209 [==============================] - ETA: 0s - loss: 8.2267e-04
# Epoch 16: val_loss did not improve from 0.00032
# 209/209 [==============================] - 6s 26ms/step - loss: 8.2267e-04 - val_loss: 5.0882e-04
# Epoch 17/100
# 209/209 [==============================] - ETA: 0s - loss: 7.1930e-04
# Epoch 17: val_loss did not improve from 0.00032
# 209/209 [==============================] - 6s 28ms/step - loss: 7.1930e-04 - val_loss: 5.8067e-04
# Epoch 18/100
# 207/209 [============================>.] - ETA: 0s - loss: 8.0206e-04
# Epoch 18: val_loss improved from 0.00032 to 0.00032, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 6s 27ms/step - loss: 7.9746e-04 - val_loss: 3.1739e-04
# Epoch 19/100
# 205/209 [============================>.] - ETA: 0s - loss: 8.0113e-04
# Epoch 19: val_loss did not improve from 0.00032
# 209/209 [==============================] - 6s 28ms/step - loss: 8.0161e-04 - val_loss: 5.8676e-04
# Epoch 20/100
# 208/209 [============================>.] - ETA: 0s - loss: 7.0081e-04
# Epoch 20: val_loss did not improve from 0.00032
# 209/209 [==============================] - 8s 39ms/step - loss: 7.0365e-04 - val_loss: 6.8881e-04
# Epoch 21/100
# 209/209 [==============================] - ETA: 0s - loss: 8.1025e-04
# Epoch 21: val_loss did not improve from 0.00032
# 209/209 [==============================] - 7s 33ms/step - loss: 8.1025e-04 - val_loss: 5.2088e-04
# Epoch 22/100
# 209/209 [==============================] - ETA: 0s - loss: 7.1302e-04
# Epoch 22: val_loss improved from 0.00032 to 0.00030, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 9s 41ms/step - loss: 7.1302e-04 - val_loss: 3.0381e-04
# Epoch 23/100
# 206/209 [============================>.] - ETA: 0s - loss: 8.1928e-04
# Epoch 23: val_loss did not improve from 0.00030
# 209/209 [==============================] - 7s 35ms/step - loss: 8.2081e-04 - val_loss: 5.6243e-04
# Epoch 24/100
# 208/209 [============================>.] - ETA: 0s - loss: 7.6336e-04
# Epoch 24: val_loss did not improve from 0.00030
# 209/209 [==============================] - 6s 27ms/step - loss: 7.6317e-04 - val_loss: 6.2675e-04
# Epoch 25/100
# 209/209 [==============================] - ETA: 0s - loss: 7.6802e-04
# Epoch 25: val_loss did not improve from 0.00030
# 209/209 [==============================] - 6s 27ms/step - loss: 7.6802e-04 - val_loss: 7.4049e-04
# Epoch 26/100
# 209/209 [==============================] - ETA: 0s - loss: 6.9231e-04
# Epoch 26: val_loss improved from 0.00030 to 0.00028, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 6s 27ms/step - loss: 6.9231e-04 - val_loss: 2.7553e-04
# Epoch 27/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.8017e-04
# Epoch 27: val_loss did not improve from 0.00028
# 209/209 [==============================] - 5s 25ms/step - loss: 6.7864e-04 - val_loss: 0.0011
# Epoch 28/100
# 205/209 [============================>.] - ETA: 0s - loss: 7.4581e-04
# Epoch 28: val_loss did not improve from 0.00028
# 209/209 [==============================] - 5s 23ms/step - loss: 7.4572e-04 - val_loss: 0.0021
# Epoch 29/100
# 208/209 [============================>.] - ETA: 0s - loss: 7.0395e-04
# Epoch 29: val_loss did not improve from 0.00028
# 209/209 [==============================] - 5s 25ms/step - loss: 7.0161e-04 - val_loss: 9.0159e-04
# Epoch 30/100
# 208/209 [============================>.] - ETA: 0s - loss: 7.0373e-04
# Epoch 30: val_loss improved from 0.00028 to 0.00027, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 6s 27ms/step - loss: 7.0269e-04 - val_loss: 2.7381e-04
# Epoch 31/100
# 208/209 [============================>.] - ETA: 0s - loss: 8.4410e-04
# Epoch 31: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 28ms/step - loss: 8.4327e-04 - val_loss: 6.2270e-04
# Epoch 32/100
# 209/209 [==============================] - ETA: 0s - loss: 7.3983e-04
# Epoch 32: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 31ms/step - loss: 7.3983e-04 - val_loss: 3.1386e-04
# Epoch 33/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.9120e-04
# Epoch 33: val_loss did not improve from 0.00027
# 209/209 [==============================] - 9s 44ms/step - loss: 6.9076e-04 - val_loss: 3.5047e-04
# Epoch 34/100
# 206/209 [============================>.] - ETA: 0s - loss: 7.6042e-04
# Epoch 34: val_loss did not improve from 0.00027
# 209/209 [==============================] - 9s 42ms/step - loss: 7.5663e-04 - val_loss: 4.6901e-04
# Epoch 35/100
# 209/209 [==============================] - ETA: 0s - loss: 6.6002e-04
# Epoch 35: val_loss did not improve from 0.00027
# 209/209 [==============================] - 8s 37ms/step - loss: 6.6002e-04 - val_loss: 8.8553e-04
# Epoch 36/100
# 207/209 [============================>.] - ETA: 0s - loss: 7.5519e-04
# Epoch 36: val_loss did not improve from 0.00027
# 209/209 [==============================] - 7s 35ms/step - loss: 7.6147e-04 - val_loss: 2.8304e-04
# Epoch 37/100
# 206/209 [============================>.] - ETA: 0s - loss: 7.1166e-04
# Epoch 37: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 31ms/step - loss: 7.1385e-04 - val_loss: 7.4754e-04
# Epoch 38/100
# 206/209 [============================>.] - ETA: 0s - loss: 7.4122e-04
# Epoch 38: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 29ms/step - loss: 7.4392e-04 - val_loss: 3.6879e-04
# Epoch 39/100
# 207/209 [============================>.] - ETA: 0s - loss: 5.8907e-04
# Epoch 39: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 30ms/step - loss: 5.9643e-04 - val_loss: 4.9605e-04
# Epoch 40/100
# 207/209 [============================>.] - ETA: 0s - loss: 6.7985e-04
# Epoch 40: val_loss did not improve from 0.00027
# 209/209 [==============================] - 6s 27ms/step - loss: 6.7655e-04 - val_loss: 0.0013
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:5755.44803878245
# [15392.070237995433, 21493.814406738158, 11596.089260645462, 12449.254758831548, 14123.663847750779, 5755.44803878245]
# Epoch 1/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 1: val_loss improved from inf to 0.00516, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 31s 43ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 2/100
# 244/244 [==============================] - ETA: 0s - loss: 7.4380e-04
# Epoch 2: val_loss improved from 0.00516 to 0.00170, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 9s 37ms/step - loss: 7.4380e-04 - val_loss: 0.0017
# Epoch 3/100
# 242/244 [============================>.] - ETA: 0s - loss: 5.5575e-04
# Epoch 3: val_loss did not improve from 0.00170
# 244/244 [==============================] - 7s 30ms/step - loss: 5.5416e-04 - val_loss: 0.0021
# Epoch 4/100
# 242/244 [============================>.] - ETA: 0s - loss: 4.5804e-04
# Epoch 4: val_loss did not improve from 0.00170
# 244/244 [==============================] - 8s 32ms/step - loss: 4.5862e-04 - val_loss: 0.0025
# Epoch 5/100
# 242/244 [============================>.] - ETA: 0s - loss: 3.8094e-04
# Epoch 5: val_loss improved from 0.00170 to 0.00063, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 9s 38ms/step - loss: 3.8206e-04 - val_loss: 6.2581e-04
# Epoch 6/100
# 243/244 [============================>.] - ETA: 0s - loss: 3.3231e-04
# Epoch 6: val_loss improved from 0.00063 to 0.00059, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 9s 36ms/step - loss: 3.3427e-04 - val_loss: 5.8562e-04
# Epoch 7/100
# 243/244 [============================>.] - ETA: 0s - loss: 3.2129e-04
# Epoch 7: val_loss did not improve from 0.00059
# 244/244 [==============================] - 9s 38ms/step - loss: 3.2096e-04 - val_loss: 0.0024
# Epoch 8/100
# 242/244 [============================>.] - ETA: 0s - loss: 3.1782e-04
# Epoch 8: val_loss did not improve from 0.00059
# 244/244 [==============================] - 9s 35ms/step - loss: 3.1809e-04 - val_loss: 0.0029
# Epoch 9/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.7757e-04
# Epoch 9: val_loss did not improve from 0.00059
# 244/244 [==============================] - 7s 28ms/step - loss: 2.7787e-04 - val_loss: 8.8421e-04
# Epoch 10/100
# 244/244 [==============================] - ETA: 0s - loss: 2.7811e-04
# Epoch 10: val_loss did not improve from 0.00059
# 244/244 [==============================] - 5s 21ms/step - loss: 2.7811e-04 - val_loss: 0.0023
# Epoch 11/100
# 241/244 [============================>.] - ETA: 0s - loss: 3.0843e-04
# Epoch 11: val_loss did not improve from 0.00059
# 244/244 [==============================] - 5s 19ms/step - loss: 3.0622e-04 - val_loss: 0.0063
# Epoch 12/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.6504e-04
# Epoch 12: val_loss did not improve from 0.00059
# 244/244 [==============================] - 5s 19ms/step - loss: 2.6448e-04 - val_loss: 0.0049
# Epoch 13/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.4634e-04
# Epoch 13: val_loss did not improve from 0.00059
# 244/244 [==============================] - 5s 20ms/step - loss: 2.4605e-04 - val_loss: 0.0065
# Epoch 14/100
# 244/244 [==============================] - ETA: 0s - loss: 2.4769e-04
# Epoch 14: val_loss did not improve from 0.00059
# 244/244 [==============================] - 6s 23ms/step - loss: 2.4769e-04 - val_loss: 0.0036
# Epoch 15/100
# 243/244 [============================>.] - ETA: 0s - loss: 2.5131e-04
# Epoch 15: val_loss did not improve from 0.00059
# 244/244 [==============================] - 5s 22ms/step - loss: 2.5133e-04 - val_loss: 0.0040
# Epoch 16/100
# 240/244 [============================>.] - ETA: 0s - loss: 2.2710e-04
# Epoch 16: val_loss did not improve from 0.00059
# 244/244 [==============================] - 6s 24ms/step - loss: 2.2754e-04 - val_loss: 0.0034
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:8776.534449141667
# [15392.070237995433, 21493.814406738158, 11596.089260645462, 12449.254758831548, 14123.663847750779, 5755.44803878245, 8776.534449141667]
# Epoch 1/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 1: val_loss improved from inf to 0.00174, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 28s 39ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 2/100
# 274/279 [============================>.] - ETA: 0s - loss: 5.0123e-04
# Epoch 2: val_loss improved from 0.00174 to 0.00110, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 7s 23ms/step - loss: 4.9843e-04 - val_loss: 0.0011
# Epoch 3/100
# 275/279 [============================>.] - ETA: 0s - loss: 3.5480e-04
# Epoch 3: val_loss did not improve from 0.00110
# 279/279 [==============================] - 6s 20ms/step - loss: 3.5344e-04 - val_loss: 0.0019
# Epoch 4/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.9304e-04
# Epoch 4: val_loss did not improve from 0.00110
# 279/279 [==============================] - 6s 21ms/step - loss: 2.9380e-04 - val_loss: 0.0016
# Epoch 5/100
# 276/279 [============================>.] - ETA: 0s - loss: 2.5080e-04
# Epoch 5: val_loss did not improve from 0.00110
# 279/279 [==============================] - 7s 26ms/step - loss: 2.5145e-04 - val_loss: 0.0014
# Epoch 6/100
# 279/279 [==============================] - ETA: 0s - loss: 2.3406e-04
# Epoch 6: val_loss did not improve from 0.00110
# 279/279 [==============================] - 9s 33ms/step - loss: 2.3406e-04 - val_loss: 0.0013
# Epoch 7/100
# 279/279 [==============================] - ETA: 0s - loss: 2.1602e-04
# Epoch 7: val_loss did not improve from 0.00110
# 279/279 [==============================] - 10s 37ms/step - loss: 2.1602e-04 - val_loss: 0.0026
# Epoch 8/100
# 277/279 [============================>.] - ETA: 0s - loss: 2.0567e-04
# Epoch 8: val_loss did not improve from 0.00110
# 279/279 [==============================] - 10s 37ms/step - loss: 2.0666e-04 - val_loss: 0.0041
# Epoch 9/100
# 276/279 [============================>.] - ETA: 0s - loss: 2.1606e-04
# Epoch 9: val_loss did not improve from 0.00110
# 279/279 [==============================] - 10s 35ms/step - loss: 2.1567e-04 - val_loss: 0.0049
# Epoch 10/100
# 276/279 [============================>.] - ETA: 0s - loss: 1.9343e-04
# Epoch 10: val_loss did not improve from 0.00110
# 279/279 [==============================] - 8s 27ms/step - loss: 1.9386e-04 - val_loss: 0.0099
# Epoch 11/100
# 341/341 [==============================] - ETA: 0s - loss: 8.1703e-05
# Epoch 12: val_loss did not improve from 0.00020
# 341/341 [==============================] - 21s 63ms/step - loss: 8.1703e-05 - val_loss: 0.0018
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:53563.81654401919
# [15392.070237995433, 21493.814406738158, 11596.089260645462, 12449.254758831548, 14123.663847750779, 5755.44803878245, 8776.534449141667, 17534.836543023997, 37466.47114222919, 53563.81654401919]

# %%
print(predict)
# Out:
# [array([[186631.4]], dtype=float32), array([[174920.31]], dtype=float32), array([[192525.62]], dtype=float32), array([[197116.03]], dtype=float32), array([[210570.6]], dtype=float32), array([[192533.6]], dtype=float32), array([[189485.95]], dtype=float32), array([[185232.45]], dtype=float32), array([[165869.48]], dtype=float32), array([[136879.28]], dtype=float32)]

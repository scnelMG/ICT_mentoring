# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = False,
                      activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
    

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0198
# Epoch 1: val_loss improved from inf to 0.02807, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 27ms/step - loss: 0.0183 - val_loss: 0.0281
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 2: val_loss improved from 0.02807 to 0.01023, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 3/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0051
# Epoch 3: val_loss did not improve from 0.01023
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0054 - val_loss: 0.0103
# Epoch 4/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0055
# Epoch 4: val_loss improved from 0.01023 to 0.00998, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0100
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0046
# Epoch 5: val_loss did not improve from 0.00998
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0158
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0051
# Epoch 6: val_loss improved from 0.00998 to 0.00581, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 7: val_loss did not improve from 0.00581
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 8/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0039
# Epoch 8: val_loss improved from 0.00581 to 0.00455, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 9/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0043
# Epoch 9: val_loss did not improve from 0.00455
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0042 - val_loss: 0.0203
# Epoch 10/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0038
# Epoch 10: val_loss did not improve from 0.00455
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0038 - val_loss: 0.0123
# Epoch 11/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0039
# Epoch 11: val_loss did not improve from 0.00455
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0112
# Epoch 12/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0032
# Epoch 12: val_loss did not improve from 0.00455
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 13/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0037
# Epoch 13: val_loss improved from 0.00455 to 0.00370, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 14/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 14: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0064
# Epoch 15/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0176
# Epoch 16/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0033
# Epoch 16: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0100
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 17: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0090
# Epoch 18/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0029
# Epoch 18: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0181
# Epoch 19/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0022
# Epoch 19: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 20: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0187
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 21: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0194
# Epoch 22/100
# 29/34 [========================>.....] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0149
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 23: val_loss did not improve from 0.00370
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0213
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:44743.410562798985
# [44743.410562798985]
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.1267
# Epoch 1: val_loss improved from inf to 0.00188, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 14ms/step - loss: 0.1251 - val_loss: 0.0019
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 2: val_loss improved from 0.00188 to 0.00171, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0169 - val_loss: 0.0017
# Epoch 3/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 3: val_loss did not improve from 0.00171
# 69/69 [==============================] - 1s 7ms/step - loss: 0.0116 - val_loss: 0.0020
# Epoch 4/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0119
# Epoch 4: val_loss improved from 0.00171 to 0.00116, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0116 - val_loss: 0.0012
# Epoch 5/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0102
# Epoch 5: val_loss improved from 0.00116 to 0.00064, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0100 - val_loss: 6.4380e-04
# Epoch 6/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 6: val_loss did not improve from 0.00064
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0091 - val_loss: 8.1616e-04
# Epoch 7/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 7: val_loss improved from 0.00064 to 0.00037, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0087 - val_loss: 3.7439e-04
# Epoch 8/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0084
# Epoch 8: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0085 - val_loss: 4.5861e-04
# Epoch 9/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0089
# Epoch 9: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0089 - val_loss: 0.0014
# Epoch 10/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0084
# Epoch 10: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0083 - val_loss: 4.7460e-04
# Epoch 11/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0076
# Epoch 11: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0075 - val_loss: 7.1554e-04
# Epoch 12/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0077
# Epoch 12: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0076 - val_loss: 0.0020
# Epoch 13/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0076
# Epoch 13: val_loss did not improve from 0.00037
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0076 - val_loss: 6.4548e-04
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 14: val_loss improved from 0.00037 to 0.00023, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0066 - val_loss: 2.3318e-04
# Epoch 15/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 15: val_loss did not improve from 0.00023
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0068 - val_loss: 6.8694e-04
# Epoch 16/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 16: val_loss did not improve from 0.00023
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 6.5511e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 17: val_loss improved from 0.00023 to 0.00018, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0059 - val_loss: 1.8475e-04
# Epoch 18/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 18: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 19/100
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0050
# Epoch 19: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 20/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 20: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0051 - val_loss: 4.4237e-04
# Epoch 21/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 21: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0049 - val_loss: 7.5721e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 22: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 23/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0041
# Epoch 23: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0041 - val_loss: 2.4411e-04
# Epoch 24/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 24: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 3.4009e-04
# Epoch 25/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 25: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 26/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 26: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 9.2663e-04
# Epoch 27/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 27: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 7.3910e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:24393.762271370117
# [44743.410562798985, 24393.762271370117]
# Epoch 1/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0506
# Epoch 1: val_loss improved from inf to 0.00071, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 13ms/step - loss: 0.0494 - val_loss: 7.0714e-04
# Epoch 2/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0168
# Epoch 2: val_loss did not improve from 0.00071
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0165 - val_loss: 0.0012
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 3: val_loss improved from 0.00071 to 0.00033, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0143 - val_loss: 3.2905e-04
# Epoch 4/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0121
# Epoch 4: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0122 - val_loss: 5.1284e-04
# Epoch 5/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0111
# Epoch 5: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0111 - val_loss: 0.0013
# Epoch 6/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 6: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0109 - val_loss: 4.1069e-04
# Epoch 7/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 7: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0098 - val_loss: 9.6177e-04
# Epoch 8/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0088
# Epoch 8: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0087 - val_loss: 5.8020e-04
# Epoch 9/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0083
# Epoch 9: val_loss did not improve from 0.00033
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0083 - val_loss: 4.1965e-04
# Epoch 10/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0080
# Epoch 10: val_loss improved from 0.00033 to 0.00025, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0079 - val_loss: 2.4608e-04
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 11: val_loss improved from 0.00025 to 0.00024, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0070 - val_loss: 2.4234e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 12: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0065 - val_loss: 2.9953e-04
# Epoch 13/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 13: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0054 - val_loss: 2.8160e-04
# Epoch 14/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 14: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0052 - val_loss: 3.3999e-04
# Epoch 15/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 15: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 7.5016e-04
# Epoch 16/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 16: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 3.1715e-04
# Epoch 17/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 17: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 2.5278e-04
# Epoch 18/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 18: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 3.5643e-04
# Epoch 19/100
#  95/104 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 19: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 4.0366e-04
# Epoch 20/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 20: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 3.3987e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 21: val_loss did not improve from 0.00024
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 3.3126e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:13828.940182574846
# [44743.410562798985, 24393.762271370117, 13828.940182574846]
# Epoch 1/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0403
# Epoch 1: val_loss improved from inf to 0.00340, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 3s 12ms/step - loss: 0.0403 - val_loss: 0.0034
# Epoch 2/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 2: val_loss improved from 0.00340 to 0.00117, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0130 - val_loss: 0.0012
# Epoch 3/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0105
# Epoch 3: val_loss improved from 0.00117 to 0.00043, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0103 - val_loss: 4.2713e-04
# Epoch 4/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 4: val_loss did not improve from 0.00043
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0089 - val_loss: 9.3735e-04
# Epoch 5/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 5: val_loss improved from 0.00043 to 0.00040, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 0.0079 - val_loss: 4.0245e-04
# Epoch 6/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0075
# Epoch 6: val_loss did not improve from 0.00040
# 139/139 [==============================] - 1s 11ms/step - loss: 0.0075 - val_loss: 8.8719e-04
# Epoch 7/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 7: val_loss did not improve from 0.00040
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 8.4483e-04
# Epoch 8/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 8: val_loss improved from 0.00040 to 0.00033, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0055 - val_loss: 3.2958e-04
# Epoch 9/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 9: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 3.8947e-04
# Epoch 10/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 10: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 11/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 11: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 12/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 12: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 5.8499e-04
# Epoch 13/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 13: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0042 - val_loss: 7.0717e-04
# Epoch 14/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 14: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 5.6166e-04
# Epoch 15/100
# 132/139 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss did not improve from 0.00033
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 5.8507e-04
# Epoch 16/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 16: val_loss improved from 0.00033 to 0.00031, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 3.1389e-04
# Epoch 17/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 17: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 5.4628e-04
# Epoch 18/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 18: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 4.4557e-04
# Epoch 19/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 19: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 3.1970e-04
# Epoch 20/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 6.7140e-04
# Epoch 21/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 21: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0029 - val_loss: 6.3932e-04
# Epoch 22/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 22: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0028 - val_loss: 5.5090e-04
# Epoch 23/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 23: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 6.7716e-04
# Epoch 24/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 24: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 4.7236e-04
# Epoch 25/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 25: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 26/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 26: val_loss did not improve from 0.00031
# 139/139 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 5.6654e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:10022.56130146786
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786]
# Epoch 1/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0131
# Epoch 1: val_loss improved from inf to 0.00188, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 3s 11ms/step - loss: 0.0129 - val_loss: 0.0019
# Epoch 2/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 2: val_loss did not improve from 0.00188
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0055 - val_loss: 0.0095
# Epoch 3/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 3: val_loss improved from 0.00188 to 0.00043, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 4.3334e-04
# Epoch 4/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 4: val_loss did not improve from 0.00043
# 174/174 [==============================] - 1s 9ms/step - loss: 0.0042 - val_loss: 4.3840e-04
# Epoch 5/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 5: val_loss improved from 0.00043 to 0.00037, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0032 - val_loss: 3.6658e-04
# Epoch 6/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 6: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0032 - val_loss: 5.0350e-04
# Epoch 7/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 7: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 8/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 8: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 10ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 9/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 9: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 10/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 10: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0025 - val_loss: 4.4241e-04
# Epoch 11/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 11: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 13ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 12/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 12: val_loss did not improve from 0.00037
# 174/174 [==============================] - 3s 15ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 13/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 13: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 8.4670e-04
# Epoch 14/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 14: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0021 - val_loss: 5.3635e-04
# Epoch 15/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 15: val_loss did not improve from 0.00037
# 174/174 [==============================] - 2s 12ms/step - loss: 0.0021 - val_loss: 8.5087e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:9164.526502340537
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537]
# Epoch 1/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 1: val_loss improved from inf to 0.00084, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 5s 10ms/step - loss: 0.0061 - val_loss: 8.3683e-04
# Epoch 2/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 2: val_loss did not improve from 0.00084
# 209/209 [==============================] - 2s 7ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 3/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 3: val_loss did not improve from 0.00084
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0020 - val_loss: 9.8186e-04
# Epoch 4/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 4: val_loss did not improve from 0.00084
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 5/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 5: val_loss improved from 0.00084 to 0.00076, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0017 - val_loss: 7.5526e-04
# Epoch 6/100
# 203/209 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 6: val_loss improved from 0.00076 to 0.00047, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0017 - val_loss: 4.7203e-04
# Epoch 7/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 7: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 8/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 8: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0016 - val_loss: 6.1183e-04
# Epoch 9/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 9: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0014 - val_loss: 5.1131e-04
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 10: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0015 - val_loss: 5.0090e-04
# Epoch 11/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0013 - val_loss: 7.1219e-04
# Epoch 12/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00047
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0013 - val_loss: 6.0605e-04
# Epoch 13/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 13: val_loss improved from 0.00047 to 0.00041, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 4.0982e-04
# Epoch 14/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 14: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 10ms/step - loss: 0.0014 - val_loss: 6.4918e-04
# Epoch 15/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 15: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 16/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0014 - val_loss: 8.0872e-04
# Epoch 17/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 17: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 12ms/step - loss: 0.0013 - val_loss: 4.8187e-04
# Epoch 18/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00041
# 209/209 [==============================] - 3s 12ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 19/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 19: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0013 - val_loss: 4.7948e-04
# Epoch 20/100
# 208/209 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 20: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 21/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 21: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 9.0514e-04
# Epoch 22/100
# 202/209 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 22: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 23/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 23: val_loss did not improve from 0.00041
# 209/209 [==============================] - 2s 11ms/step - loss: 0.0013 - val_loss: 5.1645e-04
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:7620.0806018806
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537, 7620.0806018806]
# Epoch 1/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 1: val_loss improved from inf to 0.01483, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 5s 12ms/step - loss: 0.0187 - val_loss: 0.0148
# Epoch 2/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 2: val_loss improved from 0.01483 to 0.00132, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 9ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 3/100
# 238/244 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 3: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 7ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 4/100
# 238/244 [============================>.] - ETA: 0s - loss: 8.6281e-04
# Epoch 4: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 8ms/step - loss: 8.6012e-04 - val_loss: 0.0029
# Epoch 5/100
# 240/244 [============================>.] - ETA: 0s - loss: 7.6328e-04
# Epoch 5: val_loss did not improve from 0.00132
# 244/244 [==============================] - 3s 10ms/step - loss: 7.5987e-04 - val_loss: 0.0025
# Epoch 6/100
# 242/244 [============================>.] - ETA: 0s - loss: 6.8248e-04
# Epoch 6: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 10ms/step - loss: 6.8082e-04 - val_loss: 0.0026
# Epoch 7/100
# 242/244 [============================>.] - ETA: 0s - loss: 6.0039e-04
# Epoch 7: val_loss did not improve from 0.00132
# 244/244 [==============================] - 3s 11ms/step - loss: 5.9849e-04 - val_loss: 0.0014
# Epoch 8/100
# 242/244 [============================>.] - ETA: 0s - loss: 5.7056e-04
# Epoch 8: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 10ms/step - loss: 5.6974e-04 - val_loss: 0.0060
# Epoch 9/100
# 243/244 [============================>.] - ETA: 0s - loss: 5.3770e-04
# Epoch 9: val_loss did not improve from 0.00132
# 244/244 [==============================] - 3s 11ms/step - loss: 5.3644e-04 - val_loss: 0.0033
# Epoch 10/100
# 243/244 [============================>.] - ETA: 0s - loss: 4.9941e-04
# Epoch 10: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 10ms/step - loss: 4.9832e-04 - val_loss: 0.0084
# Epoch 11/100
# 244/244 [==============================] - ETA: 0s - loss: 5.3134e-04
# Epoch 11: val_loss did not improve from 0.00132
# 244/244 [==============================] - 3s 11ms/step - loss: 5.3134e-04 - val_loss: 0.0090
# Epoch 12/100
# 244/244 [==============================] - ETA: 0s - loss: 4.6841e-04
# Epoch 12: val_loss did not improve from 0.00132
# 244/244 [==============================] - 2s 10ms/step - loss: 4.6841e-04 - val_loss: 0.0092
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:14951.913753863544
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537, 7620.0806018806, 14951.913753863544]
# Epoch 1/100
# 275/279 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 1: val_loss improved from inf to 0.00300, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 6s 12ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 2/100
# 276/279 [============================>.] - ETA: 0s - loss: 9.2490e-04
# Epoch 2: val_loss did not improve from 0.00300
# 279/279 [==============================] - 3s 12ms/step - loss: 9.2119e-04 - val_loss: 0.0052
# Epoch 3/100
# 276/279 [============================>.] - ETA: 0s - loss: 6.6153e-04
# Epoch 3: val_loss improved from 0.00300 to 0.00148, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 12ms/step - loss: 6.5846e-04 - val_loss: 0.0015
# Epoch 4/100
# 278/279 [============================>.] - ETA: 0s - loss: 5.7670e-04
# Epoch 4: val_loss improved from 0.00148 to 0.00133, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 10ms/step - loss: 5.7642e-04 - val_loss: 0.0013
# Epoch 5/100
# 277/279 [============================>.] - ETA: 0s - loss: 4.9309e-04
# Epoch 5: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 11ms/step - loss: 4.9236e-04 - val_loss: 0.0030
# Epoch 6/100
# 273/279 [============================>.] - ETA: 0s - loss: 4.2004e-04
# Epoch 6: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 4.2226e-04 - val_loss: 0.0044
# Epoch 7/100
# 277/279 [============================>.] - ETA: 0s - loss: 4.2375e-04
# Epoch 7: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 4.2373e-04 - val_loss: 0.0045
# Epoch 8/100
# 278/279 [============================>.] - ETA: 0s - loss: 4.1986e-04
# Epoch 8: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 4.1963e-04 - val_loss: 0.0077
# Epoch 9/100
# 279/279 [==============================] - ETA: 0s - loss: 3.6432e-04
# Epoch 9: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 3.6432e-04 - val_loss: 0.0049
# Epoch 10/100
# 273/279 [============================>.] - ETA: 0s - loss: 4.0327e-04
# Epoch 10: val_loss did not improve from 0.00133
# 279/279 [==============================] - 2s 8ms/step - loss: 4.0259e-04 - val_loss: 0.0100
# Epoch 11/100
# 274/279 [============================>.] - ETA: 0s - loss: 3.5975e-04
# Epoch 11: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 3.5985e-04 - val_loss: 0.0088
# Epoch 12/100
# 276/279 [============================>.] - ETA: 0s - loss: 3.5465e-04
# Epoch 12: val_loss did not improve from 0.00133
# 279/279 [==============================] - 2s 8ms/step - loss: 3.5339e-04 - val_loss: 0.0082
# Epoch 13/100
# 277/279 [============================>.] - ETA: 0s - loss: 3.3093e-04
# Epoch 13: val_loss did not improve from 0.00133
# 279/279 [==============================] - 3s 10ms/step - loss: 3.3079e-04 - val_loss: 0.0115
# Epoch 14/100
# 274/279 [============================>.] - ETA: 0s - loss: 3.0908e-04
# Epoch 14: val_loss did not improve from 0.00133
# 279/279 [==============================] - 2s 8ms/step - loss: 3.0865e-04 - val_loss: 0.0112
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:28013.56672511367
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537, 7620.0806018806, 14951.913753863544, 28013.56672511367]
# Epoch 1/100
# 310/314 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 1: val_loss improved from inf to 0.00281, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 6s 12ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 2/100
# 311/314 [============================>.] - ETA: 0s - loss: 3.5158e-04
# Epoch 2: val_loss improved from 0.00281 to 0.00135, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 3s 10ms/step - loss: 3.5056e-04 - val_loss: 0.0013
# Epoch 3/100
# 313/314 [============================>.] - ETA: 0s - loss: 2.7815e-04
# Epoch 3: val_loss did not improve from 0.00135
# 314/314 [==============================] - 3s 10ms/step - loss: 2.7776e-04 - val_loss: 0.0015
# Epoch 4/100
# 312/314 [============================>.] - ETA: 0s - loss: 2.2863e-04
# Epoch 4: val_loss did not improve from 0.00135
# 314/314 [==============================] - 3s 10ms/step - loss: 2.2964e-04 - val_loss: 0.0016
# Epoch 5/100
# 310/314 [============================>.] - ETA: 0s - loss: 2.4566e-04
# Epoch 5: val_loss did not improve from 0.00135
# 314/314 [==============================] - 3s 10ms/step - loss: 2.4514e-04 - val_loss: 0.0026
# Epoch 6/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.3218e-04
# Epoch 6: val_loss improved from 0.00135 to 0.00082, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 3s 10ms/step - loss: 2.3039e-04 - val_loss: 8.1719e-04
# Epoch 7/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.0052e-04
# Epoch 7: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 9ms/step - loss: 2.0004e-04 - val_loss: 0.0015
# Epoch 8/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.9943e-04
# Epoch 8: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 9ms/step - loss: 1.9889e-04 - val_loss: 9.5851e-04
# Epoch 9/100
# 307/314 [============================>.] - ETA: 0s - loss: 1.8724e-04
# Epoch 9: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 9ms/step - loss: 1.8499e-04 - val_loss: 0.0013
# Epoch 10/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.1128e-04
# Epoch 10: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 8ms/step - loss: 2.1004e-04 - val_loss: 0.0018
# Epoch 11/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.1013e-04
# Epoch 11: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 10ms/step - loss: 2.0923e-04 - val_loss: 0.0031
# Epoch 12/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.2255e-04
# Epoch 12: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 8ms/step - loss: 2.2099e-04 - val_loss: 0.0030
# Epoch 13/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.0782e-04
# Epoch 13: val_loss did not improve from 0.00082
# 314/314 [==============================] - 3s 9ms/step - loss: 2.0635e-04 - val_loss: 0.0029
# Epoch 14/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.8423e-04
# Epoch 14: val_loss improved from 0.00082 to 0.00046, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 3s 9ms/step - loss: 1.8566e-04 - val_loss: 4.6462e-04
# Epoch 15/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.0109e-04
# Epoch 15: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 2.0052e-04 - val_loss: 0.0015
# Epoch 16/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.9126e-04
# Epoch 16: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 8ms/step - loss: 1.9062e-04 - val_loss: 9.8901e-04
# Epoch 17/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.7911e-04
# Epoch 17: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 8ms/step - loss: 1.7889e-04 - val_loss: 0.0024
# Epoch 18/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.8514e-04
# Epoch 18: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.8526e-04 - val_loss: 9.3990e-04
# Epoch 19/100
# 309/314 [============================>.] - ETA: 0s - loss: 1.9465e-04
# Epoch 19: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.9363e-04 - val_loss: 0.0013
# Epoch 20/100
# 310/314 [============================>.] - ETA: 0s - loss: 1.6458e-04
# Epoch 20: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.6461e-04 - val_loss: 7.6675e-04
# Epoch 21/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.8120e-04
# Epoch 21: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.8080e-04 - val_loss: 0.0014
# Epoch 22/100
# 311/314 [============================>.] - ETA: 0s - loss: 1.7393e-04
# Epoch 22: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.7532e-04 - val_loss: 0.0013
# Epoch 23/100
# 309/314 [============================>.] - ETA: 0s - loss: 1.8011e-04
# Epoch 23: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 9ms/step - loss: 1.7901e-04 - val_loss: 9.6410e-04
# Epoch 24/100
# 309/314 [============================>.] - ETA: 0s - loss: 1.9039e-04
# Epoch 24: val_loss did not improve from 0.00046
# 314/314 [==============================] - 3s 10ms/step - loss: 1.9170e-04 - val_loss: 7.9954e-04
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:15982.156782287351
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537, 7620.0806018806, 14951.913753863544, 28013.56672511367, 15982.156782287351]
# Epoch 1/100
# 339/341 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 1: val_loss improved from inf to 0.00179, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 6s 11ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 2/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.9495e-04
# Epoch 2: val_loss improved from 0.00179 to 0.00046, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 2.9368e-04 - val_loss: 4.6378e-04
# Epoch 3/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.8633e-04
# Epoch 3: val_loss improved from 0.00046 to 0.00025, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 13ms/step - loss: 1.8634e-04 - val_loss: 2.4850e-04
# Epoch 4/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.5843e-04
# Epoch 4: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 12ms/step - loss: 1.5793e-04 - val_loss: 2.8608e-04
# Epoch 5/100
# 336/341 [============================>.] - ETA: 0s - loss: 1.3206e-04
# Epoch 5: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 12ms/step - loss: 1.3229e-04 - val_loss: 3.2885e-04
# Epoch 6/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.2137e-04
# Epoch 6: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 11ms/step - loss: 1.2081e-04 - val_loss: 3.0844e-04
# Epoch 7/100
# 341/341 [==============================] - ETA: 0s - loss: 1.0421e-04
# Epoch 7: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 12ms/step - loss: 1.0421e-04 - val_loss: 9.0416e-04
# Epoch 8/100
# 338/341 [============================>.] - ETA: 0s - loss: 1.0392e-04
# Epoch 8: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 11ms/step - loss: 1.0499e-04 - val_loss: 6.1436e-04
# Epoch 9/100
# 338/341 [============================>.] - ETA: 0s - loss: 1.0228e-04
# Epoch 9: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 11ms/step - loss: 1.0228e-04 - val_loss: 0.0012
# Epoch 10/100
# 341/341 [==============================] - ETA: 0s - loss: 9.2818e-05
# Epoch 10: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 13ms/step - loss: 9.2818e-05 - val_loss: 0.0011
# Epoch 11/100
# 339/341 [============================>.] - ETA: 0s - loss: 8.3523e-05
# Epoch 11: val_loss did not improve from 0.00025
# 341/341 [==============================] - 5s 14ms/step - loss: 8.3546e-05 - val_loss: 0.0020
# Epoch 12/100
# 338/341 [============================>.] - ETA: 0s - loss: 9.0449e-05
# Epoch 12: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 13ms/step - loss: 9.0322e-05 - val_loss: 0.0020
# Epoch 13/100
# 339/341 [============================>.] - ETA: 0s - loss: 8.4481e-05
# Epoch 13: val_loss did not improve from 0.00025
# 341/341 [==============================] - 4s 12ms/step - loss: 8.4366e-05 - val_loss: 0.0015
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:106597.51137506714
# [44743.410562798985, 24393.762271370117, 13828.940182574846, 10022.56130146786, 9164.526502340537, 7620.0806018806, 14951.913753863544, 28013.56672511367, 15982.156782287351, 106597.51137506714]

# %%
print(predict)
# Out:
# [array([[151519.9]], dtype=float32), array([[177179.67]], dtype=float32), array([[188414.36]], dtype=float32), array([[198682.3]], dtype=float32), array([[197687.66]], dtype=float32), array([[196524.6]], dtype=float32), array([[178750.28]], dtype=float32), array([[155572.39]], dtype=float32), array([[165367.]], dtype=float32), array([[96457.81]], dtype=float32)]

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("./[경기관련소비재]현대차.csv")

df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(64, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(64, return_sequences=False, stateful=False))
        model.add(Dropout(0.3))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: ta in c:\users\gram\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.3.4)
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from ta) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gram\anaconda3\lib\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ta) (1.16.0)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\gram\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0362
# Epoch 1: val_loss improved from inf to 0.04465, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 72s 523ms/step - loss: 0.0346 - val_loss: 0.0447
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 2: val_loss improved from 0.04465 to 0.01404, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0073 - val_loss: 0.0140
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 3: val_loss did not improve from 0.01404
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0048 - val_loss: 0.0227
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 4: val_loss did not improve from 0.01404
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0037 - val_loss: 0.0142
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 5: val_loss improved from 0.01404 to 0.00542, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 99ms/step - loss: 0.0035 - val_loss: 0.0054
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 6: val_loss did not improve from 0.00542
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0033 - val_loss: 0.0118
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 7: val_loss did not improve from 0.00542
# 34/34 [==============================] - 2s 68ms/step - loss: 0.0025 - val_loss: 0.0148
# Epoch 8/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 8: val_loss did not improve from 0.00542
# 34/34 [==============================] - 3s 72ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 9/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 9: val_loss did not improve from 0.00542
# 34/34 [==============================] - 3s 103ms/step - loss: 0.0027 - val_loss: 0.0083
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 10: val_loss did not improve from 0.00542
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0023 - val_loss: 0.0065
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 11: val_loss did not improve from 0.00542
# 34/34 [==============================] - 3s 98ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 12: val_loss did not improve from 0.00542
# 34/34 [==============================] - 3s 89ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 13: val_loss improved from 0.00542 to 0.00353, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 101ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 14/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 14: val_loss did not improve from 0.00353
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0023 - val_loss: 0.0070
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 15: val_loss did not improve from 0.00353
# 34/34 [==============================] - 3s 91ms/step - loss: 0.0018 - val_loss: 0.0077
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 16: val_loss did not improve from 0.00353
# 34/34 [==============================] - 4s 103ms/step - loss: 0.0019 - val_loss: 0.0065
# Epoch 17/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 17: val_loss did not improve from 0.00353
# 34/34 [==============================] - 2s 66ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 18: val_loss did not improve from 0.00353
# 34/34 [==============================] - 3s 86ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 19: val_loss did not improve from 0.00353
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0019 - val_loss: 0.0046
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.00353
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0019 - val_loss: 0.0070
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 21: val_loss did not improve from 0.00353
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00353
# 34/34 [==============================] - 3s 92ms/step - loss: 0.0023 - val_loss: 0.0105
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 23: val_loss did not improve from 0.00353
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0019 - val_loss: 0.0101
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:31958.877058524344
# [31958.877058524344]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0279
# Epoch 1: val_loss improved from inf to 0.00076, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 74s 320ms/step - loss: 0.0274 - val_loss: 7.6272e-04
# Epoch 2/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 2: val_loss improved from 0.00076 to 0.00036, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 5s 71ms/step - loss: 0.0049 - val_loss: 3.6122e-04
# Epoch 3/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 3: val_loss improved from 0.00036 to 0.00021, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0040 - val_loss: 2.0528e-04
# Epoch 4/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 4: val_loss did not improve from 0.00021
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0035 - val_loss: 2.9043e-04
# Epoch 5/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 5: val_loss did not improve from 0.00021
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0035 - val_loss: 4.8562e-04
# Epoch 6/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 6: val_loss did not improve from 0.00021
# 69/69 [==============================] - 3s 47ms/step - loss: 0.0031 - val_loss: 2.0858e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 7: val_loss did not improve from 0.00021
# 69/69 [==============================] - 6s 84ms/step - loss: 0.0030 - val_loss: 2.7212e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 8: val_loss did not improve from 0.00021
# 69/69 [==============================] - 5s 78ms/step - loss: 0.0031 - val_loss: 2.8933e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 9: val_loss did not improve from 0.00021
# 69/69 [==============================] - 4s 61ms/step - loss: 0.0029 - val_loss: 7.9125e-04
# Epoch 10/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 10: val_loss did not improve from 0.00021
# 69/69 [==============================] - 4s 59ms/step - loss: 0.0026 - val_loss: 2.6157e-04
# Epoch 11/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 11: val_loss did not improve from 0.00021
# 69/69 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 2.6684e-04
# Epoch 12/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 12: val_loss did not improve from 0.00021
# 69/69 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 8.4070e-04
# Epoch 13/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 13: val_loss did not improve from 0.00021
# 69/69 [==============================] - 3s 42ms/step - loss: 0.0024 - val_loss: 9.7241e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:12311.33244041687
# [31958.877058524344, 12311.33244041687]
# Epoch 1/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 1: val_loss improved from inf to 0.00100, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 53s 156ms/step - loss: 0.0227 - val_loss: 0.0010
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 2: val_loss improved from 0.00100 to 0.00066, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 51ms/step - loss: 0.0068 - val_loss: 6.5902e-04
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 3: val_loss did not improve from 0.00066
# 104/104 [==============================] - 4s 40ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 4: val_loss did not improve from 0.00066
# 104/104 [==============================] - 4s 42ms/step - loss: 0.0050 - val_loss: 8.4270e-04
# Epoch 5/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 5: val_loss improved from 0.00066 to 0.00033, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 48ms/step - loss: 0.0048 - val_loss: 3.2749e-04
# Epoch 6/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 6: val_loss did not improve from 0.00033
# 104/104 [==============================] - 6s 57ms/step - loss: 0.0044 - val_loss: 4.5190e-04
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 7: val_loss improved from 0.00033 to 0.00026, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 6s 59ms/step - loss: 0.0044 - val_loss: 2.6224e-04
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 8: val_loss improved from 0.00026 to 0.00022, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0043 - val_loss: 2.1799e-04
# Epoch 9/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 9: val_loss did not improve from 0.00022
# 104/104 [==============================] - 7s 67ms/step - loss: 0.0038 - val_loss: 5.1873e-04
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 10: val_loss did not improve from 0.00022
# 104/104 [==============================] - 8s 72ms/step - loss: 0.0038 - val_loss: 3.5797e-04
# Epoch 11/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 11: val_loss did not improve from 0.00022
# 104/104 [==============================] - 7s 65ms/step - loss: 0.0039 - val_loss: 2.3277e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss did not improve from 0.00022
# 104/104 [==============================] - 5s 45ms/step - loss: 0.0037 - val_loss: 2.6428e-04
# Epoch 13/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 13: val_loss improved from 0.00022 to 0.00020, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 5s 49ms/step - loss: 0.0034 - val_loss: 1.9597e-04
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 14: val_loss did not improve from 0.00020
# 104/104 [==============================] - 5s 46ms/step - loss: 0.0029 - val_loss: 5.8143e-04
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 15: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 43ms/step - loss: 0.0028 - val_loss: 2.9526e-04
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 16: val_loss did not improve from 0.00020
# 104/104 [==============================] - 5s 44ms/step - loss: 0.0029 - val_loss: 2.3690e-04
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 17: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0027 - val_loss: 2.0619e-04
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 18: val_loss did not improve from 0.00020
# 104/104 [==============================] - 4s 41ms/step - loss: 0.0026 - val_loss: 5.8545e-04
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 19: val_loss did not improve from 0.00020
# 104/104 [==============================] - 5s 47ms/step - loss: 0.0028 - val_loss: 3.2804e-04
# Epoch 20/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 20: val_loss did not improve from 0.00020
# 104/104 [==============================] - 5s 46ms/step - loss: 0.0024 - val_loss: 3.0758e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 21: val_loss did not improve from 0.00020
# 104/104 [==============================] - 5s 51ms/step - loss: 0.0023 - val_loss: 2.0215e-04
# Epoch 22/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 22: val_loss did not improve from 0.00020
# 104/104 [==============================] - 6s 59ms/step - loss: 0.0022 - val_loss: 5.2998e-04
# Epoch 23/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 23: val_loss did not improve from 0.00020
# 104/104 [==============================] - 7s 64ms/step - loss: 0.0022 - val_loss: 6.0952e-04
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:18653.74840875568
# [31958.877058524344, 12311.33244041687, 18653.74840875568]
# Epoch 1/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 1: val_loss improved from inf to 0.00029, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 92s 155ms/step - loss: 0.0175 - val_loss: 2.8642e-04
# Epoch 2/100
# 137/139 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 2: val_loss did not improve from 0.00029
# 139/139 [==============================] - 7s 54ms/step - loss: 0.0049 - val_loss: 0.0010
# Epoch 3/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 3: val_loss did not improve from 0.00029
# 139/139 [==============================] - 7s 54ms/step - loss: 0.0035 - val_loss: 3.7257e-04
# Epoch 4/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 4: val_loss did not improve from 0.00029
# 139/139 [==============================] - 8s 58ms/step - loss: 0.0038 - val_loss: 6.8120e-04
# Epoch 5/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 5: val_loss did not improve from 0.00029
# 139/139 [==============================] - 8s 57ms/step - loss: 0.0036 - val_loss: 5.7475e-04
# Epoch 6/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 6: val_loss did not improve from 0.00029
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 7/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 7: val_loss did not improve from 0.00029
# 139/139 [==============================] - 10s 69ms/step - loss: 0.0034 - val_loss: 2.9522e-04
# Epoch 8/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 8: val_loss improved from 0.00029 to 0.00021, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 8s 60ms/step - loss: 0.0028 - val_loss: 2.0626e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 9.1744e-04
# Epoch 40: val_loss did not improve from 0.00013
# 139/139 [==============================] - 10s 75ms/step - loss: 9.1875e-04 - val_loss: 4.2527e-04
# Epoch 41/100
# 137/139 [============================>.] - ETA: 0s - loss: 9.2855e-04
# Epoch 41: val_loss did not improve from 0.00013
# 139/139 [==============================] - 10s 74ms/step - loss: 9.2603e-04 - val_loss: 1.3659e-04
# Epoch 42/100
# 138/139 [============================>.] - ETA: 0s - loss: 8.7146e-04
# Epoch 42: val_loss did not improve from 0.00013
# 139/139 [==============================] - 8s 55ms/step - loss: 8.7533e-04 - val_loss: 1.4100e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:6635.654976125128
# [31958.877058524344, 12311.33244041687, 18653.74840875568, 6635.654976125128]
# Epoch 1/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 1: val_loss improved from inf to 0.00123, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 78s 150ms/step - loss: 0.0142 - val_loss: 0.0012
# Epoch 2/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 2: val_loss improved from 0.00123 to 0.00093, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 11s 61ms/step - loss: 0.0030 - val_loss: 9.2708e-04
# Epoch 3/100
# 174/174 [==============================] - ETA: 0s - loss: 9.1836e-04
# Epoch 27: val_loss did not improve from 0.00034
# 174/174 [==============================] - 12s 71ms/step - loss: 9.1836e-04 - val_loss: 3.4673e-04
# Epoch 28/100
# 174/174 [==============================] - ETA: 0s - loss: 8.0759e-04
# Epoch 28: val_loss did not improve from 0.00034
# 174/174 [==============================] - 13s 74ms/step - loss: 8.0759e-04 - val_loss: 4.5369e-04
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:7250.114546327217
# [31958.877058524344, 12311.33244041687, 18653.74840875568, 6635.654976125128, 7250.114546327217]
# Epoch 1/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 1: val_loss improved from inf to 0.00111, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 75s 97ms/step - loss: 0.0104 - val_loss: 0.0011
# Epoch 2/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 2: val_loss did not improve from 0.00111
# 209/209 [==============================] - 11s 52ms/step - loss: 0.0018 - val_loss: 0.0078
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss did not improve from 0.00111
# 209/209 [==============================] - 14s 68ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 4/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 4: val_loss did not improve from 0.00111
# 209/209 [==============================] - 11s 54ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 5/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 5: val_loss improved from 0.00111 to 0.00046, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 8s 41ms/step - loss: 0.0012 - val_loss: 4.6272e-04
# Epoch 6/100
# 209/209 [==============================] - ETA: 0s - loss: 9.8195e-04
# Epoch 6: val_loss did not improve from 0.00046
# 209/209 [==============================] - 9s 42ms/step - loss: 9.8195e-04 - val_loss: 0.0046
# Epoch 7/100
# 209/209 [==============================] - ETA: 0s - loss: 8.7678e-04
# Epoch 7: val_loss did not improve from 0.00046
# 209/209 [==============================] - 9s 43ms/step - loss: 8.7678e-04 - val_loss: 0.0015
# Epoch 8/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 1: val_loss improved from inf to 0.00198, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 70s 68ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 2/100
# 243/244 [============================>.] - ETA: 0s - loss: 6.0067e-04
# Epoch 2: val_loss improved from 0.00198 to 0.00139, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 9s 38ms/step - loss: 6.0235e-04 - val_loss: 0.0014
# Epoch 3/100
# 244/244 [==============================] - ETA: 0s - loss: 4.3490e-04
# Epoch 3: val_loss improved from 0.00139 to 0.00123, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 11s 44ms/step - loss: 4.3490e-04 - val_loss: 0.0012
# Epoch 4/100
# 244/244 [==============================] - ETA: 0s - loss: 3.5839e-04
# Epoch 4: val_loss did not improve from 0.00123
# 244/244 [==============================] - 16s 67ms/step - loss: 3.5839e-04 - val_loss: 0.0014
# Epoch 5/100
# 242/244 [============================>.] - ETA: 0s - loss: 1.2073e-04
# Epoch 26: val_loss did not improve from 0.00045
# 244/244 [==============================] - 8s 34ms/step - loss: 1.2036e-04 - val_loss: 4.6981e-04
# Epoch 27/100
# 243/244 [============================>.] - ETA: 0s - loss: 1.2120e-04
# Epoch 27: val_loss did not improve from 0.00045
# 244/244 [==============================] - 10s 43ms/step - loss: 1.2159e-04 - val_loss: 0.0010
# Epoch 28/100
# 244/244 [==============================] - ETA: 0s - loss: 1.1879e-04
# Epoch 28: val_loss did not improve from 0.00045
# 244/244 [==============================] - 8s 33ms/step - loss: 1.1879e-04 - val_loss: 7.6440e-04
# Epoch 29/100
# 242/244 [============================>.] - ETA: 0s - loss: 1.2479e-04
# Epoch 29: val_loss did not improve from 0.00045
# 244/244 [==============================] - 6s 24ms/step - loss: 1.2437e-04 - val_loss: 0.0011
# Epoch 30/100
# 244/244 [==============================] - ETA: 0s - loss: 1.1974e-04
# Epoch 30: val_loss did not improve from 0.00045
# 244/244 [==============================] - 6s 25ms/step - loss: 1.1974e-04 - val_loss: 6.9191e-04
# Epoch 31/100
# 145/244 [================>.............] - ETA: 2s - loss: 1.3333e-047000길이의 데이터 적용 완료
#  길이: 7000, RMSE:9632.331341247693
# [31958.877058524344, 12311.33244041687, 18653.74840875568, 6635.654976125128, 7250.114546327217, 4129.8349118676715, 9632.331341247693]
# Epoch 1/100
# 279/279 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 1: val_loss improved from inf to 0.01564, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 52s 77ms/step - loss: 0.0028 - val_loss: 0.0156
# Epoch 2/100
# 279/279 [==============================] - ETA: 0s - loss: 5.1442e-04
# Epoch 2: val_loss improved from 0.01564 to 0.00728, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 12s 44ms/step - loss: 5.1442e-04 - val_loss: 0.0073
# Epoch 3/100
# 279/279 [==============================] - ETA: 0s - loss: 3.5154e-04
# Epoch 3: val_loss improved from 0.00728 to 0.00659, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 11s 38ms/step - loss: 3.5154e-04 - val_loss: 0.0066
# Epoch 4/100
# 279/279 [==============================] - ETA: 0s - loss: 2.9171e-04
# Epoch 4: val_loss did not improve from 0.00659
# 279/279 [==============================] - 8s 30ms/step - loss: 2.9171e-04 - val_loss: 0.0069
# Epoch 5/100
# 279/279 [==============================] - ETA: 0s - loss: 2.2621e-04
# Epoch 5: val_loss did not improve from 0.00659
# 279/279 [==============================] - 7s 26ms/step - loss: 2.2621e-04 - val_loss: 0.0077
# Epoch 6/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.9346e-04
# Epoch 6: val_loss improved from 0.00659 to 0.00346, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 8s 27ms/step - loss: 1.9375e-04 - val_loss: 0.0035
# Epoch 7/100
# 277/279 [============================>.] - ETA: 0s - loss: 1.6413e-04
# Epoch 7: val_loss did not improve from 0.00346
# 279/279 [==============================] - 8s 28ms/step - loss: 1.6669e-04 - val_loss: 0.0060
# Epoch 8/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.4992e-04
# Epoch 8: val_loss improved from 0.00346 to 0.00212, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 8s 29ms/step - loss: 1.5057e-04 - val_loss: 0.0021
# Epoch 9/100
# 279/279 [==============================] - ETA: 0s - loss: 1.4005e-04
# Epoch 9: val_loss improved from 0.00212 to 0.00202, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 8s 30ms/step - loss: 1.4005e-04 - val_loss: 0.0020
# Epoch 10/100
# 279/279 [==============================] - ETA: 0s - loss: 1.4424e-04
# Epoch 10: val_loss improved from 0.00202 to 0.00180, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 10s 37ms/step - loss: 1.4424e-04 - val_loss: 0.0018
# Epoch 11/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.2987e-04
# Epoch 11: val_loss improved from 0.00180 to 0.00122, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 13s 46ms/step - loss: 1.2973e-04 - val_loss: 0.0012
# Epoch 12/100
# 279/279 [==============================] - ETA: 0s - loss: 1.0920e-04
# Epoch 12: val_loss did not improve from 0.00122
# 279/279 [==============================] - 11s 40ms/step - loss: 1.0920e-04 - val_loss: 0.0018
# Epoch 13/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.0695e-04
# Epoch 13: val_loss did not improve from 0.00122
# 279/279 [==============================] - 8s 28ms/step - loss: 1.0669e-04 - val_loss: 0.0018
# Epoch 14/100
# 279/279 [==============================] - ETA: 0s - loss: 1.1136e-04
# Epoch 14: val_loss improved from 0.00122 to 0.00121, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 8s 28ms/step - loss: 1.1136e-04 - val_loss: 0.0012
# Epoch 15/100
# 279/279 [==============================] - ETA: 0s - loss: 9.7945e-05
# Epoch 15: val_loss did not improve from 0.00121
# 279/279 [==============================] - 8s 28ms/step - loss: 9.7945e-05 - val_loss: 0.0013
# Epoch 16/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.0293e-04
# Epoch 16: val_loss did not improve from 0.00121
# 279/279 [==============================] - 10s 37ms/step - loss: 1.0308e-04 - val_loss: 0.0020
# Epoch 17/100
# 278/279 [============================>.] - ETA: 0s - loss: 1.0881e-04
# Epoch 17: val_loss improved from 0.00121 to 0.00094, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 9s 31ms/step - loss: 1.0859e-04 - val_loss: 9.4490e-04
# Epoch 18/100
# 279/279 [==============================] - ETA: 0s - loss: 8.9707e-05
# Epoch 18: val_loss did not improve from 0.00094
# 279/279 [==============================] - 12s 42ms/step - loss: 8.9707e-05 - val_loss: 9.7223e-04
# Epoch 19/100
# 279/279 [==============================] - ETA: 0s - loss: 9.7865e-05
# Epoch 19: val_loss improved from 0.00094 to 0.00087, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 11s 41ms/step - loss: 9.7865e-05 - val_loss: 8.7314e-04
# Epoch 20/100
# 279/279 [==============================] - ETA: 0s - loss: 9.6402e-05
# Epoch 20: val_loss improved from 0.00087 to 0.00086, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 11s 41ms/step - loss: 9.6402e-05 - val_loss: 8.6226e-04
# Epoch 21/100
# 279/279 [==============================] - ETA: 0s - loss: 9.4023e-05
# Epoch 21: val_loss improved from 0.00086 to 0.00051, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 10s 34ms/step - loss: 9.4023e-05 - val_loss: 5.1025e-04
# Epoch 22/100
# 277/279 [============================>.] - ETA: 0s - loss: 9.3587e-05
# Epoch 22: val_loss did not improve from 0.00051
# 279/279 [==============================] - 9s 33ms/step - loss: 9.3974e-05 - val_loss: 7.1718e-04
# Epoch 23/100
# 278/279 [============================>.] - ETA: 0s - loss: 8.0113e-05
# Epoch 23: val_loss improved from 0.00051 to 0.00045, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 9s 33ms/step - loss: 8.0039e-05 - val_loss: 4.4932e-04
# Epoch 24/100
# 313/314 [============================>.] - ETA: 0s - loss: 8.9096e-05
# Epoch 8: val_loss did not improve from 0.00058
# 314/314 [==============================] - 12s 37ms/step - loss: 8.8914e-05 - val_loss: 0.0029
# Epoch 9/100
# 314/314 [==============================] - ETA: 0s - loss: 9.9752e-05
# Epoch 9: val_loss did not improve from 0.00058
# 314/314 [==============================] - 13s 41ms/step - loss: 9.9752e-05 - val_loss: 0.0016
# Epoch 10/100
# 312/314 [============================>.] - ETA: 0s - loss: 7.6356e-05
# Epoch 10: val_loss did not improve from 0.00058
# 314/314 [==============================] - 12s 37ms/step - loss: 7.6682e-05 - val_loss: 0.0019
# Epoch 11/100
# 314/314 [==============================] - ETA: 0s - loss: 6.8076e-05
# Epoch 12: val_loss did not improve from 0.00058
# 314/314 [==============================] - 8s 26ms/step - loss: 6.8076e-05 - val_loss: 0.0015
# Epoch 13/100
# 312/314 [============================>.] - ETA: 0s - loss: 7.3568e-05
# Epoch 13: val_loss did not improve from 0.00058
# 314/314 [==============================] - 9s 29ms/step - loss: 7.3528e-05 - val_loss: 0.0016
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:17165.337257519248
# [31958.877058524344, 12311.33244041687, 18653.74840875568, 6635.654976125128, 7250.114546327217, 4129.8349118676715, 9632.331341247693, 8315.087129057134, 17165.337257519248]
# Epoch 1/100
# 340/341 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 1: val_loss improved from inf to 0.00177, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 40s 44ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 2/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0804e-04
# Epoch 2: val_loss improved from 0.00177 to 0.00128, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 12s 36ms/step - loss: 3.0804e-04 - val_loss: 0.0013
# Epoch 3/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.8179e-04
# Epoch 3: val_loss did not improve from 0.00128
# 341/341 [==============================] - 12s 36ms/step - loss: 1.8166e-04 - val_loss: 0.0015
# Epoch 4/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.4096e-04
# Epoch 4: val_loss improved from 0.00128 to 0.00047, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 16s 47ms/step - loss: 1.4077e-04 - val_loss: 4.6941e-04
# Epoch 5/100
# 341/341 [==============================] - ETA: 0s - loss: 1.0657e-04
# Epoch 5: val_loss improved from 0.00047 to 0.00042, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 16s 46ms/step - loss: 1.0657e-04 - val_loss: 4.1564e-04
# Epoch 6/100
# 341/341 [==============================] - ETA: 0s - loss: 8.0611e-05
# Epoch 6: val_loss did not improve from 0.00042
# 341/341 [==============================] - 16s 48ms/step - loss: 8.0611e-05 - val_loss: 6.2901e-04
# Epoch 7/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.8329e-05
# Epoch 7: val_loss improved from 0.00042 to 0.00021, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 14s 42ms/step - loss: 6.8273e-05 - val_loss: 2.0858e-04
# Epoch 8/100
# 341/341 [==============================] - ETA: 0s - loss: 5.8016e-05
# Epoch 8: val_loss did not improve from 0.00021
# 341/341 [==============================] - 16s 47ms/step - loss: 5.8016e-05 - val_loss: 6.0165e-04
# Epoch 9/100
# 341/341 [==============================] - ETA: 0s - loss: 5.3319e-05
# Epoch 9: val_loss improved from 0.00021 to 0.00018, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 16s 46ms/step - loss: 5.3319e-05 - val_loss: 1.7567e-04
# Epoch 10/100
# 341/341 [==============================] - ETA: 0s - loss: 5.0478e-05
# Epoch 10: val_loss improved from 0.00018 to 0.00016, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 20s 60ms/step - loss: 5.0478e-05 - val_loss: 1.5928e-04
# Epoch 11/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.7658e-05
# Epoch 11: val_loss did not improve from 0.00016
# 341/341 [==============================] - 14s 42ms/step - loss: 4.7650e-05 - val_loss: 2.0949e-04
# Epoch 12/100
# 341/341 [==============================] - ETA: 0s - loss: 4.1336e-05
# Epoch 12: val_loss did not improve from 0.00016
# 341/341 [==============================] - 14s 41ms/step - loss: 4.1336e-05 - val_loss: 1.7094e-04
# Epoch 13/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.9629e-05
# Epoch 13: val_loss did not improve from 0.00016
# 341/341 [==============================] - 21s 60ms/step - loss: 3.9589e-05 - val_loss: 3.5113e-04
# Epoch 14/100
# 341/341 [==============================] - ETA: 0s - loss: 3.9178e-05
# Epoch 14: val_loss improved from 0.00016 to 0.00013, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 18s 52ms/step - loss: 3.9178e-05 - val_loss: 1.2653e-04
# Epoch 15/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4820e-05
# Epoch 15: val_loss did not improve from 0.00013
# 341/341 [==============================] - 14s 42ms/step - loss: 3.4820e-05 - val_loss: 1.9462e-04
# Epoch 16/100
# 341/341 [==============================] - ETA: 0s - loss: 3.3845e-05
# Epoch 16: val_loss did not improve from 0.00013
# 341/341 [==============================] - 13s 38ms/step - loss: 3.3845e-05 - val_loss: 1.5486e-04
# Epoch 17/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2213e-05
# Epoch 17: val_loss did not improve from 0.00013
# 341/341 [==============================] - 13s 38ms/step - loss: 3.2213e-05 - val_loss: 3.3506e-04
# Epoch 18/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.9716e-05
# Epoch 18: val_loss did not improve from 0.00013
# 341/341 [==============================] - 16s 48ms/step - loss: 2.9683e-05 - val_loss: 6.4679e-04
# Epoch 19/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.0581e-05
# Epoch 19: val_loss did not improve from 0.00013
# 341/341 [==============================] - 15s 44ms/step - loss: 3.0535e-05 - val_loss: 1.5319e-04
# Epoch 20/100
# 341/341 [==============================] - ETA: 0s - loss: 3.1474e-05
# Epoch 20: val_loss did not improve from 0.00013
# 341/341 [==============================] - 12s 34ms/step - loss: 3.1474e-05 - val_loss: 5.5987e-04
# Epoch 21/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.9851e-05
# Epoch 21: val_loss did not improve from 0.00013
# 341/341 [==============================] - 12s 34ms/step - loss: 2.9869e-05 - val_loss: 1.7381e-04
# Epoch 22/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.8251e-05
# Epoch 22: val_loss did not improve from 0.00013
# 341/341 [==============================] - 14s 40ms/step - loss: 2.8235e-05 - val_loss: 1.7406e-04
# Epoch 23/100
# 341/341 [==============================] - ETA: 0s - loss: 2.7545e-05
# Epoch 23: val_loss improved from 0.00013 to 0.00009, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 21s 63ms/step - loss: 2.7545e-05 - val_loss: 8.6549e-05
# Epoch 24/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.7932e-05
# Epoch 24: val_loss did not improve from 0.00009
# 341/341 [==============================] - 21s 62ms/step - loss: 2.7941e-05 - val_loss: 1.3633e-04
# Epoch 25/100
# 341/341 [==============================] - ETA: 0s - loss: 2.7706e-05
# Epoch 25: val_loss did not improve from 0.00009
# 341/341 [==============================] - 18s 52ms/step - loss: 2.7706e-05 - val_loss: 1.2966e-04
# Epoch 26/100
# 341/341 [==============================] - ETA: 0s - loss: 2.6188e-05
# Epoch 26: val_loss did not improve from 0.00009
# 341/341 [==============================] - 18s 52ms/step - loss: 2.6188e-05 - val_loss: 9.5428e-05
# Epoch 27/100
# 341/341 [==============================] - ETA: 0s - loss: 2.7845e-05
# Epoch 27: val_loss improved from 0.00009 to 0.00008, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 15s 44ms/step - loss: 2.7845e-05 - val_loss: 7.9646e-05
# Epoch 28/100
# 341/341 [==============================] - ETA: 0s - loss: 2.4679e-05
# Epoch 28: val_loss did not improve from 0.00008
# 341/341 [==============================] - 12s 36ms/step - loss: 2.4679e-05 - val_loss: 8.6841e-05
# Epoch 29/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.3292e-05
# Epoch 29: val_loss did not improve from 0.00008
# 341/341 [==============================] - 12s 35ms/step - loss: 2.3275e-05 - val_loss: 1.5208e-04
# Epoch 30/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.6635e-05
# Epoch 30: val_loss did not improve from 0.00008
# 341/341 [==============================] - 14s 42ms/step - loss: 2.6642e-05 - val_loss: 1.3043e-04
# Epoch 31/100
# 341/341 [==============================] - ETA: 0s - loss: 2.6490e-05
# Epoch 31: val_loss did not improve from 0.00008
# 341/341 [==============================] - 20s 59ms/step - loss: 2.6490e-05 - val_loss: 4.0010e-04
# Epoch 32/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.6200e-05
# Epoch 32: val_loss did not improve from 0.00008
# 341/341 [==============================] - 18s 51ms/step - loss: 2.6160e-05 - val_loss: 1.3323e-04
# Epoch 33/100
# 341/341 [==============================] - ETA: 0s - loss: 2.3039e-05
# Epoch 33: val_loss improved from 0.00008 to 0.00007, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 20s 58ms/step - loss: 2.3039e-05 - val_loss: 7.2562e-05
# Epoch 34/100
# 341/341 [==============================] - ETA: 0s - loss: 2.3136e-05
# Epoch 34: val_loss did not improve from 0.00007
# 341/341 [==============================] - 24s 71ms/step - loss: 2.3136e-05 - val_loss: 1.6980e-04
# Epoch 35/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.2375e-05
# Epoch 35: val_loss did not improve from 0.00007
# 341/341 [==============================] - 23s 68ms/step - loss: 2.2362e-05 - val_loss: 1.1853e-04
# Epoch 36/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.5018e-05
# Epoch 36: val_loss did not improve from 0.00007
# 341/341 [==============================] - 14s 42ms/step - loss: 2.4978e-05 - val_loss: 6.6994e-04
# Epoch 37/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5502e-05
# Epoch 37: val_loss did not improve from 0.00007
# 341/341 [==============================] - 14s 41ms/step - loss: 2.5502e-05 - val_loss: 1.3419e-04
# Epoch 38/100
# 341/341 [==============================] - ETA: 0s - loss: 2.3027e-05
# Epoch 38: val_loss did not improve from 0.00007
# 341/341 [==============================] - 15s 45ms/step - loss: 2.3027e-05 - val_loss: 1.7869e-04
# Epoch 39/100
# 341/341 [==============================] - ETA: 0s - loss: 2.2390e-05
# Epoch 39: val_loss did not improve from 0.00007
# 341/341 [==============================] - 19s 55ms/step - loss: 2.2390e-05 - val_loss: 1.3565e-04
# Epoch 40/100
# 226/341 [==================>...........] - ETA: 5s - loss: 2.1160e-05
# Epoch 43: val_loss did not improve from 0.00007
# 341/341 [==============================] - 15s 44ms/step - loss: 2.2476e-05 - val_loss: 2.6860e-04
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:29024.803880625437
# [31958.877058524344, 12311.33244041687, 18653.74840875568, 6635.654976125128, 7250.114546327217, 4129.8349118676715, 9632.331341247693, 8315.087129057134, 17165.337257519248, 29024.803880625437]

# %%
print(predict)
# Out:
# [array([[163096.6]], dtype=float32), array([[194433.73]], dtype=float32), array([[169342.39]], dtype=float32), array([[189160.98]], dtype=float32), array([[199202.66]], dtype=float32), array([[191619.84]], dtype=float32), array([[201225.56]], dtype=float32), array([[196767.86]], dtype=float32), array([[177926.48]], dtype=float32), array([[219854.47]], dtype=float32)]

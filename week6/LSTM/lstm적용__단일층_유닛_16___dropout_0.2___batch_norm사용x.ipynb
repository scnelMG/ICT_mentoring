# %%
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("[IT]삼성전자.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf

# seed_num = 42
# np.random.seed(seed_num)
# rn.seed(seed_num)
# tf.random.set_seed(seed_num)
# tf.set_random_seed(seed_num)

for i in range(1, len(df)//1000+2):
  
        # 데이터 불러오기
        df_copy = df
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()

        model.add(LSTM(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences=False,
                      activation='relu'))
      
        model.add(Dense(1))
        model.add(Dropout(0.2))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:938: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_up = pd.Series(index=self._psar.index)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:939: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_down = pd.Series(index=self._psar.index)
# Epoch 1/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0635
# Epoch 1: val_loss improved from inf to 0.05555, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 19ms/step - loss: 0.0638 - val_loss: 0.0556
# Epoch 2/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0509
# Epoch 2: val_loss improved from 0.05555 to 0.04252, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0541 - val_loss: 0.0425
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0571
# Epoch 3: val_loss improved from 0.04252 to 0.04233, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0584 - val_loss: 0.0423
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0582
# Epoch 4: val_loss did not improve from 0.04233
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0580 - val_loss: 0.0442
# Epoch 5/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0634
# Epoch 5: val_loss improved from 0.04233 to 0.03924, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0642 - val_loss: 0.0392
# Epoch 6/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0549
# Epoch 6: val_loss did not improve from 0.03924
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0567 - val_loss: 0.0439
# Epoch 7/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0643
# Epoch 7: val_loss did not improve from 0.03924
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0627 - val_loss: 0.0423
# Epoch 8/100
# 26/34 [=====================>........] - ETA: 0s - loss: 0.0637
# Epoch 8: val_loss improved from 0.03924 to 0.03699, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0637 - val_loss: 0.0370
# Epoch 9/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0658
# Epoch 9: val_loss improved from 0.03699 to 0.03698, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0623 - val_loss: 0.0370
# Epoch 10/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0514
# Epoch 10: val_loss improved from 0.03698 to 0.03053, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0563 - val_loss: 0.0305
# Epoch 11/100
# 26/34 [=====================>........] - ETA: 0s - loss: 0.0576
# Epoch 11: val_loss did not improve from 0.03053
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0554 - val_loss: 0.0335
# Epoch 12/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0636
# Epoch 12: val_loss did not improve from 0.03053
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0633 - val_loss: 0.0379
# Epoch 13/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0630
# Epoch 13: val_loss improved from 0.03053 to 0.02701, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0599 - val_loss: 0.0270
# Epoch 14/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0503
# Epoch 14: val_loss improved from 0.02701 to 0.02682, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0501 - val_loss: 0.0268
# Epoch 15/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0519
# Epoch 15: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0503 - val_loss: 0.0364
# Epoch 16/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0645
# Epoch 16: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0599 - val_loss: 0.0287
# Epoch 17/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0609
# Epoch 17: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0631 - val_loss: 0.0325
# Epoch 18/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0565
# Epoch 18: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0573 - val_loss: 0.0299
# Epoch 19/100
# 28/34 [=======================>......] - ETA: 0s - loss: 0.0568
# Epoch 19: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0556 - val_loss: 0.0313
# Epoch 20/100
# 27/34 [======================>.......] - ETA: 0s - loss: 0.0501
# Epoch 20: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0528 - val_loss: 0.0305
# Epoch 21/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0624
# Epoch 21: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0610 - val_loss: 0.0331
# Epoch 22/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0629
# Epoch 22: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0629 - val_loss: 0.0290
# Epoch 23/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0552
# Epoch 23: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0543 - val_loss: 0.0276
# Epoch 24/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0457
# Epoch 24: val_loss did not improve from 0.02682
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0484 - val_loss: 0.0316
# 9/9 [==============================] - 1s 5ms/step
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:13011.426245981189
# [13011.426245981189]
# 1/1 [==============================] - 0s 29ms/step
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0402
# Epoch 1: val_loss improved from inf to 0.01213, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 12ms/step - loss: 0.0400 - val_loss: 0.0121
# Epoch 2/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0333
# Epoch 2: val_loss did not improve from 0.01213
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0345 - val_loss: 0.0124
# Epoch 3/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0353
# Epoch 3: val_loss did not improve from 0.01213
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0351 - val_loss: 0.0122
# Epoch 4/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0338
# Epoch 4: val_loss improved from 0.01213 to 0.01164, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0333 - val_loss: 0.0116
# Epoch 5/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0283
# Epoch 5: val_loss improved from 0.01164 to 0.01073, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0289 - val_loss: 0.0107
# Epoch 6/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0270
# Epoch 6: val_loss did not improve from 0.01073
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0272 - val_loss: 0.0124
# Epoch 7/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0336
# Epoch 7: val_loss improved from 0.01073 to 0.01030, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0337 - val_loss: 0.0103
# Epoch 8/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0375
# Epoch 8: val_loss did not improve from 0.01030
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0378 - val_loss: 0.0119
# Epoch 9/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0324
# Epoch 9: val_loss did not improve from 0.01030
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0326 - val_loss: 0.0104
# Epoch 10/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0308
# Epoch 10: val_loss improved from 0.01030 to 0.00995, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0304 - val_loss: 0.0100
# Epoch 11/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0334
# Epoch 11: val_loss improved from 0.00995 to 0.00984, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0325 - val_loss: 0.0098
# Epoch 12/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0312
# Epoch 12: val_loss did not improve from 0.00984
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0311 - val_loss: 0.0102
# Epoch 13/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0347
# Epoch 13: val_loss did not improve from 0.00984
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0342 - val_loss: 0.0117
# Epoch 14/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0298
# Epoch 14: val_loss did not improve from 0.00984
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0298 - val_loss: 0.0104
# Epoch 15/100
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0334
# Epoch 15: val_loss did not improve from 0.00984
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0342 - val_loss: 0.0115
# Epoch 16/100
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0338
# Epoch 16: val_loss improved from 0.00984 to 0.00914, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0329 - val_loss: 0.0091
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 17: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0349 - val_loss: 0.0121
# Epoch 18/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0300
# Epoch 18: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0302 - val_loss: 0.0118
# Epoch 19/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0342
# Epoch 19: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0343 - val_loss: 0.0124
# Epoch 20/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0346
# Epoch 20: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0343 - val_loss: 0.0100
# Epoch 21/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0336
# Epoch 21: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0343 - val_loss: 0.0097
# Epoch 22/100
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0309
# Epoch 22: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0310 - val_loss: 0.0092
# Epoch 23/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0337
# Epoch 23: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0341 - val_loss: 0.0114
# Epoch 24/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0368
# Epoch 24: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0373 - val_loss: 0.0116
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 25: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0303 - val_loss: 0.0103
# Epoch 26/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 26: val_loss did not improve from 0.00914
# 69/69 [==============================] - 1s 12ms/step - loss: 0.0351 - val_loss: 0.0102
# 19/19 [==============================] - 0s 5ms/step
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:16752.93020190381
# [13011.426245981189, 16752.93020190381]
# 1/1 [==============================] - 0s 61ms/step
# Epoch 1/100
#  98/104 [===========================>..] - ETA: 0s - loss: 0.0205
# Epoch 1: val_loss improved from inf to 0.02246, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 3s 14ms/step - loss: 0.0203 - val_loss: 0.0225
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 2: val_loss improved from 0.02246 to 0.01471, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0158 - val_loss: 0.0147
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0153
# Epoch 3: val_loss improved from 0.01471 to 0.01363, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0153 - val_loss: 0.0136
# Epoch 4/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 4: val_loss improved from 0.01363 to 0.01272, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0165 - val_loss: 0.0127
# Epoch 5/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0140
# Epoch 5: val_loss did not improve from 0.01272
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0142 - val_loss: 0.0136
# Epoch 6/100
#  99/104 [===========================>..] - ETA: 0s - loss: 0.0135
# Epoch 6: val_loss improved from 0.01272 to 0.01166, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0137 - val_loss: 0.0117
# Epoch 7/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0155
# Epoch 7: val_loss did not improve from 0.01166
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0158 - val_loss: 0.0121
# Epoch 8/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0153
# Epoch 8: val_loss improved from 0.01166 to 0.01055, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0154 - val_loss: 0.0105
# Epoch 9/100
# 103/104 [============================>.] - ETA: 0s - loss: 0.0149
# Epoch 9: val_loss improved from 0.01055 to 0.01032, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 0.0150 - val_loss: 0.0103
# Epoch 10/100
# 100/104 [===========================>..] - ETA: 0s - loss: 0.0133
# Epoch 10: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0136 - val_loss: 0.0121
# Epoch 11/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 11: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0162 - val_loss: 0.0110
# Epoch 12/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 12: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 11ms/step - loss: 0.0145 - val_loss: 0.0105
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0147
# Epoch 13: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 10ms/step - loss: 0.0145 - val_loss: 0.0131
# Epoch 14/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 14: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0140 - val_loss: 0.0115
# Epoch 15/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0152
# Epoch 15: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0153 - val_loss: 0.0117
# Epoch 16/100
# 104/104 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 16: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0146 - val_loss: 0.0110
# Epoch 17/100
#  97/104 [==========================>...] - ETA: 0s - loss: 0.0159
# Epoch 17: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0158 - val_loss: 0.0120
# Epoch 18/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 18: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0145 - val_loss: 0.0112
# Epoch 19/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 19: val_loss did not improve from 0.01032
# 104/104 [==============================] - 1s 12ms/step - loss: 0.0161 - val_loss: 0.0118
# 28/28 [==============================] - 1s 5ms/step
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:13011.248991565175
# [13011.426245981189, 16752.93020190381, 13011.248991565175]
# 1/1 [==============================] - 0s 31ms/step
# Epoch 1/100
# 135/139 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 1: val_loss improved from inf to 0.00408, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 10ms/step - loss: 0.0116 - val_loss: 0.0041
# Epoch 2/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 2: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0104 - val_loss: 0.0043
# Epoch 3/100
# 131/139 [===========================>..] - ETA: 0s - loss: 0.0097
# Epoch 3: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0096 - val_loss: 0.0049
# Epoch 4/100
# 132/139 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 4: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0088 - val_loss: 0.0057
# Epoch 5/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 5: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0088 - val_loss: 0.0052
# Epoch 6/100
# 132/139 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 6: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0092 - val_loss: 0.0048
# Epoch 7/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0084
# Epoch 7: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0084 - val_loss: 0.0045
# Epoch 8/100
# 133/139 [===========================>..] - ETA: 0s - loss: 0.0084
# Epoch 8: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 9/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 9: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 7ms/step - loss: 0.0090 - val_loss: 0.0051
# Epoch 10/100
# 138/139 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 10: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0097 - val_loss: 0.0048
# Epoch 11/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 11: val_loss did not improve from 0.00408
# 139/139 [==============================] - 1s 9ms/step - loss: 0.0089 - val_loss: 0.0065
# 37/37 [==============================] - 0s 4ms/step
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:15375.90547630989
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989]
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0113
# Epoch 1: val_loss improved from inf to 0.00607, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 3s 9ms/step - loss: 0.0111 - val_loss: 0.0061
# Epoch 2/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 2: val_loss improved from 0.00607 to 0.00409, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 3/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 3: val_loss improved from 0.00409 to 0.00379, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 4/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 4: val_loss improved from 0.00379 to 0.00338, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 7ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 5/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 5: val_loss did not improve from 0.00338
# 174/174 [==============================] - 1s 7ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 6/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 6: val_loss did not improve from 0.00338
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 0.0035
# Epoch 7/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 7: val_loss did not improve from 0.00338
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 8/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 8: val_loss did not improve from 0.00338
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 9/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0053
# Epoch 9: val_loss improved from 0.00338 to 0.00306, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 10/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 10: val_loss did not improve from 0.00306
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 11/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 11: val_loss did not improve from 0.00306
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 12/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 12: val_loss did not improve from 0.00306
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 13/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 13: val_loss improved from 0.00306 to 0.00305, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0031
# Epoch 14/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 14: val_loss did not improve from 0.00305
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 15/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 15: val_loss improved from 0.00305 to 0.00303, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 16/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 16: val_loss did not improve from 0.00303
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 17/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 17: val_loss improved from 0.00303 to 0.00302, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0051 - val_loss: 0.0030
# Epoch 18/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 18: val_loss improved from 0.00302 to 0.00294, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 19/100
# 170/174 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 19: val_loss did not improve from 0.00294
# 174/174 [==============================] - 2s 11ms/step - loss: 0.0052 - val_loss: 0.0031
# Epoch 20/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 20: val_loss did not improve from 0.00294
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 21/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 21: val_loss did not improve from 0.00294
# 174/174 [==============================] - 2s 9ms/step - loss: 0.0056 - val_loss: 0.0041
# Epoch 22/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 22: val_loss did not improve from 0.00294
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 23/100
# 168/174 [===========================>..] - ETA: 0s - loss: 0.0055
# Epoch 23: val_loss improved from 0.00294 to 0.00287, saving model to model\tmp_checkpoint.h5
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 24/100
# 173/174 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 24: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 25/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 25: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 26/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 26: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 27/100
# 167/174 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 27: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0057 - val_loss: 0.0038
# Epoch 28/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 28: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 29/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 29: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 30/100
# 169/174 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 30: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 31/100
# 171/174 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 31: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 32/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 32: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0052 - val_loss: 0.0031
# Epoch 33/100
# 172/174 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 33: val_loss did not improve from 0.00287
# 174/174 [==============================] - 1s 8ms/step - loss: 0.0055 - val_loss: 0.0034
# 47/47 [==============================] - 1s 4ms/step
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:13801.155674710639
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639]
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 1: val_loss improved from inf to 0.00143, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 4s 10ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 2/100
# 203/209 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 2: val_loss improved from 0.00143 to 0.00123, saving model to model\tmp_checkpoint.h5
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 3/100
# 207/209 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 3: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 4/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 4: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 5/100
# 205/209 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 5: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 6/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 6: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 7/100
# 201/209 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 7: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 8/100
# 206/209 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 8: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 9: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 10: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 11/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 11: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 12/100
# 204/209 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 12: val_loss did not improve from 0.00123
# 209/209 [==============================] - 2s 9ms/step - loss: 0.0027 - val_loss: 0.0036
# 56/56 [==============================] - 1s 4ms/step
# 6000길이의 데이터 적용 완료
#  길이: 6000, RMSE:10746.965879775214
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639, 10746.965879775214]
# 1/1 [==============================] - 0s 31ms/step
# Epoch 1/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 1: val_loss improved from inf to 0.02405, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 4s 10ms/step - loss: 0.0060 - val_loss: 0.0241
# Epoch 2/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 2: val_loss improved from 0.02405 to 0.01700, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 10ms/step - loss: 0.0018 - val_loss: 0.0170
# Epoch 3/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 3: val_loss improved from 0.01700 to 0.01155, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0018 - val_loss: 0.0116
# Epoch 4/100
# 237/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 4: val_loss improved from 0.01155 to 0.00965, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0097
# Epoch 5/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss improved from 0.00965 to 0.00656, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 7ms/step - loss: 0.0014 - val_loss: 0.0066
# Epoch 6/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 6: val_loss improved from 0.00656 to 0.00432, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 9ms/step - loss: 0.0015 - val_loss: 0.0043
# Epoch 7/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 7: val_loss improved from 0.00432 to 0.00351, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 9ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 8/100
# 237/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 8: val_loss improved from 0.00351 to 0.00310, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 9ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 9/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 9: val_loss improved from 0.00310 to 0.00232, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 9ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 10/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 10: val_loss did not improve from 0.00232
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 11/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 11: val_loss improved from 0.00232 to 0.00194, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 12/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 12: val_loss did not improve from 0.00194
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 13/100
# 237/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 13: val_loss did not improve from 0.00194
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 14/100
# 240/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 14: val_loss improved from 0.00194 to 0.00144, saving model to model\tmp_checkpoint.h5
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 15/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 15: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 16/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 16: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 17/100
# 241/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 17: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 18/100
# 237/244 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 18: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 19/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 19: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 20/100
# 239/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 20: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 7ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 21/100
# 242/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 21: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 22/100
# 243/244 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 22: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 23/100
# 237/244 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 23: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 24/100
# 244/244 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 24: val_loss did not improve from 0.00144
# 244/244 [==============================] - 2s 8ms/step - loss: 0.0015 - val_loss: 0.0019
# 65/65 [==============================] - 1s 4ms/step
# 7000길이의 데이터 적용 완료
#  길이: 7000, RMSE:6303.038890474011
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639, 10746.965879775214, 6303.038890474011]
# 1/1 [==============================] - 0s 216ms/step
# Epoch 1/100
# 277/279 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 1: val_loss improved from inf to 0.00175, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 4s 9ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 2/100
# 274/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 2: val_loss improved from 0.00175 to 0.00098, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 2s 8ms/step - loss: 0.0011 - val_loss: 9.8001e-04
# Epoch 3/100
# 275/279 [============================>.] - ETA: 0s - loss: 9.5147e-04
# Epoch 3: val_loss improved from 0.00098 to 0.00092, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 2s 8ms/step - loss: 9.5383e-04 - val_loss: 9.1966e-04
# Epoch 4/100
# 276/279 [============================>.] - ETA: 0s - loss: 8.6204e-04
# Epoch 4: val_loss improved from 0.00092 to 0.00086, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 2s 8ms/step - loss: 8.6433e-04 - val_loss: 8.6019e-04
# Epoch 5/100
# 275/279 [============================>.] - ETA: 0s - loss: 9.7447e-04
# Epoch 5: val_loss did not improve from 0.00086
# 279/279 [==============================] - 2s 8ms/step - loss: 9.7562e-04 - val_loss: 8.6702e-04
# Epoch 6/100
# 276/279 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 6: val_loss improved from 0.00086 to 0.00069, saving model to model\tmp_checkpoint.h5
# 279/279 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 6.8991e-04
# Epoch 7/100
# 275/279 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 7: val_loss did not improve from 0.00069
# 279/279 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 8.5088e-04
# Epoch 8/100
# 279/279 [==============================] - ETA: 0s - loss: 9.6763e-04
# Epoch 8: val_loss did not improve from 0.00069
# 279/279 [==============================] - 3s 9ms/step - loss: 9.6763e-04 - val_loss: 9.3808e-04
# Epoch 9/100
# 276/279 [============================>.] - ETA: 0s - loss: 8.9845e-04
# Epoch 9: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 7ms/step - loss: 8.9742e-04 - val_loss: 9.4918e-04
# Epoch 10/100
# 272/279 [============================>.] - ETA: 0s - loss: 9.0890e-04
# Epoch 10: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 9.0460e-04 - val_loss: 8.9076e-04
# Epoch 11/100
# 276/279 [============================>.] - ETA: 0s - loss: 9.5275e-04
# Epoch 11: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 9.6421e-04 - val_loss: 9.8390e-04
# Epoch 12/100
# 277/279 [============================>.] - ETA: 0s - loss: 8.9677e-04
# Epoch 12: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 9ms/step - loss: 9.0703e-04 - val_loss: 0.0010
# Epoch 13/100
# 277/279 [============================>.] - ETA: 0s - loss: 9.4296e-04
# Epoch 13: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 9.4005e-04 - val_loss: 9.8627e-04
# Epoch 14/100
# 277/279 [============================>.] - ETA: 0s - loss: 8.3097e-04
# Epoch 14: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 8.3751e-04 - val_loss: 7.4250e-04
# Epoch 15/100
# 276/279 [============================>.] - ETA: 0s - loss: 9.5475e-04
# Epoch 15: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 9.5418e-04 - val_loss: 0.0010
# Epoch 16/100
# 274/279 [============================>.] - ETA: 0s - loss: 9.0987e-04
# Epoch 16: val_loss did not improve from 0.00069
# 279/279 [==============================] - 2s 8ms/step - loss: 9.0916e-04 - val_loss: 8.2740e-04
# 75/75 [==============================] - 1s 4ms/step
# 8000길이의 데이터 적용 완료
#  길이: 8000, RMSE:14804.454589750767
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639, 10746.965879775214, 6303.038890474011, 14804.454589750767]
# 1/1 [==============================] - 0s 30ms/step
# Epoch 1/100
# 312/314 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 1: val_loss improved from inf to 0.00050, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 5s 10ms/step - loss: 0.0013 - val_loss: 5.0145e-04
# Epoch 2/100
# 314/314 [==============================] - ETA: 0s - loss: 6.1568e-04
# Epoch 2: val_loss did not improve from 0.00050
# 314/314 [==============================] - 3s 8ms/step - loss: 6.1568e-04 - val_loss: 7.3198e-04
# Epoch 3/100
# 314/314 [==============================] - ETA: 0s - loss: 5.8589e-04
# Epoch 3: val_loss did not improve from 0.00050
# 314/314 [==============================] - 3s 8ms/step - loss: 5.8589e-04 - val_loss: 6.8718e-04
# Epoch 4/100
# 308/314 [============================>.] - ETA: 0s - loss: 5.1819e-04
# Epoch 4: val_loss did not improve from 0.00050
# 314/314 [==============================] - 3s 8ms/step - loss: 5.1143e-04 - val_loss: 6.2639e-04
# Epoch 5/100
# 307/314 [============================>.] - ETA: 0s - loss: 5.4772e-04
# Epoch 5: val_loss did not improve from 0.00050
# 314/314 [==============================] - 2s 8ms/step - loss: 5.4245e-04 - val_loss: 5.5604e-04
# Epoch 6/100
# 310/314 [============================>.] - ETA: 0s - loss: 5.6911e-04
# Epoch 6: val_loss did not improve from 0.00050
# 314/314 [==============================] - 2s 8ms/step - loss: 5.6945e-04 - val_loss: 6.2714e-04
# Epoch 7/100
# 311/314 [============================>.] - ETA: 0s - loss: 5.4190e-04
# Epoch 7: val_loss did not improve from 0.00050
# 314/314 [==============================] - 2s 8ms/step - loss: 5.3966e-04 - val_loss: 7.7546e-04
# Epoch 8/100
# 311/314 [============================>.] - ETA: 0s - loss: 5.7397e-04
# Epoch 8: val_loss did not improve from 0.00050
# 314/314 [==============================] - 3s 8ms/step - loss: 5.6951e-04 - val_loss: 7.5001e-04
# Epoch 9/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.8107e-04
# Epoch 9: val_loss did not improve from 0.00050
# 314/314 [==============================] - 2s 8ms/step - loss: 5.8321e-04 - val_loss: 9.2116e-04
# Epoch 10/100
# 312/314 [============================>.] - ETA: 0s - loss: 4.8755e-04
# Epoch 10: val_loss did not improve from 0.00050
# 314/314 [==============================] - 2s 7ms/step - loss: 4.8465e-04 - val_loss: 7.4996e-04
# Epoch 11/100
# 314/314 [==============================] - ETA: 0s - loss: 5.2686e-04
# Epoch 11: val_loss did not improve from 0.00050
# 314/314 [==============================] - 3s 8ms/step - loss: 5.2686e-04 - val_loss: 8.3518e-04
# 84/84 [==============================] - 1s 4ms/step
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:5297.21656933946
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639, 10746.965879775214, 6303.038890474011, 14804.454589750767, 5297.21656933946]
# 1/1 [==============================] - 0s 69ms/step
# Epoch 1/100
# 341/341 [==============================] - ETA: 0s - loss: 9.6214e-04
# Epoch 1: val_loss improved from inf to 0.00195, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 10ms/step - loss: 9.6214e-04 - val_loss: 0.0020
# Epoch 2/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.5273e-04
# Epoch 2: val_loss improved from 0.00195 to 0.00116, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 3s 9ms/step - loss: 3.5300e-04 - val_loss: 0.0012
# Epoch 3/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4018e-04
# Epoch 3: val_loss did not improve from 0.00116
# 341/341 [==============================] - 3s 10ms/step - loss: 3.4018e-04 - val_loss: 0.0013
# Epoch 4/100
# 336/341 [============================>.] - ETA: 0s - loss: 3.3531e-04
# Epoch 4: val_loss improved from 0.00116 to 0.00093, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 3s 10ms/step - loss: 3.3315e-04 - val_loss: 9.3056e-04
# Epoch 5/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.8704e-04
# Epoch 5: val_loss improved from 0.00093 to 0.00092, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 2.8834e-04 - val_loss: 9.1761e-04
# Epoch 6/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.8964e-04
# Epoch 6: val_loss did not improve from 0.00092
# 341/341 [==============================] - 4s 11ms/step - loss: 2.8922e-04 - val_loss: 0.0011
# Epoch 7/100
# 339/341 [============================>.] - ETA: 0s - loss: 2.9516e-04
# Epoch 7: val_loss did not improve from 0.00092
# 341/341 [==============================] - 4s 10ms/step - loss: 2.9535e-04 - val_loss: 9.3639e-04
# Epoch 8/100
# 336/341 [============================>.] - ETA: 0s - loss: 2.9447e-04
# Epoch 8: val_loss did not improve from 0.00092
# 341/341 [==============================] - 3s 10ms/step - loss: 2.9536e-04 - val_loss: 0.0010
# Epoch 9/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.0881e-04
# Epoch 9: val_loss did not improve from 0.00092
# 341/341 [==============================] - 3s 10ms/step - loss: 3.0665e-04 - val_loss: 9.8518e-04
# Epoch 10/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.1579e-04
# Epoch 10: val_loss improved from 0.00092 to 0.00085, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 3.1670e-04 - val_loss: 8.5143e-04
# Epoch 11/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.0563e-04
# Epoch 11: val_loss did not improve from 0.00085
# 341/341 [==============================] - 3s 10ms/step - loss: 3.0430e-04 - val_loss: 9.2853e-04
# Epoch 12/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.0082e-04
# Epoch 12: val_loss improved from 0.00085 to 0.00079, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 2.9941e-04 - val_loss: 7.9207e-04
# Epoch 13/100
# 336/341 [============================>.] - ETA: 0s - loss: 3.1270e-04
# Epoch 13: val_loss did not improve from 0.00079
# 341/341 [==============================] - 4s 10ms/step - loss: 3.0955e-04 - val_loss: 8.7647e-04
# Epoch 14/100
# 339/341 [============================>.] - ETA: 0s - loss: 2.7593e-04
# Epoch 14: val_loss did not improve from 0.00079
# 341/341 [==============================] - 6s 17ms/step - loss: 2.7583e-04 - val_loss: 8.2320e-04
# Epoch 15/100
# 341/341 [==============================] - ETA: 0s - loss: 2.7663e-04
# Epoch 15: val_loss did not improve from 0.00079
# 341/341 [==============================] - 4s 12ms/step - loss: 2.7663e-04 - val_loss: 8.8732e-04
# Epoch 16/100
# 335/341 [============================>.] - ETA: 0s - loss: 3.0395e-04
# Epoch 16: val_loss did not improve from 0.00079
# 341/341 [==============================] - 3s 10ms/step - loss: 3.0861e-04 - val_loss: 8.9511e-04
# Epoch 17/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.9714e-04
# Epoch 17: val_loss did not improve from 0.00079
# 341/341 [==============================] - 3s 9ms/step - loss: 2.9492e-04 - val_loss: 8.0915e-04
# Epoch 18/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2870e-04
# Epoch 18: val_loss did not improve from 0.00079
# 341/341 [==============================] - 4s 11ms/step - loss: 3.2870e-04 - val_loss: 9.2853e-04
# Epoch 19/100
# 341/341 [==============================] - ETA: 0s - loss: 2.9864e-04
# Epoch 19: val_loss improved from 0.00079 to 0.00078, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 5s 14ms/step - loss: 2.9864e-04 - val_loss: 7.8380e-04
# Epoch 20/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.8101e-04
# Epoch 20: val_loss improved from 0.00078 to 0.00066, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 2.7834e-04 - val_loss: 6.6293e-04
# Epoch 21/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.9291e-04
# Epoch 21: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 2.9238e-04 - val_loss: 8.9350e-04
# Epoch 22/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.0180e-04
# Epoch 22: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 3.0012e-04 - val_loss: 7.4831e-04
# Epoch 23/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.9210e-04
# Epoch 23: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 2.8971e-04 - val_loss: 8.2837e-04
# Epoch 24/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.3204e-04
# Epoch 24: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 3.3088e-04 - val_loss: 8.4341e-04
# Epoch 25/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.2906e-04
# Epoch 25: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 3.2728e-04 - val_loss: 8.0914e-04
# Epoch 26/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.2010e-04
# Epoch 26: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 3.1768e-04 - val_loss: 7.1121e-04
# Epoch 27/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.9576e-04
# Epoch 27: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 10ms/step - loss: 2.9306e-04 - val_loss: 8.6254e-04
# Epoch 28/100
# 335/341 [============================>.] - ETA: 0s - loss: 2.8490e-04
# Epoch 28: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 11ms/step - loss: 2.8402e-04 - val_loss: 7.4738e-04
# Epoch 29/100
# 337/341 [============================>.] - ETA: 0s - loss: 2.9657e-04
# Epoch 29: val_loss did not improve from 0.00066
# 341/341 [==============================] - 3s 10ms/step - loss: 2.9807e-04 - val_loss: 8.7873e-04
# Epoch 30/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.8857e-04
# Epoch 30: val_loss did not improve from 0.00066
# 341/341 [==============================] - 4s 12ms/step - loss: 2.8805e-04 - val_loss: 7.4570e-04
# 91/91 [==============================] - 1s 4ms/step
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:9306.168563755053
# [13011.426245981189, 16752.93020190381, 13011.248991565175, 15375.90547630989, 13801.155674710639, 10746.965879775214, 6303.038890474011, 14804.454589750767, 5297.21656933946, 9306.168563755053]
# 1/1 [==============================] - 0s 30ms/step

# %%
tmp = min(result)
index = result.index(tmp)
(index + 1)*1000
# Out:
# 9000

# %%
import matplotlib.pyplot as plt
plt.plot(result)

# %%
result
# Out:
# [13011.426245981189,
#  16752.93020190381,
#  13011.248991565175,
#  15375.90547630989,
#  13801.155674710639,
#  10746.965879775214,
#  6303.038890474011,
#  14804.454589750767,
#  5297.21656933946,
#  9306.168563755053]

# %%
predict
# Out:
# [array([[62771.7]], dtype=float32),
#  array([[51852.938]], dtype=float32),
#  array([[56091.46]], dtype=float32),
#  array([[54101.69]], dtype=float32),
#  array([[47610.73]], dtype=float32),
#  array([[88960.2]], dtype=float32),
#  array([[68861.12]], dtype=float32),
#  array([[109075.44]], dtype=float32),
#  array([[65066.023]], dtype=float32),
#  array([[84659.45]], dtype=float32)]

# %%
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("[IT]삼성전자.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf

# seed_num = 42
# np.random.seed(seed_num)
# rn.seed(seed_num)
# tf.random.set_seed(seed_num)
# tf.set_random_seed(seed_num)

for i in range(1, len(df)//1000+2):
  
        # seed_num = 42
        # np.random.seed(seed_num)
        # rn.seed(seed_num)
        # tf.random.set_seed(seed_num)
        
        # 데이터 불러오기
        df_copy = df
        # df = df.set_index(keys=['Date'], inplace=False, drop=True)
        # df = df.drop('Close', axis = 1)
        # df.rename(columns ={'Adj Close':'Close'}, inplace = True)
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()

        model.add(LSTM(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        
        # model.add(batch_normalization.BatchNormalization())

        model.add(LSTM(16, return_sequences=False, stateful=False))
        # model.add(batch_normalization.BatchNormalization())
        model.add(Dense(1))
        # model.add(Dropout(0.2, seed=123))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
        
        # new_pred = model.predict(pred_feature)
        # rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        # predict.append(rescaled_newpred)
        
        
        
        
    # data_size = list(range(1000, len(df_origin), 1000))
    # data_size.append(len(df_origin))
    # plt.style.use("ggplot")
    # plt.rcParams['font.family'] = 'Malgun Gothic'
    # data_size = list(range(1000, len(df_origin), 1000))
    # data_size.append(len(df_origin))
    # plt.figure(figsize=(9, 6))
    # plt.plot(data_size, result)
    # plt.tick_params(axis='x')
    # plt.tick_params(axis='y')
    # plt.title(f'{file_name}')
    # plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 1: val_loss improved from inf to 0.06531, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 9s 103ms/step - loss: 0.0079 - val_loss: 0.0653
# Epoch 2/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 2: val_loss improved from 0.06531 to 0.05343, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 32ms/step - loss: 0.0019 - val_loss: 0.0534
# Epoch 3/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 3: val_loss improved from 0.05343 to 0.04554, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 0.0455
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 9.5831e-04
# Epoch 4: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 25ms/step - loss: 9.5157e-04 - val_loss: 0.0535
# Epoch 5/100
# 32/34 [===========================>..] - ETA: 0s - loss: 5.3674e-04
# Epoch 5: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 24ms/step - loss: 5.3263e-04 - val_loss: 0.0829
# Epoch 6/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.6485e-04
# Epoch 6: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 24ms/step - loss: 4.6668e-04 - val_loss: 0.0503
# Epoch 7/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.4799e-04
# Epoch 7: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 29ms/step - loss: 4.4964e-04 - val_loss: 0.0617
# Epoch 8/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.2714e-04
# Epoch 8: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 27ms/step - loss: 3.2077e-04 - val_loss: 0.0507
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 3.9677e-04
# Epoch 9: val_loss did not improve from 0.04554
# 34/34 [==============================] - 1s 29ms/step - loss: 3.9677e-04 - val_loss: 0.0491
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.8456e-04
# Epoch 10: val_loss improved from 0.04554 to 0.02956, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 21ms/step - loss: 3.8226e-04 - val_loss: 0.0296
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 2.8969e-04
# Epoch 11: val_loss did not improve from 0.02956
# 34/34 [==============================] - 1s 15ms/step - loss: 2.8969e-04 - val_loss: 0.0457
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 2.2472e-04
# Epoch 12: val_loss did not improve from 0.02956
# 34/34 [==============================] - 1s 15ms/step - loss: 2.2472e-04 - val_loss: 0.0383
# Epoch 13/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.0755e-04
# Epoch 13: val_loss did not improve from 0.02956
# 34/34 [==============================] - 0s 14ms/step - loss: 2.0634e-04 - val_loss: 0.0415
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 2.1063e-04
# Epoch 14: val_loss did not improve from 0.02956
# 34/34 [==============================] - 1s 15ms/step - loss: 2.1063e-04 - val_loss: 0.0385
# Epoch 15/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.0666e-04
# Epoch 15: val_loss did not improve from 0.02956
# 34/34 [==============================] - 1s 15ms/step - loss: 2.0639e-04 - val_loss: 0.0442
# Epoch 16/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.1693e-04
# Epoch 16: val_loss did not improve from 0.02956
# 34/34 [==============================] - 0s 15ms/step - loss: 2.1701e-04 - val_loss: 0.0399
# Epoch 17/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.0285e-04
# Epoch 17: val_loss did not improve from 0.02956
# 34/34 [==============================] - 1s 15ms/step - loss: 2.0542e-04 - val_loss: 0.0382
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 1.8699e-04
# Epoch 18: val_loss did not improve from 0.02956
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8642e-04 - val_loss: 0.0417
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 1.7855e-04
# Epoch 19: val_loss did not improve from 0.02956
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7855e-04 - val_loss: 0.0412
# Epoch 20/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.4155e-04
# Epoch 20: val_loss improved from 0.02956 to 0.02732, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 2.4096e-04 - val_loss: 0.0273
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 1.7170e-04
# Epoch 21: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7170e-04 - val_loss: 0.0333
# Epoch 22/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.1921e-04
# Epoch 22: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 2.1730e-04 - val_loss: 0.0316
# Epoch 23/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.6841e-04
# Epoch 23: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.6614e-04 - val_loss: 0.0289
# Epoch 24/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.8158e-04
# Epoch 24: val_loss did not improve from 0.02732
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7784e-04 - val_loss: 0.0333
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6575e-04
# Epoch 25: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.6575e-04 - val_loss: 0.0353
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 1.5755e-04
# Epoch 26: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.5639e-04 - val_loss: 0.0317
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 1.8850e-04
# Epoch 27: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8850e-04 - val_loss: 0.0337
# Epoch 28/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.6439e-04
# Epoch 28: val_loss did not improve from 0.02732
# 34/34 [==============================] - 1s 15ms/step - loss: 1.6406e-04 - val_loss: 0.0327
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 1.6133e-04
# Epoch 29: val_loss did not improve from 0.02732
# 34/34 [==============================] - 0s 14ms/step - loss: 1.6133e-04 - val_loss: 0.0404
# Epoch 30/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.0127e-04
# Epoch 30: val_loss did not improve from 0.02732
# 34/34 [==============================] - 1s 15ms/step - loss: 1.9936e-04 - val_loss: 0.0365
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:19888.227935952873
# [19888.227935952873]
# Epoch 1/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 1: val_loss improved from inf to 0.00059, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 9s 42ms/step - loss: 0.0095 - val_loss: 5.9408e-04
# Epoch 2/100
# 68/69 [============================>.] - ETA: 0s - loss: 3.5214e-04
# Epoch 2: val_loss improved from 0.00059 to 0.00033, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 3.4972e-04 - val_loss: 3.2500e-04
# Epoch 3/100
# 66/69 [===========================>..] - ETA: 0s - loss: 2.0937e-04
# Epoch 3: val_loss improved from 0.00033 to 0.00025, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 2.0617e-04 - val_loss: 2.5200e-04
# Epoch 4/100
# 69/69 [==============================] - ETA: 0s - loss: 1.6702e-04
# Epoch 4: val_loss did not improve from 0.00025
# 69/69 [==============================] - 1s 14ms/step - loss: 1.6702e-04 - val_loss: 3.0572e-04
# Epoch 5/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.5202e-04
# Epoch 5: val_loss improved from 0.00025 to 0.00023, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 1.5265e-04 - val_loss: 2.2776e-04
# Epoch 6/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.4544e-04
# Epoch 6: val_loss improved from 0.00023 to 0.00021, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.4778e-04 - val_loss: 2.0846e-04
# Epoch 7/100
# 69/69 [==============================] - ETA: 0s - loss: 1.2687e-04
# Epoch 7: val_loss improved from 0.00021 to 0.00019, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 1.2687e-04 - val_loss: 1.9018e-04
# Epoch 8/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.2841e-04
# Epoch 8: val_loss did not improve from 0.00019
# 69/69 [==============================] - 1s 14ms/step - loss: 1.2748e-04 - val_loss: 3.0823e-04
# Epoch 9/100
# 69/69 [==============================] - ETA: 0s - loss: 1.1701e-04
# Epoch 9: val_loss improved from 0.00019 to 0.00018, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1701e-04 - val_loss: 1.8435e-04
# Epoch 10/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.1229e-04
# Epoch 10: val_loss improved from 0.00018 to 0.00018, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1243e-04 - val_loss: 1.7547e-04
# Epoch 11/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.1123e-04
# Epoch 11: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1203e-04 - val_loss: 1.8534e-04
# Epoch 12/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.1494e-04
# Epoch 12: val_loss did not improve from 0.00018
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1721e-04 - val_loss: 1.9568e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 9.6415e-05
# Epoch 13: val_loss improved from 0.00018 to 0.00017, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 9.6415e-05 - val_loss: 1.7400e-04
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.1142e-04
# Epoch 14: val_loss improved from 0.00017 to 0.00015, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1008e-04 - val_loss: 1.5359e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.1056e-04
# Epoch 15: val_loss did not improve from 0.00015
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1075e-04 - val_loss: 1.5766e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 9.5839e-05
# Epoch 16: val_loss improved from 0.00015 to 0.00014, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 9.5839e-05 - val_loss: 1.4464e-04
# Epoch 17/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.0091e-04
# Epoch 17: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 15ms/step - loss: 1.0124e-04 - val_loss: 2.3737e-04
# Epoch 18/100
# 69/69 [==============================] - ETA: 0s - loss: 1.1020e-04
# Epoch 18: val_loss improved from 0.00014 to 0.00014, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1020e-04 - val_loss: 1.3621e-04
# Epoch 19/100
# 69/69 [==============================] - ETA: 0s - loss: 9.1558e-05
# Epoch 19: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 14ms/step - loss: 9.1558e-05 - val_loss: 1.4518e-04
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.7965e-05
# Epoch 20: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 14ms/step - loss: 8.7819e-05 - val_loss: 1.6208e-04
# Epoch 21/100
# 69/69 [==============================] - ETA: 0s - loss: 9.6278e-05
# Epoch 21: val_loss improved from 0.00014 to 0.00013, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 9.6278e-05 - val_loss: 1.2915e-04
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.7759e-05
# Epoch 22: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 15ms/step - loss: 8.8138e-05 - val_loss: 2.0192e-04
# Epoch 23/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.4986e-05
# Epoch 23: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 15ms/step - loss: 9.4281e-05 - val_loss: 1.8560e-04
# Epoch 24/100
# 65/69 [===========================>..] - ETA: 0s - loss: 9.9250e-05
# Epoch 24: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 14ms/step - loss: 9.7711e-05 - val_loss: 1.3496e-04
# Epoch 25/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.0281e-05
# Epoch 25: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 14ms/step - loss: 7.9360e-05 - val_loss: 1.3961e-04
# Epoch 26/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.7852e-05
# Epoch 26: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 14ms/step - loss: 7.7030e-05 - val_loss: 1.3960e-04
# Epoch 27/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.8584e-05
# Epoch 27: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 15ms/step - loss: 8.9901e-05 - val_loss: 1.3001e-04
# Epoch 28/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.8639e-05
# Epoch 28: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 15ms/step - loss: 8.7367e-05 - val_loss: 2.1587e-04
# Epoch 29/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.7848e-05
# Epoch 29: val_loss improved from 0.00013 to 0.00012, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 7.8126e-05 - val_loss: 1.2379e-04
# Epoch 30/100
# 69/69 [==============================] - ETA: 0s - loss: 8.3933e-05
# Epoch 30: val_loss improved from 0.00012 to 0.00012, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 8.3933e-05 - val_loss: 1.1719e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 8.7149e-05
# Epoch 31: val_loss did not improve from 0.00012
# 69/69 [==============================] - 1s 16ms/step - loss: 8.7149e-05 - val_loss: 1.2486e-04
# Epoch 32/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.7945e-05
# Epoch 32: val_loss did not improve from 0.00012
# 69/69 [==============================] - 1s 14ms/step - loss: 8.8747e-05 - val_loss: 2.1945e-04
# Epoch 33/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.0878e-05
# Epoch 33: val_loss did not improve from 0.00012
# 69/69 [==============================] - 1s 14ms/step - loss: 8.2469e-05 - val_loss: 1.2946e-04
# Epoch 34/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.4537e-05
# Epoch 34: val_loss improved from 0.00012 to 0.00011, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 9.3162e-05 - val_loss: 1.1498e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.5381e-05
# Epoch 35: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 13ms/step - loss: 7.4703e-05 - val_loss: 1.1601e-04
# Epoch 36/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.7798e-05
# Epoch 36: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 8.0246e-05 - val_loss: 1.4924e-04
# Epoch 37/100
# 69/69 [==============================] - ETA: 0s - loss: 7.2852e-05
# Epoch 37: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 7.2852e-05 - val_loss: 1.5737e-04
# Epoch 38/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.8413e-05
# Epoch 38: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 7.8028e-05 - val_loss: 1.1667e-04
# Epoch 39/100
# 69/69 [==============================] - ETA: 0s - loss: 9.9901e-05
# Epoch 39: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 9.9901e-05 - val_loss: 1.4228e-04
# Epoch 40/100
# 65/69 [===========================>..] - ETA: 0s - loss: 7.1901e-05
# Epoch 40: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 7.3330e-05 - val_loss: 1.3381e-04
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 8.9138e-05
# Epoch 41: val_loss improved from 0.00011 to 0.00011, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 8.9138e-05 - val_loss: 1.0913e-04
# Epoch 42/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.8002e-05
# Epoch 42: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 8.6377e-05 - val_loss: 1.1630e-04
# Epoch 43/100
# 69/69 [==============================] - ETA: 0s - loss: 7.1847e-05
# Epoch 43: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 7.1847e-05 - val_loss: 1.2268e-04
# Epoch 44/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.0864e-05
# Epoch 44: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 15ms/step - loss: 7.0525e-05 - val_loss: 1.1274e-04
# Epoch 45/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.4256e-05
# Epoch 45: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 15ms/step - loss: 7.3763e-05 - val_loss: 1.1079e-04
# Epoch 46/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.4679e-05
# Epoch 46: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 15ms/step - loss: 7.4863e-05 - val_loss: 1.4211e-04
# Epoch 47/100
# 67/69 [============================>.] - ETA: 0s - loss: 6.7056e-05
# Epoch 47: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 6.6258e-05 - val_loss: 1.1187e-04
# Epoch 48/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.0914e-04
# Epoch 48: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 15ms/step - loss: 1.0949e-04 - val_loss: 2.3875e-04
# Epoch 49/100
# 69/69 [==============================] - ETA: 0s - loss: 7.5408e-05
# Epoch 49: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 7.5408e-05 - val_loss: 1.1084e-04
# Epoch 50/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.0958e-05
# Epoch 50: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 9.2964e-05 - val_loss: 1.1165e-04
# Epoch 51/100
# 69/69 [==============================] - ETA: 0s - loss: 9.9645e-05
# Epoch 51: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 14ms/step - loss: 9.9645e-05 - val_loss: 1.3400e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:6778.042317111854
# [19888.227935952873, 6778.042317111854]
# Epoch 1/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 1: val_loss improved from inf to 0.02568, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 5s 30ms/step - loss: 0.0067 - val_loss: 0.0257
# Epoch 2/100
# 104/104 [==============================] - ETA: 0s - loss: 2.9005e-04
# Epoch 2: val_loss improved from 0.02568 to 0.01033, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 3s 26ms/step - loss: 2.9005e-04 - val_loss: 0.0103
# Epoch 3/100
# 104/104 [==============================] - ETA: 0s - loss: 1.6780e-04
# Epoch 3: val_loss improved from 0.01033 to 0.00941, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 1.6780e-04 - val_loss: 0.0094
# Epoch 4/100
# 102/104 [============================>.] - ETA: 0s - loss: 1.4184e-04
# Epoch 4: val_loss improved from 0.00941 to 0.00900, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 1.4180e-04 - val_loss: 0.0090
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 1.3157e-04
# Epoch 5: val_loss improved from 0.00900 to 0.00768, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 16ms/step - loss: 1.3138e-04 - val_loss: 0.0077
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 1.0315e-04
# Epoch 6: val_loss improved from 0.00768 to 0.00748, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 1.0313e-04 - val_loss: 0.0075
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 9.1196e-05
# Epoch 7: val_loss did not improve from 0.00748
# 104/104 [==============================] - 2s 15ms/step - loss: 9.1196e-05 - val_loss: 0.0078
# Epoch 8/100
# 101/104 [============================>.] - ETA: 0s - loss: 7.9148e-05
# Epoch 8: val_loss improved from 0.00748 to 0.00593, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 7.8956e-05 - val_loss: 0.0059
# Epoch 9/100
# 101/104 [============================>.] - ETA: 0s - loss: 8.6811e-05
# Epoch 9: val_loss did not improve from 0.00593
# 104/104 [==============================] - 2s 15ms/step - loss: 8.5875e-05 - val_loss: 0.0066
# Epoch 10/100
# 104/104 [==============================] - ETA: 0s - loss: 6.6166e-05
# Epoch 10: val_loss did not improve from 0.00593
# 104/104 [==============================] - 1s 14ms/step - loss: 6.6166e-05 - val_loss: 0.0065
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.1615e-05
# Epoch 11: val_loss did not improve from 0.00593
# 104/104 [==============================] - 1s 14ms/step - loss: 7.1621e-05 - val_loss: 0.0062
# Epoch 12/100
# 104/104 [==============================] - ETA: 0s - loss: 6.4353e-05
# Epoch 12: val_loss improved from 0.00593 to 0.00563, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 6.4353e-05 - val_loss: 0.0056
# Epoch 13/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.6398e-05
# Epoch 13: val_loss improved from 0.00563 to 0.00497, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 6.6171e-05 - val_loss: 0.0050
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.6672e-05
# Epoch 14: val_loss did not improve from 0.00497
# 104/104 [==============================] - 2s 15ms/step - loss: 5.7269e-05 - val_loss: 0.0052
# Epoch 15/100
# 104/104 [==============================] - ETA: 0s - loss: 5.7110e-05
# Epoch 15: val_loss improved from 0.00497 to 0.00384, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 5.7110e-05 - val_loss: 0.0038
# Epoch 16/100
# 101/104 [============================>.] - ETA: 0s - loss: 6.4556e-05
# Epoch 16: val_loss did not improve from 0.00384
# 104/104 [==============================] - 1s 14ms/step - loss: 6.4017e-05 - val_loss: 0.0041
# Epoch 17/100
# 104/104 [==============================] - ETA: 0s - loss: 5.9755e-05
# Epoch 17: val_loss improved from 0.00384 to 0.00332, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 14ms/step - loss: 5.9755e-05 - val_loss: 0.0033
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 5.3558e-05
# Epoch 18: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 15ms/step - loss: 5.3558e-05 - val_loss: 0.0040
# Epoch 19/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.0202e-05
# Epoch 19: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 15ms/step - loss: 5.0423e-05 - val_loss: 0.0034
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.7107e-05
# Epoch 20: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 14ms/step - loss: 4.6859e-05 - val_loss: 0.0036
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 4.6197e-05
# Epoch 21: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6197e-05 - val_loss: 0.0033
# Epoch 22/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.5067e-05
# Epoch 22: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 15ms/step - loss: 4.4898e-05 - val_loss: 0.0036
# Epoch 23/100
# 104/104 [==============================] - ETA: 0s - loss: 4.6334e-05
# Epoch 23: val_loss did not improve from 0.00332
# 104/104 [==============================] - 1s 14ms/step - loss: 4.6334e-05 - val_loss: 0.0038
# Epoch 24/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.9644e-05
# Epoch 24: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 14ms/step - loss: 4.9555e-05 - val_loss: 0.0034
# Epoch 25/100
# 104/104 [==============================] - ETA: 0s - loss: 4.2567e-05
# Epoch 25: val_loss did not improve from 0.00332
# 104/104 [==============================] - 2s 15ms/step - loss: 4.2567e-05 - val_loss: 0.0038
# Epoch 26/100
# 104/104 [==============================] - ETA: 0s - loss: 5.4130e-05
# Epoch 26: val_loss improved from 0.00332 to 0.00285, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 19ms/step - loss: 5.4130e-05 - val_loss: 0.0028
# Epoch 27/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.8380e-05
# Epoch 27: val_loss did not improve from 0.00285
# 104/104 [==============================] - 2s 15ms/step - loss: 4.8128e-05 - val_loss: 0.0029
# Epoch 28/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.2811e-05
# Epoch 28: val_loss improved from 0.00285 to 0.00257, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 4.3284e-05 - val_loss: 0.0026
# Epoch 29/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.7310e-05
# Epoch 29: val_loss did not improve from 0.00257
# 104/104 [==============================] - 2s 15ms/step - loss: 5.8036e-05 - val_loss: 0.0032
# Epoch 30/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.3434e-05
# Epoch 30: val_loss did not improve from 0.00257
# 104/104 [==============================] - 2s 15ms/step - loss: 4.3283e-05 - val_loss: 0.0029
# Epoch 31/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.4680e-05
# Epoch 31: val_loss did not improve from 0.00257
# 104/104 [==============================] - 2s 15ms/step - loss: 4.4439e-05 - val_loss: 0.0030
# Epoch 32/100
# 103/104 [============================>.] - ETA: 0s - loss: 5.8391e-05
# Epoch 32: val_loss did not improve from 0.00257
# 104/104 [==============================] - 2s 15ms/step - loss: 5.9352e-05 - val_loss: 0.0027
# Epoch 33/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.4395e-05
# Epoch 33: val_loss did not improve from 0.00257
# 104/104 [==============================] - 1s 14ms/step - loss: 4.4341e-05 - val_loss: 0.0029
# Epoch 34/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.6632e-05
# Epoch 34: val_loss did not improve from 0.00257
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6725e-05 - val_loss: 0.0027
# Epoch 35/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1103e-05
# Epoch 35: val_loss improved from 0.00257 to 0.00215, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 4.1103e-05 - val_loss: 0.0021
# Epoch 36/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.9441e-05
# Epoch 36: val_loss did not improve from 0.00215
# 104/104 [==============================] - 2s 15ms/step - loss: 5.0128e-05 - val_loss: 0.0030
# Epoch 37/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.6558e-05
# Epoch 37: val_loss did not improve from 0.00215
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6194e-05 - val_loss: 0.0025
# Epoch 38/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.7341e-05
# Epoch 38: val_loss did not improve from 0.00215
# 104/104 [==============================] - 1s 14ms/step - loss: 3.7269e-05 - val_loss: 0.0028
# Epoch 39/100
# 102/104 [============================>.] - ETA: 0s - loss: 5.1670e-05
# Epoch 39: val_loss did not improve from 0.00215
# 104/104 [==============================] - 1s 14ms/step - loss: 5.1591e-05 - val_loss: 0.0031
# Epoch 40/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.5683e-05
# Epoch 40: val_loss improved from 0.00215 to 0.00197, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 4.5885e-05 - val_loss: 0.0020
# Epoch 41/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.1074e-05
# Epoch 41: val_loss improved from 0.00197 to 0.00154, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 2s 15ms/step - loss: 4.1817e-05 - val_loss: 0.0015
# Epoch 42/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.5513e-05
# Epoch 42: val_loss did not improve from 0.00154
# 104/104 [==============================] - 1s 14ms/step - loss: 4.5029e-05 - val_loss: 0.0019
# Epoch 43/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.1258e-05
# Epoch 43: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.1259e-05 - val_loss: 0.0021
# Epoch 44/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.6900e-05
# Epoch 44: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6604e-05 - val_loss: 0.0031
# Epoch 45/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4417e-05
# Epoch 45: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.4417e-05 - val_loss: 0.0026
# Epoch 46/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.2147e-05
# Epoch 46: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.1968e-05 - val_loss: 0.0021
# Epoch 47/100
# 101/104 [============================>.] - ETA: 0s - loss: 4.3855e-05
# Epoch 47: val_loss did not improve from 0.00154
# 104/104 [==============================] - 1s 14ms/step - loss: 4.3568e-05 - val_loss: 0.0024
# Epoch 48/100
# 104/104 [==============================] - ETA: 0s - loss: 4.7518e-05
# Epoch 48: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 23ms/step - loss: 4.7518e-05 - val_loss: 0.0027
# Epoch 49/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.6574e-05
# Epoch 49: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.6200e-05 - val_loss: 0.0025
# Epoch 50/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.0393e-05
# Epoch 50: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 15ms/step - loss: 4.0258e-05 - val_loss: 0.0016
# Epoch 51/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.8890e-05
# Epoch 51: val_loss did not improve from 0.00154
# 104/104 [==============================] - 2s 14ms/step - loss: 3.8375e-05 - val_loss: 0.0021
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:17683.264727048205
# [19888.227935952873, 6778.042317111854, 17683.264727048205]
# Epoch 1/100
# 136/139 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 1: val_loss improved from inf to 0.00032, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 3.1772e-04
# Epoch 2/100
# 139/139 [==============================] - ETA: 0s - loss: 7.7359e-05
# Epoch 2: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 7.7359e-05 - val_loss: 5.7320e-04
# Epoch 3/100
# 136/139 [============================>.] - ETA: 0s - loss: 6.7905e-05
# Epoch 3: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 6.7594e-05 - val_loss: 4.2203e-04
# Epoch 4/100
# 139/139 [==============================] - ETA: 0s - loss: 5.2116e-05
# Epoch 4: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 15ms/step - loss: 5.2116e-05 - val_loss: 5.9633e-04
# Epoch 5/100
# 136/139 [============================>.] - ETA: 0s - loss: 4.3411e-05
# Epoch 5: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 15ms/step - loss: 4.3175e-05 - val_loss: 5.0242e-04
# Epoch 6/100
# 136/139 [============================>.] - ETA: 0s - loss: 4.0863e-05
# Epoch 6: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 15ms/step - loss: 4.0529e-05 - val_loss: 5.9231e-04
# Epoch 7/100
# 136/139 [============================>.] - ETA: 0s - loss: 3.9494e-05
# Epoch 7: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 15ms/step - loss: 3.9516e-05 - val_loss: 5.6948e-04
# Epoch 8/100
# 137/139 [============================>.] - ETA: 0s - loss: 3.8295e-05
# Epoch 8: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 3.7973e-05 - val_loss: 5.8571e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 3.5969e-05
# Epoch 9: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 3.5973e-05 - val_loss: 5.2876e-04
# Epoch 10/100
# 137/139 [============================>.] - ETA: 0s - loss: 3.3506e-05
# Epoch 10: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 3.3272e-05 - val_loss: 4.6002e-04
# Epoch 11/100
# 137/139 [============================>.] - ETA: 0s - loss: 3.6157e-05
# Epoch 11: val_loss did not improve from 0.00032
# 139/139 [==============================] - 2s 16ms/step - loss: 3.5977e-05 - val_loss: 7.3254e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:18703.338040624356
# [19888.227935952873, 6778.042317111854, 17683.264727048205, 18703.338040624356]
# Epoch 1/100
# 174/174 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 1: val_loss improved from inf to 0.00023, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 6s 19ms/step - loss: 0.0017 - val_loss: 2.2763e-04
# Epoch 2/100
# 172/174 [============================>.] - ETA: 0s - loss: 1.1591e-04
# Epoch 2: val_loss improved from 0.00023 to 0.00015, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 1.1607e-04 - val_loss: 1.4888e-04
# Epoch 3/100
# 171/174 [============================>.] - ETA: 0s - loss: 7.7894e-05
# Epoch 3: val_loss improved from 0.00015 to 0.00011, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 7.7417e-05 - val_loss: 1.1025e-04
# Epoch 4/100
# 174/174 [==============================] - ETA: 0s - loss: 6.2535e-05
# Epoch 4: val_loss improved from 0.00011 to 0.00006, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 16ms/step - loss: 6.2535e-05 - val_loss: 6.2637e-05
# Epoch 5/100
# 172/174 [============================>.] - ETA: 0s - loss: 4.7576e-05
# Epoch 5: val_loss improved from 0.00006 to 0.00005, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 16ms/step - loss: 4.7466e-05 - val_loss: 4.9163e-05
# Epoch 6/100
# 171/174 [============================>.] - ETA: 0s - loss: 4.0987e-05
# Epoch 6: val_loss improved from 0.00005 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 16ms/step - loss: 4.0915e-05 - val_loss: 4.3841e-05
# Epoch 7/100
# 173/174 [============================>.] - ETA: 0s - loss: 3.5047e-05
# Epoch 7: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 17ms/step - loss: 3.5088e-05 - val_loss: 4.5519e-05
# Epoch 8/100
# 173/174 [============================>.] - ETA: 0s - loss: 3.2460e-05
# Epoch 8: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 3.2495e-05 - val_loss: 4.3863e-05
# Epoch 9/100
# 172/174 [============================>.] - ETA: 0s - loss: 3.5911e-05
# Epoch 9: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 3.5820e-05 - val_loss: 3.7900e-05
# Epoch 10/100
# 173/174 [============================>.] - ETA: 0s - loss: 3.5641e-05
# Epoch 10: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 15ms/step - loss: 3.5952e-05 - val_loss: 6.3521e-05
# Epoch 11/100
# 174/174 [==============================] - ETA: 0s - loss: 2.7034e-05
# Epoch 11: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 15ms/step - loss: 2.7034e-05 - val_loss: 4.2238e-05
# Epoch 12/100
# 173/174 [============================>.] - ETA: 0s - loss: 3.2281e-05
# Epoch 12: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 15ms/step - loss: 3.2262e-05 - val_loss: 5.9017e-05
# Epoch 13/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.7291e-05
# Epoch 13: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 2.7251e-05 - val_loss: 3.7620e-05
# Epoch 14/100
# 172/174 [============================>.] - ETA: 0s - loss: 3.2873e-05
# Epoch 14: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 15ms/step - loss: 3.3154e-05 - val_loss: 5.8369e-05
# Epoch 15/100
# 174/174 [==============================] - ETA: 0s - loss: 3.3048e-05
# Epoch 15: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 3.3048e-05 - val_loss: 1.0063e-04
# Epoch 16/100
# 174/174 [==============================] - ETA: 0s - loss: 2.4199e-05
# Epoch 16: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 15ms/step - loss: 2.4199e-05 - val_loss: 3.9061e-05
# Epoch 17/100
# 174/174 [==============================] - ETA: 0s - loss: 3.8064e-05
# Epoch 17: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 16ms/step - loss: 3.8064e-05 - val_loss: 3.6879e-05
# Epoch 18/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.6416e-05
# Epoch 18: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 2.6346e-05 - val_loss: 4.8951e-05
# Epoch 19/100
# 174/174 [==============================] - ETA: 0s - loss: 2.0267e-05
# Epoch 19: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 2.0267e-05 - val_loss: 3.9422e-05
# Epoch 20/100
# 171/174 [============================>.] - ETA: 0s - loss: 3.0026e-05
# Epoch 20: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 3.0118e-05 - val_loss: 3.8354e-05
# Epoch 21/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.1075e-05
# Epoch 21: val_loss did not improve from 0.00004
# 174/174 [==============================] - 3s 16ms/step - loss: 2.1083e-05 - val_loss: 4.9250e-05
# Epoch 22/100
# 172/174 [============================>.] - ETA: 0s - loss: 2.3514e-05
# Epoch 22: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 17ms/step - loss: 2.3441e-05 - val_loss: 3.3940e-05
# Epoch 23/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.6928e-05
# Epoch 23: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.6948e-05 - val_loss: 3.5156e-05
# Epoch 24/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.4300e-05
# Epoch 24: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.4501e-05 - val_loss: 4.1268e-05
# Epoch 25/100
# 174/174 [==============================] - ETA: 0s - loss: 2.2973e-05
# Epoch 25: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.2973e-05 - val_loss: 4.2217e-05
# Epoch 26/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.3753e-05
# Epoch 26: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.3679e-05 - val_loss: 9.5741e-05
# Epoch 27/100
# 172/174 [============================>.] - ETA: 0s - loss: 2.7710e-05
# Epoch 27: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.7775e-05 - val_loss: 6.5831e-05
# Epoch 28/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.2373e-05
# Epoch 28: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 17ms/step - loss: 2.2324e-05 - val_loss: 3.5765e-05
# Epoch 29/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.0492e-05
# Epoch 29: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 17ms/step - loss: 2.0817e-05 - val_loss: 5.9752e-05
# Epoch 30/100
# 172/174 [============================>.] - ETA: 0s - loss: 1.9902e-05
# Epoch 30: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 1.9833e-05 - val_loss: 7.6576e-05
# Epoch 31/100
# 174/174 [==============================] - ETA: 0s - loss: 2.3257e-05
# Epoch 31: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 16ms/step - loss: 2.3257e-05 - val_loss: 3.6780e-05
# Epoch 32/100
# 173/174 [============================>.] - ETA: 0s - loss: 1.9076e-05
# Epoch 32: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 17ms/step - loss: 1.9052e-05 - val_loss: 3.8202e-05
# 5000길이의 데이터 적용 완료
#  길이: 5000, RMSE:10220.264807664218
# [19888.227935952873, 6778.042317111854, 17683.264727048205, 18703.338040624356, 10220.264807664218]
# Epoch 1/100
# 206/209 [============================>.] - ETA: 0s - loss: 5.9061e-04
# Epoch 1: val_loss improved from inf to 0.00017, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 7s 20ms/step - loss: 5.8297e-04 - val_loss: 1.7220e-04
# Epoch 2/100
# 208/209 [============================>.] - ETA: 0s - loss: 6.6504e-05
# Epoch 2: val_loss improved from 0.00017 to 0.00013, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 16ms/step - loss: 6.6400e-05 - val_loss: 1.3225e-04
# Epoch 3/100
# 207/209 [============================>.] - ETA: 0s - loss: 3.9739e-05
# Epoch 3: val_loss improved from 0.00013 to 0.00010, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 16ms/step - loss: 3.9604e-05 - val_loss: 9.6498e-05
# Epoch 4/100
# 207/209 [============================>.] - ETA: 0s - loss: 2.8770e-05
# Epoch 4: val_loss improved from 0.00010 to 0.00008, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 4s 17ms/step - loss: 2.8804e-05 - val_loss: 7.5725e-05
# Epoch 5/100
# 206/209 [============================>.] - ETA: 0s - loss: 2.8773e-05
# Epoch 5: val_loss did not improve from 0.00008
# 209/209 [==============================] - 3s 16ms/step - loss: 2.8724e-05 - val_loss: 8.0328e-05
# Epoch 6/100
# 209/209 [==============================] - ETA: 0s - loss: 2.0736e-05
# Epoch 6: val_loss did not improve from 0.00008
# 209/209 [==============================] - 4s 17ms/step - loss: 2.0736e-05 - val_loss: 8.2714e-05
# Epoch 7/100
# 208/209 [============================>.] - ETA: 0s - loss: 2.0026e-05
# Epoch 7: val_loss did not improve from 0.00008
# 209/209 [==============================] - 3s 16ms/step - loss: 2.0028e-05 - val_loss: 8.6057e-05
# Epoch 8/100
# 206/209 [============================>.] - ETA: 0s - loss: 2.0080e-05
# Epoch 8: val_loss improved from 0.00008 to 0.00005, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 16ms/step - loss: 2.0061e-05 - val_loss: 5.0118e-05
# Epoch 9/100
# 207/209 [============================>.] - ETA: 0s - loss: 1.9195e-05
# Epoch 9: val_loss improved from 0.00005 to 0.00005, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 16ms/step - loss: 1.9146e-05 - val_loss: 4.9289e-05
# Epoch 10/100
# 206/209 [============================>.] - ETA: 0s - loss: 1.8036e-05
# Epoch 10: val_loss did not improve from 0.00005
# 209/209 [==============================] - 4s 17ms/step - loss: 1.8181e-05 - val_loss: 5.3444e-05
# Epoch 11/100
# 209/209 [==============================] - ETA: 0s - loss: 1.6650e-05
# Epoch 11: val_loss did not improve from 0.00005
# 209/209 [==============================] - 3s 16ms/step - loss: 1.6650e-05 - val_loss: 5.6401e-05
# Epoch 12/100
# 207/209 [============================>.] - ETA: 0s - loss: 1.7426e-05
# Epoch 12: val_loss improved from 0.00005 to 0.00004, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 15ms/step - loss: 1.7613e-05 - val_loss: 4.1730e-05
# Epoch 13/100
# 207/209 [============================>.] - ETA: 0s - loss: 1.6822e-05
# Epoch 13: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 16ms/step - loss: 1.6873e-05 - val_loss: 4.2993e-05
# Epoch 14/100
# 208/209 [============================>.] - ETA: 0s - loss: 1.4694e-05
# Epoch 14: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 16ms/step - loss: 1.4773e-05 - val_loss: 1.0569e-04
# Epoch 15/100
# 206/209 [============================>.] - ETA: 0s - loss: 1.4321e-05
# Epoch 15: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 15ms/step - loss: 1.4429e-05 - val_loss: 1.3618e-04
# Epoch 16/100
# 208/209 [============================>.] - ETA: 0s - loss: 1.6131e-05
# Epoch 16: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 16ms/step - loss: 1.6115e-05 - val_loss: 4.6467e-05
# Epoch 17/100
# 209/209 [==============================] - ETA: 0s - loss: 1.3141e-05
# Epoch 17: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 16ms/step - loss: 1.3141e-05 - val_loss: 7.3891e-05
# Epoch 18/100
# 208/209 [============================>.] - ETA: 0s - loss: 1.3358e-05
# Epoch 18: val_loss did not improve from 0.00004
# 209/209 [==============================] - 3s 16ms/step - loss: 1.3450e-05 - val_loss: 7.2124e-05
# Epoch 19/100
# 208/209 [============================>.] - ETA: 0s - loss: 1.5435e-05
# Epoch 19: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 17ms/step - loss: 1.5400e-05 - val_loss: 3.3276e-05
# Epoch 20/100
# 208/209 [============================>.] - ETA: 0s - loss: 1.2618e-05
# Epoch 20: val_loss did not improve from 0.00003
# 209/209 [==============================] - 3s 16ms/step - loss: 1.2655e-05 - val_loss: 3.4112e-05
# Epoch 21/100
# 209/209 [==============================] - ETA: 0s - loss: 1.1801e-05
# Epoch 21: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 209/209 [==============================] - 3s 16ms/step - loss: 1.1801e-05 - val_loss: 3.1150e-05
# Epoch 22/100
# 206/209 [============================>.] - ETA: 0s - loss: 1.4020e-05
# Epoch 22: val_loss did not improve from 0.00003
# 209/209 [==============================] - 4s 17ms/step - loss: 1.4138e-05 - val_loss: 1.3470e-04
# Epoch 23/100
# 206/209 [============================>.] - ETA: 0s - loss: 1.4481e-05
# Epoch 23: val_loss did not improve from 0.00003
# ...
# 314/314 [==============================] - 6s 18ms/step - loss: 5.2400e-06 - val_loss: 1.6960e-05
# Epoch 21/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.4164e-06
# Epoch 21: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 15ms/step - loss: 5.4302e-06 - val_loss: 4.9756e-05
# Epoch 22/100
# 313/314 [============================>.] - ETA: 0s - loss: 4.9440e-06
# Epoch 22: val_loss improved from 0.00001 to 0.00001, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 16ms/step - loss: 4.9394e-06 - val_loss: 1.4204e-05
# Epoch 23/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.3214e-06
# Epoch 23: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 5.3050e-06 - val_loss: 2.6532e-05
# Epoch 24/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.1068e-06
# Epoch 24: val_loss improved from 0.00001 to 0.00001, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 16ms/step - loss: 5.0998e-06 - val_loss: 1.3225e-05
# Epoch 25/100
# 314/314 [==============================] - ETA: 0s - loss: 4.6051e-06
# Epoch 25: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.6051e-06 - val_loss: 1.4500e-05
# Epoch 26/100
# 312/314 [============================>.] - ETA: 0s - loss: 4.6374e-06
# Epoch 26: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.6293e-06 - val_loss: 1.6917e-05
# Epoch 27/100
# 313/314 [============================>.] - ETA: 0s - loss: 4.6954e-06
# Epoch 27: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.6893e-06 - val_loss: 1.4261e-05
# Epoch 28/100
# 311/314 [============================>.] - ETA: 0s - loss: 4.4420e-06
# Epoch 28: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.4343e-06 - val_loss: 1.5163e-05
# Epoch 29/100
# 313/314 [============================>.] - ETA: 0s - loss: 3.8889e-06
# Epoch 29: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 3.8991e-06 - val_loss: 2.0977e-05
# Epoch 30/100
# 314/314 [==============================] - ETA: 0s - loss: 3.9454e-06
# Epoch 30: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 3.9454e-06 - val_loss: 1.8402e-05
# Epoch 31/100
# 313/314 [============================>.] - ETA: 0s - loss: 4.4125e-06
# Epoch 31: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.4208e-06 - val_loss: 1.4457e-05
# Epoch 32/100
# 312/314 [============================>.] - ETA: 0s - loss: 3.9365e-06
# Epoch 32: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 15ms/step - loss: 3.9415e-06 - val_loss: 2.5762e-05
# Epoch 33/100
# 311/314 [============================>.] - ETA: 0s - loss: 3.8048e-06
# Epoch 33: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 15ms/step - loss: 3.8101e-06 - val_loss: 1.4061e-05
# Epoch 34/100
# 314/314 [==============================] - ETA: 0s - loss: 4.6696e-06
# Epoch 34: val_loss did not improve from 0.00001
# 314/314 [==============================] - 5s 16ms/step - loss: 4.6696e-06 - val_loss: 1.6261e-05
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:23777.436071904067
# [19888.227935952873, 6778.042317111854, 17683.264727048205, 18703.338040624356, 10220.264807664218, 7303.492998968487, 20274.116054615228, 13674.863576175687, 23777.436071904067]
# Epoch 1/100
# 340/341 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 1: val_loss improved from inf to 0.00164, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 11s 24ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 2/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.3385e-04
# Epoch 2: val_loss improved from 0.00164 to 0.00101, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 1.3366e-04 - val_loss: 0.0010
# Epoch 3/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.3940e-05
# Epoch 3: val_loss improved from 0.00101 to 0.00046, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 6.3898e-05 - val_loss: 4.5915e-04
# Epoch 4/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.9721e-05
# Epoch 4: val_loss improved from 0.00046 to 0.00037, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 3.9707e-05 - val_loss: 3.7136e-04
# Epoch 5/100
# 341/341 [==============================] - ETA: 0s - loss: 2.9169e-05
# Epoch 5: val_loss improved from 0.00037 to 0.00033, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 2.9169e-05 - val_loss: 3.2837e-04
# Epoch 6/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.2318e-05
# Epoch 6: val_loss improved from 0.00033 to 0.00030, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 2.2306e-05 - val_loss: 3.0440e-04
# Epoch 7/100
# 341/341 [==============================] - ETA: 0s - loss: 1.7393e-05
# Epoch 7: val_loss did not improve from 0.00030
# 341/341 [==============================] - 7s 22ms/step - loss: 1.7393e-05 - val_loss: 3.2941e-04
# Epoch 8/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.6721e-05
# Epoch 8: val_loss did not improve from 0.00030
# 341/341 [==============================] - 7s 21ms/step - loss: 1.6774e-05 - val_loss: 3.5067e-04
# Epoch 9/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.3050e-05
# Epoch 9: val_loss did not improve from 0.00030
# 341/341 [==============================] - 7s 22ms/step - loss: 1.3055e-05 - val_loss: 3.6392e-04
# Epoch 10/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.1282e-05
# Epoch 10: val_loss did not improve from 0.00030
# 341/341 [==============================] - 7s 22ms/step - loss: 1.1311e-05 - val_loss: 3.1685e-04
# Epoch 11/100
# 341/341 [==============================] - ETA: 0s - loss: 1.0649e-05
# Epoch 11: val_loss did not improve from 0.00030
# 341/341 [==============================] - 7s 22ms/step - loss: 1.0649e-05 - val_loss: 3.2749e-04
# Epoch 12/100
# 341/341 [==============================] - ETA: 0s - loss: 9.0646e-06
# Epoch 12: val_loss improved from 0.00030 to 0.00029, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 9.0646e-06 - val_loss: 2.9309e-04
# Epoch 13/100
# 339/341 [============================>.] - ETA: 0s - loss: 8.1594e-06
# Epoch 13: val_loss improved from 0.00029 to 0.00025, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 8.1437e-06 - val_loss: 2.4951e-04
# Epoch 14/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.3537e-06
# Epoch 14: val_loss improved from 0.00025 to 0.00024, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 7.3737e-06 - val_loss: 2.4494e-04
# Epoch 15/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.6578e-06
# Epoch 15: val_loss did not improve from 0.00024
# 341/341 [==============================] - 8s 22ms/step - loss: 7.6745e-06 - val_loss: 3.0656e-04
# Epoch 16/100
# 339/341 [============================>.] - ETA: 0s - loss: 6.4086e-06
# Epoch 16: val_loss improved from 0.00024 to 0.00021, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 6.4047e-06 - val_loss: 2.1381e-04
# Epoch 17/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.9831e-06
# Epoch 17: val_loss improved from 0.00021 to 0.00018, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 7.9598e-06 - val_loss: 1.7900e-04
# Epoch 18/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.0014e-06
# Epoch 18: val_loss did not improve from 0.00018
# 341/341 [==============================] - 7s 22ms/step - loss: 6.0016e-06 - val_loss: 1.9833e-04
# Epoch 19/100
# 341/341 [==============================] - ETA: 0s - loss: 5.8824e-06
# Epoch 19: val_loss did not improve from 0.00018
# 341/341 [==============================] - 7s 22ms/step - loss: 5.8824e-06 - val_loss: 2.0015e-04
# Epoch 20/100
# 341/341 [==============================] - ETA: 0s - loss: 6.0024e-06
# Epoch 20: val_loss improved from 0.00018 to 0.00012, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 6.0024e-06 - val_loss: 1.1521e-04
# Epoch 21/100
# 341/341 [==============================] - ETA: 0s - loss: 5.3594e-06
# Epoch 21: val_loss improved from 0.00012 to 0.00011, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 7s 22ms/step - loss: 5.3594e-06 - val_loss: 1.0576e-04
# Epoch 22/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.1646e-06
# Epoch 22: val_loss did not improve from 0.00011
# 341/341 [==============================] - 8s 22ms/step - loss: 5.1636e-06 - val_loss: 1.7196e-04
# Epoch 23/100
# 341/341 [==============================] - ETA: 0s - loss: 5.1344e-06
# Epoch 23: val_loss did not improve from 0.00011
# 341/341 [==============================] - 7s 22ms/step - loss: 5.1344e-06 - val_loss: 1.7450e-04
# Epoch 24/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.6525e-06
# Epoch 24: val_loss improved from 0.00011 to 0.00010, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 4.6640e-06 - val_loss: 9.6078e-05
# Epoch 25/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.1930e-06
# Epoch 25: val_loss did not improve from 0.00010
# 341/341 [==============================] - 8s 22ms/step - loss: 4.1913e-06 - val_loss: 1.2153e-04
# Epoch 26/100
# 341/341 [==============================] - ETA: 0s - loss: 4.8859e-06
# Epoch 26: val_loss did not improve from 0.00010
# 341/341 [==============================] - 8s 22ms/step - loss: 4.8859e-06 - val_loss: 1.1153e-04
# Epoch 27/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.9762e-06
# Epoch 27: val_loss improved from 0.00010 to 0.00008, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 3.9790e-06 - val_loss: 7.7617e-05
# Epoch 28/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.5507e-06
# Epoch 28: val_loss improved from 0.00008 to 0.00005, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 4.5422e-06 - val_loss: 4.8754e-05
# Epoch 29/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5558e-06
# Epoch 29: val_loss improved from 0.00005 to 0.00004, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 3.5591e-06 - val_loss: 3.5586e-05
# Epoch 30/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5168e-06
# Epoch 30: val_loss did not improve from 0.00004
# 341/341 [==============================] - 8s 22ms/step - loss: 3.5112e-06 - val_loss: 4.9048e-05
# Epoch 31/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5856e-06
# Epoch 31: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 3.5808e-06 - val_loss: 3.4193e-05
# Epoch 32/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4323e-06
# Epoch 32: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 21ms/step - loss: 3.4323e-06 - val_loss: 5.9836e-05
# Epoch 33/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.0711e-06
# Epoch 33: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 3.0736e-06 - val_loss: 7.4332e-05
# Epoch 34/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.3140e-06
# Epoch 34: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 3.3135e-06 - val_loss: 1.1918e-04
# Epoch 35/100
# 341/341 [==============================] - ETA: 0s - loss: 3.5606e-06
# Epoch 35: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 3.5606e-06 - val_loss: 3.8112e-05
# Epoch 36/100
# 341/341 [==============================] - ETA: 0s - loss: 2.8599e-06
# Epoch 36: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 22ms/step - loss: 2.8599e-06 - val_loss: 3.0909e-05
# Epoch 37/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.1404e-06
# Epoch 37: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 3.1387e-06 - val_loss: 3.2572e-05
# Epoch 38/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2441e-06
# Epoch 38: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 3.2441e-06 - val_loss: 6.6561e-05
# Epoch 39/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5779e-06
# Epoch 39: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 2.5779e-06 - val_loss: 2.6923e-05
# Epoch 40/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2175e-06
# Epoch 40: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 3.2175e-06 - val_loss: 6.4996e-05
# Epoch 41/100
# 341/341 [==============================] - ETA: 0s - loss: 2.9445e-06
# Epoch 41: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 22ms/step - loss: 2.9445e-06 - val_loss: 1.4461e-04
# Epoch 42/100
# 341/341 [==============================] - ETA: 0s - loss: 3.2492e-06
# Epoch 42: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 3.2492e-06 - val_loss: 4.5602e-05
# Epoch 43/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.8865e-06
# Epoch 43: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 2.8877e-06 - val_loss: 4.9263e-05
# Epoch 44/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5284e-06
# Epoch 44: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 2.5284e-06 - val_loss: 5.3829e-05
# Epoch 45/100
# 341/341 [==============================] - ETA: 0s - loss: 2.6422e-06
# Epoch 45: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 2.6422e-06 - val_loss: 5.5248e-05
# Epoch 46/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.7623e-06
# Epoch 46: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 21ms/step - loss: 2.7623e-06 - val_loss: 5.8276e-05
# Epoch 47/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5308e-06
# Epoch 47: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 21ms/step - loss: 2.5308e-06 - val_loss: 5.2991e-05
# Epoch 48/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.4001e-06
# Epoch 48: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 3.4000e-06 - val_loss: 7.2449e-05
# Epoch 49/100
# 339/341 [============================>.] - ETA: 0s - loss: 2.4378e-06
# Epoch 49: val_loss did not improve from 0.00003
# 341/341 [==============================] - 7s 22ms/step - loss: 2.4317e-06 - val_loss: 2.7395e-05
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:3849.6271157020033
# [19888.227935952873, 6778.042317111854, 17683.264727048205, 18703.338040624356, 10220.264807664218, 7303.492998968487, 20274.116054615228, 13674.863576175687, 23777.436071904067, 3849.6271157020033]

# %%
# !pip install ta

# %%
tmp = min(result)
index = result.index(tmp)
(index + 1)*1000
# Out:
# 10000

# %%
import matplotlib.pyplot as plt
plt.plot(result)

# %%
result
# Out:
# [19888.227935952873,
#  6778.042317111854,
#  17683.264727048205,
#  18703.338040624356,
#  10220.264807664218,
#  7303.492998968487,
#  20274.116054615228,
#  13674.863576175687,
#  23777.436071904067,
#  3849.6271157020033]

# %%
predict
# Out:
# [array([[58248.15]], dtype=float32),
#  array([[64257.8]], dtype=float32),
#  array([[50958.117]], dtype=float32),
#  array([[52953.41]], dtype=float32),
#  array([[54098.51]], dtype=float32),
#  array([[62213.53]], dtype=float32),
#  array([[56936.93]], dtype=float32),
#  array([[42914.918]], dtype=float32),
#  array([[36553.656]], dtype=float32),
#  array([[61240.695]], dtype=float32)]

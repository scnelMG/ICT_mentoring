# %% [markdown]
# # LSTM
#
# ## [금융] KB금융
#
# ### 1층
#
# #### 정답 : 58,200
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |3000              |1198.52|60818|X
# 64   |x        |3000              |1217.53|61107|X
# 128  |x        |4000              |1322.74|60166|O
# 16   |0.2      |3000              |4396.87|60441|X
# 64   |0.2      |2000              |4274.25|55186|O
# 128  |0.2      |3000              |5186.96|53787|X
# 16   |0.3      |3000              |3822.53|53020|X
# 64   |0.3      |3000              |6536.46|51494|O
# 128  |0.3      |3000              |6856.42|51063|X
#
#
# ### 2층
#
# #### 정답 : 58,200
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |4000              |1126.07|59233|O
# 64   |x        |3000              |1150.24|60956|X
# 128  |x        |3000              |1102.85|61084|X
# 16   |0.2      |2000              |3641.21|55668|X
# 64   |0.2      |3000              |4426.36|55199|O
# 128  |0.2      |3000              |5071.13|55190|O
# 16   |0.3      |3000              |6294.30|51528|O
# 64   |0.3      |4000              |6643.28|49897|X
# 128  |0.3      |3000              |6907.70|51242|O

# %% [markdown]
# ## [경기관련소비재] 현대차
#
# ### 1층
#
# #### 정답 : 187,500
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |6000          |3811.95|193644|X
# 64   |x        |7000          |4179.96|186326|O
# 128  |x        |5000          |4987.46|193447|X
# 16   |0.2      |7000          |18589.07|184150|O
# 64   |0.2      |8000          |23005.81|167483|X
# 128  |0.2      |5000          |33099.16|159853|O
# 16   |0.3      |4000          |38960.01|155268|O
# 64   |0.3      |10000          |31882.56|142296|X
# 128  |0.3      |6000          |4540.30|196384|X
#
#
# ### 2층
#
# #### 정답 : 187,500
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |4000          |5612.31|204186|X
# 64   |x        |4000          |4641.88|195288|X
# 128  |x        |5000          |4255.29|194140|X
# 16   |0.2      |4000          |27696.37|172612|O
# 64   |0.2      |6000          |28194.69|164574|X
# 128  |0.2      |5000          |29722.59|162789|X
# 16   |0.3      |7000          |40195.96|175145|O
# 64   |0.3      |5000          |47014.07|142403|X
# 128  |0.3      |10000         |44414.54|168296|X

# %% [markdown]
# ## [건강관리] 삼성바이오로직스
#
# ### 1층
#
# #### 정답 : 843,000
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |1000|72613|843728|O
# 64   |x        |1000|60406.49|841005|O
# 128  |x        |2000|26047.60|893071|X
# 16   |0.2      |2000|80246.04|823224|O
# 64   |0.2      |2000|106839.91|853552|O
# 128  |0.2      |1000|150574.54|756635|O
# 16   |0.3      |2000|214904.15|650415|X
# 64   |0.3      |1000|224423.99|663672|O
# 128  |0.3      |1000|214096.86|650829|O
#
#
# ### 2층
#
# #### 정답 : 843,000
#
# unit | dropout | 최적의 변수 개수 | RMSE | 결과 | 다른 결과와 비교해서 정답데이터와 가장 가까운가?
# -----|---------|------------------|------|------|--------------------------------------------------
# 16   |x        |1000|40546.33|802924|O
# 64   |x        |1000|25551.04|826924|O
# 128  |x        |1000|57299.15|795671|X
# 16   |0.2      |1000|153961.05|733367|O
# 64   |0.2      |2000|150862.01|731937|O
# 128  |0.2      |1000|93640.39|776898|O
# 16   |0.3      |2000|225822.57|595171|X
# 64   |0.3      |1000|184010.75|608317|X
# 128  |0.3      |1000|210430|634856|O

# %%
# !pip install ta
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout,GRU
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("/content/[IT]삼성전자.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf


for i in range(1, len(df)//1000+2):

        # 데이터 불러오기
        df_copy = df
     
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()
        model.add(GRU(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences = True,
                      activation='relu'))
        model.add(GRU(16, return_sequences=False, stateful=False))
        model.add(Dense(1))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /usr/local/lib/python3.7/dist-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# Epoch 1/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0430
# Epoch 1: val_loss improved from inf to 0.06229, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 9s 95ms/step - loss: 0.0419 - val_loss: 0.0623
# Epoch 2/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 2: val_loss improved from 0.06229 to 0.03914, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0027 - val_loss: 0.0391
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 3: val_loss improved from 0.03914 to 0.03792, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 0.0379
# Epoch 4/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 4: val_loss improved from 0.03792 to 0.03110, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 0.0311
# Epoch 5/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 5: val_loss improved from 0.03110 to 0.02465, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 0.0246
# Epoch 6/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss improved from 0.02465 to 0.02350, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 0.0235
# Epoch 7/100
# 30/34 [=========================>....] - ETA: 0s - loss: 9.9851e-04
# Epoch 7: val_loss improved from 0.02350 to 0.01424, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0142
# Epoch 8/100
# 31/34 [==========================>...] - ETA: 0s - loss: 8.6743e-04
# Epoch 8: val_loss improved from 0.01424 to 0.01326, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 8.3664e-04 - val_loss: 0.0133
# Epoch 9/100
# 31/34 [==========================>...] - ETA: 0s - loss: 6.0975e-04
# Epoch 9: val_loss improved from 0.01326 to 0.01063, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 6.0052e-04 - val_loss: 0.0106
# Epoch 10/100
# 33/34 [============================>.] - ETA: 0s - loss: 4.5572e-04
# Epoch 10: val_loss improved from 0.01063 to 0.00630, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 4.7409e-04 - val_loss: 0.0063
# Epoch 11/100
# 30/34 [=========================>....] - ETA: 0s - loss: 4.2747e-04
# Epoch 11: val_loss improved from 0.00630 to 0.00449, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 4.1693e-04 - val_loss: 0.0045
# Epoch 12/100
# 33/34 [============================>.] - ETA: 0s - loss: 3.5764e-04
# Epoch 12: val_loss improved from 0.00449 to 0.00407, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 3.5246e-04 - val_loss: 0.0041
# Epoch 13/100
# 31/34 [==========================>...] - ETA: 0s - loss: 3.2497e-04
# Epoch 13: val_loss did not improve from 0.00407
# 34/34 [==============================] - 0s 13ms/step - loss: 3.2084e-04 - val_loss: 0.0043
# Epoch 14/100
# 30/34 [=========================>....] - ETA: 0s - loss: 3.0945e-04
# Epoch 14: val_loss improved from 0.00407 to 0.00255, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 3.0950e-04 - val_loss: 0.0025
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0045e-04
# Epoch 15: val_loss did not improve from 0.00255
# 34/34 [==============================] - 0s 14ms/step - loss: 3.0045e-04 - val_loss: 0.0045
# Epoch 16/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.7474e-04
# Epoch 16: val_loss did not improve from 0.00255
# 34/34 [==============================] - 0s 13ms/step - loss: 2.8139e-04 - val_loss: 0.0032
# Epoch 17/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.3576e-04
# Epoch 17: val_loss did not improve from 0.00255
# 34/34 [==============================] - 0s 13ms/step - loss: 2.3696e-04 - val_loss: 0.0029
# Epoch 18/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.3012e-04
# Epoch 18: val_loss improved from 0.00255 to 0.00222, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 2.3200e-04 - val_loss: 0.0022
# Epoch 19/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.2429e-04
# Epoch 19: val_loss did not improve from 0.00222
# 34/34 [==============================] - 0s 13ms/step - loss: 2.2593e-04 - val_loss: 0.0028
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.1700e-04
# Epoch 20: val_loss improved from 0.00222 to 0.00203, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 15ms/step - loss: 2.2077e-04 - val_loss: 0.0020
# Epoch 21/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.3864e-04
# Epoch 21: val_loss did not improve from 0.00203
# 34/34 [==============================] - 0s 14ms/step - loss: 2.4377e-04 - val_loss: 0.0036
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 2.1893e-04
# Epoch 22: val_loss did not improve from 0.00203
# 34/34 [==============================] - 1s 16ms/step - loss: 2.1893e-04 - val_loss: 0.0026
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 1.9125e-04
# Epoch 23: val_loss did not improve from 0.00203
# 34/34 [==============================] - 1s 16ms/step - loss: 1.9125e-04 - val_loss: 0.0029
# Epoch 24/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.9579e-04
# Epoch 24: val_loss improved from 0.00203 to 0.00174, saving model to model/tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 1.9747e-04 - val_loss: 0.0017
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 2.0372e-04
# Epoch 25: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 14ms/step - loss: 2.0372e-04 - val_loss: 0.0019
# Epoch 26/100
# 33/34 [============================>.] - ETA: 0s - loss: 1.7556e-04
# Epoch 26: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8175e-04 - val_loss: 0.0029
# Epoch 27/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.7126e-04
# Epoch 27: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 13ms/step - loss: 1.7855e-04 - val_loss: 0.0021
# Epoch 28/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.8367e-04
# Epoch 28: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8914e-04 - val_loss: 0.0033
# Epoch 29/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.5793e-04
# Epoch 29: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 13ms/step - loss: 1.6624e-04 - val_loss: 0.0026
# Epoch 30/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.6519e-04
# Epoch 30: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 13ms/step - loss: 1.6004e-04 - val_loss: 0.0023
# Epoch 31/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.6437e-04
# Epoch 31: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 13ms/step - loss: 1.5974e-04 - val_loss: 0.0025
# Epoch 32/100
# 31/34 [==========================>...] - ETA: 0s - loss: 1.9359e-04
# Epoch 32: val_loss did not improve from 0.00174
# 34/34 [==============================] - 0s 15ms/step - loss: 1.8386e-04 - val_loss: 0.0024
# Epoch 33/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.5645e-04
# Epoch 33: val_loss did not improve from 0.00174
# 34/34 [==============================] - 1s 15ms/step - loss: 1.5960e-04 - val_loss: 0.0023
# Epoch 34/100
# 32/34 [===========================>..] - ETA: 0s - loss: 1.5453e-04
# Epoch 34: val_loss did not improve from 0.00174
# 34/34 [==============================] - 1s 15ms/step - loss: 1.5715e-04 - val_loss: 0.0027
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:7851.155064087212
# [7851.155064087212]
# Epoch 1/100
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0122
# Epoch 1: val_loss improved from inf to 0.00187, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 4s 22ms/step - loss: 0.0116 - val_loss: 0.0019
# Epoch 2/100
# 65/69 [===========================>..] - ETA: 0s - loss: 6.9360e-04
# Epoch 2: val_loss improved from 0.00187 to 0.00071, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 6.7836e-04 - val_loss: 7.1250e-04
# Epoch 3/100
# 66/69 [===========================>..] - ETA: 0s - loss: 3.6201e-04
# Epoch 3: val_loss improved from 0.00071 to 0.00048, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 3.6130e-04 - val_loss: 4.7500e-04
# Epoch 4/100
# 67/69 [============================>.] - ETA: 0s - loss: 2.9810e-04
# Epoch 4: val_loss improved from 0.00048 to 0.00040, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 2.9751e-04 - val_loss: 4.0441e-04
# Epoch 5/100
# 68/69 [============================>.] - ETA: 0s - loss: 2.2963e-04
# Epoch 5: val_loss improved from 0.00040 to 0.00034, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 2.2979e-04 - val_loss: 3.3918e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 2.1774e-04
# Epoch 6: val_loss improved from 0.00034 to 0.00032, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 2.1774e-04 - val_loss: 3.2444e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.9890e-04
# Epoch 7: val_loss improved from 0.00032 to 0.00027, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 1.9927e-04 - val_loss: 2.6934e-04
# Epoch 8/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.8152e-04
# Epoch 8: val_loss improved from 0.00027 to 0.00024, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.7829e-04 - val_loss: 2.3603e-04
# Epoch 9/100
# 65/69 [===========================>..] - ETA: 0s - loss: 1.5797e-04
# Epoch 9: val_loss improved from 0.00024 to 0.00022, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.5955e-04 - val_loss: 2.1979e-04
# Epoch 10/100
# 65/69 [===========================>..] - ETA: 0s - loss: 1.5530e-04
# Epoch 10: val_loss improved from 0.00022 to 0.00020, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.5462e-04 - val_loss: 2.0374e-04
# Epoch 11/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.4152e-04
# Epoch 11: val_loss did not improve from 0.00020
# 69/69 [==============================] - 1s 13ms/step - loss: 1.4274e-04 - val_loss: 2.6115e-04
# Epoch 12/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.4003e-04
# Epoch 12: val_loss improved from 0.00020 to 0.00020, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.4169e-04 - val_loss: 2.0116e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 1.2613e-04
# Epoch 13: val_loss improved from 0.00020 to 0.00017, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 1.2613e-04 - val_loss: 1.7366e-04
# Epoch 14/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.3948e-04
# Epoch 14: val_loss improved from 0.00017 to 0.00016, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 1.4100e-04 - val_loss: 1.6268e-04
# Epoch 15/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.2670e-04
# Epoch 15: val_loss did not improve from 0.00016
# 69/69 [==============================] - 1s 13ms/step - loss: 1.2662e-04 - val_loss: 1.9107e-04
# Epoch 16/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.1688e-04
# Epoch 16: val_loss improved from 0.00016 to 0.00016, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 1.1719e-04 - val_loss: 1.5957e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 1.1209e-04
# Epoch 17: val_loss improved from 0.00016 to 0.00014, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1209e-04 - val_loss: 1.3891e-04
# Epoch 18/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.0836e-04
# Epoch 18: val_loss did not improve from 0.00014
# 69/69 [==============================] - 1s 13ms/step - loss: 1.0680e-04 - val_loss: 1.3921e-04
# Epoch 19/100
# 69/69 [==============================] - ETA: 0s - loss: 9.7986e-05
# Epoch 19: val_loss improved from 0.00014 to 0.00013, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 9.7986e-05 - val_loss: 1.3171e-04
# Epoch 20/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.0678e-05
# Epoch 20: val_loss improved from 0.00013 to 0.00013, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 9.0361e-05 - val_loss: 1.2537e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.0266e-05
# Epoch 21: val_loss did not improve from 0.00013
# 69/69 [==============================] - 1s 16ms/step - loss: 9.0984e-05 - val_loss: 1.2854e-04
# Epoch 22/100
# 69/69 [==============================] - ETA: 0s - loss: 9.5019e-05
# Epoch 22: val_loss improved from 0.00013 to 0.00012, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 29ms/step - loss: 9.5019e-05 - val_loss: 1.2032e-04
# Epoch 23/100
# 69/69 [==============================] - ETA: 0s - loss: 9.9357e-05
# Epoch 23: val_loss did not improve from 0.00012
# 69/69 [==============================] - 2s 26ms/step - loss: 9.9357e-05 - val_loss: 1.6212e-04
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 9.2157e-05
# Epoch 24: val_loss did not improve from 0.00012
# 69/69 [==============================] - 2s 24ms/step - loss: 9.2157e-05 - val_loss: 1.8388e-04
# Epoch 25/100
# 69/69 [==============================] - ETA: 0s - loss: 8.2479e-05
# Epoch 25: val_loss did not improve from 0.00012
# 69/69 [==============================] - 2s 24ms/step - loss: 8.2479e-05 - val_loss: 1.5532e-04
# Epoch 26/100
# 69/69 [==============================] - ETA: 0s - loss: 8.6095e-05
# Epoch 26: val_loss improved from 0.00012 to 0.00012, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 27ms/step - loss: 8.6095e-05 - val_loss: 1.1851e-04
# Epoch 27/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.0075e-04
# Epoch 27: val_loss did not improve from 0.00012
# 69/69 [==============================] - 2s 25ms/step - loss: 1.0057e-04 - val_loss: 1.2584e-04
# Epoch 28/100
# 69/69 [==============================] - ETA: 0s - loss: 8.4009e-05
# Epoch 28: val_loss did not improve from 0.00012
# 69/69 [==============================] - 2s 26ms/step - loss: 8.4009e-05 - val_loss: 1.7285e-04
# Epoch 29/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.2822e-05
# Epoch 29: val_loss improved from 0.00012 to 0.00011, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 8.1699e-05 - val_loss: 1.0953e-04
# Epoch 30/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.7985e-05
# Epoch 30: val_loss did not improve from 0.00011
# 69/69 [==============================] - 2s 29ms/step - loss: 7.7604e-05 - val_loss: 1.6479e-04
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 8.9013e-05
# Epoch 31: val_loss improved from 0.00011 to 0.00011, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 2s 26ms/step - loss: 8.9013e-05 - val_loss: 1.0648e-04
# Epoch 32/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.0144e-04
# Epoch 32: val_loss did not improve from 0.00011
# 69/69 [==============================] - 2s 26ms/step - loss: 1.0060e-04 - val_loss: 2.3217e-04
# Epoch 33/100
# 66/69 [===========================>..] - ETA: 0s - loss: 1.0473e-04
# Epoch 33: val_loss improved from 0.00011 to 0.00010, saving model to model/tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 1.0259e-04 - val_loss: 1.0452e-04
# Epoch 34/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.7441e-05
# Epoch 34: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 8.6400e-05 - val_loss: 1.1224e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.6108e-05
# Epoch 35: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 8.5598e-05 - val_loss: 1.1746e-04
# Epoch 36/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.2056e-05
# Epoch 36: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 14ms/step - loss: 7.2997e-05 - val_loss: 1.1808e-04
# Epoch 37/100
# 67/69 [============================>.] - ETA: 0s - loss: 8.3861e-05
# Epoch 37: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 8.3808e-05 - val_loss: 1.8938e-04
# Epoch 38/100
# 69/69 [==============================] - ETA: 0s - loss: 7.3698e-05
# Epoch 38: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 7.3698e-05 - val_loss: 1.0795e-04
# Epoch 39/100
# 69/69 [==============================] - ETA: 0s - loss: 6.4458e-05
# Epoch 39: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 14ms/step - loss: 6.4458e-05 - val_loss: 1.1592e-04
# Epoch 40/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.5587e-05
# Epoch 40: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 7.5998e-05 - val_loss: 1.2026e-04
# Epoch 41/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.8236e-05
# Epoch 41: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 13ms/step - loss: 7.8990e-05 - val_loss: 1.2023e-04
# Epoch 42/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.5685e-05
# Epoch 42: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 14ms/step - loss: 8.7890e-05 - val_loss: 1.9271e-04
# Epoch 43/100
# 69/69 [==============================] - ETA: 0s - loss: 7.1567e-05
# Epoch 43: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 14ms/step - loss: 7.1567e-05 - val_loss: 1.0684e-04
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:6183.772848578907
# [7851.155064087212, 6183.772848578907]
# Epoch 1/100
# 102/104 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 1: val_loss improved from inf to 0.00249, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 5s 20ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 2/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4882e-04
# Epoch 2: val_loss improved from 0.00249 to 0.00148, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 3.4931e-04 - val_loss: 0.0015
# Epoch 3/100
# 102/104 [============================>.] - ETA: 0s - loss: 2.1882e-04
# Epoch 3: val_loss did not improve from 0.00148
# 104/104 [==============================] - 1s 14ms/step - loss: 2.1920e-04 - val_loss: 0.0016
# Epoch 4/100
# 104/104 [==============================] - ETA: 0s - loss: 1.7770e-04
# Epoch 4: val_loss did not improve from 0.00148
# 104/104 [==============================] - 1s 14ms/step - loss: 1.7770e-04 - val_loss: 0.0017
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 1.3880e-04
# Epoch 5: val_loss improved from 0.00148 to 0.00116, saving model to model/tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 1.3911e-04 - val_loss: 0.0012
# Epoch 6/100
# 103/104 [============================>.] - ETA: 0s - loss: 1.2685e-04
# Epoch 6: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 13ms/step - loss: 1.2631e-04 - val_loss: 0.0017
# Epoch 7/100
# 101/104 [============================>.] - ETA: 0s - loss: 1.1247e-04
# Epoch 7: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 13ms/step - loss: 1.1167e-04 - val_loss: 0.0015
# Epoch 8/100
# 103/104 [============================>.] - ETA: 0s - loss: 1.0146e-04
# Epoch 8: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 1.0285e-04 - val_loss: 0.0015
# Epoch 9/100
# 101/104 [============================>.] - ETA: 0s - loss: 1.0032e-04
# Epoch 9: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 1.0015e-04 - val_loss: 0.0015
# Epoch 10/100
# 101/104 [============================>.] - ETA: 0s - loss: 8.7262e-05
# Epoch 10: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 13ms/step - loss: 8.7011e-05 - val_loss: 0.0014
# Epoch 11/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.7352e-05
# Epoch 11: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 7.6929e-05 - val_loss: 0.0018
# Epoch 12/100
# 102/104 [============================>.] - ETA: 0s - loss: 7.5603e-05
# Epoch 12: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 7.5199e-05 - val_loss: 0.0017
# Epoch 13/100
# 101/104 [============================>.] - ETA: 0s - loss: 8.1726e-05
# Epoch 13: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 8.0807e-05 - val_loss: 0.0022
# Epoch 14/100
# 102/104 [============================>.] - ETA: 0s - loss: 6.7738e-05
# Epoch 14: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 6.7742e-05 - val_loss: 0.0020
# Epoch 15/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.8625e-05
# Epoch 15: val_loss did not improve from 0.00116
# 104/104 [==============================] - 1s 14ms/step - loss: 7.8576e-05 - val_loss: 0.0018
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:11061.99443991518
# [7851.155064087212, 6183.772848578907, 11061.99443991518]
# Epoch 1/100
# 139/139 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 1: val_loss improved from inf to 0.00169, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 5s 18ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 2/100
# 137/139 [============================>.] - ETA: 0s - loss: 1.7703e-04
# Epoch 2: val_loss improved from 0.00169 to 0.00112, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 15ms/step - loss: 1.7723e-04 - val_loss: 0.0011
# Epoch 3/100
# 137/139 [============================>.] - ETA: 0s - loss: 1.2106e-04
# Epoch 3: val_loss improved from 0.00112 to 0.00095, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 1.2113e-04 - val_loss: 9.5202e-04
# Epoch 4/100
# 136/139 [============================>.] - ETA: 0s - loss: 8.6450e-05
# Epoch 4: val_loss did not improve from 0.00095
# 139/139 [==============================] - 2s 13ms/step - loss: 8.5967e-05 - val_loss: 9.5349e-04
# Epoch 5/100
# 136/139 [============================>.] - ETA: 0s - loss: 7.0514e-05
# Epoch 5: val_loss improved from 0.00095 to 0.00081, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 7.0536e-05 - val_loss: 8.1231e-04
# Epoch 6/100
# 136/139 [============================>.] - ETA: 0s - loss: 6.1687e-05
# Epoch 6: val_loss improved from 0.00081 to 0.00062, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 6.1542e-05 - val_loss: 6.2083e-04
# Epoch 7/100
# 136/139 [============================>.] - ETA: 0s - loss: 5.4553e-05
# Epoch 7: val_loss did not improve from 0.00062
# 139/139 [==============================] - 2s 13ms/step - loss: 5.4929e-05 - val_loss: 6.3432e-04
# Epoch 8/100
# 137/139 [============================>.] - ETA: 0s - loss: 4.8837e-05
# Epoch 8: val_loss did not improve from 0.00062
# 139/139 [==============================] - 2s 13ms/step - loss: 4.8651e-05 - val_loss: 8.5567e-04
# Epoch 9/100
# 138/139 [============================>.] - ETA: 0s - loss: 4.1236e-05
# Epoch 9: val_loss did not improve from 0.00062
# 139/139 [==============================] - 2s 14ms/step - loss: 4.1262e-05 - val_loss: 7.8836e-04
# Epoch 10/100
# 135/139 [============================>.] - ETA: 0s - loss: 3.9399e-05
# Epoch 10: val_loss improved from 0.00062 to 0.00059, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 3.9794e-05 - val_loss: 5.9329e-04
# Epoch 11/100
# 138/139 [============================>.] - ETA: 0s - loss: 4.0234e-05
# Epoch 11: val_loss did not improve from 0.00059
# 139/139 [==============================] - 2s 13ms/step - loss: 4.0136e-05 - val_loss: 6.0021e-04
# Epoch 12/100
# 139/139 [==============================] - ETA: 0s - loss: 3.6504e-05
# Epoch 12: val_loss did not improve from 0.00059
# 139/139 [==============================] - 2s 14ms/step - loss: 3.6504e-05 - val_loss: 7.1124e-04
# Epoch 13/100
# 137/139 [============================>.] - ETA: 0s - loss: 3.7287e-05
# Epoch 13: val_loss improved from 0.00059 to 0.00047, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 3.7110e-05 - val_loss: 4.7186e-04
# Epoch 14/100
# 139/139 [==============================] - ETA: 0s - loss: 3.1982e-05
# Epoch 14: val_loss did not improve from 0.00047
# 139/139 [==============================] - 2s 14ms/step - loss: 3.1982e-05 - val_loss: 5.7803e-04
# Epoch 15/100
# 138/139 [============================>.] - ETA: 0s - loss: 3.5739e-05
# Epoch 15: val_loss improved from 0.00047 to 0.00047, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 3.5609e-05 - val_loss: 4.6533e-04
# Epoch 16/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.9180e-05
# Epoch 16: val_loss improved from 0.00047 to 0.00044, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 2.9185e-05 - val_loss: 4.3633e-04
# Epoch 17/100
# 138/139 [============================>.] - ETA: 0s - loss: 3.0820e-05
# Epoch 17: val_loss did not improve from 0.00044
# 139/139 [==============================] - 2s 14ms/step - loss: 3.1188e-05 - val_loss: 4.5579e-04
# Epoch 18/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.8211e-05
# Epoch 18: val_loss improved from 0.00044 to 0.00042, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 2.8097e-05 - val_loss: 4.2443e-04
# Epoch 19/100
# 138/139 [============================>.] - ETA: 0s - loss: 3.6422e-05
# Epoch 19: val_loss did not improve from 0.00042
# 139/139 [==============================] - 2s 14ms/step - loss: 3.6282e-05 - val_loss: 5.2839e-04
# Epoch 20/100
# 139/139 [==============================] - ETA: 0s - loss: 2.9505e-05
# Epoch 20: val_loss did not improve from 0.00042
# 139/139 [==============================] - 2s 13ms/step - loss: 2.9505e-05 - val_loss: 4.7869e-04
# Epoch 21/100
# 136/139 [============================>.] - ETA: 0s - loss: 3.5396e-05
# Epoch 21: val_loss did not improve from 0.00042
# 139/139 [==============================] - 2s 14ms/step - loss: 3.5021e-05 - val_loss: 4.3482e-04
# Epoch 22/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.5165e-05
# Epoch 22: val_loss improved from 0.00042 to 0.00036, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 2.5299e-05 - val_loss: 3.5899e-04
# Epoch 23/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.7452e-05
# Epoch 23: val_loss improved from 0.00036 to 0.00034, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 2.7545e-05 - val_loss: 3.4048e-04
# Epoch 24/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.5917e-05
# Epoch 24: val_loss did not improve from 0.00034
# 139/139 [==============================] - 2s 13ms/step - loss: 2.5982e-05 - val_loss: 3.8944e-04
# Epoch 25/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.9006e-05
# Epoch 25: val_loss did not improve from 0.00034
# 139/139 [==============================] - 2s 13ms/step - loss: 2.8935e-05 - val_loss: 3.8027e-04
# Epoch 26/100
# 136/139 [============================>.] - ETA: 0s - loss: 3.1659e-05
# Epoch 26: val_loss improved from 0.00034 to 0.00033, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 3.1593e-05 - val_loss: 3.3033e-04
# Epoch 27/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.7912e-05
# Epoch 27: val_loss did not improve from 0.00033
# 139/139 [==============================] - 2s 14ms/step - loss: 2.7883e-05 - val_loss: 3.6360e-04
# Epoch 28/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.9914e-05
# Epoch 28: val_loss did not improve from 0.00033
# 139/139 [==============================] - 2s 13ms/step - loss: 2.9793e-05 - val_loss: 3.3177e-04
# Epoch 29/100
# 139/139 [==============================] - ETA: 0s - loss: 2.6784e-05
# Epoch 29: val_loss improved from 0.00033 to 0.00033, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 13ms/step - loss: 2.6784e-05 - val_loss: 3.2660e-04
# Epoch 30/100
# 138/139 [============================>.] - ETA: 0s - loss: 3.2738e-05
# Epoch 30: val_loss did not improve from 0.00033
# 139/139 [==============================] - 3s 21ms/step - loss: 3.2580e-05 - val_loss: 4.4465e-04
# Epoch 31/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.7007e-05
# Epoch 31: val_loss did not improve from 0.00033
# 139/139 [==============================] - 2s 14ms/step - loss: 2.6966e-05 - val_loss: 4.8791e-04
# Epoch 32/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.2267e-05
# Epoch 32: val_loss improved from 0.00033 to 0.00029, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 2.2143e-05 - val_loss: 2.8769e-04
# Epoch 33/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.9191e-05
# Epoch 33: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 17ms/step - loss: 2.9133e-05 - val_loss: 3.1216e-04
# Epoch 34/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.9660e-05
# Epoch 34: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 14ms/step - loss: 2.9943e-05 - val_loss: 3.2973e-04
# Epoch 35/100
# 139/139 [==============================] - ETA: 0s - loss: 2.6587e-05
# Epoch 35: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 14ms/step - loss: 2.6587e-05 - val_loss: 4.7217e-04
# Epoch 36/100
# 139/139 [==============================] - ETA: 0s - loss: 2.6561e-05
# Epoch 36: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 14ms/step - loss: 2.6561e-05 - val_loss: 5.2236e-04
# Epoch 37/100
# 139/139 [==============================] - ETA: 0s - loss: 2.6118e-05
# Epoch 37: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 14ms/step - loss: 2.6118e-05 - val_loss: 3.0202e-04
# Epoch 38/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.2224e-05
# Epoch 38: val_loss did not improve from 0.00029
# 139/139 [==============================] - 2s 16ms/step - loss: 2.2573e-05 - val_loss: 3.5585e-04
# Epoch 39/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.2128e-05
# Epoch 39: val_loss improved from 0.00029 to 0.00027, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 2.2043e-05 - val_loss: 2.6574e-04
# Epoch 40/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.2676e-05
# Epoch 40: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 2.2640e-05 - val_loss: 3.0578e-04
# Epoch 41/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.5170e-05
# Epoch 41: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 2.4989e-05 - val_loss: 2.8779e-04
# Epoch 42/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.5984e-05
# Epoch 42: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 15ms/step - loss: 2.5919e-05 - val_loss: 3.2016e-04
# Epoch 43/100
# 135/139 [============================>.] - ETA: 0s - loss: 2.3617e-05
# Epoch 43: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 13ms/step - loss: 2.3846e-05 - val_loss: 3.4124e-04
# Epoch 44/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.9445e-05
# Epoch 44: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 2.9530e-05 - val_loss: 4.3215e-04
# Epoch 45/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.0942e-05
# Epoch 45: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 2.0840e-05 - val_loss: 3.1829e-04
# Epoch 46/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.4903e-05
# Epoch 46: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 15ms/step - loss: 2.4875e-05 - val_loss: 3.7211e-04
# Epoch 47/100
# 139/139 [==============================] - ETA: 0s - loss: 3.2285e-05
# Epoch 47: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 3.2285e-05 - val_loss: 3.4532e-04
# Epoch 48/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.6385e-05
# Epoch 48: val_loss did not improve from 0.00027
# 139/139 [==============================] - 2s 14ms/step - loss: 2.6236e-05 - val_loss: 3.2255e-04
# Epoch 49/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.4317e-05
# Epoch 49: val_loss improved from 0.00027 to 0.00023, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 2.4580e-05 - val_loss: 2.2740e-04
# Epoch 50/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.5535e-05
# Epoch 50: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 13ms/step - loss: 2.5197e-05 - val_loss: 3.2379e-04
# Epoch 51/100
# 139/139 [==============================] - ETA: 0s - loss: 2.6517e-05
# Epoch 51: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 13ms/step - loss: 2.6517e-05 - val_loss: 2.6749e-04
# Epoch 52/100
# 135/139 [============================>.] - ETA: 0s - loss: 2.4289e-05
# Epoch 52: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 14ms/step - loss: 2.4089e-05 - val_loss: 2.6241e-04
# Epoch 53/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.0431e-05
# Epoch 53: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 13ms/step - loss: 2.0758e-05 - val_loss: 3.4697e-04
# Epoch 54/100
# 137/139 [============================>.] - ETA: 0s - loss: 1.9971e-05
# Epoch 54: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 13ms/step - loss: 1.9958e-05 - val_loss: 2.7115e-04
# Epoch 55/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.2299e-05
# Epoch 55: val_loss did not improve from 0.00023
# 139/139 [==============================] - 2s 13ms/step - loss: 2.2343e-05 - val_loss: 2.7263e-04
# Epoch 56/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.4527e-05
# Epoch 56: val_loss improved from 0.00023 to 0.00022, saving model to model/tmp_checkpoint.h5
# 139/139 [==============================] - 2s 15ms/step - loss: 2.4525e-05 - val_loss: 2.2044e-04
# Epoch 57/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.1786e-05
# Epoch 57: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 2.1832e-05 - val_loss: 2.9167e-04
# Epoch 58/100
# 139/139 [==============================] - ETA: 0s - loss: 2.2869e-05
# Epoch 58: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 13ms/step - loss: 2.2869e-05 - val_loss: 2.2213e-04
# Epoch 59/100
# 135/139 [============================>.] - ETA: 0s - loss: 3.0157e-05
# Epoch 59: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 3.1099e-05 - val_loss: 2.2461e-04
# Epoch 60/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.6186e-05
# Epoch 60: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 13ms/step - loss: 2.6229e-05 - val_loss: 3.0377e-04
# Epoch 61/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.7375e-05
# Epoch 61: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 13ms/step - loss: 2.7312e-05 - val_loss: 3.6897e-04
# Epoch 62/100
# 139/139 [==============================] - ETA: 0s - loss: 2.0594e-05
# Epoch 62: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 15ms/step - loss: 2.0594e-05 - val_loss: 3.1659e-04
# Epoch 63/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.3728e-05
# Epoch 63: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 2.3623e-05 - val_loss: 2.4197e-04
# Epoch 64/100
# 137/139 [============================>.] - ETA: 0s - loss: 2.2695e-05
# Epoch 64: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 2.2517e-05 - val_loss: 2.2730e-04
# Epoch 65/100
# 136/139 [============================>.] - ETA: 0s - loss: 2.1912e-05
# Epoch 65: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 2.1816e-05 - val_loss: 2.8268e-04
# Epoch 66/100
# 136/139 [============================>.] - ETA: 0s - loss: 1.8994e-05
# Epoch 66: val_loss did not improve from 0.00022
# 139/139 [==============================] - 2s 14ms/step - loss: 1.9270e-05 - val_loss: 3.1858e-04
# 4000길이의 데이터 적용 완료
#  길이: 4000, RMSE:11534.310443182672
# [7851.155064087212, 6183.772848578907, 11061.99443991518, 11534.310443182672]
# Epoch 1/100
# 173/174 [============================>.] - ETA: 0s - loss: 8.4355e-04
# Epoch 1: val_loss improved from inf to 0.00016, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 5s 18ms/step - loss: 8.4024e-04 - val_loss: 1.6237e-04
# Epoch 2/100
# 174/174 [==============================] - ETA: 0s - loss: 1.1172e-04
# Epoch 2: val_loss improved from 0.00016 to 0.00009, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 1.1172e-04 - val_loss: 9.1492e-05
# Epoch 3/100
# 173/174 [============================>.] - ETA: 0s - loss: 7.7008e-05
# Epoch 3: val_loss did not improve from 0.00009
# 174/174 [==============================] - 3s 14ms/step - loss: 7.6734e-05 - val_loss: 1.0589e-04
# Epoch 4/100
# 172/174 [============================>.] - ETA: 0s - loss: 4.2989e-05
# Epoch 4: val_loss improved from 0.00009 to 0.00009, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 4.2752e-05 - val_loss: 8.9103e-05
# Epoch 5/100
# 173/174 [============================>.] - ETA: 0s - loss: 4.0462e-05
# Epoch 5: val_loss improved from 0.00009 to 0.00005, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 4.0370e-05 - val_loss: 5.3614e-05
# Epoch 6/100
# 173/174 [============================>.] - ETA: 0s - loss: 3.7050e-05
# Epoch 6: val_loss did not improve from 0.00005
# 174/174 [==============================] - 2s 14ms/step - loss: 3.7412e-05 - val_loss: 9.3294e-05
# Epoch 7/100
# 174/174 [==============================] - ETA: 0s - loss: 3.2725e-05
# Epoch 7: val_loss improved from 0.00005 to 0.00005, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 3.2725e-05 - val_loss: 4.5702e-05
# Epoch 8/100
# 171/174 [============================>.] - ETA: 0s - loss: 3.0297e-05
# Epoch 8: val_loss did not improve from 0.00005
# 174/174 [==============================] - 2s 14ms/step - loss: 3.2159e-05 - val_loss: 6.2827e-05
# Epoch 9/100
# 174/174 [==============================] - ETA: 0s - loss: 3.7196e-05
# Epoch 9: val_loss did not improve from 0.00005
# 174/174 [==============================] - 2s 14ms/step - loss: 3.7196e-05 - val_loss: 1.2328e-04
# Epoch 10/100
# 171/174 [============================>.] - ETA: 0s - loss: 3.3437e-05
# Epoch 10: val_loss did not improve from 0.00005
# 174/174 [==============================] - 2s 14ms/step - loss: 3.3403e-05 - val_loss: 6.0191e-05
# Epoch 11/100
# 172/174 [============================>.] - ETA: 0s - loss: 2.1977e-05
# Epoch 11: val_loss improved from 0.00005 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 14ms/step - loss: 2.1967e-05 - val_loss: 3.9313e-05
# Epoch 12/100
# 174/174 [==============================] - ETA: 0s - loss: 3.0242e-05
# Epoch 12: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 3.0242e-05 - val_loss: 4.1410e-05
# Epoch 13/100
# 172/174 [============================>.] - ETA: 0s - loss: 2.5954e-05
# Epoch 13: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 2.5898e-05 - val_loss: 3.7793e-05
# Epoch 14/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.3152e-05
# Epoch 14: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 2s 14ms/step - loss: 2.3170e-05 - val_loss: 3.5726e-05
# Epoch 15/100
# 174/174 [==============================] - ETA: 0s - loss: 2.8341e-05
# Epoch 15: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 2.8341e-05 - val_loss: 3.8893e-05
# Epoch 16/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.1917e-05
# Epoch 16: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 2.1863e-05 - val_loss: 3.8482e-05
# Epoch 17/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.7320e-05
# Epoch 17: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 2.7263e-05 - val_loss: 1.1803e-04
# Epoch 18/100
# 172/174 [============================>.] - ETA: 0s - loss: 2.3013e-05
# Epoch 18: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 2.2915e-05 - val_loss: 4.4802e-05
# Epoch 19/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.1356e-05
# Epoch 19: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 2.1341e-05 - val_loss: 3.5825e-05
# Epoch 20/100
# 174/174 [==============================] - ETA: 0s - loss: 1.9463e-05
# Epoch 20: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 1.9463e-05 - val_loss: 5.3887e-05
# Epoch 21/100
# 171/174 [============================>.] - ETA: 0s - loss: 1.9694e-05
# Epoch 21: val_loss did not improve from 0.00004
# 174/174 [==============================] - 2s 14ms/step - loss: 1.9980e-05 - val_loss: 1.2805e-04
# Epoch 22/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.5364e-05
# Epoch 22: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 2.5333e-05 - val_loss: 3.2803e-05
# Epoch 23/100
# 172/174 [============================>.] - ETA: 0s - loss: 1.9923e-05
# Epoch 23: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 2.0109e-05 - val_loss: 3.5219e-05
# Epoch 24/100
# 173/174 [============================>.] - ETA: 0s - loss: 1.8058e-05
# Epoch 24: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 1.8143e-05 - val_loss: 3.3572e-05
# Epoch 25/100
# 173/174 [============================>.] - ETA: 0s - loss: 1.9772e-05
# Epoch 25: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 18ms/step - loss: 2.0064e-05 - val_loss: 3.2810e-05
# Epoch 26/100
# 174/174 [==============================] - ETA: 0s - loss: 1.9808e-05
# Epoch 26: val_loss did not improve from 0.00003
# 174/174 [==============================] - 4s 20ms/step - loss: 1.9808e-05 - val_loss: 4.2654e-05
# Epoch 27/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.2258e-05
# Epoch 27: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 2.2360e-05 - val_loss: 8.0995e-05
# Epoch 28/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.2472e-05
# Epoch 28: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 174/174 [==============================] - 3s 15ms/step - loss: 2.2272e-05 - val_loss: 2.9563e-05
# Epoch 29/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.5216e-05
# Epoch 29: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 2.5147e-05 - val_loss: 3.8277e-05
# Epoch 30/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.3408e-05
# Epoch 30: val_loss did not improve from 0.00003
# 174/174 [==============================] - 3s 15ms/step - loss: 2.3331e-05 - val_loss: 3.1442e-05
# Epoch 31/100
# 171/174 [============================>.] - ETA: 0s - loss: 2.4761e-05
# Epoch 31: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 2.4814e-05 - val_loss: 5.4041e-05
# Epoch 32/100
# 172/174 [============================>.] - ETA: 0s - loss: 1.7701e-05
# Epoch 32: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 1.7621e-05 - val_loss: 3.2472e-05
# Epoch 33/100
# 173/174 [============================>.] - ETA: 0s - loss: 2.0187e-05
# Epoch 33: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 2.0153e-05 - val_loss: 3.4344e-05
# Epoch 34/100
# 172/174 [============================>.] - ETA: 0s - loss: 1.8658e-05
# Epoch 34: val_loss did not improve from 0.00003
# 174/174 [==============================] - 2s 14ms/step - loss: 1.8881e-05 - val_loss: 5.1935e-05
# Epoch 35/100
# 173/174 [============================>.] - ETA: 0s - loss: 1.9752e-05
# ...
# 314/314 [==============================] - 5s 16ms/step - loss: 2.0373e-05 - val_loss: 6.5312e-05
# Epoch 7/100
# 312/314 [============================>.] - ETA: 0s - loss: 1.7281e-05
# Epoch 7: val_loss improved from 0.00004 to 0.00004, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 15ms/step - loss: 1.7307e-05 - val_loss: 3.6830e-05
# Epoch 8/100
# 311/314 [============================>.] - ETA: 0s - loss: 1.5317e-05
# Epoch 8: val_loss did not improve from 0.00004
# 314/314 [==============================] - 5s 15ms/step - loss: 1.5281e-05 - val_loss: 3.7007e-05
# Epoch 9/100
# 314/314 [==============================] - ETA: 0s - loss: 1.2956e-05
# Epoch 9: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 15ms/step - loss: 1.2956e-05 - val_loss: 3.2300e-05
# Epoch 10/100
# 313/314 [============================>.] - ETA: 0s - loss: 1.2542e-05
# Epoch 10: val_loss did not improve from 0.00003
# 314/314 [==============================] - 5s 15ms/step - loss: 1.2528e-05 - val_loss: 4.5637e-05
# Epoch 11/100
# 314/314 [==============================] - ETA: 0s - loss: 1.0437e-05
# Epoch 11: val_loss did not improve from 0.00003
# 314/314 [==============================] - 5s 14ms/step - loss: 1.0437e-05 - val_loss: 3.2977e-05
# Epoch 12/100
# 313/314 [============================>.] - ETA: 0s - loss: 9.6058e-06
# Epoch 12: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 15ms/step - loss: 9.6235e-06 - val_loss: 3.1389e-05
# Epoch 13/100
# 312/314 [============================>.] - ETA: 0s - loss: 8.5228e-06
# Epoch 13: val_loss did not improve from 0.00003
# 314/314 [==============================] - 5s 14ms/step - loss: 8.4900e-06 - val_loss: 4.1228e-05
# Epoch 14/100
# 314/314 [==============================] - ETA: 0s - loss: 9.2919e-06
# Epoch 14: val_loss did not improve from 0.00003
# 314/314 [==============================] - 5s 14ms/step - loss: 9.2919e-06 - val_loss: 4.2034e-05
# Epoch 15/100
# 312/314 [============================>.] - ETA: 0s - loss: 7.8742e-06
# Epoch 15: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 15ms/step - loss: 7.9022e-06 - val_loss: 2.9170e-05
# Epoch 16/100
# 311/314 [============================>.] - ETA: 0s - loss: 7.1884e-06
# Epoch 16: val_loss did not improve from 0.00003
# 314/314 [==============================] - 5s 15ms/step - loss: 7.1998e-06 - val_loss: 5.1955e-05
# Epoch 17/100
# 314/314 [==============================] - ETA: 0s - loss: 7.9151e-06
# Epoch 17: val_loss improved from 0.00003 to 0.00002, saving model to model/tmp_checkpoint.h5
# 314/314 [==============================] - 5s 15ms/step - loss: 7.9151e-06 - val_loss: 2.1712e-05
# Epoch 18/100
# 311/314 [============================>.] - ETA: 0s - loss: 6.9188e-06
# Epoch 18: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 6.9027e-06 - val_loss: 2.8728e-05
# Epoch 19/100
# 313/314 [============================>.] - ETA: 0s - loss: 5.7149e-06
# Epoch 19: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 5.7451e-06 - val_loss: 3.3648e-05
# Epoch 20/100
# 314/314 [==============================] - ETA: 0s - loss: 6.6478e-06
# Epoch 20: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 6.6478e-06 - val_loss: 3.0799e-05
# Epoch 21/100
# 314/314 [==============================] - ETA: 0s - loss: 5.7937e-06
# Epoch 21: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 5.7937e-06 - val_loss: 7.8051e-05
# Epoch 22/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.5778e-06
# Epoch 22: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 5.5757e-06 - val_loss: 4.1119e-05
# Epoch 23/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.6000e-06
# Epoch 23: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 17ms/step - loss: 5.6124e-06 - val_loss: 8.0037e-05
# Epoch 24/100
# 312/314 [============================>.] - ETA: 0s - loss: 5.2784e-06
# Epoch 24: val_loss did not improve from 0.00002
# 314/314 [==============================] - 6s 19ms/step - loss: 5.2717e-06 - val_loss: 2.3434e-05
# Epoch 25/100
# 314/314 [==============================] - ETA: 0s - loss: 6.7966e-06
# Epoch 25: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 16ms/step - loss: 6.7966e-06 - val_loss: 2.8099e-05
# Epoch 26/100
# 313/314 [============================>.] - ETA: 0s - loss: 5.2547e-06
# Epoch 26: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 15ms/step - loss: 5.2652e-06 - val_loss: 3.7169e-05
# Epoch 27/100
# 312/314 [============================>.] - ETA: 0s - loss: 4.4758e-06
# Epoch 27: val_loss did not improve from 0.00002
# 314/314 [==============================] - 5s 16ms/step - loss: 4.4678e-06 - val_loss: 2.5516e-05
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:10908.84959437863
# [7851.155064087212, 6183.772848578907, 11061.99443991518, 11534.310443182672, 6867.061769552663, 19673.035958719232, 17901.246056637894, 24336.253767272297, 10908.84959437863]
# Epoch 1/100
# 339/341 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 1: val_loss improved from inf to 0.00051, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 12s 25ms/step - loss: 0.0010 - val_loss: 5.1216e-04
# Epoch 2/100
# 341/341 [==============================] - ETA: 0s - loss: 8.8534e-05
# Epoch 2: val_loss improved from 0.00051 to 0.00024, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 8.8534e-05 - val_loss: 2.4127e-04
# Epoch 3/100
# 339/341 [============================>.] - ETA: 0s - loss: 4.7900e-05
# Epoch 3: val_loss improved from 0.00024 to 0.00021, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 4.7810e-05 - val_loss: 2.1223e-04
# Epoch 4/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.5173e-05
# Epoch 4: val_loss improved from 0.00021 to 0.00014, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 3.5133e-05 - val_loss: 1.3973e-04
# Epoch 5/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.4469e-05
# Epoch 5: val_loss improved from 0.00014 to 0.00013, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 2.4477e-05 - val_loss: 1.3255e-04
# Epoch 6/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.1054e-05
# Epoch 6: val_loss improved from 0.00013 to 0.00010, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 2.1029e-05 - val_loss: 1.0315e-04
# Epoch 7/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.6338e-05
# Epoch 7: val_loss improved from 0.00010 to 0.00010, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 1.6366e-05 - val_loss: 1.0020e-04
# Epoch 8/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.3591e-05
# Epoch 8: val_loss improved from 0.00010 to 0.00010, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 1.3594e-05 - val_loss: 9.7429e-05
# Epoch 9/100
# 340/341 [============================>.] - ETA: 0s - loss: 1.4222e-05
# Epoch 9: val_loss did not improve from 0.00010
# 341/341 [==============================] - 8s 23ms/step - loss: 1.4235e-05 - val_loss: 1.3940e-04
# Epoch 10/100
# 339/341 [============================>.] - ETA: 0s - loss: 1.1839e-05
# Epoch 10: val_loss improved from 0.00010 to 0.00006, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 1.1833e-05 - val_loss: 6.0755e-05
# Epoch 11/100
# 341/341 [==============================] - ETA: 0s - loss: 1.1366e-05
# Epoch 11: val_loss did not improve from 0.00006
# 341/341 [==============================] - 8s 23ms/step - loss: 1.1366e-05 - val_loss: 7.5383e-05
# Epoch 12/100
# 341/341 [==============================] - ETA: 0s - loss: 9.6456e-06
# Epoch 12: val_loss improved from 0.00006 to 0.00005, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 9.6456e-06 - val_loss: 4.8915e-05
# Epoch 13/100
# 341/341 [==============================] - ETA: 0s - loss: 8.9777e-06
# Epoch 13: val_loss did not improve from 0.00005
# 341/341 [==============================] - 8s 24ms/step - loss: 8.9777e-06 - val_loss: 5.7597e-05
# Epoch 14/100
# 339/341 [============================>.] - ETA: 0s - loss: 9.1391e-06
# Epoch 14: val_loss did not improve from 0.00005
# 341/341 [==============================] - 8s 23ms/step - loss: 9.2616e-06 - val_loss: 6.1215e-05
# Epoch 15/100
# 339/341 [============================>.] - ETA: 0s - loss: 9.1304e-06
# Epoch 15: val_loss improved from 0.00005 to 0.00005, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 9.1134e-06 - val_loss: 4.6422e-05
# Epoch 16/100
# 339/341 [============================>.] - ETA: 0s - loss: 7.0527e-06
# Epoch 16: val_loss improved from 0.00005 to 0.00004, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 23ms/step - loss: 7.0653e-06 - val_loss: 4.2607e-05
# Epoch 17/100
# 340/341 [============================>.] - ETA: 0s - loss: 7.4389e-06
# Epoch 17: val_loss did not improve from 0.00004
# 341/341 [==============================] - 8s 23ms/step - loss: 7.4303e-06 - val_loss: 4.8998e-05
# Epoch 18/100
# 341/341 [==============================] - ETA: 0s - loss: 6.1169e-06
# Epoch 18: val_loss improved from 0.00004 to 0.00003, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 6.1169e-06 - val_loss: 3.3308e-05
# Epoch 19/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.9227e-06
# Epoch 19: val_loss improved from 0.00003 to 0.00003, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 25ms/step - loss: 5.9233e-06 - val_loss: 3.1185e-05
# Epoch 20/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.4097e-06
# Epoch 20: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 24ms/step - loss: 6.4241e-06 - val_loss: 3.3170e-05
# Epoch 21/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.1946e-06
# Epoch 21: val_loss did not improve from 0.00003
# 341/341 [==============================] - 8s 24ms/step - loss: 6.2084e-06 - val_loss: 8.5967e-05
# Epoch 22/100
# 340/341 [============================>.] - ETA: 0s - loss: 6.4478e-06
# Epoch 22: val_loss improved from 0.00003 to 0.00002, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 6.4472e-06 - val_loss: 2.2961e-05
# Epoch 23/100
# 339/341 [============================>.] - ETA: 0s - loss: 6.9985e-06
# Epoch 23: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 6.9877e-06 - val_loss: 3.9093e-05
# Epoch 24/100
# 341/341 [==============================] - ETA: 0s - loss: 5.5570e-06
# Epoch 24: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 5.5570e-06 - val_loss: 2.5774e-05
# Epoch 25/100
# 341/341 [==============================] - ETA: 0s - loss: 5.4536e-06
# Epoch 25: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 25ms/step - loss: 5.4536e-06 - val_loss: 2.5030e-05
# Epoch 26/100
# 339/341 [============================>.] - ETA: 0s - loss: 6.3351e-06
# Epoch 26: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 6.3333e-06 - val_loss: 2.6024e-05
# Epoch 27/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.8936e-06
# Epoch 27: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 4.8860e-06 - val_loss: 1.2320e-04
# Epoch 28/100
# 341/341 [==============================] - ETA: 0s - loss: 5.1347e-06
# Epoch 28: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 5.1347e-06 - val_loss: 9.0569e-05
# Epoch 29/100
# 341/341 [==============================] - ETA: 0s - loss: 4.6586e-06
# Epoch 29: val_loss improved from 0.00002 to 0.00002, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 4.6586e-06 - val_loss: 2.2293e-05
# Epoch 30/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.4238e-06
# Epoch 30: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 4.4163e-06 - val_loss: 3.3292e-05
# Epoch 31/100
# 340/341 [============================>.] - ETA: 0s - loss: 4.8409e-06
# Epoch 31: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 4.8530e-06 - val_loss: 2.9070e-05
# Epoch 32/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.2878e-06
# Epoch 32: val_loss improved from 0.00002 to 0.00002, saving model to model/tmp_checkpoint.h5
# 341/341 [==============================] - 8s 24ms/step - loss: 5.2843e-06 - val_loss: 1.6902e-05
# Epoch 33/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.0824e-06
# Epoch 33: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 5.0693e-06 - val_loss: 6.3705e-05
# Epoch 34/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.9446e-06
# Epoch 34: val_loss did not improve from 0.00002
# 341/341 [==============================] - 10s 29ms/step - loss: 3.9507e-06 - val_loss: 2.6465e-05
# Epoch 35/100
# 341/341 [==============================] - ETA: 0s - loss: 6.4937e-06
# Epoch 35: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 6.4937e-06 - val_loss: 6.3079e-05
# Epoch 36/100
# 339/341 [============================>.] - ETA: 0s - loss: 5.1342e-06
# Epoch 36: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 5.1215e-06 - val_loss: 2.3987e-05
# Epoch 37/100
# 341/341 [==============================] - ETA: 0s - loss: 3.5653e-06
# Epoch 37: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 24ms/step - loss: 3.5653e-06 - val_loss: 1.2165e-04
# Epoch 38/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.2896e-06
# Epoch 38: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 5.2839e-06 - val_loss: 2.8797e-05
# Epoch 39/100
# 341/341 [==============================] - ETA: 0s - loss: 4.9240e-06
# Epoch 39: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 4.9240e-06 - val_loss: 7.4335e-05
# Epoch 40/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.9965e-06
# Epoch 40: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 4.0039e-06 - val_loss: 1.7616e-05
# Epoch 41/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.9625e-06
# Epoch 41: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 3.9598e-06 - val_loss: 6.7346e-05
# Epoch 42/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.2763e-06
# Epoch 42: val_loss did not improve from 0.00002
# 341/341 [==============================] - 8s 23ms/step - loss: 3.2873e-06 - val_loss: 1.7520e-05
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:3410.1216345283906
# [7851.155064087212, 6183.772848578907, 11061.99443991518, 11534.310443182672, 6867.061769552663, 19673.035958719232, 17901.246056637894, 24336.253767272297, 10908.84959437863, 3410.1216345283906]

# %%
print(predict)
# Out:
# [array([[59719.504]], dtype=float32), array([[65669.586]], dtype=float32), array([[58604.086]], dtype=float32), array([[53024.39]], dtype=float32), array([[56824.71]], dtype=float32), array([[40704.566]], dtype=float32), array([[44234.88]], dtype=float32), array([[33468.055]], dtype=float32), array([[48182.99]], dtype=float32), array([[49354.004]], dtype=float32)]

# %%
from google.colab import drive
drive.mount('/content/drive')

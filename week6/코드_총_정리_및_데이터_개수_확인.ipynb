# %%
#데이터셋을 만들어 주는 함수
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.layers import LSTM,Dropout
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score

df = pd.read_csv("[IT]삼성전자.csv")
df_columns = ['Date','Open', 'High', 'Low', 'Close', 'Volume']
df.columns = df_columns
df = df.sort_values('Date')
df['Date']= df['Date'].astype('str')
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)

ma = [5,20,60,120]
for days in ma:
    df['ma_'+str(days)] = df['Close'].rolling(window = days).mean()
    df['vma_'+str(days)] = df['Volume'].rolling(window = days).mean()

df.dropna(inplace=True)


import ta

H, L, C, V = df['High'], df['Low'], df['Close'], df['Volume']

# df['bol_high'] = ta.volatility.bollinger_hband(C)
# df['bol_low']  = ta.volatility.bollinger_lband(C)
df['MFI'] = ta.volume.money_flow_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['ADI'] = ta.volume.acc_dist_index(
    high=H, low=L, close=C, volume=V, fillna=True)

df['OBV'] = ta.volume.on_balance_volume(close=C, volume=V, fillna=True)
df['CMF'] = ta.volume.chaikin_money_flow(
    high=H, low=L, close=C, volume=V, fillna=True)

df['FI'] = ta.volume.force_index(close=C, volume=V, fillna=True)
df['EOM, EMV'] = ta.volume.ease_of_movement(
    high=H, low=L, volume=V, fillna=True)

df['VPT'] = ta.volume.volume_price_trend(close=C, volume=V, fillna=True)
df['NVI'] = ta.volume.negative_volume_index(close=C, volume=V, fillna=True)
df['VMAP'] = ta.volume.volume_weighted_average_price(
    high=H, low=L, close=C, volume=V, fillna=True)

# Volatility
df['ATR'] = ta.volatility.average_true_range(
    high=H, low=L, close=C, fillna=True)
df['BHB'] = ta.volatility.bollinger_hband(close=C, fillna=True)
df['BLB'] = ta.volatility.bollinger_lband(close=C, fillna=True)
df['KCH'] = ta.volatility.keltner_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['KCL'] = ta.volatility.keltner_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['KCM'] = ta.volatility.keltner_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['DCH'] = ta.volatility.donchian_channel_hband(
    high=H, low=L, close=C, fillna=True)
df['DCL'] = ta.volatility.donchian_channel_lband(
    high=H, low=L, close=C, fillna=True)
df['DCM'] = ta.volatility.donchian_channel_mband(
    high=H, low=L, close=C, fillna=True)
df['UI'] = ta.volatility.ulcer_index(close=C, fillna=True)
# Trend
df['SMA'] = ta.trend.sma_indicator(close=C, fillna=True)
df['EMA'] = ta.trend.ema_indicator(close=C, fillna=True)
df['WMA'] = ta.trend.wma_indicator(close=C, fillna=True)
df['MACD'] = ta.trend.macd(close=C, fillna=True)
df['ADX'] = ta.trend.adx(high=H, low=L, close=C, fillna=True)
df['-VI'] = ta.trend.vortex_indicator_neg(
    high=H, low=L, close=C, fillna=True)
df['+VI'] = ta.trend.vortex_indicator_pos(
    high=H, low=L, close=C, fillna=True)
df['TRIX'] = ta.trend.trix(close=C, fillna=True)
df['MI'] = ta.trend.mass_index(high=H, low=L, fillna=True)
df['CCI'] = ta.trend.cci(high=H, low=L, close=C, fillna=True)
df['DPO'] = ta.trend.dpo(close=C, fillna=True)
df['KST'] = ta.trend.kst(close=C, fillna=True)
df['Ichimoku'] = ta.trend.ichimoku_a(high=H, low=L, fillna=True)
df['Parabolic SAR'] = ta.trend.psar_down(
    high=H, low=L, close=C, fillna=True)
df['STC'] = ta.trend.stc(close=C, fillna=True)
# Momentum
df['RSI'] = ta.momentum.rsi(close=C, fillna=True)
df['SRSI'] = ta.momentum.stochrsi(close=C, fillna=True)
df['TSI'] = ta.momentum.tsi(close=C, fillna=True)
df['UO'] = ta.momentum.ultimate_oscillator(
    high=H, low=L, close=C, fillna=True)
df['SR'] = ta.momentum.stoch(close=C, high=H, low=L, fillna=True)
df['WR'] = ta.momentum.williams_r(high=H, low=L, close=C, fillna=True)
df['AO'] = ta.momentum.awesome_oscillator(high=H, low=L, fillna=True)
df['KAMA'] = ta.momentum.kama(close=C, fillna=True)
df['ROC'] = ta.momentum.roc(close=C, fillna=True)
df['PPO'] = ta.momentum.ppo(close=C, fillna=True)
df['PVO'] = ta.momentum.pvo(volume=V, fillna=True)


from sklearn.preprocessing import MinMaxScaler

# 피처값 스케일링
scaler = MinMaxScaler()

scaled_df = scaler.fit_transform(df.drop(['Close'], axis=1))
scaled_df = pd.DataFrame(scaled_df, columns = df.drop(['Close'], axis=1).columns)

scaler1 = MinMaxScaler()

temp = scaler1.fit_transform(df['Close'].values.reshape(-1,1))

scaled_df.insert(3, 'Close',temp)
scaled_df

df = scaled_df



import numpy as np

def make_dataset(feature, label, window_size = 20):
  
  feature_list = []
  label_list = []
  
  for i in range(len(feature) - window_size) :
    feature_list.append(feature.iloc[i:i+window_size])
    label_list.append(label.iloc[i+window_size])
  
  return np.array(feature_list), np.array(label_list)

WINDOW_SIZE=20

result = []
predict = []


####최근 20개의 데이터만
pred_feature = df[-WINDOW_SIZE :]
pred_feature = pred_feature.to_numpy()

pred_feature = pred_feature.reshape((1,20,-1))
# pred_feature.shape

import random as rn
import tensorflow as tf

# seed_num = 42
# np.random.seed(seed_num)
# rn.seed(seed_num)
# tf.random.set_seed(seed_num)
# tf.set_random_seed(seed_num)

for i in range(1, len(df)//1000+2):
  
        # seed_num = 42
        # np.random.seed(seed_num)
        # rn.seed(seed_num)
        # tf.random.set_seed(seed_num)
        
        # 데이터 불러오기
        df_copy = df
        # df = df.set_index(keys=['Date'], inplace=False, drop=True)
        # df = df.drop('Close', axis = 1)
        # df.rename(columns ={'Adj Close':'Close'}, inplace = True)
        # 원하는 크기로 데이터 자르기
        df_copy = df_copy[-i*1000:]
        # 피처값, 타켓 스케일링
        
        TEST_SIZE = int(len(df_copy) * 0.7)
        
        train = df_copy[:TEST_SIZE]
        test = df_copy[TEST_SIZE:]

##200일의 데이터를 얼마나 잘 예측하느냐
        
        # feature_cols = df.drop('Close', axis =1).columns
        feature_cols = df.columns
        label_cols = ['Close']

        train_feature = train[feature_cols]
        train_label = train[label_cols]

        train_feature, train_label = make_dataset(train_feature, train_label,20)

        from sklearn.model_selection import train_test_split
        x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2, shuffle = False)
        
        
        test_feature = test[feature_cols]
        test_label = test[label_cols]
        test_feature , test_label = make_dataset(test_feature, test_label,20)
        
        
        from keras.layers.normalization import batch_normalization

        model = Sequential()

        model.add(LSTM(16, 
                      input_shape=(train_feature.shape[1], train_feature.shape[2]), 
                      return_sequences=False,
                      activation='relu'))
      
        model.add(Dense(1))
        # model.add(Dropout(0.2, seed=123))
      
        
        model.compile(loss='mean_squared_error', optimizer='adam')

        early_stop = EarlyStopping(monitor='val_loss', patience=10)

        import os
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

        model_path = 'model'
        filename = os.path.join(model_path, 'tmp_checkpoint.h5')
        checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

        history = model.fit(x_train, y_train, 
                                            epochs=100, 
                                            batch_size=16,
                                            validation_data=(x_valid, y_valid), 
                                            callbacks=[early_stop, checkpoint])


        pred = model.predict(test_feature)
        # rescaleing 작업
        rescaled_y_true = scaler1.inverse_transform(np.array(test_label).reshape(-1, 1))
        rescaled_pred = scaler1.inverse_transform(np.array(pred).reshape(-1,1))
        
        
        # 평가지표(RMSE) 계산
        RMSE = np.sqrt(mean_squared_error(rescaled_y_true, rescaled_pred))
        result.append(RMSE)
        print(f"{i * 1000}길이의 데이터 적용 완료\n 길이: {i * 1000}, RMSE:{RMSE}")
        print(result)
        
        
        model.load_weights(filename)

        new_pred = model.predict(pred_feature)
        rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        predict.append(rescaled_newpred)
        
        # new_pred = model.predict(pred_feature)
        # rescaled_newpred = scaler1.inverse_transform(np.array(new_pred).reshape(-1,1))
        # predict.append(rescaled_newpred)
        
        
        
        
    # data_size = list(range(1000, len(df_origin), 1000))
    # data_size.append(len(df_origin))
    # plt.style.use("ggplot")
    # plt.rcParams['font.family'] = 'Malgun Gothic'
    # data_size = list(range(1000, len(df_origin), 1000))
    # data_size.append(len(df_origin))
    # plt.figure(figsize=(9, 6))
    # plt.plot(data_size, result)
    # plt.tick_params(axis='x')
    # plt.tick_params(axis='y')
    # plt.title(f'{file_name}')
    # plt.show()
# Out:
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:938: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_up = pd.Series(index=self._psar.index)
# C:\Users\ssoyeon\anaconda3_1\envs\dataanalysis\lib\site-packages\ta\trend.py:939: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_down = pd.Series(index=self._psar.index)
# Epoch 1/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.2219
# Epoch 1: val_loss improved from inf to 0.08551, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 3s 36ms/step - loss: 0.2099 - val_loss: 0.0855
# Epoch 2/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0172
# Epoch 2: val_loss improved from 0.08551 to 0.04526, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0168 - val_loss: 0.0453
# Epoch 3/100
# 31/34 [==========================>...] - ETA: 0s - loss: 0.0092
# Epoch 3: val_loss improved from 0.04526 to 0.02362, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 0.0236
# Epoch 4/100
# 32/34 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 4: val_loss improved from 0.02362 to 0.00652, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 5/100
# 30/34 [=========================>....] - ETA: 0s - loss: 0.0020
# Epoch 5: val_loss did not improve from 0.00652
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 6/100
# 30/34 [=========================>....] - ETA: 0s - loss: 9.0809e-04
# Epoch 6: val_loss improved from 0.00652 to 0.00455, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 0s 15ms/step - loss: 8.9788e-04 - val_loss: 0.0045
# Epoch 7/100
# 31/34 [==========================>...] - ETA: 0s - loss: 7.2236e-04
# Epoch 7: val_loss did not improve from 0.00455
# 34/34 [==============================] - 0s 13ms/step - loss: 7.2041e-04 - val_loss: 0.0073
# Epoch 8/100
# 30/34 [=========================>....] - ETA: 0s - loss: 6.1994e-04
# Epoch 8: val_loss improved from 0.00455 to 0.00349, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 16ms/step - loss: 6.1751e-04 - val_loss: 0.0035
# Epoch 9/100
# 29/34 [========================>.....] - ETA: 0s - loss: 5.1438e-04
# Epoch 9: val_loss did not improve from 0.00349
# 34/34 [==============================] - 0s 13ms/step - loss: 5.1688e-04 - val_loss: 0.0045
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 5.0850e-04
# Epoch 10: val_loss did not improve from 0.00349
# 34/34 [==============================] - 0s 14ms/step - loss: 5.0850e-04 - val_loss: 0.0037
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 4.4704e-04
# Epoch 11: val_loss did not improve from 0.00349
# 34/34 [==============================] - 0s 10ms/step - loss: 4.4704e-04 - val_loss: 0.0048
# Epoch 12/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.8172e-04
# Epoch 12: val_loss did not improve from 0.00349
# 34/34 [==============================] - 0s 11ms/step - loss: 3.7873e-04 - val_loss: 0.0037
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 3.5247e-04
# Epoch 13: val_loss improved from 0.00349 to 0.00260, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 3.5247e-04 - val_loss: 0.0026
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 3.2628e-04
# Epoch 14: val_loss improved from 0.00260 to 0.00223, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 29ms/step - loss: 3.2628e-04 - val_loss: 0.0022
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 3.0779e-04
# Epoch 15: val_loss improved from 0.00223 to 0.00215, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 27ms/step - loss: 3.0779e-04 - val_loss: 0.0022
# Epoch 16/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.0077e-04
# Epoch 16: val_loss improved from 0.00215 to 0.00147, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 17ms/step - loss: 3.0181e-04 - val_loss: 0.0015
# Epoch 17/100
# 32/34 [===========================>..] - ETA: 0s - loss: 3.2151e-04
# Epoch 17: val_loss did not improve from 0.00147
# 34/34 [==============================] - 0s 11ms/step - loss: 3.2550e-04 - val_loss: 0.0029
# Epoch 18/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.9939e-04
# Epoch 18: val_loss did not improve from 0.00147
# 34/34 [==============================] - 0s 9ms/step - loss: 3.0717e-04 - val_loss: 0.0023
# Epoch 19/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.6261e-04
# Epoch 19: val_loss did not improve from 0.00147
# 34/34 [==============================] - 0s 10ms/step - loss: 2.6506e-04 - val_loss: 0.0019
# Epoch 20/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.4424e-04
# Epoch 20: val_loss did not improve from 0.00147
# 34/34 [==============================] - 0s 10ms/step - loss: 2.4384e-04 - val_loss: 0.0018
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 2.6307e-04
# Epoch 21: val_loss did not improve from 0.00147
# 34/34 [==============================] - 0s 11ms/step - loss: 2.6307e-04 - val_loss: 0.0018
# Epoch 22/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4336e-04
# Epoch 22: val_loss improved from 0.00147 to 0.00108, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4552e-04 - val_loss: 0.0011
# Epoch 23/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.8333e-04
# Epoch 23: val_loss did not improve from 0.00108
# 34/34 [==============================] - 0s 12ms/step - loss: 2.7896e-04 - val_loss: 0.0027
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 2.3729e-04
# Epoch 24: val_loss did not improve from 0.00108
# 34/34 [==============================] - 0s 11ms/step - loss: 2.3729e-04 - val_loss: 0.0021
# Epoch 25/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.3883e-04
# Epoch 25: val_loss did not improve from 0.00108
# 34/34 [==============================] - 0s 13ms/step - loss: 2.3716e-04 - val_loss: 0.0014
# Epoch 26/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.0060e-04
# Epoch 26: val_loss did not improve from 0.00108
# 34/34 [==============================] - 1s 20ms/step - loss: 2.0443e-04 - val_loss: 0.0019
# Epoch 27/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.7862e-04
# Epoch 27: val_loss did not improve from 0.00108
# 34/34 [==============================] - 0s 10ms/step - loss: 2.8256e-04 - val_loss: 0.0019
# Epoch 28/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.5966e-04
# Epoch 28: val_loss did not improve from 0.00108
# 34/34 [==============================] - 1s 17ms/step - loss: 2.5806e-04 - val_loss: 0.0021
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 2.1105e-04
# Epoch 29: val_loss did not improve from 0.00108
# 34/34 [==============================] - 1s 16ms/step - loss: 2.1105e-04 - val_loss: 0.0018
# Epoch 30/100
# 30/34 [=========================>....] - ETA: 0s - loss: 2.0508e-04
# Epoch 30: val_loss did not improve from 0.00108
# 34/34 [==============================] - 1s 15ms/step - loss: 2.0825e-04 - val_loss: 0.0016
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 2.1876e-04
# Epoch 31: val_loss improved from 0.00108 to 0.00095, saving model to model\tmp_checkpoint.h5
# 34/34 [==============================] - 1s 26ms/step - loss: 2.1876e-04 - val_loss: 9.5370e-04
# Epoch 32/100
# 30/34 [=========================>....] - ETA: 0s - loss: 1.9433e-04
# Epoch 32: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 23ms/step - loss: 2.0538e-04 - val_loss: 0.0014
# Epoch 33/100
# 32/34 [===========================>..] - ETA: 0s - loss: 2.4976e-04
# Epoch 33: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 12ms/step - loss: 2.4184e-04 - val_loss: 0.0015
# Epoch 34/100
# 32/34 [===========================>..] - ETA: 0s - loss: 1.9218e-04
# Epoch 34: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 9ms/step - loss: 1.9839e-04 - val_loss: 0.0018
# Epoch 35/100
# 33/34 [============================>.] - ETA: 0s - loss: 1.8182e-04
# Epoch 35: val_loss did not improve from 0.00095
# 34/34 [==============================] - 1s 21ms/step - loss: 1.7976e-04 - val_loss: 0.0011
# Epoch 36/100
# 29/34 [========================>.....] - ETA: 0s - loss: 1.7627e-04
# Epoch 36: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 12ms/step - loss: 1.8116e-04 - val_loss: 0.0010
# Epoch 37/100
# 32/34 [===========================>..] - ETA: 0s - loss: 1.9439e-04
# Epoch 37: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 13ms/step - loss: 1.9472e-04 - val_loss: 0.0010
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 1.9237e-04
# Epoch 38: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 14ms/step - loss: 1.9237e-04 - val_loss: 0.0011
# Epoch 39/100
# 31/34 [==========================>...] - ETA: 0s - loss: 2.2316e-04
# Epoch 39: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 14ms/step - loss: 2.2761e-04 - val_loss: 0.0014
# Epoch 40/100
# 33/34 [============================>.] - ETA: 0s - loss: 2.1161e-04
# Epoch 40: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 14ms/step - loss: 2.1269e-04 - val_loss: 0.0015
# Epoch 41/100
# 33/34 [============================>.] - ETA: 0s - loss: 1.7512e-04
# Epoch 41: val_loss did not improve from 0.00095
# 34/34 [==============================] - 0s 11ms/step - loss: 1.7423e-04 - val_loss: 0.0011
# 9/9 [==============================] - 1s 6ms/step
# 1000길이의 데이터 적용 완료
#  길이: 1000, RMSE:2001.1273209289466
# [2001.1273209289466]
# 1/1 [==============================] - 0s 58ms/step
# Epoch 1/100
# 68/69 [============================>.] - ETA: 0s - loss: 0.0291
# Epoch 1: val_loss improved from inf to 0.00231, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 6s 34ms/step - loss: 0.0287 - val_loss: 0.0023
# Epoch 2/100
# 67/69 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 2: val_loss improved from 0.00231 to 0.00090, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0014 - val_loss: 8.9752e-04
# Epoch 3/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.2640e-04
# Epoch 3: val_loss improved from 0.00090 to 0.00056, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 8.1973e-04 - val_loss: 5.6271e-04
# Epoch 4/100
# 67/69 [============================>.] - ETA: 0s - loss: 5.6133e-04
# Epoch 4: val_loss improved from 0.00056 to 0.00035, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 5.5854e-04 - val_loss: 3.5219e-04
# Epoch 5/100
# 64/69 [==========================>...] - ETA: 0s - loss: 4.1887e-04
# Epoch 5: val_loss improved from 0.00035 to 0.00027, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 4.1022e-04 - val_loss: 2.6566e-04
# Epoch 6/100
# 69/69 [==============================] - ETA: 0s - loss: 3.0723e-04
# Epoch 6: val_loss improved from 0.00027 to 0.00022, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 24ms/step - loss: 3.0723e-04 - val_loss: 2.1687e-04
# Epoch 7/100
# 68/69 [============================>.] - ETA: 0s - loss: 2.4205e-04
# Epoch 7: val_loss improved from 0.00022 to 0.00018, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 3s 40ms/step - loss: 2.4369e-04 - val_loss: 1.8464e-04
# Epoch 8/100
# 68/69 [============================>.] - ETA: 0s - loss: 2.0635e-04
# Epoch 8: val_loss improved from 0.00018 to 0.00012, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 18ms/step - loss: 2.0753e-04 - val_loss: 1.2475e-04
# Epoch 9/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.8690e-04
# Epoch 9: val_loss did not improve from 0.00012
# 69/69 [==============================] - 1s 17ms/step - loss: 1.8701e-04 - val_loss: 1.3839e-04
# Epoch 10/100
# 65/69 [===========================>..] - ETA: 0s - loss: 1.9057e-04
# Epoch 10: val_loss improved from 0.00012 to 0.00011, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 1.8724e-04 - val_loss: 1.1340e-04
# Epoch 11/100
# 65/69 [===========================>..] - ETA: 0s - loss: 1.4771e-04
# Epoch 11: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 13ms/step - loss: 1.4662e-04 - val_loss: 1.2802e-04
# Epoch 12/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.3248e-04
# Epoch 12: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 15ms/step - loss: 1.3386e-04 - val_loss: 1.5111e-04
# Epoch 13/100
# 69/69 [==============================] - ETA: 0s - loss: 1.3594e-04
# Epoch 13: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 18ms/step - loss: 1.3594e-04 - val_loss: 1.2811e-04
# Epoch 14/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.2866e-04
# Epoch 14: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 20ms/step - loss: 1.2723e-04 - val_loss: 1.5593e-04
# Epoch 15/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.1936e-04
# Epoch 15: val_loss improved from 0.00011 to 0.00011, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 17ms/step - loss: 1.1827e-04 - val_loss: 1.0510e-04
# Epoch 16/100
# 69/69 [==============================] - ETA: 0s - loss: 1.6087e-04
# Epoch 16: val_loss did not improve from 0.00011
# 69/69 [==============================] - 1s 18ms/step - loss: 1.6087e-04 - val_loss: 1.3908e-04
# Epoch 17/100
# 69/69 [==============================] - ETA: 0s - loss: 1.1558e-04
# Epoch 17: val_loss improved from 0.00011 to 0.00010, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 19ms/step - loss: 1.1558e-04 - val_loss: 1.0373e-04
# Epoch 18/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.6108e-04
# Epoch 18: val_loss did not improve from 0.00010
# 69/69 [==============================] - 1s 18ms/step - loss: 1.6146e-04 - val_loss: 3.5793e-04
# Epoch 19/100
# 67/69 [============================>.] - ETA: 0s - loss: 1.5214e-04
# Epoch 19: val_loss improved from 0.00010 to 0.00010, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 1.4998e-04 - val_loss: 9.7875e-05
# Epoch 20/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.9854e-05
# Epoch 20: val_loss did not improve from 0.00010
# 69/69 [==============================] - 2s 25ms/step - loss: 1.0024e-04 - val_loss: 1.0145e-04
# Epoch 21/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.9337e-05
# Epoch 21: val_loss improved from 0.00010 to 0.00009, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 2s 23ms/step - loss: 1.0004e-04 - val_loss: 8.9703e-05
# Epoch 22/100
# 68/69 [============================>.] - ETA: 0s - loss: 9.5159e-05
# Epoch 22: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 15ms/step - loss: 9.6753e-05 - val_loss: 9.1667e-05
# Epoch 23/100
# 67/69 [============================>.] - ETA: 0s - loss: 9.3252e-05
# Epoch 23: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 13ms/step - loss: 9.3228e-05 - val_loss: 9.0069e-05
# Epoch 24/100
# 69/69 [==============================] - ETA: 0s - loss: 9.1474e-05
# Epoch 24: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 11ms/step - loss: 9.1474e-05 - val_loss: 1.3956e-04
# Epoch 25/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.0323e-04
# Epoch 25: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 11ms/step - loss: 1.0242e-04 - val_loss: 1.1995e-04
# Epoch 26/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.8197e-05
# Epoch 26: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 12ms/step - loss: 8.8376e-05 - val_loss: 9.4029e-05
# Epoch 27/100
# 65/69 [===========================>..] - ETA: 0s - loss: 9.1535e-05
# Epoch 27: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 13ms/step - loss: 9.0969e-05 - val_loss: 1.0711e-04
# Epoch 28/100
# 68/69 [============================>.] - ETA: 0s - loss: 1.0000e-04
# Epoch 28: val_loss did not improve from 0.00009
# 69/69 [==============================] - 1s 13ms/step - loss: 9.9950e-05 - val_loss: 1.2314e-04
# Epoch 29/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.8684e-05
# Epoch 29: val_loss improved from 0.00009 to 0.00009, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 9.6889e-05 - val_loss: 8.7032e-05
# Epoch 30/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.9886e-05
# Epoch 30: val_loss improved from 0.00009 to 0.00009, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 13ms/step - loss: 9.0412e-05 - val_loss: 8.5366e-05
# Epoch 31/100
# 69/69 [==============================] - ETA: 0s - loss: 9.3831e-05
# Epoch 31: val_loss improved from 0.00009 to 0.00008, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 15ms/step - loss: 9.3831e-05 - val_loss: 8.1032e-05
# Epoch 32/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.8134e-05
# Epoch 32: val_loss improved from 0.00008 to 0.00008, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 20ms/step - loss: 8.7443e-05 - val_loss: 8.0022e-05
# Epoch 33/100
# 69/69 [==============================] - ETA: 0s - loss: 7.9033e-05
# Epoch 33: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 11ms/step - loss: 7.9033e-05 - val_loss: 9.0220e-05
# Epoch 34/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.1222e-05
# Epoch 34: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 13ms/step - loss: 8.1726e-05 - val_loss: 1.1146e-04
# Epoch 35/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.4486e-05
# Epoch 35: val_loss improved from 0.00008 to 0.00008, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 8.4009e-05 - val_loss: 7.8356e-05
# Epoch 36/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.2365e-05
# Epoch 36: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 16ms/step - loss: 7.1964e-05 - val_loss: 8.2256e-05
# Epoch 37/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.4997e-05
# Epoch 37: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 19ms/step - loss: 8.4949e-05 - val_loss: 1.0522e-04
# Epoch 38/100
# 69/69 [==============================] - ETA: 0s - loss: 1.0178e-04
# Epoch 38: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 17ms/step - loss: 1.0178e-04 - val_loss: 1.2919e-04
# Epoch 39/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.7365e-05
# Epoch 39: val_loss did not improve from 0.00008
# 69/69 [==============================] - 2s 22ms/step - loss: 8.7004e-05 - val_loss: 1.3134e-04
# Epoch 40/100
# 64/69 [==========================>...] - ETA: 0s - loss: 9.4751e-05
# Epoch 40: val_loss improved from 0.00008 to 0.00008, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 9.3401e-05 - val_loss: 7.6562e-05
# Epoch 41/100
# 69/69 [==============================] - ETA: 0s - loss: 7.8768e-05
# Epoch 41: val_loss improved from 0.00008 to 0.00008, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 12ms/step - loss: 7.8768e-05 - val_loss: 7.5513e-05
# Epoch 42/100
# 64/69 [==========================>...] - ETA: 0s - loss: 9.2163e-05
# Epoch 42: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 11ms/step - loss: 9.1386e-05 - val_loss: 9.3503e-05
# Epoch 43/100
# 66/69 [===========================>..] - ETA: 0s - loss: 6.7684e-05
# Epoch 43: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 12ms/step - loss: 6.7778e-05 - val_loss: 1.3270e-04
# Epoch 44/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.2674e-05
# Epoch 44: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 12ms/step - loss: 8.0376e-05 - val_loss: 8.5889e-05
# Epoch 45/100
# 68/69 [============================>.] - ETA: 0s - loss: 8.3659e-05
# Epoch 45: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 11ms/step - loss: 8.3708e-05 - val_loss: 7.5842e-05
# Epoch 46/100
# 66/69 [===========================>..] - ETA: 0s - loss: 7.7108e-05
# Epoch 46: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 10ms/step - loss: 7.7081e-05 - val_loss: 9.0175e-05
# Epoch 47/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.6511e-05
# Epoch 47: val_loss did not improve from 0.00008
# 69/69 [==============================] - 1s 10ms/step - loss: 6.6480e-05 - val_loss: 8.6474e-05
# Epoch 48/100
# 64/69 [==========================>...] - ETA: 0s - loss: 6.5665e-05
# Epoch 48: val_loss improved from 0.00008 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 14ms/step - loss: 6.5901e-05 - val_loss: 7.4289e-05
# Epoch 49/100
# 66/69 [===========================>..] - ETA: 0s - loss: 8.1871e-05
# Epoch 49: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 16ms/step - loss: 8.0369e-05 - val_loss: 7.9891e-05
# Epoch 50/100
# 66/69 [===========================>..] - ETA: 0s - loss: 9.0101e-05
# Epoch 50: val_loss improved from 0.00007 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 8.9937e-05 - val_loss: 7.3240e-05
# Epoch 51/100
# 63/69 [==========================>...] - ETA: 0s - loss: 6.6522e-05
# Epoch 51: val_loss improved from 0.00007 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 11ms/step - loss: 6.6683e-05 - val_loss: 7.0534e-05
# Epoch 52/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.8826e-05
# Epoch 52: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 15ms/step - loss: 6.9410e-05 - val_loss: 1.1366e-04
# Epoch 53/100
# 63/69 [==========================>...] - ETA: 0s - loss: 8.1928e-05
# Epoch 53: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 17ms/step - loss: 8.2011e-05 - val_loss: 1.3677e-04
# Epoch 54/100
# 69/69 [==============================] - ETA: 0s - loss: 8.5465e-05
# Epoch 54: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 8.5465e-05 - val_loss: 7.4860e-05
# Epoch 55/100
# 63/69 [==========================>...] - ETA: 0s - loss: 6.1700e-05
# Epoch 55: val_loss improved from 0.00007 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 6.1384e-05 - val_loss: 6.9707e-05
# Epoch 56/100
# 65/69 [===========================>..] - ETA: 0s - loss: 6.1682e-05
# Epoch 56: val_loss improved from 0.00007 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 10ms/step - loss: 6.0246e-05 - val_loss: 6.9308e-05
# Epoch 57/100
# 69/69 [==============================] - ETA: 0s - loss: 8.3247e-05
# Epoch 57: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 15ms/step - loss: 8.3247e-05 - val_loss: 7.4568e-05
# Epoch 58/100
# 63/69 [==========================>...] - ETA: 0s - loss: 7.0345e-05
# Epoch 58: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 13ms/step - loss: 7.2346e-05 - val_loss: 1.8774e-04
# Epoch 59/100
# 65/69 [===========================>..] - ETA: 0s - loss: 9.7881e-05
# Epoch 59: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 9.5903e-05 - val_loss: 7.3440e-05
# Epoch 60/100
# 69/69 [==============================] - ETA: 0s - loss: 5.9035e-05
# Epoch 60: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 5.9035e-05 - val_loss: 8.1570e-05
# Epoch 61/100
# 69/69 [==============================] - ETA: 0s - loss: 6.8160e-05
# Epoch 61: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 19ms/step - loss: 6.8160e-05 - val_loss: 9.9986e-05
# Epoch 62/100
# 69/69 [==============================] - ETA: 0s - loss: 5.9514e-05
# Epoch 62: val_loss improved from 0.00007 to 0.00007, saving model to model\tmp_checkpoint.h5
# 69/69 [==============================] - 1s 21ms/step - loss: 5.9514e-05 - val_loss: 6.8949e-05
# Epoch 63/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.3490e-05
# Epoch 63: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 7.2885e-05 - val_loss: 7.4261e-05
# Epoch 64/100
# 65/69 [===========================>..] - ETA: 0s - loss: 8.4721e-05
# Epoch 64: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 11ms/step - loss: 8.4407e-05 - val_loss: 1.7144e-04
# Epoch 65/100
# 69/69 [==============================] - ETA: 0s - loss: 7.0482e-05
# Epoch 65: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 13ms/step - loss: 7.0482e-05 - val_loss: 6.9051e-05
# Epoch 66/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.7950e-05
# Epoch 66: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 14ms/step - loss: 6.8459e-05 - val_loss: 2.7892e-04
# Epoch 67/100
# 67/69 [============================>.] - ETA: 0s - loss: 7.2845e-05
# Epoch 67: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 7.2169e-05 - val_loss: 9.7284e-05
# Epoch 68/100
# 63/69 [==========================>...] - ETA: 0s - loss: 6.1153e-05
# Epoch 68: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 6.1811e-05 - val_loss: 7.4439e-05
# Epoch 69/100
# 68/69 [============================>.] - ETA: 0s - loss: 6.6132e-05
# Epoch 69: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 6.5927e-05 - val_loss: 9.9120e-05
# Epoch 70/100
# 68/69 [============================>.] - ETA: 0s - loss: 7.1567e-05
# Epoch 70: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 10ms/step - loss: 7.1523e-05 - val_loss: 1.5531e-04
# Epoch 71/100
# 69/69 [==============================] - ETA: 0s - loss: 6.9909e-05
# Epoch 71: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 11ms/step - loss: 6.9909e-05 - val_loss: 7.9013e-05
# Epoch 72/100
# 65/69 [===========================>..] - ETA: 0s - loss: 7.5841e-05
# Epoch 72: val_loss did not improve from 0.00007
# 69/69 [==============================] - 1s 12ms/step - loss: 7.5160e-05 - val_loss: 1.0206e-04
# 19/19 [==============================] - 1s 5ms/step
# 2000길이의 데이터 적용 완료
#  길이: 2000, RMSE:1620.0389288411295
# [2001.1273209289466, 1620.0389288411295]
# 1/1 [==============================] - 0s 36ms/step
# Epoch 1/100
# 101/104 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 1: val_loss improved from inf to 0.00191, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 4s 13ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 2/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.2104e-04
# Epoch 2: val_loss improved from 0.00191 to 0.00165, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 3.1987e-04 - val_loss: 0.0016
# Epoch 3/100
# 100/104 [===========================>..] - ETA: 0s - loss: 2.2842e-04
# Epoch 3: val_loss improved from 0.00165 to 0.00064, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 2.2470e-04 - val_loss: 6.3625e-04
# Epoch 4/100
# 101/104 [============================>.] - ETA: 0s - loss: 1.7972e-04
# Epoch 4: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 14ms/step - loss: 1.7827e-04 - val_loss: 0.0013
# Epoch 5/100
# 102/104 [============================>.] - ETA: 0s - loss: 1.5195e-04
# Epoch 5: val_loss did not improve from 0.00064
# 104/104 [==============================] - 2s 17ms/step - loss: 1.5202e-04 - val_loss: 7.6423e-04
# Epoch 6/100
# 102/104 [============================>.] - ETA: 0s - loss: 1.2346e-04
# Epoch 6: val_loss did not improve from 0.00064
# 104/104 [==============================] - 1s 11ms/step - loss: 1.2221e-04 - val_loss: 6.7225e-04
# Epoch 7/100
# 104/104 [==============================] - ETA: 0s - loss: 1.0460e-04
# Epoch 7: val_loss improved from 0.00064 to 0.00062, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 2s 17ms/step - loss: 1.0460e-04 - val_loss: 6.2243e-04
# Epoch 8/100
# 104/104 [==============================] - ETA: 0s - loss: 9.5599e-05
# Epoch 8: val_loss improved from 0.00062 to 0.00056, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 9.5599e-05 - val_loss: 5.6447e-04
# Epoch 9/100
#  98/104 [===========================>..] - ETA: 0s - loss: 9.6991e-05
# Epoch 9: val_loss improved from 0.00056 to 0.00053, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 9.5699e-05 - val_loss: 5.3009e-04
# Epoch 10/100
#  97/104 [==========================>...] - ETA: 0s - loss: 7.4781e-05
# Epoch 10: val_loss improved from 0.00053 to 0.00052, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 7.4528e-05 - val_loss: 5.1918e-04
# Epoch 11/100
#  99/104 [===========================>..] - ETA: 0s - loss: 8.3971e-05
# Epoch 11: val_loss did not improve from 0.00052
# 104/104 [==============================] - 1s 11ms/step - loss: 8.1934e-05 - val_loss: 5.5220e-04
# Epoch 12/100
# 103/104 [============================>.] - ETA: 0s - loss: 7.7046e-05
# Epoch 12: val_loss improved from 0.00052 to 0.00050, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 13ms/step - loss: 7.6657e-05 - val_loss: 4.9916e-04
# Epoch 13/100
# 100/104 [===========================>..] - ETA: 0s - loss: 5.5988e-05
# Epoch 13: val_loss improved from 0.00050 to 0.00045, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 5.5980e-05 - val_loss: 4.4718e-04
# Epoch 14/100
#  98/104 [===========================>..] - ETA: 0s - loss: 6.3674e-05
# Epoch 14: val_loss improved from 0.00045 to 0.00043, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 6.3419e-05 - val_loss: 4.3110e-04
# Epoch 15/100
# 101/104 [============================>.] - ETA: 0s - loss: 6.3137e-05
# Epoch 15: val_loss did not improve from 0.00043
# 104/104 [==============================] - 1s 13ms/step - loss: 6.4261e-05 - val_loss: 4.5859e-04
# Epoch 16/100
# 103/104 [============================>.] - ETA: 0s - loss: 6.5975e-05
# Epoch 16: val_loss improved from 0.00043 to 0.00042, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 6.5749e-05 - val_loss: 4.2279e-04
# Epoch 17/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.1123e-05
# Epoch 17: val_loss improved from 0.00042 to 0.00041, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 5.1457e-05 - val_loss: 4.1444e-04
# Epoch 18/100
# 104/104 [==============================] - ETA: 0s - loss: 5.1226e-05
# Epoch 18: val_loss did not improve from 0.00041
# 104/104 [==============================] - 1s 9ms/step - loss: 5.1226e-05 - val_loss: 6.3474e-04
# Epoch 19/100
#  99/104 [===========================>..] - ETA: 0s - loss: 5.2464e-05
# Epoch 19: val_loss did not improve from 0.00041
# 104/104 [==============================] - 1s 12ms/step - loss: 5.2466e-05 - val_loss: 4.6348e-04
# Epoch 20/100
# 102/104 [============================>.] - ETA: 0s - loss: 4.8235e-05
# Epoch 20: val_loss improved from 0.00041 to 0.00040, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 4.8226e-05 - val_loss: 4.0211e-04
# Epoch 21/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4973e-05
# Epoch 21: val_loss improved from 0.00040 to 0.00038, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 4.4973e-05 - val_loss: 3.8150e-04
# Epoch 22/100
# 104/104 [==============================] - ETA: 0s - loss: 4.4278e-05
# Epoch 22: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 9ms/step - loss: 4.4278e-05 - val_loss: 4.8154e-04
# Epoch 23/100
#  99/104 [===========================>..] - ETA: 0s - loss: 4.5830e-05
# Epoch 23: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 10ms/step - loss: 4.5969e-05 - val_loss: 5.1085e-04
# Epoch 24/100
# 101/104 [============================>.] - ETA: 0s - loss: 5.3160e-05
# Epoch 24: val_loss improved from 0.00038 to 0.00038, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 5.3747e-05 - val_loss: 3.7922e-04
# Epoch 25/100
#  97/104 [==========================>...] - ETA: 0s - loss: 4.8129e-05
# Epoch 25: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 10ms/step - loss: 4.7805e-05 - val_loss: 4.3671e-04
# Epoch 26/100
# 104/104 [==============================] - ETA: 0s - loss: 3.9523e-05
# Epoch 26: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 9ms/step - loss: 3.9523e-05 - val_loss: 5.9273e-04
# Epoch 27/100
# 103/104 [============================>.] - ETA: 0s - loss: 4.7145e-05
# Epoch 27: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 11ms/step - loss: 4.6993e-05 - val_loss: 4.6926e-04
# Epoch 28/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.6840e-05
# Epoch 28: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 10ms/step - loss: 3.7015e-05 - val_loss: 3.8985e-04
# Epoch 29/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.1417e-05
# Epoch 29: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 9ms/step - loss: 4.2506e-05 - val_loss: 4.1732e-04
# Epoch 30/100
#  98/104 [===========================>..] - ETA: 0s - loss: 4.4558e-05
# Epoch 30: val_loss did not improve from 0.00038
# 104/104 [==============================] - 1s 9ms/step - loss: 4.4928e-05 - val_loss: 5.1173e-04
# Epoch 31/100
# 104/104 [==============================] - ETA: 0s - loss: 4.1647e-05
# Epoch 31: val_loss improved from 0.00038 to 0.00036, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 14ms/step - loss: 4.1647e-05 - val_loss: 3.6275e-04
# Epoch 32/100
#  97/104 [==========================>...] - ETA: 0s - loss: 4.9612e-05
# Epoch 32: val_loss did not improve from 0.00036
# 104/104 [==============================] - 1s 9ms/step - loss: 5.0164e-05 - val_loss: 4.0032e-04
# Epoch 33/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.5677e-05
# Epoch 33: val_loss did not improve from 0.00036
# 104/104 [==============================] - 1s 11ms/step - loss: 3.6506e-05 - val_loss: 5.7931e-04
# Epoch 34/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.6221e-05
# Epoch 34: val_loss did not improve from 0.00036
# 104/104 [==============================] - 1s 13ms/step - loss: 3.6202e-05 - val_loss: 3.6537e-04
# Epoch 35/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.3905e-05
# Epoch 35: val_loss did not improve from 0.00036
# 104/104 [==============================] - 1s 9ms/step - loss: 3.3955e-05 - val_loss: 3.7113e-04
# Epoch 36/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.7597e-05
# Epoch 36: val_loss did not improve from 0.00036
# 104/104 [==============================] - 1s 12ms/step - loss: 3.7494e-05 - val_loss: 4.3535e-04
# Epoch 37/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.3374e-05
# Epoch 37: val_loss improved from 0.00036 to 0.00031, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 11ms/step - loss: 3.3729e-05 - val_loss: 3.1354e-04
# Epoch 38/100
#  98/104 [===========================>..] - ETA: 0s - loss: 3.6152e-05
# Epoch 38: val_loss did not improve from 0.00031
# 104/104 [==============================] - 1s 10ms/step - loss: 3.5820e-05 - val_loss: 3.3406e-04
# Epoch 39/100
#  99/104 [===========================>..] - ETA: 0s - loss: 4.1162e-05
# Epoch 39: val_loss improved from 0.00031 to 0.00030, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 9ms/step - loss: 4.0846e-05 - val_loss: 3.0331e-04
# Epoch 40/100
#  98/104 [===========================>..] - ETA: 0s - loss: 4.0719e-05
# Epoch 40: val_loss improved from 0.00030 to 0.00030, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 4.0960e-05 - val_loss: 2.9968e-04
# Epoch 41/100
# 100/104 [===========================>..] - ETA: 0s - loss: 4.0134e-05
# Epoch 41: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 13ms/step - loss: 3.9556e-05 - val_loss: 4.3389e-04
# Epoch 42/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.6302e-05
# Epoch 42: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 9ms/step - loss: 3.5912e-05 - val_loss: 5.0119e-04
# Epoch 43/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.7060e-05
# Epoch 43: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 10ms/step - loss: 3.7153e-05 - val_loss: 3.6755e-04
# Epoch 44/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.1494e-05
# Epoch 44: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 10ms/step - loss: 3.1605e-05 - val_loss: 3.9908e-04
# Epoch 45/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.2529e-05
# Epoch 45: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 9ms/step - loss: 3.3026e-05 - val_loss: 4.6642e-04
# Epoch 46/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.8421e-05
# Epoch 46: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 9ms/step - loss: 3.8205e-05 - val_loss: 2.9987e-04
# Epoch 47/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.9766e-05
# Epoch 47: val_loss did not improve from 0.00030
# 104/104 [==============================] - 1s 9ms/step - loss: 3.9996e-05 - val_loss: 6.1851e-04
# Epoch 48/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.3239e-05
# Epoch 48: val_loss improved from 0.00030 to 0.00029, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 3.2858e-05 - val_loss: 2.8560e-04
# Epoch 49/100
# 104/104 [==============================] - ETA: 0s - loss: 3.4163e-05
# Epoch 49: val_loss did not improve from 0.00029
# 104/104 [==============================] - 1s 14ms/step - loss: 3.4163e-05 - val_loss: 3.6794e-04
# Epoch 50/100
# 101/104 [============================>.] - ETA: 0s - loss: 3.4000e-05
# Epoch 50: val_loss improved from 0.00029 to 0.00025, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 12ms/step - loss: 3.4159e-05 - val_loss: 2.4869e-04
# Epoch 51/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.3214e-05
# Epoch 51: val_loss improved from 0.00025 to 0.00023, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 3.3242e-05 - val_loss: 2.3332e-04
# Epoch 52/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.9764e-05
# Epoch 52: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 14ms/step - loss: 3.9807e-05 - val_loss: 3.8841e-04
# Epoch 53/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.0941e-05
# Epoch 53: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 11ms/step - loss: 3.0966e-05 - val_loss: 2.8328e-04
# Epoch 54/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.4003e-05
# Epoch 54: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 9ms/step - loss: 3.3838e-05 - val_loss: 2.3494e-04
# Epoch 55/100
#  97/104 [==========================>...] - ETA: 0s - loss: 4.2950e-05
# Epoch 55: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 9ms/step - loss: 4.4690e-05 - val_loss: 2.3548e-04
# Epoch 56/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.9413e-05
# Epoch 56: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 9ms/step - loss: 3.9279e-05 - val_loss: 2.7325e-04
# Epoch 57/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.1094e-05
# Epoch 57: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 10ms/step - loss: 3.0861e-05 - val_loss: 3.4680e-04
# Epoch 58/100
#  98/104 [===========================>..] - ETA: 0s - loss: 3.3176e-05
# Epoch 58: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 9ms/step - loss: 3.2514e-05 - val_loss: 2.8556e-04
# Epoch 59/100
#  98/104 [===========================>..] - ETA: 0s - loss: 4.0115e-05
# Epoch 59: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 9ms/step - loss: 4.0753e-05 - val_loss: 2.4848e-04
# Epoch 60/100
# 104/104 [==============================] - ETA: 0s - loss: 3.0732e-05
# Epoch 60: val_loss did not improve from 0.00023
# 104/104 [==============================] - 1s 11ms/step - loss: 3.0732e-05 - val_loss: 2.8744e-04
# Epoch 61/100
#  98/104 [===========================>..] - ETA: 0s - loss: 2.7519e-05
# Epoch 61: val_loss improved from 0.00023 to 0.00020, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 2.8579e-05 - val_loss: 1.9721e-04
# Epoch 62/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.1405e-05
# Epoch 62: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 3.1276e-05 - val_loss: 2.4206e-04
# Epoch 63/100
# 104/104 [==============================] - ETA: 0s - loss: 2.7935e-05
# Epoch 63: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 2.7935e-05 - val_loss: 2.4493e-04
# Epoch 64/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.4127e-05
# Epoch 64: val_loss improved from 0.00020 to 0.00020, saving model to model\tmp_checkpoint.h5
# 104/104 [==============================] - 1s 10ms/step - loss: 3.4201e-05 - val_loss: 1.9587e-04
# Epoch 65/100
#  99/104 [===========================>..] - ETA: 0s - loss: 3.6112e-05
# Epoch 65: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 10ms/step - loss: 3.6275e-05 - val_loss: 4.4880e-04
# Epoch 66/100
# 103/104 [============================>.] - ETA: 0s - loss: 3.2988e-05
# Epoch 66: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 3.2963e-05 - val_loss: 2.2664e-04
# Epoch 67/100
#  98/104 [===========================>..] - ETA: 0s - loss: 3.4542e-05
# Epoch 67: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 11ms/step - loss: 3.4151e-05 - val_loss: 3.0469e-04
# Epoch 68/100
#  98/104 [===========================>..] - ETA: 0s - loss: 2.9257e-05
# Epoch 68: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 2.9413e-05 - val_loss: 2.1295e-04
# Epoch 69/100
#  98/104 [===========================>..] - ETA: 0s - loss: 3.8973e-05
# Epoch 69: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 3.8378e-05 - val_loss: 2.3759e-04
# Epoch 70/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.3471e-05
# Epoch 70: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 3.3401e-05 - val_loss: 2.9521e-04
# Epoch 71/100
# 100/104 [===========================>..] - ETA: 0s - loss: 3.0130e-05
# Epoch 71: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 9ms/step - loss: 2.9974e-05 - val_loss: 2.7741e-04
# Epoch 72/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.2100e-05
# Epoch 72: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 10ms/step - loss: 3.2041e-05 - val_loss: 2.0002e-04
# Epoch 73/100
# 102/104 [============================>.] - ETA: 0s - loss: 2.8018e-05
# Epoch 73: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 10ms/step - loss: 2.8377e-05 - val_loss: 2.4152e-04
# Epoch 74/100
# 102/104 [============================>.] - ETA: 0s - loss: 3.2190e-05
# Epoch 74: val_loss did not improve from 0.00020
# 104/104 [==============================] - 1s 11ms/step - loss: 3.2210e-05 - val_loss: 2.2977e-04
# 28/28 [==============================] - 1s 4ms/step
# 3000길이의 데이터 적용 완료
#  길이: 3000, RMSE:3813.426286039069
# [2001.1273209289466, 1620.0389288411295, 3813.426286039069]
# 1/1 [==============================] - 0s 61ms/step
# Epoch 1/100
# 134/139 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 1: val_loss improved from inf to 0.00058, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 4s 16ms/step - loss: 0.0011 - val_loss: 5.8408e-04
# Epoch 2/100
# 138/139 [============================>.] - ETA: 0s - loss: 2.4946e-04
# Epoch 2: val_loss improved from 0.00058 to 0.00028, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 12ms/step - loss: 2.4937e-04 - val_loss: 2.8300e-04
# Epoch 3/100
# 136/139 [============================>.] - ETA: 0s - loss: 1.3521e-04
# Epoch 3: val_loss improved from 0.00028 to 0.00023, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 2s 14ms/step - loss: 1.3472e-04 - val_loss: 2.2785e-04
# Epoch 4/100
# 136/139 [============================>.] - ETA: 0s - loss: 8.6698e-05
# Epoch 4: val_loss improved from 0.00023 to 0.00021, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 8.6879e-05 - val_loss: 2.1422e-04
# Epoch 5/100
# 135/139 [============================>.] - ETA: 0s - loss: 8.0889e-05
# Epoch 5: val_loss improved from 0.00021 to 0.00016, saving model to model\tmp_checkpoint.h5
# 139/139 [==============================] - 1s 10ms/step - loss: 8.0439e-05 - val_loss: 1.5945e-04
# Epoch 6/100
# 139/139 [==============================] - ETA: 0s - loss: 6.4462e-05
# Epoch 6: val_loss improved from 0.00016 to 0.00011, saving model to model\tmp_checkpoint.h5
# ...
# 314/314 [==============================] - 3s 9ms/step - loss: 2.9193e-06 - val_loss: 1.2702e-05
# Epoch 35/100
# 312/314 [============================>.] - ETA: 0s - loss: 3.4890e-06
# Epoch 35: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 3.4913e-06 - val_loss: 2.0599e-05
# Epoch 36/100
# 313/314 [============================>.] - ETA: 0s - loss: 2.8276e-06
# Epoch 36: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.8255e-06 - val_loss: 1.6512e-05
# Epoch 37/100
# 314/314 [==============================] - ETA: 0s - loss: 2.9841e-06
# Epoch 37: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 10ms/step - loss: 2.9841e-06 - val_loss: 1.3180e-05
# Epoch 38/100
# 309/314 [============================>.] - ETA: 0s - loss: 3.2048e-06
# Epoch 38: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 11ms/step - loss: 3.1914e-06 - val_loss: 1.4380e-05
# Epoch 39/100
# 311/314 [============================>.] - ETA: 0s - loss: 3.0003e-06
# Epoch 39: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.9891e-06 - val_loss: 1.5153e-05
# Epoch 40/100
# 308/314 [============================>.] - ETA: 0s - loss: 3.0858e-06
# Epoch 40: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 3.0741e-06 - val_loss: 1.5716e-05
# Epoch 41/100
# 314/314 [==============================] - ETA: 0s - loss: 3.1383e-06
# Epoch 41: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 3.1383e-06 - val_loss: 1.4578e-05
# Epoch 42/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.9080e-06
# Epoch 42: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.9083e-06 - val_loss: 1.5342e-05
# Epoch 43/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.7512e-06
# Epoch 43: val_loss improved from 0.00001 to 0.00001, saving model to model\tmp_checkpoint.h5
# 314/314 [==============================] - 3s 10ms/step - loss: 2.7488e-06 - val_loss: 1.2122e-05
# Epoch 44/100
# 306/314 [============================>.] - ETA: 0s - loss: 2.5580e-06
# Epoch 44: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 8ms/step - loss: 2.5385e-06 - val_loss: 1.5060e-05
# Epoch 45/100
# 311/314 [============================>.] - ETA: 0s - loss: 2.7741e-06
# Epoch 45: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.7654e-06 - val_loss: 1.2448e-05
# Epoch 46/100
# 308/314 [============================>.] - ETA: 0s - loss: 3.0954e-06
# Epoch 46: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 3.0839e-06 - val_loss: 2.7530e-05
# Epoch 47/100
# 310/314 [============================>.] - ETA: 0s - loss: 3.0077e-06
# Epoch 47: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 10ms/step - loss: 3.0189e-06 - val_loss: 1.3446e-05
# Epoch 48/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.7057e-06
# Epoch 48: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.6939e-06 - val_loss: 1.2840e-05
# Epoch 49/100
# 309/314 [============================>.] - ETA: 0s - loss: 2.5687e-06
# Epoch 49: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.5646e-06 - val_loss: 1.2361e-05
# Epoch 50/100
# 312/314 [============================>.] - ETA: 0s - loss: 2.8650e-06
# Epoch 50: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.8599e-06 - val_loss: 2.8858e-05
# Epoch 51/100
# 313/314 [============================>.] - ETA: 0s - loss: 2.5392e-06
# Epoch 51: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.5364e-06 - val_loss: 1.6706e-05
# Epoch 52/100
# 310/314 [============================>.] - ETA: 0s - loss: 2.6418e-06
# Epoch 52: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.6628e-06 - val_loss: 1.2981e-05
# Epoch 53/100
# 312/314 [============================>.] - ETA: 0s - loss: 2.4948e-06
# Epoch 53: val_loss did not improve from 0.00001
# 314/314 [==============================] - 3s 9ms/step - loss: 2.4943e-06 - val_loss: 1.4443e-05
# 84/84 [==============================] - 1s 5ms/step
# 9000길이의 데이터 적용 완료
#  길이: 9000, RMSE:10174.983462272878
# [2001.1273209289466, 1620.0389288411295, 3813.426286039069, 3929.6648530234993, 2960.242404715908, 3109.5061072429835, 8816.530345902453, 9517.918645244437, 10174.983462272878]
# 1/1 [==============================] - 0s 44ms/step
# Epoch 1/100
# 339/341 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 1: val_loss improved from inf to 0.00061, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 6s 12ms/step - loss: 0.0028 - val_loss: 6.0802e-04
# Epoch 2/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.1880e-04
# Epoch 2: val_loss improved from 0.00061 to 0.00028, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 1.1842e-04 - val_loss: 2.8052e-04
# Epoch 3/100
# 338/341 [============================>.] - ETA: 0s - loss: 5.9763e-05
# Epoch 3: val_loss improved from 0.00028 to 0.00013, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 5.9789e-05 - val_loss: 1.2799e-04
# Epoch 4/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.7987e-05
# Epoch 4: val_loss did not improve from 0.00013
# 341/341 [==============================] - 4s 13ms/step - loss: 3.7942e-05 - val_loss: 1.4868e-04
# Epoch 5/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.7457e-05
# Epoch 5: val_loss improved from 0.00013 to 0.00010, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 2.7442e-05 - val_loss: 1.0346e-04
# Epoch 6/100
# 341/341 [==============================] - ETA: 0s - loss: 2.0865e-05
# Epoch 6: val_loss improved from 0.00010 to 0.00006, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 2.0865e-05 - val_loss: 6.0931e-05
# Epoch 7/100
# 341/341 [==============================] - ETA: 0s - loss: 1.7564e-05
# Epoch 7: val_loss did not improve from 0.00006
# 341/341 [==============================] - 4s 12ms/step - loss: 1.7564e-05 - val_loss: 9.1703e-05
# Epoch 8/100
# 336/341 [============================>.] - ETA: 0s - loss: 1.4533e-05
# Epoch 8: val_loss improved from 0.00006 to 0.00005, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 1.4542e-05 - val_loss: 4.9439e-05
# Epoch 9/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.2252e-05
# Epoch 9: val_loss improved from 0.00005 to 0.00004, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 1.2213e-05 - val_loss: 3.6966e-05
# Epoch 10/100
# 338/341 [============================>.] - ETA: 0s - loss: 1.0783e-05
# Epoch 10: val_loss did not improve from 0.00004
# 341/341 [==============================] - 4s 11ms/step - loss: 1.0783e-05 - val_loss: 4.3158e-05
# Epoch 11/100
# 337/341 [============================>.] - ETA: 0s - loss: 1.0414e-05
# Epoch 11: val_loss improved from 0.00004 to 0.00003, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 1.0352e-05 - val_loss: 3.2302e-05
# Epoch 12/100
# 339/341 [============================>.] - ETA: 0s - loss: 8.5399e-06
# Epoch 12: val_loss improved from 0.00003 to 0.00003, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 8.5953e-06 - val_loss: 2.8397e-05
# Epoch 13/100
# 341/341 [==============================] - ETA: 0s - loss: 7.6064e-06
# Epoch 13: val_loss improved from 0.00003 to 0.00003, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 7.6064e-06 - val_loss: 2.7932e-05
# Epoch 14/100
# 341/341 [==============================] - ETA: 0s - loss: 7.2428e-06
# Epoch 14: val_loss improved from 0.00003 to 0.00002, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 7.2428e-06 - val_loss: 2.1539e-05
# Epoch 15/100
# 338/341 [============================>.] - ETA: 0s - loss: 7.1015e-06
# Epoch 15: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 7.0827e-06 - val_loss: 2.2483e-05
# Epoch 16/100
# 338/341 [============================>.] - ETA: 0s - loss: 6.3186e-06
# Epoch 16: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 6.3404e-06 - val_loss: 2.4683e-05
# Epoch 17/100
# 340/341 [============================>.] - ETA: 0s - loss: 5.3165e-06
# Epoch 17: val_loss improved from 0.00002 to 0.00002, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 12ms/step - loss: 5.3198e-06 - val_loss: 2.0782e-05
# Epoch 18/100
# 337/341 [============================>.] - ETA: 0s - loss: 5.6066e-06
# Epoch 18: val_loss improved from 0.00002 to 0.00002, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 5.5734e-06 - val_loss: 1.5911e-05
# Epoch 19/100
# 341/341 [==============================] - ETA: 0s - loss: 5.4017e-06
# Epoch 19: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 5.4017e-06 - val_loss: 1.9770e-05
# Epoch 20/100
# 341/341 [==============================] - ETA: 0s - loss: 4.4953e-06
# Epoch 20: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 4.4953e-06 - val_loss: 1.9992e-05
# Epoch 21/100
# 338/341 [============================>.] - ETA: 0s - loss: 4.4553e-06
# Epoch 21: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 12ms/step - loss: 4.4456e-06 - val_loss: 3.8873e-05
# Epoch 22/100
# 338/341 [============================>.] - ETA: 0s - loss: 4.7161e-06
# Epoch 22: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 12ms/step - loss: 4.7080e-06 - val_loss: 1.7643e-05
# Epoch 23/100
# 336/341 [============================>.] - ETA: 0s - loss: 3.6958e-06
# Epoch 23: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.6916e-06 - val_loss: 1.6698e-05
# Epoch 24/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.8169e-06
# Epoch 24: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.8027e-06 - val_loss: 1.8386e-05
# Epoch 25/100
# 341/341 [==============================] - ETA: 0s - loss: 3.5722e-06
# Epoch 25: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.5722e-06 - val_loss: 2.3896e-05
# Epoch 26/100
# 337/341 [============================>.] - ETA: 0s - loss: 3.8992e-06
# Epoch 26: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.9238e-06 - val_loss: 1.6780e-05
# Epoch 27/100
# 339/341 [============================>.] - ETA: 0s - loss: 3.3323e-06
# Epoch 27: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.3309e-06 - val_loss: 2.1184e-05
# Epoch 28/100
# 340/341 [============================>.] - ETA: 0s - loss: 3.2290e-06
# Epoch 28: val_loss improved from 0.00002 to 0.00002, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 3.2272e-06 - val_loss: 1.5289e-05
# Epoch 29/100
# 335/341 [============================>.] - ETA: 0s - loss: 3.6738e-06
# Epoch 29: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.6812e-06 - val_loss: 2.0976e-05
# Epoch 30/100
# 341/341 [==============================] - ETA: 0s - loss: 3.4997e-06
# Epoch 30: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.4997e-06 - val_loss: 2.6950e-05
# Epoch 31/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.2299e-06
# Epoch 31: val_loss did not improve from 0.00002
# 341/341 [==============================] - 4s 11ms/step - loss: 3.2539e-06 - val_loss: 1.5898e-05
# Epoch 32/100
# 338/341 [============================>.] - ETA: 0s - loss: 3.4259e-06
# Epoch 32: val_loss improved from 0.00002 to 0.00001, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 3.4074e-06 - val_loss: 1.2923e-05
# Epoch 33/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.7547e-06
# Epoch 33: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.7831e-06 - val_loss: 1.3576e-05
# Epoch 34/100
# 341/341 [==============================] - ETA: 0s - loss: 3.0021e-06
# Epoch 34: val_loss improved from 0.00001 to 0.00001, saving model to model\tmp_checkpoint.h5
# 341/341 [==============================] - 4s 11ms/step - loss: 3.0021e-06 - val_loss: 1.0850e-05
# Epoch 35/100
# 341/341 [==============================] - ETA: 0s - loss: 2.6287e-06
# Epoch 35: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.6287e-06 - val_loss: 1.9275e-05
# Epoch 36/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5267e-06
# Epoch 36: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.5267e-06 - val_loss: 1.6911e-05
# Epoch 37/100
# 341/341 [==============================] - ETA: 0s - loss: 2.5200e-06
# Epoch 37: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.5200e-06 - val_loss: 1.9115e-05
# Epoch 38/100
# 339/341 [============================>.] - ETA: 0s - loss: 2.7394e-06
# Epoch 38: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.7463e-06 - val_loss: 1.1081e-05
# Epoch 39/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.5401e-06
# Epoch 39: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.5363e-06 - val_loss: 2.6329e-05
# Epoch 40/100
# 336/341 [============================>.] - ETA: 0s - loss: 2.4467e-06
# Epoch 40: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.4848e-06 - val_loss: 1.2428e-05
# Epoch 41/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.6564e-06
# Epoch 41: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.6573e-06 - val_loss: 1.2895e-05
# Epoch 42/100
# 339/341 [============================>.] - ETA: 0s - loss: 2.2375e-06
# Epoch 42: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.2497e-06 - val_loss: 1.2271e-05
# Epoch 43/100
# 338/341 [============================>.] - ETA: 0s - loss: 2.2009e-06
# Epoch 43: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.2069e-06 - val_loss: 1.2527e-05
# Epoch 44/100
# 340/341 [============================>.] - ETA: 0s - loss: 2.4512e-06
# Epoch 44: val_loss did not improve from 0.00001
# 341/341 [==============================] - 4s 11ms/step - loss: 2.4473e-06 - val_loss: 2.1137e-05
# 91/91 [==============================] - 1s 5ms/step
# 10000길이의 데이터 적용 완료
#  길이: 10000, RMSE:37825.08328404532
# [2001.1273209289466, 1620.0389288411295, 3813.426286039069, 3929.6648530234993, 2960.242404715908, 3109.5061072429835, 8816.530345902453, 9517.918645244437, 10174.983462272878, 37825.08328404532]
# 1/1 [==============================] - 0s 40ms/step

# %%
tmp = min(result)
index = result.index(tmp)
(index + 1)*1000
# Out:
# 2000

# %%
import matplotlib.pyplot as plt
plt.plot(result)

# %%
result
# Out:
# [2001.1273209289466,
#  1620.0389288411295,
#  3813.426286039069,
#  3929.6648530234993,
#  2960.242404715908,
#  3109.5061072429835,
#  8816.530345902453,
#  9517.918645244437,
#  10174.983462272878,
#  37825.08328404532]

# %%
predict
# Out:
# [array([[69520.1]], dtype=float32),
#  array([[68295.53]], dtype=float32),
#  array([[66581.88]], dtype=float32),
#  array([[63250.93]], dtype=float32),
#  array([[62335.996]], dtype=float32),
#  array([[72517.2]], dtype=float32),
#  array([[79378.]], dtype=float32),
#  array([[67218.664]], dtype=float32),
#  array([[79223.35]], dtype=float32),
#  array([[-1032.3619]], dtype=float32)]
